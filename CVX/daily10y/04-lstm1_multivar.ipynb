# %% [markdown]
# <a href="https://colab.research.google.com/github/rklepov/hse-cs-ml-2018-2019-grad-work/blob/CVX-10yr/CVX/daily10y/04-lstm1_multivar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # *Многомерная модель на LSTM* (1 слой)
#
# В качестве признаков используются цены, объём торгов и некоторое число индикаторов (всего 18 признаков)

# %%
import os
import glob
import datetime
import pickle

import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.set_context('paper')

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from pandas_datareader import data as pdr

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
import tensorflow as tf
# tf.test.is_gpu_available()
tf.__version__
# Out:
# '2.0.0'

# %%
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Input, Dense, LSTM, GRU, Flatten, ReLU, LeakyReLU, Dropout, BatchNormalization
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers import Nadam

# %%
from mdp import TimeSeries
from mdp import MarketData
from mdp import MovingWindowFeatures
from mdp import ClassificationGenerator, RegressionGenerator, MultitaskGenerator
from mdp import invert_log_ret

import mdp.utils as utils
import mdp.plotHelpers as plotHelpers

# %%
import importlib

import mdp

importlib.reload(mdp)
importlib.reload(mdp.datasetGenerator)
importlib.reload(mdp.marketData)
importlib.reload(mdp.movingWindowFeatures)
importlib.reload(mdp.timeSeries)
importlib.reload(mdp.plotHelpers)
importlib.reload(mdp.utils);

# %% [markdown]
# # *Параметры*

# %%
INSTRUMENT = 'CVX' # Chevron corp
START_FROM = '2008-11-14'
END_DATE = '2020-01-01'
WINDOW_SIZE = 30
FORECAST_OFFSET=1
BATCH_SIZE = 32
VAL_SPLIT = '2019-01-01'
TEST_SPLIT = '2019-06-01'
FORCE_TRAIN = True

# %% [markdown]
# # *Исходные данные*
#
# Загрузка данных и вычисление индикаторов.

# %%
instr = MarketData.create_from_tiingo(INSTRUMENT, start=START_FROM, end=END_DATE)

# %%
instr.feature_names
# Out:
# ['o',
#  'h',
#  'l',
#  'c',
#  'v',
#  'ema14',
#  'ema30',
#  'macd',
#  'macd_signal',
#  'rsi14',
#  'bband20_upper',
#  'bband20_middle',
#  'bband20_lower',
#  'willr14',
#  'stochk',
#  'stochd',
#  'adline',
#  'adosc']

# %% [markdown]
# ## Целевая переменная

# %% [markdown]
# Цена закрытия.

# %%
orig_target = instr.c

# %%
def plot_transformed_series(instrument, series, orig_display_name, transformed_display_name):
    plotHelpers.plot_transformed_timeseries(
        instrument.instrument,
        series,
        title_orig = orig_display_name,
        xlabel_orig = 'Date',
        ylabel_orig = orig_display_name,
        title_transformed = transformed_display_name,
        xlabel_transformed = 'Date',
        ylabel_transformed = transformed_display_name
    )

# %% [markdown]
# Переходим к логарифмической доходности.

# %%
transformed_target = instr.c.transform(transforms={'ratios' : {}, 'ln' : {}})

# %%
plot_transformed_series(instr,
                        transformed_target,
                        'Daily close price, USD', 'Daily log return')

# %% [markdown]
# ## Трансформация признаков
#
# Приведение временных рядов к стационарности.

# %%
def make_feature_selector():
    price_transformer = lambda: {'ratios': {}, 'ln': {}}
    diff_transformer = lambda o: {'diffs': {'order': o}}
    identity_transformer = lambda: {}
    feature_transformations = {
        'o': price_transformer(),
        'h': price_transformer(),
        'l': price_transformer(),
        'c': price_transformer(),
        'v': diff_transformer(1),
        'ema14': diff_transformer(1),
        'ema30': diff_transformer(1),
        'macd': identity_transformer(),
        'macd_signal': identity_transformer(),
        'rsi14': diff_transformer(1),
        'bband20_upper': diff_transformer(1),
        'bband20_middle': diff_transformer(1),
        'bband20_lower': diff_transformer(1),
        'willr14': identity_transformer(),
        'stochd': identity_transformer(),
        'stochk': identity_transformer(),
        'adline': diff_transformer(1),
        'adosc': diff_transformer(1)
    }
    return feature_transformations

# %%
instr_transformed = instr.select_transform(make_feature_selector())

# %%
transformed_target = instr_transformed.c

# %% [markdown]
# ## Обучающая, валидационная и тестовая выборки

# %%
instr_train, instr_val_test = instr_transformed.train_test_split(VAL_SPLIT, window_size=WINDOW_SIZE,
                                                                 scaler=StandardScaler)
#                                                                  scaler=MinMaxScaler,
#                                                                  scaler_kwargs={'feature_range': (-1, 1)})

instr_val, instr_test = instr_val_test.train_test_split(TEST_SPLIT, window_size=WINDOW_SIZE, scaler=None)

len(instr_train), len(instr_val), len(instr_test)
# Out:
# (2514, 134, 178)

# %% [markdown]
# Все отмасштабированные признаки на одном графике (для валидационного датасета):

# %%
plotHelpers.plot_all_features(instr_val)

# %% [markdown]
# ## Признаки - скользящие окна

# %%
train_mwf = MovingWindowFeatures.create(instr_train.c, [instr_train], instr_train.feature_names, window_size=WINDOW_SIZE)
val_mwf = MovingWindowFeatures.create(instr_val.c, [instr_val], instr_val.feature_names, window_size=WINDOW_SIZE)
test_mwf = MovingWindowFeatures.create(instr_test.c, [instr_test], instr_test.feature_names, window_size=WINDOW_SIZE)

len(instr_train), len(train_mwf), train_mwf.features.shape
# Out:
# (2514, 2484, (2484, 30, 18))

# %% [markdown]
# Проверка, что скользящие окна соответствуют исходным данным.
#
# Возьмём произвольный признак и произвольное окно (строка #**41**). Проверим, что данные в точности совпадают:

# %%
def check_data(md, mwf, row):
    col = np.random.randint(len(mwf.feature_names))
    feature = mwf.feature_names[col]
    check = (getattr(md, feature).data[row:row + mwf.window_size] == mwf.features[row, :, col]).all()
    assert check
    return feature, check

check_data(instr_train, train_mwf, 41)
# Out:
# ('bband20_lower', True)

# %% [markdown]
# # *Модели*

# %% [markdown]
# Модель с одним LSTM слоем.

# %%
def build_lstm_layers(input_shape, latent_dim=16):
    # формат входа: матрица (окно; признак)
    inp = Input(input_shape, name='input')

    lstm = LSTM(latent_dim, return_sequences=True,
                    recurrent_dropout=0.2, dropout=0.2,
                    bias_initializer='he_uniform',
                    bias_regularizer=L1L2(0.01, 0.02),
                    kernel_regularizer=L1L2(0.01, 0.02),
                    recurrent_regularizer=L1L2(0.01, 0.02)
               )(inp)
    
    lstm = Flatten()(lstm)
    
    return inp, lstm

# %% [markdown]
# #### Пути сохранения моделей:

# %%
model_path_root = 'models'
model_type_name = 'lstm1_multivar'

def make_model_save_dir(path_root, type_name, class_name):
    save_dir = os.path.join(path_root, type_name, class_name)
    os.makedirs(save_dir, exist_ok=True)
    return save_dir

# %% [markdown]
# #### Общие коллбэки:

# %%
# уменьшение learning rate в случае, если loss не изменяется
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001, verbose=1)

# уменьшение learning rate в 2 раза каждую 5-ю эпоху
def lr_decay(e, lr):
    return lr * (1 - 0.5 * (0 == (e + 1) % 5))

lr_scheduler = LearningRateScheduler(schedule=lr_decay, verbose=1)

# %% [markdown]
# ## Задача регрессии
#
# Непосредственное прогнозирование цены следующего периода.

# %%
train_regr_gen = RegressionGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_regr_gen = RegressionGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_regr_gen = RegressionGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# Следующие числа соответствуют значению параметра `steps_per_epoch` метода [`fit_generator`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit_generator "tf.keras.layers.SimpleRNN &nbsp;|&nbsp; TensorFlow Core r2.0") - то есть это число батчей, которые генератор выдаст за одну эпоху обучения (если класс генератора поддерживает метод `len()`, то данный параметр можно не указывать).

# %%
len(train_regr_gen), len(val_regr_gen), len(test_regr_gen)
# Out:
# (78, 4, 5)

# %% [markdown]
# Один сэмпл данных представляет собой матрицу размером *(длина окна; число признаков)*

# %%
train_regr_gen.input_shape
# Out:
# (30, 18)

# %% [markdown]
# ### Модель для задачи регрессии

# %%
model_class_name = 'regression'

# %%
def build_regression_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=64)

    regr = Dense(128)(lstm)
    regr = LeakyReLU()(regr)
    regr = BatchNormalization()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    return Model(inputs=[inp], outputs=[regr])

# %%
multivariate_regression_lstm = build_regression_model(train_regr_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:
# [`Nadam`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Nadam) (*Adam with Nestrov momentum*).

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Функция потерь:
#
# В качестве функции потерь будем использовать [MSE](https://www.tensorflow.org/api_docs/python/tf/keras/losses/MSE) (чтобы штрафовать за большие отклонения). Xотя хорошая функция потерь в контексте темы данной задачи - это [вопрос сложный](https://github.com/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Chapter5_LossFunctions/Ch5_LossFunctions_PyMC3.ipynb). В частности, здесь нам, очевидно, помимо абсолютного значения отклонения также важен его знак.

# %%
multivariate_regression_lstm.compile(optimizer=optimizer,
                                     loss={'regr': 'mse'},
                                     metrics={'regr': 'mae'})

multivariate_regression_lstm.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 30, 18)]          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 30, 64)            21248
# _________________________________________________________________
# flatten (Flatten)            (None, 1920)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               245888
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 128)               0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# regr (Dense)                 (None, 1)                 129
# =================================================================
# Total params: 267,777
# Trainable params: 267,521
# Non-trainable params: 256
# _________________________________________________________________

# %% [markdown]
# #### Обучение:

# %%
regr_history = utils.train_model(multivariate_regression_lstm,
                                 model_save_dir, train_regr_gen, val_regr_gen,
                                 callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                 force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 77/78 [============================>.] - ETA: 0s - loss: 16.2035 - mae: 1.3941
# Epoch 00001: val_loss improved from inf to 10.67902, saving model to models\lstm1_multivar\regression\01.hdf5
# 78/78 [==============================] - 17s 212ms/step - loss: 16.1548 - mae: 1.3921 - val_loss: 10.6790 - val_mae: 0.6839
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 77/78 [============================>.] - ETA: 0s - loss: 10.1821 - mae: 1.1681
# Epoch 00002: val_loss improved from 10.67902 to 7.13564, saving model to models\lstm1_multivar\regression\02.hdf5
# 78/78 [==============================] - 16s 210ms/step - loss: 10.1577 - mae: 1.1683 - val_loss: 7.1356 - val_mae: 0.6698
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 77/78 [============================>.] - ETA: 0s - loss: 7.2484 - mae: 1.0587
# Epoch 00003: val_loss improved from 7.13564 to 5.43720, saving model to models\lstm1_multivar\regression\03.hdf5
# 78/78 [==============================] - 16s 207ms/step - loss: 7.2433 - mae: 1.0600 - val_loss: 5.4372 - val_mae: 0.7516
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 77/78 [============================>.] - ETA: 0s - loss: 5.4102 - mae: 0.9715
# Epoch 00004: val_loss improved from 5.43720 to 3.96355, saving model to models\lstm1_multivar\regression\04.hdf5
# 78/78 [==============================] - 20s 261ms/step - loss: 5.3951 - mae: 0.9704 - val_loss: 3.9635 - val_mae: 0.6489
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.3966 - mae: 0.9003
# Epoch 00005: val_loss improved from 3.96355 to 3.44743, saving model to models\lstm1_multivar\regression\05.hdf5
# 78/78 [==============================] - 21s 268ms/step - loss: 4.3950 - mae: 0.8992 - val_loss: 3.4474 - val_mae: 0.6400
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 77/78 [============================>.] - ETA: 0s - loss: 3.9548 - mae: 0.8830
# Epoch 00006: val_loss improved from 3.44743 to 3.08015, saving model to models\lstm1_multivar\regression\06.hdf5
# 78/78 [==============================] - 15s 190ms/step - loss: 3.9572 - mae: 0.8837 - val_loss: 3.0802 - val_mae: 0.6318
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 77/78 [============================>.] - ETA: 0s - loss: 3.5075 - mae: 0.8704
# Epoch 00007: val_loss improved from 3.08015 to 2.79749, saving model to models\lstm1_multivar\regression\07.hdf5
# 78/78 [==============================] - 18s 227ms/step - loss: 3.5052 - mae: 0.8700 - val_loss: 2.7975 - val_mae: 0.6574
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 77/78 [============================>.] - ETA: 0s - loss: 3.1316 - mae: 0.8429- ETA: 2s - loss: 3.1557
# Epoch 00008: val_loss improved from 2.79749 to 2.53178, saving model to models\lstm1_multivar\regression\08.hdf5
# 78/78 [==============================] - 15s 190ms/step - loss: 3.1500 - mae: 0.8464 - val_loss: 2.5318 - val_mae: 0.6511
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.8786 - mae: 0.8243
# Epoch 00009: val_loss improved from 2.53178 to 2.31977, saving model to models\lstm1_multivar\regression\09.hdf5
# 78/78 [==============================] - 18s 232ms/step - loss: 2.8776 - mae: 0.8232 - val_loss: 2.3198 - val_mae: 0.6361
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.6998 - mae: 0.8102
# Epoch 00010: val_loss improved from 2.31977 to 2.23130, saving model to models\lstm1_multivar\regression\10.hdf5
# 78/78 [==============================] - 15s 190ms/step - loss: 2.6900 - mae: 0.8083 - val_loss: 2.2313 - val_mae: 0.6371
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.5829 - mae: 0.7994
# Epoch 00011: val_loss improved from 2.23130 to 2.18662, saving model to models\lstm1_multivar\regression\11.hdf5
# 78/78 [==============================] - 15s 197ms/step - loss: 2.5860 - mae: 0.8008 - val_loss: 2.1866 - val_mae: 0.6460
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.4760 - mae: 0.7848
# Epoch 00012: val_loss improved from 2.18662 to 2.11152, saving model to models\lstm1_multivar\regression\12.hdf5
# 78/78 [==============================] - 15s 191ms/step - loss: 2.4692 - mae: 0.7834 - val_loss: 2.1115 - val_mae: 0.6544
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.3916 - mae: 0.7902
# Epoch 00013: val_loss improved from 2.11152 to 2.06718, saving model to models\lstm1_multivar\regression\13.hdf5
# 78/78 [==============================] - 14s 183ms/step - loss: 2.3895 - mae: 0.7895 - val_loss: 2.0672 - val_mae: 0.6567
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.2810 - mae: 0.7598
# Epoch 00014: val_loss improved from 2.06718 to 1.98616, saving model to models\lstm1_multivar\regression\14.hdf5
# 78/78 [==============================] - 15s 186ms/step - loss: 2.2874 - mae: 0.7617 - val_loss: 1.9862 - val_mae: 0.6553
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.2606 - mae: 0.7792
# Epoch 00015: val_loss improved from 1.98616 to 1.93377, saving model to models\lstm1_multivar\regression\15.hdf5
# 78/78 [==============================] - 14s 184ms/step - loss: 2.2539 - mae: 0.7772 - val_loss: 1.9338 - val_mae: 0.6461
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.2007 - mae: 0.7667
# Epoch 00016: val_loss improved from 1.93377 to 1.90905, saving model to models\lstm1_multivar\regression\16.hdf5
# 78/78 [==============================] - 16s 199ms/step - loss: 2.1922 - mae: 0.7652 - val_loss: 1.9090 - val_mae: 0.6494
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.1509 - mae: 0.7642
# Epoch 00017: val_loss improved from 1.90905 to 1.86590, saving model to models\lstm1_multivar\regression\17.hdf5
# 78/78 [==============================] - 15s 189ms/step - loss: 2.1659 - mae: 0.7668 - val_loss: 1.8659 - val_mae: 0.6488
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.1339 - mae: 0.7660
# Epoch 00018: val_loss improved from 1.86590 to 1.83959, saving model to models\lstm1_multivar\regression\18.hdf5
# 78/78 [==============================] - 14s 183ms/step - loss: 2.1336 - mae: 0.7660 - val_loss: 1.8396 - val_mae: 0.6527
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.1087 - mae: 0.7683
# Epoch 00019: val_loss improved from 1.83959 to 1.80459, saving model to models\lstm1_multivar\regression\19.hdf5
# 78/78 [==============================] - 14s 178ms/step - loss: 2.1039 - mae: 0.7674 - val_loss: 1.8046 - val_mae: 0.6457
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.0509 - mae: 0.7622
# Epoch 00020: val_loss improved from 1.80459 to 1.79263, saving model to models\lstm1_multivar\regression\20.hdf5
# 78/78 [==============================] - 14s 178ms/step - loss: 2.0506 - mae: 0.7619 - val_loss: 1.7926 - val_mae: 0.6478
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.0241 - mae: 0.7598
# Epoch 00021: val_loss improved from 1.79263 to 1.78324, saving model to models\lstm1_multivar\regression\21.hdf5
# 78/78 [==============================] - 14s 180ms/step - loss: 2.0173 - mae: 0.7580 - val_loss: 1.7832 - val_mae: 0.6501
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.0715 - mae: 0.7735
# Epoch 00022: val_loss improved from 1.78324 to 1.76920, saving model to models\lstm1_multivar\regression\22.hdf5
# 78/78 [==============================] - 14s 181ms/step - loss: 2.0677 - mae: 0.7728 - val_loss: 1.7692 - val_mae: 0.6508
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.0418 - mae: 0.7612
# Epoch 00023: val_loss improved from 1.76920 to 1.75286, saving model to models\lstm1_multivar\regression\23.hdf5
# 78/78 [==============================] - 14s 179ms/step - loss: 2.0341 - mae: 0.7590 - val_loss: 1.7529 - val_mae: 0.6506
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.9845 - mae: 0.7568
# Epoch 00024: val_loss improved from 1.75286 to 1.73750, saving model to models\lstm1_multivar\regression\24.hdf5
# 78/78 [==============================] - 14s 180ms/step - loss: 1.9878 - mae: 0.7570 - val_loss: 1.7375 - val_mae: 0.6497
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.9759 - mae: 0.7551
# Epoch 00025: val_loss improved from 1.73750 to 1.73235, saving model to models\lstm1_multivar\regression\25.hdf5
# 78/78 [==============================] - 14s 179ms/step - loss: 1.9742 - mae: 0.7557 - val_loss: 1.7324 - val_mae: 0.6511
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.9610 - mae: 0.7590- ETA: 2s - loss: 1.9510 -
# Epoch 00026: val_loss improved from 1.73235 to 1.72870, saving model to models\lstm1_multivar\regression\26.hdf5
# 78/78 [==============================] - 14s 178ms/step - loss: 1.9534 - mae: 0.7572 - val_loss: 1.7287 - val_mae: 0.6545
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.9502 - mae: 0.7484
# Epoch 00027: val_loss improved from 1.72870 to 1.72509, saving model to models\lstm1_multivar\regression\27.hdf5
# 78/78 [==============================] - 14s 178ms/step - loss: 1.9462 - mae: 0.7479 - val_loss: 1.7251 - val_mae: 0.6520
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.9413 - mae: 0.7522
# Epoch 00028: val_loss improved from 1.72509 to 1.72018, saving model to models\lstm1_multivar\regression\28.hdf5
# 78/78 [==============================] - 14s 181ms/step - loss: 1.9579 - mae: 0.7539 - val_loss: 1.7202 - val_mae: 0.6533
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.9180 - mae: 0.7476
# Epoch 00029: val_loss improved from 1.72018 to 1.70451, saving model to models\lstm1_multivar\regression\29.hdf5
# 78/78 [==============================] - 14s 179ms/step - loss: 1.9157 - mae: 0.7474 - val_loss: 1.7045 - val_mae: 0.6505
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.9131 - mae: 0.7510
# Epoch 00030: val_loss improved from 1.70451 to 1.69889, saving model to models\lstm1_multivar\regression\30.hdf5
# 78/78 [==============================] - 14s 180ms/step - loss: 1.9099 - mae: 0.7506 - val_loss: 1.6989 - val_mae: 0.6506
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.9080 - mae: 0.7513
# Epoch 00031: val_loss improved from 1.69889 to 1.69455, saving model to models\lstm1_multivar\regression\31.hdf5
# 78/78 [==============================] - 14s 178ms/step - loss: 1.9110 - mae: 0.7521 - val_loss: 1.6946 - val_mae: 0.6500
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.9284 - mae: 0.7511
# Epoch 00032: val_loss improved from 1.69455 to 1.68986, saving model to models\lstm1_multivar\regression\32.hdf5
# 78/78 [==============================] - 14s 178ms/step - loss: 1.9201 - mae: 0.7488 - val_loss: 1.6899 - val_mae: 0.6499

# %%
def plot_regr_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'MSE', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'MAE', 'mae', 'val_mae')
    
plot_regr_history(regr_history);

# %% [markdown]
# ### Прогноз задачи регрессии

# %% [markdown]
# *Судя по всему, просто выходит на модель случайного блуждания*

# %%
# загружаем последнюю эпоху с минимальным лоссом
multivariate_regression_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret_test = multivariate_regression_lstm.predict_generator(test_regr_gen, verbose=1)
# Out:
# 5/5 [==============================] - 0s 76ms/step

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret_test, figsize=(16, 20))

# %% [markdown]
# ## Задача классификации
#
# Прогнозируем направление изменения цены по сравнению с предыдущим периодом (**0** - снижение, **1** - рост).

# %%
model_class_name = 'classification'

# %%
train_clf_gen = ClassificationGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_clf_gen = ClassificationGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_clf_gen = ClassificationGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_classification_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=64)

    clf = Dense(128)(lstm)
    clf = LeakyReLU()(clf)
    clf = BatchNormalization()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)

    return Model(inputs=[inp], outputs=[clf])

# %%
multivariate_classification_lstm = build_classification_model(test_clf_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
multivariate_classification_lstm.compile(optimizer=optimizer,
                                         loss={'clf': 'binary_crossentropy'},
                                         metrics={'clf': 'accuracy'})

multivariate_classification_lstm.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 30, 18)]          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 30, 64)            21248
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1920)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               245888
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# clf (Dense)                  (None, 1)                 129
# =================================================================
# Total params: 267,777
# Trainable params: 267,521
# Non-trainable params: 256
# _________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
clf_history = utils.train_model(multivariate_classification_lstm,
                                model_save_dir, train_clf_gen, val_clf_gen,
                                callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 77/78 [============================>.] - ETA: 0s - loss: 11.3937 - accuracy: 0.4639
# Epoch 00001: val_loss improved from inf to 6.64904, saving model to models\lstm1_multivar\classification\01.hdf5
# 78/78 [==============================] - 14s 180ms/step - loss: 11.3318 - accuracy: 0.4658 - val_loss: 6.6490 - val_accuracy: 0.5000
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.7666 - accuracy: 0.5146
# Epoch 00002: val_loss improved from 6.64904 to 3.29320, saving model to models\lstm1_multivar\classification\02.hdf5
# 78/78 [==============================] - 14s 179ms/step - loss: 4.7501 - accuracy: 0.5153 - val_loss: 3.2932 - val_accuracy: 0.4808
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.9016 - accuracy: 0.5154
# Epoch 00003: val_loss improved from 3.29320 to 2.43025, saving model to models\lstm1_multivar\classification\03.hdf5
# 78/78 [==============================] - 14s 184ms/step - loss: 2.8991 - accuracy: 0.5141 - val_loss: 2.4303 - val_accuracy: 0.4808
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.3640 - accuracy: 0.5154
# Epoch 00004: val_loss improved from 2.43025 to 2.05349, saving model to models\lstm1_multivar\classification\04.hdf5
# 78/78 [==============================] - 14s 182ms/step - loss: 2.3608 - accuracy: 0.5153 - val_loss: 2.0535 - val_accuracy: 0.5481
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.0618 - accuracy: 0.5045
# Epoch 00005: val_loss improved from 2.05349 to 1.88544, saving model to models\lstm1_multivar\classification\05.hdf5
# 78/78 [==============================] - 15s 190ms/step - loss: 2.0602 - accuracy: 0.5036 - val_loss: 1.8854 - val_accuracy: 0.5481
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.9268 - accuracy: 0.5097
# Epoch 00006: val_loss improved from 1.88544 to 1.77848, saving model to models\lstm1_multivar\classification\06.hdf5
# 78/78 [==============================] - 14s 183ms/step - loss: 1.9263 - accuracy: 0.5089 - val_loss: 1.7785 - val_accuracy: 0.4808
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.8064 - accuracy: 0.5118
# Epoch 00007: val_loss improved from 1.77848 to 1.68848, saving model to models\lstm1_multivar\classification\07.hdf5
# 78/78 [==============================] - 14s 185ms/step - loss: 1.8038 - accuracy: 0.5121 - val_loss: 1.6885 - val_accuracy: 0.4808
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.6971 - accuracy: 0.5016
# Epoch 00008: val_loss improved from 1.68848 to 1.58215, saving model to models\lstm1_multivar\classification\08.hdf5
# 78/78 [==============================] - 14s 181ms/step - loss: 1.6959 - accuracy: 0.5012 - val_loss: 1.5821 - val_accuracy: 0.4904
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.5890 - accuracy: 0.5162
# Epoch 00009: val_loss improved from 1.58215 to 1.50484, saving model to models\lstm1_multivar\classification\09.hdf5
# 78/78 [==============================] - 14s 184ms/step - loss: 1.5891 - accuracy: 0.5161 - val_loss: 1.5048 - val_accuracy: 0.5192
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.5213 - accuracy: 0.5012 ETA: 1s - loss: 1.5255 - ac
# Epoch 00010: val_loss improved from 1.50484 to 1.46330, saving model to models\lstm1_multivar\classification\10.hdf5
# 78/78 [==============================] - 14s 182ms/step - loss: 1.5221 - accuracy: 0.5000 - val_loss: 1.4633 - val_accuracy: 0.4231
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.4624 - accuracy: 0.5073
# Epoch 00011: val_loss improved from 1.46330 to 1.41199, saving model to models\lstm1_multivar\classification\11.hdf5
# 78/78 [==============================] - 14s 180ms/step - loss: 1.4623 - accuracy: 0.5085 - val_loss: 1.4120 - val_accuracy: 0.5481
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.4157 - accuracy: 0.5223
# Epoch 00012: val_loss improved from 1.41199 to 1.39032, saving model to models\lstm1_multivar\classification\12.hdf5
# 78/78 [==============================] - 14s 181ms/step - loss: 1.4151 - accuracy: 0.5229 - val_loss: 1.3903 - val_accuracy: 0.5192
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.3773 - accuracy: 0.5162
# Epoch 00013: val_loss improved from 1.39032 to 1.33873, saving model to models\lstm1_multivar\classification\13.hdf5
# 78/78 [==============================] - 14s 184ms/step - loss: 1.3770 - accuracy: 0.5165 - val_loss: 1.3387 - val_accuracy: 0.5577
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.3354 - accuracy: 0.5365
# Epoch 00014: val_loss improved from 1.33873 to 1.32139, saving model to models\lstm1_multivar\classification\14.hdf5
# 78/78 [==============================] - 15s 189ms/step - loss: 1.3348 - accuracy: 0.5362 - val_loss: 1.3214 - val_accuracy: 0.4904
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.3003 - accuracy: 0.5300
# Epoch 00015: val_loss improved from 1.32139 to 1.29044, saving model to models\lstm1_multivar\classification\15.hdf5
# 78/78 [==============================] - 15s 191ms/step - loss: 1.3000 - accuracy: 0.5306 - val_loss: 1.2904 - val_accuracy: 0.5000
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.2812 - accuracy: 0.5085
# Epoch 00016: val_loss improved from 1.29044 to 1.26531, saving model to models\lstm1_multivar\classification\16.hdf5
# 78/78 [==============================] - 15s 191ms/step - loss: 1.2809 - accuracy: 0.5089 - val_loss: 1.2653 - val_accuracy: 0.5385
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.2584 - accuracy: 0.5524
# Epoch 00017: val_loss improved from 1.26531 to 1.25189, saving model to models\lstm1_multivar\classification\17.hdf5
# 78/78 [==============================] - 15s 186ms/step - loss: 1.2587 - accuracy: 0.5507 - val_loss: 1.2519 - val_accuracy: 0.5385
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.2463 - accuracy: 0.5248
# Epoch 00018: val_loss improved from 1.25189 to 1.23648, saving model to models\lstm1_multivar\classification\18.hdf5
# 78/78 [==============================] - 15s 188ms/step - loss: 1.2469 - accuracy: 0.5229 - val_loss: 1.2365 - val_accuracy: 0.5192
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.2290 - accuracy: 0.5406
# Epoch 00019: val_loss improved from 1.23648 to 1.22586, saving model to models\lstm1_multivar\classification\19.hdf5
# 78/78 [==============================] - 14s 183ms/step - loss: 1.2286 - accuracy: 0.5407 - val_loss: 1.2259 - val_accuracy: 0.5192
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.2132 - accuracy: 0.5268
# Epoch 00020: val_loss improved from 1.22586 to 1.21045, saving model to models\lstm1_multivar\classification\20.hdf5
# 78/78 [==============================] - 14s 185ms/step - loss: 1.2136 - accuracy: 0.5266 - val_loss: 1.2105 - val_accuracy: 0.5769
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.2004 - accuracy: 0.54 - ETA: 0s - loss: 1.2006 - accuracy: 0.5434
# Epoch 00021: val_loss improved from 1.21045 to 1.20114, saving model to models\lstm1_multivar\classification\21.hdf5
# 78/78 [==============================] - 15s 187ms/step - loss: 1.2009 - accuracy: 0.5431 - val_loss: 1.2011 - val_accuracy: 0.5288
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.1926 - accuracy: 0.5430
# Epoch 00022: val_loss improved from 1.20114 to 1.19167, saving model to models\lstm1_multivar\classification\22.hdf5
# 78/78 [==============================] - 14s 184ms/step - loss: 1.1931 - accuracy: 0.5415 - val_loss: 1.1917 - val_accuracy: 0.5192
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.1860 - accuracy: 0.5471
# Epoch 00023: val_loss improved from 1.19167 to 1.18772, saving model to models\lstm1_multivar\classification\23.hdf5
# 78/78 [==============================] - 15s 191ms/step - loss: 1.1859 - accuracy: 0.5479 - val_loss: 1.1877 - val_accuracy: 0.4904
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.1814 - accuracy: 0.5288
# Epoch 00024: val_loss improved from 1.18772 to 1.18194, saving model to models\lstm1_multivar\classification\24.hdf5
# 78/78 [==============================] - 14s 185ms/step - loss: 1.1817 - accuracy: 0.5278 - val_loss: 1.1819 - val_accuracy: 0.4904
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.1697 - accuracy: 0.5446
# Epoch 00025: val_loss improved from 1.18194 to 1.17428, saving model to models\lstm1_multivar\classification\25.hdf5
# 78/78 [==============================] - 15s 188ms/step - loss: 1.1700 - accuracy: 0.5431 - val_loss: 1.1743 - val_accuracy: 0.4904
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.1638 - accuracy: 0.5524
# Epoch 00026: val_loss improved from 1.17428 to 1.17124, saving model to models\lstm1_multivar\classification\26.hdf5
# 78/78 [==============================] - 18s 228ms/step - loss: 1.1640 - accuracy: 0.5519 - val_loss: 1.1712 - val_accuracy: 0.4712
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.1592 - accuracy: 0.5613
# Epoch 00027: val_loss improved from 1.17124 to 1.16478, saving model to models\lstm1_multivar\classification\27.hdf5
# 78/78 [==============================] - 28s 360ms/step - loss: 1.1595 - accuracy: 0.5612 - val_loss: 1.1648 - val_accuracy: 0.4808
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.1558 - accuracy: 0.5503
# Epoch 00028: val_loss improved from 1.16478 to 1.16215, saving model to models\lstm1_multivar\classification\28.hdf5
# 78/78 [==============================] - 18s 227ms/step - loss: 1.1561 - accuracy: 0.5499 - val_loss: 1.1622 - val_accuracy: 0.4712
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.1556 - accuracy: 0.5434
# Epoch 00029: val_loss improved from 1.16215 to 1.15964, saving model to models\lstm1_multivar\classification\29.hdf5
# 78/78 [==============================] - 15s 196ms/step - loss: 1.1557 - accuracy: 0.5431 - val_loss: 1.1596 - val_accuracy: 0.4808
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.1492 - accuracy: 0.5434
# Epoch 00030: val_loss improved from 1.15964 to 1.15443, saving model to models\lstm1_multivar\classification\30.hdf5
# 78/78 [==============================] - 17s 215ms/step - loss: 1.1490 - accuracy: 0.5435 - val_loss: 1.1544 - val_accuracy: 0.4808
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.1478 - accuracy: 0.5386
# Epoch 00031: val_loss improved from 1.15443 to 1.15387, saving model to models\lstm1_multivar\classification\31.hdf5
# 78/78 [==============================] - 16s 202ms/step - loss: 1.1476 - accuracy: 0.5395 - val_loss: 1.1539 - val_accuracy: 0.4904
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.1459 - accuracy: 0.5430 ETA: 0s - loss: 1.1457 - accuracy
# Epoch 00032: val_loss improved from 1.15387 to 1.15236, saving model to models\lstm1_multivar\classification\32.hdf5
# 78/78 [==============================] - 15s 189ms/step - loss: 1.1460 - accuracy: 0.5431 - val_loss: 1.1524 - val_accuracy: 0.4904

# %%
def plot_clf_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'Loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'Accuracy', 'accuracy', 'val_accuracy')
    
plot_clf_history(clf_history);

# %% [markdown]
# ### Прогноз задачи классификации

# %% [markdown]
# *Разделяющая способность довольно слабая, вероятности обоих классов очень близки к порогу отсечения*.

# %%
# загружаем последнюю эпоху с минимальным лоссом
multivariate_classification_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %%
pred_direction_proba = multivariate_classification_lstm.predict_generator(test_clf_gen, verbose=1)

true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 5/5 [==============================] - 0s 76ms/step
# 0.510945

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([71, 77], dtype=int64)),
#  (array([0, 1]), array([69, 79], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.54      0.54        71
#            1       0.58      0.60      0.59        77
#
#     accuracy                           0.57       148
#    macro avg       0.57      0.57      0.57       148
# weighted avg       0.57      0.57      0.57       148

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[38, 33],
#        [31, 46]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.55072464, 0.41772152],
#        [0.44927536, 0.58227848]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# ## Многозадачная модель: одновременно регрессия и классификация
#
# Пытаемся одновременно предсказать и значение цены, и направление изменения, предполагая, что комбинированная ошибка позволит точнее скорректировать веса рекуррентных слоёв.

# %%
model_class_name = 'multitask'

# %%
train_multi_gen = MultitaskGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_multi_gen = MultitaskGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_multi_gen = MultitaskGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_multitask_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=64)

    # первый выход: задача регрссии
    regr = Dense(128)(lstm)
    regr = LeakyReLU()(regr)
    regr = BatchNormalization()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    # второй выход: задача классификации
    clf = Dense(128)(lstm)
    clf = LeakyReLU()(clf)
    clf = BatchNormalization()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)
    
    return Model(inputs=[inp], outputs=[regr, clf])

# %%
multivariate_multitask_lstm = build_multitask_model(train_multi_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
multivariate_multitask_lstm.compile(optimizer=optimizer,
                                    loss={'regr': 'mse', 'clf': 'binary_crossentropy'},
                                    loss_weights={'regr': 2., 'clf': 1.},
                                    metrics={'regr': 'mae', 'clf' : 'accuracy'})

multivariate_multitask_lstm.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 30, 18)]     0
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 30, 64)       21248       input[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1920)         0           lstm_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          245888      flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          245888      flatten_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 128)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 128)          0           dense_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128)          512         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128)          512         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 128)          0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 128)          0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# regr (Dense)                    (None, 1)            129         dropout_2[0][0]
# __________________________________________________________________________________________________
# clf (Dense)                     (None, 1)            129         dropout_3[0][0]
# ==================================================================================================
# Total params: 514,306
# Trainable params: 513,794
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
multitask_history = utils.train_model(multivariate_multitask_lstm,
                                      model_save_dir, train_multi_gen, val_multi_gen,
                                      callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                      force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 77/78 [============================>.] - ETA: 0s - loss: 21.5204 - regr_loss: 3.2895 - clf_loss: 0.9881 - regr_mae: 1.3932 - clf_accuracy: 0.4732
# Epoch 00001: val_loss improved from inf to 14.68666, saving model to models\lstm1_multivar\multitask\01.hdf5
# 78/78 [==============================] - 18s 226ms/step - loss: 21.4535 - regr_loss: 3.2710 - clf_loss: 0.9849 - regr_mae: 1.3902 - clf_accuracy: 0.4742 - val_loss: 14.6867 - val_regr_loss: 1.0580 - val_clf_loss: 0.7607 - val_regr_mae: 0.7863 - val_clf_accuracy: 0.4712
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 77/78 [============================>.] - ETA: 0s - loss: 15.1820 - regr_loss: 2.1463 - clf_loss: 0.8484 - regr_mae: 1.1168 - clf_accuracy: 0.5300
# Epoch 00002: val_loss improved from 14.68666 to 11.06723, saving model to models\lstm1_multivar\multitask\02.hdf5
# 78/78 [==============================] - 17s 217ms/step - loss: 15.1401 - regr_loss: 2.1356 - clf_loss: 0.8480 - regr_mae: 1.1154 - clf_accuracy: 0.5302 - val_loss: 11.0672 - val_regr_loss: 0.9421 - val_clf_loss: 0.7422 - val_regr_mae: 0.7402 - val_clf_accuracy: 0.4904
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 77/78 [============================>.] - ETA: 0s - loss: 11.7995 - regr_loss: 1.7963 - clf_loss: 0.8349 - regr_mae: 1.0306 - clf_accuracy: 0.5093- ETA: 5s - loss: 12.2252 - regr_loss: 1.8670 - clf_loss: 0.8334 - regr_mae: 1.0401
# Epoch 00003: val_loss improved from 11.06723 to 8.97603, saving model to models\lstm1_multivar\multitask\03.hdf5
# 78/78 [==============================] - 18s 226ms/step - loss: 11.7659 - regr_loss: 1.7849 - clf_loss: 0.8358 - regr_mae: 1.0279 - clf_accuracy: 0.5089 - val_loss: 8.9760 - val_regr_loss: 0.9180 - val_clf_loss: 0.7080 - val_regr_mae: 0.6970 - val_clf_accuracy: 0.5481
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 77/78 [============================>.] - ETA: 0s - loss: 9.5942 - regr_loss: 1.5077 - clf_loss: 0.7934 - regr_mae: 0.9329 - clf_accuracy: 0.5114
# Epoch 00004: val_loss improved from 8.97603 to 7.45973, saving model to models\lstm1_multivar\multitask\04.hdf5
# 78/78 [==============================] - 17s 219ms/step - loss: 9.5842 - regr_loss: 1.5070 - clf_loss: 0.7923 - regr_mae: 0.9338 - clf_accuracy: 0.5121 - val_loss: 7.4597 - val_regr_loss: 0.7830 - val_clf_loss: 0.7117 - val_regr_mae: 0.6580 - val_clf_accuracy: 0.5192
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 77/78 [============================>.] - ETA: 0s - loss: 8.4580 - regr_loss: 1.3946 - clf_loss: 0.7619 - regr_mae: 0.8938 - clf_accuracy: 0.5219
# Epoch 00005: val_loss improved from 7.45973 to 6.85456, saving model to models\lstm1_multivar\multitask\05.hdf5
# 78/78 [==============================] - 17s 221ms/step - loss: 8.4461 - regr_loss: 1.3909 - clf_loss: 0.7607 - regr_mae: 0.8930 - clf_accuracy: 0.5221 - val_loss: 6.8546 - val_regr_loss: 0.7608 - val_clf_loss: 0.6926 - val_regr_mae: 0.6517 - val_clf_accuracy: 0.5769
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 77/78 [============================>.] - ETA: 0s - loss: 7.7673 - regr_loss: 1.3032 - clf_loss: 0.7657 - regr_mae: 0.8684 - clf_accuracy: 0.5252
# Epoch 00006: val_loss improved from 6.85456 to 6.27036, saving model to models\lstm1_multivar\multitask\06.hdf5
# 78/78 [==============================] - 17s 219ms/step - loss: 7.7619 - regr_loss: 1.3027 - clf_loss: 0.7645 - regr_mae: 0.8683 - clf_accuracy: 0.5250 - val_loss: 6.2704 - val_regr_loss: 0.7167 - val_clf_loss: 0.6945 - val_regr_mae: 0.6265 - val_clf_accuracy: 0.5481
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 77/78 [============================>.] - ETA: 0s - loss: 7.1656 - regr_loss: 1.2551 - clf_loss: 0.7449 - regr_mae: 0.8477 - clf_accuracy: 0.5292
# Epoch 00007: val_loss improved from 6.27036 to 5.85202, saving model to models\lstm1_multivar\multitask\07.hdf5
# 78/78 [==============================] - 17s 221ms/step - loss: 7.1532 - regr_loss: 1.2499 - clf_loss: 0.7457 - regr_mae: 0.8468 - clf_accuracy: 0.5286 - val_loss: 5.8520 - val_regr_loss: 0.7335 - val_clf_loss: 0.7108 - val_regr_mae: 0.6391 - val_clf_accuracy: 0.4808
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 77/78 [============================>.] - ETA: 0s - loss: 6.6114 - regr_loss: 1.2019 - clf_loss: 0.7454 - regr_mae: 0.8196 - clf_accuracy: 0.5142
# Epoch 00008: val_loss improved from 5.85202 to 5.39184, saving model to models\lstm1_multivar\multitask\08.hdf5
# 78/78 [==============================] - 18s 227ms/step - loss: 6.6209 - regr_loss: 1.2074 - clf_loss: 0.7466 - regr_mae: 0.8215 - clf_accuracy: 0.5133 - val_loss: 5.3918 - val_regr_loss: 0.7326 - val_clf_loss: 0.6769 - val_regr_mae: 0.6348 - val_clf_accuracy: 0.5673
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 77/78 [============================>.] - ETA: 0s - loss: 6.0945 - regr_loss: 1.1506 - clf_loss: 0.7365 - regr_mae: 0.8114 - clf_accuracy: 0.5272
# Epoch 00009: val_loss improved from 5.39184 to 5.05386, saving model to models\lstm1_multivar\multitask\09.hdf5
# 78/78 [==============================] - 17s 218ms/step - loss: 6.1031 - regr_loss: 1.1561 - clf_loss: 0.7367 - regr_mae: 0.8129 - clf_accuracy: 0.5270 - val_loss: 5.0539 - val_regr_loss: 0.7400 - val_clf_loss: 0.7079 - val_regr_mae: 0.6375 - val_clf_accuracy: 0.5192
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 77/78 [============================>.] - ETA: 0s - loss: 5.7462 - regr_loss: 1.1301 - clf_loss: 0.7169 - regr_mae: 0.7965 - clf_accuracy: 0.5406
# Epoch 00010: val_loss improved from 5.05386 to 4.84924, saving model to models\lstm1_multivar\multitask\10.hdf5
# 78/78 [==============================] - 18s 226ms/step - loss: 5.7354 - regr_loss: 1.1253 - clf_loss: 0.7167 - regr_mae: 0.7957 - clf_accuracy: 0.5407 - val_loss: 4.8492 - val_regr_loss: 0.7306 - val_clf_loss: 0.7091 - val_regr_mae: 0.6379 - val_clf_accuracy: 0.4808
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 77/78 [============================>.] - ETA: 0s - loss: 5.5854 - regr_loss: 1.1290 - clf_loss: 0.7298 - regr_mae: 0.7908 - clf_accuracy: 0.5264
# Epoch 00011: val_loss improved from 4.84924 to 4.71004, saving model to models\lstm1_multivar\multitask\11.hdf5
# 78/78 [==============================] - 22s 280ms/step - loss: 5.5694 - regr_loss: 1.1208 - clf_loss: 0.7312 - regr_mae: 0.7890 - clf_accuracy: 0.5254 - val_loss: 4.7100 - val_regr_loss: 0.7421 - val_clf_loss: 0.7132 - val_regr_mae: 0.6451 - val_clf_accuracy: 0.4904
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 77/78 [============================>.] - ETA: 0s - loss: 5.3556 - regr_loss: 1.1000 - clf_loss: 0.7202 - regr_mae: 0.7781 - clf_accuracy: 0.5446
# Epoch 00012: val_loss improved from 4.71004 to 4.53472, saving model to models\lstm1_multivar\multitask\12.hdf5
# 78/78 [==============================] - 27s 347ms/step - loss: 5.3427 - regr_loss: 1.0944 - clf_loss: 0.7194 - regr_mae: 0.7775 - clf_accuracy: 0.5443 - val_loss: 4.5347 - val_regr_loss: 0.7408 - val_clf_loss: 0.6973 - val_regr_mae: 0.6422 - val_clf_accuracy: 0.5096
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 77/78 [============================>.] - ETA: 0s - loss: 5.1795 - regr_loss: 1.0878 - clf_loss: 0.7206 - regr_mae: 0.7751 - clf_accuracy: 0.5373
# Epoch 00013: val_loss improved from 4.53472 to 4.38815, saving model to models\lstm1_multivar\multitask\13.hdf5
# 78/78 [==============================] - 19s 244ms/step - loss: 5.1676 - regr_loss: 1.0821 - clf_loss: 0.7208 - regr_mae: 0.7734 - clf_accuracy: 0.5370 - val_loss: 4.3881 - val_regr_loss: 0.7382 - val_clf_loss: 0.7017 - val_regr_mae: 0.6355 - val_clf_accuracy: 0.5192
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 77/78 [============================>.] - ETA: 0s - loss: 5.0585 - regr_loss: 1.1004 - clf_loss: 0.7149 - regr_mae: 0.7891 - clf_accuracy: 0.5373
# Epoch 00014: val_loss improved from 4.38815 to 4.28132, saving model to models\lstm1_multivar\multitask\14.hdf5
# 78/78 [==============================] - 17s 221ms/step - loss: 5.0598 - regr_loss: 1.1009 - clf_loss: 0.7161 - regr_mae: 0.7884 - clf_accuracy: 0.5370 - val_loss: 4.2813 - val_regr_loss: 0.7471 - val_clf_loss: 0.7124 - val_regr_mae: 0.6468 - val_clf_accuracy: 0.5288
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.9294 - regr_loss: 1.0875 - clf_loss: 0.7174 - regr_mae: 0.7758 - clf_accuracy: 0.5341
# Epoch 00015: val_loss improved from 4.28132 to 4.18332, saving model to models\lstm1_multivar\multitask\15.hdf5
# 78/78 [==============================] - 20s 262ms/step - loss: 4.9163 - regr_loss: 1.0818 - clf_loss: 0.7161 - regr_mae: 0.7741 - clf_accuracy: 0.5346 - val_loss: 4.1833 - val_regr_loss: 0.7424 - val_clf_loss: 0.6957 - val_regr_mae: 0.6401 - val_clf_accuracy: 0.4712
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.8048 - regr_loss: 1.0619 - clf_loss: 0.7091 - regr_mae: 0.7681 - clf_accuracy: 0.5515
# Epoch 00016: val_loss improved from 4.18332 to 4.15778, saving model to models\lstm1_multivar\multitask\16.hdf5
# 78/78 [==============================] - 19s 249ms/step - loss: 4.8059 - regr_loss: 1.0627 - clf_loss: 0.7091 - regr_mae: 0.7687 - clf_accuracy: 0.5507 - val_loss: 4.1578 - val_regr_loss: 0.7590 - val_clf_loss: 0.7009 - val_regr_mae: 0.6494 - val_clf_accuracy: 0.4904
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.6845 - regr_loss: 1.0331 - clf_loss: 0.7098 - regr_mae: 0.7551 - clf_accuracy: 0.5515
# Epoch 00017: val_loss improved from 4.15778 to 4.11357, saving model to models\lstm1_multivar\multitask\17.hdf5
# 78/78 [==============================] - 17s 221ms/step - loss: 4.6772 - regr_loss: 1.0296 - clf_loss: 0.7100 - regr_mae: 0.7554 - clf_accuracy: 0.5515 - val_loss: 4.1136 - val_regr_loss: 0.7671 - val_clf_loss: 0.7027 - val_regr_mae: 0.6526 - val_clf_accuracy: 0.5096
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.6056 - regr_loss: 1.0229 - clf_loss: 0.7125 - regr_mae: 0.7467 - clf_accuracy: 0.5402
# Epoch 00018: val_loss improved from 4.11357 to 4.03071, saving model to models\lstm1_multivar\multitask\18.hdf5
# 78/78 [==============================] - 17s 217ms/step - loss: 4.5989 - regr_loss: 1.0201 - clf_loss: 0.7117 - regr_mae: 0.7468 - clf_accuracy: 0.5415 - val_loss: 4.0307 - val_regr_loss: 0.7557 - val_clf_loss: 0.7020 - val_regr_mae: 0.6484 - val_clf_accuracy: 0.4904
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.5496 - regr_loss: 1.0256 - clf_loss: 0.7100 - regr_mae: 0.7492 - clf_accuracy: 0.5381
# Epoch 00019: val_loss improved from 4.03071 to 3.94127, saving model to models\lstm1_multivar\multitask\19.hdf5
# 78/78 [==============================] - 17s 217ms/step - loss: 4.5309 - regr_loss: 1.0159 - clf_loss: 0.7109 - regr_mae: 0.7462 - clf_accuracy: 0.5378 - val_loss: 3.9413 - val_regr_loss: 0.7439 - val_clf_loss: 0.6947 - val_regr_mae: 0.6417 - val_clf_accuracy: 0.5096
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.5207 - regr_loss: 1.0340 - clf_loss: 0.7102 - regr_mae: 0.7597 - clf_accuracy: 0.5463
# Epoch 00020: val_loss improved from 3.94127 to 3.93477, saving model to models\lstm1_multivar\multitask\20.hdf5
# 78/78 [==============================] - 17s 222ms/step - loss: 4.5145 - regr_loss: 1.0307 - clf_loss: 0.7108 - regr_mae: 0.7594 - clf_accuracy: 0.5459 - val_loss: 3.9348 - val_regr_loss: 0.7533 - val_clf_loss: 0.7005 - val_regr_mae: 0.6458 - val_clf_accuracy: 0.4904
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.4231 - regr_loss: 1.0020 - clf_loss: 0.7050 - regr_mae: 0.7414 - clf_accuracy: 0.5625
# Epoch 00021: val_loss improved from 3.93477 to 3.90918, saving model to models\lstm1_multivar\multitask\21.hdf5
# 78/78 [==============================] - 22s 280ms/step - loss: 4.4308 - regr_loss: 1.0067 - clf_loss: 0.7035 - regr_mae: 0.7431 - clf_accuracy: 0.5632 - val_loss: 3.9092 - val_regr_loss: 0.7547 - val_clf_loss: 0.7000 - val_regr_mae: 0.6479 - val_clf_accuracy: 0.5096
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.4211 - regr_loss: 1.0155 - clf_loss: 0.7042 - regr_mae: 0.7494 - clf_accuracy: 0.5442
# Epoch 00022: val_loss improved from 3.90918 to 3.89093, saving model to models\lstm1_multivar\multitask\22.hdf5
# 78/78 [==============================] - 19s 249ms/step - loss: 4.4199 - regr_loss: 1.0141 - clf_loss: 0.7059 - regr_mae: 0.7490 - clf_accuracy: 0.5427 - val_loss: 3.8909 - val_regr_loss: 0.7593 - val_clf_loss: 0.7004 - val_regr_mae: 0.6503 - val_clf_accuracy: 0.4904
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.3811 - regr_loss: 1.0095 - clf_loss: 0.7038 - regr_mae: 0.7492 - clf_accuracy: 0.5511
# Epoch 00023: val_loss improved from 3.89093 to 3.85098, saving model to models\lstm1_multivar\multitask\23.hdf5
# 78/78 [==============================] - 17s 217ms/step - loss: 4.3649 - regr_loss: 1.0018 - clf_loss: 0.7031 - regr_mae: 0.7475 - clf_accuracy: 0.5511 - val_loss: 3.8510 - val_regr_loss: 0.7551 - val_clf_loss: 0.6964 - val_regr_mae: 0.6475 - val_clf_accuracy: 0.5000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.3698 - regr_loss: 1.0186 - clf_loss: 0.7012 - regr_mae: 0.7511 - clf_accuracy: 0.5544
# Epoch 00024: val_loss improved from 3.85098 to 3.82184, saving model to models\lstm1_multivar\multitask\24.hdf5
# 78/78 [==============================] - 17s 220ms/step - loss: 4.3598 - regr_loss: 1.0134 - clf_loss: 0.7016 - regr_mae: 0.7504 - clf_accuracy: 0.5552 - val_loss: 3.8218 - val_regr_loss: 0.7524 - val_clf_loss: 0.6994 - val_regr_mae: 0.6457 - val_clf_accuracy: 0.5000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.2816 - regr_loss: 0.9817 - clf_loss: 0.7087 - regr_mae: 0.7388 - clf_accuracy: 0.5353
# Epoch 00025: val_loss improved from 3.82184 to 3.80509, saving model to models\lstm1_multivar\multitask\25.hdf5
# 78/78 [==============================] - 17s 217ms/step - loss: 4.2670 - regr_loss: 0.9741 - clf_loss: 0.7093 - regr_mae: 0.7369 - clf_accuracy: 0.5346 - val_loss: 3.8051 - val_regr_loss: 0.7534 - val_clf_loss: 0.6959 - val_regr_mae: 0.6460 - val_clf_accuracy: 0.4712
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.2575 - regr_loss: 0.9771 - clf_loss: 0.7072 - regr_mae: 0.7350 - clf_accuracy: 0.5568
# Epoch 00026: val_loss improved from 3.80509 to 3.80166, saving model to models\lstm1_multivar\multitask\26.hdf5
# 78/78 [==============================] - 18s 227ms/step - loss: 4.2506 - regr_loss: 0.9740 - clf_loss: 0.7066 - regr_mae: 0.7344 - clf_accuracy: 0.5568 - val_loss: 3.8017 - val_regr_loss: 0.7579 - val_clf_loss: 0.6968 - val_regr_mae: 0.6495 - val_clf_accuracy: 0.4712
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.3557 - regr_loss: 1.0318 - clf_loss: 0.7097 - regr_mae: 0.7530 - clf_accuracy: 0.5418
# Epoch 00027: val_loss improved from 3.80166 to 3.79055, saving model to models\lstm1_multivar\multitask\27.hdf5
# 78/78 [==============================] - 17s 224ms/step - loss: 4.3525 - regr_loss: 1.0305 - clf_loss: 0.7091 - regr_mae: 0.7527 - clf_accuracy: 0.5431 - val_loss: 3.7905 - val_regr_loss: 0.7585 - val_clf_loss: 0.6977 - val_regr_mae: 0.6497 - val_clf_accuracy: 0.4904
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.2458 - regr_loss: 0.9961 - clf_loss: 0.6848 - regr_mae: 0.7393 - clf_accuracy: 0.5682
# Epoch 00028: val_loss improved from 3.79055 to 3.77989, saving model to models\lstm1_multivar\multitask\28.hdf5
# 78/78 [==============================] - 17s 223ms/step - loss: 4.2484 - regr_loss: 0.9985 - clf_loss: 0.6828 - regr_mae: 0.7395 - clf_accuracy: 0.5696 - val_loss: 3.7799 - val_regr_loss: 0.7597 - val_clf_loss: 0.6984 - val_regr_mae: 0.6510 - val_clf_accuracy: 0.4712
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.2798 - regr_loss: 1.0130 - clf_loss: 0.6985 - regr_mae: 0.7461 - clf_accuracy: 0.5479
# Epoch 00029: val_loss improved from 3.77989 to 3.75445, saving model to models\lstm1_multivar\multitask\29.hdf5
# 78/78 [==============================] - 17s 220ms/step - loss: 4.2685 - regr_loss: 1.0068 - clf_loss: 0.6994 - regr_mae: 0.7443 - clf_accuracy: 0.5467 - val_loss: 3.7545 - val_regr_loss: 0.7547 - val_clf_loss: 0.6965 - val_regr_mae: 0.6474 - val_clf_accuracy: 0.4712
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.2313 - regr_loss: 0.9888 - clf_loss: 0.7090 - regr_mae: 0.7458 - clf_accuracy: 0.5455
# Epoch 00030: val_loss improved from 3.75445 to 3.75136, saving model to models\lstm1_multivar\multitask\30.hdf5
# 78/78 [==============================] - 17s 220ms/step - loss: 4.2270 - regr_loss: 0.9868 - clf_loss: 0.7088 - regr_mae: 0.7458 - clf_accuracy: 0.5455 - val_loss: 3.7514 - val_regr_loss: 0.7565 - val_clf_loss: 0.6973 - val_regr_mae: 0.6485 - val_clf_accuracy: 0.4712
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.2547 - regr_loss: 1.0020 - clf_loss: 0.7128 - regr_mae: 0.7410 - clf_accuracy: 0.5418
# Epoch 00031: val_loss improved from 3.75136 to 3.74515, saving model to models\lstm1_multivar\multitask\31.hdf5
# 78/78 [==============================] - 18s 230ms/step - loss: 4.2542 - regr_loss: 1.0022 - clf_loss: 0.7120 - regr_mae: 0.7420 - clf_accuracy: 0.5423 - val_loss: 3.7451 - val_regr_loss: 0.7571 - val_clf_loss: 0.6965 - val_regr_mae: 0.6483 - val_clf_accuracy: 0.4615
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.2004 - regr_loss: 0.9839 - clf_loss: 0.7015 - regr_mae: 0.7374 - clf_accuracy: 0.5560
# Epoch 00032: val_loss improved from 3.74515 to 3.74112, saving model to models\lstm1_multivar\multitask\32.hdf5
# 78/78 [==============================] - 18s 225ms/step - loss: 4.1979 - regr_loss: 0.9830 - clf_loss: 0.7008 - regr_mae: 0.7377 - clf_accuracy: 0.5560 - val_loss: 3.7411 - val_regr_loss: 0.7584 - val_clf_loss: 0.6965 - val_regr_mae: 0.6477 - val_clf_accuracy: 0.4712

# %%
def plot_multitask_history(hist):
    fig, ax = plt.subplots(2, 2, figsize=(16, 12))
    plotHelpers.plot_train_history(ax[0, 0], hist, 'Total loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[0, 1], hist, 'Accuracy', 'clf_accuracy', 'val_clf_accuracy')
    plotHelpers.plot_train_history(ax[1, 0], hist, 'MSE', 'regr_loss', 'val_regr_loss')
    plotHelpers.plot_train_history(ax[1, 1], hist, 'MAE', 'regr_mae', 'val_regr_mae')
    
plot_multitask_history(multitask_history);

# %% [markdown]
# ### Прогноз

# %%
# загружаем последнюю эпоху с минимальным лоссом
multivariate_multitask_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret, pred_direction_proba = multivariate_multitask_lstm.predict_generator(test_multi_gen, verbose=1)
# Out:
# 5/5 [==============================] - 0s 90ms/step

# %%
np.set_printoptions(precision=3, suppress=True)

np.column_stack([pred_log_ret, pred_direction_proba])[-10:]
# Out:
# array([[0.195, 0.548],
#        [0.104, 0.532],
#        [0.007, 0.53 ],
#        [0.218, 0.609],
#        [0.132, 0.606],
#        [0.197, 0.606],
#        [0.199, 0.588],
#        [0.19 , 0.529],
#        [0.09 , 0.478],
#        [0.136, 0.489]], dtype=float32)

# %% [markdown]
# #### Прогноз задачи регрессии

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret, figsize=(16, 20))

# %% [markdown]
# #### Прогноз задачи классификации

# %% [markdown]
# *Качество классификации даже ухудшилось*.

# %%
true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 0.506555

# %%
true_direction = test_multi_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([71, 77], dtype=int64)),
#  (array([0, 1]), array([70, 78], dtype=int64)))

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.51      0.51        71
#            1       0.55      0.56      0.55        77
#
#     accuracy                           0.53       148
#    macro avg       0.53      0.53      0.53       148
# weighted avg       0.53      0.53      0.53       148

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[36, 35],
#        [34, 43]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.514, 0.449],
#        [0.486, 0.551]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# # Выводы
#
# 1.  Размер батча сильно влияет на скорость обучения.
# 2.  Инициализация весов (`bias_initializer`) в слое **LSTM** оказалась очень важным параметром.
# 3.  Модель регрессии пока просто выходит на модель случайного блуждания.
# 4.  Разделяющая способность модели классификации довольно низкая.
# 5.  Комбинированная (многозадачная) модель не смогла как-то улучшить качество прогнозирования по сравнению с каждой из двух однозадачных моделей (качество даже ухудшилось).
# 6. Улучшения в точности прогнозирования по сравнению с одномерной моделью за счёт добавления дополнительных признаков добиться не удалось.

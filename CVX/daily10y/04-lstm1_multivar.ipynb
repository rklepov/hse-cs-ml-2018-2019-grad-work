# %% [markdown]
# <a href="https://colab.research.google.com/github/rklepov/hse-cs-ml-2018-2019-grad-work/blob/CVX-10yr/CVX/daily10y/04-lstm1_multivar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # *Многомерная модель на LSTM* (1 слой)
#
# В качестве признаков используются цены, объём торгов и некоторое число индикаторов (всего 18 признаков)

# %%
import os
import glob
import datetime
import pickle

import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from pandas_datareader import data as pdr

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
import tensorflow as tf
# tf.test.is_gpu_available()
tf.__version__
# Out:
# '2.0.0'

# %%
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Input, Dense, LSTM, GRU, Flatten, ReLU, LeakyReLU, Dropout, BatchNormalization
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers import Nadam

# %%
from mdp import TimeSeries
from mdp import MarketData
from mdp import MovingWindowFeatures
from mdp import ClassificationGenerator, RegressionGenerator, MultitaskGenerator
from mdp import invert_log_ret

import mdp.utils as utils
import mdp.plotHelpers as plotHelpers

# %%
import importlib

import mdp

importlib.reload(mdp)
importlib.reload(mdp.datasetGenerator)
importlib.reload(mdp.marketData)
importlib.reload(mdp.movingWindowFeatures)
importlib.reload(mdp.timeSeries)
importlib.reload(mdp.plotHelpers)
importlib.reload(mdp.utils);

# %% [markdown]
# # *Параметры*

# %%
INSTRUMENT = 'CVX' # Chevron corp
START_FROM = '2008-11-14'
WINDOW_SIZE = 30
FORECAST_OFFSET=1
BATCH_SIZE = 32
VAL_SPLIT = '2019-01-01'
TEST_SPLIT = '2019-06-01'
FORCE_TRAIN = True

# %% [markdown]
# # *Исходные данные*
#
# Загрузка данных и вычисление индикаторов.

# %%
instr = MarketData.create_from_tiingo(INSTRUMENT, start=START_FROM)

# %%
instr.feature_names
# Out:
# ['o',
#  'h',
#  'l',
#  'c',
#  'v',
#  'ema14',
#  'ema30',
#  'macd',
#  'macd_signal',
#  'rsi14',
#  'bband20_upper',
#  'bband20_middle',
#  'bband20_lower',
#  'willr14',
#  'stochk',
#  'stochd',
#  'adline',
#  'adosc']

# %% [markdown]
# ## Целевая переменная

# %% [markdown]
# Цена закрытия.

# %%
orig_target = instr.c

# %%
def plot_transformed_series(instrument, series, orig_display_name, transformed_display_name):
    plotHelpers.plot_transformed_timeseries(
        instrument.instrument,
        series,
        title_orig = orig_display_name,
        xlabel_orig = 'Date',
        ylabel_orig = orig_display_name,
        title_transformed = transformed_display_name,
        xlabel_transformed = 'Date',
        ylabel_transformed = transformed_display_name
    )

# %% [markdown]
# Переходим к логарифмической доходности.

# %%
transformed_target = instr.c.transform(transforms={'ratios' : {}, 'ln' : {}})

# %%
plot_transformed_series(instr,
                        transformed_target,
                        'Daily close price, USD', 'Daily log return')

# %% [markdown]
# ## Трансформация признаков
#
# Приведение временных рядов к стационарности.

# %%
def make_feature_selector():
    price_transformer = lambda: {'ratios': {}, 'ln': {}}
    diff_transformer = lambda o: {'diffs': {'order': o}}
    identity_transformer = lambda: {}
    feature_transformations = {
        'o': price_transformer(),
        'h': price_transformer(),
        'l': price_transformer(),
        'c': price_transformer(),
        'v': diff_transformer(1),
        'ema14': diff_transformer(1),
        'ema30': diff_transformer(1),
        'macd': identity_transformer(),
        'macd_signal': identity_transformer(),
        'rsi14': diff_transformer(1),
        'bband20_upper': diff_transformer(1),
        'bband20_middle': diff_transformer(1),
        'bband20_lower': diff_transformer(1),
        'willr14': identity_transformer(),
        'stochd': identity_transformer(),
        'stochk': identity_transformer(),
        'adline': diff_transformer(1),
        'adosc': diff_transformer(1)
    }
    return feature_transformations

# %%
instr_transformed = instr.select_transform(make_feature_selector())

# %%
transformed_target = instr_transformed.c

# %% [markdown]
# ## Обучающая, валидационная и тестовая выборки

# %%
instr_train, instr_val_test = instr_transformed.train_test_split(VAL_SPLIT, window_size=WINDOW_SIZE,
                                                                 scaler=StandardScaler)
#                                                                  scaler=MinMaxScaler,
#                                                                  scaler_kwargs={'feature_range': (-1, 1)})

instr_val, instr_test = instr_val_test.train_test_split(TEST_SPLIT, window_size=WINDOW_SIZE, scaler=None)

len(instr_train), len(instr_val), len(instr_test)
# Out:
# (2514, 134, 172)

# %% [markdown]
# Все отмасштабированные признаки на одном графике (для валидационного датасета):

# %%
plotHelpers.plot_all_features(instr_val)

# %% [markdown]
# ## Признаки - скользящие окна

# %%
train_mwf = MovingWindowFeatures.create(instr_train.c, [instr_train], instr_train.feature_names, window_size=WINDOW_SIZE)
val_mwf = MovingWindowFeatures.create(instr_val.c, [instr_val], instr_val.feature_names, window_size=WINDOW_SIZE)
test_mwf = MovingWindowFeatures.create(instr_test.c, [instr_test], instr_test.feature_names, window_size=WINDOW_SIZE)

len(instr_train), len(train_mwf), train_mwf.features.shape
# Out:
# (2514, 2484, (2484, 30, 18))

# %% [markdown]
# Проверка, что скользящие окна соответствуют исходным данным.
#
# Возьмём произвольный признак и произвольное окно (строка #**41**). Проверим, что данные в точности совпадают:

# %%
def check_data(md, mwf, row):
    col = np.random.randint(len(mwf.feature_names))
    feature = mwf.feature_names[col]
    check = (getattr(md, feature).data[row:row + mwf.window_size] == mwf.features[row, :, col]).all()
    assert check
    return feature, check

check_data(instr_train, train_mwf, 41)
# Out:
# ('bband20_middle', True)

# %% [markdown]
# # *Модели*

# %% [markdown]
# Модель с одним LSTM слоем.

# %%
def build_lstm_layers(input_shape, latent_dim=16):
    # формат входа: матрица (окно; признак)
    inp = Input(input_shape, name='input')

    lstm = LSTM(latent_dim, return_sequences=True,
                    recurrent_dropout=0.2, dropout=0.2,
                    bias_initializer='he_uniform',
                    bias_regularizer=L1L2(0.01, 0.02),
                    kernel_regularizer=L1L2(0.01, 0.02),
                    recurrent_regularizer=L1L2(0.01, 0.02)
               )(inp)
    
    lstm = Flatten()(lstm)
    
    return inp, lstm

# %% [markdown]
# #### Пути сохранения моделей:

# %%
model_path_root = 'models'
model_type_name = 'lstm1_multivar'

def make_model_save_dir(path_root, type_name, class_name):
    save_dir = os.path.join(path_root, type_name, class_name)
    os.makedirs(save_dir, exist_ok=True)
    return save_dir

# %% [markdown]
# #### Общие коллбэки:

# %%
# уменьшение learning rate в случае, если loss не изменяется
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001, verbose=1)

# уменьшение learning rate в 2 раза каждую 5-ю эпоху
def lr_decay(e, lr):
    return lr * (1 - 0.5 * (0 == (e + 1) % 5))

lr_scheduler = LearningRateScheduler(schedule=lr_decay, verbose=1)

# %% [markdown]
# ## Задача регрессии
#
# Непосредственное прогнозирование цены следующего периода.

# %%
train_regr_gen = RegressionGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_regr_gen = RegressionGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_regr_gen = RegressionGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# Следующие числа соответствуют значению параметра `steps_per_epoch` метода [`fit_generator`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit_generator "tf.keras.layers.SimpleRNN &nbsp;|&nbsp; TensorFlow Core r2.0") - то есть это число батчей, которые генератор выдаст за одну эпоху обучения (если класс генератора поддерживает метод `len()`, то данный параметр можно не указывать).

# %%
len(train_regr_gen), len(val_regr_gen), len(test_regr_gen)
# Out:
# (78, 4, 5)

# %% [markdown]
# Один сэмпл данных представляет собой матрицу размером *(длина окна; число признаков)*

# %%
train_regr_gen.input_shape
# Out:
# (30, 18)

# %% [markdown]
# ### Модель для задачи регрессии

# %%
model_class_name = 'regression'

# %%
def build_regression_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=64)

    regr = Dense(128)(lstm)
    regr = LeakyReLU()(regr)
    regr = BatchNormalization()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    return Model(inputs=[inp], outputs=[regr])

# %%
multivariate_regression_lstm = build_regression_model(train_regr_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:
# [`Nadam`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Nadam) (*Adam with Nestrov momentum*).

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Функция потерь:
#
# В качестве функции потерь будем использовать [MSE](https://www.tensorflow.org/api_docs/python/tf/keras/losses/MSE) (чтобы штрафовать за большие отклонения). Xотя хорошая функция потерь в контексте темы данной задачи - это [вопрос сложный](https://github.com/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Chapter5_LossFunctions/Ch5_LossFunctions_PyMC3.ipynb). В частности, здесь нам, очевидно, помимо абсолютного значения отклонения также важен его знак.

# %%
multivariate_regression_lstm.compile(optimizer=optimizer,
                                     loss={'regr': 'mse'},
                                     metrics={'regr': 'mae'})

multivariate_regression_lstm.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 30, 18)]          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 30, 64)            21248
# _________________________________________________________________
# flatten (Flatten)            (None, 1920)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               245888
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 128)               0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# regr (Dense)                 (None, 1)                 129
# =================================================================
# Total params: 267,777
# Trainable params: 267,521
# Non-trainable params: 256
# _________________________________________________________________

# %% [markdown]
# #### Обучение:

# %%
regr_history = utils.train_model(multivariate_regression_lstm,
                                 model_save_dir, train_regr_gen, val_regr_gen,
                                 callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                 force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 77/78 [============================>.] - ETA: 0s - loss: 16.2032 - mae: 1.3933
# Epoch 00001: val_loss improved from inf to 10.82326, saving model to models/lstm1_multivar/regression/01.hdf5
# 78/78 [==============================] - 6s 80ms/step - loss: 16.1333 - mae: 1.3881 - val_loss: 10.8233 - val_mae: 0.7870
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 77/78 [============================>.] - ETA: 0s - loss: 10.2589 - mae: 1.1656
# Epoch 00002: val_loss improved from 10.82326 to 7.13551, saving model to models/lstm1_multivar/regression/02.hdf5
# 78/78 [==============================] - 7s 83ms/step - loss: 10.2320 - mae: 1.1643 - val_loss: 7.1355 - val_mae: 0.6830
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 77/78 [============================>.] - ETA: 0s - loss: 7.3520 - mae: 1.0876
# Epoch 00003: val_loss improved from 7.13551 to 5.41392, saving model to models/lstm1_multivar/regression/03.hdf5
# 78/78 [==============================] - 7s 83ms/step - loss: 7.3452 - mae: 1.0881 - val_loss: 5.4139 - val_mae: 0.7074
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 77/78 [============================>.] - ETA: 0s - loss: 5.4456 - mae: 0.9592
# Epoch 00004: val_loss improved from 5.41392 to 4.01161, saving model to models/lstm1_multivar/regression/04.hdf5
# 78/78 [==============================] - 6s 83ms/step - loss: 5.4301 - mae: 0.9567 - val_loss: 4.0116 - val_mae: 0.6744
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.4627 - mae: 0.9274
# Epoch 00005: val_loss improved from 4.01161 to 3.52994, saving model to models/lstm1_multivar/regression/05.hdf5
# 78/78 [==============================] - 6s 82ms/step - loss: 4.4632 - mae: 0.9269 - val_loss: 3.5299 - val_mae: 0.6531
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 77/78 [============================>.] - ETA: 0s - loss: 3.9438 - mae: 0.8871
# Epoch 00006: val_loss improved from 3.52994 to 3.18790, saving model to models/lstm1_multivar/regression/06.hdf5
# 78/78 [==============================] - 6s 82ms/step - loss: 3.9468 - mae: 0.8882 - val_loss: 3.1879 - val_mae: 0.6712
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 77/78 [============================>.] - ETA: 0s - loss: 3.5298 - mae: 0.8568
# Epoch 00007: val_loss improved from 3.18790 to 2.87393, saving model to models/lstm1_multivar/regression/07.hdf5
# 78/78 [==============================] - 7s 83ms/step - loss: 3.5272 - mae: 0.8571 - val_loss: 2.8739 - val_mae: 0.6540
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 77/78 [============================>.] - ETA: 0s - loss: 3.1944 - mae: 0.8380
# Epoch 00008: val_loss improved from 2.87393 to 2.58929, saving model to models/lstm1_multivar/regression/08.hdf5
# 78/78 [==============================] - 7s 84ms/step - loss: 3.1921 - mae: 0.8379 - val_loss: 2.5893 - val_mae: 0.6544
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.9162 - mae: 0.8244
# Epoch 00009: val_loss improved from 2.58929 to 2.42873, saving model to models/lstm1_multivar/regression/09.hdf5
# 78/78 [==============================] - 7s 84ms/step - loss: 2.9060 - mae: 0.8222 - val_loss: 2.4287 - val_mae: 0.6765
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.6879 - mae: 0.7997
# Epoch 00010: val_loss improved from 2.42873 to 2.29771, saving model to models/lstm1_multivar/regression/10.hdf5
# 78/78 [==============================] - 6s 80ms/step - loss: 2.6808 - mae: 0.7984 - val_loss: 2.2977 - val_mae: 0.6482
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.6251 - mae: 0.7979
# Epoch 00011: val_loss improved from 2.29771 to 2.20729, saving model to models/lstm1_multivar/regression/11.hdf5
# 78/78 [==============================] - 6s 81ms/step - loss: 2.6334 - mae: 0.7998 - val_loss: 2.2073 - val_mae: 0.6463
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.5414 - mae: 0.8027
# Epoch 00012: val_loss improved from 2.20729 to 2.12877, saving model to models/lstm1_multivar/regression/12.hdf5
# 78/78 [==============================] - 6s 83ms/step - loss: 2.5304 - mae: 0.7997 - val_loss: 2.1288 - val_mae: 0.6420
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.4027 - mae: 0.7713
# Epoch 00013: val_loss improved from 2.12877 to 2.08916, saving model to models/lstm1_multivar/regression/13.hdf5
# 78/78 [==============================] - 6s 81ms/step - loss: 2.4137 - mae: 0.7733 - val_loss: 2.0892 - val_mae: 0.6677
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.3650 - mae: 0.7849
# Epoch 00014: val_loss improved from 2.08916 to 2.06258, saving model to models/lstm1_multivar/regression/14.hdf5
# 78/78 [==============================] - 6s 82ms/step - loss: 2.3639 - mae: 0.7849 - val_loss: 2.0626 - val_mae: 0.6788
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.2950 - mae: 0.7879
# Epoch 00015: val_loss improved from 2.06258 to 1.97265, saving model to models/lstm1_multivar/regression/15.hdf5
# 78/78 [==============================] - 6s 82ms/step - loss: 2.2870 - mae: 0.7858 - val_loss: 1.9726 - val_mae: 0.6510
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.2287 - mae: 0.7659
# Epoch 00016: val_loss improved from 1.97265 to 1.94230, saving model to models/lstm1_multivar/regression/16.hdf5
# 78/78 [==============================] - 6s 81ms/step - loss: 2.2375 - mae: 0.7689 - val_loss: 1.9423 - val_mae: 0.6574
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.2025 - mae: 0.7669
# Epoch 00017: val_loss improved from 1.94230 to 1.90480, saving model to models/lstm1_multivar/regression/17.hdf5
# 78/78 [==============================] - 6s 82ms/step - loss: 2.2270 - mae: 0.7718 - val_loss: 1.9048 - val_mae: 0.6497
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.1759 - mae: 0.7753
# Epoch 00018: val_loss improved from 1.90480 to 1.86933, saving model to models/lstm1_multivar/regression/18.hdf5
# 78/78 [==============================] - 6s 80ms/step - loss: 2.1728 - mae: 0.7742 - val_loss: 1.8693 - val_mae: 0.6482
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.1528 - mae: 0.7676
# Epoch 00019: val_loss improved from 1.86933 to 1.84201, saving model to models/lstm1_multivar/regression/19.hdf5
# 78/78 [==============================] - 6s 81ms/step - loss: 2.1573 - mae: 0.7687 - val_loss: 1.8420 - val_mae: 0.6480
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.0931 - mae: 0.7632
# Epoch 00020: val_loss improved from 1.84201 to 1.82901, saving model to models/lstm1_multivar/regression/20.hdf5
# 78/78 [==============================] - 6s 83ms/step - loss: 2.0886 - mae: 0.7625 - val_loss: 1.8290 - val_mae: 0.6515
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.0558 - mae: 0.7496
# Epoch 00021: val_loss improved from 1.82901 to 1.80969, saving model to models/lstm1_multivar/regression/21.hdf5
# 78/78 [==============================] - 7s 84ms/step - loss: 2.0552 - mae: 0.7502 - val_loss: 1.8097 - val_mae: 0.6485
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.0574 - mae: 0.7614
# Epoch 00022: val_loss improved from 1.80969 to 1.79110, saving model to models/lstm1_multivar/regression/22.hdf5
# 78/78 [==============================] - 6s 81ms/step - loss: 2.0493 - mae: 0.7592 - val_loss: 1.7911 - val_mae: 0.6468
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.0477 - mae: 0.7615
# Epoch 00023: val_loss improved from 1.79110 to 1.77376, saving model to models/lstm1_multivar/regression/23.hdf5
# 78/78 [==============================] - 6s 83ms/step - loss: 2.0519 - mae: 0.7626 - val_loss: 1.7738 - val_mae: 0.6473
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.0158 - mae: 0.7571
# Epoch 00024: val_loss improved from 1.77376 to 1.76575, saving model to models/lstm1_multivar/regression/24.hdf5
# 78/78 [==============================] - 6s 81ms/step - loss: 2.0258 - mae: 0.7592 - val_loss: 1.7658 - val_mae: 0.6496
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.9801 - mae: 0.7456
# Epoch 00025: val_loss improved from 1.76575 to 1.75418, saving model to models/lstm1_multivar/regression/25.hdf5
# 78/78 [==============================] - 7s 86ms/step - loss: 1.9801 - mae: 0.7459 - val_loss: 1.7542 - val_mae: 0.6507
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.9831 - mae: 0.7560
# Epoch 00026: val_loss improved from 1.75418 to 1.74965, saving model to models/lstm1_multivar/regression/26.hdf5
# 78/78 [==============================] - 7s 84ms/step - loss: 1.9876 - mae: 0.7557 - val_loss: 1.7496 - val_mae: 0.6510
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.9632 - mae: 0.7452
# Epoch 00027: val_loss improved from 1.74965 to 1.73981, saving model to models/lstm1_multivar/regression/27.hdf5
# 78/78 [==============================] - 6s 81ms/step - loss: 1.9592 - mae: 0.7447 - val_loss: 1.7398 - val_mae: 0.6493
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.0080 - mae: 0.7611
# Epoch 00028: val_loss improved from 1.73981 to 1.72919, saving model to models/lstm1_multivar/regression/28.hdf5
# 78/78 [==============================] - 6s 80ms/step - loss: 2.0027 - mae: 0.7596 - val_loss: 1.7292 - val_mae: 0.6477
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.9519 - mae: 0.7471
# Epoch 00029: val_loss improved from 1.72919 to 1.72293, saving model to models/lstm1_multivar/regression/29.hdf5
# 78/78 [==============================] - 6s 79ms/step - loss: 1.9452 - mae: 0.7454 - val_loss: 1.7229 - val_mae: 0.6483
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.9247 - mae: 0.7436
# Epoch 00030: val_loss improved from 1.72293 to 1.72057, saving model to models/lstm1_multivar/regression/30.hdf5
# 78/78 [==============================] - 6s 81ms/step - loss: 1.9227 - mae: 0.7429 - val_loss: 1.7206 - val_mae: 0.6491
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.9520 - mae: 0.7540
# Epoch 00031: val_loss improved from 1.72057 to 1.71966, saving model to models/lstm1_multivar/regression/31.hdf5
# 78/78 [==============================] - 6s 81ms/step - loss: 1.9614 - mae: 0.7551 - val_loss: 1.7197 - val_mae: 0.6496
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.9346 - mae: 0.7425
# Epoch 00032: val_loss improved from 1.71966 to 1.71636, saving model to models/lstm1_multivar/regression/32.hdf5
# 78/78 [==============================] - 6s 82ms/step - loss: 1.9342 - mae: 0.7429 - val_loss: 1.7164 - val_mae: 0.6497

# %%
def plot_regr_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'MSE', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'MAE', 'mae', 'val_mae')
    
plot_regr_history(regr_history);

# %% [markdown]
# ### Прогноз задачи регрессии

# %% [markdown]
# *Судя по всему, просто выходит на модель случайного блуждания*

# %%
# загружаем последнюю эпоху с минимальным лоссом
multivariate_regression_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret_test = multivariate_regression_lstm.predict_generator(test_regr_gen, verbose=1)
# Out:
# 5/5 [==============================] - 0s 28ms/step

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret_test, figsize=(16, 20))

# %% [markdown]
# ## Задача классификации
#
# Прогнозируем направление изменения цены по сравнению с предыдущим периодом (**0** - снижение, **1** - рост).

# %%
model_class_name = 'classification'

# %%
train_clf_gen = ClassificationGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_clf_gen = ClassificationGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_clf_gen = ClassificationGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_classification_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=64)

    clf = Dense(128)(lstm)
    clf = LeakyReLU()(clf)
    clf = BatchNormalization()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)

    return Model(inputs=[inp], outputs=[clf])

# %%
multivariate_classification_lstm = build_classification_model(test_clf_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
multivariate_classification_lstm.compile(optimizer=optimizer,
                                         loss={'clf': 'binary_crossentropy'},
                                         metrics={'clf': 'accuracy'})

multivariate_classification_lstm.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 30, 18)]          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 30, 64)            21248
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1920)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               245888
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# clf (Dense)                  (None, 1)                 129
# =================================================================
# Total params: 267,777
# Trainable params: 267,521
# Non-trainable params: 256
# _________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
clf_history = utils.train_model(multivariate_classification_lstm,
                                model_save_dir, train_clf_gen, val_clf_gen,
                                callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 77/78 [============================>.] - ETA: 0s - loss: 11.0456 - accuracy: 0.4797
# Epoch 00001: val_loss improved from inf to 6.23323, saving model to models/lstm1_multivar/classification/01.hdf5
# 78/78 [==============================] - 6s 83ms/step - loss: 10.9862 - accuracy: 0.4803 - val_loss: 6.2332 - val_accuracy: 0.5000
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.4668 - accuracy: 0.5069
# Epoch 00002: val_loss improved from 6.23323 to 3.07814, saving model to models/lstm1_multivar/classification/02.hdf5
# 78/78 [==============================] - 6s 82ms/step - loss: 4.4487 - accuracy: 0.5068 - val_loss: 3.0781 - val_accuracy: 0.4423
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.7499 - accuracy: 0.5045
# Epoch 00003: val_loss improved from 3.07814 to 2.29500, saving model to models/lstm1_multivar/classification/03.hdf5
# 78/78 [==============================] - 6s 83ms/step - loss: 2.7419 - accuracy: 0.5068 - val_loss: 2.2950 - val_accuracy: 0.5385
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 77/78 [============================>.] - ETA: 0s - loss: 2.2287 - accuracy: 0.5114
# Epoch 00004: val_loss improved from 2.29500 to 1.96763, saving model to models/lstm1_multivar/classification/04.hdf5
# 78/78 [==============================] - 6s 81ms/step - loss: 2.2294 - accuracy: 0.5113 - val_loss: 1.9676 - val_accuracy: 0.5577
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.9911 - accuracy: 0.5101
# Epoch 00005: val_loss improved from 1.96763 to 1.82855, saving model to models/lstm1_multivar/classification/05.hdf5
# 78/78 [==============================] - 6s 82ms/step - loss: 1.9939 - accuracy: 0.5093 - val_loss: 1.8286 - val_accuracy: 0.5000
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.8595 - accuracy: 0.4996
# Epoch 00006: val_loss improved from 1.82855 to 1.72898, saving model to models/lstm1_multivar/classification/06.hdf5
# 78/78 [==============================] - 6s 79ms/step - loss: 1.8583 - accuracy: 0.5004 - val_loss: 1.7290 - val_accuracy: 0.4712
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.7536 - accuracy: 0.5089
# Epoch 00007: val_loss improved from 1.72898 to 1.65650, saving model to models/lstm1_multivar/classification/07.hdf5
# 78/78 [==============================] - 6s 79ms/step - loss: 1.7532 - accuracy: 0.5081 - val_loss: 1.6565 - val_accuracy: 0.5192
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.6677 - accuracy: 0.5126
# Epoch 00008: val_loss improved from 1.65650 to 1.56029, saving model to models/lstm1_multivar/classification/08.hdf5
# 78/78 [==============================] - 6s 82ms/step - loss: 1.6678 - accuracy: 0.5129 - val_loss: 1.5603 - val_accuracy: 0.5865
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.5692 - accuracy: 0.5114
# Epoch 00009: val_loss improved from 1.56029 to 1.52082, saving model to models/lstm1_multivar/classification/09.hdf5
# 78/78 [==============================] - 6s 81ms/step - loss: 1.5684 - accuracy: 0.5109 - val_loss: 1.5208 - val_accuracy: 0.4712
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.4757 - accuracy: 0.5004
# Epoch 00010: val_loss improved from 1.52082 to 1.43253, saving model to models/lstm1_multivar/classification/10.hdf5
# 78/78 [==============================] - 7s 85ms/step - loss: 1.4751 - accuracy: 0.5004 - val_loss: 1.4325 - val_accuracy: 0.5288
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.4249 - accuracy: 0.5203
# Epoch 00011: val_loss improved from 1.43253 to 1.40686, saving model to models/lstm1_multivar/classification/11.hdf5
# 78/78 [==============================] - 6s 81ms/step - loss: 1.4241 - accuracy: 0.5201 - val_loss: 1.4069 - val_accuracy: 0.5000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.3921 - accuracy: 0.5146
# Epoch 00012: val_loss improved from 1.40686 to 1.38504, saving model to models/lstm1_multivar/classification/12.hdf5
# 78/78 [==============================] - 6s 82ms/step - loss: 1.3923 - accuracy: 0.5137 - val_loss: 1.3850 - val_accuracy: 0.4712
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.3531 - accuracy: 0.5142
# Epoch 00013: val_loss improved from 1.38504 to 1.34249, saving model to models/lstm1_multivar/classification/13.hdf5
# 78/78 [==============================] - 6s 83ms/step - loss: 1.3523 - accuracy: 0.5153 - val_loss: 1.3425 - val_accuracy: 0.4615
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.3157 - accuracy: 0.5292
# Epoch 00014: val_loss improved from 1.34249 to 1.31083, saving model to models/lstm1_multivar/classification/14.hdf5
# 78/78 [==============================] - 6s 83ms/step - loss: 1.3155 - accuracy: 0.5286 - val_loss: 1.3108 - val_accuracy: 0.5000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.2802 - accuracy: 0.5442
# Epoch 00015: val_loss improved from 1.31083 to 1.28155, saving model to models/lstm1_multivar/classification/15.hdf5
# 78/78 [==============================] - 6s 79ms/step - loss: 1.2799 - accuracy: 0.5447 - val_loss: 1.2816 - val_accuracy: 0.4808
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.2658 - accuracy: 0.5365
# Epoch 00016: val_loss improved from 1.28155 to 1.26425, saving model to models/lstm1_multivar/classification/16.hdf5
# 78/78 [==============================] - 6s 79ms/step - loss: 1.2658 - accuracy: 0.5362 - val_loss: 1.2643 - val_accuracy: 0.4615
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.2482 - accuracy: 0.5434
# Epoch 00017: val_loss improved from 1.26425 to 1.24763, saving model to models/lstm1_multivar/classification/17.hdf5
# 78/78 [==============================] - 6s 81ms/step - loss: 1.2478 - accuracy: 0.5439 - val_loss: 1.2476 - val_accuracy: 0.5000
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.2317 - accuracy: 0.5414
# Epoch 00018: val_loss improved from 1.24763 to 1.23277, saving model to models/lstm1_multivar/classification/18.hdf5
# 78/78 [==============================] - 6s 79ms/step - loss: 1.2313 - accuracy: 0.5419 - val_loss: 1.2328 - val_accuracy: 0.5096
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.2165 - accuracy: 0.5248
# Epoch 00019: val_loss improved from 1.23277 to 1.22517, saving model to models/lstm1_multivar/classification/19.hdf5
# 78/78 [==============================] - 6s 82ms/step - loss: 1.2164 - accuracy: 0.5254 - val_loss: 1.2252 - val_accuracy: 0.4519
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.1997 - accuracy: 0.5446
# Epoch 00020: val_loss improved from 1.22517 to 1.21088, saving model to models/lstm1_multivar/classification/20.hdf5
# 78/78 [==============================] - 6s 79ms/step - loss: 1.1992 - accuracy: 0.5455 - val_loss: 1.2109 - val_accuracy: 0.4808
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.1922 - accuracy: 0.5495
# Epoch 00021: val_loss improved from 1.21088 to 1.20246, saving model to models/lstm1_multivar/classification/21.hdf5
# 78/78 [==============================] - 6s 82ms/step - loss: 1.1922 - accuracy: 0.5495 - val_loss: 1.2025 - val_accuracy: 0.4808
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.1847 - accuracy: 0.5422
# Epoch 00022: val_loss improved from 1.20246 to 1.19079, saving model to models/lstm1_multivar/classification/22.hdf5
# 78/78 [==============================] - 7s 86ms/step - loss: 1.1849 - accuracy: 0.5419 - val_loss: 1.1908 - val_accuracy: 0.5096
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.1739 - accuracy: 0.5483
# Epoch 00023: val_loss improved from 1.19079 to 1.18504, saving model to models/lstm1_multivar/classification/23.hdf5
# 78/78 [==============================] - 6s 80ms/step - loss: 1.1741 - accuracy: 0.5471 - val_loss: 1.1850 - val_accuracy: 0.4808
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.1669 - accuracy: 0.5576
# Epoch 00024: val_loss improved from 1.18504 to 1.18032, saving model to models/lstm1_multivar/classification/24.hdf5
# 78/78 [==============================] - 6s 80ms/step - loss: 1.1667 - accuracy: 0.5592 - val_loss: 1.1803 - val_accuracy: 0.4904
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.1629 - accuracy: 0.5414
# Epoch 00025: val_loss improved from 1.18032 to 1.17326, saving model to models/lstm1_multivar/classification/25.hdf5
# 78/78 [==============================] - 6s 83ms/step - loss: 1.1627 - accuracy: 0.5423 - val_loss: 1.1733 - val_accuracy: 0.4904
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.1572 - accuracy: 0.5544
# Epoch 00026: val_loss improved from 1.17326 to 1.16911, saving model to models/lstm1_multivar/classification/26.hdf5
# 78/78 [==============================] - 6s 82ms/step - loss: 1.1568 - accuracy: 0.5552 - val_loss: 1.1691 - val_accuracy: 0.4904
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.1550 - accuracy: 0.5450
# Epoch 00027: val_loss improved from 1.16911 to 1.16333, saving model to models/lstm1_multivar/classification/27.hdf5
# 78/78 [==============================] - 7s 83ms/step - loss: 1.1549 - accuracy: 0.5451 - val_loss: 1.1633 - val_accuracy: 0.4904
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.1487 - accuracy: 0.5572
# Epoch 00028: val_loss improved from 1.16333 to 1.15859, saving model to models/lstm1_multivar/classification/28.hdf5
# 78/78 [==============================] - 6s 80ms/step - loss: 1.1487 - accuracy: 0.5564 - val_loss: 1.1586 - val_accuracy: 0.4808
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.1448 - accuracy: 0.5544
# Epoch 00029: val_loss improved from 1.15859 to 1.15575, saving model to models/lstm1_multivar/classification/29.hdf5
# 78/78 [==============================] - 6s 80ms/step - loss: 1.1444 - accuracy: 0.5552 - val_loss: 1.1557 - val_accuracy: 0.4519
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.1396 - accuracy: 0.5605
# Epoch 00030: val_loss improved from 1.15575 to 1.15273, saving model to models/lstm1_multivar/classification/30.hdf5
# 78/78 [==============================] - 6s 80ms/step - loss: 1.1397 - accuracy: 0.5608 - val_loss: 1.1527 - val_accuracy: 0.4808
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.1379 - accuracy: 0.5584
# Epoch 00031: val_loss improved from 1.15273 to 1.15064, saving model to models/lstm1_multivar/classification/31.hdf5
# 78/78 [==============================] - 6s 80ms/step - loss: 1.1378 - accuracy: 0.5572 - val_loss: 1.1506 - val_accuracy: 0.4615
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 77/78 [============================>.] - ETA: 0s - loss: 1.1353 - accuracy: 0.5471
# Epoch 00032: val_loss improved from 1.15064 to 1.14827, saving model to models/lstm1_multivar/classification/32.hdf5
# 78/78 [==============================] - 6s 81ms/step - loss: 1.1358 - accuracy: 0.5463 - val_loss: 1.1483 - val_accuracy: 0.4615

# %%
def plot_clf_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'Loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'Accuracy', 'accuracy', 'val_accuracy')
    
plot_clf_history(clf_history);

# %% [markdown]
# ### Прогноз задачи классификации

# %% [markdown]
# *Разделяющая способность довольно слабая, вероятности обоих классов очень близки к порогу отсечения*.

# %%
# загружаем последнюю эпоху с минимальным лоссом
multivariate_classification_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %%
pred_direction_proba = multivariate_classification_lstm.predict_generator(test_clf_gen, verbose=1)

true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 5/5 [==============================] - 0s 28ms/step
# 0.5130958

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([68, 74])), (array([0, 1]), array([72, 70])))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.57      0.56        68
#            1       0.59      0.55      0.57        74
#
#     accuracy                           0.56       142
#    macro avg       0.56      0.56      0.56       142
# weighted avg       0.56      0.56      0.56       142

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[39, 29],
#        [33, 41]])

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.54166667, 0.41428571],
#        [0.45833333, 0.58571429]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# ## Многозадачная модель: одновременно регрессия и классификация
#
# Пытаемся одновременно предсказать и значение цены, и направление изменения, предполагая, что комбинированная ошибка позволит точнее скорректировать веса рекуррентных слоёв.

# %%
model_class_name = 'multitask'

# %%
train_multi_gen = MultitaskGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_multi_gen = MultitaskGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_multi_gen = MultitaskGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_multitask_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=64)

    # первый выход: задача регрссии
    regr = Dense(128)(lstm)
    regr = LeakyReLU()(regr)
    regr = BatchNormalization()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    # второй выход: задача классификации
    clf = Dense(128)(lstm)
    clf = LeakyReLU()(clf)
    clf = BatchNormalization()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)
    
    return Model(inputs=[inp], outputs=[regr, clf])

# %%
multivariate_multitask_lstm = build_multitask_model(train_multi_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
multivariate_multitask_lstm.compile(optimizer=optimizer,
                                    loss={'regr': 'mse', 'clf': 'binary_crossentropy'},
                                    loss_weights={'regr': 2., 'clf': 1.},
                                    metrics={'regr': 'mae', 'clf' : 'accuracy'})

multivariate_multitask_lstm.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 30, 18)]     0
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 30, 64)       21248       input[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1920)         0           lstm_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          245888      flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          245888      flatten_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 128)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 128)          0           dense_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128)          512         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128)          512         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 128)          0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 128)          0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# regr (Dense)                    (None, 1)            129         dropout_2[0][0]
# __________________________________________________________________________________________________
# clf (Dense)                     (None, 1)            129         dropout_3[0][0]
# ==================================================================================================
# Total params: 514,306
# Trainable params: 513,794
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
multitask_history = utils.train_model(multivariate_multitask_lstm,
                                      model_save_dir, train_multi_gen, val_multi_gen,
                                      callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                      force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 77/78 [============================>.] - ETA: 0s - loss: 22.1714 - regr_loss: 3.5918 - clf_loss: 0.9480 - regr_mae: 1.4400 - clf_accuracy: 0.5045
# Epoch 00001: val_loss improved from inf to 14.38829, saving model to models/lstm1_multivar/multitask/01.hdf5
# 78/78 [==============================] - 8s 101ms/step - loss: 22.0934 - regr_loss: 3.5675 - clf_loss: 0.9447 - regr_mae: 1.4370 - clf_accuracy: 0.5056 - val_loss: 14.3883 - val_regr_loss: 0.8258 - val_clf_loss: 0.8020 - val_regr_mae: 0.7364 - val_clf_accuracy: 0.4904
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 77/78 [============================>.] - ETA: 0s - loss: 15.9126 - regr_loss: 2.4311 - clf_loss: 0.8800 - regr_mae: 1.2043 - clf_accuracy: 0.4951
# Epoch 00002: val_loss improved from 14.38829 to 11.61968, saving model to models/lstm1_multivar/multitask/02.hdf5
# 78/78 [==============================] - 8s 102ms/step - loss: 15.8654 - regr_loss: 2.4176 - clf_loss: 0.8798 - regr_mae: 1.2020 - clf_accuracy: 0.4940 - val_loss: 11.6197 - val_regr_loss: 1.1638 - val_clf_loss: 0.7327 - val_regr_mae: 0.7831 - val_clf_accuracy: 0.4423
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 77/78 [============================>.] - ETA: 0s - loss: 12.2700 - regr_loss: 1.9998 - clf_loss: 0.8030 - regr_mae: 1.0851 - clf_accuracy: 0.5219
# Epoch 00003: val_loss improved from 11.61968 to 8.87850, saving model to models/lstm1_multivar/multitask/03.hdf5
# 78/78 [==============================] - 8s 104ms/step - loss: 12.2383 - regr_loss: 1.9897 - clf_loss: 0.8034 - regr_mae: 1.0837 - clf_accuracy: 0.5225 - val_loss: 8.8785 - val_regr_loss: 0.8429 - val_clf_loss: 0.6901 - val_regr_mae: 0.6925 - val_clf_accuracy: 0.5385
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 77/78 [============================>.] - ETA: 0s - loss: 9.9690 - regr_loss: 1.6829 - clf_loss: 0.7762 - regr_mae: 0.9884 - clf_accuracy: 0.5312
# Epoch 00004: val_loss improved from 8.87850 to 7.55243, saving model to models/lstm1_multivar/multitask/04.hdf5
# 78/78 [==============================] - 8s 104ms/step - loss: 9.9579 - regr_loss: 1.6821 - clf_loss: 0.7745 - regr_mae: 0.9884 - clf_accuracy: 0.5318 - val_loss: 7.5524 - val_regr_loss: 0.8182 - val_clf_loss: 0.7110 - val_regr_mae: 0.6922 - val_clf_accuracy: 0.5192
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 77/78 [============================>.] - ETA: 0s - loss: 8.7155 - regr_loss: 1.5107 - clf_loss: 0.7670 - regr_mae: 0.9359 - clf_accuracy: 0.5252
# Epoch 00005: val_loss improved from 7.55243 to 6.87716, saving model to models/lstm1_multivar/multitask/05.hdf5
# 78/78 [==============================] - 8s 104ms/step - loss: 8.6975 - regr_loss: 1.5021 - clf_loss: 0.7694 - regr_mae: 0.9338 - clf_accuracy: 0.5242 - val_loss: 6.8772 - val_regr_loss: 0.7533 - val_clf_loss: 0.7120 - val_regr_mae: 0.6339 - val_clf_accuracy: 0.4327
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 77/78 [============================>.] - ETA: 0s - loss: 8.0431 - regr_loss: 1.4389 - clf_loss: 0.7501 - regr_mae: 0.9183 - clf_accuracy: 0.5227
# Epoch 00006: val_loss improved from 6.87716 to 6.55174, saving model to models/lstm1_multivar/multitask/06.hdf5
# 78/78 [==============================] - 8s 103ms/step - loss: 8.0269 - regr_loss: 1.4323 - clf_loss: 0.7501 - regr_mae: 0.9174 - clf_accuracy: 0.5233 - val_loss: 6.5517 - val_regr_loss: 0.8202 - val_clf_loss: 0.7475 - val_regr_mae: 0.6624 - val_clf_accuracy: 0.4904
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 77/78 [============================>.] - ETA: 0s - loss: 7.3002 - regr_loss: 1.3002 - clf_loss: 0.7659 - regr_mae: 0.8588 - clf_accuracy: 0.4992
# Epoch 00007: val_loss improved from 6.55174 to 5.94334, saving model to models/lstm1_multivar/multitask/07.hdf5
# 78/78 [==============================] - 9s 110ms/step - loss: 7.3169 - regr_loss: 1.3095 - clf_loss: 0.7670 - regr_mae: 0.8602 - clf_accuracy: 0.4972 - val_loss: 5.9433 - val_regr_loss: 0.7577 - val_clf_loss: 0.7276 - val_regr_mae: 0.6590 - val_clf_accuracy: 0.4712
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 77/78 [============================>.] - ETA: 0s - loss: 6.7413 - regr_loss: 1.2517 - clf_loss: 0.7475 - regr_mae: 0.8430 - clf_accuracy: 0.5215
# Epoch 00008: val_loss improved from 5.94334 to 5.48725, saving model to models/lstm1_multivar/multitask/08.hdf5
# 78/78 [==============================] - 8s 104ms/step - loss: 6.7340 - regr_loss: 1.2504 - clf_loss: 0.7455 - regr_mae: 0.8430 - clf_accuracy: 0.5229 - val_loss: 5.4873 - val_regr_loss: 0.7563 - val_clf_loss: 0.6958 - val_regr_mae: 0.6320 - val_clf_accuracy: 0.5192
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 77/78 [============================>.] - ETA: 0s - loss: 6.2936 - regr_loss: 1.2380 - clf_loss: 0.7276 - regr_mae: 0.8347 - clf_accuracy: 0.5398
# Epoch 00009: val_loss improved from 5.48725 to 5.14144, saving model to models/lstm1_multivar/multitask/09.hdf5
# 78/78 [==============================] - 8s 100ms/step - loss: 6.2728 - regr_loss: 1.2283 - clf_loss: 0.7285 - regr_mae: 0.8325 - clf_accuracy: 0.5382 - val_loss: 5.1414 - val_regr_loss: 0.7636 - val_clf_loss: 0.7160 - val_regr_mae: 0.6356 - val_clf_accuracy: 0.4904
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 77/78 [============================>.] - ETA: 0s - loss: 5.9482 - regr_loss: 1.2052 - clf_loss: 0.7327 - regr_mae: 0.8213 - clf_accuracy: 0.5337
# Epoch 00010: val_loss improved from 5.14144 to 4.95554, saving model to models/lstm1_multivar/multitask/10.hdf5
# 78/78 [==============================] - 8s 102ms/step - loss: 5.9444 - regr_loss: 1.2035 - clf_loss: 0.7336 - regr_mae: 0.8210 - clf_accuracy: 0.5334 - val_loss: 4.9555 - val_regr_loss: 0.7638 - val_clf_loss: 0.7124 - val_regr_mae: 0.6380 - val_clf_accuracy: 0.4712
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 77/78 [============================>.] - ETA: 0s - loss: 5.6388 - regr_loss: 1.1364 - clf_loss: 0.7322 - regr_mae: 0.7969 - clf_accuracy: 0.5276
# Epoch 00011: val_loss improved from 4.95554 to 4.88336, saving model to models/lstm1_multivar/multitask/11.hdf5
# 78/78 [==============================] - 8s 101ms/step - loss: 5.6447 - regr_loss: 1.1395 - clf_loss: 0.7330 - regr_mae: 0.7973 - clf_accuracy: 0.5266 - val_loss: 4.8834 - val_regr_loss: 0.8030 - val_clf_loss: 0.7279 - val_regr_mae: 0.6693 - val_clf_accuracy: 0.4712
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 77/78 [============================>.] - ETA: 0s - loss: 5.5247 - regr_loss: 1.1640 - clf_loss: 0.7256 - regr_mae: 0.8075 - clf_accuracy: 0.5187
# Epoch 00012: val_loss improved from 4.88336 to 4.70146, saving model to models/lstm1_multivar/multitask/12.hdf5
# 78/78 [==============================] - 8s 104ms/step - loss: 5.5081 - regr_loss: 1.1555 - clf_loss: 0.7268 - regr_mae: 0.8056 - clf_accuracy: 0.5181 - val_loss: 4.7015 - val_regr_loss: 0.7909 - val_clf_loss: 0.7289 - val_regr_mae: 0.6553 - val_clf_accuracy: 0.4904
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 77/78 [============================>.] - ETA: 0s - loss: 5.2733 - regr_loss: 1.1217 - clf_loss: 0.7120 - regr_mae: 0.7913 - clf_accuracy: 0.5414
# Epoch 00013: val_loss improved from 4.70146 to 4.53056, saving model to models/lstm1_multivar/multitask/13.hdf5
# 78/78 [==============================] - 8s 102ms/step - loss: 5.2537 - regr_loss: 1.1127 - clf_loss: 0.7113 - regr_mae: 0.7889 - clf_accuracy: 0.5423 - val_loss: 4.5306 - val_regr_loss: 0.7914 - val_clf_loss: 0.7056 - val_regr_mae: 0.6492 - val_clf_accuracy: 0.4519
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 77/78 [============================>.] - ETA: 0s - loss: 5.0740 - regr_loss: 1.0939 - clf_loss: 0.7121 - regr_mae: 0.7742 - clf_accuracy: 0.5467
# Epoch 00014: val_loss improved from 4.53056 to 4.36022, saving model to models/lstm1_multivar/multitask/14.hdf5
# 78/78 [==============================] - 8s 104ms/step - loss: 5.0627 - regr_loss: 1.0881 - clf_loss: 0.7131 - regr_mae: 0.7731 - clf_accuracy: 0.5451 - val_loss: 4.3602 - val_regr_loss: 0.7736 - val_clf_loss: 0.7088 - val_regr_mae: 0.6443 - val_clf_accuracy: 0.4519
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.9581 - regr_loss: 1.0925 - clf_loss: 0.7064 - regr_mae: 0.7787 - clf_accuracy: 0.5507
# Epoch 00015: val_loss improved from 4.36022 to 4.27424, saving model to models/lstm1_multivar/multitask/15.hdf5
# 78/78 [==============================] - 8s 103ms/step - loss: 4.9682 - regr_loss: 1.0976 - clf_loss: 0.7067 - regr_mae: 0.7798 - clf_accuracy: 0.5515 - val_loss: 4.2742 - val_regr_loss: 0.7653 - val_clf_loss: 0.7107 - val_regr_mae: 0.6411 - val_clf_accuracy: 0.4423
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.8424 - regr_loss: 1.0621 - clf_loss: 0.7170 - regr_mae: 0.7694 - clf_accuracy: 0.5345
# Epoch 00016: val_loss improved from 4.27424 to 4.25024, saving model to models/lstm1_multivar/multitask/16.hdf5
# 78/78 [==============================] - 8s 102ms/step - loss: 4.8318 - regr_loss: 1.0571 - clf_loss: 0.7169 - regr_mae: 0.7684 - clf_accuracy: 0.5350 - val_loss: 4.2502 - val_regr_loss: 0.7823 - val_clf_loss: 0.7177 - val_regr_mae: 0.6473 - val_clf_accuracy: 0.4904
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.8389 - regr_loss: 1.0958 - clf_loss: 0.7102 - regr_mae: 0.7854 - clf_accuracy: 0.5341
# Epoch 00017: val_loss improved from 4.25024 to 4.15763, saving model to models/lstm1_multivar/multitask/17.hdf5
# 78/78 [==============================] - 8s 104ms/step - loss: 4.8344 - regr_loss: 1.0935 - clf_loss: 0.7105 - regr_mae: 0.7851 - clf_accuracy: 0.5338 - val_loss: 4.1576 - val_regr_loss: 0.7728 - val_clf_loss: 0.7064 - val_regr_mae: 0.6446 - val_clf_accuracy: 0.4519
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.7048 - regr_loss: 1.0588 - clf_loss: 0.7122 - regr_mae: 0.7696 - clf_accuracy: 0.5515
# Epoch 00018: val_loss improved from 4.15763 to 4.07792, saving model to models/lstm1_multivar/multitask/18.hdf5
# 78/78 [==============================] - 8s 102ms/step - loss: 4.7449 - regr_loss: 1.0789 - clf_loss: 0.7127 - regr_mae: 0.7737 - clf_accuracy: 0.5511 - val_loss: 4.0779 - val_regr_loss: 0.7657 - val_clf_loss: 0.7019 - val_regr_mae: 0.6398 - val_clf_accuracy: 0.4808
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.6256 - regr_loss: 1.0544 - clf_loss: 0.7018 - regr_mae: 0.7624 - clf_accuracy: 0.5430
# Epoch 00019: val_loss improved from 4.07792 to 4.03397, saving model to models/lstm1_multivar/multitask/19.hdf5
# 78/78 [==============================] - 8s 106ms/step - loss: 4.6184 - regr_loss: 1.0509 - clf_loss: 0.7018 - regr_mae: 0.7613 - clf_accuracy: 0.5435 - val_loss: 4.0340 - val_regr_loss: 0.7721 - val_clf_loss: 0.7045 - val_regr_mae: 0.6481 - val_clf_accuracy: 0.4231
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.6279 - regr_loss: 1.0767 - clf_loss: 0.7059 - regr_mae: 0.7687 - clf_accuracy: 0.5430
# Epoch 00020: val_loss improved from 4.03397 to 4.00987, saving model to models/lstm1_multivar/multitask/20.hdf5
# 78/78 [==============================] - 8s 103ms/step - loss: 4.6183 - regr_loss: 1.0715 - clf_loss: 0.7069 - regr_mae: 0.7678 - clf_accuracy: 0.5423 - val_loss: 4.0099 - val_regr_loss: 0.7732 - val_clf_loss: 0.7101 - val_regr_mae: 0.6474 - val_clf_accuracy: 0.5000
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.5533 - regr_loss: 1.0505 - clf_loss: 0.7127 - regr_mae: 0.7643 - clf_accuracy: 0.5499
# Epoch 00021: val_loss improved from 4.00987 to 3.98475, saving model to models/lstm1_multivar/multitask/21.hdf5
# 78/78 [==============================] - 8s 101ms/step - loss: 4.5708 - regr_loss: 1.0591 - clf_loss: 0.7133 - regr_mae: 0.7665 - clf_accuracy: 0.5491 - val_loss: 3.9847 - val_regr_loss: 0.7759 - val_clf_loss: 0.7076 - val_regr_mae: 0.6462 - val_clf_accuracy: 0.4423
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.4922 - regr_loss: 1.0428 - clf_loss: 0.6958 - regr_mae: 0.7615 - clf_accuracy: 0.5694
# Epoch 00022: val_loss improved from 3.98475 to 3.96254, saving model to models/lstm1_multivar/multitask/22.hdf5
# 78/78 [==============================] - 8s 104ms/step - loss: 4.5069 - regr_loss: 1.0503 - clf_loss: 0.6956 - regr_mae: 0.7629 - clf_accuracy: 0.5684 - val_loss: 3.9625 - val_regr_loss: 0.7795 - val_clf_loss: 0.7072 - val_regr_mae: 0.6477 - val_clf_accuracy: 0.4327
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.4876 - regr_loss: 1.0506 - clf_loss: 0.7036 - regr_mae: 0.7628 - clf_accuracy: 0.5564
# Epoch 00023: val_loss improved from 3.96254 to 3.93660, saving model to models/lstm1_multivar/multitask/23.hdf5
# 78/78 [==============================] - 8s 102ms/step - loss: 4.4777 - regr_loss: 1.0457 - clf_loss: 0.7037 - regr_mae: 0.7622 - clf_accuracy: 0.5564 - val_loss: 3.9366 - val_regr_loss: 0.7797 - val_clf_loss: 0.7084 - val_regr_mae: 0.6463 - val_clf_accuracy: 0.4423
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.4107 - regr_loss: 1.0304 - clf_loss: 0.6948 - regr_mae: 0.7575 - clf_accuracy: 0.5532
# Epoch 00024: val_loss improved from 3.93660 to 3.92221, saving model to models/lstm1_multivar/multitask/24.hdf5
# 78/78 [==============================] - 8s 102ms/step - loss: 4.4299 - regr_loss: 1.0401 - clf_loss: 0.6949 - regr_mae: 0.7586 - clf_accuracy: 0.5531 - val_loss: 3.9222 - val_regr_loss: 0.7835 - val_clf_loss: 0.7134 - val_regr_mae: 0.6478 - val_clf_accuracy: 0.5192
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.4499 - regr_loss: 1.0552 - clf_loss: 0.7064 - regr_mae: 0.7606 - clf_accuracy: 0.5463
# Epoch 00025: val_loss improved from 3.92221 to 3.89920, saving model to models/lstm1_multivar/multitask/25.hdf5
# 78/78 [==============================] - 8s 103ms/step - loss: 4.4677 - regr_loss: 1.0636 - clf_loss: 0.7075 - regr_mae: 0.7623 - clf_accuracy: 0.5451 - val_loss: 3.8992 - val_regr_loss: 0.7816 - val_clf_loss: 0.7099 - val_regr_mae: 0.6472 - val_clf_accuracy: 0.4327
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.3357 - regr_loss: 1.0103 - clf_loss: 0.6961 - regr_mae: 0.7460 - clf_accuracy: 0.5605
# Epoch 00026: val_loss improved from 3.89920 to 3.89269, saving model to models/lstm1_multivar/multitask/26.hdf5
# 78/78 [==============================] - 8s 104ms/step - loss: 4.3426 - regr_loss: 1.0136 - clf_loss: 0.6964 - regr_mae: 0.7467 - clf_accuracy: 0.5604 - val_loss: 3.8927 - val_regr_loss: 0.7817 - val_clf_loss: 0.7168 - val_regr_mae: 0.6485 - val_clf_accuracy: 0.4904
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.4049 - regr_loss: 1.0502 - clf_loss: 0.6992 - regr_mae: 0.7586 - clf_accuracy: 0.5479
# Epoch 00027: val_loss improved from 3.89269 to 3.88301, saving model to models/lstm1_multivar/multitask/27.hdf5
# 78/78 [==============================] - 8s 102ms/step - loss: 4.3969 - regr_loss: 1.0463 - clf_loss: 0.6989 - regr_mae: 0.7579 - clf_accuracy: 0.5487 - val_loss: 3.8830 - val_regr_loss: 0.7855 - val_clf_loss: 0.7138 - val_regr_mae: 0.6487 - val_clf_accuracy: 0.4519
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.3098 - regr_loss: 1.0029 - clf_loss: 0.7125 - regr_mae: 0.7509 - clf_accuracy: 0.5353
# Epoch 00028: val_loss improved from 3.88301 to 3.87280, saving model to models/lstm1_multivar/multitask/28.hdf5
# 78/78 [==============================] - 8s 101ms/step - loss: 4.3074 - regr_loss: 1.0022 - clf_loss: 0.7117 - regr_mae: 0.7512 - clf_accuracy: 0.5358 - val_loss: 3.8728 - val_regr_loss: 0.7879 - val_clf_loss: 0.7125 - val_regr_mae: 0.6498 - val_clf_accuracy: 0.4423
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.3096 - regr_loss: 1.0168 - clf_loss: 0.6984 - regr_mae: 0.7447 - clf_accuracy: 0.5649
# Epoch 00029: val_loss improved from 3.87280 to 3.86174, saving model to models/lstm1_multivar/multitask/29.hdf5
# 78/78 [==============================] - 8s 103ms/step - loss: 4.2973 - regr_loss: 1.0098 - clf_loss: 0.7002 - regr_mae: 0.7432 - clf_accuracy: 0.5636 - val_loss: 3.8617 - val_regr_loss: 0.7888 - val_clf_loss: 0.7136 - val_regr_mae: 0.6499 - val_clf_accuracy: 0.4423
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.3624 - regr_loss: 1.0465 - clf_loss: 0.7032 - regr_mae: 0.7522 - clf_accuracy: 0.5475
# Epoch 00030: val_loss improved from 3.86174 to 3.85070, saving model to models/lstm1_multivar/multitask/30.hdf5
# 78/78 [==============================] - 8s 103ms/step - loss: 4.3580 - regr_loss: 1.0448 - clf_loss: 0.7021 - regr_mae: 0.7525 - clf_accuracy: 0.5483 - val_loss: 3.8507 - val_regr_loss: 0.7869 - val_clf_loss: 0.7143 - val_regr_mae: 0.6493 - val_clf_accuracy: 0.4808
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.3371 - regr_loss: 1.0336 - clf_loss: 0.7108 - regr_mae: 0.7476 - clf_accuracy: 0.5499
# Epoch 00031: val_loss did not improve from 3.85070
# 78/78 [==============================] - 8s 101ms/step - loss: 4.3389 - regr_loss: 1.0344 - clf_loss: 0.7110 - regr_mae: 0.7480 - clf_accuracy: 0.5479 - val_loss: 3.8513 - val_regr_loss: 0.7893 - val_clf_loss: 0.7171 - val_regr_mae: 0.6497 - val_clf_accuracy: 0.4808
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 77/78 [============================>.] - ETA: 0s - loss: 4.2492 - regr_loss: 0.9985 - clf_loss: 0.7001 - regr_mae: 0.7454 - clf_accuracy: 0.5491
# Epoch 00032: val_loss improved from 3.85070 to 3.84285, saving model to models/lstm1_multivar/multitask/32.hdf5
# 78/78 [==============================] - 8s 101ms/step - loss: 4.2494 - regr_loss: 0.9991 - clf_loss: 0.6992 - regr_mae: 0.7455 - clf_accuracy: 0.5503 - val_loss: 3.8429 - val_regr_loss: 0.7898 - val_clf_loss: 0.7148 - val_regr_mae: 0.6504 - val_clf_accuracy: 0.4519

# %%
def plot_multitask_history(hist):
    fig, ax = plt.subplots(2, 2, figsize=(16, 12))
    plotHelpers.plot_train_history(ax[0, 0], hist, 'Total loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[0, 1], hist, 'Accuracy', 'clf_accuracy', 'val_clf_accuracy')
    plotHelpers.plot_train_history(ax[1, 0], hist, 'MSE', 'regr_loss', 'val_regr_loss')
    plotHelpers.plot_train_history(ax[1, 1], hist, 'MAE', 'regr_mae', 'val_regr_mae')
    
plot_multitask_history(multitask_history);

# %% [markdown]
# ### Прогноз

# %%
# загружаем последнюю эпоху с минимальным лоссом
multivariate_multitask_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret, pred_direction_proba = multivariate_multitask_lstm.predict_generator(test_multi_gen, verbose=1)
# Out:
# 5/5 [==============================] - 0s 31ms/step

# %%
np.set_printoptions(precision=3, suppress=True)

np.column_stack([pred_log_ret, pred_direction_proba])[-10:]
# Out:
# array([[-0.138,  0.44 ],
#        [-0.139,  0.446],
#        [-0.094,  0.484],
#        [ 0.141,  0.643],
#        [ 0.146,  0.626],
#        [ 0.214,  0.65 ],
#        [ 0.135,  0.538],
#        [ 0.125,  0.548],
#        [-0.022,  0.547],
#        [ 0.17 ,  0.608]], dtype=float32)

# %% [markdown]
# #### Прогноз задачи регрессии

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret, figsize=(16, 20))

# %% [markdown]
# #### Прогноз задачи классификации

# %% [markdown]
# *Качество классификации даже ухудшилось*.

# %%
true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 0.5069473

# %%
true_direction = test_multi_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([68, 74])), (array([0, 1]), array([69, 73])))

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.50      0.50        68
#            1       0.53      0.53      0.53        74
#
#     accuracy                           0.51       142
#    macro avg       0.51      0.51      0.51       142
# weighted avg       0.51      0.51      0.51       142

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[34, 34],
#        [35, 39]])

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.493, 0.466],
#        [0.507, 0.534]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# # Выводы
#
# 1.  Размер батча сильно влияет на скорость обучения.
# 2.  Инициализация весов (`bias_initializer`) в слое **LSTM** оказалась очень важным параметром.
# 3.  Модель регрессии пока просто выходит на модель случайного блуждания.
# 4.  Разделяющая способность модели классификации довольно низкая.
# 5.  Комбинированная (многозадачная) модель не смогла как-то улучшить качество прогнозирования по сравнению с каждой из двух однозадачных моделей (качество даже ухудшилось).
# 6. Улучшения в точности прогнозирования по сравнению с одномерной моделью за счёт добавления дополнительных признаков добиться не удалось.

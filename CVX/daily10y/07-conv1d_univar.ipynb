# %% [markdown]
# # *Одномерная модель на 1D свёрточных слоях*
#
# В качестве единственного признака используется сама цена.

# %%
import os
import glob
import datetime
import pickle

import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from pandas_datareader import data as pdr

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
import tensorflow as tf
# tf.test.is_gpu_available()
tf.__version__
# Out:
# '2.0.0'

# %%
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import (Input, Dense, Convolution1D, MaxPooling1D, Flatten,
                                     ReLU, LeakyReLU, Dropout, BatchNormalization)
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers import Nadam

# %%
from mdp import TimeSeries
from mdp import MarketData
from mdp import MovingWindowFeatures
from mdp import ClassificationGenerator, RegressionGenerator, MultitaskGenerator
from mdp import invert_log_ret

import mdp.utils as utils
import mdp.plotHelpers as plotHelpers

# %%
import importlib

import mdp

importlib.reload(mdp)
importlib.reload(mdp.datasetGenerator)
importlib.reload(mdp.marketData)
importlib.reload(mdp.movingWindowFeatures)
importlib.reload(mdp.timeSeries)
importlib.reload(mdp.plotHelpers)
importlib.reload(mdp.utils);

# %% [markdown]
# # *Параметры*

# %%
INSTRUMENT = 'CVX' # Chevron corp
START_FROM = '2008-11-14'
END_DATE = '2020-01-01'
WINDOW_SIZE = 60
FORECAST_OFFSET=1
BATCH_SIZE = 32
VAL_SPLIT = '2019-01-01'
TEST_SPLIT = '2019-06-01'
FORCE_TRAIN = True

# %% [markdown]
# # *Исходные данные*
#
# Загрузка данных и вычисление индикаторов.

# %%
instr = MarketData.create_from_tiingo(INSTRUMENT, start=START_FROM, end=END_DATE)

# %%
instr.feature_names
# Out:
# ['o',
#  'h',
#  'l',
#  'c',
#  'v',
#  'ema14',
#  'ema30',
#  'macd',
#  'macd_signal',
#  'rsi14',
#  'bband20_upper',
#  'bband20_middle',
#  'bband20_lower',
#  'willr14',
#  'stochk',
#  'stochd',
#  'adline',
#  'adosc']

# %% [markdown]
# ## Целевая переменная

# %% [markdown]
# Цена закрытия.

# %%
orig_target = instr.c

# %%
def plot_transformed_series(instrument, series, orig_display_name, transformed_display_name):
    plotHelpers.plot_transformed_timeseries(
        instrument.instrument,
        series,
        title_orig = orig_display_name,
        xlabel_orig = 'Date',
        ylabel_orig = orig_display_name,
        title_transformed = transformed_display_name,
        xlabel_transformed = 'Date',
        ylabel_transformed = transformed_display_name
    )

# %% [markdown]
# Переходим к логарифмической доходности.

# %%
transformed_target = instr.c.transform(transforms={'ratios' : {}, 'ln' : {}})

# %%
plot_transformed_series(instr,
                        transformed_target,
                        'Daily close price, USD', 'Daily log return')

# %% [markdown]
# ## Трансформация признаков
#
# Из признаков выбираем только цену закрытия. Временной ряд цен преобразуется к ряду логарифмических доходностей (что также позволяет убрать нестационарность).

# %%
def make_feature_selector():
    price_transformer = lambda: {'ratios': {}, 'ln': {}}
    diff_transformer = lambda o: {'diffs': {'order': o}}
    identity_transformer = lambda: {}
    feature_transformations = {
        'c': price_transformer(),
    }
    return feature_transformations

# %%
instr_transformed = instr.select_transform(make_feature_selector())

# %%
transformed_target = instr_transformed.c

# %% [markdown]
# ## Обучающая, валидационная и тестовая выборки

# %%
instr_train, instr_val_test = instr_transformed.train_test_split(VAL_SPLIT, window_size=WINDOW_SIZE,
                                                                 scaler=StandardScaler)
#                                                                  scaler=MinMaxScaler,
#                                                                  scaler_kwargs={'feature_range': (-1, 1)})

instr_val, instr_test = instr_val_test.train_test_split(TEST_SPLIT, window_size=WINDOW_SIZE, scaler=None)

len(instr_train), len(instr_val), len(instr_test)
# Out:
# (2514, 164, 208)

# %% [markdown]
# ## Признаки - скользящие окна

# %%
train_mwf = MovingWindowFeatures.create(instr_train.c, [instr_train], instr_train.feature_names, window_size=WINDOW_SIZE)
val_mwf = MovingWindowFeatures.create(instr_val.c, [instr_val], instr_val.feature_names, window_size=WINDOW_SIZE)
test_mwf = MovingWindowFeatures.create(instr_test.c, [instr_test], instr_test.feature_names, window_size=WINDOW_SIZE)

len(instr_train), len(train_mwf), train_mwf.features.shape
# Out:
# (2514, 2454, (2454, 60, 1))

# %% [markdown]
# Проверка, что скользящие окна соответствуют исходным данным.
#
# Возьмём произвольный признак и произвольное окно (строка #**41**). Проверим, что данные в точности совпадают:

# %%
def check_data(md, mwf, row):
    col = np.random.randint(len(mwf.feature_names))
    feature = mwf.feature_names[col]
    check = (getattr(md, feature).data[row:row + mwf.window_size] == mwf.features[row, :, col]).all()
    assert check
    return feature, check

check_data(instr_train, train_mwf, 41)
# Out:
# ('c', True)

# %% [markdown]
# # *Модели*

# %% [markdown]
# Модель с двумя 1D свёрточными слоями.

# %%
def build_conv1d_layers(input_shape, filters=(16, 8), kernel_size=5, pool_size=2):
    # формат входа: наша матрица (окно; признак)
    inp = Input(input_shape, name='input')

    # стекаем два уровня Conv1D
    conv1d = Convolution1D(filters=filters[0],
                           kernel_size=kernel_size,
                           padding='same',
                           bias_initializer='he_uniform',
                           bias_regularizer=L1L2(0.01, 0.02),
                           kernel_regularizer=L1L2(0.01, 0.02)
                          )(inp)
    conv1d = BatchNormalization()(conv1d)
    conv1d = LeakyReLU()(conv1d)
    conv1d = Dropout(0.25)(conv1d)

    conv1d = Convolution1D(filters=filters[1],
                           kernel_size=kernel_size,
                           padding='same',
                           bias_initializer='he_uniform',
                           bias_regularizer=L1L2(0.01, 0.02),
                           kernel_regularizer=L1L2(0.01, 0.02)
                          )(conv1d)
    conv1d = BatchNormalization()(conv1d)
    conv1d = LeakyReLU()(conv1d)
    conv1d = Dropout(0.25)(conv1d)
    
    conv1d = MaxPooling1D(pool_size=pool_size)(conv1d)
    
    conv1d = Flatten()(conv1d)
    
    return inp, conv1d

# %% [markdown]
# #### Пути сохранения моделей:

# %%
model_path_root = 'models'
model_type_name = 'conv1d_univar'

def make_model_save_dir(path_root, type_name, class_name):
    save_dir = os.path.join(path_root, type_name, class_name)
    os.makedirs(save_dir, exist_ok=True)
    return save_dir

# %% [markdown]
# #### Общие коллбэки:

# %%
# уменьшение learning rate в случае, если loss не изменяется
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001, verbose=1)

# уменьшение learning rate в 2 раза каждую 5-ю эпоху
def lr_decay(e, lr):
    return lr * (1 - 0.5 * (0 == (e + 1) % 5))

lr_scheduler = LearningRateScheduler(schedule=lr_decay, verbose=1)

# %% [markdown]
# ## Задача регрессии
#
# Непосредственное прогнозирование цены следующего периода.

# %%
train_regr_gen = RegressionGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_regr_gen = RegressionGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_regr_gen = RegressionGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# Следующие числа соответствуют значению параметра `steps_per_epoch` метода [`fit_generator`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit_generator "tf.keras.layers.SimpleRNN &nbsp;|&nbsp; TensorFlow Core r2.0") - то есть это число батчей, которые генератор выдаст за одну эпоху обучения (если класс генератора поддерживает метод `len()`, то данный параметр можно не указывать).

# %%
len(train_regr_gen), len(val_regr_gen), len(test_regr_gen)
# Out:
# (77, 4, 5)

# %% [markdown]
# Один сэмпл данных представляет собой матрицу размером *(длина окна; число признаков)*

# %%
train_regr_gen.input_shape
# Out:
# (60, 1)

# %% [markdown]
# ### Модель для задачи регрессии

# %%
model_class_name = 'regression'

# %%
def build_regression_model(input_shape):
    inp, conv1d = build_conv1d_layers(input_shape, filters=(64, 32))

    regr = Dense(64)(conv1d)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.25)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    return Model(inputs=[inp], outputs=[regr])

# %%
univariate_regression_conv1d = build_regression_model(train_regr_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:
# [`Nadam`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Nadam) (*Adam with Nestrov momentum*).

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Функция потерь:
#
# В качестве функции потерь будем использовать [MSE](https://www.tensorflow.org/api_docs/python/tf/keras/losses/MSE) (чтобы штрафовать за большие отклонения). Xотя хорошая функция потерь в контексте темы данной задачи - это [вопрос сложный](https://github.com/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Chapter5_LossFunctions/Ch5_LossFunctions_PyMC3.ipynb). В частности, здесь нам, очевидно, помимо абсолютного значения отклонения также важен его знак.

# %%
univariate_regression_conv1d.compile(optimizer=optimizer,
                                   loss={'regr': 'mse'},
                                   metrics={'regr': 'mae'})

univariate_regression_conv1d.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 60, 1)]           0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 60, 64)            384
# _________________________________________________________________
# batch_normalization (BatchNo (None, 60, 64)            256
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 60, 64)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 60, 64)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 60, 32)            10272
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 60, 32)            128
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 60, 32)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 60, 32)            0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 30, 32)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 960)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                61504
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# regr (Dense)                 (None, 1)                 65
# =================================================================
# Total params: 72,865
# Trainable params: 72,545
# Non-trainable params: 320
# _________________________________________________________________

# %% [markdown]
# #### Обучение:

# %%
regr_history = utils.train_model(univariate_regression_conv1d,
                                 model_save_dir, train_regr_gen, val_regr_gen,
                                 callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                 force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 76/77 [============================>.] - ETA: 0s - loss: 8.3804 - mae: 0.9934
# Epoch 00001: val_loss improved from inf to 6.78577, saving model to models\conv1d_univar\regression\01.hdf5
# 77/77 [==============================] - 11s 138ms/step - loss: 8.3611 - mae: 0.9913 - val_loss: 6.7858 - val_mae: 0.6452
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 76/77 [============================>.] - ETA: 0s - loss: 6.7621 - mae: 0.8698
# Epoch 00002: val_loss improved from 6.78577 to 5.50466, saving model to models\conv1d_univar\regression\02.hdf5
# 77/77 [==============================] - 7s 88ms/step - loss: 6.7482 - mae: 0.8681 - val_loss: 5.5047 - val_mae: 0.6551
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 76/77 [============================>.] - ETA: 0s - loss: 5.2862 - mae: 0.8006
# Epoch 00003: val_loss improved from 5.50466 to 4.28605, saving model to models\conv1d_univar\regression\03.hdf5
# 77/77 [==============================] - 7s 89ms/step - loss: 5.2879 - mae: 0.8027 - val_loss: 4.2861 - val_mae: 0.6660
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 76/77 [============================>.] - ETA: 0s - loss: 4.0793 - mae: 0.7918
# Epoch 00004: val_loss improved from 4.28605 to 3.18899, saving model to models\conv1d_univar\regression\04.hdf5
# 77/77 [==============================] - 7s 87ms/step - loss: 4.0669 - mae: 0.7898 - val_loss: 3.1890 - val_mae: 0.6498
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 76/77 [============================>.] - ETA: 0s - loss: 3.2116 - mae: 0.7571
# Epoch 00005: val_loss improved from 3.18899 to 2.69390, saving model to models\conv1d_univar\regression\05.hdf5
# 77/77 [==============================] - 7s 88ms/step - loss: 3.2097 - mae: 0.7567 - val_loss: 2.6939 - val_mae: 0.6556
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 76/77 [============================>.] - ETA: 0s - loss: 2.7138 - mae: 0.7403
# Epoch 00006: val_loss improved from 2.69390 to 2.26916, saving model to models\conv1d_univar\regression\06.hdf5
# 77/77 [==============================] - 7s 91ms/step - loss: 2.7083 - mae: 0.7400 - val_loss: 2.2692 - val_mae: 0.6520
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 76/77 [============================>.] - ETA: 0s - loss: 2.2680 - mae: 0.7302
# Epoch 00007: val_loss improved from 2.26916 to 1.90126, saving model to models\conv1d_univar\regression\07.hdf5
# 77/77 [==============================] - 7s 88ms/step - loss: 2.2691 - mae: 0.7312 - val_loss: 1.9013 - val_mae: 0.6422
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.9895 - mae: 0.7374
# Epoch 00008: val_loss improved from 1.90126 to 1.62346, saving model to models\conv1d_univar\regression\08.hdf5
# 77/77 [==============================] - 8s 99ms/step - loss: 1.9807 - mae: 0.7356 - val_loss: 1.6235 - val_mae: 0.6393
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.7554 - mae: 0.7285
# Epoch 00009: val_loss improved from 1.62346 to 1.45247, saving model to models\conv1d_univar\regression\09.hdf5
# 77/77 [==============================] - 8s 106ms/step - loss: 1.7639 - mae: 0.7305 - val_loss: 1.4525 - val_mae: 0.6531
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.5757 - mae: 0.7211
# Epoch 00010: val_loss improved from 1.45247 to 1.30857, saving model to models\conv1d_univar\regression\10.hdf5
# 77/77 [==============================] - 13s 166ms/step - loss: 1.5769 - mae: 0.7223 - val_loss: 1.3086 - val_mae: 0.6381
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.4695 - mae: 0.7145
# Epoch 00011: val_loss improved from 1.30857 to 1.25570, saving model to models\conv1d_univar\regression\11.hdf5
# 77/77 [==============================] - 10s 136ms/step - loss: 1.4651 - mae: 0.7135 - val_loss: 1.2557 - val_mae: 0.6498
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.4213 - mae: 0.7254
# Epoch 00012: val_loss improved from 1.25570 to 1.18869, saving model to models\conv1d_univar\regression\12.hdf5
# 77/77 [==============================] - 8s 100ms/step - loss: 1.4241 - mae: 0.7258 - val_loss: 1.1887 - val_mae: 0.6427
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.3490 - mae: 0.7123
# Epoch 00013: val_loss improved from 1.18869 to 1.14999, saving model to models\conv1d_univar\regression\13.hdf5
# 77/77 [==============================] - 7s 96ms/step - loss: 1.3434 - mae: 0.7110 - val_loss: 1.1500 - val_mae: 0.6456
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.3411 - mae: 0.7249
# Epoch 00014: val_loss improved from 1.14999 to 1.14843, saving model to models\conv1d_univar\regression\14.hdf5
# 77/77 [==============================] - 8s 98ms/step - loss: 1.3400 - mae: 0.7248 - val_loss: 1.1484 - val_mae: 0.6633
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.2886 - mae: 0.7104
# Epoch 00015: val_loss improved from 1.14843 to 1.07664, saving model to models\conv1d_univar\regression\15.hdf5
# 77/77 [==============================] - 7s 97ms/step - loss: 1.2832 - mae: 0.7089 - val_loss: 1.0766 - val_mae: 0.6473
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.2406 - mae: 0.7078- ETA: 2s -
# Epoch 00016: val_loss did not improve from 1.07664
# 77/77 [==============================] - 7s 96ms/step - loss: 1.2416 - mae: 0.7063 - val_loss: 1.0950 - val_mae: 0.6579
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.1978 - mae: 0.7067
# Epoch 00017: val_loss improved from 1.07664 to 1.05516, saving model to models\conv1d_univar\regression\17.hdf5
# 77/77 [==============================] - 7s 97ms/step - loss: 1.1935 - mae: 0.7056 - val_loss: 1.0552 - val_mae: 0.6508
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.2136 - mae: 0.7074
# Epoch 00018: val_loss improved from 1.05516 to 1.03900, saving model to models\conv1d_univar\regression\18.hdf5
# 77/77 [==============================] - 8s 98ms/step - loss: 1.2196 - mae: 0.7097 - val_loss: 1.0390 - val_mae: 0.6461
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.1824 - mae: 0.6969
# Epoch 00019: val_loss improved from 1.03900 to 1.02391, saving model to models\conv1d_univar\regression\19.hdf5
# 77/77 [==============================] - 8s 99ms/step - loss: 1.1797 - mae: 0.6962 - val_loss: 1.0239 - val_mae: 0.6413
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.1328 - mae: 0.6941
# Epoch 00020: val_loss improved from 1.02391 to 1.00446, saving model to models\conv1d_univar\regression\20.hdf5
# 77/77 [==============================] - 8s 98ms/step - loss: 1.1264 - mae: 0.6925 - val_loss: 1.0045 - val_mae: 0.6471
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.1483 - mae: 0.6963
# Epoch 00021: val_loss did not improve from 1.00446
# 77/77 [==============================] - 7s 87ms/step - loss: 1.1506 - mae: 0.6972 - val_loss: 1.0106 - val_mae: 0.6524
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.1237 - mae: 0.6959
# Epoch 00022: val_loss improved from 1.00446 to 1.00045, saving model to models\conv1d_univar\regression\22.hdf5
# 77/77 [==============================] - 7s 88ms/step - loss: 1.1275 - mae: 0.6968 - val_loss: 1.0004 - val_mae: 0.6526
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.1427 - mae: 0.7063
# Epoch 00023: val_loss improved from 1.00045 to 0.98689, saving model to models\conv1d_univar\regression\23.hdf5
# 77/77 [==============================] - 7s 88ms/step - loss: 1.1379 - mae: 0.7048 - val_loss: 0.9869 - val_mae: 0.6458
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.1001 - mae: 0.6913
# Epoch 00024: val_loss did not improve from 0.98689
# 77/77 [==============================] - 7s 89ms/step - loss: 1.1006 - mae: 0.6919 - val_loss: 0.9979 - val_mae: 0.6521
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.0884 - mae: 0.6888
# Epoch 00025: val_loss improved from 0.98689 to 0.98356, saving model to models\conv1d_univar\regression\25.hdf5
# 77/77 [==============================] - 7s 89ms/step - loss: 1.0854 - mae: 0.6883 - val_loss: 0.9836 - val_mae: 0.6509
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.0717 - mae: 0.6895
# Epoch 00026: val_loss improved from 0.98356 to 0.97874, saving model to models\conv1d_univar\regression\26.hdf5
# 77/77 [==============================] - 7s 88ms/step - loss: 1.0724 - mae: 0.6893 - val_loss: 0.9787 - val_mae: 0.6538
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.0763 - mae: 0.6918
# Epoch 00027: val_loss improved from 0.97874 to 0.97424, saving model to models\conv1d_univar\regression\27.hdf5
# 77/77 [==============================] - 7s 89ms/step - loss: 1.0794 - mae: 0.6915 - val_loss: 0.9742 - val_mae: 0.6518
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.0517 - mae: 0.6867
# Epoch 00028: val_loss improved from 0.97424 to 0.96360, saving model to models\conv1d_univar\regression\28.hdf5
# 77/77 [==============================] - 7s 89ms/step - loss: 1.0574 - mae: 0.6883 - val_loss: 0.9636 - val_mae: 0.6543
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.0580 - mae: 0.6847
# Epoch 00029: val_loss improved from 0.96360 to 0.96199, saving model to models\conv1d_univar\regression\29.hdf5
# 77/77 [==============================] - 7s 90ms/step - loss: 1.0578 - mae: 0.6845 - val_loss: 0.9620 - val_mae: 0.6557
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.0400 - mae: 0.6811- ETA: 2s - l
# Epoch 00030: val_loss improved from 0.96199 to 0.95827, saving model to models\conv1d_univar\regression\30.hdf5
# 77/77 [==============================] - 7s 90ms/step - loss: 1.0512 - mae: 0.6839 - val_loss: 0.9583 - val_mae: 0.6552
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.0717 - mae: 0.6964
# Epoch 00031: val_loss did not improve from 0.95827
# 77/77 [==============================] - 7s 88ms/step - loss: 1.0717 - mae: 0.6969 - val_loss: 0.9636 - val_mae: 0.6567
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.0494 - mae: 0.6883
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00032: val_loss did not improve from 0.95827
# 77/77 [==============================] - 7s 89ms/step - loss: 1.0488 - mae: 0.6879 - val_loss: 0.9639 - val_mae: 0.6555

# %%
def plot_regr_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'MSE', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'MAE', 'mae', 'val_mae')
    
plot_regr_history(regr_history);

# %% [markdown]
# ### Прогноз задачи регрессии

# %% [markdown]
# *Судя по всему, просто выходит на модель случайного блуждания*.

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_regression_conv1d.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret_test = univariate_regression_conv1d.predict_generator(test_regr_gen, verbose=1)
# Out:
# 5/5 [==============================] - 0s 48ms/step

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret_test, figsize=(16, 20))

# %% [markdown]
# ## Задача классификации
#
# Прогнозируем направление изменения цены по сравнению с предыдущим периодом (**0** - снижение, **1** - рост).

# %%
model_class_name = 'classification'

# %%
train_clf_gen = ClassificationGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_clf_gen = ClassificationGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_clf_gen = ClassificationGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_classification_model(input_shape):
    inp, conv1d = build_conv1d_layers(input_shape, filters=(64, 32))

    clf = Dense(64)(conv1d)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.25)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)

    return Model(inputs=[inp], outputs=[clf])

# %%
univariate_classification_conv1d = build_classification_model(test_clf_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
univariate_classification_conv1d.compile(optimizer=optimizer,
                                         loss={'clf': 'binary_crossentropy'},
                                         metrics={'clf': 'accuracy'})

univariate_classification_conv1d.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 60, 1)]           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 60, 64)            384
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 60, 64)            256
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 60, 64)            0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 60, 64)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 60, 32)            10272
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 60, 32)            128
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 60, 32)            0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 60, 32)            0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 30, 32)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 960)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                61504
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# clf (Dense)                  (None, 1)                 65
# =================================================================
# Total params: 72,865
# Trainable params: 72,545
# Non-trainable params: 320
# _________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
clf_history = utils.train_model(univariate_classification_conv1d,
                                model_save_dir, train_clf_gen, val_clf_gen,
                                callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 76/77 [============================>.] - ETA: 0s - loss: 5.9368 - accuracy: 0.4918
# Epoch 00001: val_loss improved from inf to 3.93562, saving model to models\conv1d_univar\classification\01.hdf5
# 77/77 [==============================] - 8s 104ms/step - loss: 5.9151 - accuracy: 0.4902 - val_loss: 3.9356 - val_accuracy: 0.5096
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 76/77 [============================>.] - ETA: 0s - loss: 2.8331 - accuracy: 0.5247
# Epoch 00002: val_loss improved from 3.93562 to 1.87591, saving model to models\conv1d_univar\classification\02.hdf5
# 77/77 [==============================] - 8s 106ms/step - loss: 2.8226 - accuracy: 0.5244 - val_loss: 1.8759 - val_accuracy: 0.5192
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.5110 - accuracy: 0.5267
# Epoch 00003: val_loss improved from 1.87591 to 1.19924, saving model to models\conv1d_univar\classification\03.hdf5
# 77/77 [==============================] - 9s 122ms/step - loss: 1.5102 - accuracy: 0.5236 - val_loss: 1.1992 - val_accuracy: 0.5577
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.1216 - accuracy: 0.5185
# Epoch 00004: val_loss improved from 1.19924 to 1.01609, saving model to models\conv1d_univar\classification\04.hdf5
# 77/77 [==============================] - 10s 129ms/step - loss: 1.1217 - accuracy: 0.5179 - val_loss: 1.0161 - val_accuracy: 0.4615
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 76/77 [============================>.] - ETA: 0s - loss: 0.9671 - accuracy: 0.5280
# Epoch 00005: val_loss improved from 1.01609 to 0.91420, saving model to models\conv1d_univar\classification\05.hdf5
# 77/77 [==============================] - 10s 129ms/step - loss: 0.9675 - accuracy: 0.5285 - val_loss: 0.9142 - val_accuracy: 0.4712
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 76/77 [============================>.] - ETA: 0s - loss: 0.9082 - accuracy: 0.5201
# Epoch 00006: val_loss improved from 0.91420 to 0.87863, saving model to models\conv1d_univar\classification\06.hdf5
# 77/77 [==============================] - 9s 118ms/step - loss: 0.9088 - accuracy: 0.5196 - val_loss: 0.8786 - val_accuracy: 0.5192
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 76/77 [============================>.] - ETA: 0s - loss: 0.8700 - accuracy: 0.5197
# Epoch 00007: val_loss improved from 0.87863 to 0.83829, saving model to models\conv1d_univar\classification\07.hdf5
# 77/77 [==============================] - 8s 104ms/step - loss: 0.8699 - accuracy: 0.5196 - val_loss: 0.8383 - val_accuracy: 0.4808
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 76/77 [============================>.] - ETA: 0s - loss: 0.8301 - accuracy: 0.5251
# Epoch 00008: val_loss improved from 0.83829 to 0.79512, saving model to models\conv1d_univar\classification\08.hdf5
# 77/77 [==============================] - 9s 123ms/step - loss: 0.8296 - accuracy: 0.5257 - val_loss: 0.7951 - val_accuracy: 0.4808
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 76/77 [============================>.] - ETA: 0s - loss: 0.7975 - accuracy: 0.5337
# Epoch 00009: val_loss improved from 0.79512 to 0.78432, saving model to models\conv1d_univar\classification\09.hdf5
# 77/77 [==============================] - 9s 119ms/step - loss: 0.7973 - accuracy: 0.5342 - val_loss: 0.7843 - val_accuracy: 0.4712
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 76/77 [============================>.] - ETA: 0s - loss: 0.7670 - accuracy: 0.5337
# Epoch 00010: val_loss improved from 0.78432 to 0.75534, saving model to models\conv1d_univar\classification\10.hdf5
# 77/77 [==============================] - 9s 121ms/step - loss: 0.7676 - accuracy: 0.5326 - val_loss: 0.7553 - val_accuracy: 0.5096
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 76/77 [============================>.] - ETA: 0s - loss: 0.7569 - accuracy: 0.5489
# Epoch 00011: val_loss improved from 0.75534 to 0.74150, saving model to models\conv1d_univar\classification\11.hdf5
# 77/77 [==============================] - 8s 107ms/step - loss: 0.7580 - accuracy: 0.5489 - val_loss: 0.7415 - val_accuracy: 0.5096
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 76/77 [============================>.] - ETA: 0s - loss: 0.7415 - accuracy: 0.5514
# Epoch 00012: val_loss improved from 0.74150 to 0.74057, saving model to models\conv1d_univar\classification\12.hdf5
# 77/77 [==============================] - 10s 126ms/step - loss: 0.7424 - accuracy: 0.5497 - val_loss: 0.7406 - val_accuracy: 0.5192
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 76/77 [============================>.] - ETA: 0s - loss: 0.7451 - accuracy: 0.5580
# Epoch 00013: val_loss improved from 0.74057 to 0.73855, saving model to models\conv1d_univar\classification\13.hdf5
# 77/77 [==============================] - 8s 107ms/step - loss: 0.7453 - accuracy: 0.5566 - val_loss: 0.7385 - val_accuracy: 0.5288
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 76/77 [============================>.] - ETA: 0s - loss: 0.7338 - accuracy: 0.5580
# Epoch 00014: val_loss improved from 0.73855 to 0.73447, saving model to models\conv1d_univar\classification\14.hdf5
# 77/77 [==============================] - 9s 120ms/step - loss: 0.7350 - accuracy: 0.5575 - val_loss: 0.7345 - val_accuracy: 0.5096
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 76/77 [============================>.] - ETA: 0s - loss: 0.7246 - accuracy: 0.5674
# Epoch 00015: val_loss improved from 0.73447 to 0.72458, saving model to models\conv1d_univar\classification\15.hdf5
# 77/77 [==============================] - 7s 92ms/step - loss: 0.7245 - accuracy: 0.5676 - val_loss: 0.7246 - val_accuracy: 0.5577
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 76/77 [============================>.] - ETA: 0s - loss: 0.7136 - accuracy: 0.5711
# Epoch 00016: val_loss did not improve from 0.72458
# 77/77 [==============================] - 7s 93ms/step - loss: 0.7142 - accuracy: 0.5697 - val_loss: 0.7306 - val_accuracy: 0.5385
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 76/77 [============================>.] - ETA: 0s - loss: 0.7145 - accuracy: 0.5670
# Epoch 00017: val_loss improved from 0.72458 to 0.72432, saving model to models\conv1d_univar\classification\17.hdf5
# 77/77 [==============================] - 7s 91ms/step - loss: 0.7122 - accuracy: 0.5701 - val_loss: 0.7243 - val_accuracy: 0.5288
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 76/77 [============================>.] - ETA: 0s - loss: 0.7125 - accuracy: 0.5769
# Epoch 00018: val_loss did not improve from 0.72432
# 77/77 [==============================] - 7s 91ms/step - loss: 0.7133 - accuracy: 0.5758 - val_loss: 0.7247 - val_accuracy: 0.5192
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 76/77 [============================>.] - ETA: 0s - loss: 0.7110 - accuracy: 0.5695
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 2.5000001187436283e-05.
#
# Epoch 00019: val_loss did not improve from 0.72432
# 77/77 [==============================] - 7s 92ms/step - loss: 0.7116 - accuracy: 0.5685 - val_loss: 0.7243 - val_accuracy: 0.5385
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 20/32
# 76/77 [============================>.] - ETA: 0s - loss: 0.7038 - accuracy: 0.5896
# Epoch 00020: val_loss improved from 0.72432 to 0.72380, saving model to models\conv1d_univar\classification\20.hdf5
# 77/77 [==============================] - 7s 92ms/step - loss: 0.7035 - accuracy: 0.5896 - val_loss: 0.7238 - val_accuracy: 0.5385
# Epoch 00020: early stopping

# %%
def plot_clf_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'Loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'Accuracy', 'accuracy', 'val_accuracy')
    
plot_clf_history(clf_history);

# %% [markdown]
# ### Прогноз задачи классификации

# %% [markdown]
# *ROC AUC низкий*.

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_classification_conv1d.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %%
pred_direction_proba = univariate_classification_conv1d.predict_generator(test_clf_gen, verbose=1)

true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 5/5 [==============================] - 0s 23ms/step
# 0.508694

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([71, 77], dtype=int64)),
#  (array([0, 1]), array([74, 74], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.55      0.54        71
#            1       0.57      0.55      0.56        77
#
#     accuracy                           0.55       148
#    macro avg       0.55      0.55      0.55       148
# weighted avg       0.55      0.55      0.55       148

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[39, 32],
#        [35, 42]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.52702703, 0.43243243],
#        [0.47297297, 0.56756757]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# ## Многозадачная модель: одновременно регрессия и классификация

# %%
model_class_name = 'multitask'

# %%
train_multi_gen = MultitaskGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_multi_gen = MultitaskGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_multi_gen = MultitaskGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_multitask_model(input_shape):
    inp, conv1d = build_conv1d_layers(input_shape, filters=(64, 32))

    # первый выход: задача регрссии
    regr = Dense(64)(conv1d)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.25)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    # второй выход: задача классификации
    clf = Dense(64)(conv1d)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.25)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)
    
    return Model(inputs=[inp], outputs=[regr, clf])

# %%
univariate_multitask_conv1d = build_multitask_model(train_multi_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
univariate_multitask_conv1d.compile(optimizer=optimizer,
                                    loss={'regr': 'mse', 'clf': 'binary_crossentropy'},
                                    loss_weights={'regr': 2., 'clf': 1.},
                                    metrics={'regr': 'mae', 'clf' : 'accuracy'})

univariate_multitask_conv1d.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 60, 1)]      0
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 60, 64)       384         input[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 60, 64)       256         conv1d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 60, 64)       0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 60, 64)       0           leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 60, 32)       10272       dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 60, 32)       128         conv1d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 60, 32)       0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 60, 32)       0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 30, 32)       0           dropout_7[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 960)          0           max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           61504       flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           61504       flatten_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64)           256         dense_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 64)           256         dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 64)           0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 64)           0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 64)           0           leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 64)           0           leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# regr (Dense)                    (None, 1)            65          dropout_8[0][0]
# __________________________________________________________________________________________________
# clf (Dense)                     (None, 1)            65          dropout_9[0][0]
# ==================================================================================================
# Total params: 134,690
# Trainable params: 134,242
# Non-trainable params: 448
# __________________________________________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
multitask_history = utils.train_model(univariate_multitask_conv1d,
                                      model_save_dir, train_multi_gen, val_multi_gen,
                                      callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                      force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 76/77 [============================>.] - ETA: 0s - loss: 11.3849 - regr_loss: 1.8520 - clf_loss: 0.8068 - regr_mae: 1.0303 - clf_accuracy: 0.5012
# Epoch 00001: val_loss improved from inf to 8.77109, saving model to models\conv1d_univar\multitask\01.hdf5
# 77/77 [==============================] - 9s 122ms/step - loss: 11.3719 - regr_loss: 1.8469 - clf_loss: 0.8080 - regr_mae: 1.0292 - clf_accuracy: 0.5004 - val_loss: 8.7711 - val_regr_loss: 0.7580 - val_clf_loss: 0.7002 - val_regr_mae: 0.6478 - val_clf_accuracy: 0.5096
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 76/77 [============================>.] - ETA: 0s - loss: 9.7920 - regr_loss: 1.4067 - clf_loss: 0.7679 - regr_mae: 0.8854 - clf_accuracy: 0.5021
# Epoch 00002: val_loss improved from 8.77109 to 7.97318, saving model to models\conv1d_univar\multitask\02.hdf5
# 77/77 [==============================] - 10s 123ms/step - loss: 9.7723 - regr_loss: 1.3991 - clf_loss: 0.7680 - regr_mae: 0.8838 - clf_accuracy: 0.5020 - val_loss: 7.9732 - val_regr_loss: 0.7239 - val_clf_loss: 0.6888 - val_regr_mae: 0.6274 - val_clf_accuracy: 0.5673
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 76/77 [============================>.] - ETA: 0s - loss: 8.5635 - regr_loss: 1.1888 - clf_loss: 0.7215 - regr_mae: 0.8192 - clf_accuracy: 0.5300
# Epoch 00003: val_loss improved from 7.97318 to 7.24278, saving model to models\conv1d_univar\multitask\03.hdf5
# 77/77 [==============================] - 9s 121ms/step - loss: 8.5495 - regr_loss: 1.1839 - clf_loss: 0.7221 - regr_mae: 0.8170 - clf_accuracy: 0.5293 - val_loss: 7.2428 - val_regr_loss: 0.7401 - val_clf_loss: 0.6903 - val_regr_mae: 0.6359 - val_clf_accuracy: 0.5481
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 76/77 [============================>.] - ETA: 0s - loss: 7.6134 - regr_loss: 1.1075 - clf_loss: 0.7038 - regr_mae: 0.7858 - clf_accuracy: 0.5580
# Epoch 00004: val_loss improved from 7.24278 to 6.50305, saving model to models\conv1d_univar\multitask\04.hdf5
# 77/77 [==============================] - 10s 131ms/step - loss: 7.6140 - regr_loss: 1.1106 - clf_loss: 0.7031 - regr_mae: 0.7857 - clf_accuracy: 0.5587 - val_loss: 6.5031 - val_regr_loss: 0.7555 - val_clf_loss: 0.6898 - val_regr_mae: 0.6481 - val_clf_accuracy: 0.5481
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 76/77 [============================>.] - ETA: 0s - loss: 6.9066 - regr_loss: 1.0507 - clf_loss: 0.6984 - regr_mae: 0.7672 - clf_accuracy: 0.5518
# Epoch 00005: val_loss improved from 6.50305 to 6.07689, saving model to models\conv1d_univar\multitask\05.hdf5
# 77/77 [==============================] - 9s 121ms/step - loss: 6.8990 - regr_loss: 1.0475 - clf_loss: 0.6997 - regr_mae: 0.7658 - clf_accuracy: 0.5509 - val_loss: 6.0769 - val_regr_loss: 0.7426 - val_clf_loss: 0.6890 - val_regr_mae: 0.6337 - val_clf_accuracy: 0.5288
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 76/77 [============================>.] - ETA: 0s - loss: 6.3968 - regr_loss: 0.9964 - clf_loss: 0.6951 - regr_mae: 0.7555 - clf_accuracy: 0.5567
# Epoch 00006: val_loss improved from 6.07689 to 5.63778, saving model to models\conv1d_univar\multitask\06.hdf5
# 77/77 [==============================] - 9s 122ms/step - loss: 6.4033 - regr_loss: 1.0011 - clf_loss: 0.6949 - regr_mae: 0.7565 - clf_accuracy: 0.5562 - val_loss: 5.6378 - val_regr_loss: 0.7222 - val_clf_loss: 0.6869 - val_regr_mae: 0.6324 - val_clf_accuracy: 0.5673
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 76/77 [============================>.] - ETA: 0s - loss: 5.9577 - regr_loss: 0.9770 - clf_loss: 0.6890 - regr_mae: 0.7377 - clf_accuracy: 0.5547
# Epoch 00007: val_loss improved from 5.63778 to 5.26164, saving model to models\conv1d_univar\multitask\07.hdf5
# 77/77 [==============================] - 9s 122ms/step - loss: 5.9528 - regr_loss: 0.9754 - clf_loss: 0.6899 - regr_mae: 0.7365 - clf_accuracy: 0.5542 - val_loss: 5.2616 - val_regr_loss: 0.7246 - val_clf_loss: 0.6982 - val_regr_mae: 0.6284 - val_clf_accuracy: 0.5192
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 76/77 [============================>.] - ETA: 0s - loss: 5.5646 - regr_loss: 0.9744 - clf_loss: 0.6830 - regr_mae: 0.7470 - clf_accuracy: 0.5592
# Epoch 00008: val_loss improved from 5.26164 to 4.89030, saving model to models\conv1d_univar\multitask\08.hdf5
# 77/77 [==============================] - 9s 121ms/step - loss: 5.5595 - regr_loss: 0.9731 - clf_loss: 0.6830 - regr_mae: 0.7471 - clf_accuracy: 0.5587 - val_loss: 4.8903 - val_regr_loss: 0.7287 - val_clf_loss: 0.6876 - val_regr_mae: 0.6453 - val_clf_accuracy: 0.5481
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 76/77 [============================>.] - ETA: 0s - loss: 5.1433 - regr_loss: 0.9470 - clf_loss: 0.6799 - regr_mae: 0.7318 - clf_accuracy: 0.5806
# Epoch 00009: val_loss improved from 4.89030 to 4.54707, saving model to models\conv1d_univar\multitask\09.hdf5
# 77/77 [==============================] - 9s 122ms/step - loss: 5.1418 - regr_loss: 0.9469 - clf_loss: 0.6808 - regr_mae: 0.7324 - clf_accuracy: 0.5795 - val_loss: 4.5471 - val_regr_loss: 0.7296 - val_clf_loss: 0.6948 - val_regr_mae: 0.6465 - val_clf_accuracy: 0.5000
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 76/77 [============================>.] - ETA: 0s - loss: 4.7619 - regr_loss: 0.8973 - clf_loss: 0.6671 - regr_mae: 0.7074 - clf_accuracy: 0.5781
# Epoch 00010: val_loss improved from 4.54707 to 4.36187, saving model to models\conv1d_univar\multitask\10.hdf5
# 77/77 [==============================] - 9s 122ms/step - loss: 4.7759 - regr_loss: 0.9045 - clf_loss: 0.6679 - regr_mae: 0.7092 - clf_accuracy: 0.5795 - val_loss: 4.3619 - val_regr_loss: 0.7284 - val_clf_loss: 0.6963 - val_regr_mae: 0.6407 - val_clf_accuracy: 0.4904
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 76/77 [============================>.] - ETA: 0s - loss: 4.6155 - regr_loss: 0.9101 - clf_loss: 0.6690 - regr_mae: 0.7201 - clf_accuracy: 0.5876
# Epoch 00011: val_loss improved from 4.36187 to 4.17373, saving model to models\conv1d_univar\multitask\11.hdf5
# 77/77 [==============================] - 9s 122ms/step - loss: 4.6326 - regr_loss: 0.9192 - clf_loss: 0.6692 - regr_mae: 0.7218 - clf_accuracy: 0.5864 - val_loss: 4.1737 - val_regr_loss: 0.7216 - val_clf_loss: 0.6891 - val_regr_mae: 0.6369 - val_clf_accuracy: 0.5096
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 76/77 [============================>.] - ETA: 0s - loss: 4.4362 - regr_loss: 0.8997 - clf_loss: 0.6737 - regr_mae: 0.7160 - clf_accuracy: 0.5757
# Epoch 00012: val_loss improved from 4.17373 to 4.01596, saving model to models\conv1d_univar\multitask\12.hdf5
# 77/77 [==============================] - 10s 124ms/step - loss: 4.4368 - regr_loss: 0.9005 - clf_loss: 0.6738 - regr_mae: 0.7165 - clf_accuracy: 0.5758 - val_loss: 4.0160 - val_regr_loss: 0.7239 - val_clf_loss: 0.6847 - val_regr_mae: 0.6436 - val_clf_accuracy: 0.5000
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 76/77 [============================>.] - ETA: 0s - loss: 4.2694 - regr_loss: 0.8973 - clf_loss: 0.6641 - regr_mae: 0.7091 - clf_accuracy: 0.5938
# Epoch 00013: val_loss improved from 4.01596 to 3.83498, saving model to models\conv1d_univar\multitask\13.hdf5
# 77/77 [==============================] - 9s 122ms/step - loss: 4.2599 - regr_loss: 0.8935 - clf_loss: 0.6631 - regr_mae: 0.7083 - clf_accuracy: 0.5937 - val_loss: 3.8350 - val_regr_loss: 0.7147 - val_clf_loss: 0.6728 - val_regr_mae: 0.6391 - val_clf_accuracy: 0.5673
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 76/77 [============================>.] - ETA: 0s - loss: 4.1428 - regr_loss: 0.9060 - clf_loss: 0.6678 - regr_mae: 0.7084 - clf_accuracy: 0.5818
# Epoch 00014: val_loss improved from 3.83498 to 3.68162, saving model to models\conv1d_univar\multitask\14.hdf5
# 77/77 [==============================] - 9s 123ms/step - loss: 4.1649 - regr_loss: 0.9177 - clf_loss: 0.6676 - regr_mae: 0.7109 - clf_accuracy: 0.5819 - val_loss: 3.6816 - val_regr_loss: 0.7071 - val_clf_loss: 0.6776 - val_regr_mae: 0.6375 - val_clf_accuracy: 0.5673
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 76/77 [============================>.] - ETA: 0s - loss: 4.0038 - regr_loss: 0.8974 - clf_loss: 0.6606 - regr_mae: 0.7057 - clf_accuracy: 0.5954
# Epoch 00015: val_loss improved from 3.68162 to 3.60374, saving model to models\conv1d_univar\multitask\15.hdf5
# 77/77 [==============================] - 9s 120ms/step - loss: 3.9935 - regr_loss: 0.8924 - clf_loss: 0.6609 - regr_mae: 0.7043 - clf_accuracy: 0.5954 - val_loss: 3.6037 - val_regr_loss: 0.7074 - val_clf_loss: 0.6816 - val_regr_mae: 0.6331 - val_clf_accuracy: 0.5385
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 76/77 [============================>.] - ETA: 0s - loss: 3.8941 - regr_loss: 0.8830 - clf_loss: 0.6550 - regr_mae: 0.7029 - clf_accuracy: 0.6164
# Epoch 00016: val_loss improved from 3.60374 to 3.52228, saving model to models\conv1d_univar\multitask\16.hdf5
# 77/77 [==============================] - 9s 120ms/step - loss: 3.8852 - regr_loss: 0.8786 - clf_loss: 0.6552 - regr_mae: 0.7020 - clf_accuracy: 0.6170 - val_loss: 3.5223 - val_regr_loss: 0.6994 - val_clf_loss: 0.6850 - val_regr_mae: 0.6285 - val_clf_accuracy: 0.5192
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 76/77 [============================>.] - ETA: 0s - loss: 3.8490 - regr_loss: 0.8967 - clf_loss: 0.6499 - regr_mae: 0.7087 - clf_accuracy: 0.6139
# Epoch 00017: val_loss improved from 3.52228 to 3.46094, saving model to models\conv1d_univar\multitask\17.hdf5
# 77/77 [==============================] - 9s 120ms/step - loss: 3.8474 - regr_loss: 0.8951 - clf_loss: 0.6518 - regr_mae: 0.7083 - clf_accuracy: 0.6125 - val_loss: 3.4609 - val_regr_loss: 0.7026 - val_clf_loss: 0.6823 - val_regr_mae: 0.6327 - val_clf_accuracy: 0.5192
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 76/77 [============================>.] - ETA: 0s - loss: 3.7099 - regr_loss: 0.8558 - clf_loss: 0.6566 - regr_mae: 0.6925 - clf_accuracy: 0.6106
# Epoch 00018: val_loss improved from 3.46094 to 3.40341, saving model to models\conv1d_univar\multitask\18.hdf5
# 77/77 [==============================] - 10s 124ms/step - loss: 3.7140 - regr_loss: 0.8578 - clf_loss: 0.6572 - regr_mae: 0.6931 - clf_accuracy: 0.6112 - val_loss: 3.4034 - val_regr_loss: 0.7056 - val_clf_loss: 0.6815 - val_regr_mae: 0.6384 - val_clf_accuracy: 0.5481
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 76/77 [============================>.] - ETA: 0s - loss: 3.6095 - regr_loss: 0.8367 - clf_loss: 0.6558 - regr_mae: 0.6883 - clf_accuracy: 0.6139
# Epoch 00019: val_loss improved from 3.40341 to 3.34264, saving model to models\conv1d_univar\multitask\19.hdf5
# 77/77 [==============================] - 9s 121ms/step - loss: 3.6166 - regr_loss: 0.8403 - clf_loss: 0.6561 - regr_mae: 0.6901 - clf_accuracy: 0.6129 - val_loss: 3.3426 - val_regr_loss: 0.7056 - val_clf_loss: 0.6821 - val_regr_mae: 0.6394 - val_clf_accuracy: 0.5385
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 76/77 [============================>.] - ETA: 0s - loss: 3.5812 - regr_loss: 0.8503 - clf_loss: 0.6491 - regr_mae: 0.6909 - clf_accuracy: 0.6102
# Epoch 00020: val_loss improved from 3.34264 to 3.31154, saving model to models\conv1d_univar\multitask\20.hdf5
# 77/77 [==============================] - 9s 121ms/step - loss: 3.5780 - regr_loss: 0.8484 - clf_loss: 0.6501 - regr_mae: 0.6912 - clf_accuracy: 0.6092 - val_loss: 3.3115 - val_regr_loss: 0.7091 - val_clf_loss: 0.6804 - val_regr_mae: 0.6387 - val_clf_accuracy: 0.5577
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 76/77 [============================>.] - ETA: 0s - loss: 3.5385 - regr_loss: 0.8472 - clf_loss: 0.6469 - regr_mae: 0.6907 - clf_accuracy: 0.6176
# Epoch 00021: val_loss improved from 3.31154 to 3.27750, saving model to models\conv1d_univar\multitask\21.hdf5
# 77/77 [==============================] - 9s 120ms/step - loss: 3.5253 - regr_loss: 0.8411 - clf_loss: 0.6460 - regr_mae: 0.6890 - clf_accuracy: 0.6194 - val_loss: 3.2775 - val_regr_loss: 0.7086 - val_clf_loss: 0.6793 - val_regr_mae: 0.6399 - val_clf_accuracy: 0.5577
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 76/77 [============================>.] - ETA: 0s - loss: 3.4999 - regr_loss: 0.8408 - clf_loss: 0.6517 - regr_mae: 0.6884 - clf_accuracy: 0.6221
# Epoch 00022: val_loss improved from 3.27750 to 3.22921, saving model to models\conv1d_univar\multitask\22.hdf5
# 77/77 [==============================] - 9s 120ms/step - loss: 3.5031 - regr_loss: 0.8430 - clf_loss: 0.6508 - regr_mae: 0.6890 - clf_accuracy: 0.6239 - val_loss: 3.2292 - val_regr_loss: 0.7012 - val_clf_loss: 0.6754 - val_regr_mae: 0.6377 - val_clf_accuracy: 0.5577
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 76/77 [============================>.] - ETA: 0s - loss: 3.4766 - regr_loss: 0.8421 - clf_loss: 0.6535 - regr_mae: 0.6902 - clf_accuracy: 0.6114
# Epoch 00023: val_loss improved from 3.22921 to 3.20948, saving model to models\conv1d_univar\multitask\23.hdf5
# 77/77 [==============================] - 9s 121ms/step - loss: 3.4735 - regr_loss: 0.8410 - clf_loss: 0.6528 - regr_mae: 0.6905 - clf_accuracy: 0.6125 - val_loss: 3.2095 - val_regr_loss: 0.7048 - val_clf_loss: 0.6758 - val_regr_mae: 0.6391 - val_clf_accuracy: 0.5673
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 76/77 [============================>.] - ETA: 0s - loss: 3.4262 - regr_loss: 0.8343 - clf_loss: 0.6466 - regr_mae: 0.6851 - clf_accuracy: 0.6160
# Epoch 00024: val_loss improved from 3.20948 to 3.18100, saving model to models\conv1d_univar\multitask\24.hdf5
# 77/77 [==============================] - 9s 120ms/step - loss: 3.4401 - regr_loss: 0.8416 - clf_loss: 0.6461 - regr_mae: 0.6871 - clf_accuracy: 0.6161 - val_loss: 3.1810 - val_regr_loss: 0.7034 - val_clf_loss: 0.6768 - val_regr_mae: 0.6410 - val_clf_accuracy: 0.5865
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 76/77 [============================>.] - ETA: 0s - loss: 3.3768 - regr_loss: 0.8224 - clf_loss: 0.6430 - regr_mae: 0.6841 - clf_accuracy: 0.6246
# Epoch 00025: val_loss improved from 3.18100 to 3.16442, saving model to models\conv1d_univar\multitask\25.hdf5
# 77/77 [==============================] - 10s 125ms/step - loss: 3.3829 - regr_loss: 0.8253 - clf_loss: 0.6433 - regr_mae: 0.6851 - clf_accuracy: 0.6239 - val_loss: 3.1644 - val_regr_loss: 0.7028 - val_clf_loss: 0.6781 - val_regr_mae: 0.6403 - val_clf_accuracy: 0.5769
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 76/77 [============================>.] - ETA: 0s - loss: 3.4097 - regr_loss: 0.8429 - clf_loss: 0.6499 - regr_mae: 0.6923 - clf_accuracy: 0.6205
# Epoch 00026: val_loss improved from 3.16442 to 3.15103, saving model to models\conv1d_univar\multitask\26.hdf5
# 77/77 [==============================] - 10s 126ms/step - loss: 3.4059 - regr_loss: 0.8407 - clf_loss: 0.6506 - regr_mae: 0.6921 - clf_accuracy: 0.6194 - val_loss: 3.1510 - val_regr_loss: 0.7044 - val_clf_loss: 0.6760 - val_regr_mae: 0.6422 - val_clf_accuracy: 0.5385
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 76/77 [============================>.] - ETA: 0s - loss: 3.3936 - regr_loss: 0.8397 - clf_loss: 0.6546 - regr_mae: 0.6871 - clf_accuracy: 0.6201
# Epoch 00027: val_loss improved from 3.15103 to 3.13502, saving model to models\conv1d_univar\multitask\27.hdf5
# 77/77 [==============================] - 9s 122ms/step - loss: 3.3847 - regr_loss: 0.8349 - clf_loss: 0.6553 - regr_mae: 0.6853 - clf_accuracy: 0.6190 - val_loss: 3.1350 - val_regr_loss: 0.7035 - val_clf_loss: 0.6756 - val_regr_mae: 0.6424 - val_clf_accuracy: 0.5577
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 76/77 [============================>.] - ETA: 0s - loss: 3.4396 - regr_loss: 0.8716 - clf_loss: 0.6500 - regr_mae: 0.6982 - clf_accuracy: 0.6131
# Epoch 00028: val_loss improved from 3.13502 to 3.13221, saving model to models\conv1d_univar\multitask\28.hdf5
# 77/77 [==============================] - 9s 120ms/step - loss: 3.4394 - regr_loss: 0.8718 - clf_loss: 0.6495 - regr_mae: 0.6981 - clf_accuracy: 0.6145 - val_loss: 3.1322 - val_regr_loss: 0.7076 - val_clf_loss: 0.6765 - val_regr_mae: 0.6433 - val_clf_accuracy: 0.5673
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 76/77 [============================>.] - ETA: 0s - loss: 3.3422 - regr_loss: 0.8334 - clf_loss: 0.6407 - regr_mae: 0.6846 - clf_accuracy: 0.6382
# Epoch 00029: val_loss improved from 3.13221 to 3.11763, saving model to models\conv1d_univar\multitask\29.hdf5
# 77/77 [==============================] - 9s 120ms/step - loss: 3.3393 - regr_loss: 0.8323 - clf_loss: 0.6401 - regr_mae: 0.6848 - clf_accuracy: 0.6377 - val_loss: 3.1176 - val_regr_loss: 0.7066 - val_clf_loss: 0.6762 - val_regr_mae: 0.6418 - val_clf_accuracy: 0.5769
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 76/77 [============================>.] - ETA: 0s - loss: 3.3367 - regr_loss: 0.8303 - clf_loss: 0.6519 - regr_mae: 0.6776 - clf_accuracy: 0.6160
# Epoch 00030: val_loss improved from 3.11763 to 3.10609, saving model to models\conv1d_univar\multitask\30.hdf5
# 77/77 [==============================] - 9s 120ms/step - loss: 3.3401 - regr_loss: 0.8322 - clf_loss: 0.6515 - regr_mae: 0.6783 - clf_accuracy: 0.6174 - val_loss: 3.1061 - val_regr_loss: 0.7049 - val_clf_loss: 0.6763 - val_regr_mae: 0.6409 - val_clf_accuracy: 0.5769
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 76/77 [============================>.] - ETA: 0s - loss: 3.3339 - regr_loss: 0.8368 - clf_loss: 0.6437 - regr_mae: 0.6843 - clf_accuracy: 0.6221
# Epoch 00031: val_loss improved from 3.10609 to 3.09687, saving model to models\conv1d_univar\multitask\31.hdf5
# 77/77 [==============================] - 9s 121ms/step - loss: 3.3305 - regr_loss: 0.8357 - clf_loss: 0.6426 - regr_mae: 0.6840 - clf_accuracy: 0.6243 - val_loss: 3.0969 - val_regr_loss: 0.7040 - val_clf_loss: 0.6757 - val_regr_mae: 0.6412 - val_clf_accuracy: 0.5673
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 76/77 [============================>.] - ETA: 0s - loss: 3.3064 - regr_loss: 0.8265 - clf_loss: 0.6434 - regr_mae: 0.6841 - clf_accuracy: 0.6361
# Epoch 00032: val_loss improved from 3.09687 to 3.09449, saving model to models\conv1d_univar\multitask\32.hdf5
# 77/77 [==============================] - 10s 127ms/step - loss: 3.2971 - regr_loss: 0.8216 - clf_loss: 0.6438 - regr_mae: 0.6826 - clf_accuracy: 0.6357 - val_loss: 3.0945 - val_regr_loss: 0.7060 - val_clf_loss: 0.6756 - val_regr_mae: 0.6415 - val_clf_accuracy: 0.5769

# %%
def plot_multitask_history(hist):
    fig, ax = plt.subplots(2, 2, figsize=(16, 12))
    plotHelpers.plot_train_history(ax[0, 0], hist, 'Total loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[0, 1], hist, 'Accuracy', 'clf_accuracy', 'val_clf_accuracy')
    plotHelpers.plot_train_history(ax[1, 0], hist, 'MSE', 'regr_loss', 'val_regr_loss')
    plotHelpers.plot_train_history(ax[1, 1], hist, 'MAE', 'regr_mae', 'val_regr_mae')
    
plot_multitask_history(multitask_history);

# %% [markdown]
# ### Прогноз

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_multitask_conv1d.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret, pred_direction_proba = univariate_multitask_conv1d.predict_generator(test_multi_gen, verbose=1)
# Out:
# 5/5 [==============================] - 0s 30ms/step

# %%
np.set_printoptions(precision=3, suppress=True)

np.column_stack([pred_log_ret, pred_direction_proba])[-10:]
# Out:
# array([[ 0.134,  0.58 ],
#        [-0.004,  0.454],
#        [-0.06 ,  0.453],
#        [ 0.249,  0.55 ],
#        [ 0.261,  0.648],
#        [ 0.179,  0.584],
#        [ 0.277,  0.63 ],
#        [ 0.014,  0.587],
#        [-0.013,  0.596],
#        [ 0.013,  0.539]], dtype=float32)

# %% [markdown]
# #### Прогноз задачи регрессии

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret, figsize=(16, 20))

# %% [markdown]
# #### Прогноз задачи классификации

# %% [markdown]
# *ROC AUC увеличился по сравнению с однозадачной моделью классификации*.

# %%
true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 0.51711625

# %%
true_direction = test_multi_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([71, 77], dtype=int64)),
#  (array([0, 1]), array([75, 73], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.54      0.52        71
#            1       0.55      0.52      0.53        77
#
#     accuracy                           0.53       148
#    macro avg       0.53      0.53      0.53       148
# weighted avg       0.53      0.53      0.53       148

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[38, 33],
#        [37, 40]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.507, 0.452],
#        [0.493, 0.548]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# # Выводы
#
# 1.  Модель с 1D свёртками обучается гораздо быстрее модели LSTM
# 2.  Многозадачная модель позволила улучшить качество прогноза задачи классификации по сравнению с однозадачной.

# %% [markdown]
# # *Одномерная модель на LSTM* (1 слой)
#
# В качестве единственного признака используется сама цена.

# %%
import os
import glob
import datetime
import pickle

import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from pandas_datareader import data as pdr

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
import tensorflow as tf
# tf.test.is_gpu_available()
tf.__version__
# Out:
# '2.0.0'

# %%
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Input, Dense, LSTM, GRU, Flatten, ReLU, LeakyReLU, Dropout, BatchNormalization
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers import Nadam

# %%
from mdp import TimeSeries
from mdp import MarketData
from mdp import MovingWindowFeatures
from mdp import ClassificationGenerator, RegressionGenerator, MultitaskGenerator
from mdp import invert_log_ret

import mdp.utils as utils
import mdp.plotHelpers as plotHelpers

# %%
import importlib

import mdp

importlib.reload(mdp)
importlib.reload(mdp.datasetGenerator)
importlib.reload(mdp.marketData)
importlib.reload(mdp.movingWindowFeatures)
importlib.reload(mdp.timeSeries)
importlib.reload(mdp.plotHelpers)
importlib.reload(mdp.utils);

# %% [markdown]
# # *Параметры*

# %%
INSTRUMENT = 'CVX' # Chevron corp
START_FROM = '2018-11-14'
WINDOW_SIZE = 10
FORECAST_OFFSET=1
BATCH_SIZE = 8
VAL_SPLIT = '2019-11-01'
TEST_SPLIT = '2019-12-01'
FORCE_TRAIN = True

# %% [markdown]
# # *Исходные данные*
#
# Загрузка данных и вычисление индикаторов.

# %%
instr = MarketData.create_from_tiingo(INSTRUMENT, start=START_FROM)

# %%
instr.feature_names
# Out:
# ['o',
#  'h',
#  'l',
#  'c',
#  'v',
#  'ema14',
#  'ema30',
#  'macd',
#  'macd_signal',
#  'rsi14',
#  'bband20_upper',
#  'bband20_middle',
#  'bband20_lower',
#  'willr14',
#  'stochk',
#  'stochd',
#  'adline',
#  'adosc']

# %% [markdown]
# ## Целевая переменная

# %% [markdown]
# Цена закрытия.

# %%
orig_target = instr.c

# %% [markdown]
# Переходим к логарифмической доходности.

# %%
transformed_target = instr.c.transform(transforms={'ratios' : {}, 'ln' : {}})

# %%
plotHelpers.plot_transformed_timeseries_unit(instr,
                                             transformed_target,
                                             'Daily close price, USD', 'Daily log return')

# %% [markdown]
# ## Трансформация признаков
#
# Выбираем только один признак: цену закрытия.
# Временной ряд цены преобразуется к логарифмической доходности (что также позволяет убрать нестационарность).

# %%
def make_feature_selector():
    price_transformer = lambda: {'ratios': {}, 'ln': {}}
    diff_transformer = lambda o: {'diffs': {'order': o}}
    identity_transformer = lambda: {}
    feature_transformations = {
        'c': price_transformer(),
    }
    return feature_transformations

# %%
instr_transformed = instr.select_transform(make_feature_selector())

# %%
transformed_target = instr_transformed.c

# %% [markdown]
# ## Обучающая, валидационная и тестовая выборки

# %%
instr_train, instr_val_test = instr_transformed.train_test_split(VAL_SPLIT, window_size=WINDOW_SIZE,
                                                                 scaler=StandardScaler)
#                                                                  scaler=MinMaxScaler,
#                                                                  scaler_kwargs={'feature_range': (-1, 1)})

instr_val, instr_test = instr_val_test.train_test_split(TEST_SPLIT, window_size=WINDOW_SIZE, scaler=None)

len(instr_train), len(instr_val), len(instr_test)
# Out:
# (208, 30, 25)

# %% [markdown]
# ## Признаки - скользящие окна

# %%
train_mwf = MovingWindowFeatures.create(instr_train.c, [instr_train], instr_train.feature_names, window_size=WINDOW_SIZE)
val_mwf = MovingWindowFeatures.create(instr_val.c, [instr_val], instr_val.feature_names, window_size=WINDOW_SIZE)
test_mwf = MovingWindowFeatures.create(instr_test.c, [instr_test], instr_test.feature_names, window_size=WINDOW_SIZE)

len(instr_train), len(train_mwf), train_mwf.features.shape
# Out:
# (208, 198, (198, 10, 1))

# %% [markdown]
# Проверка, что скользящие окна соответствуют исходным данным.
#
# Возьмём произвольный признак и произвольное окно (строка #**41**). Проверим, что данные в точности совпадают:

# %%
def check_data(md, mwf, row):
    col = np.random.randint(len(mwf.feature_names))
    feature = mwf.feature_names[col]
    check = (getattr(md, feature).data[row:row + mwf.window_size] == mwf.features[row, :, col]).all()
    assert check
    return feature, check

check_data(instr_train, train_mwf, 41)
# Out:
# ('c', True)

# %% [markdown]
# # *Модели*

# %% [markdown]
# Модель с одним LSTM слоем.

# %%
def build_lstm_layers(input_shape, latent_dim=16):
    # формат входа: матрица (окно; признак)
    inp = Input(input_shape, name='input')

    lstm = LSTM(latent_dim, return_sequences=True,
                    recurrent_dropout=0.2, dropout=0.2,
                    bias_initializer='he_uniform',
                    bias_regularizer=L1L2(0.01, 0.02),
                    kernel_regularizer=L1L2(0.01, 0.02),
                    recurrent_regularizer=L1L2(0.01, 0.02)
               )(inp)
    
    lstm = Flatten()(lstm)
    
    return inp, lstm

# %% [markdown]
# #### Пути сохранения моделей:

# %%
model_path_root = 'models'
model_type_name = 'lstm1_univar'

def make_model_save_dir(path_root, type_name, class_name):
    save_dir = os.path.join(path_root, type_name, class_name)
    os.makedirs(save_dir, exist_ok=True)
    return save_dir

# %% [markdown]
# #### Общие коллбэки:

# %%
# уменьшение learning rate в случае, если loss не изменяется
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001, verbose=1)

# уменьшение learning rate в 2 раза каждую 5-ю эпоху
def lr_decay(e, lr):
    return lr * (1 - 0.5 * (0 == (e + 1) % 5))

lr_scheduler = LearningRateScheduler(schedule=lr_decay, verbose=1)

# %% [markdown]
# ## Задача регрессии
#
# Непосредственное прогнозирование цены следующего периода.

# %%
train_regr_gen = RegressionGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_regr_gen = RegressionGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_regr_gen = RegressionGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# Следующие числа соответствуют значению параметра `steps_per_epoch` метода [`fit_generator`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit_generator "tf.keras.layers.SimpleRNN &nbsp;|&nbsp; TensorFlow Core r2.0") - то есть это число батчей, которые генератор выдаст за одну эпоху обучения (если класс генератора поддерживает метод `len()`, то данный параметр можно не указывать).

# %%
len(train_regr_gen), len(val_regr_gen), len(test_regr_gen)
# Out:
# (25, 3, 2)

# %% [markdown]
# Один сэмпл данных представляет собой матрицу размером *(длина окна; число признаков)*

# %%
train_regr_gen.input_shape
# Out:
# (10, 1)

# %% [markdown]
# ### Модель для задачи регрессии

# %%
model_class_name = 'regression'

# %%
def build_regression_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape)

    regr = Dense(32)(lstm)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    return Model(inputs=[inp], outputs=[regr])

# %%
univariate_regression_lstm = build_regression_model(train_regr_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:
# [`Nadam`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Nadam) (*Adam with Nestrov momentum*).

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Функция потерь:
#
# В качестве функции потерь будем использовать [MSE](https://www.tensorflow.org/api_docs/python/tf/keras/losses/MSE) (чтобы штрафовать за большие отклонения). Xотя хорошая функция потерь в контексте темы данной задачи - это [вопрос сложный](https://github.com/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Chapter5_LossFunctions/Ch5_LossFunctions_PyMC3.ipynb). В частности, здесь нам, очевидно, помимо абсолютного значения отклонения также важен его знак.

# %%
univariate_regression_lstm.compile(optimizer=optimizer,
                                   loss={'regr': 'mse'},
                                   metrics={'regr': 'mae'})

univariate_regression_lstm.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 10, 1)]           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 10, 16)            1152
# _________________________________________________________________
# flatten (Flatten)            (None, 160)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                5152
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32)                128
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 32)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# regr (Dense)                 (None, 1)                 33
# =================================================================
# Total params: 6,465
# Trainable params: 6,401
# Non-trainable params: 64
# _________________________________________________________________

# %% [markdown]
# #### Обучение:

# %%
regr_history = utils.train_model(univariate_regression_lstm,
                                 model_save_dir, train_regr_gen, val_regr_gen,
                                 callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                 force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.7329 - mae: 1.2125
# Epoch 00001: val_loss improved from inf to 3.30859, saving model to models\lstm1_univar\regression\01.hdf5
# 25/25 [==============================] - 3s 135ms/step - loss: 4.6858 - mae: 1.2026 - val_loss: 3.3086 - val_mae: 0.8158
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.6865 - mae: 1.1831
# Epoch 00002: val_loss improved from 3.30859 to 3.21684, saving model to models\lstm1_univar\regression\02.hdf5
# 25/25 [==============================] - 4s 173ms/step - loss: 4.7216 - mae: 1.1895 - val_loss: 3.2168 - val_mae: 0.8133
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.7558 - mae: 1.0487
# Epoch 00003: val_loss improved from 3.21684 to 3.11859, saving model to models\lstm1_univar\regression\03.hdf5
# 25/25 [==============================] - 4s 145ms/step - loss: 3.7168 - mae: 1.0412 - val_loss: 3.1186 - val_mae: 0.7917
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.5724 - mae: 1.0056
# Epoch 00004: val_loss improved from 3.11859 to 3.04545, saving model to models\lstm1_univar\regression\04.hdf5
# 25/25 [==============================] - 4s 169ms/step - loss: 3.5272 - mae: 0.9965 - val_loss: 3.0454 - val_mae: 0.7903
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.5937 - mae: 0.9788
# Epoch 00005: val_loss improved from 3.04545 to 3.01232, saving model to models\lstm1_univar\regression\05.hdf5
# 25/25 [==============================] - 4s 147ms/step - loss: 3.5763 - mae: 0.9819 - val_loss: 3.0123 - val_mae: 0.7902
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.6382 - mae: 1.0408
# Epoch 00006: val_loss improved from 3.01232 to 2.97634, saving model to models\lstm1_univar\regression\06.hdf5
# 25/25 [==============================] - 3s 118ms/step - loss: 3.6922 - mae: 1.0498 - val_loss: 2.9763 - val_mae: 0.7929
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.3958 - mae: 1.0071
# Epoch 00007: val_loss improved from 2.97634 to 2.94962, saving model to models\lstm1_univar\regression\07.hdf5
# 25/25 [==============================] - 3s 109ms/step - loss: 3.4745 - mae: 1.0313 - val_loss: 2.9496 - val_mae: 0.7943
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.4602 - mae: 1.0371
# Epoch 00008: val_loss improved from 2.94962 to 2.92047, saving model to models\lstm1_univar\regression\08.hdf5
# 25/25 [==============================] - 4s 160ms/step - loss: 3.5696 - mae: 1.0577 - val_loss: 2.9205 - val_mae: 0.7971
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.2204 - mae: 0.9772
# Epoch 00009: val_loss improved from 2.92047 to 2.89230, saving model to models\lstm1_univar\regression\09.hdf5
# 25/25 [==============================] - 4s 170ms/step - loss: 3.2403 - mae: 0.9862 - val_loss: 2.8923 - val_mae: 0.7996
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.0363 - mae: 0.9003
# Epoch 00010: val_loss improved from 2.89230 to 2.88431, saving model to models\lstm1_univar\regression\10.hdf5
# 25/25 [==============================] - 3s 130ms/step - loss: 3.0263 - mae: 0.8947 - val_loss: 2.8843 - val_mae: 0.8037
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.1334 - mae: 0.9432
# Epoch 00011: val_loss improved from 2.88431 to 2.87674, saving model to models\lstm1_univar\regression\11.hdf5
# 25/25 [==============================] - 3s 134ms/step - loss: 3.1631 - mae: 0.9478 - val_loss: 2.8767 - val_mae: 0.8091
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.2118 - mae: 0.9689
# Epoch 00012: val_loss improved from 2.87674 to 2.86381, saving model to models\lstm1_univar\regression\12.hdf5
# 25/25 [==============================] - 5s 202ms/step - loss: 3.1936 - mae: 0.9697 - val_loss: 2.8638 - val_mae: 0.8077
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.2451 - mae: 1.0016
# Epoch 00013: val_loss improved from 2.86381 to 2.84933, saving model to models\lstm1_univar\regression\13.hdf5
# 25/25 [==============================] - 5s 199ms/step - loss: 3.2137 - mae: 0.9961 - val_loss: 2.8493 - val_mae: 0.8053
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.1439 - mae: 0.9545
# Epoch 00014: val_loss did not improve from 2.84933
# 25/25 [==============================] - 3s 105ms/step - loss: 3.1270 - mae: 0.9550 - val_loss: 2.8515 - val_mae: 0.8140
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.9544 - mae: 0.9219
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 2.5000001187436283e-05.
#
# Epoch 00015: val_loss did not improve from 2.84933
# 25/25 [==============================] - 3s 106ms/step - loss: 2.9722 - mae: 0.9355 - val_loss: 2.8705 - val_mae: 0.8229
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 16/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.2121 - mae: 0.9754
# Epoch 00016: val_loss did not improve from 2.84933
# 25/25 [==============================] - 3s 117ms/step - loss: 3.2113 - mae: 0.9740 - val_loss: 2.8840 - val_mae: 0.8265
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 17/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.2841 - mae: 1.0080
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00017: val_loss did not improve from 2.84933
# 25/25 [==============================] - 3s 132ms/step - loss: 3.2391 - mae: 0.9995 - val_loss: 2.8994 - val_mae: 0.8303
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 9.999999747378752e-06.
# Epoch 18/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.1065 - mae: 0.9845
# Epoch 00018: val_loss did not improve from 2.84933
# 25/25 [==============================] - 4s 160ms/step - loss: 3.1167 - mae: 0.9889 - val_loss: 2.9157 - val_mae: 0.8340
# Epoch 00018: early stopping

# %%
def plot_regr_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'MSE', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'MAE', 'mae', 'val_mae')
    
plot_regr_history(regr_history);

# %% [markdown]
# ### Прогноз задачи регрессии

# %% [markdown]
# *Судя по всему, просто выходит на модель случайного блуждания*.

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_regression_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret_test = univariate_regression_lstm.predict_generator(test_regr_gen, verbose=1)
# Out:
# 2/2 [==============================] - 0s 35ms/step

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret_test, figsize=(16, 10), datetime_unit='D')

# %% [markdown]
# ## Задача классификации
#
# Прогнозируем направление изменения цены по сравнению с предыдущим периодом (**0** - снижение, **1** - рост).

# %%
model_class_name = 'classification'

# %%
train_clf_gen = ClassificationGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_clf_gen = ClassificationGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_clf_gen = ClassificationGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_classification_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape)

    clf = Dense(32)(lstm)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)

    return Model(inputs=[inp], outputs=[clf])

# %%
univariate_classification_lstm = build_classification_model(test_clf_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
univariate_classification_lstm.compile(optimizer=optimizer,
                                         loss={'clf': 'binary_crossentropy'},
                                         metrics={'clf': 'accuracy'})

univariate_classification_lstm.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 10, 1)]           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 16)            1152
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 160)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                5152
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32)                128
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 32)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# clf (Dense)                  (None, 1)                 33
# =================================================================
# Total params: 6,465
# Trainable params: 6,401
# Non-trainable params: 64
# _________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
clf_history = utils.train_model(univariate_classification_lstm,
                                model_save_dir, train_clf_gen, val_clf_gen,
                                callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.9326 - accuracy: 0.5156
# Epoch 00001: val_loss improved from inf to 2.61821, saving model to models\lstm1_univar\classification\01.hdf5
# 25/25 [==============================] - 4s 154ms/step - loss: 2.9263 - accuracy: 0.5101 - val_loss: 2.6182 - val_accuracy: 0.4500
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.5972 - accuracy: 0.4896
# Epoch 00002: val_loss improved from 2.61821 to 2.36934, saving model to models\lstm1_univar\classification\02.hdf5
# 25/25 [==============================] - 3s 137ms/step - loss: 2.6060 - accuracy: 0.4798 - val_loss: 2.3693 - val_accuracy: 0.4500
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.3553 - accuracy: 0.5312
# Epoch 00003: val_loss improved from 2.36934 to 2.16167, saving model to models\lstm1_univar\classification\03.hdf5
# 25/25 [==============================] - 4s 158ms/step - loss: 2.3400 - accuracy: 0.5354 - val_loss: 2.1617 - val_accuracy: 0.5000
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.1419 - accuracy: 0.5260
# Epoch 00004: val_loss improved from 2.16167 to 1.98304, saving model to models\lstm1_univar\classification\04.hdf5
# 25/25 [==============================] - 4s 164ms/step - loss: 2.1326 - accuracy: 0.5354 - val_loss: 1.9830 - val_accuracy: 0.4500
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.0347 - accuracy: 0.5104
# Epoch 00005: val_loss improved from 1.98304 to 1.90453, saving model to models\lstm1_univar\classification\05.hdf5
# 25/25 [==============================] - 3s 121ms/step - loss: 2.0320 - accuracy: 0.5152 - val_loss: 1.9045 - val_accuracy: 0.6000
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 24/25 [===========================>..] - ETA: 0s - loss: 1.9316 - accuracy: 0.5104
# Epoch 00006: val_loss improved from 1.90453 to 1.83130, saving model to models\lstm1_univar\classification\06.hdf5
# 25/25 [==============================] - 4s 175ms/step - loss: 1.9326 - accuracy: 0.5051 - val_loss: 1.8313 - val_accuracy: 0.5500
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 24/25 [===========================>..] - ETA: 0s - loss: 1.9376 - accuracy: 0.4948
# Epoch 00007: val_loss improved from 1.83130 to 1.76496, saving model to models\lstm1_univar\classification\07.hdf5
# 25/25 [==============================] - 5s 187ms/step - loss: 1.9239 - accuracy: 0.5000 - val_loss: 1.7650 - val_accuracy: 0.5000
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 24/25 [===========================>..] - ETA: 0s - loss: 1.7706 - accuracy: 0.5729
# Epoch 00008: val_loss improved from 1.76496 to 1.69900, saving model to models\lstm1_univar\classification\08.hdf5
# 25/25 [==============================] - 4s 171ms/step - loss: 1.7732 - accuracy: 0.5657 - val_loss: 1.6990 - val_accuracy: 0.5000
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 24/25 [===========================>..] - ETA: 0s - loss: 1.6886 - accuracy: 0.5885
# Epoch 00009: val_loss improved from 1.69900 to 1.64207, saving model to models\lstm1_univar\classification\09.hdf5
# 25/25 [==============================] - 4s 177ms/step - loss: 1.6905 - accuracy: 0.5909 - val_loss: 1.6421 - val_accuracy: 0.5000
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 24/25 [===========================>..] - ETA: 0s - loss: 1.6692 - accuracy: 0.5729
# Epoch 00010: val_loss improved from 1.64207 to 1.61666, saving model to models\lstm1_univar\classification\10.hdf5
# 25/25 [==============================] - 3s 121ms/step - loss: 1.6655 - accuracy: 0.5758 - val_loss: 1.6167 - val_accuracy: 0.5000
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 24/25 [===========================>..] - ETA: 0s - loss: 1.7084 - accuracy: 0.4896
# Epoch 00011: val_loss improved from 1.61666 to 1.59408, saving model to models\lstm1_univar\classification\11.hdf5
# 25/25 [==============================] - 3s 119ms/step - loss: 1.6995 - accuracy: 0.4949 - val_loss: 1.5941 - val_accuracy: 0.5000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 24/25 [===========================>..] - ETA: 0s - loss: 1.5932 - accuracy: 0.5417
# Epoch 00012: val_loss improved from 1.59408 to 1.57021, saving model to models\lstm1_univar\classification\12.hdf5
# 25/25 [==============================] - 3s 121ms/step - loss: 1.5932 - accuracy: 0.5404 - val_loss: 1.5702 - val_accuracy: 0.5000
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 24/25 [===========================>..] - ETA: 0s - loss: 1.6014 - accuracy: 0.5417
# Epoch 00013: val_loss improved from 1.57021 to 1.54502, saving model to models\lstm1_univar\classification\13.hdf5
# 25/25 [==============================] - 3s 120ms/step - loss: 1.6018 - accuracy: 0.5455 - val_loss: 1.5450 - val_accuracy: 0.5000
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 24/25 [===========================>..] - ETA: 0s - loss: 1.5454 - accuracy: 0.5729
# Epoch 00014: val_loss improved from 1.54502 to 1.51692, saving model to models\lstm1_univar\classification\14.hdf5
# 25/25 [==============================] - 3s 121ms/step - loss: 1.5422 - accuracy: 0.5758 - val_loss: 1.5169 - val_accuracy: 0.5000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 24/25 [===========================>..] - ETA: 0s - loss: 1.5701 - accuracy: 0.5521
# Epoch 00015: val_loss improved from 1.51692 to 1.49875, saving model to models\lstm1_univar\classification\15.hdf5
# 25/25 [==============================] - 4s 165ms/step - loss: 1.5746 - accuracy: 0.5505 - val_loss: 1.4988 - val_accuracy: 0.5500
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 24/25 [===========================>..] - ETA: 0s - loss: 1.5744 - accuracy: 0.5833
# Epoch 00016: val_loss improved from 1.49875 to 1.48122, saving model to models\lstm1_univar\classification\16.hdf5
# 25/25 [==============================] - 3s 134ms/step - loss: 1.5810 - accuracy: 0.5707 - val_loss: 1.4812 - val_accuracy: 0.5500
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 24/25 [===========================>..] - ETA: 0s - loss: 1.5139 - accuracy: 0.5885
# Epoch 00017: val_loss improved from 1.48122 to 1.46749, saving model to models\lstm1_univar\classification\17.hdf5
# 25/25 [==============================] - 3s 136ms/step - loss: 1.5085 - accuracy: 0.5960 - val_loss: 1.4675 - val_accuracy: 0.6000
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 24/25 [===========================>..] - ETA: 0s - loss: 1.5322 - accuracy: 0.5312
# Epoch 00018: val_loss improved from 1.46749 to 1.45898, saving model to models\lstm1_univar\classification\18.hdf5
# 25/25 [==============================] - 4s 159ms/step - loss: 1.5351 - accuracy: 0.5303 - val_loss: 1.4590 - val_accuracy: 0.6000
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 24/25 [===========================>..] - ETA: 0s - loss: 1.5173 - accuracy: 0.5625
# Epoch 00019: val_loss improved from 1.45898 to 1.44790, saving model to models\lstm1_univar\classification\19.hdf5
# 25/25 [==============================] - 4s 168ms/step - loss: 1.5124 - accuracy: 0.5657 - val_loss: 1.4479 - val_accuracy: 0.5500
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 24/25 [===========================>..] - ETA: 0s - loss: 1.5186 - accuracy: 0.5521
# Epoch 00020: val_loss improved from 1.44790 to 1.43907, saving model to models\lstm1_univar\classification\20.hdf5
# 25/25 [==============================] - 3s 136ms/step - loss: 1.5190 - accuracy: 0.5505 - val_loss: 1.4391 - val_accuracy: 0.6000
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 24/25 [===========================>..] - ETA: 0s - loss: 1.5295 - accuracy: 0.5052
# Epoch 00021: val_loss improved from 1.43907 to 1.43024, saving model to models\lstm1_univar\classification\21.hdf5
# 25/25 [==============================] - 3s 125ms/step - loss: 1.5209 - accuracy: 0.5152 - val_loss: 1.4302 - val_accuracy: 0.6000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 24/25 [===========================>..] - ETA: 0s - loss: 1.4809 - accuracy: 0.5729
# Epoch 00022: val_loss improved from 1.43024 to 1.42334, saving model to models\lstm1_univar\classification\22.hdf5
# 25/25 [==============================] - 3s 128ms/step - loss: 1.4745 - accuracy: 0.5707 - val_loss: 1.4233 - val_accuracy: 0.7500
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 24/25 [===========================>..] - ETA: 0s - loss: 1.5108 - accuracy: 0.5677
# Epoch 00023: val_loss improved from 1.42334 to 1.41408, saving model to models\lstm1_univar\classification\23.hdf5
# 25/25 [==============================] - 3s 139ms/step - loss: 1.5012 - accuracy: 0.5758 - val_loss: 1.4141 - val_accuracy: 0.7500
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 24/25 [===========================>..] - ETA: 0s - loss: 1.5162 - accuracy: 0.5469
# Epoch 00024: val_loss improved from 1.41408 to 1.40201, saving model to models\lstm1_univar\classification\24.hdf5
# 25/25 [==============================] - 3s 123ms/step - loss: 1.5136 - accuracy: 0.5455 - val_loss: 1.4020 - val_accuracy: 0.7000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 24/25 [===========================>..] - ETA: 0s - loss: 1.4843 - accuracy: 0.6042
# Epoch 00025: val_loss improved from 1.40201 to 1.39705, saving model to models\lstm1_univar\classification\25.hdf5
# 25/25 [==============================] - 3s 122ms/step - loss: 1.4899 - accuracy: 0.6010 - val_loss: 1.3971 - val_accuracy: 0.7000
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 24/25 [===========================>..] - ETA: 0s - loss: 1.5292 - accuracy: 0.5156
# Epoch 00026: val_loss improved from 1.39705 to 1.39336, saving model to models\lstm1_univar\classification\26.hdf5
# 25/25 [==============================] - 3s 122ms/step - loss: 1.5307 - accuracy: 0.5152 - val_loss: 1.3934 - val_accuracy: 0.7000
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 24/25 [===========================>..] - ETA: 0s - loss: 1.4273 - accuracy: 0.6302
# Epoch 00027: val_loss improved from 1.39336 to 1.39108, saving model to models\lstm1_univar\classification\27.hdf5
# 25/25 [==============================] - 4s 165ms/step - loss: 1.4327 - accuracy: 0.6162 - val_loss: 1.3911 - val_accuracy: 0.7000
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 24/25 [===========================>..] - ETA: 0s - loss: 1.4737 - accuracy: 0.5469
# Epoch 00028: val_loss improved from 1.39108 to 1.38826, saving model to models\lstm1_univar\classification\28.hdf5
# 25/25 [==============================] - 4s 169ms/step - loss: 1.4850 - accuracy: 0.5455 - val_loss: 1.3883 - val_accuracy: 0.7000
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 24/25 [===========================>..] - ETA: 0s - loss: 1.4177 - accuracy: 0.6042
# Epoch 00029: val_loss improved from 1.38826 to 1.38497, saving model to models\lstm1_univar\classification\29.hdf5
# 25/25 [==============================] - 4s 159ms/step - loss: 1.4320 - accuracy: 0.5960 - val_loss: 1.3850 - val_accuracy: 0.7000
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 24/25 [===========================>..] - ETA: 0s - loss: 1.4258 - accuracy: 0.6042
# Epoch 00030: val_loss improved from 1.38497 to 1.38253, saving model to models\lstm1_univar\classification\30.hdf5
# 25/25 [==============================] - 3s 135ms/step - loss: 1.4414 - accuracy: 0.5960 - val_loss: 1.3825 - val_accuracy: 0.7000
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 24/25 [===========================>..] - ETA: 0s - loss: 1.4814 - accuracy: 0.5417
# Epoch 00031: val_loss improved from 1.38253 to 1.37994, saving model to models\lstm1_univar\classification\31.hdf5
# 25/25 [==============================] - 3s 137ms/step - loss: 1.4783 - accuracy: 0.5505 - val_loss: 1.3799 - val_accuracy: 0.7000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 24/25 [===========================>..] - ETA: 0s - loss: 1.4854 - accuracy: 0.5208
# Epoch 00032: val_loss improved from 1.37994 to 1.37699, saving model to models\lstm1_univar\classification\32.hdf5
# 25/25 [==============================] - 4s 161ms/step - loss: 1.4774 - accuracy: 0.5303 - val_loss: 1.3770 - val_accuracy: 0.7000

# %%
def plot_clf_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'Loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'Accuracy', 'accuracy', 'val_accuracy')
    
plot_clf_history(clf_history);

# %% [markdown]
# ### Прогноз задачи классификации

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_classification_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %%
pred_direction_proba = univariate_classification_lstm.predict_generator(test_clf_gen, verbose=1)

true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 2/2 [==============================] - 0s 33ms/step
# 0.50073063

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([9, 6], dtype=int64)),
#  (array([0, 1]), array([8, 7], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.44      0.47         9
#            1       0.29      0.33      0.31         6
#
#     accuracy                           0.40        15
#    macro avg       0.39      0.39      0.39        15
# weighted avg       0.41      0.40      0.41        15

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[4, 5],
#        [4, 2]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.5       , 0.71428571],
#        [0.5       , 0.28571429]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# ## Многозадачная модель: одновременно регрессия и классификация
#
# Пытаемся одновременно предсказать и значение цены, и направление изменения, предполагая, что комбинированная ошибка позволит точнее скорректировать веса рекуррентных слоёв.

# %%
model_class_name = 'multitask'

# %%
train_multi_gen = MultitaskGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_multi_gen = MultitaskGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_multi_gen = MultitaskGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_multitask_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape)

    # первый выход: задача регрссии
    regr = Dense(32)(lstm)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    # второй выход: задача классификации
    clf = Dense(32)(lstm)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)
    
    return Model(inputs=[inp], outputs=[regr, clf])

# %%
univariate_multitask_lstm = build_multitask_model(train_multi_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
univariate_multitask_lstm.compile(optimizer=optimizer,
                                  loss={'regr': 'mse', 'clf': 'binary_crossentropy'},
                                  loss_weights={'regr': 2., 'clf': 1.},
                                  metrics={'regr': 'mae', 'clf' : 'accuracy'})

univariate_multitask_lstm.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 10, 1)]      0
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 10, 16)       1152        input[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 160)          0           lstm_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 32)           5152        flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 32)           5152        flatten_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32)           128         dense_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32)           128         dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 32)           0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 32)           0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32)           0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 32)           0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# regr (Dense)                    (None, 1)            33          dropout_2[0][0]
# __________________________________________________________________________________________________
# clf (Dense)                     (None, 1)            33          dropout_3[0][0]
# ==================================================================================================
# Total params: 11,778
# Trainable params: 11,650
# Non-trainable params: 128
# __________________________________________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
multitask_history = utils.train_model(univariate_multitask_lstm,
                                      model_save_dir, train_multi_gen, val_multi_gen,
                                      callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                      force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 24/25 [===========================>..] - ETA: 0s - loss: 8.7148 - regr_loss: 2.8197 - clf_loss: 0.9033 - regr_mae: 1.3249 - clf_accuracy: 0.5052
# Epoch 00001: val_loss improved from inf to 5.27310, saving model to models\lstm1_univar\multitask\01.hdf5
# 25/25 [==============================] - 4s 174ms/step - loss: 8.6525 - regr_loss: 2.7956 - clf_loss: 0.8897 - regr_mae: 1.3214 - clf_accuracy: 0.5152 - val_loss: 5.2731 - val_regr_loss: 1.2005 - val_clf_loss: 0.7248 - val_regr_mae: 0.7856 - val_clf_accuracy: 0.4000
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.2193 - regr_loss: 2.1369 - clf_loss: 0.8203 - regr_mae: 1.1017 - clf_accuracy: 0.5260
# Epoch 00002: val_loss improved from 5.27310 to 5.23357, saving model to models\lstm1_univar\multitask\02.hdf5
# 25/25 [==============================] - 4s 155ms/step - loss: 7.1435 - regr_loss: 2.0952 - clf_loss: 0.8283 - regr_mae: 1.0986 - clf_accuracy: 0.5152 - val_loss: 5.2336 - val_regr_loss: 1.2140 - val_clf_loss: 0.7078 - val_regr_mae: 0.7763 - val_clf_accuracy: 0.4500
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 24/25 [===========================>..] - ETA: 0s - loss: 6.8856 - regr_loss: 1.9860 - clf_loss: 0.8400 - regr_mae: 1.0423 - clf_accuracy: 0.5052
# Epoch 00003: val_loss improved from 5.23357 to 5.22723, saving model to models\lstm1_univar\multitask\03.hdf5
# 25/25 [==============================] - 4s 165ms/step - loss: 6.8662 - regr_loss: 1.9794 - clf_loss: 0.8348 - regr_mae: 1.0449 - clf_accuracy: 0.5051 - val_loss: 5.2272 - val_regr_loss: 1.2403 - val_clf_loss: 0.7026 - val_regr_mae: 0.7926 - val_clf_accuracy: 0.4500
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 24/25 [===========================>..] - ETA: 0s - loss: 6.4313 - regr_loss: 1.8283 - clf_loss: 0.7522 - regr_mae: 1.0358 - clf_accuracy: 0.5469
# Epoch 00004: val_loss improved from 5.22723 to 5.19126, saving model to models\lstm1_univar\multitask\04.hdf5
# 25/25 [==============================] - 4s 148ms/step - loss: 6.5341 - regr_loss: 1.8837 - clf_loss: 0.7462 - regr_mae: 1.0520 - clf_accuracy: 0.5505 - val_loss: 5.1913 - val_regr_loss: 1.2466 - val_clf_loss: 0.7002 - val_regr_mae: 0.7983 - val_clf_accuracy: 0.4000
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.4605 - regr_loss: 2.3614 - clf_loss: 0.7511 - regr_mae: 1.1173 - clf_accuracy: 0.5156
# Epoch 00005: val_loss improved from 5.19126 to 5.18897, saving model to models\lstm1_univar\multitask\05.hdf5
# 25/25 [==============================] - 4s 159ms/step - loss: 7.2946 - regr_loss: 2.2819 - clf_loss: 0.7432 - regr_mae: 1.1006 - clf_accuracy: 0.5202 - val_loss: 5.1890 - val_regr_loss: 1.2602 - val_clf_loss: 0.6952 - val_regr_mae: 0.8058 - val_clf_accuracy: 0.4500
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 24/25 [===========================>..] - ETA: 0s - loss: 6.1820 - regr_loss: 1.7358 - clf_loss: 0.7484 - regr_mae: 1.0301 - clf_accuracy: 0.5573
# Epoch 00006: val_loss did not improve from 5.18897
# 25/25 [==============================] - 4s 164ms/step - loss: 6.2619 - regr_loss: 1.7779 - clf_loss: 0.7454 - regr_mae: 1.0286 - clf_accuracy: 0.5606 - val_loss: 5.2024 - val_regr_loss: 1.2852 - val_clf_loss: 0.6839 - val_regr_mae: 0.8224 - val_clf_accuracy: 0.7000
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 24/25 [===========================>..] - ETA: 0s - loss: 6.5329 - regr_loss: 1.9151 - clf_loss: 0.7662 - regr_mae: 1.0222 - clf_accuracy: 0.4948
# Epoch 00007: val_loss improved from 5.18897 to 5.14898, saving model to models\lstm1_univar\multitask\07.hdf5
# 25/25 [==============================] - 4s 168ms/step - loss: 6.4475 - regr_loss: 1.8775 - clf_loss: 0.7556 - regr_mae: 1.0187 - clf_accuracy: 0.5051 - val_loss: 5.1490 - val_regr_loss: 1.2729 - val_clf_loss: 0.6801 - val_regr_mae: 0.8161 - val_clf_accuracy: 0.7000
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 24/25 [===========================>..] - ETA: 0s - loss: 6.1352 - regr_loss: 1.7462 - clf_loss: 0.7321 - regr_mae: 1.0522 - clf_accuracy: 0.5521
# Epoch 00008: val_loss improved from 5.14898 to 5.13570, saving model to models\lstm1_univar\multitask\08.hdf5
# 25/25 [==============================] - 4s 169ms/step - loss: 6.0909 - regr_loss: 1.7274 - clf_loss: 0.7254 - regr_mae: 1.0467 - clf_accuracy: 0.5606 - val_loss: 5.1357 - val_regr_loss: 1.2806 - val_clf_loss: 0.6774 - val_regr_mae: 0.8195 - val_clf_accuracy: 0.6500
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 24/25 [===========================>..] - ETA: 0s - loss: 6.3016 - regr_loss: 1.8172 - clf_loss: 0.7813 - regr_mae: 1.0312 - clf_accuracy: 0.4792
# Epoch 00009: val_loss did not improve from 5.13570
# 25/25 [==============================] - 4s 155ms/step - loss: 6.3855 - regr_loss: 1.8610 - clf_loss: 0.7789 - regr_mae: 1.0432 - clf_accuracy: 0.4747 - val_loss: 5.1537 - val_regr_loss: 1.3034 - val_clf_loss: 0.6744 - val_regr_mae: 0.8316 - val_clf_accuracy: 0.5500
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 24/25 [===========================>..] - ETA: 0s - loss: 5.3971 - regr_loss: 1.4104 - clf_loss: 0.7099 - regr_mae: 0.9064 - clf_accuracy: 0.5625
# Epoch 00010: val_loss improved from 5.13570 to 5.10762, saving model to models\lstm1_univar\multitask\10.hdf5
# 25/25 [==============================] - 5s 192ms/step - loss: 5.6265 - regr_loss: 1.5229 - clf_loss: 0.7166 - regr_mae: 0.9281 - clf_accuracy: 0.5556 - val_loss: 5.1076 - val_regr_loss: 1.2866 - val_clf_loss: 0.6750 - val_regr_mae: 0.8200 - val_clf_accuracy: 0.5500
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 24/25 [===========================>..] - ETA: 0s - loss: 5.8382 - regr_loss: 1.6199 - clf_loss: 0.7450 - regr_mae: 0.9601 - clf_accuracy: 0.5521
# Epoch 00011: val_loss improved from 5.10762 to 5.06921, saving model to models\lstm1_univar\multitask\11.hdf5
# 25/25 [==============================] - 4s 180ms/step - loss: 5.7976 - regr_loss: 1.6046 - clf_loss: 0.7350 - regr_mae: 0.9583 - clf_accuracy: 0.5606 - val_loss: 5.0692 - val_regr_loss: 1.2733 - val_clf_loss: 0.6767 - val_regr_mae: 0.8183 - val_clf_accuracy: 0.6000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 24/25 [===========================>..] - ETA: 0s - loss: 6.0946 - regr_loss: 1.7282 - clf_loss: 0.7985 - regr_mae: 1.0116 - clf_accuracy: 0.5260
# Epoch 00012: val_loss improved from 5.06921 to 5.03483, saving model to models\lstm1_univar\multitask\12.hdf5
# 25/25 [==============================] - 5s 184ms/step - loss: 6.1383 - regr_loss: 1.7554 - clf_loss: 0.7886 - regr_mae: 1.0105 - clf_accuracy: 0.5303 - val_loss: 5.0348 - val_regr_loss: 1.2616 - val_clf_loss: 0.6793 - val_regr_mae: 0.8134 - val_clf_accuracy: 0.6000
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 24/25 [===========================>..] - ETA: 0s - loss: 5.4482 - regr_loss: 1.4310 - clf_loss: 0.7598 - regr_mae: 0.9135 - clf_accuracy: 0.5312
# Epoch 00013: val_loss improved from 5.03483 to 5.00209, saving model to models\lstm1_univar\multitask\13.hdf5
# 25/25 [==============================] - 4s 177ms/step - loss: 5.6754 - regr_loss: 1.5457 - clf_loss: 0.7600 - regr_mae: 0.9408 - clf_accuracy: 0.5303 - val_loss: 5.0021 - val_regr_loss: 1.2522 - val_clf_loss: 0.6786 - val_regr_mae: 0.8104 - val_clf_accuracy: 0.6500
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 24/25 [===========================>..] - ETA: 0s - loss: 5.4380 - regr_loss: 1.4140 - clf_loss: 0.7967 - regr_mae: 0.8927 - clf_accuracy: 0.5000
# Epoch 00014: val_loss did not improve from 5.00209
# 25/25 [==============================] - 4s 174ms/step - loss: 5.3375 - regr_loss: 1.3681 - clf_loss: 0.7873 - regr_mae: 0.8772 - clf_accuracy: 0.5051 - val_loss: 5.0074 - val_regr_loss: 1.2617 - val_clf_loss: 0.6775 - val_regr_mae: 0.8229 - val_clf_accuracy: 0.6500
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 24/25 [===========================>..] - ETA: 0s - loss: 5.4901 - regr_loss: 1.4792 - clf_loss: 0.7285 - regr_mae: 0.9228 - clf_accuracy: 0.5208
# Epoch 00015: val_loss improved from 5.00209 to 4.99433, saving model to models\lstm1_univar\multitask\15.hdf5
# 25/25 [==============================] - 6s 220ms/step - loss: 5.6741 - regr_loss: 1.5679 - clf_loss: 0.7369 - regr_mae: 0.9430 - clf_accuracy: 0.5152 - val_loss: 4.9943 - val_regr_loss: 1.2587 - val_clf_loss: 0.6774 - val_regr_mae: 0.8248 - val_clf_accuracy: 0.6500
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 24/25 [===========================>..] - ETA: 0s - loss: 5.3768 - regr_loss: 1.4086 - clf_loss: 0.7632 - regr_mae: 0.8667 - clf_accuracy: 0.5365
# Epoch 00016: val_loss improved from 4.99433 to 4.98737, saving model to models\lstm1_univar\multitask\16.hdf5
# 25/25 [==============================] - 4s 155ms/step - loss: 5.4649 - regr_loss: 1.4545 - clf_loss: 0.7604 - regr_mae: 0.8839 - clf_accuracy: 0.5354 - val_loss: 4.9874 - val_regr_loss: 1.2590 - val_clf_loss: 0.6764 - val_regr_mae: 0.8249 - val_clf_accuracy: 0.6500
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 24/25 [===========================>..] - ETA: 0s - loss: 5.8809 - regr_loss: 1.6999 - clf_loss: 0.6911 - regr_mae: 0.9737 - clf_accuracy: 0.6198
# Epoch 00017: val_loss improved from 4.98737 to 4.96891, saving model to models\lstm1_univar\multitask\17.hdf5
# 25/25 [==============================] - 4s 147ms/step - loss: 5.8231 - regr_loss: 1.6722 - clf_loss: 0.6885 - regr_mae: 0.9727 - clf_accuracy: 0.6212 - val_loss: 4.9689 - val_regr_loss: 1.2536 - val_clf_loss: 0.6754 - val_regr_mae: 0.8252 - val_clf_accuracy: 0.6500
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 24/25 [===========================>..] - ETA: 0s - loss: 5.7897 - regr_loss: 1.6406 - clf_loss: 0.7252 - regr_mae: 0.9470 - clf_accuracy: 0.5260
# Epoch 00018: val_loss improved from 4.96891 to 4.96100, saving model to models\lstm1_univar\multitask\18.hdf5
# 25/25 [==============================] - 4s 152ms/step - loss: 5.7095 - regr_loss: 1.5986 - clf_loss: 0.7285 - regr_mae: 0.9361 - clf_accuracy: 0.5202 - val_loss: 4.9610 - val_regr_loss: 1.2505 - val_clf_loss: 0.6806 - val_regr_mae: 0.8191 - val_clf_accuracy: 0.6500
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 24/25 [===========================>..] - ETA: 0s - loss: 5.5672 - regr_loss: 1.5200 - clf_loss: 0.7510 - regr_mae: 0.9683 - clf_accuracy: 0.5208
# Epoch 00019: val_loss did not improve from 4.96100
# 25/25 [==============================] - 4s 145ms/step - loss: 5.5056 - regr_loss: 1.4920 - clf_loss: 0.7449 - regr_mae: 0.9627 - clf_accuracy: 0.5253 - val_loss: 4.9737 - val_regr_loss: 1.2597 - val_clf_loss: 0.6817 - val_regr_mae: 0.8218 - val_clf_accuracy: 0.6500
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 24/25 [===========================>..] - ETA: 0s - loss: 5.7673 - regr_loss: 1.6180 - clf_loss: 0.7603 - regr_mae: 0.9333 - clf_accuracy: 0.5312
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1.2500000593718141e-05.
#
# Epoch 00020: val_loss did not improve from 4.96100
# 25/25 [==============================] - 4s 147ms/step - loss: 5.7711 - regr_loss: 1.6204 - clf_loss: 0.7594 - regr_mae: 0.9381 - clf_accuracy: 0.5303 - val_loss: 4.9727 - val_regr_loss: 1.2618 - val_clf_loss: 0.6798 - val_regr_mae: 0.8268 - val_clf_accuracy: 0.6500
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 21/32
# 24/25 [===========================>..] - ETA: 0s - loss: 5.3779 - regr_loss: 1.4361 - clf_loss: 0.7367 - regr_mae: 0.9172 - clf_accuracy: 0.5156
# Epoch 00021: val_loss did not improve from 4.96100
# 25/25 [==============================] - 5s 181ms/step - loss: 5.2842 - regr_loss: 1.3950 - clf_loss: 0.7244 - regr_mae: 0.9078 - clf_accuracy: 0.5253 - val_loss: 4.9871 - val_regr_loss: 1.2680 - val_clf_loss: 0.6826 - val_regr_mae: 0.8315 - val_clf_accuracy: 0.6500
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 22/32
# 24/25 [===========================>..] - ETA: 0s - loss: 5.8218 - regr_loss: 1.6666 - clf_loss: 0.7203 - regr_mae: 0.9813 - clf_accuracy: 0.5521
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00022: val_loss did not improve from 4.96100
# 25/25 [==============================] - 5s 192ms/step - loss: 5.8234 - regr_loss: 1.6695 - clf_loss: 0.7162 - regr_mae: 0.9826 - clf_accuracy: 0.5556 - val_loss: 4.9991 - val_regr_loss: 1.2738 - val_clf_loss: 0.6836 - val_regr_mae: 0.8360 - val_clf_accuracy: 0.6500
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 9.999999747378752e-06.
# Epoch 23/32
# 24/25 [===========================>..] - ETA: 0s - loss: 5.5032 - regr_loss: 1.4942 - clf_loss: 0.7473 - regr_mae: 0.9523 - clf_accuracy: 0.5000
# Epoch 00023: val_loss did not improve from 4.96100
# 25/25 [==============================] - 5s 185ms/step - loss: 5.5908 - regr_loss: 1.5340 - clf_loss: 0.7561 - regr_mae: 0.9583 - clf_accuracy: 0.4949 - val_loss: 5.0054 - val_regr_loss: 1.2767 - val_clf_loss: 0.6848 - val_regr_mae: 0.8390 - val_clf_accuracy: 0.6500
# Epoch 00023: early stopping

# %%
def plot_multitask_history(hist):
    fig, ax = plt.subplots(2, 2, figsize=(16, 12))
    plotHelpers.plot_train_history(ax[0, 0], hist, 'Total loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[0, 1], hist, 'Accuracy', 'clf_accuracy', 'val_clf_accuracy')
    plotHelpers.plot_train_history(ax[1, 0], hist, 'MSE', 'regr_loss', 'val_regr_loss')
    plotHelpers.plot_train_history(ax[1, 1], hist, 'MAE', 'regr_mae', 'val_regr_mae')
    
plot_multitask_history(multitask_history);

# %% [markdown]
# ### Прогноз

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_multitask_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret, pred_direction_proba = univariate_multitask_lstm.predict_generator(test_multi_gen, verbose=1)
# Out:
# 2/2 [==============================] - 0s 66ms/step

# %%
np.set_printoptions(precision=3, suppress=True)

np.column_stack([pred_log_ret, pred_direction_proba])[-10:]
# Out:
# array([[ 0.089,  0.555],
#        [-0.195,  0.479],
#        [-0.036,  0.512],
#        [-0.222,  0.476],
#        [ 0.068,  0.546],
#        [-0.153,  0.429],
#        [-0.07 ,  0.518],
#        [-0.104,  0.538],
#        [-0.208,  0.439],
#        [-0.104,  0.553]], dtype=float32)

# %% [markdown]
# #### Прогноз задачи регрессии

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret, figsize=(16, 10), datetime_unit='D')

# %% [markdown]
# #### Прогноз задачи классификации

# %% [markdown]
# *Разделяющая способность, также как и метрики, улучшились по сравнению с однозадачной моделью классификации*.

# %%
true_direction = test_multi_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 0.5098871

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([9, 6], dtype=int64)),
#  (array([0, 1]), array([ 5, 10], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.40      0.22      0.29         9
#            1       0.30      0.50      0.37         6
#
#     accuracy                           0.33        15
#    macro avg       0.35      0.36      0.33        15
# weighted avg       0.36      0.33      0.32        15

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[2, 7],
#        [3, 3]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.4, 0.7],
#        [0.6, 0.3]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# # Выводы
#
# 1.  Размер батча влияет на скорость обучения.
# 2.  Инициализация весов (`bias_initializer`) в слое **LSTM** оказалась очень важным параметром.
# 3.  Модель регрессии близка к модели случайного блуждания.
# 4.  Задача классификации не решается удовлетворительно.
# 5.  Комбинированная (многозадачная) модель не смогла что-то улучшить.

# %% [markdown]
# # *Одномерная модель на LSTM* (2 слоя)
#
# В качестве единственного признака используется сама цена.

# %%
import os
import glob
import datetime
import pickle

import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from pandas_datareader import data as pdr

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
import tensorflow as tf
# tf.test.is_gpu_available()
tf.__version__
# Out:
# '2.0.0'

# %%
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Input, Dense, LSTM, GRU, Flatten, ReLU, LeakyReLU, Dropout, BatchNormalization
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers import Nadam

# %%
from mdp import TimeSeries
from mdp import MarketData
from mdp import MovingWindowFeatures
from mdp import ClassificationGenerator, RegressionGenerator, MultitaskGenerator
from mdp import invert_log_ret

import mdp.utils as utils
import mdp.plotHelpers as plotHelpers

# %%
import importlib

import mdp

importlib.reload(mdp)
importlib.reload(mdp.datasetGenerator)
importlib.reload(mdp.marketData)
importlib.reload(mdp.movingWindowFeatures)
importlib.reload(mdp.timeSeries)
importlib.reload(mdp.plotHelpers)
importlib.reload(mdp.utils);

# %% [markdown]
# # *Параметры*

# %%
INSTRUMENT = 'CVX' # Chevron corp
START_FROM = '2018-11-14'
WINDOW_SIZE = 10
FORECAST_OFFSET=1
BATCH_SIZE = 8
VAL_SPLIT = '2019-11-01'
TEST_SPLIT = '2019-12-01'
FORCE_TRAIN = True

# %% [markdown]
# # *Исходные данные*
#
# Загрузка данных и вычисление индикаторов.

# %%
instr = MarketData.create_from_tiingo(INSTRUMENT, start=START_FROM)

# %%
instr.feature_names
# Out:
# ['o',
#  'h',
#  'l',
#  'c',
#  'v',
#  'ema14',
#  'ema30',
#  'macd',
#  'macd_signal',
#  'rsi14',
#  'bband20_upper',
#  'bband20_middle',
#  'bband20_lower',
#  'willr14',
#  'stochk',
#  'stochd',
#  'adline',
#  'adosc']

# %% [markdown]
# ## Целевая переменная

# %% [markdown]
# Цена закрытия.

# %%
orig_target = instr.c

# %% [markdown]
# Переходим к логарифмической доходности.

# %%
transformed_target = instr.c.transform(transforms={'ratios' : {}, 'ln' : {}})

# %%
plotHelpers.plot_transformed_timeseries_unit(instr,
                                             transformed_target,
                                             'Daily close price, USD', 'Daily log return')

# %% [markdown]
# ## Трансформация признаков
#
# Из признаков выбираем только цену закрытия. Временной ряд цен преобразуется к ряду логарифмических доходностей (что также позволяет убрать нестационарность).

# %%
def make_feature_selector():
    price_transformer = lambda: {'ratios': {}, 'ln': {}}
    diff_transformer = lambda o: {'diffs': {'order': o}}
    identity_transformer = lambda: {}
    feature_transformations = {
        'c': price_transformer(),
    }
    return feature_transformations

# %%
instr_transformed = instr.select_transform(make_feature_selector())

# %%
transformed_target = instr_transformed.c

# %% [markdown]
# ## Обучающая, валидационная и тестовая выборки

# %%
instr_train, instr_val_test = instr_transformed.train_test_split(VAL_SPLIT, window_size=WINDOW_SIZE,
                                                                 scaler=StandardScaler)
#                                                                  scaler=MinMaxScaler,
#                                                                  scaler_kwargs={'feature_range': (-1, 1)})

instr_val, instr_test = instr_val_test.train_test_split(TEST_SPLIT, window_size=WINDOW_SIZE, scaler=None)

len(instr_train), len(instr_val), len(instr_test)
# Out:
# (208, 30, 25)

# %% [markdown]
# ## Признаки - скользящие окна

# %%
train_mwf = MovingWindowFeatures.create(instr_train.c, [instr_train], instr_train.feature_names, window_size=WINDOW_SIZE)
val_mwf = MovingWindowFeatures.create(instr_val.c, [instr_val], instr_val.feature_names, window_size=WINDOW_SIZE)
test_mwf = MovingWindowFeatures.create(instr_test.c, [instr_test], instr_test.feature_names, window_size=WINDOW_SIZE)

len(instr_train), len(train_mwf), train_mwf.features.shape
# Out:
# (208, 198, (198, 10, 1))

# %% [markdown]
# Проверка, что скользящие окна соответствуют исходным данным.
#
# Возьмём произвольный признак и произвольное окно (строка #**41**). Проверим, что данные в точности совпадают:

# %%
def check_data(md, mwf, row):
    col = np.random.randint(len(mwf.feature_names))
    feature = mwf.feature_names[col]
    check = (getattr(md, feature).data[row:row + mwf.window_size] == mwf.features[row, :, col]).all()
    assert check
    return feature, check

check_data(instr_train, train_mwf, 41)
# Out:
# ('c', True)

# %% [markdown]
# # *Модели*

# %% [markdown]
# Модель с двумя LSTM слоями.

# %%
def build_lstm_layers(input_shape, latent_dim=(8, 16)):
    # формат входа: наша матрица (окно; признак)
    inp = Input(input_shape, name='input')

    # стекаем два уровня LSTM
    lstm = LSTM(latent_dim[0], return_sequences=True, 
                    recurrent_dropout=0.2, dropout=0.2, 
                    bias_initializer='he_uniform',
                    bias_regularizer=L1L2(0.01, 0.02),
                    kernel_regularizer=L1L2(0.01, 0.02),
                    recurrent_regularizer=L1L2(0.02, 0.02)
               )(inp)

    lstm = LSTM(latent_dim[1], return_sequences=True,
                    recurrent_dropout=0.2, dropout=0.2,
                    bias_initializer='he_uniform',
                    bias_regularizer=L1L2(0.01, 0.02),
                    kernel_regularizer=L1L2(0.01, 0.02),
                    recurrent_regularizer=L1L2(0.01, 0.02)
               )(lstm)
    
    lstm = Flatten()(lstm)
    
    return inp, lstm

# %% [markdown]
# #### Пути сохранения моделей:

# %%
model_path_root = 'models'
model_type_name = 'lstm2_univar'

def make_model_save_dir(path_root, type_name, class_name):
    save_dir = os.path.join(path_root, type_name, class_name)
    os.makedirs(save_dir, exist_ok=True)
    return save_dir

# %% [markdown]
# #### Общие коллбэки:

# %%
# уменьшение learning rate в случае, если loss не изменяется
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001, verbose=1)

# уменьшение learning rate в 2 раза каждую 5-ю эпоху
def lr_decay(e, lr):
    return lr * (1 - 0.5 * (0 == (e + 1) % 5))

lr_scheduler = LearningRateScheduler(schedule=lr_decay, verbose=1)

# %% [markdown]
# ## Задача регрессии
#
# Непосредственное прогнозирование цены следующего периода.

# %%
train_regr_gen = RegressionGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_regr_gen = RegressionGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_regr_gen = RegressionGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# Следующие числа соответствуют значению параметра `steps_per_epoch` метода [`fit_generator`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit_generator "tf.keras.layers.SimpleRNN &nbsp;|&nbsp; TensorFlow Core r2.0") - то есть это число батчей, которые генератор выдаст за одну эпоху обучения (если класс генератора поддерживает метод `len()`, то данный параметр можно не указывать).

# %%
len(train_regr_gen), len(val_regr_gen), len(test_regr_gen)
# Out:
# (25, 3, 2)

# %% [markdown]
# Один сэмпл данных представляет собой матрицу размером *(длина окна; число признаков)*

# %%
train_regr_gen.input_shape
# Out:
# (10, 1)

# %% [markdown]
# ### Модель для задачи регрессии

# %%
model_class_name = 'regression'

# %%
def build_regression_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=(16, 16))

    regr = Dense(32)(lstm)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    return Model(inputs=[inp], outputs=[regr])

# %%
univariate_regression_lstm = build_regression_model(train_regr_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:
# [`Nadam`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Nadam) (*Adam with Nestrov momentum*).

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Функция потерь:
#
# В качестве функции потерь будем использовать [MSE](https://www.tensorflow.org/api_docs/python/tf/keras/losses/MSE) (чтобы штрафовать за большие отклонения). Xотя хорошая функция потерь в контексте темы данной задачи - это [вопрос сложный](https://github.com/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Chapter5_LossFunctions/Ch5_LossFunctions_PyMC3.ipynb). В частности, здесь нам, очевидно, помимо абсолютного значения отклонения также важен его знак.

# %%
univariate_regression_lstm.compile(optimizer=optimizer,
                                   loss={'regr': 'mse'},
                                   metrics={'regr': 'mae'})

univariate_regression_lstm.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 10, 1)]           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 10, 16)            1152
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 16)            2112
# _________________________________________________________________
# flatten (Flatten)            (None, 160)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                5152
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32)                128
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 32)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# regr (Dense)                 (None, 1)                 33
# =================================================================
# Total params: 8,577
# Trainable params: 8,513
# Non-trainable params: 64
# _________________________________________________________________

# %% [markdown]
# #### Обучение:

# %%
regr_history = utils.train_model(univariate_regression_lstm,
                                 model_save_dir, train_regr_gen, val_regr_gen,
                                 callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                 force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 24/25 [===========================>..] - ETA: 0s - loss: 9.3639 - mae: 1.2267
# Epoch 00001: val_loss improved from inf to 7.87227, saving model to models\lstm2_univar\regression\01.hdf5
# 25/25 [==============================] - 5s 205ms/step - loss: 9.3231 - mae: 1.2254 - val_loss: 7.8723 - val_mae: 0.7860
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 24/25 [===========================>..] - ETA: 0s - loss: 8.2791 - mae: 1.0529
# Epoch 00002: val_loss improved from 7.87227 to 7.30763, saving model to models\lstm2_univar\regression\02.hdf5
# 25/25 [==============================] - 5s 190ms/step - loss: 8.2493 - mae: 1.0482 - val_loss: 7.3076 - val_mae: 0.7898
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.4934 - mae: 0.9920
# Epoch 00003: val_loss improved from 7.30763 to 6.81214, saving model to models\lstm2_univar\regression\03.hdf5
# 25/25 [==============================] - 5s 183ms/step - loss: 7.6283 - mae: 1.0119 - val_loss: 6.8121 - val_mae: 0.7934
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 24/25 [===========================>..] - ETA: 0s - loss: 6.9317 - mae: 0.9527
# Epoch 00004: val_loss improved from 6.81214 to 6.35891, saving model to models\lstm2_univar\regression\04.hdf5
# 25/25 [==============================] - 5s 200ms/step - loss: 6.8962 - mae: 0.9504 - val_loss: 6.3589 - val_mae: 0.7863
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 24/25 [===========================>..] - ETA: 0s - loss: 6.3842 - mae: 0.8781
# Epoch 00005: val_loss improved from 6.35891 to 6.15793, saving model to models\lstm2_univar\regression\05.hdf5
# 25/25 [==============================] - 5s 183ms/step - loss: 6.3846 - mae: 0.8824 - val_loss: 6.1579 - val_mae: 0.7799
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 24/25 [===========================>..] - ETA: 0s - loss: 6.4032 - mae: 0.9194
# Epoch 00006: val_loss improved from 6.15793 to 5.95478, saving model to models\lstm2_univar\regression\06.hdf5
# 25/25 [==============================] - 5s 190ms/step - loss: 6.3815 - mae: 0.9179 - val_loss: 5.9548 - val_mae: 0.7811
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 24/25 [===========================>..] - ETA: 0s - loss: 6.1701 - mae: 0.9405
# Epoch 00007: val_loss improved from 5.95478 to 5.75301, saving model to models\lstm2_univar\regression\07.hdf5
# 25/25 [==============================] - 5s 204ms/step - loss: 6.1279 - mae: 0.9300 - val_loss: 5.7530 - val_mae: 0.7914
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 24/25 [===========================>..] - ETA: 0s - loss: 5.6798 - mae: 0.8466
# Epoch 00008: val_loss improved from 5.75301 to 5.57580, saving model to models\lstm2_univar\regression\08.hdf5
# 25/25 [==============================] - 5s 198ms/step - loss: 5.7230 - mae: 0.8576 - val_loss: 5.5758 - val_mae: 0.7970
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 24/25 [===========================>..] - ETA: 0s - loss: 5.6740 - mae: 0.8833- ETA: 1s - loss: 5.4571 - ma
# Epoch 00009: val_loss improved from 5.57580 to 5.40151, saving model to models\lstm2_univar\regression\09.hdf5
# 25/25 [==============================] - 5s 198ms/step - loss: 5.6243 - mae: 0.8671 - val_loss: 5.4015 - val_mae: 0.7970
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 24/25 [===========================>..] - ETA: 0s - loss: 5.5175 - mae: 0.8935
# Epoch 00010: val_loss improved from 5.40151 to 5.32044, saving model to models\lstm2_univar\regression\10.hdf5
# 25/25 [==============================] - 5s 205ms/step - loss: 5.5048 - mae: 0.8917 - val_loss: 5.3204 - val_mae: 0.8004
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 24/25 [===========================>..] - ETA: 0s - loss: 5.5649 - mae: 0.9482
# Epoch 00011: val_loss improved from 5.32044 to 5.24602, saving model to models\lstm2_univar\regression\11.hdf5
# 25/25 [==============================] - 5s 185ms/step - loss: 5.5346 - mae: 0.9402 - val_loss: 5.2460 - val_mae: 0.8069
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 24/25 [===========================>..] - ETA: 0s - loss: 5.3337 - mae: 0.9007
# Epoch 00012: val_loss improved from 5.24602 to 5.16366, saving model to models\lstm2_univar\regression\12.hdf5
# 25/25 [==============================] - 5s 184ms/step - loss: 5.3262 - mae: 0.9027 - val_loss: 5.1637 - val_mae: 0.8021
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 24/25 [===========================>..] - ETA: 0s - loss: 5.3537 - mae: 0.8770
# Epoch 00013: val_loss improved from 5.16366 to 5.08856, saving model to models\lstm2_univar\regression\13.hdf5
# 25/25 [==============================] - 5s 190ms/step - loss: 5.4386 - mae: 0.8993 - val_loss: 5.0886 - val_mae: 0.8060
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.9585 - mae: 0.8088
# Epoch 00014: val_loss improved from 5.08856 to 5.00863, saving model to models\lstm2_univar\regression\14.hdf5
# 25/25 [==============================] - 5s 191ms/step - loss: 5.0437 - mae: 0.8260 - val_loss: 5.0086 - val_mae: 0.8031
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 24/25 [===========================>..] - ETA: 0s - loss: 5.0697 - mae: 0.8652
# Epoch 00015: val_loss improved from 5.00863 to 4.96865, saving model to models\lstm2_univar\regression\15.hdf5
# 25/25 [==============================] - 5s 211ms/step - loss: 5.0366 - mae: 0.8559 - val_loss: 4.9686 - val_mae: 0.8024
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 24/25 [===========================>..] - ETA: 0s - loss: 5.1557 - mae: 0.8887
# Epoch 00016: val_loss improved from 4.96865 to 4.93078, saving model to models\lstm2_univar\regression\16.hdf5
# 25/25 [==============================] - 5s 190ms/step - loss: 5.1679 - mae: 0.8930 - val_loss: 4.9308 - val_mae: 0.8065
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.9711 - mae: 0.8494
# Epoch 00017: val_loss improved from 4.93078 to 4.89553, saving model to models\lstm2_univar\regression\17.hdf5
# 25/25 [==============================] - 5s 189ms/step - loss: 4.9644 - mae: 0.8514 - val_loss: 4.8955 - val_mae: 0.8067
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 24/25 [===========================>..] - ETA: 0s - loss: 5.0285 - mae: 0.8862- ETA: 2s - loss: 4.878
# Epoch 00018: val_loss improved from 4.89553 to 4.86090, saving model to models\lstm2_univar\regression\18.hdf5
# 25/25 [==============================] - 5s 191ms/step - loss: 4.9824 - mae: 0.8723 - val_loss: 4.8609 - val_mae: 0.8053
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.8448 - mae: 0.8007
# Epoch 00019: val_loss improved from 4.86090 to 4.83552, saving model to models\lstm2_univar\regression\19.hdf5
# 25/25 [==============================] - 5s 215ms/step - loss: 4.8074 - mae: 0.7905 - val_loss: 4.8355 - val_mae: 0.8120
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.8329 - mae: 0.8384
# Epoch 00020: val_loss improved from 4.83552 to 4.81627, saving model to models\lstm2_univar\regression\20.hdf5
# 25/25 [==============================] - 5s 201ms/step - loss: 4.8935 - mae: 0.8567 - val_loss: 4.8163 - val_mae: 0.8082
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.8023 - mae: 0.8350
# Epoch 00021: val_loss improved from 4.81627 to 4.79686, saving model to models\lstm2_univar\regression\21.hdf5
# 25/25 [==============================] - 5s 196ms/step - loss: 4.7870 - mae: 0.8298 - val_loss: 4.7969 - val_mae: 0.8053
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.7820 - mae: 0.8318- ETA: 4s - loss:
# Epoch 00022: val_loss improved from 4.79686 to 4.78312, saving model to models\lstm2_univar\regression\22.hdf5
# 25/25 [==============================] - 5s 196ms/step - loss: 4.7776 - mae: 0.8307 - val_loss: 4.7831 - val_mae: 0.8061
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.7951 - mae: 0.8379
# Epoch 00023: val_loss improved from 4.78312 to 4.76452, saving model to models\lstm2_univar\regression\23.hdf5
# 25/25 [==============================] - 5s 203ms/step - loss: 4.8079 - mae: 0.8404 - val_loss: 4.7645 - val_mae: 0.8066
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.9083 - mae: 0.9076
# Epoch 00024: val_loss improved from 4.76452 to 4.74876, saving model to models\lstm2_univar\regression\24.hdf5
# 25/25 [==============================] - 5s 202ms/step - loss: 4.8720 - mae: 0.8969 - val_loss: 4.7488 - val_mae: 0.8077
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.7399 - mae: 0.8388
# Epoch 00025: val_loss improved from 4.74876 to 4.74355, saving model to models\lstm2_univar\regression\25.hdf5
# 25/25 [==============================] - 5s 198ms/step - loss: 4.7440 - mae: 0.8432 - val_loss: 4.7436 - val_mae: 0.8118
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.6688 - mae: 0.7895
# Epoch 00026: val_loss improved from 4.74355 to 4.73648, saving model to models\lstm2_univar\regression\26.hdf5
# 25/25 [==============================] - 5s 200ms/step - loss: 4.6886 - mae: 0.7986 - val_loss: 4.7365 - val_mae: 0.8096
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.6760 - mae: 0.8216
# Epoch 00027: val_loss improved from 4.73648 to 4.72723, saving model to models\lstm2_univar\regression\27.hdf5
# 25/25 [==============================] - 5s 192ms/step - loss: 4.6636 - mae: 0.8210 - val_loss: 4.7272 - val_mae: 0.8075
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.7495 - mae: 0.8292
# Epoch 00028: val_loss improved from 4.72723 to 4.71974, saving model to models\lstm2_univar\regression\28.hdf5
# 25/25 [==============================] - 5s 188ms/step - loss: 4.7991 - mae: 0.8403 - val_loss: 4.7197 - val_mae: 0.8079
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.7245 - mae: 0.8346
# Epoch 00029: val_loss improved from 4.71974 to 4.71366, saving model to models\lstm2_univar\regression\29.hdf5
# 25/25 [==============================] - 5s 189ms/step - loss: 4.7857 - mae: 0.8429 - val_loss: 4.7137 - val_mae: 0.8109
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.5683 - mae: 0.7888
# Epoch 00030: val_loss improved from 4.71366 to 4.71061, saving model to models\lstm2_univar\regression\30.hdf5
# 25/25 [==============================] - 5s 184ms/step - loss: 4.6003 - mae: 0.7999 - val_loss: 4.7106 - val_mae: 0.8157
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.7181 - mae: 0.8195
# Epoch 00031: val_loss improved from 4.71061 to 4.70702, saving model to models\lstm2_univar\regression\31.hdf5
# 25/25 [==============================] - 5s 186ms/step - loss: 4.6928 - mae: 0.8151 - val_loss: 4.7070 - val_mae: 0.8154
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.7806 - mae: 0.8583
# Epoch 00032: val_loss improved from 4.70702 to 4.69865, saving model to models\lstm2_univar\regression\32.hdf5
# 25/25 [==============================] - 5s 184ms/step - loss: 4.7425 - mae: 0.8461 - val_loss: 4.6986 - val_mae: 0.8136

# %%
def plot_regr_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'MSE', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'MAE', 'mae', 'val_mae')
    
plot_regr_history(regr_history);

# %% [markdown]
# ### Прогноз задачи регрессии

# %% [markdown]
# *Судя по всему, просто выходит на модель случайного блуждания*.

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_regression_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret_test = univariate_regression_lstm.predict_generator(test_regr_gen, verbose=1)
# Out:
# 2/2 [==============================] - 0s 79ms/step

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret_test, figsize=(16, 10), datetime_unit='D')

# %% [markdown]
# ## Задача классификации
#
# Прогнозируем направление изменения цены по сравнению с предыдущим периодом (**0** - снижение, **1** - рост).

# %%
model_class_name = 'classification'

# %%
train_clf_gen = ClassificationGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_clf_gen = ClassificationGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_clf_gen = ClassificationGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_classification_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=(16, 16))

    clf = Dense(32)(lstm)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)

    return Model(inputs=[inp], outputs=[clf])

# %%
univariate_classification_lstm = build_classification_model(test_clf_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
univariate_classification_lstm.compile(optimizer=optimizer,
                                       loss={'clf': 'binary_crossentropy'},
                                       metrics={'clf': 'accuracy'})

univariate_classification_lstm.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 10, 1)]           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 10, 16)            1152
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 10, 16)            2112
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 160)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                5152
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32)                128
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 32)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# clf (Dense)                  (None, 1)                 33
# =================================================================
# Total params: 8,577
# Trainable params: 8,513
# Non-trainable params: 64
# _________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
clf_history = utils.train_model(univariate_classification_lstm,
                                model_save_dir, train_clf_gen, val_clf_gen,
                                callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.3958 - accuracy: 0.5052 ETA: 3s
# Epoch 00001: val_loss improved from inf to 6.77681, saving model to models\lstm2_univar\classification\01.hdf5
# 25/25 [==============================] - 5s 190ms/step - loss: 7.3692 - accuracy: 0.5101 - val_loss: 6.7768 - val_accuracy: 0.5500
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 24/25 [===========================>..] - ETA: 0s - loss: 6.4212 - accuracy: 0.4792
# Epoch 00002: val_loss improved from 6.77681 to 5.82265, saving model to models\lstm2_univar\classification\02.hdf5
# 25/25 [==============================] - 5s 190ms/step - loss: 6.4071 - accuracy: 0.4848 - val_loss: 5.8226 - val_accuracy: 0.6500
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 24/25 [===========================>..] - ETA: 0s - loss: 5.5247 - accuracy: 0.4583 ETA: 1s - loss: 5.671
# Epoch 00003: val_loss improved from 5.82265 to 5.00138, saving model to models\lstm2_univar\classification\03.hdf5
# 25/25 [==============================] - 5s 204ms/step - loss: 5.5009 - accuracy: 0.4697 - val_loss: 5.0014 - val_accuracy: 0.4500
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.7195 - accuracy: 0.4844
# Epoch 00004: val_loss improved from 5.00138 to 4.32234, saving model to models\lstm2_univar\classification\04.hdf5
# 25/25 [==============================] - 5s 205ms/step - loss: 4.7101 - accuracy: 0.4747 - val_loss: 4.3223 - val_accuracy: 0.4500
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.2456 - accuracy: 0.4375
# Epoch 00005: val_loss improved from 4.32234 to 4.02260, saving model to models\lstm2_univar\classification\05.hdf5
# 25/25 [==============================] - 5s 197ms/step - loss: 4.2409 - accuracy: 0.4293 - val_loss: 4.0226 - val_accuracy: 0.4500
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.8883 - accuracy: 0.5573
# Epoch 00006: val_loss improved from 4.02260 to 3.75189, saving model to models\lstm2_univar\classification\06.hdf5
# 25/25 [==============================] - 5s 203ms/step - loss: 3.8829 - accuracy: 0.5556 - val_loss: 3.7519 - val_accuracy: 0.4500
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.6672 - accuracy: 0.5521
# Epoch 00007: val_loss improved from 3.75189 to 3.50116, saving model to models\lstm2_univar\classification\07.hdf5
# 25/25 [==============================] - 5s 192ms/step - loss: 3.6628 - accuracy: 0.5505 - val_loss: 3.5012 - val_accuracy: 0.4500
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.4407 - accuracy: 0.4792
# Epoch 00008: val_loss improved from 3.50116 to 3.27876, saving model to models\lstm2_univar\classification\08.hdf5
# 25/25 [==============================] - 5s 198ms/step - loss: 3.4382 - accuracy: 0.4747 - val_loss: 3.2788 - val_accuracy: 0.4500
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.1773 - accuracy: 0.5573
# Epoch 00009: val_loss improved from 3.27876 to 3.08159, saving model to models\lstm2_univar\classification\09.hdf5
# 25/25 [==============================] - 5s 211ms/step - loss: 3.1744 - accuracy: 0.5606 - val_loss: 3.0816 - val_accuracy: 0.4500
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.0254 - accuracy: 0.5312
# Epoch 00010: val_loss improved from 3.08159 to 2.98898, saving model to models\lstm2_univar\classification\10.hdf5
# 25/25 [==============================] - 5s 195ms/step - loss: 3.0215 - accuracy: 0.5354 - val_loss: 2.9890 - val_accuracy: 0.4500
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.9821 - accuracy: 0.4635
# Epoch 00011: val_loss improved from 2.98898 to 2.89850, saving model to models\lstm2_univar\classification\11.hdf5
# 25/25 [==============================] - 5s 200ms/step - loss: 2.9789 - accuracy: 0.4646 - val_loss: 2.8985 - val_accuracy: 0.4500
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.8461 - accuracy: 0.5417 ETA: 1s - loss: 2.8561 - accura
# Epoch 00012: val_loss improved from 2.89850 to 2.81842, saving model to models\lstm2_univar\classification\12.hdf5
# 25/25 [==============================] - 5s 207ms/step - loss: 2.8461 - accuracy: 0.5404 - val_loss: 2.8184 - val_accuracy: 0.4500
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.7981 - accuracy: 0.4844
# Epoch 00013: val_loss improved from 2.81842 to 2.72926, saving model to models\lstm2_univar\classification\13.hdf5
# 25/25 [==============================] - 5s 205ms/step - loss: 2.7967 - accuracy: 0.4848 - val_loss: 2.7293 - val_accuracy: 0.4500
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.7166 - accuracy: 0.4427
# Epoch 00014: val_loss improved from 2.72926 to 2.64473, saving model to models\lstm2_univar\classification\14.hdf5
# 25/25 [==============================] - 5s 196ms/step - loss: 2.7117 - accuracy: 0.4495 - val_loss: 2.6447 - val_accuracy: 0.4500
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.6336 - accuracy: 0.4896
# Epoch 00015: val_loss improved from 2.64473 to 2.60395, saving model to models\lstm2_univar\classification\15.hdf5
# 25/25 [==============================] - 5s 202ms/step - loss: 2.6338 - accuracy: 0.4899 - val_loss: 2.6040 - val_accuracy: 0.4500
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.6015 - accuracy: 0.5260
# Epoch 00016: val_loss improved from 2.60395 to 2.56535, saving model to models\lstm2_univar\classification\16.hdf5
# 25/25 [==============================] - 5s 195ms/step - loss: 2.5986 - accuracy: 0.5303 - val_loss: 2.5654 - val_accuracy: 0.4500
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.5711 - accuracy: 0.4792
# Epoch 00017: val_loss improved from 2.56535 to 2.52815, saving model to models\lstm2_univar\classification\17.hdf5
# 25/25 [==============================] - 5s 197ms/step - loss: 2.5658 - accuracy: 0.4798 - val_loss: 2.5281 - val_accuracy: 0.4500
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.5093 - accuracy: 0.5417
# Epoch 00018: val_loss improved from 2.52815 to 2.48596, saving model to models\lstm2_univar\classification\18.hdf5
# 25/25 [==============================] - 5s 201ms/step - loss: 2.5068 - accuracy: 0.5404 - val_loss: 2.4860 - val_accuracy: 0.5000
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.4963 - accuracy: 0.4844
# Epoch 00019: val_loss improved from 2.48596 to 2.44974, saving model to models\lstm2_univar\classification\19.hdf5
# 25/25 [==============================] - 5s 196ms/step - loss: 2.4963 - accuracy: 0.4798 - val_loss: 2.4497 - val_accuracy: 0.5500
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.4824 - accuracy: 0.4896
# Epoch 00020: val_loss improved from 2.44974 to 2.43433, saving model to models\lstm2_univar\classification\20.hdf5
# 25/25 [==============================] - 5s 203ms/step - loss: 2.4837 - accuracy: 0.4899 - val_loss: 2.4343 - val_accuracy: 0.5500
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.4374 - accuracy: 0.5417
# Epoch 00021: val_loss improved from 2.43433 to 2.41986, saving model to models\lstm2_univar\classification\21.hdf5
# 25/25 [==============================] - 5s 216ms/step - loss: 2.4338 - accuracy: 0.5455 - val_loss: 2.4199 - val_accuracy: 0.5000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.4780 - accuracy: 0.4792
# Epoch 00022: val_loss improved from 2.41986 to 2.39991, saving model to models\lstm2_univar\classification\22.hdf5
# 25/25 [==============================] - 5s 208ms/step - loss: 2.4722 - accuracy: 0.4848 - val_loss: 2.3999 - val_accuracy: 0.5500
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.4375 - accuracy: 0.5052
# Epoch 00023: val_loss improved from 2.39991 to 2.38405, saving model to models\lstm2_univar\classification\23.hdf5
# 25/25 [==============================] - 5s 200ms/step - loss: 2.4371 - accuracy: 0.5000 - val_loss: 2.3841 - val_accuracy: 0.5500
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.3790 - accuracy: 0.5000
# Epoch 00024: val_loss improved from 2.38405 to 2.37045, saving model to models\lstm2_univar\classification\24.hdf5
# 25/25 [==============================] - 5s 200ms/step - loss: 2.3752 - accuracy: 0.5101 - val_loss: 2.3704 - val_accuracy: 0.4500
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.3802 - accuracy: 0.5365
# Epoch 00025: val_loss improved from 2.37045 to 2.36273, saving model to models\lstm2_univar\classification\25.hdf5
# 25/25 [==============================] - 5s 199ms/step - loss: 2.3773 - accuracy: 0.5354 - val_loss: 2.3627 - val_accuracy: 0.4500
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.3784 - accuracy: 0.5104
# Epoch 00026: val_loss improved from 2.36273 to 2.35453, saving model to models\lstm2_univar\classification\26.hdf5
# 25/25 [==============================] - 5s 205ms/step - loss: 2.3740 - accuracy: 0.5152 - val_loss: 2.3545 - val_accuracy: 0.4000
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.3750 - accuracy: 0.4844
# Epoch 00027: val_loss improved from 2.35453 to 2.34257, saving model to models\lstm2_univar\classification\27.hdf5
# 25/25 [==============================] - 5s 198ms/step - loss: 2.3757 - accuracy: 0.4848 - val_loss: 2.3426 - val_accuracy: 0.5000
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.3563 - accuracy: 0.5625 ETA:
# Epoch 00028: val_loss improved from 2.34257 to 2.33744, saving model to models\lstm2_univar\classification\28.hdf5
# 25/25 [==============================] - 5s 194ms/step - loss: 2.3561 - accuracy: 0.5556 - val_loss: 2.3374 - val_accuracy: 0.4500
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.3295 - accuracy: 0.5677
# Epoch 00029: val_loss improved from 2.33744 to 2.33015, saving model to models\lstm2_univar\classification\29.hdf5
# 25/25 [==============================] - 5s 213ms/step - loss: 2.3352 - accuracy: 0.5505 - val_loss: 2.3301 - val_accuracy: 0.4000
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.3353 - accuracy: 0.5573
# Epoch 00030: val_loss improved from 2.33015 to 2.32616, saving model to models\lstm2_univar\classification\30.hdf5
# 25/25 [==============================] - 5s 210ms/step - loss: 2.3348 - accuracy: 0.5556 - val_loss: 2.3262 - val_accuracy: 0.4000
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.3409 - accuracy: 0.5156
# Epoch 00031: val_loss improved from 2.32616 to 2.32041, saving model to models\lstm2_univar\classification\31.hdf5
# 25/25 [==============================] - 5s 208ms/step - loss: 2.3394 - accuracy: 0.5152 - val_loss: 2.3204 - val_accuracy: 0.4500
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.3295 - accuracy: 0.5000
# Epoch 00032: val_loss improved from 2.32041 to 2.31334, saving model to models\lstm2_univar\classification\32.hdf5
# 25/25 [==============================] - 5s 209ms/step - loss: 2.3275 - accuracy: 0.5051 - val_loss: 2.3133 - val_accuracy: 0.5000

# %%
def plot_clf_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'Loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'Accuracy', 'accuracy', 'val_accuracy')
    
plot_clf_history(clf_history);

# %% [markdown]
# ### Прогноз задачи классификации

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_classification_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %%
pred_direction_proba = univariate_classification_lstm.predict_generator(test_clf_gen, verbose=1)

true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 2/2 [==============================] - 0s 81ms/step
# 0.5138946

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([9, 6], dtype=int64)),
#  (array([0, 1]), array([10,  5], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.67      0.63         9
#            1       0.40      0.33      0.36         6
#
#     accuracy                           0.53        15
#    macro avg       0.50      0.50      0.50        15
# weighted avg       0.52      0.53      0.52        15

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[6, 3],
#        [4, 2]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.6, 0.6],
#        [0.4, 0.4]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# ## Многозадачная модель: одновременно регрессия и классификация

# %%
model_class_name = 'multitask'

# %%
train_multi_gen = MultitaskGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_multi_gen = MultitaskGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_multi_gen = MultitaskGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_multitask_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=(16, 16))

    # первый выход: задача регрссии
    regr = Dense(32)(lstm)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    # второй выход: задача классификации
    clf = Dense(32)(lstm)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)
    
    return Model(inputs=[inp], outputs=[regr, clf])

# %%
univariate_multitask_lstm = build_multitask_model(train_multi_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
univariate_multitask_lstm.compile(optimizer=optimizer,
                                  loss={'regr': 'mse', 'clf': 'binary_crossentropy'},
                                  loss_weights={'regr': 2., 'clf': 1.},
                                  metrics={'regr': 'mae', 'clf' : 'accuracy'})

univariate_multitask_lstm.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 10, 1)]      0
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 10, 16)       1152        input[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 10, 16)       2112        lstm_4[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 160)          0           lstm_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 32)           5152        flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 32)           5152        flatten_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32)           128         dense_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32)           128         dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 32)           0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 32)           0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32)           0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 32)           0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# regr (Dense)                    (None, 1)            33          dropout_2[0][0]
# __________________________________________________________________________________________________
# clf (Dense)                     (None, 1)            33          dropout_3[0][0]
# ==================================================================================================
# Total params: 13,890
# Trainable params: 13,762
# Non-trainable params: 128
# __________________________________________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
multitask_history = utils.train_model(univariate_multitask_lstm,
                                      model_save_dir, train_multi_gen, val_multi_gen,
                                      callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                      force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 24/25 [===========================>..] - ETA: 0s - loss: 11.8615 - regr_loss: 2.0344 - clf_loss: 0.8827 - regr_mae: 1.1650 - clf_accuracy: 0.4740- ETA: 1s - loss: 11.6714 - regr_loss: 1.9251 - clf_loss: 0.8783 - regr_mae: 1.1381 - clf_accuracy: 0.
# Epoch 00001: val_loss improved from inf to 9.90257, saving model to models\lstm2_univar\multitask\01.hdf5
# 25/25 [==============================] - 6s 235ms/step - loss: 11.7199 - regr_loss: 1.9699 - clf_loss: 0.8770 - regr_mae: 1.1442 - clf_accuracy: 0.4798 - val_loss: 9.9026 - val_regr_loss: 1.2667 - val_clf_loss: 0.6823 - val_regr_mae: 0.8539 - val_clf_accuracy: 0.5500
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 24/25 [===========================>..] - ETA: 0s - loss: 10.4988 - regr_loss: 1.6049 - clf_loss: 0.7937 - regr_mae: 0.9647 - clf_accuracy: 0.5156
# Epoch 00002: val_loss improved from 9.90257 to 9.47598, saving model to models\lstm2_univar\multitask\02.hdf5
# 25/25 [==============================] - 6s 243ms/step - loss: 10.4612 - regr_loss: 1.5897 - clf_loss: 0.7944 - regr_mae: 0.9613 - clf_accuracy: 0.5152 - val_loss: 9.4760 - val_regr_loss: 1.2577 - val_clf_loss: 0.6893 - val_regr_mae: 0.8457 - val_clf_accuracy: 0.5500
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 24/25 [===========================>..] - ETA: 0s - loss: 10.3858 - regr_loss: 1.7506 - clf_loss: 0.7977 - regr_mae: 1.0384 - clf_accuracy: 0.5521
# Epoch 00003: val_loss improved from 9.47598 to 9.09869, saving model to models\lstm2_univar\multitask\03.hdf5
# 25/25 [==============================] - 6s 230ms/step - loss: 10.2961 - regr_loss: 1.7060 - clf_loss: 0.8041 - regr_mae: 1.0250 - clf_accuracy: 0.5455 - val_loss: 9.0987 - val_regr_loss: 1.2549 - val_clf_loss: 0.7109 - val_regr_mae: 0.8425 - val_clf_accuracy: 0.4500
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 24/25 [===========================>..] - ETA: 0s - loss: 9.5665 - regr_loss: 1.5324 - clf_loss: 0.7952 - regr_mae: 0.8984 - clf_accuracy: 0.4167
# Epoch 00004: val_loss improved from 9.09869 to 8.65989, saving model to models\lstm2_univar\multitask\04.hdf5
# 25/25 [==============================] - 6s 228ms/step - loss: 9.5476 - regr_loss: 1.5289 - clf_loss: 0.7903 - regr_mae: 0.9016 - clf_accuracy: 0.4192 - val_loss: 8.6599 - val_regr_loss: 1.2197 - val_clf_loss: 0.7101 - val_regr_mae: 0.8043 - val_clf_accuracy: 0.4500
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 24/25 [===========================>..] - ETA: 0s - loss: 9.4575 - regr_loss: 1.6350 - clf_loss: 0.7586 - regr_mae: 1.0023 - clf_accuracy: 0.5156
# Epoch 00005: val_loss improved from 8.65989 to 8.49756, saving model to models\lstm2_univar\multitask\05.hdf5
# 25/25 [==============================] - 6s 225ms/step - loss: 9.3766 - regr_loss: 1.5915 - clf_loss: 0.7674 - regr_mae: 0.9909 - clf_accuracy: 0.5051 - val_loss: 8.4976 - val_regr_loss: 1.2250 - val_clf_loss: 0.7114 - val_regr_mae: 0.8114 - val_clf_accuracy: 0.4500
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 24/25 [===========================>..] - ETA: 0s - loss: 8.8636 - regr_loss: 1.4223 - clf_loss: 0.7602 - regr_mae: 0.9135 - clf_accuracy: 0.4635
# Epoch 00006: val_loss improved from 8.49756 to 8.33366, saving model to models\lstm2_univar\multitask\06.hdf5
# 25/25 [==============================] - 6s 228ms/step - loss: 8.9108 - regr_loss: 1.4472 - clf_loss: 0.7612 - regr_mae: 0.9130 - clf_accuracy: 0.4697 - val_loss: 8.3337 - val_regr_loss: 1.2258 - val_clf_loss: 0.7104 - val_regr_mae: 0.8105 - val_clf_accuracy: 0.4500
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 24/25 [===========================>..] - ETA: 0s - loss: 8.9741 - regr_loss: 1.5706 - clf_loss: 0.7348 - regr_mae: 0.9249 - clf_accuracy: 0.4792
# Epoch 00007: val_loss improved from 8.33366 to 8.18936, saving model to models\lstm2_univar\multitask\07.hdf5
# 25/25 [==============================] - 6s 227ms/step - loss: 8.9174 - regr_loss: 1.5465 - clf_loss: 0.7288 - regr_mae: 0.9242 - clf_accuracy: 0.4848 - val_loss: 8.1894 - val_regr_loss: 1.2287 - val_clf_loss: 0.7185 - val_regr_mae: 0.8125 - val_clf_accuracy: 0.4500
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 24/25 [===========================>..] - ETA: 0s - loss: 8.3220 - regr_loss: 1.3168 - clf_loss: 0.7449 - regr_mae: 0.8534 - clf_accuracy: 0.4896
# Epoch 00008: val_loss improved from 8.18936 to 8.11107, saving model to models\lstm2_univar\multitask\08.hdf5
# 25/25 [==============================] - 6s 230ms/step - loss: 8.3034 - regr_loss: 1.3119 - clf_loss: 0.7388 - regr_mae: 0.8554 - clf_accuracy: 0.4949 - val_loss: 8.1111 - val_regr_loss: 1.2564 - val_clf_loss: 0.7355 - val_regr_mae: 0.8425 - val_clf_accuracy: 0.4500
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 24/25 [===========================>..] - ETA: 0s - loss: 8.2500 - regr_loss: 1.3193 - clf_loss: 0.8176 - regr_mae: 0.8540 - clf_accuracy: 0.4688
# Epoch 00009: val_loss improved from 8.11107 to 7.86384, saving model to models\lstm2_univar\multitask\09.hdf5
# 25/25 [==============================] - 6s 235ms/step - loss: 8.3059 - regr_loss: 1.3458 - clf_loss: 0.8241 - regr_mae: 0.8666 - clf_accuracy: 0.4596 - val_loss: 7.8638 - val_regr_loss: 1.2179 - val_clf_loss: 0.7136 - val_regr_mae: 0.7971 - val_clf_accuracy: 0.4500
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 24/25 [===========================>..] - ETA: 0s - loss: 8.2085 - regr_loss: 1.3951 - clf_loss: 0.7377 - regr_mae: 0.8749 - clf_accuracy: 0.5052
# Epoch 00010: val_loss improved from 7.86384 to 7.79076, saving model to models\lstm2_univar\multitask\10.hdf5
# 25/25 [==============================] - 6s 234ms/step - loss: 8.3123 - regr_loss: 1.4496 - clf_loss: 0.7349 - regr_mae: 0.8864 - clf_accuracy: 0.5101 - val_loss: 7.7908 - val_regr_loss: 1.2175 - val_clf_loss: 0.7138 - val_regr_mae: 0.7950 - val_clf_accuracy: 0.4500
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.7852 - regr_loss: 1.2058 - clf_loss: 0.7646 - regr_mae: 0.8305 - clf_accuracy: 0.4740
# Epoch 00011: val_loss improved from 7.79076 to 7.71283, saving model to models\lstm2_univar\multitask\11.hdf5
# 25/25 [==============================] - 6s 232ms/step - loss: 7.7179 - regr_loss: 1.1726 - clf_loss: 0.7646 - regr_mae: 0.8224 - clf_accuracy: 0.4747 - val_loss: 7.7128 - val_regr_loss: 1.2148 - val_clf_loss: 0.7129 - val_regr_mae: 0.7938 - val_clf_accuracy: 0.4500
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.4920 - regr_loss: 1.1126 - clf_loss: 0.7285 - regr_mae: 0.8016 - clf_accuracy: 0.5573
# Epoch 00012: val_loss improved from 7.71283 to 7.67648, saving model to models\lstm2_univar\multitask\12.hdf5
# 25/25 [==============================] - 6s 229ms/step - loss: 7.6331 - regr_loss: 1.1883 - clf_loss: 0.7209 - regr_mae: 0.8223 - clf_accuracy: 0.5657 - val_loss: 7.6765 - val_regr_loss: 1.2254 - val_clf_loss: 0.7249 - val_regr_mae: 0.8158 - val_clf_accuracy: 0.4500
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.7940 - regr_loss: 1.2757 - clf_loss: 0.7740 - regr_mae: 0.8449 - clf_accuracy: 0.5156
# Epoch 00013: val_loss improved from 7.67648 to 7.64535, saving model to models\lstm2_univar\multitask\13.hdf5
# 25/25 [==============================] - 6s 224ms/step - loss: 7.7335 - regr_loss: 1.2482 - clf_loss: 0.7695 - regr_mae: 0.8410 - clf_accuracy: 0.5152 - val_loss: 7.6454 - val_regr_loss: 1.2385 - val_clf_loss: 0.7373 - val_regr_mae: 0.8270 - val_clf_accuracy: 0.4500
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.8216 - regr_loss: 1.3334 - clf_loss: 0.7555 - regr_mae: 0.8600 - clf_accuracy: 0.4844
# Epoch 00014: val_loss improved from 7.64535 to 7.50604, saving model to models\lstm2_univar\multitask\14.hdf5
# 25/25 [==============================] - 6s 230ms/step - loss: 7.7441 - regr_loss: 1.2965 - clf_loss: 0.7523 - regr_mae: 0.8487 - clf_accuracy: 0.4848 - val_loss: 7.5060 - val_regr_loss: 1.2148 - val_clf_loss: 0.7140 - val_regr_mae: 0.7995 - val_clf_accuracy: 0.4500
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.5478 - regr_loss: 1.2418 - clf_loss: 0.7176 - regr_mae: 0.8228 - clf_accuracy: 0.5365
# Epoch 00015: val_loss improved from 7.50604 to 7.47404, saving model to models\lstm2_univar\multitask\15.hdf5
# 25/25 [==============================] - 6s 229ms/step - loss: 7.4867 - regr_loss: 1.2156 - clf_loss: 0.7090 - regr_mae: 0.8198 - clf_accuracy: 0.5455 - val_loss: 7.4740 - val_regr_loss: 1.2159 - val_clf_loss: 0.7138 - val_regr_mae: 0.7947 - val_clf_accuracy: 0.4500
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.6048 - regr_loss: 1.2580 - clf_loss: 0.7758 - regr_mae: 0.8428 - clf_accuracy: 0.4740
# Epoch 00016: val_loss improved from 7.47404 to 7.44566, saving model to models\lstm2_univar\multitask\16.hdf5
# 25/25 [==============================] - 6s 228ms/step - loss: 7.5462 - regr_loss: 1.2269 - clf_loss: 0.7796 - regr_mae: 0.8350 - clf_accuracy: 0.4697 - val_loss: 7.4457 - val_regr_loss: 1.2154 - val_clf_loss: 0.7200 - val_regr_mae: 0.7932 - val_clf_accuracy: 0.4500
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.4891 - regr_loss: 1.2455 - clf_loss: 0.7183 - regr_mae: 0.8340 - clf_accuracy: 0.5469
# Epoch 00017: val_loss improved from 7.44566 to 7.42041, saving model to models\lstm2_univar\multitask\17.hdf5
# 25/25 [==============================] - 6s 225ms/step - loss: 7.5061 - regr_loss: 1.2554 - clf_loss: 0.7165 - regr_mae: 0.8354 - clf_accuracy: 0.5505 - val_loss: 7.4204 - val_regr_loss: 1.2153 - val_clf_loss: 0.7281 - val_regr_mae: 0.7965 - val_clf_accuracy: 0.4500
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.4694 - regr_loss: 1.2378 - clf_loss: 0.7473 - regr_mae: 0.8772 - clf_accuracy: 0.4896
# Epoch 00018: val_loss improved from 7.42041 to 7.39116, saving model to models\lstm2_univar\multitask\18.hdf5
# 25/25 [==============================] - 6s 229ms/step - loss: 7.6088 - regr_loss: 1.3103 - clf_loss: 0.7437 - regr_mae: 0.8882 - clf_accuracy: 0.4949 - val_loss: 7.3912 - val_regr_loss: 1.2137 - val_clf_loss: 0.7346 - val_regr_mae: 0.7873 - val_clf_accuracy: 0.4500
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.4644 - regr_loss: 1.2576 - clf_loss: 0.7353 - regr_mae: 0.8446 - clf_accuracy: 0.5000
# Epoch 00019: val_loss improved from 7.39116 to 7.37498, saving model to models\lstm2_univar\multitask\19.hdf5
# 25/25 [==============================] - 6s 235ms/step - loss: 7.4092 - regr_loss: 1.2310 - clf_loss: 0.7335 - regr_mae: 0.8360 - clf_accuracy: 0.5000 - val_loss: 7.3750 - val_regr_loss: 1.2214 - val_clf_loss: 0.7360 - val_regr_mae: 0.7945 - val_clf_accuracy: 0.4500
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.4321 - regr_loss: 1.2618 - clf_loss: 0.7202 - regr_mae: 0.8592 - clf_accuracy: 0.4792 ETA: 5s - loss: 6.8305 - regr_loss: 0.9622 - clf_loss: 0.7106
# Epoch 00020: val_loss improved from 7.37498 to 7.36277, saving model to models\lstm2_univar\multitask\20.hdf5
# 25/25 [==============================] - 6s 226ms/step - loss: 7.3951 - regr_loss: 1.2459 - clf_loss: 0.7150 - regr_mae: 0.8569 - clf_accuracy: 0.4848 - val_loss: 7.3628 - val_regr_loss: 1.2226 - val_clf_loss: 0.7381 - val_regr_mae: 0.7953 - val_clf_accuracy: 0.4500
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.4071 - regr_loss: 1.2374 - clf_loss: 0.7605 - regr_mae: 0.8307 - clf_accuracy: 0.4583
# Epoch 00021: val_loss improved from 7.36277 to 7.34871, saving model to models\lstm2_univar\multitask\21.hdf5
# 25/25 [==============================] - 6s 236ms/step - loss: 7.3958 - regr_loss: 1.2351 - clf_loss: 0.7538 - regr_mae: 0.8237 - clf_accuracy: 0.4596 - val_loss: 7.3487 - val_regr_loss: 1.2249 - val_clf_loss: 0.7359 - val_regr_mae: 0.7962 - val_clf_accuracy: 0.4500
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.2394 - regr_loss: 1.1798 - clf_loss: 0.7245 - regr_mae: 0.8172 - clf_accuracy: 0.5104
# Epoch 00022: val_loss did not improve from 7.34871
# 25/25 [==============================] - 6s 228ms/step - loss: 7.2684 - regr_loss: 1.1954 - clf_loss: 0.7229 - regr_mae: 0.8165 - clf_accuracy: 0.5152 - val_loss: 7.3528 - val_regr_loss: 1.2329 - val_clf_loss: 0.7405 - val_regr_mae: 0.8044 - val_clf_accuracy: 0.4500
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.3952 - regr_loss: 1.2787 - clf_loss: 0.6988 - regr_mae: 0.8258 - clf_accuracy: 0.5365
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.2500000593718141e-05.
#
# Epoch 00023: val_loss did not improve from 7.34871
# 25/25 [==============================] - 6s 230ms/step - loss: 7.3069 - regr_loss: 1.2378 - clf_loss: 0.6919 - regr_mae: 0.8132 - clf_accuracy: 0.5455 - val_loss: 7.3530 - val_regr_loss: 1.2394 - val_clf_loss: 0.7440 - val_regr_mae: 0.8109 - val_clf_accuracy: 0.4500
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 24/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.1797 - regr_loss: 1.1730 - clf_loss: 0.7052 - regr_mae: 0.8159 - clf_accuracy: 0.5625
# Epoch 00024: val_loss did not improve from 7.34871
# 25/25 [==============================] - 6s 220ms/step - loss: 7.1890 - regr_loss: 1.1772 - clf_loss: 0.7062 - regr_mae: 0.8167 - clf_accuracy: 0.5657 - val_loss: 7.3587 - val_regr_loss: 1.2460 - val_clf_loss: 0.7401 - val_regr_mae: 0.8141 - val_clf_accuracy: 0.4500
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 25/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.2220 - regr_loss: 1.1886 - clf_loss: 0.7189 - regr_mae: 0.8108 - clf_accuracy: 0.4948
# Epoch 00025: val_loss did not improve from 7.34871
# 25/25 [==============================] - 5s 219ms/step - loss: 7.1397 - regr_loss: 1.1492 - clf_loss: 0.7147 - regr_mae: 0.7966 - clf_accuracy: 0.4949 - val_loss: 7.3688 - val_regr_loss: 1.2521 - val_clf_loss: 0.7396 - val_regr_mae: 0.8151 - val_clf_accuracy: 0.4500
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 26/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.3408 - regr_loss: 1.2453 - clf_loss: 0.7260 - regr_mae: 0.8283 - clf_accuracy: 0.5000
# Epoch 00026: val_loss did not improve from 7.34871
# 25/25 [==============================] - 5s 219ms/step - loss: 7.4299 - regr_loss: 1.2906 - clf_loss: 0.7255 - regr_mae: 0.8455 - clf_accuracy: 0.4949 - val_loss: 7.3784 - val_regr_loss: 1.2579 - val_clf_loss: 0.7394 - val_regr_mae: 0.8163 - val_clf_accuracy: 0.4500
# Epoch 00026: early stopping

# %%
def plot_multitask_history(hist):
    fig, ax = plt.subplots(2, 2, figsize=(16, 12))
    plotHelpers.plot_train_history(ax[0, 0], hist, 'Total loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[0, 1], hist, 'Accuracy', 'clf_accuracy', 'val_clf_accuracy')
    plotHelpers.plot_train_history(ax[1, 0], hist, 'MSE', 'regr_loss', 'val_regr_loss')
    plotHelpers.plot_train_history(ax[1, 1], hist, 'MAE', 'regr_mae', 'val_regr_mae')
    
plot_multitask_history(multitask_history);

# %% [markdown]
# ### Прогноз

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_multitask_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret, pred_direction_proba = univariate_multitask_lstm.predict_generator(test_multi_gen, verbose=1)
# Out:
# 2/2 [==============================] - 0s 86ms/step

# %%
np.set_printoptions(precision=3, suppress=True)

np.column_stack([pred_log_ret, pred_direction_proba])[-10:]
# Out:
# array([[ 0.043,  0.582],
#        [ 0.066,  0.578],
#        [ 0.017,  0.568],
#        [ 0.033,  0.577],
#        [-0.015,  0.569],
#        [ 0.063,  0.561],
#        [-0.015,  0.561],
#        [ 0.04 ,  0.583],
#        [-0.043,  0.561],
#        [-0.003,  0.589]], dtype=float32)

# %% [markdown]
# #### Прогноз задачи регрессии

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret, figsize=(16, 10), datetime_unit='D')

# %% [markdown]
# #### Прогноз задачи классификации

# %% [markdown]
# *Модель получилась плохой - предсказывает наоборот*.

# %%
true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 0.57909817

# %%
true_direction = test_multi_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([9, 6], dtype=int64)),
#  (array([0, 1]), array([9, 6], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.56      0.56         9
#            1       0.33      0.33      0.33         6
#
#     accuracy                           0.47        15
#    macro avg       0.44      0.44      0.44        15
# weighted avg       0.47      0.47      0.47        15

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[5, 4],
#        [4, 2]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.556, 0.667],
#        [0.444, 0.333]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# # Выводы
#
# 1.  Размер батча сильно влияет на скорость обучения.
# 2.  Инициализация весов (`bias_initializer`) в слое **LSTM** оказалась очень важным параметром.
# 3.  Модель регрессии пока просто выходит на модель случайного блуждания.
# 4.  Модель классификации получились негодная.
# 5.  Комбинированная модель не улучшила качество.

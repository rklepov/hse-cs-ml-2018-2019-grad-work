# %% [markdown]
# # *Многомерная модель на 1D свёрточных слоях*
#
# В качестве признаков используются цены, объём торгов и некоторое число индикаторов (всего 18 признаков)

# %%
import os
import glob
import datetime
import pickle

import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from pandas_datareader import data as pdr

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
import tensorflow as tf
# tf.test.is_gpu_available()
tf.__version__
# Out:
# '2.0.0'

# %%
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import (Input, Dense, Convolution1D, MaxPooling1D, Flatten,
                                     ReLU, LeakyReLU, Dropout, BatchNormalization)
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers import Nadam

# %%
from mdp import TimeSeries
from mdp import MarketData
from mdp import MovingWindowFeatures
from mdp import ClassificationGenerator, RegressionGenerator, MultitaskGenerator
from mdp import invert_log_ret

import mdp.utils as utils
import mdp.plotHelpers as plotHelpers

# %%
import importlib

import mdp

importlib.reload(mdp)
importlib.reload(mdp.datasetGenerator)
importlib.reload(mdp.marketData)
importlib.reload(mdp.movingWindowFeatures)
importlib.reload(mdp.timeSeries)
importlib.reload(mdp.plotHelpers)
importlib.reload(mdp.utils);

# %% [markdown]
# # *Параметры*

# %%
INSTRUMENT = 'CVX' # Chevron corp
START_FROM = '2018-11-14'
WINDOW_SIZE = 10
FORECAST_OFFSET=1
BATCH_SIZE = 8
VAL_SPLIT = '2019-11-01'
TEST_SPLIT = '2019-12-01'
FORCE_TRAIN = True

# %% [markdown]
# # *Исходные данные*
#
# Загрузка данных и вычисление индикаторов.

# %%
instr = MarketData.create_from_tiingo(INSTRUMENT, start=START_FROM)

# %%
instr.feature_names
# Out:
# ['o',
#  'h',
#  'l',
#  'c',
#  'v',
#  'ema14',
#  'ema30',
#  'macd',
#  'macd_signal',
#  'rsi14',
#  'bband20_upper',
#  'bband20_middle',
#  'bband20_lower',
#  'willr14',
#  'stochk',
#  'stochd',
#  'adline',
#  'adosc']

# %% [markdown]
# ## Целевая переменная

# %% [markdown]
# Цена закрытия.

# %%
orig_target = instr.c

# %%
def plot_transformed_series(instrument, series, orig_display_name, transformed_display_name):
    plotHelpers.plot_transformed_timeseries(
        instrument.instrument,
        series,
        title_orig = orig_display_name,
        xlabel_orig = 'Date',
        ylabel_orig = orig_display_name,
        title_transformed = transformed_display_name,
        xlabel_transformed = 'Date',
        ylabel_transformed = transformed_display_name
    )

# %% [markdown]
# Переходим к логарифмической доходности.

# %%
transformed_target = instr.c.transform(transforms={'ratios' : {}, 'ln' : {}})

# %%
plotHelpers.plot_transformed_timeseries_unit(instr,
                                             transformed_target,
                                             'Daily close price, USD', 'Daily log return')

# %% [markdown]
# ## Трансформация признаков
#
# Приведение временных рядов к стационарности.

# %%
def make_feature_selector():
    price_transformer = lambda: {'ratios': {}, 'ln': {}}
    diff_transformer = lambda o: {'diffs': {'order': o}}
    identity_transformer = lambda: {}
    feature_transformations = {
        'o': price_transformer(),
        'h': price_transformer(),
        'l': price_transformer(),
        'c': price_transformer(),
        'v': diff_transformer(1),
        'ema14': diff_transformer(1),
        'ema30': diff_transformer(1),
        'macd': identity_transformer(),
        'macd_signal': identity_transformer(),
        'rsi14': diff_transformer(1),
        'bband20_upper': diff_transformer(1),
        'bband20_middle': diff_transformer(1),
        'bband20_lower': diff_transformer(1),
        'willr14': identity_transformer(),
        'stochd': identity_transformer(),
        'stochk': identity_transformer(),
        'adline': diff_transformer(1),
        'adosc': diff_transformer(1)
    }
    return feature_transformations

# %%
instr_transformed = instr.select_transform(make_feature_selector())

# %%
transformed_target = instr_transformed.c

# %% [markdown]
# ## Обучающая, валидационная и тестовая выборки

# %%
instr_train, instr_val_test = instr_transformed.train_test_split(VAL_SPLIT, window_size=WINDOW_SIZE,
                                                                 scaler=StandardScaler)
#                                                                  scaler=MinMaxScaler,
#                                                                  scaler_kwargs={'feature_range': (-1, 1)})

instr_val, instr_test = instr_val_test.train_test_split(TEST_SPLIT, window_size=WINDOW_SIZE, scaler=None)

len(instr_train), len(instr_val), len(instr_test)
# Out:
# (208, 30, 25)

# %% [markdown]
# Все отмасштабированные признаки на одном графике (для валидационного датасета):

# %%
plotHelpers.plot_all_features(instr_val)

# %% [markdown]
# ## Признаки - скользящие окна

# %%
train_mwf = MovingWindowFeatures.create(instr_train.c, [instr_train], instr_train.feature_names, window_size=WINDOW_SIZE)
val_mwf = MovingWindowFeatures.create(instr_val.c, [instr_val], instr_val.feature_names, window_size=WINDOW_SIZE)
test_mwf = MovingWindowFeatures.create(instr_test.c, [instr_test], instr_test.feature_names, window_size=WINDOW_SIZE)

len(instr_train), len(train_mwf), train_mwf.features.shape
# Out:
# (208, 198, (198, 10, 18))

# %% [markdown]
# Проверка, что скользящие окна соответствуют исходным данным.
#
# Возьмём произвольный признак и произвольное окно (строка #**41**). Проверим, что данные в точности совпадают:

# %%
def check_data(md, mwf, row):
    col = np.random.randint(len(mwf.feature_names))
    feature = mwf.feature_names[col]
    check = (getattr(md, feature).data[row:row + mwf.window_size] == mwf.features[row, :, col]).all()
    assert check
    return feature, check

check_data(instr_train, train_mwf, 41)
# Out:
# ('adline', True)

# %% [markdown]
# # *Модели*

# %% [markdown]
# Модель с двумя 1D свёрточными слоями.

# %%
def build_conv1d_layers(input_shape, filters=(16, 8), kernel_size=5, pool_size=2):
    # формат входа: наша матрица (окно; признак)
    inp = Input(input_shape, name='input')

    # стекаем два уровня Conv1D
    conv1d = Convolution1D(filters=filters[0],
                           kernel_size=kernel_size,
                           padding='same',
                           bias_initializer='he_uniform',
                           bias_regularizer=L1L2(0.01, 0.02),
                           kernel_regularizer=L1L2(0.01, 0.02)
                          )(inp)
    conv1d = BatchNormalization()(conv1d)
    conv1d = LeakyReLU()(conv1d)
    conv1d = Dropout(0.25)(conv1d)

    conv1d = Convolution1D(filters=filters[1],
                           kernel_size=kernel_size,
                           padding='same',
                           bias_initializer='he_uniform',
                           bias_regularizer=L1L2(0.01, 0.02),
                           kernel_regularizer=L1L2(0.01, 0.02)
                          )(conv1d)
    conv1d = BatchNormalization()(conv1d)
    conv1d = LeakyReLU()(conv1d)
    conv1d = Dropout(0.25)(conv1d)
    
    conv1d = MaxPooling1D(pool_size=pool_size)(conv1d)
    
    conv1d = Flatten()(conv1d)
    
    return inp, conv1d

# %% [markdown]
# #### Пути:

# %%
model_path_root = 'models'
model_type_name = 'conv1d_multivar'

def make_model_save_dir(path_root, type_name, class_name):
    save_dir = os.path.join(path_root, type_name, class_name)
    os.makedirs(save_dir, exist_ok=True)
    return save_dir

# %% [markdown]
# #### Общие коллбэки:

# %%
# уменьшение learning rate в случае, если loss не изменяется
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001, verbose=1)

# уменьшение learning rate в 2 раза каждую 5-ю эпоху
def lr_decay(e, lr):
    return lr * (1 - 0.5 * (0 == (e + 1) % 5))

lr_scheduler = LearningRateScheduler(schedule=lr_decay, verbose=1)

# %% [markdown]
# ## Задача регрессии
#
# Непосредственное прогнозирование цены следующего периода.

# %%
train_regr_gen = RegressionGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_regr_gen = RegressionGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_regr_gen = RegressionGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# Следующие числа соответствуют значению параметра `steps_per_epoch` метода [`fit_generator`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit_generator "tf.keras.layers.SimpleRNN &nbsp;|&nbsp; TensorFlow Core r2.0") - то есть это число батчей, которые генератор выдаст за одну эпоху обучения (если класс генератора поддерживает метод `len()`, то данный параметр можно не указывать).

# %%
len(train_regr_gen), len(val_regr_gen), len(test_regr_gen)
# Out:
# (25, 3, 2)

# %% [markdown]
# Один сэмпл данных представляет собой матрицу размером *(длина окна; число признаков)*

# %%
train_regr_gen.input_shape
# Out:
# (10, 18)

# %% [markdown]
# ### Модель для задачи регрессии

# %%
model_class_name = 'regression'

# %%
def build_regression_model(input_shape):
    inp, conv1d = build_conv1d_layers(input_shape, filters=(32, 16))

    regr = Dense(32)(conv1d)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    return Model(inputs=[inp], outputs=[regr])

# %%
multivariate_regression_conv1d = build_regression_model(train_regr_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:
# [`Nadam`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Nadam) (*Adam with Nestrov momentum*).

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Функция потерь:
#
# В качестве функции потерь будем использовать [MSE](https://www.tensorflow.org/api_docs/python/tf/keras/losses/MSE) (чтобы штрафовать за большие отклонения). Xотя хорошая функция потерь в контексте темы данной задачи - это [вопрос сложный](https://github.com/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Chapter5_LossFunctions/Ch5_LossFunctions_PyMC3.ipynb). В частности, здесь нам, очевидно, помимо абсолютного значения отклонения также важен его знак.

# %%
multivariate_regression_conv1d.compile(optimizer=optimizer,
                                       loss={'regr': 'mse'},
                                       metrics={'regr': 'mae'})

multivariate_regression_conv1d.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 10, 18)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 10, 64)            5824
# _________________________________________________________________
# batch_normalization (BatchNo (None, 10, 64)            256
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 10, 64)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 64)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 10, 32)            10272
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 10, 32)            128
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 10, 32)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 32)            0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 5, 32)             0
# _________________________________________________________________
# flatten (Flatten)            (None, 160)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                10304
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# regr (Dense)                 (None, 1)                 65
# =================================================================
# Total params: 27,105
# Trainable params: 26,785
# Non-trainable params: 320
# _________________________________________________________________

# %% [markdown]
# #### Обучение:

# %%
regr_history = utils.train_model(multivariate_regression_conv1d,
                                 model_save_dir, train_regr_gen, val_regr_gen,
                                 callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                 force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 24/25 [===========================>..] - ETA: 0s - loss: 12.7973 - mae: 1.1409
# Epoch 00001: val_loss improved from inf to 12.03179, saving model to models\conv1d_multivar\regression\01.hdf5
# 25/25 [==============================] - 6s 223ms/step - loss: 12.8552 - mae: 1.1533 - val_loss: 12.0318 - val_mae: 0.8469
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 24/25 [===========================>..] - ETA: 0s - loss: 11.9520 - mae: 0.9410
# Epoch 00002: val_loss improved from 12.03179 to 11.56828, saving model to models\conv1d_multivar\regression\02.hdf5
# 25/25 [==============================] - 3s 129ms/step - loss: 11.9433 - mae: 0.9452 - val_loss: 11.5683 - val_mae: 0.8171
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 24/25 [===========================>..] - ETA: 0s - loss: 11.7144 - mae: 0.9665
# Epoch 00003: val_loss improved from 11.56828 to 11.34927, saving model to models\conv1d_multivar\regression\03.hdf5
# 25/25 [==============================] - 3s 135ms/step - loss: 11.7479 - mae: 0.9748 - val_loss: 11.3493 - val_mae: 0.9060
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 24/25 [===========================>..] - ETA: 0s - loss: 11.0853 - mae: 0.8469
# Epoch 00004: val_loss improved from 11.34927 to 11.05530, saving model to models\conv1d_multivar\regression\04.hdf5
# 25/25 [==============================] - 3s 104ms/step - loss: 11.0407 - mae: 0.8344 - val_loss: 11.0553 - val_mae: 0.8580
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 24/25 [===========================>..] - ETA: 0s - loss: 10.9115 - mae: 0.8765
# Epoch 00005: val_loss improved from 11.05530 to 10.94391, saving model to models\conv1d_multivar\regression\05.hdf5
# 25/25 [==============================] - 3s 107ms/step - loss: 10.9499 - mae: 0.8908 - val_loss: 10.9439 - val_mae: 0.8967
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 24/25 [===========================>..] - ETA: 0s - loss: 10.6000 - mae: 0.8254
# Epoch 00006: val_loss improved from 10.94391 to 10.74498, saving model to models\conv1d_multivar\regression\06.hdf5
# 25/25 [==============================] - 3s 107ms/step - loss: 10.6306 - mae: 0.8240 - val_loss: 10.7450 - val_mae: 0.9095
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 24/25 [===========================>..] - ETA: 0s - loss: 10.5715 - mae: 0.9081
# Epoch 00007: val_loss improved from 10.74498 to 10.56918, saving model to models\conv1d_multivar\regression\07.hdf5
# 25/25 [==============================] - 3s 108ms/step - loss: 10.5834 - mae: 0.9190 - val_loss: 10.5692 - val_mae: 0.9008
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 24/25 [===========================>..] - ETA: 0s - loss: 10.3351 - mae: 0.8855
# Epoch 00008: val_loss improved from 10.56918 to 10.38028, saving model to models\conv1d_multivar\regression\08.hdf5
# 25/25 [==============================] - 3s 108ms/step - loss: 10.3627 - mae: 0.8987 - val_loss: 10.3803 - val_mae: 0.8948
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 24/25 [===========================>..] - ETA: 0s - loss: 10.0323 - mae: 0.8150
# Epoch 00009: val_loss improved from 10.38028 to 10.29392, saving model to models\conv1d_multivar\regression\09.hdf5
# 25/25 [==============================] - 3s 108ms/step - loss: 10.0742 - mae: 0.8194 - val_loss: 10.2939 - val_mae: 0.9300
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 24/25 [===========================>..] - ETA: 0s - loss: 9.8508 - mae: 0.8107
# Epoch 00010: val_loss improved from 10.29392 to 10.17576, saving model to models\conv1d_multivar\regression\10.hdf5
# 25/25 [==============================] - 3s 107ms/step - loss: 9.8919 - mae: 0.8185 - val_loss: 10.1758 - val_mae: 0.9336
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 24/25 [===========================>..] - ETA: 0s - loss: 9.7274 - mae: 0.7742
# Epoch 00011: val_loss improved from 10.17576 to 10.06625, saving model to models\conv1d_multivar\regression\11.hdf5
# 25/25 [==============================] - 3s 108ms/step - loss: 9.7339 - mae: 0.7776 - val_loss: 10.0663 - val_mae: 0.9304
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 24/25 [===========================>..] - ETA: 0s - loss: 9.6398 - mae: 0.8226
# Epoch 00012: val_loss improved from 10.06625 to 9.99314, saving model to models\conv1d_multivar\regression\12.hdf5
# 25/25 [==============================] - 3s 106ms/step - loss: 9.6157 - mae: 0.8154 - val_loss: 9.9931 - val_mae: 0.9324
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 24/25 [===========================>..] - ETA: 0s - loss: 9.5796 - mae: 0.8388
# Epoch 00013: val_loss improved from 9.99314 to 9.88271, saving model to models\conv1d_multivar\regression\13.hdf5
# 25/25 [==============================] - 3s 109ms/step - loss: 9.6585 - mae: 0.8515 - val_loss: 9.8827 - val_mae: 0.9319
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 24/25 [===========================>..] - ETA: 0s - loss: 9.4932 - mae: 0.8242
# Epoch 00014: val_loss improved from 9.88271 to 9.82800, saving model to models\conv1d_multivar\regression\14.hdf5
# 25/25 [==============================] - 3s 112ms/step - loss: 9.5017 - mae: 0.8326 - val_loss: 9.8280 - val_mae: 0.9527
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 24/25 [===========================>..] - ETA: 0s - loss: 9.3614 - mae: 0.7767
# Epoch 00015: val_loss improved from 9.82800 to 9.78048, saving model to models\conv1d_multivar\regression\15.hdf5
# 25/25 [==============================] - 3s 108ms/step - loss: 9.3589 - mae: 0.7789 - val_loss: 9.7805 - val_mae: 0.9511
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 24/25 [===========================>..] - ETA: 0s - loss: 9.4217 - mae: 0.8650
# Epoch 00016: val_loss improved from 9.78048 to 9.73633, saving model to models\conv1d_multivar\regression\16.hdf5
# 25/25 [==============================] - 3s 109ms/step - loss: 9.3881 - mae: 0.8541 - val_loss: 9.7363 - val_mae: 0.9515
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 24/25 [===========================>..] - ETA: 0s - loss: 9.2083 - mae: 0.7793
# Epoch 00017: val_loss improved from 9.73633 to 9.68870, saving model to models\conv1d_multivar\regression\17.hdf5
# 25/25 [==============================] - 3s 109ms/step - loss: 9.2418 - mae: 0.7899 - val_loss: 9.6887 - val_mae: 0.9506
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 24/25 [===========================>..] - ETA: 0s - loss: 9.1469 - mae: 0.7570
# Epoch 00018: val_loss improved from 9.68870 to 9.65938, saving model to models\conv1d_multivar\regression\18.hdf5
# 25/25 [==============================] - 3s 106ms/step - loss: 9.1655 - mae: 0.7631 - val_loss: 9.6594 - val_mae: 0.9569
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 24/25 [===========================>..] - ETA: 0s - loss: 9.2362 - mae: 0.8126
# Epoch 00019: val_loss improved from 9.65938 to 9.60225, saving model to models\conv1d_multivar\regression\19.hdf5
# 25/25 [==============================] - 3s 107ms/step - loss: 9.2018 - mae: 0.8020 - val_loss: 9.6023 - val_mae: 0.9584
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 24/25 [===========================>..] - ETA: 0s - loss: 9.0912 - mae: 0.8252
# Epoch 00020: val_loss improved from 9.60225 to 9.58362, saving model to models\conv1d_multivar\regression\20.hdf5
# 25/25 [==============================] - 3s 106ms/step - loss: 9.1023 - mae: 0.8290 - val_loss: 9.5836 - val_mae: 0.9632
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 24/25 [===========================>..] - ETA: 0s - loss: 9.0875 - mae: 0.7997
# Epoch 00021: val_loss improved from 9.58362 to 9.56872, saving model to models\conv1d_multivar\regression\21.hdf5
# 25/25 [==============================] - 3s 101ms/step - loss: 9.0712 - mae: 0.7951 - val_loss: 9.5687 - val_mae: 0.9668
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 24/25 [===========================>..] - ETA: 0s - loss: 9.0081 - mae: 0.7852- ETA: 0s - loss: 9.0488 - mae: 0.7
# Epoch 00022: val_loss improved from 9.56872 to 9.54408, saving model to models\conv1d_multivar\regression\22.hdf5
# 25/25 [==============================] - 3s 105ms/step - loss: 8.9830 - mae: 0.7771 - val_loss: 9.5441 - val_mae: 0.9687
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 24/25 [===========================>..] - ETA: 0s - loss: 8.9269 - mae: 0.7628
# Epoch 00023: val_loss improved from 9.54408 to 9.49628, saving model to models\conv1d_multivar\regression\23.hdf5
# 25/25 [==============================] - 3s 104ms/step - loss: 8.9170 - mae: 0.7631 - val_loss: 9.4963 - val_mae: 0.9606
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 24/25 [===========================>..] - ETA: 0s - loss: 9.0388 - mae: 0.8316
# Epoch 00024: val_loss improved from 9.49628 to 9.47511, saving model to models\conv1d_multivar\regression\24.hdf5
# 25/25 [==============================] - 3s 104ms/step - loss: 9.0272 - mae: 0.8303 - val_loss: 9.4751 - val_mae: 0.9625
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 24/25 [===========================>..] - ETA: 0s - loss: 9.0311 - mae: 0.8337
# Epoch 00025: val_loss improved from 9.47511 to 9.45079, saving model to models\conv1d_multivar\regression\25.hdf5
# 25/25 [==============================] - 3s 104ms/step - loss: 9.0179 - mae: 0.8307 - val_loss: 9.4508 - val_mae: 0.9587
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 24/25 [===========================>..] - ETA: 0s - loss: 8.9309 - mae: 0.7882- ETA: 1s - loss: 8.9177
# Epoch 00026: val_loss improved from 9.45079 to 9.43573, saving model to models\conv1d_multivar\regression\26.hdf5
# 25/25 [==============================] - 3s 106ms/step - loss: 8.9207 - mae: 0.7903 - val_loss: 9.4357 - val_mae: 0.9583
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 24/25 [===========================>..] - ETA: 0s - loss: 8.9189 - mae: 0.8039
# Epoch 00027: val_loss improved from 9.43573 to 9.41825, saving model to models\conv1d_multivar\regression\27.hdf5
# 25/25 [==============================] - 3s 104ms/step - loss: 8.9090 - mae: 0.7990 - val_loss: 9.4182 - val_mae: 0.9584
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 24/25 [===========================>..] - ETA: 0s - loss: 8.7546 - mae: 0.7236
# Epoch 00028: val_loss improved from 9.41825 to 9.40917, saving model to models\conv1d_multivar\regression\28.hdf5
# 25/25 [==============================] - 3s 106ms/step - loss: 8.7560 - mae: 0.7257 - val_loss: 9.4092 - val_mae: 0.9603
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 24/25 [===========================>..] - ETA: 0s - loss: 8.9804 - mae: 0.8103- ETA: 0s - loss: 8.9574 - mae: 0.
# Epoch 00029: val_loss improved from 9.40917 to 9.39861, saving model to models\conv1d_multivar\regression\29.hdf5
# 25/25 [==============================] - 3s 104ms/step - loss: 8.9489 - mae: 0.8022 - val_loss: 9.3986 - val_mae: 0.9633
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 24/25 [===========================>..] - ETA: 0s - loss: 8.9312 - mae: 0.8057
# Epoch 00030: val_loss improved from 9.39861 to 9.38855, saving model to models\conv1d_multivar\regression\30.hdf5
# 25/25 [==============================] - 3s 102ms/step - loss: 8.9285 - mae: 0.8065 - val_loss: 9.3886 - val_mae: 0.9645
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 24/25 [===========================>..] - ETA: 0s - loss: 8.9143 - mae: 0.7836
# Epoch 00031: val_loss improved from 9.38855 to 9.37744, saving model to models\conv1d_multivar\regression\31.hdf5
# 25/25 [==============================] - 3s 105ms/step - loss: 8.9408 - mae: 0.7928 - val_loss: 9.3774 - val_mae: 0.9626
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 24/25 [===========================>..] - ETA: 0s - loss: 8.7811 - mae: 0.7543
# Epoch 00032: val_loss improved from 9.37744 to 9.36908, saving model to models\conv1d_multivar\regression\32.hdf5
# 25/25 [==============================] - 3s 103ms/step - loss: 8.7729 - mae: 0.7556 - val_loss: 9.3691 - val_mae: 0.9621

# %%
def plot_regr_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'MSE', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'MAE', 'mae', 'val_mae')
    
plot_regr_history(regr_history);

# %% [markdown]
# ### Прогноз задачи регрессии

# %% [markdown]
# *Судя по всему, просто выходит на модель случайного блуждания*

# %%
# загружаем последнюю эпоху с минимальным лоссом
multivariate_regression_conv1d.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret_test = multivariate_regression_conv1d.predict_generator(test_regr_gen, verbose=1)
# Out:
# 2/2 [==============================] - 0s 58ms/step

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret_test, figsize=(16, 10), datetime_unit='D')

# %% [markdown]
# ## Задача классификации
#
# Прогнозируем направление изменения цены по сравнению с предыдущим периодом (**0** - снижение, **1** - рост).

# %%
model_class_name = 'classification'

# %%
train_clf_gen = ClassificationGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_clf_gen = ClassificationGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_clf_gen = ClassificationGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_classification_model(input_shape):
    inp, conv1d = build_conv1d_layers(input_shape, filters=(32, 16))

    clf = Dense(32)(conv1d)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)

    return Model(inputs=[inp], outputs=[clf])

# %%
multivariate_classification_conv1d = build_classification_model(test_clf_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
multivariate_classification_conv1d.compile(optimizer=optimizer,
                                           loss={'clf': 'binary_crossentropy'},
                                           metrics={'clf': 'accuracy'})

multivariate_classification_conv1d.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 10, 18)]          0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 10, 64)            5824
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 10, 64)            256
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 10, 64)            0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 10, 64)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 10, 32)            10272
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 10, 32)            128
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 10, 32)            0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 10, 32)            0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 5, 32)             0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 160)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                10304
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# clf (Dense)                  (None, 1)                 65
# =================================================================
# Total params: 27,105
# Trainable params: 26,785
# Non-trainable params: 320
# _________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
clf_history = utils.train_model(multivariate_classification_conv1d,
                                model_save_dir, train_clf_gen, val_clf_gen,
                                callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 24/25 [===========================>..] - ETA: 0s - loss: 11.2352 - accuracy: 0.5000
# Epoch 00001: val_loss improved from inf to 10.57767, saving model to models\conv1d_multivar\classification\01.hdf5
# 25/25 [==============================] - 3s 110ms/step - loss: 11.2143 - accuracy: 0.5051 - val_loss: 10.5777 - val_accuracy: 0.5000
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 24/25 [===========================>..] - ETA: 0s - loss: 10.0363 - accuracy: 0.5573
# Epoch 00002: val_loss improved from 10.57767 to 9.37404, saving model to models\conv1d_multivar\classification\02.hdf5
# 25/25 [==============================] - 3s 113ms/step - loss: 10.0128 - accuracy: 0.5606 - val_loss: 9.3740 - val_accuracy: 0.6000
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 24/25 [===========================>..] - ETA: 0s - loss: 8.9578 - accuracy: 0.5729
# Epoch 00003: val_loss improved from 9.37404 to 8.28135, saving model to models\conv1d_multivar\classification\03.hdf5
# 25/25 [==============================] - 3s 108ms/step - loss: 8.9304 - accuracy: 0.5758 - val_loss: 8.2813 - val_accuracy: 0.4500
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.8433 - accuracy: 0.6250
# Epoch 00004: val_loss improved from 8.28135 to 7.28558, saving model to models\conv1d_multivar\classification\04.hdf5
# 25/25 [==============================] - 3s 118ms/step - loss: 7.8334 - accuracy: 0.6212 - val_loss: 7.2856 - val_accuracy: 0.5500
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.0250 - accuracy: 0.6458
# Epoch 00005: val_loss improved from 7.28558 to 6.81982, saving model to models\conv1d_multivar\classification\05.hdf5
# 25/25 [==============================] - 3s 110ms/step - loss: 7.0063 - accuracy: 0.6566 - val_loss: 6.8198 - val_accuracy: 0.4000
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 24/25 [===========================>..] - ETA: 0s - loss: 6.5338 - accuracy: 0.7240
# Epoch 00006: val_loss improved from 6.81982 to 6.35104, saving model to models\conv1d_multivar\classification\06.hdf5
# 25/25 [==============================] - 3s 107ms/step - loss: 6.5277 - accuracy: 0.7172 - val_loss: 6.3510 - val_accuracy: 0.5500
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 24/25 [===========================>..] - ETA: 0s - loss: 6.1529 - accuracy: 0.6458
# Epoch 00007: val_loss improved from 6.35104 to 5.93681, saving model to models\conv1d_multivar\classification\07.hdf5
# 25/25 [==============================] - 3s 108ms/step - loss: 6.1502 - accuracy: 0.6364 - val_loss: 5.9368 - val_accuracy: 0.4500
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 24/25 [===========================>..] - ETA: 0s - loss: 5.7170 - accuracy: 0.6562
# Epoch 00008: val_loss improved from 5.93681 to 5.53635, saving model to models\conv1d_multivar\classification\08.hdf5
# 25/25 [==============================] - 3s 106ms/step - loss: 5.7030 - accuracy: 0.6616 - val_loss: 5.5363 - val_accuracy: 0.5500
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 24/25 [===========================>..] - ETA: 0s - loss: 5.3408 - accuracy: 0.6354
# Epoch 00009: val_loss improved from 5.53635 to 5.17453, saving model to models\conv1d_multivar\classification\09.hdf5
# 25/25 [==============================] - 3s 106ms/step - loss: 5.3417 - accuracy: 0.6313 - val_loss: 5.1745 - val_accuracy: 0.4500
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.9864 - accuracy: 0.6927
# Epoch 00010: val_loss improved from 5.17453 to 4.98270, saving model to models\conv1d_multivar\classification\10.hdf5
# 25/25 [==============================] - 3s 106ms/step - loss: 4.9795 - accuracy: 0.6970 - val_loss: 4.9827 - val_accuracy: 0.4500
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.7381 - accuracy: 0.7188
# Epoch 00011: val_loss improved from 4.98270 to 4.79974, saving model to models\conv1d_multivar\classification\11.hdf5
# 25/25 [==============================] - 3s 107ms/step - loss: 4.7408 - accuracy: 0.7172 - val_loss: 4.7997 - val_accuracy: 0.4500
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.5820 - accuracy: 0.7135
# Epoch 00012: val_loss improved from 4.79974 to 4.66255, saving model to models\conv1d_multivar\classification\12.hdf5
# 25/25 [==============================] - 3s 107ms/step - loss: 4.5830 - accuracy: 0.7121 - val_loss: 4.6626 - val_accuracy: 0.4500
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.4233 - accuracy: 0.6719
# Epoch 00013: val_loss improved from 4.66255 to 4.50831, saving model to models\conv1d_multivar\classification\13.hdf5
# 25/25 [==============================] - 3s 108ms/step - loss: 4.4178 - accuracy: 0.6717 - val_loss: 4.5083 - val_accuracy: 0.4500
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.2762 - accuracy: 0.70 - ETA: 0s - loss: 4.2679 - accuracy: 0.7083
# Epoch 00014: val_loss improved from 4.50831 to 4.35342, saving model to models\conv1d_multivar\classification\14.hdf5
# 25/25 [==============================] - 3s 109ms/step - loss: 4.2609 - accuracy: 0.7071 - val_loss: 4.3534 - val_accuracy: 0.5000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.1284 - accuracy: 0.6927
# Epoch 00015: val_loss improved from 4.35342 to 4.26992, saving model to models\conv1d_multivar\classification\15.hdf5
# 25/25 [==============================] - 3s 108ms/step - loss: 4.1340 - accuracy: 0.6919 - val_loss: 4.2699 - val_accuracy: 0.5000
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.0042 - accuracy: 0.7292
# Epoch 00016: val_loss improved from 4.26992 to 4.18791, saving model to models\conv1d_multivar\classification\16.hdf5
# 25/25 [==============================] - 3s 108ms/step - loss: 4.0119 - accuracy: 0.7222 - val_loss: 4.1879 - val_accuracy: 0.5000
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.9616 - accuracy: 0.7188
# Epoch 00017: val_loss improved from 4.18791 to 4.12601, saving model to models\conv1d_multivar\classification\17.hdf5
# 25/25 [==============================] - 3s 108ms/step - loss: 3.9484 - accuracy: 0.7273 - val_loss: 4.1260 - val_accuracy: 0.5000
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.9014 - accuracy: 0.7031
# Epoch 00018: val_loss improved from 4.12601 to 4.07360, saving model to models\conv1d_multivar\classification\18.hdf5
# 25/25 [==============================] - 3s 108ms/step - loss: 3.8959 - accuracy: 0.7071 - val_loss: 4.0736 - val_accuracy: 0.5000
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.8394 - accuracy: 0.7448
# Epoch 00019: val_loss improved from 4.07360 to 4.00746, saving model to models\conv1d_multivar\classification\19.hdf5
# 25/25 [==============================] - 3s 108ms/step - loss: 3.8328 - accuracy: 0.7424 - val_loss: 4.0075 - val_accuracy: 0.5000
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.8007 - accuracy: 0.7135
# Epoch 00020: val_loss improved from 4.00746 to 3.97561, saving model to models\conv1d_multivar\classification\20.hdf5
# 25/25 [==============================] - 3s 106ms/step - loss: 3.7889 - accuracy: 0.7222 - val_loss: 3.9756 - val_accuracy: 0.5500
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.6827 - accuracy: 0.7969
# Epoch 00021: val_loss improved from 3.97561 to 3.94590, saving model to models\conv1d_multivar\classification\21.hdf5
# 25/25 [==============================] - 3s 107ms/step - loss: 3.6887 - accuracy: 0.7929 - val_loss: 3.9459 - val_accuracy: 0.5000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.7045 - accuracy: 0.7240
# Epoch 00022: val_loss improved from 3.94590 to 3.91690, saving model to models\conv1d_multivar\classification\22.hdf5
# 25/25 [==============================] - 3s 108ms/step - loss: 3.7078 - accuracy: 0.7222 - val_loss: 3.9169 - val_accuracy: 0.5000
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.6818 - accuracy: 0.7344
# Epoch 00023: val_loss improved from 3.91690 to 3.88958, saving model to models\conv1d_multivar\classification\23.hdf5
# 25/25 [==============================] - 3s 107ms/step - loss: 3.6727 - accuracy: 0.7374 - val_loss: 3.8896 - val_accuracy: 0.5000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.6116 - accuracy: 0.7344
# Epoch 00024: val_loss improved from 3.88958 to 3.86100, saving model to models\conv1d_multivar\classification\24.hdf5
# 25/25 [==============================] - 3s 106ms/step - loss: 3.6099 - accuracy: 0.7323 - val_loss: 3.8610 - val_accuracy: 0.5000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.5822 - accuracy: 0.7292
# Epoch 00025: val_loss improved from 3.86100 to 3.83849, saving model to models\conv1d_multivar\classification\25.hdf5
# 25/25 [==============================] - 3s 107ms/step - loss: 3.5767 - accuracy: 0.7323 - val_loss: 3.8385 - val_accuracy: 0.5000
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.5703 - accuracy: 0.7500
# Epoch 00026: val_loss improved from 3.83849 to 3.82833, saving model to models\conv1d_multivar\classification\26.hdf5
# 25/25 [==============================] - 3s 110ms/step - loss: 3.5601 - accuracy: 0.7576 - val_loss: 3.8283 - val_accuracy: 0.5000
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.5011 - accuracy: 0.7760
# Epoch 00027: val_loss improved from 3.82833 to 3.81273, saving model to models\conv1d_multivar\classification\27.hdf5
# 25/25 [==============================] - 3s 107ms/step - loss: 3.5008 - accuracy: 0.7727 - val_loss: 3.8127 - val_accuracy: 0.5000
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.5450 - accuracy: 0.7604
# Epoch 00028: val_loss improved from 3.81273 to 3.80214, saving model to models\conv1d_multivar\classification\28.hdf5
# 25/25 [==============================] - 3s 107ms/step - loss: 3.5483 - accuracy: 0.7525 - val_loss: 3.8021 - val_accuracy: 0.5000
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.4998 - accuracy: 0.7344
# Epoch 00029: val_loss improved from 3.80214 to 3.78709, saving model to models\conv1d_multivar\classification\29.hdf5
# 25/25 [==============================] - 3s 109ms/step - loss: 3.4989 - accuracy: 0.7374 - val_loss: 3.7871 - val_accuracy: 0.5000
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.4913 - accuracy: 0.7656
# Epoch 00030: val_loss improved from 3.78709 to 3.77869, saving model to models\conv1d_multivar\classification\30.hdf5
# 25/25 [==============================] - 3s 107ms/step - loss: 3.4931 - accuracy: 0.7576 - val_loss: 3.7787 - val_accuracy: 0.5000
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.5238 - accuracy: 0.7031
# Epoch 00031: val_loss improved from 3.77869 to 3.77010, saving model to models\conv1d_multivar\classification\31.hdf5
# 25/25 [==============================] - 3s 111ms/step - loss: 3.5136 - accuracy: 0.7071 - val_loss: 3.7701 - val_accuracy: 0.5000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.4955 - accuracy: 0.7188
# Epoch 00032: val_loss improved from 3.77010 to 3.76595, saving model to models\conv1d_multivar\classification\32.hdf5
# 25/25 [==============================] - 3s 106ms/step - loss: 3.4945 - accuracy: 0.7172 - val_loss: 3.7659 - val_accuracy: 0.5000

# %%
def plot_clf_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'Loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'Accuracy', 'accuracy', 'val_accuracy')
    
plot_clf_history(clf_history);

# %% [markdown]
# ### Прогноз задачи классификации

# %%
# загружаем последнюю эпоху с минимальным лоссом
multivariate_classification_conv1d.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %%
pred_direction_proba = multivariate_classification_conv1d.predict_generator(test_clf_gen, verbose=1)

true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 2/2 [==============================] - 0s 26ms/step
# 0.56236154

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([9, 6], dtype=int64)),
#  (array([0, 1]), array([8, 7], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.67      0.71         9
#            1       0.57      0.67      0.62         6
#
#     accuracy                           0.67        15
#    macro avg       0.66      0.67      0.66        15
# weighted avg       0.68      0.67      0.67        15

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[6, 3],
#        [2, 4]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.75      , 0.42857143],
#        [0.25      , 0.57142857]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# ## Многозадачная модель: одновременно регрессия и классификация

# %%
model_class_name = 'multitask'

# %%
train_multi_gen = MultitaskGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_multi_gen = MultitaskGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_multi_gen = MultitaskGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_multitask_model(input_shape):
    inp, conv1d = build_conv1d_layers(input_shape, filters=(32, 16))

    # первый выход: задача регрссии
    regr = Dense(32)(conv1d)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    # второй выход: задача классификации
    clf = Dense(32)(conv1d)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)
    
    return Model(inputs=[inp], outputs=[regr, clf])

# %%
multivariate_multitask_conv1d = build_multitask_model(train_multi_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
multivariate_multitask_conv1d.compile(optimizer=optimizer,
                                      loss={'regr': 'mse', 'clf': 'binary_crossentropy'},
                                      loss_weights={'regr': 2., 'clf': 1.},
                                      metrics={'regr': 'mae', 'clf' : 'accuracy'})

multivariate_multitask_conv1d.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 10, 18)]     0
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 10, 64)       5824        input[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 10, 64)       256         conv1d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 10, 64)       0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 10, 64)       0           leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 10, 32)       10272       dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 10, 32)       128         conv1d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 10, 32)       0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 10, 32)       0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 5, 32)        0           dropout_7[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 160)          0           max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           10304       flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           10304       flatten_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64)           256         dense_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 64)           256         dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 64)           0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 64)           0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 64)           0           leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 64)           0           leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# regr (Dense)                    (None, 1)            65          dropout_8[0][0]
# __________________________________________________________________________________________________
# clf (Dense)                     (None, 1)            65          dropout_9[0][0]
# ==================================================================================================
# Total params: 37,730
# Trainable params: 37,282
# Non-trainable params: 448
# __________________________________________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
multitask_history = utils.train_model(multivariate_multitask_conv1d,
                                      model_save_dir, train_multi_gen, val_multi_gen,
                                      callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                      force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 24/25 [===========================>..] - ETA: 0s - loss: 15.9125 - regr_loss: 2.1320 - clf_loss: 0.8284 - regr_mae: 1.1958 - clf_accuracy: 0.5052
# Epoch 00001: val_loss improved from inf to 14.34796, saving model to models\conv1d_multivar\multitask\01.hdf5
# 25/25 [==============================] - 4s 146ms/step - loss: 15.8848 - regr_loss: 2.1227 - clf_loss: 0.8214 - regr_mae: 1.1930 - clf_accuracy: 0.5101 - val_loss: 14.3480 - val_regr_loss: 1.4124 - val_clf_loss: 0.7670 - val_regr_mae: 0.9156 - val_clf_accuracy: 0.4500
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 24/25 [===========================>..] - ETA: 0s - loss: 14.8080 - regr_loss: 1.7121 - clf_loss: 0.6896 - regr_mae: 1.0213 - clf_accuracy: 0.5885
# Epoch 00002: val_loss improved from 14.34796 to 14.02487, saving model to models\conv1d_multivar\multitask\02.hdf5
# 25/25 [==============================] - 4s 141ms/step - loss: 14.8569 - regr_loss: 1.7332 - clf_loss: 0.6996 - regr_mae: 1.0276 - clf_accuracy: 0.5758 - val_loss: 14.0249 - val_regr_loss: 1.3468 - val_clf_loss: 0.7114 - val_regr_mae: 0.8682 - val_clf_accuracy: 0.5000
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 24/25 [===========================>..] - ETA: 0s - loss: 14.5344 - regr_loss: 1.6087 - clf_loss: 0.7634 - regr_mae: 1.0081 - clf_accuracy: 0.5417
# Epoch 00003: val_loss did not improve from 14.02487
# 25/25 [==============================] - 3s 140ms/step - loss: 14.5300 - regr_loss: 1.6066 - clf_loss: 0.7661 - regr_mae: 1.0027 - clf_accuracy: 0.5354 - val_loss: 14.1152 - val_regr_loss: 1.4688 - val_clf_loss: 0.7018 - val_regr_mae: 0.8845 - val_clf_accuracy: 0.5500
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 24/25 [===========================>..] - ETA: 0s - loss: 13.4295 - regr_loss: 1.1679 - clf_loss: 0.6855 - regr_mae: 0.8184 - clf_accuracy: 0.5729
# Epoch 00004: val_loss improved from 14.02487 to 13.96103, saving model to models\conv1d_multivar\multitask\04.hdf5
# 25/25 [==============================] - 3s 137ms/step - loss: 13.4748 - regr_loss: 1.1953 - clf_loss: 0.6796 - regr_mae: 0.8268 - clf_accuracy: 0.5808 - val_loss: 13.9610 - val_regr_loss: 1.4431 - val_clf_loss: 0.7480 - val_regr_mae: 0.9133 - val_clf_accuracy: 0.3500
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 24/25 [===========================>..] - ETA: 0s - loss: 13.7992 - regr_loss: 1.4099 - clf_loss: 0.6891 - regr_mae: 0.9027 - clf_accuracy: 0.5885
# Epoch 00005: val_loss improved from 13.96103 to 13.83528, saving model to models\conv1d_multivar\multitask\05.hdf5
# 25/25 [==============================] - 4s 142ms/step - loss: 13.7939 - regr_loss: 1.4124 - clf_loss: 0.6802 - regr_mae: 0.9078 - clf_accuracy: 0.5909 - val_loss: 13.8353 - val_regr_loss: 1.4232 - val_clf_loss: 0.7435 - val_regr_mae: 0.9153 - val_clf_accuracy: 0.3500
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 24/25 [===========================>..] - ETA: 0s - loss: 13.6271 - regr_loss: 1.3490 - clf_loss: 0.7229 - regr_mae: 0.9106 - clf_accuracy: 0.5677
# Epoch 00006: val_loss improved from 13.83528 to 13.73659, saving model to models\conv1d_multivar\multitask\06.hdf5
# 25/25 [==============================] - 4s 141ms/step - loss: 13.5743 - regr_loss: 1.3230 - clf_loss: 0.7235 - regr_mae: 0.9063 - clf_accuracy: 0.5707 - val_loss: 13.7366 - val_regr_loss: 1.4084 - val_clf_loss: 0.7609 - val_regr_mae: 0.8909 - val_clf_accuracy: 0.3500
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 24/25 [===========================>..] - ETA: 0s - loss: 13.4093 - regr_loss: 1.3028 - clf_loss: 0.6859 - regr_mae: 0.8789 - clf_accuracy: 0.5885
# Epoch 00007: val_loss improved from 13.73659 to 13.71717, saving model to models\conv1d_multivar\multitask\07.hdf5
# 25/25 [==============================] - 4s 142ms/step - loss: 13.4978 - regr_loss: 1.3448 - clf_loss: 0.6931 - regr_mae: 0.8926 - clf_accuracy: 0.5758 - val_loss: 13.7172 - val_regr_loss: 1.4491 - val_clf_loss: 0.7503 - val_regr_mae: 0.8923 - val_clf_accuracy: 0.3000
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 24/25 [===========================>..] - ETA: 0s - loss: 13.0537 - regr_loss: 1.1691 - clf_loss: 0.6882 - regr_mae: 0.8376 - clf_accuracy: 0.5833
# Epoch 00008: val_loss improved from 13.71717 to 13.51858, saving model to models\conv1d_multivar\multitask\08.hdf5
# 25/25 [==============================] - 4s 143ms/step - loss: 13.0921 - regr_loss: 1.1887 - clf_loss: 0.6897 - regr_mae: 0.8482 - clf_accuracy: 0.5859 - val_loss: 13.5186 - val_regr_loss: 1.3921 - val_clf_loss: 0.7567 - val_regr_mae: 0.8521 - val_clf_accuracy: 0.4500
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 24/25 [===========================>..] - ETA: 0s - loss: 12.8849 - regr_loss: 1.1338 - clf_loss: 0.6831 - regr_mae: 0.8379 - clf_accuracy: 0.5781
# Epoch 00009: val_loss improved from 13.51858 to 13.46893, saving model to models\conv1d_multivar\multitask\09.hdf5
# 25/25 [==============================] - 3s 138ms/step - loss: 13.1503 - regr_loss: 1.2667 - clf_loss: 0.6870 - regr_mae: 0.8665 - clf_accuracy: 0.5758 - val_loss: 13.4689 - val_regr_loss: 1.4156 - val_clf_loss: 0.7535 - val_regr_mae: 0.8740 - val_clf_accuracy: 0.4000
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 24/25 [===========================>..] - ETA: 0s - loss: 12.8477 - regr_loss: 1.1383 - clf_loss: 0.7092 - regr_mae: 0.8135 - clf_accuracy: 0.5677
# Epoch 00010: val_loss improved from 13.46893 to 13.42696, saving model to models\conv1d_multivar\multitask\10.hdf5
# 25/25 [==============================] - 4s 144ms/step - loss: 12.9034 - regr_loss: 1.1655 - clf_loss: 0.7120 - regr_mae: 0.8201 - clf_accuracy: 0.5657 - val_loss: 13.4270 - val_regr_loss: 1.4224 - val_clf_loss: 0.7465 - val_regr_mae: 0.8791 - val_clf_accuracy: 0.5000
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 24/25 [===========================>..] - ETA: 0s - loss: 13.0643 - regr_loss: 1.2874 - clf_loss: 0.6765 - regr_mae: 0.8767 - clf_accuracy: 0.6094
# Epoch 00011: val_loss improved from 13.42696 to 13.40059, saving model to models\conv1d_multivar\multitask\11.hdf5
# 25/25 [==============================] - 4s 146ms/step - loss: 13.0759 - regr_loss: 1.2956 - clf_loss: 0.6727 - regr_mae: 0.8797 - clf_accuracy: 0.6162 - val_loss: 13.4006 - val_regr_loss: 1.4325 - val_clf_loss: 0.7493 - val_regr_mae: 0.8702 - val_clf_accuracy: 0.5000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 24/25 [===========================>..] - ETA: 0s - loss: 12.3666 - regr_loss: 0.9685 - clf_loss: 0.6666 - regr_mae: 0.8056 - clf_accuracy: 0.6667
# Epoch 00012: val_loss did not improve from 13.40059
# 25/25 [==============================] - 4s 143ms/step - loss: 12.5744 - regr_loss: 1.0761 - clf_loss: 0.6621 - regr_mae: 0.8230 - clf_accuracy: 0.6667 - val_loss: 13.4268 - val_regr_loss: 1.4721 - val_clf_loss: 0.7467 - val_regr_mae: 0.8872 - val_clf_accuracy: 0.5500
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 24/25 [===========================>..] - ETA: 0s - loss: 12.8944 - regr_loss: 1.2599 - clf_loss: 0.6617 - regr_mae: 0.8740 - clf_accuracy: 0.6406
# Epoch 00013: val_loss improved from 13.40059 to 13.32284, saving model to models\conv1d_multivar\multitask\13.hdf5
# 25/25 [==============================] - 4s 142ms/step - loss: 12.8508 - regr_loss: 1.2409 - clf_loss: 0.6568 - regr_mae: 0.8713 - clf_accuracy: 0.6465 - val_loss: 13.3228 - val_regr_loss: 1.4453 - val_clf_loss: 0.7467 - val_regr_mae: 0.8862 - val_clf_accuracy: 0.5500
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 24/25 [===========================>..] - ETA: 0s - loss: 12.6058 - regr_loss: 1.1535 - clf_loss: 0.6364 - regr_mae: 0.8413 - clf_accuracy: 0.6094
# Epoch 00014: val_loss did not improve from 13.32284
# 25/25 [==============================] - 3s 138ms/step - loss: 12.5777 - regr_loss: 1.1407 - clf_loss: 0.6346 - regr_mae: 0.8411 - clf_accuracy: 0.6111 - val_loss: 13.4027 - val_regr_loss: 1.5048 - val_clf_loss: 0.7576 - val_regr_mae: 0.9263 - val_clf_accuracy: 0.6000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 24/25 [===========================>..] - ETA: 0s - loss: 12.6543 - regr_loss: 1.1894 - clf_loss: 0.6520 - regr_mae: 0.8506 - clf_accuracy: 0.6458
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 2.5000001187436283e-05.
#
# Epoch 00015: val_loss did not improve from 13.32284
# 25/25 [==============================] - 3s 140ms/step - loss: 12.7277 - regr_loss: 1.2279 - clf_loss: 0.6497 - regr_mae: 0.8605 - clf_accuracy: 0.6465 - val_loss: 13.3440 - val_regr_loss: 1.4870 - val_clf_loss: 0.7607 - val_regr_mae: 0.9204 - val_clf_accuracy: 0.5500
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 16/32
# 24/25 [===========================>..] - ETA: 0s - loss: 12.6138 - regr_loss: 1.1765 - clf_loss: 0.6539 - regr_mae: 0.8646 - clf_accuracy: 0.6146
# Epoch 00016: val_loss did not improve from 13.32284
# 25/25 [==============================] - 3s 138ms/step - loss: 12.5806 - regr_loss: 1.1596 - clf_loss: 0.6543 - regr_mae: 0.8640 - clf_accuracy: 0.6162 - val_loss: 13.3574 - val_regr_loss: 1.4953 - val_clf_loss: 0.7629 - val_regr_mae: 0.9217 - val_clf_accuracy: 0.5500
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 17/32
# 24/25 [===========================>..] - ETA: 0s - loss: 12.2697 - regr_loss: 1.0103 - clf_loss: 0.6478 - regr_mae: 0.7930 - clf_accuracy: 0.6510
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00017: val_loss did not improve from 13.32284
# 25/25 [==============================] - 3s 136ms/step - loss: 12.2239 - regr_loss: 0.9925 - clf_loss: 0.6372 - regr_mae: 0.7854 - clf_accuracy: 0.6616 - val_loss: 13.3717 - val_regr_loss: 1.5040 - val_clf_loss: 0.7654 - val_regr_mae: 0.9226 - val_clf_accuracy: 0.5500
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 9.999999747378752e-06.
# Epoch 18/32
# 24/25 [===========================>..] - ETA: 0s - loss: 12.3519 - regr_loss: 1.0328 - clf_loss: 0.6889 - regr_mae: 0.7765 - clf_accuracy: 0.5781
# Epoch 00018: val_loss did not improve from 13.32284
# 25/25 [==============================] - 4s 140ms/step - loss: 12.3530 - regr_loss: 1.0341 - clf_loss: 0.6875 - regr_mae: 0.7782 - clf_accuracy: 0.5808 - val_loss: 13.3455 - val_regr_loss: 1.4909 - val_clf_loss: 0.7675 - val_regr_mae: 0.9173 - val_clf_accuracy: 0.5500
# Epoch 00018: early stopping

# %%
def plot_multitask_history(hist):
    fig, ax = plt.subplots(2, 2, figsize=(16, 12))
    plotHelpers.plot_train_history(ax[0, 0], hist, 'Total loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[0, 1], hist, 'Accuracy', 'clf_accuracy', 'val_clf_accuracy')
    plotHelpers.plot_train_history(ax[1, 0], hist, 'MSE', 'regr_loss', 'val_regr_loss')
    plotHelpers.plot_train_history(ax[1, 1], hist, 'MAE', 'regr_mae', 'val_regr_mae')
    
plot_multitask_history(multitask_history);

# %% [markdown]
# ### Прогноз

# %%
# загружаем последнюю эпоху с минимальным лоссом
multivariate_multitask_conv1d.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret, pred_direction_proba = multivariate_multitask_conv1d.predict_generator(test_multi_gen, verbose=1)
# Out:
# 2/2 [==============================] - 0s 39ms/step

# %%
np.set_printoptions(precision=3, suppress=True)

np.column_stack([pred_log_ret, pred_direction_proba])[-10:]
# Out:
# array([[ 0.354,  0.549],
#        [ 0.561,  0.647],
#        [ 0.746,  0.672],
#        [ 0.422,  0.657],
#        [ 0.207,  0.581],
#        [ 0.299,  0.531],
#        [ 0.185,  0.536],
#        [-0.182,  0.511],
#        [-0.429,  0.527],
#        [-0.077,  0.526]], dtype=float32)

# %% [markdown]
# #### Прогноз задачи регрессии

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret, figsize=(16, 10), datetime_unit='D')

# %% [markdown]
# #### Прогноз задачи классификации

# %% [markdown]
# *Разделяющая способность по-прежнему слабая*

# %%
true_direction = test_multi_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 0.585599

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([9, 6], dtype=int64)),
#  (array([0, 1]), array([9, 6], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67         9
#            1       0.50      0.50      0.50         6
#
#     accuracy                           0.60        15
#    macro avg       0.58      0.58      0.58        15
# weighted avg       0.60      0.60      0.60        15

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[6, 3],
#        [3, 3]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.667, 0.5  ],
#        [0.333, 0.5  ]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# # Выводы
#
# 1.  Модель с 1D свёртками обучается гораздо быстрее модели LSTM
# 2.  Точность классификации выше, чем у аналогичной одномерной модели.

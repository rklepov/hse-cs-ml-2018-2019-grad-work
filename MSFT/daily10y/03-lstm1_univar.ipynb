# %% [markdown]
# <a href="https://colab.research.google.com/github/rklepov/hse-cs-ml-2018-2019-grad-work/blob/MSFT-10yr/MSFT/daily10y/03-lstm1_univar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # *Одномерная модель на LSTM* (1 слой)
#
# В качестве единственного признака используется сама цена.

# %%
import os
import glob
import datetime
import pickle

import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from pandas_datareader import data as pdr

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
tf.__version__
# Out:
# '2.2.0-rc2'

# %%
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Input, Dense, LSTM, GRU, Flatten, ReLU, LeakyReLU, Dropout, BatchNormalization
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers import Nadam

# %%
from mdp import TimeSeries
from mdp import MarketData
from mdp import MovingWindowFeatures
from mdp import ClassificationGenerator, RegressionGenerator, MultitaskGenerator
from mdp import invert_log_ret

import mdp.utils as utils
import mdp.plotHelpers as plotHelpers

# %%
import importlib

import mdp

importlib.reload(mdp)
importlib.reload(mdp.datasetGenerator)
importlib.reload(mdp.marketData)
importlib.reload(mdp.movingWindowFeatures)
importlib.reload(mdp.timeSeries)
importlib.reload(mdp.plotHelpers)
importlib.reload(mdp.utils);

# %% [markdown]
# # *Параметры*

# %%
INSTRUMENT = 'MSFT' # Microsoft corp
START_FROM = '2008-11-14'
END_DATE = '2020-01-01'
WINDOW_SIZE = 60
FORECAST_OFFSET=1
BATCH_SIZE = 32
VAL_SPLIT = '2019-01-01'
TEST_SPLIT = '2019-06-01'
FORCE_TRAIN = True

# %% [markdown]
# # *Исходные данные*
#
# Загрузка данных и вычисление индикаторов.

# %%
instr = MarketData.create_from_tiingo(INSTRUMENT, start=START_FROM, end=END_DATE)

# %%
instr.feature_names
# Out:
# ['o',
#  'h',
#  'l',
#  'c',
#  'v',
#  'ema14',
#  'ema30',
#  'macd',
#  'macd_signal',
#  'rsi14',
#  'bband20_upper',
#  'bband20_middle',
#  'bband20_lower',
#  'willr14',
#  'stochk',
#  'stochd',
#  'adline',
#  'adosc']

# %% [markdown]
# ## Целевая переменная

# %% [markdown]
# Цена закрытия.

# %%
orig_target = instr.c

# %%
def plot_transformed_series(instrument, series, orig_display_name, transformed_display_name):
    plotHelpers.plot_transformed_timeseries(
        instrument.instrument,
        series,
        title_orig = orig_display_name,
        xlabel_orig = 'Date',
        ylabel_orig = orig_display_name,
        title_transformed = transformed_display_name,
        xlabel_transformed = 'Date',
        ylabel_transformed = transformed_display_name
    )

# %% [markdown]
# Переходим к логарифмической доходности.

# %%
transformed_target = instr.c.transform(transforms={'ratios' : {}, 'ln' : {}})

# %%
plot_transformed_series(instr,
                        transformed_target,
                        'Daily close price, USD', 'Daily log return')

# %% [markdown]
# ## Трансформация признаков
#
# Выбираем только один признак: цену закрытия.
# Временной ряд цены преобразуется к логарифмической доходности (что также позволяет убрать нестационарность).

# %%
def make_feature_selector():
    price_transformer = lambda: {'ratios': {}, 'ln': {}}
    diff_transformer = lambda o: {'diffs': {'order': o}}
    identity_transformer = lambda: {}
    feature_transformations = {
        'c': price_transformer(),
    }
    return feature_transformations

# %%
instr_transformed = instr.select_transform(make_feature_selector())

# %%
transformed_target = instr_transformed.c

# %% [markdown]
# ## Обучающая, валидационная и тестовая выборки

# %%
instr_train, instr_val_test = instr_transformed.train_test_split(VAL_SPLIT, window_size=WINDOW_SIZE,
                                                                 scaler=StandardScaler)
#                                                                  scaler=MinMaxScaler,
#                                                                  scaler_kwargs={'feature_range': (-1, 1)})

instr_val, instr_test = instr_val_test.train_test_split(TEST_SPLIT, window_size=WINDOW_SIZE, scaler=None)

len(instr_train), len(instr_val), len(instr_test)
# Out:
# (2514, 164, 208)

# %% [markdown]
# ## Признаки - скользящие окна

# %%
train_mwf = MovingWindowFeatures.create(instr_train.c, [instr_train], instr_train.feature_names, window_size=WINDOW_SIZE)
val_mwf = MovingWindowFeatures.create(instr_val.c, [instr_val], instr_val.feature_names, window_size=WINDOW_SIZE)
test_mwf = MovingWindowFeatures.create(instr_test.c, [instr_test], instr_test.feature_names, window_size=WINDOW_SIZE)

len(instr_train), len(train_mwf), train_mwf.features.shape
# Out:
# (2514, 2454, (2454, 60, 1))

# %% [markdown]
# Проверка, что скользящие окна соответствуют исходным данным.
#
# Возьмём произвольный признак и произвольное окно (строка #**41**). Проверим, что данные в точности совпадают:

# %%
def check_data(md, mwf, row):
    col = np.random.randint(len(mwf.feature_names))
    feature = mwf.feature_names[col]
    check = (getattr(md, feature).data[row:row + mwf.window_size] == mwf.features[row, :, col]).all()
    assert check
    return feature, check

check_data(instr_train, train_mwf, 41)
# Out:
# ('c', True)

# %% [markdown]
# # *Модели*

# %% [markdown]
# Модель с одним LSTM слоем.

# %%
def build_lstm_layers(input_shape, latent_dim=16):
    # формат входа: матрица (окно; признак)
    inp = Input(input_shape, name='input')

    lstm = LSTM(latent_dim, return_sequences=True,
                    recurrent_dropout=0.2, dropout=0.2,
                    bias_initializer='he_uniform',
                    bias_regularizer=L1L2(0.01, 0.02),
                    kernel_regularizer=L1L2(0.01, 0.02),
                    recurrent_regularizer=L1L2(0.01, 0.02)
               )(inp)
    
    lstm = Flatten()(lstm)
    
    return inp, lstm

# %% [markdown]
# #### Пути сохранения моделей:

# %%
model_path_root = 'models'
model_type_name = 'lstm1_univar'

def make_model_save_dir(path_root, type_name, class_name):
    save_dir = os.path.join(path_root, type_name, class_name)
    os.makedirs(save_dir, exist_ok=True)
    return save_dir

# %% [markdown]
# #### Общие коллбэки:

# %%
# уменьшение learning rate в случае, если loss не изменяется
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001, verbose=1)

# уменьшение learning rate в 2 раза каждую 5-ю эпоху
def lr_decay(e, lr):
    return lr * (1 - 0.5 * (0 == (e + 1) % 5))

lr_scheduler = LearningRateScheduler(schedule=lr_decay, verbose=1)

# %% [markdown]
# ## Задача регрессии
#
# Непосредственное прогнозирование цены следующего периода.

# %%
train_regr_gen = RegressionGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_regr_gen = RegressionGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_regr_gen = RegressionGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# Следующие числа соответствуют значению параметра `steps_per_epoch` метода [`fit_generator`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit_generator "tf.keras.layers.SimpleRNN &nbsp;|&nbsp; TensorFlow Core r2.0") - то есть это число батчей, которые генератор выдаст за одну эпоху обучения (если класс генератора поддерживает метод `len()`, то данный параметр можно не указывать).

# %%
len(train_regr_gen), len(val_regr_gen), len(test_regr_gen)
# Out:
# (77, 4, 5)

# %% [markdown]
# Один сэмпл данных представляет собой матрицу размером *(длина окна; число признаков)*

# %%
train_regr_gen.input_shape
# Out:
# (60, 1)

# %% [markdown]
# ### Модель для задачи регрессии

# %%
model_class_name = 'regression'

# %%
def build_regression_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=16)

    regr = Dense(32)(lstm)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    return Model(inputs=[inp], outputs=[regr])

# %%
univariate_regression_lstm = build_regression_model(train_regr_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:
# [`Nadam`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Nadam) (*Adam with Nestrov momentum*).

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Функция потерь:
#
# В качестве функции потерь будем использовать [MSE](https://www.tensorflow.org/api_docs/python/tf/keras/losses/MSE) (чтобы штрафовать за большие отклонения). Xотя хорошая функция потерь в контексте темы данной задачи - это [вопрос сложный](https://github.com/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Chapter5_LossFunctions/Ch5_LossFunctions_PyMC3.ipynb). В частности, здесь нам, очевидно, помимо абсолютного значения отклонения также важен его знак.

# %%
univariate_regression_lstm.compile(optimizer=optimizer,
                                   loss={'regr': 'mse'},
                                   metrics={'regr': 'mae'})

univariate_regression_lstm.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 60, 1)]           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 60, 16)            1152
# _________________________________________________________________
# flatten (Flatten)            (None, 960)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                30752
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32)                128
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 32)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# regr (Dense)                 (None, 1)                 33
# =================================================================
# Total params: 32,065
# Trainable params: 32,001
# Non-trainable params: 64
# _________________________________________________________________

# %% [markdown]
# #### Обучение:

# %%
regr_history = utils.train_model(univariate_regression_lstm,
                                 model_save_dir, train_regr_gen, val_regr_gen,
                                 callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                 force_train=FORCE_TRAIN, verbose=1)
# Out:
# WARNING:tensorflow:From /content/hse-cs-ml-2018-2019-grad-work/mdp/utils.py:79: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 77/77 [==============================] - ETA: 0s - loss: 3.8354 - mae: 1.0559
# Epoch 00001: val_loss improved from inf to 2.26097, saving model to models/lstm1_univar/regression/01.hdf5
# 77/77 [==============================] - 4s 54ms/step - loss: 3.8354 - mae: 1.0559 - val_loss: 2.2610 - val_mae: 0.6693 - lr: 0.0010
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 77/77 [==============================] - ETA: 0s - loss: 2.8147 - mae: 0.9150
# Epoch 00002: val_loss improved from 2.26097 to 1.76701, saving model to models/lstm1_univar/regression/02.hdf5
# 77/77 [==============================] - 4s 48ms/step - loss: 2.8147 - mae: 0.9150 - val_loss: 1.7670 - val_mae: 0.6437 - lr: 0.0010
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 76/77 [============================>.] - ETA: 0s - loss: 2.1871 - mae: 0.8306
# Epoch 00003: val_loss improved from 1.76701 to 1.44990, saving model to models/lstm1_univar/regression/03.hdf5
# 77/77 [==============================] - 4s 49ms/step - loss: 2.1963 - mae: 0.8332 - val_loss: 1.4499 - val_mae: 0.6462 - lr: 0.0010
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 77/77 [==============================] - ETA: 0s - loss: 1.7838 - mae: 0.7598
# Epoch 00004: val_loss improved from 1.44990 to 1.23694, saving model to models/lstm1_univar/regression/04.hdf5
# 77/77 [==============================] - 4s 49ms/step - loss: 1.7838 - mae: 0.7598 - val_loss: 1.2369 - val_mae: 0.6484 - lr: 0.0010
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 77/77 [==============================] - ETA: 0s - loss: 1.5475 - mae: 0.7298
# Epoch 00005: val_loss improved from 1.23694 to 1.22293, saving model to models/lstm1_univar/regression/05.hdf5
# 77/77 [==============================] - 4s 49ms/step - loss: 1.5475 - mae: 0.7298 - val_loss: 1.2229 - val_mae: 0.7004 - lr: 5.0000e-04
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 77/77 [==============================] - ETA: 0s - loss: 1.4454 - mae: 0.7123
# Epoch 00006: val_loss improved from 1.22293 to 1.10928, saving model to models/lstm1_univar/regression/06.hdf5
# 77/77 [==============================] - 4s 52ms/step - loss: 1.4454 - mae: 0.7123 - val_loss: 1.1093 - val_mae: 0.6612 - lr: 5.0000e-04
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 77/77 [==============================] - ETA: 0s - loss: 1.3320 - mae: 0.6908
# Epoch 00007: val_loss improved from 1.10928 to 1.07975, saving model to models/lstm1_univar/regression/07.hdf5
# 77/77 [==============================] - 4s 50ms/step - loss: 1.3320 - mae: 0.6908 - val_loss: 1.0797 - val_mae: 0.6842 - lr: 5.0000e-04
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.2745 - mae: 0.6813
# Epoch 00008: val_loss improved from 1.07975 to 1.01909, saving model to models/lstm1_univar/regression/08.hdf5
# 77/77 [==============================] - 4s 49ms/step - loss: 1.2897 - mae: 0.6849 - val_loss: 1.0191 - val_mae: 0.6483 - lr: 5.0000e-04
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 77/77 [==============================] - ETA: 0s - loss: 1.2312 - mae: 0.6799
# Epoch 00009: val_loss improved from 1.01909 to 0.96018, saving model to models/lstm1_univar/regression/09.hdf5
# 77/77 [==============================] - 4s 49ms/step - loss: 1.2312 - mae: 0.6799 - val_loss: 0.9602 - val_mae: 0.6399 - lr: 5.0000e-04
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 77/77 [==============================] - ETA: 0s - loss: 1.1613 - mae: 0.6606
# Epoch 00010: val_loss improved from 0.96018 to 0.94547, saving model to models/lstm1_univar/regression/10.hdf5
# 77/77 [==============================] - 4s 49ms/step - loss: 1.1613 - mae: 0.6606 - val_loss: 0.9455 - val_mae: 0.6478 - lr: 2.5000e-04
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 77/77 [==============================] - ETA: 0s - loss: 1.1470 - mae: 0.6606
# Epoch 00011: val_loss improved from 0.94547 to 0.92765, saving model to models/lstm1_univar/regression/11.hdf5
# 77/77 [==============================] - 4s 51ms/step - loss: 1.1470 - mae: 0.6606 - val_loss: 0.9276 - val_mae: 0.6590 - lr: 2.5000e-04
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.1396 - mae: 0.6629
# Epoch 00012: val_loss improved from 0.92765 to 0.92009, saving model to models/lstm1_univar/regression/12.hdf5
# 77/77 [==============================] - 4s 50ms/step - loss: 1.1329 - mae: 0.6613 - val_loss: 0.9201 - val_mae: 0.6643 - lr: 2.5000e-04
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.1191 - mae: 0.6618
# Epoch 00013: val_loss improved from 0.92009 to 0.91577, saving model to models/lstm1_univar/regression/13.hdf5
# 77/77 [==============================] - 4s 49ms/step - loss: 1.1138 - mae: 0.6607 - val_loss: 0.9158 - val_mae: 0.6584 - lr: 2.5000e-04
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0998 - mae: 0.6637
# Epoch 00014: val_loss did not improve from 0.91577
# 77/77 [==============================] - 4s 51ms/step - loss: 1.0998 - mae: 0.6637 - val_loss: 0.9405 - val_mae: 0.6975 - lr: 2.5000e-04
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0863 - mae: 0.6585
# Epoch 00015: val_loss improved from 0.91577 to 0.88763, saving model to models/lstm1_univar/regression/15.hdf5
# 77/77 [==============================] - 4s 51ms/step - loss: 1.0863 - mae: 0.6585 - val_loss: 0.8876 - val_mae: 0.6619 - lr: 1.2500e-04
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0809 - mae: 0.6575
# Epoch 00016: val_loss improved from 0.88763 to 0.87642, saving model to models/lstm1_univar/regression/16.hdf5
# 77/77 [==============================] - 4s 50ms/step - loss: 1.0809 - mae: 0.6575 - val_loss: 0.8764 - val_mae: 0.6559 - lr: 1.2500e-04
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.0751 - mae: 0.6594
# Epoch 00017: val_loss improved from 0.87642 to 0.87067, saving model to models/lstm1_univar/regression/17.hdf5
# 77/77 [==============================] - 4s 51ms/step - loss: 1.0718 - mae: 0.6592 - val_loss: 0.8707 - val_mae: 0.6560 - lr: 1.2500e-04
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0580 - mae: 0.6547
# Epoch 00018: val_loss improved from 0.87067 to 0.86811, saving model to models/lstm1_univar/regression/18.hdf5
# 77/77 [==============================] - 4s 50ms/step - loss: 1.0580 - mae: 0.6547 - val_loss: 0.8681 - val_mae: 0.6541 - lr: 1.2500e-04
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0618 - mae: 0.6611
# Epoch 00019: val_loss improved from 0.86811 to 0.86581, saving model to models/lstm1_univar/regression/19.hdf5
# 77/77 [==============================] - 4s 51ms/step - loss: 1.0618 - mae: 0.6611 - val_loss: 0.8658 - val_mae: 0.6545 - lr: 1.2500e-04
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0461 - mae: 0.6554
# Epoch 00020: val_loss improved from 0.86581 to 0.85717, saving model to models/lstm1_univar/regression/20.hdf5
# 77/77 [==============================] - 4s 51ms/step - loss: 1.0461 - mae: 0.6554 - val_loss: 0.8572 - val_mae: 0.6527 - lr: 6.2500e-05
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.0519 - mae: 0.6563
# Epoch 00021: val_loss improved from 0.85717 to 0.85456, saving model to models/lstm1_univar/regression/21.hdf5
# 77/77 [==============================] - 4s 50ms/step - loss: 1.0476 - mae: 0.6554 - val_loss: 0.8546 - val_mae: 0.6549 - lr: 6.2500e-05
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0468 - mae: 0.6560
# Epoch 00022: val_loss did not improve from 0.85456
# 77/77 [==============================] - 4s 51ms/step - loss: 1.0468 - mae: 0.6560 - val_loss: 0.8549 - val_mae: 0.6567 - lr: 6.2500e-05
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0285 - mae: 0.6525
# Epoch 00023: val_loss improved from 0.85456 to 0.85427, saving model to models/lstm1_univar/regression/23.hdf5
# 77/77 [==============================] - 4s 51ms/step - loss: 1.0285 - mae: 0.6525 - val_loss: 0.8543 - val_mae: 0.6598 - lr: 6.2500e-05
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0371 - mae: 0.6553
# Epoch 00024: val_loss improved from 0.85427 to 0.85324, saving model to models/lstm1_univar/regression/24.hdf5
# 77/77 [==============================] - 4s 51ms/step - loss: 1.0371 - mae: 0.6553 - val_loss: 0.8532 - val_mae: 0.6623 - lr: 6.2500e-05
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0511 - mae: 0.6551
# Epoch 00025: val_loss improved from 0.85324 to 0.85002, saving model to models/lstm1_univar/regression/25.hdf5
# 77/77 [==============================] - 4s 53ms/step - loss: 1.0511 - mae: 0.6551 - val_loss: 0.8500 - val_mae: 0.6599 - lr: 3.1250e-05
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0312 - mae: 0.6564
# Epoch 00026: val_loss improved from 0.85002 to 0.84746, saving model to models/lstm1_univar/regression/26.hdf5
# 77/77 [==============================] - 4s 54ms/step - loss: 1.0312 - mae: 0.6564 - val_loss: 0.8475 - val_mae: 0.6592 - lr: 3.1250e-05
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0380 - mae: 0.6576
# Epoch 00027: val_loss improved from 0.84746 to 0.84709, saving model to models/lstm1_univar/regression/27.hdf5
# 77/77 [==============================] - 4s 50ms/step - loss: 1.0380 - mae: 0.6576 - val_loss: 0.8471 - val_mae: 0.6607 - lr: 3.1250e-05
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0325 - mae: 0.6548
# Epoch 00028: val_loss improved from 0.84709 to 0.84483, saving model to models/lstm1_univar/regression/28.hdf5
# 77/77 [==============================] - 4s 49ms/step - loss: 1.0325 - mae: 0.6548 - val_loss: 0.8448 - val_mae: 0.6587 - lr: 3.1250e-05
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.0196 - mae: 0.6530
# Epoch 00029: val_loss improved from 0.84483 to 0.84444, saving model to models/lstm1_univar/regression/29.hdf5
# 77/77 [==============================] - 4s 51ms/step - loss: 1.0226 - mae: 0.6537 - val_loss: 0.8444 - val_mae: 0.6592 - lr: 3.1250e-05
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.0309 - mae: 0.6537
# Epoch 00030: val_loss did not improve from 0.84444
# 77/77 [==============================] - 4s 51ms/step - loss: 1.0306 - mae: 0.6541 - val_loss: 0.8447 - val_mae: 0.6608 - lr: 1.5625e-05
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.0208 - mae: 0.6493
# Epoch 00031: val_loss improved from 0.84444 to 0.84399, saving model to models/lstm1_univar/regression/31.hdf5
# 77/77 [==============================] - 4s 51ms/step - loss: 1.0184 - mae: 0.6495 - val_loss: 0.8440 - val_mae: 0.6610 - lr: 1.5625e-05
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0229 - mae: 0.6508
# Epoch 00032: val_loss improved from 0.84399 to 0.84240, saving model to models/lstm1_univar/regression/32.hdf5
# 77/77 [==============================] - 4s 54ms/step - loss: 1.0229 - mae: 0.6508 - val_loss: 0.8424 - val_mae: 0.6590 - lr: 1.5625e-05

# %%
def plot_regr_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'MSE', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'MAE', 'mae', 'val_mae')
    
plot_regr_history(regr_history);

# %% [markdown]
# ### Прогноз задачи регрессии

# %% [markdown]
# *Судя по всему, просто выходит на модель случайного блуждания*.

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_regression_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret_test = univariate_regression_lstm.predict_generator(test_regr_gen, verbose=1)
# Out:
# WARNING:tensorflow:From <ipython-input-39-c831dcaf40ce>:1: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.
# 5/5 [==============================] - 0s 6ms/step

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret_test, figsize=(16, 20))

# %% [markdown]
# ## Задача классификации
#
# Прогнозируем направление изменения цены по сравнению с предыдущим периодом (**0** - снижение, **1** - рост).

# %%
model_class_name = 'classification'

# %%
train_clf_gen = ClassificationGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_clf_gen = ClassificationGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_clf_gen = ClassificationGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_classification_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=16)

    clf = Dense(32)(lstm)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)

    return Model(inputs=[inp], outputs=[clf])

# %%
univariate_classification_lstm = build_classification_model(test_clf_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
univariate_classification_lstm.compile(optimizer=optimizer,
                                         loss={'clf': 'binary_crossentropy'},
                                         metrics={'clf': 'accuracy'})

univariate_classification_lstm.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 60, 1)]           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 60, 16)            1152
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 960)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                30752
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32)                128
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 32)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# clf (Dense)                  (None, 1)                 33
# =================================================================
# Total params: 32,065
# Trainable params: 32,001
# Non-trainable params: 64
# _________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
clf_history = utils.train_model(univariate_classification_lstm,
                                model_save_dir, train_clf_gen, val_clf_gen,
                                callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 77/77 [==============================] - ETA: 0s - loss: 2.5554 - accuracy: 0.5061
# Epoch 00001: val_loss improved from inf to 2.07874, saving model to models/lstm1_univar/classification/01.hdf5
# 77/77 [==============================] - 4s 57ms/step - loss: 2.5554 - accuracy: 0.5061 - val_loss: 2.0787 - val_accuracy: 0.4519 - lr: 0.0010
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 77/77 [==============================] - ETA: 0s - loss: 1.8517 - accuracy: 0.5175
# Epoch 00002: val_loss improved from 2.07874 to 1.54388, saving model to models/lstm1_univar/classification/02.hdf5
# 77/77 [==============================] - 4s 52ms/step - loss: 1.8517 - accuracy: 0.5175 - val_loss: 1.5439 - val_accuracy: 0.4904 - lr: 0.0010
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 77/77 [==============================] - ETA: 0s - loss: 1.4599 - accuracy: 0.5134
# Epoch 00003: val_loss improved from 1.54388 to 1.28424, saving model to models/lstm1_univar/classification/03.hdf5
# 77/77 [==============================] - 4s 53ms/step - loss: 1.4599 - accuracy: 0.5134 - val_loss: 1.2842 - val_accuracy: 0.4712 - lr: 0.0010
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 77/77 [==============================] - ETA: 0s - loss: 1.2367 - accuracy: 0.5167
# Epoch 00004: val_loss improved from 1.28424 to 1.13109, saving model to models/lstm1_univar/classification/04.hdf5
# 77/77 [==============================] - 4s 52ms/step - loss: 1.2367 - accuracy: 0.5167 - val_loss: 1.1311 - val_accuracy: 0.4904 - lr: 0.0010
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 77/77 [==============================] - ETA: 0s - loss: 1.1183 - accuracy: 0.5265
# Epoch 00005: val_loss improved from 1.13109 to 1.06356, saving model to models/lstm1_univar/classification/05.hdf5
# 77/77 [==============================] - 4s 52ms/step - loss: 1.1183 - accuracy: 0.5265 - val_loss: 1.0636 - val_accuracy: 0.5000 - lr: 5.0000e-04
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0493 - accuracy: 0.5412
# Epoch 00006: val_loss improved from 1.06356 to 1.01909, saving model to models/lstm1_univar/classification/06.hdf5
# 77/77 [==============================] - 4s 53ms/step - loss: 1.0493 - accuracy: 0.5412 - val_loss: 1.0191 - val_accuracy: 0.5385 - lr: 5.0000e-04
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0173 - accuracy: 0.5289
# Epoch 00007: val_loss improved from 1.01909 to 0.98460, saving model to models/lstm1_univar/classification/07.hdf5
# 77/77 [==============================] - 4s 54ms/step - loss: 1.0173 - accuracy: 0.5289 - val_loss: 0.9846 - val_accuracy: 0.5000 - lr: 5.0000e-04
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 77/77 [==============================] - ETA: 0s - loss: 0.9820 - accuracy: 0.5460
# Epoch 00008: val_loss improved from 0.98460 to 0.95380, saving model to models/lstm1_univar/classification/08.hdf5
# 77/77 [==============================] - 4s 52ms/step - loss: 0.9820 - accuracy: 0.5460 - val_loss: 0.9538 - val_accuracy: 0.5769 - lr: 5.0000e-04
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 77/77 [==============================] - ETA: 0s - loss: 0.9420 - accuracy: 0.5485
# Epoch 00009: val_loss improved from 0.95380 to 0.92408, saving model to models/lstm1_univar/classification/09.hdf5
# 77/77 [==============================] - 4s 51ms/step - loss: 0.9420 - accuracy: 0.5485 - val_loss: 0.9241 - val_accuracy: 0.5865 - lr: 5.0000e-04
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 77/77 [==============================] - ETA: 0s - loss: 0.9229 - accuracy: 0.5477
# Epoch 00010: val_loss improved from 0.92408 to 0.90981, saving model to models/lstm1_univar/classification/10.hdf5
# 77/77 [==============================] - 4s 52ms/step - loss: 0.9229 - accuracy: 0.5477 - val_loss: 0.9098 - val_accuracy: 0.5385 - lr: 2.5000e-04
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 77/77 [==============================] - ETA: 0s - loss: 0.9031 - accuracy: 0.5477
# Epoch 00011: val_loss improved from 0.90981 to 0.89851, saving model to models/lstm1_univar/classification/11.hdf5
# 77/77 [==============================] - 4s 52ms/step - loss: 0.9031 - accuracy: 0.5477 - val_loss: 0.8985 - val_accuracy: 0.5000 - lr: 2.5000e-04
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 77/77 [==============================] - ETA: 0s - loss: 0.8860 - accuracy: 0.5550
# Epoch 00012: val_loss improved from 0.89851 to 0.88472, saving model to models/lstm1_univar/classification/12.hdf5
# 77/77 [==============================] - 4s 53ms/step - loss: 0.8860 - accuracy: 0.5550 - val_loss: 0.8847 - val_accuracy: 0.5096 - lr: 2.5000e-04
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 77/77 [==============================] - ETA: 0s - loss: 0.8702 - accuracy: 0.5595
# Epoch 00013: val_loss improved from 0.88472 to 0.87282, saving model to models/lstm1_univar/classification/13.hdf5
# 77/77 [==============================] - 4s 55ms/step - loss: 0.8702 - accuracy: 0.5595 - val_loss: 0.8728 - val_accuracy: 0.5577 - lr: 2.5000e-04
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 77/77 [==============================] - ETA: 0s - loss: 0.8693 - accuracy: 0.5530
# Epoch 00014: val_loss improved from 0.87282 to 0.86116, saving model to models/lstm1_univar/classification/14.hdf5
# 77/77 [==============================] - 4s 54ms/step - loss: 0.8693 - accuracy: 0.5530 - val_loss: 0.8612 - val_accuracy: 0.5192 - lr: 2.5000e-04
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 76/77 [============================>.] - ETA: 0s - loss: 0.8469 - accuracy: 0.5683
# Epoch 00015: val_loss improved from 0.86116 to 0.85435, saving model to models/lstm1_univar/classification/15.hdf5
# 77/77 [==============================] - 4s 53ms/step - loss: 0.8472 - accuracy: 0.5668 - val_loss: 0.8544 - val_accuracy: 0.5192 - lr: 1.2500e-04
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 77/77 [==============================] - ETA: 0s - loss: 0.8512 - accuracy: 0.5534
# Epoch 00016: val_loss improved from 0.85435 to 0.85407, saving model to models/lstm1_univar/classification/16.hdf5
# 77/77 [==============================] - 4s 54ms/step - loss: 0.8512 - accuracy: 0.5534 - val_loss: 0.8541 - val_accuracy: 0.5000 - lr: 1.2500e-04
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 76/77 [============================>.] - ETA: 0s - loss: 0.8460 - accuracy: 0.5691
# Epoch 00017: val_loss improved from 0.85407 to 0.85052, saving model to models/lstm1_univar/classification/17.hdf5
# 77/77 [==============================] - 4s 51ms/step - loss: 0.8443 - accuracy: 0.5717 - val_loss: 0.8505 - val_accuracy: 0.5000 - lr: 1.2500e-04
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 77/77 [==============================] - ETA: 0s - loss: 0.8395 - accuracy: 0.5697
# Epoch 00018: val_loss improved from 0.85052 to 0.84555, saving model to models/lstm1_univar/classification/18.hdf5
# 77/77 [==============================] - 4s 51ms/step - loss: 0.8395 - accuracy: 0.5697 - val_loss: 0.8455 - val_accuracy: 0.5000 - lr: 1.2500e-04
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 76/77 [============================>.] - ETA: 0s - loss: 0.8321 - accuracy: 0.5629
# Epoch 00019: val_loss improved from 0.84555 to 0.84013, saving model to models/lstm1_univar/classification/19.hdf5
# 77/77 [==============================] - 4s 49ms/step - loss: 0.8322 - accuracy: 0.5628 - val_loss: 0.8401 - val_accuracy: 0.5096 - lr: 1.2500e-04
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 76/77 [============================>.] - ETA: 0s - loss: 0.8353 - accuracy: 0.5555
# Epoch 00020: val_loss improved from 0.84013 to 0.83938, saving model to models/lstm1_univar/classification/20.hdf5
# 77/77 [==============================] - 4s 51ms/step - loss: 0.8348 - accuracy: 0.5558 - val_loss: 0.8394 - val_accuracy: 0.5192 - lr: 6.2500e-05
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 77/77 [==============================] - ETA: 0s - loss: 0.8241 - accuracy: 0.5615
# Epoch 00021: val_loss improved from 0.83938 to 0.83665, saving model to models/lstm1_univar/classification/21.hdf5
# 77/77 [==============================] - 4s 52ms/step - loss: 0.8241 - accuracy: 0.5615 - val_loss: 0.8366 - val_accuracy: 0.5481 - lr: 6.2500e-05
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 77/77 [==============================] - ETA: 0s - loss: 0.8236 - accuracy: 0.5689
# Epoch 00022: val_loss improved from 0.83665 to 0.83488, saving model to models/lstm1_univar/classification/22.hdf5
# 77/77 [==============================] - 4s 51ms/step - loss: 0.8236 - accuracy: 0.5689 - val_loss: 0.8349 - val_accuracy: 0.5481 - lr: 6.2500e-05
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 76/77 [============================>.] - ETA: 0s - loss: 0.8279 - accuracy: 0.5625
# Epoch 00023: val_loss improved from 0.83488 to 0.83133, saving model to models/lstm1_univar/classification/23.hdf5
# 77/77 [==============================] - 4s 50ms/step - loss: 0.8273 - accuracy: 0.5636 - val_loss: 0.8313 - val_accuracy: 0.5385 - lr: 6.2500e-05
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 77/77 [==============================] - ETA: 0s - loss: 0.8169 - accuracy: 0.5672
# Epoch 00024: val_loss improved from 0.83133 to 0.82987, saving model to models/lstm1_univar/classification/24.hdf5
# 77/77 [==============================] - 4s 50ms/step - loss: 0.8169 - accuracy: 0.5672 - val_loss: 0.8299 - val_accuracy: 0.5481 - lr: 6.2500e-05
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 76/77 [============================>.] - ETA: 0s - loss: 0.8197 - accuracy: 0.5563
# Epoch 00025: val_loss improved from 0.82987 to 0.82905, saving model to models/lstm1_univar/classification/25.hdf5
# 77/77 [==============================] - 4s 51ms/step - loss: 0.8200 - accuracy: 0.5558 - val_loss: 0.8291 - val_accuracy: 0.5385 - lr: 3.1250e-05
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 77/77 [==============================] - ETA: 0s - loss: 0.8212 - accuracy: 0.5481
# Epoch 00026: val_loss improved from 0.82905 to 0.82722, saving model to models/lstm1_univar/classification/26.hdf5
# 77/77 [==============================] - 4s 51ms/step - loss: 0.8212 - accuracy: 0.5481 - val_loss: 0.8272 - val_accuracy: 0.5385 - lr: 3.1250e-05
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 77/77 [==============================] - ETA: 0s - loss: 0.8136 - accuracy: 0.5681
# Epoch 00027: val_loss improved from 0.82722 to 0.82595, saving model to models/lstm1_univar/classification/27.hdf5
# 77/77 [==============================] - 4s 51ms/step - loss: 0.8136 - accuracy: 0.5681 - val_loss: 0.8260 - val_accuracy: 0.5481 - lr: 3.1250e-05
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 77/77 [==============================] - ETA: 0s - loss: 0.8104 - accuracy: 0.5807
# Epoch 00028: val_loss improved from 0.82595 to 0.82522, saving model to models/lstm1_univar/classification/28.hdf5
# 77/77 [==============================] - 4s 50ms/step - loss: 0.8104 - accuracy: 0.5807 - val_loss: 0.8252 - val_accuracy: 0.5385 - lr: 3.1250e-05
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 77/77 [==============================] - ETA: 0s - loss: 0.8105 - accuracy: 0.5685
# Epoch 00029: val_loss improved from 0.82522 to 0.82365, saving model to models/lstm1_univar/classification/29.hdf5
# 77/77 [==============================] - 4s 53ms/step - loss: 0.8105 - accuracy: 0.5685 - val_loss: 0.8236 - val_accuracy: 0.5481 - lr: 3.1250e-05
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 77/77 [==============================] - ETA: 0s - loss: 0.8131 - accuracy: 0.5640
# Epoch 00030: val_loss improved from 0.82365 to 0.82352, saving model to models/lstm1_univar/classification/30.hdf5
# 77/77 [==============================] - 4s 51ms/step - loss: 0.8131 - accuracy: 0.5640 - val_loss: 0.8235 - val_accuracy: 0.5385 - lr: 1.5625e-05
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 77/77 [==============================] - ETA: 0s - loss: 0.8100 - accuracy: 0.5713
# Epoch 00031: val_loss improved from 0.82352 to 0.82312, saving model to models/lstm1_univar/classification/31.hdf5
# 77/77 [==============================] - 4s 49ms/step - loss: 0.8100 - accuracy: 0.5713 - val_loss: 0.8231 - val_accuracy: 0.5385 - lr: 1.5625e-05
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 77/77 [==============================] - ETA: 0s - loss: 0.8062 - accuracy: 0.5713
# Epoch 00032: val_loss improved from 0.82312 to 0.82270, saving model to models/lstm1_univar/classification/32.hdf5
# 77/77 [==============================] - 4s 50ms/step - loss: 0.8062 - accuracy: 0.5713 - val_loss: 0.8227 - val_accuracy: 0.5288 - lr: 1.5625e-05

# %%
def plot_clf_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'Loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'Accuracy', 'accuracy', 'val_accuracy')
    
plot_clf_history(clf_history);

# %% [markdown]
# ### Прогноз задачи классификации

# %% [markdown]
# *Разделяющая способность довольно слабая, вероятности обоих классов очень близки к порогу отсечения*.

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_classification_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %%
pred_direction_proba = univariate_classification_lstm.predict_generator(test_clf_gen, verbose=1)

true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 5/5 [==============================] - 0s 6ms/step
# 0.49501306

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([66, 82])), (array([0, 1]), array([76, 72])))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.43      0.50      0.46        66
#            1       0.54      0.48      0.51        82
#
#     accuracy                           0.49       148
#    macro avg       0.49      0.49      0.49       148
# weighted avg       0.49      0.49      0.49       148

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[33, 33],
#        [43, 39]])

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.43421053, 0.45833333],
#        [0.56578947, 0.54166667]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# ## Многозадачная модель: одновременно регрессия и классификация
#
# Пытаемся одновременно предсказать и значение цены, и направление изменения, предполагая, что комбинированная ошибка позволит точнее скорректировать веса рекуррентных слоёв.

# %%
model_class_name = 'multitask'

# %%
train_multi_gen = MultitaskGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_multi_gen = MultitaskGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_multi_gen = MultitaskGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_multitask_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=16)

    # первый выход: задача регрссии
    regr = Dense(32)(lstm)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    # второй выход: задача классификации
    clf = Dense(32)(lstm)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)
    
    return Model(inputs=[inp], outputs=[regr, clf])

# %%
univariate_multitask_lstm = build_multitask_model(train_multi_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
univariate_multitask_lstm.compile(optimizer=optimizer,
                                  loss={'regr': 'mse', 'clf': 'binary_crossentropy'},
                                  loss_weights={'regr': 1., 'clf': 1.},
                                  metrics={'regr': 'mae', 'clf' : 'accuracy'})

univariate_multitask_lstm.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 60, 1)]      0
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 60, 16)       1152        input[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 960)          0           lstm_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 32)           30752       flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 32)           30752       flatten_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32)           128         dense_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32)           128         dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 32)           0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 32)           0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32)           0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 32)           0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# regr (Dense)                    (None, 1)            33          dropout_2[0][0]
# __________________________________________________________________________________________________
# clf (Dense)                     (None, 1)            33          dropout_3[0][0]
# ==================================================================================================
# Total params: 62,978
# Trainable params: 62,850
# Non-trainable params: 128
# __________________________________________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
multitask_history = utils.train_model(univariate_multitask_lstm,
                                      model_save_dir, train_multi_gen, val_multi_gen,
                                      callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                      force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 77/77 [==============================] - ETA: 0s - loss: 4.6548 - regr_loss: 1.9071 - clf_loss: 0.7973 - regr_mae: 1.0559 - clf_accuracy: 0.5049
# Epoch 00001: val_loss improved from inf to 3.09451, saving model to models/lstm1_univar/multitask/01.hdf5
# 77/77 [==============================] - 4s 58ms/step - loss: 4.6548 - regr_loss: 1.9071 - clf_loss: 0.7973 - regr_mae: 1.0559 - clf_accuracy: 0.5049 - val_loss: 3.0945 - val_regr_loss: 0.6946 - val_clf_loss: 0.7068 - val_regr_mae: 0.6662 - val_clf_accuracy: 0.4519 - lr: 0.0010
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 76/77 [============================>.] - ETA: 0s - loss: 3.7521 - regr_loss: 1.5475 - clf_loss: 0.7622 - regr_mae: 0.9313 - clf_accuracy: 0.5197
# Epoch 00002: val_loss improved from 3.09451 to 2.87662, saving model to models/lstm1_univar/multitask/02.hdf5
# 77/77 [==============================] - 4s 55ms/step - loss: 3.7443 - regr_loss: 1.5427 - clf_loss: 0.7623 - regr_mae: 0.9305 - clf_accuracy: 0.5208 - val_loss: 2.8766 - val_regr_loss: 0.9896 - val_clf_loss: 0.6973 - val_regr_mae: 0.7882 - val_clf_accuracy: 0.4712 - lr: 0.0010
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 77/77 [==============================] - ETA: 0s - loss: 3.0253 - regr_loss: 1.2999 - clf_loss: 0.7321 - regr_mae: 0.8309 - clf_accuracy: 0.5277
# Epoch 00003: val_loss improved from 2.87662 to 2.18987, saving model to models/lstm1_univar/multitask/03.hdf5
# 77/77 [==============================] - 4s 53ms/step - loss: 3.0253 - regr_loss: 1.2999 - clf_loss: 0.7321 - regr_mae: 0.8309 - clf_accuracy: 0.5277 - val_loss: 2.1899 - val_regr_loss: 0.6690 - val_clf_loss: 0.6955 - val_regr_mae: 0.6387 - val_clf_accuracy: 0.4808 - lr: 0.0010
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 77/77 [==============================] - ETA: 0s - loss: 2.5859 - regr_loss: 1.1477 - clf_loss: 0.7323 - regr_mae: 0.7729 - clf_accuracy: 0.5244
# Epoch 00004: val_loss improved from 2.18987 to 2.03993, saving model to models/lstm1_univar/multitask/04.hdf5
# 77/77 [==============================] - 4s 52ms/step - loss: 2.5859 - regr_loss: 1.1477 - clf_loss: 0.7323 - regr_mae: 0.7729 - clf_accuracy: 0.5244 - val_loss: 2.0399 - val_regr_loss: 0.7530 - val_clf_loss: 0.6884 - val_regr_mae: 0.7244 - val_clf_accuracy: 0.5288 - lr: 0.0010
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 77/77 [==============================] - ETA: 0s - loss: 2.3002 - regr_loss: 1.0287 - clf_loss: 0.7133 - regr_mae: 0.7431 - clf_accuracy: 0.5318
# Epoch 00005: val_loss improved from 2.03993 to 1.92103, saving model to models/lstm1_univar/multitask/05.hdf5
# 77/77 [==============================] - 4s 53ms/step - loss: 2.3002 - regr_loss: 1.0287 - clf_loss: 0.7133 - regr_mae: 0.7431 - clf_accuracy: 0.5318 - val_loss: 1.9210 - val_regr_loss: 0.7065 - val_clf_loss: 0.6947 - val_regr_mae: 0.6896 - val_clf_accuracy: 0.5000 - lr: 5.0000e-04
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 77/77 [==============================] - ETA: 0s - loss: 2.1911 - regr_loss: 0.9981 - clf_loss: 0.7050 - regr_mae: 0.7220 - clf_accuracy: 0.5440
# Epoch 00006: val_loss improved from 1.92103 to 1.81974, saving model to models/lstm1_univar/multitask/06.hdf5
# 77/77 [==============================] - 4s 53ms/step - loss: 2.1911 - regr_loss: 0.9981 - clf_loss: 0.7050 - regr_mae: 0.7220 - clf_accuracy: 0.5440 - val_loss: 1.8197 - val_regr_loss: 0.6696 - val_clf_loss: 0.6929 - val_regr_mae: 0.6626 - val_clf_accuracy: 0.4904 - lr: 5.0000e-04
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 77/77 [==============================] - ETA: 0s - loss: 2.1073 - regr_loss: 0.9737 - clf_loss: 0.7022 - regr_mae: 0.7088 - clf_accuracy: 0.5505
# Epoch 00007: val_loss improved from 1.81974 to 1.77485, saving model to models/lstm1_univar/multitask/07.hdf5
# 77/77 [==============================] - 4s 52ms/step - loss: 2.1073 - regr_loss: 0.9737 - clf_loss: 0.7022 - regr_mae: 0.7088 - clf_accuracy: 0.5505 - val_loss: 1.7748 - val_regr_loss: 0.6709 - val_clf_loss: 0.6981 - val_regr_mae: 0.6669 - val_clf_accuracy: 0.4904 - lr: 5.0000e-04
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 77/77 [==============================] - ETA: 0s - loss: 2.0327 - regr_loss: 0.9526 - clf_loss: 0.6978 - regr_mae: 0.7020 - clf_accuracy: 0.5538
# Epoch 00008: val_loss improved from 1.77485 to 1.72832, saving model to models/lstm1_univar/multitask/08.hdf5
# 77/77 [==============================] - 4s 54ms/step - loss: 2.0327 - regr_loss: 0.9526 - clf_loss: 0.6978 - regr_mae: 0.7020 - clf_accuracy: 0.5538 - val_loss: 1.7283 - val_regr_loss: 0.6769 - val_clf_loss: 0.6917 - val_regr_mae: 0.6697 - val_clf_accuracy: 0.5481 - lr: 5.0000e-04
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 77/77 [==============================] - ETA: 0s - loss: 1.9725 - regr_loss: 0.9333 - clf_loss: 0.6998 - regr_mae: 0.6906 - clf_accuracy: 0.5424
# Epoch 00009: val_loss did not improve from 1.72832
# 77/77 [==============================] - 4s 50ms/step - loss: 1.9725 - regr_loss: 0.9333 - clf_loss: 0.6998 - regr_mae: 0.6906 - clf_accuracy: 0.5424 - val_loss: 1.7611 - val_regr_loss: 0.7416 - val_clf_loss: 0.6999 - val_regr_mae: 0.7148 - val_clf_accuracy: 0.5288 - lr: 5.0000e-04
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 77/77 [==============================] - ETA: 0s - loss: 1.9087 - regr_loss: 0.9127 - clf_loss: 0.6865 - regr_mae: 0.6799 - clf_accuracy: 0.5693
# Epoch 00010: val_loss improved from 1.72832 to 1.67851, saving model to models/lstm1_univar/multitask/10.hdf5
# 77/77 [==============================] - 4s 52ms/step - loss: 1.9087 - regr_loss: 0.9127 - clf_loss: 0.6865 - regr_mae: 0.6799 - clf_accuracy: 0.5693 - val_loss: 1.6785 - val_regr_loss: 0.6786 - val_clf_loss: 0.6995 - val_regr_mae: 0.6722 - val_clf_accuracy: 0.5192 - lr: 2.5000e-04
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 77/77 [==============================] - ETA: 0s - loss: 1.8943 - regr_loss: 0.9135 - clf_loss: 0.6888 - regr_mae: 0.6811 - clf_accuracy: 0.5746
# Epoch 00011: val_loss improved from 1.67851 to 1.66499, saving model to models/lstm1_univar/multitask/11.hdf5
# 77/77 [==============================] - 4s 52ms/step - loss: 1.8943 - regr_loss: 0.9135 - clf_loss: 0.6888 - regr_mae: 0.6811 - clf_accuracy: 0.5746 - val_loss: 1.6650 - val_regr_loss: 0.6789 - val_clf_loss: 0.7024 - val_regr_mae: 0.6721 - val_clf_accuracy: 0.5385 - lr: 2.5000e-04
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.8952 - regr_loss: 0.9247 - clf_loss: 0.6948 - regr_mae: 0.6837 - clf_accuracy: 0.5559
# Epoch 00012: val_loss improved from 1.66499 to 1.64215, saving model to models/lstm1_univar/multitask/12.hdf5
# 77/77 [==============================] - 4s 56ms/step - loss: 1.8942 - regr_loss: 0.9249 - clf_loss: 0.6937 - regr_mae: 0.6841 - clf_accuracy: 0.5562 - val_loss: 1.6422 - val_regr_loss: 0.6771 - val_clf_loss: 0.6975 - val_regr_mae: 0.6707 - val_clf_accuracy: 0.5288 - lr: 2.5000e-04
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 77/77 [==============================] - ETA: 0s - loss: 1.8517 - regr_loss: 0.9045 - clf_loss: 0.6871 - regr_mae: 0.6726 - clf_accuracy: 0.5599
# Epoch 00013: val_loss improved from 1.64215 to 1.61876, saving model to models/lstm1_univar/multitask/13.hdf5
# 77/77 [==============================] - 4s 52ms/step - loss: 1.8517 - regr_loss: 0.9045 - clf_loss: 0.6871 - regr_mae: 0.6726 - clf_accuracy: 0.5599 - val_loss: 1.6188 - val_regr_loss: 0.6691 - val_clf_loss: 0.6970 - val_regr_mae: 0.6576 - val_clf_accuracy: 0.5481 - lr: 2.5000e-04
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 77/77 [==============================] - ETA: 0s - loss: 1.8496 - regr_loss: 0.9099 - clf_loss: 0.6942 - regr_mae: 0.6821 - clf_accuracy: 0.5636
# Epoch 00014: val_loss improved from 1.61876 to 1.59773, saving model to models/lstm1_univar/multitask/14.hdf5
# 77/77 [==============================] - 4s 53ms/step - loss: 1.8496 - regr_loss: 0.9099 - clf_loss: 0.6942 - regr_mae: 0.6821 - clf_accuracy: 0.5636 - val_loss: 1.5977 - val_regr_loss: 0.6671 - val_clf_loss: 0.6922 - val_regr_mae: 0.6527 - val_clf_accuracy: 0.5481 - lr: 2.5000e-04
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 77/77 [==============================] - ETA: 0s - loss: 1.8052 - regr_loss: 0.8945 - clf_loss: 0.6761 - regr_mae: 0.6725 - clf_accuracy: 0.5835
# Epoch 00015: val_loss improved from 1.59773 to 1.58989, saving model to models/lstm1_univar/multitask/15.hdf5
# 77/77 [==============================] - 4s 52ms/step - loss: 1.8052 - regr_loss: 0.8945 - clf_loss: 0.6761 - regr_mae: 0.6725 - clf_accuracy: 0.5835 - val_loss: 1.5899 - val_regr_loss: 0.6685 - val_clf_loss: 0.6901 - val_regr_mae: 0.6565 - val_clf_accuracy: 0.5481 - lr: 1.2500e-04
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.8050 - regr_loss: 0.8973 - clf_loss: 0.6796 - regr_mae: 0.6714 - clf_accuracy: 0.5711
# Epoch 00016: val_loss improved from 1.58989 to 1.57810, saving model to models/lstm1_univar/multitask/16.hdf5
# 77/77 [==============================] - 4s 50ms/step - loss: 1.8005 - regr_loss: 0.8940 - clf_loss: 0.6785 - regr_mae: 0.6711 - clf_accuracy: 0.5713 - val_loss: 1.5781 - val_regr_loss: 0.6647 - val_clf_loss: 0.6887 - val_regr_mae: 0.6508 - val_clf_accuracy: 0.5385 - lr: 1.2500e-04
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 77/77 [==============================] - ETA: 0s - loss: 1.8012 - regr_loss: 0.9021 - clf_loss: 0.6776 - regr_mae: 0.6711 - clf_accuracy: 0.5656
# Epoch 00017: val_loss improved from 1.57810 to 1.57688, saving model to models/lstm1_univar/multitask/17.hdf5
# 77/77 [==============================] - 4s 52ms/step - loss: 1.8012 - regr_loss: 0.9021 - clf_loss: 0.6776 - regr_mae: 0.6711 - clf_accuracy: 0.5656 - val_loss: 1.5769 - val_regr_loss: 0.6670 - val_clf_loss: 0.6917 - val_regr_mae: 0.6546 - val_clf_accuracy: 0.5481 - lr: 1.2500e-04
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.7914 - regr_loss: 0.8903 - clf_loss: 0.6861 - regr_mae: 0.6689 - clf_accuracy: 0.5683
# Epoch 00018: val_loss improved from 1.57688 to 1.57336, saving model to models/lstm1_univar/multitask/18.hdf5
# 77/77 [==============================] - 4s 51ms/step - loss: 1.7855 - regr_loss: 0.8843 - clf_loss: 0.6862 - regr_mae: 0.6679 - clf_accuracy: 0.5685 - val_loss: 1.5734 - val_regr_loss: 0.6696 - val_clf_loss: 0.6920 - val_regr_mae: 0.6544 - val_clf_accuracy: 0.5481 - lr: 1.2500e-04
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 77/77 [==============================] - ETA: 0s - loss: 1.7717 - regr_loss: 0.8774 - clf_loss: 0.6854 - regr_mae: 0.6635 - clf_accuracy: 0.5595
# Epoch 00019: val_loss improved from 1.57336 to 1.57012, saving model to models/lstm1_univar/multitask/19.hdf5
# 77/77 [==============================] - 4s 51ms/step - loss: 1.7717 - regr_loss: 0.8774 - clf_loss: 0.6854 - regr_mae: 0.6635 - clf_accuracy: 0.5595 - val_loss: 1.5701 - val_regr_loss: 0.6738 - val_clf_loss: 0.6906 - val_regr_mae: 0.6547 - val_clf_accuracy: 0.5481 - lr: 1.2500e-04
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 77/77 [==============================] - ETA: 0s - loss: 1.7599 - regr_loss: 0.8755 - clf_loss: 0.6804 - regr_mae: 0.6676 - clf_accuracy: 0.5636
# Epoch 00020: val_loss improved from 1.57012 to 1.56505, saving model to models/lstm1_univar/multitask/20.hdf5
# 77/77 [==============================] - 4s 52ms/step - loss: 1.7599 - regr_loss: 0.8755 - clf_loss: 0.6804 - regr_mae: 0.6676 - clf_accuracy: 0.5636 - val_loss: 1.5650 - val_regr_loss: 0.6715 - val_clf_loss: 0.6910 - val_regr_mae: 0.6538 - val_clf_accuracy: 0.5577 - lr: 6.2500e-05
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.7720 - regr_loss: 0.8848 - clf_loss: 0.6861 - regr_mae: 0.6636 - clf_accuracy: 0.5584
# Epoch 00021: val_loss improved from 1.56505 to 1.56265, saving model to models/lstm1_univar/multitask/21.hdf5
# 77/77 [==============================] - 4s 54ms/step - loss: 1.7694 - regr_loss: 0.8820 - clf_loss: 0.6864 - regr_mae: 0.6624 - clf_accuracy: 0.5575 - val_loss: 1.5627 - val_regr_loss: 0.6716 - val_clf_loss: 0.6915 - val_regr_mae: 0.6525 - val_clf_accuracy: 0.5673 - lr: 6.2500e-05
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 77/77 [==============================] - ETA: 0s - loss: 1.7607 - regr_loss: 0.8777 - clf_loss: 0.6849 - regr_mae: 0.6595 - clf_accuracy: 0.5648
# Epoch 00022: val_loss improved from 1.56265 to 1.55873, saving model to models/lstm1_univar/multitask/22.hdf5
# 77/77 [==============================] - 4s 51ms/step - loss: 1.7607 - regr_loss: 0.8777 - clf_loss: 0.6849 - regr_mae: 0.6595 - clf_accuracy: 0.5648 - val_loss: 1.5587 - val_regr_loss: 0.6709 - val_clf_loss: 0.6914 - val_regr_mae: 0.6535 - val_clf_accuracy: 0.5481 - lr: 6.2500e-05
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.7619 - regr_loss: 0.8854 - clf_loss: 0.6814 - regr_mae: 0.6645 - clf_accuracy: 0.5703
# Epoch 00023: val_loss improved from 1.55873 to 1.55544, saving model to models/lstm1_univar/multitask/23.hdf5
# 77/77 [==============================] - 4s 54ms/step - loss: 1.7566 - regr_loss: 0.8795 - clf_loss: 0.6820 - regr_mae: 0.6630 - clf_accuracy: 0.5705 - val_loss: 1.5554 - val_regr_loss: 0.6704 - val_clf_loss: 0.6915 - val_regr_mae: 0.6532 - val_clf_accuracy: 0.5577 - lr: 6.2500e-05
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 77/77 [==============================] - ETA: 0s - loss: 1.7577 - regr_loss: 0.8795 - clf_loss: 0.6861 - regr_mae: 0.6662 - clf_accuracy: 0.5599
# Epoch 00024: val_loss improved from 1.55544 to 1.55215, saving model to models/lstm1_univar/multitask/24.hdf5
# 77/77 [==============================] - 4s 50ms/step - loss: 1.7577 - regr_loss: 0.8795 - clf_loss: 0.6861 - regr_mae: 0.6662 - clf_accuracy: 0.5599 - val_loss: 1.5521 - val_regr_loss: 0.6710 - val_clf_loss: 0.6906 - val_regr_mae: 0.6524 - val_clf_accuracy: 0.5769 - lr: 6.2500e-05
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 77/77 [==============================] - ETA: 0s - loss: 1.7366 - regr_loss: 0.8709 - clf_loss: 0.6760 - regr_mae: 0.6581 - clf_accuracy: 0.5823
# Epoch 00025: val_loss improved from 1.55215 to 1.55027, saving model to models/lstm1_univar/multitask/25.hdf5
# 77/77 [==============================] - 4s 50ms/step - loss: 1.7366 - regr_loss: 0.8709 - clf_loss: 0.6760 - regr_mae: 0.6581 - clf_accuracy: 0.5823 - val_loss: 1.5503 - val_regr_loss: 0.6706 - val_clf_loss: 0.6906 - val_regr_mae: 0.6525 - val_clf_accuracy: 0.5673 - lr: 3.1250e-05
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.7478 - regr_loss: 0.8816 - clf_loss: 0.6779 - regr_mae: 0.6626 - clf_accuracy: 0.5773
# Epoch 00026: val_loss improved from 1.55027 to 1.54962, saving model to models/lstm1_univar/multitask/26.hdf5
# 77/77 [==============================] - 4s 54ms/step - loss: 1.7492 - regr_loss: 0.8830 - clf_loss: 0.6780 - regr_mae: 0.6632 - clf_accuracy: 0.5770 - val_loss: 1.5496 - val_regr_loss: 0.6710 - val_clf_loss: 0.6912 - val_regr_mae: 0.6528 - val_clf_accuracy: 0.5673 - lr: 3.1250e-05
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.7447 - regr_loss: 0.8813 - clf_loss: 0.6767 - regr_mae: 0.6638 - clf_accuracy: 0.5691
# Epoch 00027: val_loss improved from 1.54962 to 1.54761, saving model to models/lstm1_univar/multitask/27.hdf5
# 77/77 [==============================] - 4s 52ms/step - loss: 1.7424 - regr_loss: 0.8799 - clf_loss: 0.6757 - regr_mae: 0.6633 - clf_accuracy: 0.5701 - val_loss: 1.5476 - val_regr_loss: 0.6703 - val_clf_loss: 0.6914 - val_regr_mae: 0.6531 - val_clf_accuracy: 0.5481 - lr: 3.1250e-05
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.7558 - regr_loss: 0.8910 - clf_loss: 0.6796 - regr_mae: 0.6618 - clf_accuracy: 0.5769
# Epoch 00028: val_loss improved from 1.54761 to 1.54530, saving model to models/lstm1_univar/multitask/28.hdf5
# 77/77 [==============================] - 4s 51ms/step - loss: 1.7481 - regr_loss: 0.8834 - clf_loss: 0.6796 - regr_mae: 0.6594 - clf_accuracy: 0.5774 - val_loss: 1.5453 - val_regr_loss: 0.6700 - val_clf_loss: 0.6909 - val_regr_mae: 0.6533 - val_clf_accuracy: 0.5481 - lr: 3.1250e-05
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 77/77 [==============================] - ETA: 0s - loss: 1.7554 - regr_loss: 0.8858 - clf_loss: 0.6859 - regr_mae: 0.6642 - clf_accuracy: 0.5534
# Epoch 00029: val_loss improved from 1.54530 to 1.54273, saving model to models/lstm1_univar/multitask/29.hdf5
# 77/77 [==============================] - 4s 52ms/step - loss: 1.7554 - regr_loss: 0.8858 - clf_loss: 0.6859 - regr_mae: 0.6642 - clf_accuracy: 0.5534 - val_loss: 1.5427 - val_regr_loss: 0.6696 - val_clf_loss: 0.6901 - val_regr_mae: 0.6535 - val_clf_accuracy: 0.5481 - lr: 3.1250e-05
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 77/77 [==============================] - ETA: 0s - loss: 1.7400 - regr_loss: 0.8809 - clf_loss: 0.6766 - regr_mae: 0.6608 - clf_accuracy: 0.5909
# Epoch 00030: val_loss improved from 1.54273 to 1.54269, saving model to models/lstm1_univar/multitask/30.hdf5
# 77/77 [==============================] - 4s 51ms/step - loss: 1.7400 - regr_loss: 0.8809 - clf_loss: 0.6766 - regr_mae: 0.6608 - clf_accuracy: 0.5909 - val_loss: 1.5427 - val_regr_loss: 0.6699 - val_clf_loss: 0.6906 - val_regr_mae: 0.6531 - val_clf_accuracy: 0.5481 - lr: 1.5625e-05
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 77/77 [==============================] - ETA: 0s - loss: 1.7358 - regr_loss: 0.8716 - clf_loss: 0.6825 - regr_mae: 0.6573 - clf_accuracy: 0.5566
# Epoch 00031: val_loss improved from 1.54269 to 1.54199, saving model to models/lstm1_univar/multitask/31.hdf5
# 77/77 [==============================] - 4s 53ms/step - loss: 1.7358 - regr_loss: 0.8716 - clf_loss: 0.6825 - regr_mae: 0.6573 - clf_accuracy: 0.5566 - val_loss: 1.5420 - val_regr_loss: 0.6696 - val_clf_loss: 0.6910 - val_regr_mae: 0.6530 - val_clf_accuracy: 0.5385 - lr: 1.5625e-05
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 76/77 [============================>.] - ETA: 0s - loss: 1.7115 - regr_loss: 0.8512 - clf_loss: 0.6792 - regr_mae: 0.6568 - clf_accuracy: 0.5670
# Epoch 00032: val_loss improved from 1.54199 to 1.54106, saving model to models/lstm1_univar/multitask/32.hdf5
# 77/77 [==============================] - 4s 51ms/step - loss: 1.7398 - regr_loss: 0.8793 - clf_loss: 0.6794 - regr_mae: 0.6593 - clf_accuracy: 0.5668 - val_loss: 1.5411 - val_regr_loss: 0.6694 - val_clf_loss: 0.6909 - val_regr_mae: 0.6533 - val_clf_accuracy: 0.5385 - lr: 1.5625e-05

# %%
def plot_multitask_history(hist):
    fig, ax = plt.subplots(2, 2, figsize=(16, 12))
    plotHelpers.plot_train_history(ax[0, 0], hist, 'Total loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[0, 1], hist, 'Accuracy', 'clf_accuracy', 'val_clf_accuracy')
    plotHelpers.plot_train_history(ax[1, 0], hist, 'MSE', 'regr_loss', 'val_regr_loss')
    plotHelpers.plot_train_history(ax[1, 1], hist, 'MAE', 'regr_mae', 'val_regr_mae')
    
plot_multitask_history(multitask_history);

# %% [markdown]
# ### Прогноз

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_multitask_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret, pred_direction_proba = univariate_multitask_lstm.predict_generator(test_multi_gen, verbose=1)
# Out:
# 5/5 [==============================] - 0s 6ms/step

# %%
np.set_printoptions(precision=3, suppress=True)

np.column_stack([pred_log_ret, pred_direction_proba])[-10:]
# Out:
# array([[-0.131,  0.423],
#        [-0.046,  0.551],
#        [ 0.025,  0.534],
#        [-0.097,  0.431],
#        [ 0.031,  0.401],
#        [-0.058,  0.47 ],
#        [-0.034,  0.445],
#        [ 0.006,  0.4  ],
#        [ 0.089,  0.552],
#        [ 0.053,  0.519]], dtype=float32)

# %% [markdown]
# #### Прогноз задачи регрессии

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret, figsize=(16, 20))

# %% [markdown]
# #### Прогноз задачи классификации

# %% [markdown]
# *Разделяющая способность по-прежнему слабая*.

# %%
true_direction = test_multi_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 0.4863872

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([66, 82])), (array([0, 1]), array([73, 75])))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.45      0.50      0.47        66
#            1       0.56      0.51      0.54        82
#
#     accuracy                           0.51       148
#    macro avg       0.51      0.51      0.50       148
# weighted avg       0.51      0.51      0.51       148

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[33, 33],
#        [40, 42]])

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.452, 0.44 ],
#        [0.548, 0.56 ]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# # Выводы
#
# 1.  Размер батча сильно влияет на скорость обучения.
# 2.  Инициализация весов (`bias_initializer`) в слое **LSTM** оказалась очень важным параметром.
# 3.  Модель регрессии пока просто выходит на модель случайного блуждания.
# 4.  Разделяющая способность модели классификации довольно низкая.
# 5.  Комбинированная (многозадачная) модель не смогла как-то улучшить качество прогнозирования по сравнению с каждой из двух однозадачных моделей.

# %% [markdown]
# <a href="https://colab.research.google.com/github/rklepov/hse-cs-ml-2018-2019-grad-work/blob/MSFT-10yr/MSFT/daily10y/05-lstm2_univar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # *Одномерная модель на LSTM* (2 слоя)
#
# В качестве единственного признака используется сама цена.

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import os
import glob
import datetime
import pickle

import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
from pandas_datareader import data as pdr

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
tf.__version__
# Out:
# '2.2.0-rc2'

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Input, Dense, LSTM, GRU, Flatten, ReLU, LeakyReLU, Dropout, BatchNormalization
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers import Nadam

# %%
from mdp import TimeSeries
from mdp import MarketData
from mdp import MovingWindowFeatures
from mdp import ClassificationGenerator, RegressionGenerator, MultitaskGenerator
from mdp import invert_log_ret

import mdp.utils as utils
import mdp.plotHelpers as plotHelpers

# %%
import importlib

import mdp

importlib.reload(mdp)
importlib.reload(mdp.datasetGenerator)
importlib.reload(mdp.marketData)
importlib.reload(mdp.movingWindowFeatures)
importlib.reload(mdp.timeSeries)
importlib.reload(mdp.plotHelpers)
importlib.reload(mdp.utils);

# %% [markdown]
# # *Параметры*

# %%
INSTRUMENT = 'MSFT' # Microsoft corp
START_FROM = '2008-11-14'
END_DATE = '2020-01-01'
WINDOW_SIZE = 60
FORECAST_OFFSET=1
BATCH_SIZE = 32
VAL_SPLIT = '2019-01-01'
TEST_SPLIT = '2019-06-01'
FORCE_TRAIN = True

# %% [markdown]
# # *Исходные данные*
#
# Загрузка данных и вычисление индикаторов.

# %%
instr = MarketData.create_from_tiingo(INSTRUMENT, start=START_FROM, end=END_DATE)

# %%
instr.feature_names
# Out:
# ['o',
#  'h',
#  'l',
#  'c',
#  'v',
#  'ema14',
#  'ema30',
#  'macd',
#  'macd_signal',
#  'rsi14',
#  'bband20_upper',
#  'bband20_middle',
#  'bband20_lower',
#  'willr14',
#  'stochk',
#  'stochd',
#  'adline',
#  'adosc']

# %% [markdown]
# ## Целевая переменная

# %% [markdown]
# Цена закрытия.

# %%
orig_target = instr.c

# %%
def plot_transformed_series(instrument, series, orig_display_name, transformed_display_name):
    plotHelpers.plot_transformed_timeseries(
        instrument.instrument,
        series,
        title_orig = orig_display_name,
        xlabel_orig = 'Date',
        ylabel_orig = orig_display_name,
        title_transformed = transformed_display_name,
        xlabel_transformed = 'Date',
        ylabel_transformed = transformed_display_name
    )

# %% [markdown]
# Переходим к логарифмической доходности.

# %%
transformed_target = instr.c.transform(transforms={'ratios' : {}, 'ln' : {}})

# %%
plot_transformed_series(instr,
                        transformed_target,
                        'Daily close price, USD', 'Daily log return')

# %% [markdown]
# ## Трансформация признаков
#
# Из признаков выбираем только цену закрытия. Временной ряд цен преобразуется к ряду логарифмических доходностей (что также позволяет убрать нестационарность).

# %%
def make_feature_selector():
    price_transformer = lambda: {'ratios': {}, 'ln': {}}
    diff_transformer = lambda o: {'diffs': {'order': o}}
    identity_transformer = lambda: {}
    feature_transformations = {
        'c': price_transformer(),
    }
    return feature_transformations

# %%
instr_transformed = instr.select_transform(make_feature_selector())

# %%
transformed_target = instr_transformed.c

# %% [markdown]
# ## Обучающая, валидационная и тестовая выборки

# %%
instr_train, instr_val_test = instr_transformed.train_test_split(VAL_SPLIT, window_size=WINDOW_SIZE,
                                                                 scaler=StandardScaler)
#                                                                  scaler=MinMaxScaler,
#                                                                  scaler_kwargs={'feature_range': (-1, 1)})

instr_val, instr_test = instr_val_test.train_test_split(TEST_SPLIT, window_size=WINDOW_SIZE, scaler=None)

len(instr_train), len(instr_val), len(instr_test)
# Out:
# (2514, 164, 208)

# %% [markdown]
# ## Признаки - скользящие окна

# %%
train_mwf = MovingWindowFeatures.create(instr_train.c, [instr_train], instr_train.feature_names, window_size=WINDOW_SIZE)
val_mwf = MovingWindowFeatures.create(instr_val.c, [instr_val], instr_val.feature_names, window_size=WINDOW_SIZE)
test_mwf = MovingWindowFeatures.create(instr_test.c, [instr_test], instr_test.feature_names, window_size=WINDOW_SIZE)

len(instr_train), len(train_mwf), train_mwf.features.shape
# Out:
# (2514, 2454, (2454, 60, 1))

# %% [markdown]
# Проверка, что скользящие окна соответствуют исходным данным.
#
# Возьмём произвольный признак и произвольное окно (строка #**41**). Проверим, что данные в точности совпадают:

# %%
def check_data(md, mwf, row):
    col = np.random.randint(len(mwf.feature_names))
    feature = mwf.feature_names[col]
    check = (getattr(md, feature).data[row:row + mwf.window_size] == mwf.features[row, :, col]).all()
    assert check
    return feature, check

check_data(instr_train, train_mwf, 41)
# Out:
# ('c', True)

# %% [markdown]
# # *Модели*

# %% [markdown]
# Модель с двумя LSTM слоями.

# %%
def build_lstm_layers(input_shape, latent_dim=(8, 16)):
    # формат входа: наша матрица (окно; признак)
    inp = Input(input_shape, name='input')

    # стекаем два уровня LSTM
    lstm = LSTM(latent_dim[0], return_sequences=True, 
                    recurrent_dropout=0.2, dropout=0.2, 
                    bias_initializer='he_uniform',
                    bias_regularizer=L1L2(0.01, 0.02),
                    kernel_regularizer=L1L2(0.01, 0.02),
                    recurrent_regularizer=L1L2(0.02, 0.02)
               )(inp)

    lstm = LSTM(latent_dim[1], return_sequences=True,
                    recurrent_dropout=0.2, dropout=0.2,
                    bias_initializer='he_uniform',
                    bias_regularizer=L1L2(0.01, 0.02),
                    kernel_regularizer=L1L2(0.01, 0.02),
                    recurrent_regularizer=L1L2(0.01, 0.02)
               )(lstm)
    
    lstm = Flatten()(lstm)
    
    return inp, lstm

# %% [markdown]
# #### Пути сохранения моделей:

# %%
model_path_root = 'models'
model_type_name = 'lstm2_univar'

def make_model_save_dir(path_root, type_name, class_name):
    save_dir = os.path.join(path_root, type_name, class_name)
    os.makedirs(save_dir, exist_ok=True)
    return save_dir

# %% [markdown]
# #### Общие коллбэки:

# %%
# уменьшение learning rate в случае, если loss не изменяется
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001, verbose=1)

# уменьшение learning rate в 2 раза каждую 5-ю эпоху
def lr_decay(e, lr):
    return lr * (1 - 0.5 * (0 == (e + 1) % 5))

lr_scheduler = LearningRateScheduler(schedule=lr_decay, verbose=1)

# %% [markdown]
# ## Задача регрессии
#
# Непосредственное прогнозирование цены следующего периода.

# %%
train_regr_gen = RegressionGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_regr_gen = RegressionGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_regr_gen = RegressionGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# Следующие числа соответствуют значению параметра `steps_per_epoch` метода [`fit_generator`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit_generator "tf.keras.layers.SimpleRNN &nbsp;|&nbsp; TensorFlow Core r2.0") - то есть это число батчей, которые генератор выдаст за одну эпоху обучения (если класс генератора поддерживает метод `len()`, то данный параметр можно не указывать).

# %%
len(train_regr_gen), len(val_regr_gen), len(test_regr_gen)
# Out:
# (77, 4, 5)

# %% [markdown]
# Один сэмпл данных представляет собой матрицу размером *(длина окна; число признаков)*

# %%
train_regr_gen.input_shape
# Out:
# (60, 1)

# %% [markdown]
# ### Модель для задачи регрессии

# %%
model_class_name = 'regression'

# %%
def build_regression_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=(16, 32))

    regr = Dense(64)(lstm)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    return Model(inputs=[inp], outputs=[regr])

# %%
univariate_regression_lstm = build_regression_model(train_regr_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:
# [`Nadam`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Nadam) (*Adam with Nestrov momentum*).

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Функция потерь:
#
# В качестве функции потерь будем использовать [MSE](https://www.tensorflow.org/api_docs/python/tf/keras/losses/MSE) (чтобы штрафовать за большие отклонения). Xотя хорошая функция потерь в контексте темы данной задачи - это [вопрос сложный](https://github.com/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Chapter5_LossFunctions/Ch5_LossFunctions_PyMC3.ipynb). В частности, здесь нам, очевидно, помимо абсолютного значения отклонения также важен его знак.

# %%
univariate_regression_lstm.compile(optimizer=optimizer,
                                   loss={'regr': 'mse'},
                                   metrics={'regr': 'mae'})

univariate_regression_lstm.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 60, 1)]           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 60, 16)            1152
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 60, 32)            6272
# _________________________________________________________________
# flatten (Flatten)            (None, 1920)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                122944
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64)                256
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 64)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# regr (Dense)                 (None, 1)                 65
# =================================================================
# Total params: 130,689
# Trainable params: 130,561
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# #### Обучение:

# %%
regr_history = utils.train_model(univariate_regression_lstm,
                                 model_save_dir, train_regr_gen, val_regr_gen,
                                 callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                 force_train=FORCE_TRAIN, verbose=1)
# Out:
# WARNING:tensorflow:From /content/hse-cs-ml-2018-2019-grad-work/mdp/utils.py:79: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 77/77 [==============================] - ETA: 0s - loss: 10.4811 - mae: 1.0243
# Epoch 00001: val_loss improved from inf to 7.34458, saving model to models/lstm2_univar/regression/01.hdf5
# 77/77 [==============================] - 9s 115ms/step - loss: 10.4811 - mae: 1.0243 - val_loss: 7.3446 - val_mae: 0.6357 - lr: 0.0010
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 77/77 [==============================] - ETA: 0s - loss: 6.3839 - mae: 0.8459
# Epoch 00002: val_loss improved from 7.34458 to 4.46620, saving model to models/lstm2_univar/regression/02.hdf5
# 77/77 [==============================] - 8s 106ms/step - loss: 6.3839 - mae: 0.8459 - val_loss: 4.4662 - val_mae: 0.6452 - lr: 0.0010
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 77/77 [==============================] - ETA: 0s - loss: 4.0079 - mae: 0.7485
# Epoch 00003: val_loss improved from 4.46620 to 2.97058, saving model to models/lstm2_univar/regression/03.hdf5
# 77/77 [==============================] - 8s 104ms/step - loss: 4.0079 - mae: 0.7485 - val_loss: 2.9706 - val_mae: 0.6443 - lr: 0.0010
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 77/77 [==============================] - ETA: 0s - loss: 2.8246 - mae: 0.7007
# Epoch 00004: val_loss improved from 2.97058 to 2.19339, saving model to models/lstm2_univar/regression/04.hdf5
# 77/77 [==============================] - 8s 104ms/step - loss: 2.8246 - mae: 0.7007 - val_loss: 2.1934 - val_mae: 0.6608 - lr: 0.0010
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 77/77 [==============================] - ETA: 0s - loss: 2.2819 - mae: 0.6771
# Epoch 00005: val_loss improved from 2.19339 to 2.01318, saving model to models/lstm2_univar/regression/05.hdf5
# 77/77 [==============================] - 8s 104ms/step - loss: 2.2819 - mae: 0.6771 - val_loss: 2.0132 - val_mae: 0.7318 - lr: 5.0000e-04
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 77/77 [==============================] - ETA: 0s - loss: 2.0324 - mae: 0.6690
# Epoch 00006: val_loss improved from 2.01318 to 1.70150, saving model to models/lstm2_univar/regression/06.hdf5
# 77/77 [==============================] - 8s 105ms/step - loss: 2.0324 - mae: 0.6690 - val_loss: 1.7015 - val_mae: 0.6349 - lr: 5.0000e-04
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 77/77 [==============================] - ETA: 0s - loss: 1.8448 - mae: 0.6640
# Epoch 00007: val_loss improved from 1.70150 to 1.68709, saving model to models/lstm2_univar/regression/07.hdf5
# 77/77 [==============================] - 8s 104ms/step - loss: 1.8448 - mae: 0.6640 - val_loss: 1.6871 - val_mae: 0.6997 - lr: 5.0000e-04
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 77/77 [==============================] - ETA: 0s - loss: 1.6943 - mae: 0.6626
# Epoch 00008: val_loss improved from 1.68709 to 1.40488, saving model to models/lstm2_univar/regression/08.hdf5
# 77/77 [==============================] - 11s 147ms/step - loss: 1.6943 - mae: 0.6626 - val_loss: 1.4049 - val_mae: 0.6358 - lr: 5.0000e-04
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 77/77 [==============================] - ETA: 0s - loss: 1.5748 - mae: 0.6604
# Epoch 00009: val_loss improved from 1.40488 to 1.39506, saving model to models/lstm2_univar/regression/09.hdf5
# 77/77 [==============================] - 8s 108ms/step - loss: 1.5748 - mae: 0.6604 - val_loss: 1.3951 - val_mae: 0.6734 - lr: 5.0000e-04
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 77/77 [==============================] - ETA: 0s - loss: 1.4932 - mae: 0.6587
# Epoch 00010: val_loss improved from 1.39506 to 1.25922, saving model to models/lstm2_univar/regression/10.hdf5
# 77/77 [==============================] - 8s 104ms/step - loss: 1.4932 - mae: 0.6587 - val_loss: 1.2592 - val_mae: 0.6503 - lr: 2.5000e-04
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 77/77 [==============================] - ETA: 0s - loss: 1.4494 - mae: 0.6599
# Epoch 00011: val_loss did not improve from 1.25922
# 77/77 [==============================] - 8s 104ms/step - loss: 1.4494 - mae: 0.6599 - val_loss: 1.6396 - val_mae: 0.9149 - lr: 2.5000e-04
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 77/77 [==============================] - ETA: 0s - loss: 1.4127 - mae: 0.6592
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 5.0000002374872565e-05.
#
# Epoch 00012: val_loss did not improve from 1.25922
# 77/77 [==============================] - 8s 103ms/step - loss: 1.4127 - mae: 0.6592 - val_loss: 1.5235 - val_mae: 0.8721 - lr: 5.0000e-05
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 5.0000002374872565e-05.
# Epoch 13/32
# 77/77 [==============================] - ETA: 0s - loss: 1.3841 - mae: 0.6590
# Epoch 00013: val_loss improved from 1.25922 to 1.21377, saving model to models/lstm2_univar/regression/13.hdf5
# 77/77 [==============================] - 8s 105ms/step - loss: 1.3841 - mae: 0.6590 - val_loss: 1.2138 - val_mae: 0.6874 - lr: 5.0000e-05
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 5.0000002374872565e-05.
# Epoch 14/32
# 77/77 [==============================] - ETA: 0s - loss: 1.3742 - mae: 0.6582
# Epoch 00014: val_loss improved from 1.21377 to 1.16610, saving model to models/lstm2_univar/regression/14.hdf5
# 77/77 [==============================] - 8s 104ms/step - loss: 1.3742 - mae: 0.6582 - val_loss: 1.1661 - val_mae: 0.6501 - lr: 5.0000e-05
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 15/32
# 77/77 [==============================] - ETA: 0s - loss: 1.3698 - mae: 0.6585
# Epoch 00015: val_loss improved from 1.16610 to 1.15775, saving model to models/lstm2_univar/regression/15.hdf5
# 77/77 [==============================] - 8s 106ms/step - loss: 1.3698 - mae: 0.6585 - val_loss: 1.1578 - val_mae: 0.6447 - lr: 2.5000e-05
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 16/32
# 77/77 [==============================] - ETA: 0s - loss: 1.3692 - mae: 0.6605
# Epoch 00016: val_loss improved from 1.15775 to 1.15127, saving model to models/lstm2_univar/regression/16.hdf5
# 77/77 [==============================] - 8s 104ms/step - loss: 1.3692 - mae: 0.6605 - val_loss: 1.1513 - val_mae: 0.6404 - lr: 2.5000e-05
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 17/32
# 77/77 [==============================] - ETA: 0s - loss: 1.3693 - mae: 0.6606
# Epoch 00017: val_loss improved from 1.15127 to 1.14652, saving model to models/lstm2_univar/regression/17.hdf5
# 77/77 [==============================] - 8s 104ms/step - loss: 1.3693 - mae: 0.6606 - val_loss: 1.1465 - val_mae: 0.6389 - lr: 2.5000e-05
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 18/32
# 77/77 [==============================] - ETA: 0s - loss: 1.3582 - mae: 0.6578
# Epoch 00018: val_loss improved from 1.14652 to 1.14183, saving model to models/lstm2_univar/regression/18.hdf5
# 77/77 [==============================] - 8s 104ms/step - loss: 1.3582 - mae: 0.6578 - val_loss: 1.1418 - val_mae: 0.6378 - lr: 2.5000e-05
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 19/32
# 77/77 [==============================] - ETA: 0s - loss: 1.3700 - mae: 0.6595
# Epoch 00019: val_loss improved from 1.14183 to 1.13880, saving model to models/lstm2_univar/regression/19.hdf5
# 77/77 [==============================] - 8s 105ms/step - loss: 1.3700 - mae: 0.6595 - val_loss: 1.1388 - val_mae: 0.6386 - lr: 2.5000e-05
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 20/32
# 77/77 [==============================] - ETA: 0s - loss: 1.3518 - mae: 0.6582
# Epoch 00020: val_loss improved from 1.13880 to 1.13711, saving model to models/lstm2_univar/regression/20.hdf5
# 77/77 [==============================] - 8s 107ms/step - loss: 1.3518 - mae: 0.6582 - val_loss: 1.1371 - val_mae: 0.6390 - lr: 1.2500e-05
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 21/32
# 77/77 [==============================] - ETA: 0s - loss: 1.3488 - mae: 0.6577
# Epoch 00021: val_loss improved from 1.13711 to 1.13570, saving model to models/lstm2_univar/regression/21.hdf5
# 77/77 [==============================] - 8s 106ms/step - loss: 1.3488 - mae: 0.6577 - val_loss: 1.1357 - val_mae: 0.6395 - lr: 1.2500e-05
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 22/32
# 77/77 [==============================] - ETA: 0s - loss: 1.3487 - mae: 0.6587
# Epoch 00022: val_loss improved from 1.13570 to 1.13352, saving model to models/lstm2_univar/regression/22.hdf5
# 77/77 [==============================] - 8s 106ms/step - loss: 1.3487 - mae: 0.6587 - val_loss: 1.1335 - val_mae: 0.6392 - lr: 1.2500e-05
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 23/32
# 77/77 [==============================] - ETA: 0s - loss: 1.3464 - mae: 0.6584
# Epoch 00023: val_loss improved from 1.13352 to 1.13172, saving model to models/lstm2_univar/regression/23.hdf5
# 77/77 [==============================] - 8s 105ms/step - loss: 1.3464 - mae: 0.6584 - val_loss: 1.1317 - val_mae: 0.6391 - lr: 1.2500e-05
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 24/32
# 77/77 [==============================] - ETA: 0s - loss: 1.3466 - mae: 0.6593
# Epoch 00024: val_loss improved from 1.13172 to 1.13039, saving model to models/lstm2_univar/regression/24.hdf5
# 77/77 [==============================] - 8s 104ms/step - loss: 1.3466 - mae: 0.6593 - val_loss: 1.1304 - val_mae: 0.6397 - lr: 1.2500e-05
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 25/32
# 77/77 [==============================] - ETA: 0s - loss: 1.3457 - mae: 0.6586
# Epoch 00025: val_loss improved from 1.13039 to 1.12932, saving model to models/lstm2_univar/regression/25.hdf5
# 77/77 [==============================] - 8s 104ms/step - loss: 1.3457 - mae: 0.6586 - val_loss: 1.1293 - val_mae: 0.6398 - lr: 6.2500e-06
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 26/32
# 77/77 [==============================] - ETA: 0s - loss: 1.3403 - mae: 0.6577
# Epoch 00026: val_loss improved from 1.12932 to 1.12784, saving model to models/lstm2_univar/regression/26.hdf5
# 77/77 [==============================] - 8s 105ms/step - loss: 1.3403 - mae: 0.6577 - val_loss: 1.1278 - val_mae: 0.6392 - lr: 6.2500e-06
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 27/32
# 77/77 [==============================] - ETA: 0s - loss: 1.3433 - mae: 0.6582
# Epoch 00027: val_loss improved from 1.12784 to 1.12655, saving model to models/lstm2_univar/regression/27.hdf5
# 77/77 [==============================] - 8s 106ms/step - loss: 1.3433 - mae: 0.6582 - val_loss: 1.1266 - val_mae: 0.6386 - lr: 6.2500e-06
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 28/32
# 77/77 [==============================] - ETA: 0s - loss: 1.3432 - mae: 0.6589
# Epoch 00028: val_loss improved from 1.12655 to 1.12575, saving model to models/lstm2_univar/regression/28.hdf5
# 77/77 [==============================] - 8s 105ms/step - loss: 1.3432 - mae: 0.6589 - val_loss: 1.1258 - val_mae: 0.6387 - lr: 6.2500e-06
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 29/32
# 77/77 [==============================] - ETA: 0s - loss: 1.3383 - mae: 0.6577
# Epoch 00029: val_loss improved from 1.12575 to 1.12515, saving model to models/lstm2_univar/regression/29.hdf5
# 77/77 [==============================] - 8s 104ms/step - loss: 1.3383 - mae: 0.6577 - val_loss: 1.1251 - val_mae: 0.6389 - lr: 6.2500e-06
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 3.1250001484295353e-06.
# Epoch 30/32
# 77/77 [==============================] - ETA: 0s - loss: 1.3397 - mae: 0.6573
# Epoch 00030: val_loss improved from 1.12515 to 1.12438, saving model to models/lstm2_univar/regression/30.hdf5
# 77/77 [==============================] - 8s 104ms/step - loss: 1.3397 - mae: 0.6573 - val_loss: 1.1244 - val_mae: 0.6388 - lr: 3.1250e-06
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 3.1250001484295353e-06.
# Epoch 31/32
# 77/77 [==============================] - ETA: 0s - loss: 1.3389 - mae: 0.6586
# Epoch 00031: val_loss improved from 1.12438 to 1.12403, saving model to models/lstm2_univar/regression/31.hdf5
# 77/77 [==============================] - 8s 105ms/step - loss: 1.3389 - mae: 0.6586 - val_loss: 1.1240 - val_mae: 0.6389 - lr: 3.1250e-06
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 3.1250001484295353e-06.
# Epoch 32/32
# 77/77 [==============================] - ETA: 0s - loss: 1.3392 - mae: 0.6587
# Epoch 00032: val_loss improved from 1.12403 to 1.12343, saving model to models/lstm2_univar/regression/32.hdf5
# 77/77 [==============================] - 8s 106ms/step - loss: 1.3392 - mae: 0.6587 - val_loss: 1.1234 - val_mae: 0.6388 - lr: 3.1250e-06

# %%
def plot_regr_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'MSE', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'MAE', 'mae', 'val_mae')
    
plot_regr_history(regr_history);

# %% [markdown]
# ### Прогноз задачи регрессии

# %% [markdown]
# *Судя по всему, просто выходит на модель случайного блуждания*

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_regression_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret_test = univariate_regression_lstm.predict_generator(test_regr_gen, verbose=1)
# Out:
# WARNING:tensorflow:From <ipython-input-40-c831dcaf40ce>:1: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.
# 5/5 [==============================] - 0s 11ms/step

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret_test, figsize=(16, 20))

# %% [markdown]
# ## Задача классификации
#
# Прогнозируем направление изменения цены по сравнению с предыдущим периодом (**0** - снижение, **1** - рост).

# %%
model_class_name = 'classification'

# %%
train_clf_gen = ClassificationGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_clf_gen = ClassificationGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_clf_gen = ClassificationGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_classification_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=(16, 32))

    clf = Dense(64)(lstm)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)

    return Model(inputs=[inp], outputs=[clf])

# %%
univariate_classification_lstm = build_classification_model(test_clf_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
univariate_classification_lstm.compile(optimizer=optimizer,
                                       loss={'clf': 'binary_crossentropy'},
                                       metrics={'clf': 'accuracy'})

univariate_classification_lstm.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 60, 1)]           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 60, 16)            1152
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 60, 32)            6272
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1920)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                122944
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# clf (Dense)                  (None, 1)                 65
# =================================================================
# Total params: 130,689
# Trainable params: 130,561
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
clf_history = utils.train_model(univariate_classification_lstm,
                                model_save_dir, train_clf_gen, val_clf_gen,
                                callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 77/77 [==============================] - ETA: 0s - loss: 8.6242 - accuracy: 0.5098
# Epoch 00001: val_loss improved from inf to 5.94379, saving model to models/lstm2_univar/classification/01.hdf5
# 77/77 [==============================] - 9s 113ms/step - loss: 8.6242 - accuracy: 0.5098 - val_loss: 5.9438 - val_accuracy: 0.5481 - lr: 0.0010
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 77/77 [==============================] - ETA: 0s - loss: 4.4689 - accuracy: 0.5106
# Epoch 00002: val_loss improved from 5.94379 to 3.20557, saving model to models/lstm2_univar/classification/02.hdf5
# 77/77 [==============================] - 8s 105ms/step - loss: 4.4689 - accuracy: 0.5106 - val_loss: 3.2056 - val_accuracy: 0.4519 - lr: 0.0010
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 77/77 [==============================] - ETA: 0s - loss: 2.6155 - accuracy: 0.5073
# Epoch 00003: val_loss improved from 3.20557 to 2.16552, saving model to models/lstm2_univar/classification/03.hdf5
# 77/77 [==============================] - 8s 104ms/step - loss: 2.6155 - accuracy: 0.5073 - val_loss: 2.1655 - val_accuracy: 0.4519 - lr: 0.0010
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 77/77 [==============================] - ETA: 0s - loss: 1.9374 - accuracy: 0.5155
# Epoch 00004: val_loss improved from 2.16552 to 1.75196, saving model to models/lstm2_univar/classification/04.hdf5
# 77/77 [==============================] - 8s 106ms/step - loss: 1.9374 - accuracy: 0.5155 - val_loss: 1.7520 - val_accuracy: 0.4712 - lr: 0.0010
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 77/77 [==============================] - ETA: 0s - loss: 1.6743 - accuracy: 0.5175
# Epoch 00005: val_loss improved from 1.75196 to 1.60872, saving model to models/lstm2_univar/classification/05.hdf5
# 77/77 [==============================] - 9s 111ms/step - loss: 1.6743 - accuracy: 0.5175 - val_loss: 1.6087 - val_accuracy: 0.5481 - lr: 5.0000e-04
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 77/77 [==============================] - ETA: 0s - loss: 1.5597 - accuracy: 0.5407
# Epoch 00006: val_loss improved from 1.60872 to 1.51452, saving model to models/lstm2_univar/classification/06.hdf5
# 77/77 [==============================] - 8s 104ms/step - loss: 1.5597 - accuracy: 0.5407 - val_loss: 1.5145 - val_accuracy: 0.4808 - lr: 5.0000e-04
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 77/77 [==============================] - ETA: 0s - loss: 1.4702 - accuracy: 0.5220
# Epoch 00007: val_loss improved from 1.51452 to 1.43007, saving model to models/lstm2_univar/classification/07.hdf5
# 77/77 [==============================] - 8s 105ms/step - loss: 1.4702 - accuracy: 0.5220 - val_loss: 1.4301 - val_accuracy: 0.4615 - lr: 5.0000e-04
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 77/77 [==============================] - ETA: 0s - loss: 1.3947 - accuracy: 0.5302
# Epoch 00008: val_loss improved from 1.43007 to 1.36403, saving model to models/lstm2_univar/classification/08.hdf5
# 77/77 [==============================] - 8s 105ms/step - loss: 1.3947 - accuracy: 0.5302 - val_loss: 1.3640 - val_accuracy: 0.4615 - lr: 5.0000e-04
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 77/77 [==============================] - ETA: 0s - loss: 1.3302 - accuracy: 0.5147
# Epoch 00009: val_loss improved from 1.36403 to 1.29759, saving model to models/lstm2_univar/classification/09.hdf5
# 77/77 [==============================] - 8s 106ms/step - loss: 1.3302 - accuracy: 0.5147 - val_loss: 1.2976 - val_accuracy: 0.4519 - lr: 5.0000e-04
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 77/77 [==============================] - ETA: 0s - loss: 1.2793 - accuracy: 0.5179
# Epoch 00010: val_loss improved from 1.29759 to 1.26489, saving model to models/lstm2_univar/classification/10.hdf5
# 77/77 [==============================] - 8s 106ms/step - loss: 1.2793 - accuracy: 0.5179 - val_loss: 1.2649 - val_accuracy: 0.4519 - lr: 2.5000e-04
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 77/77 [==============================] - ETA: 0s - loss: 1.2514 - accuracy: 0.5147
# Epoch 00011: val_loss improved from 1.26489 to 1.23847, saving model to models/lstm2_univar/classification/11.hdf5
# 77/77 [==============================] - 8s 107ms/step - loss: 1.2514 - accuracy: 0.5147 - val_loss: 1.2385 - val_accuracy: 0.4519 - lr: 2.5000e-04
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 77/77 [==============================] - ETA: 0s - loss: 1.2243 - accuracy: 0.5118
# Epoch 00012: val_loss improved from 1.23847 to 1.20947, saving model to models/lstm2_univar/classification/12.hdf5
# 77/77 [==============================] - 8s 108ms/step - loss: 1.2243 - accuracy: 0.5118 - val_loss: 1.2095 - val_accuracy: 0.5385 - lr: 2.5000e-04
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 77/77 [==============================] - ETA: 0s - loss: 1.1978 - accuracy: 0.5118
# Epoch 00013: val_loss improved from 1.20947 to 1.18528, saving model to models/lstm2_univar/classification/13.hdf5
# 77/77 [==============================] - 8s 107ms/step - loss: 1.1978 - accuracy: 0.5118 - val_loss: 1.1853 - val_accuracy: 0.5481 - lr: 2.5000e-04
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 77/77 [==============================] - ETA: 0s - loss: 1.1725 - accuracy: 0.5110
# Epoch 00014: val_loss improved from 1.18528 to 1.15832, saving model to models/lstm2_univar/classification/14.hdf5
# 77/77 [==============================] - 8s 105ms/step - loss: 1.1725 - accuracy: 0.5110 - val_loss: 1.1583 - val_accuracy: 0.5481 - lr: 2.5000e-04
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 77/77 [==============================] - ETA: 0s - loss: 1.1509 - accuracy: 0.5106
# Epoch 00015: val_loss improved from 1.15832 to 1.14449, saving model to models/lstm2_univar/classification/15.hdf5
# 77/77 [==============================] - 8s 104ms/step - loss: 1.1509 - accuracy: 0.5106 - val_loss: 1.1445 - val_accuracy: 0.5577 - lr: 1.2500e-04
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 77/77 [==============================] - ETA: 0s - loss: 1.1389 - accuracy: 0.5110
# Epoch 00016: val_loss improved from 1.14449 to 1.13317, saving model to models/lstm2_univar/classification/16.hdf5
# 77/77 [==============================] - 8s 106ms/step - loss: 1.1389 - accuracy: 0.5110 - val_loss: 1.1332 - val_accuracy: 0.4519 - lr: 1.2500e-04
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 77/77 [==============================] - ETA: 0s - loss: 1.1268 - accuracy: 0.5102
# Epoch 00017: val_loss improved from 1.13317 to 1.12087, saving model to models/lstm2_univar/classification/17.hdf5
# 77/77 [==============================] - 8s 106ms/step - loss: 1.1268 - accuracy: 0.5102 - val_loss: 1.1209 - val_accuracy: 0.4519 - lr: 1.2500e-04
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 77/77 [==============================] - ETA: 0s - loss: 1.1147 - accuracy: 0.5102
# Epoch 00018: val_loss improved from 1.12087 to 1.10939, saving model to models/lstm2_univar/classification/18.hdf5
# 77/77 [==============================] - 8s 106ms/step - loss: 1.1147 - accuracy: 0.5102 - val_loss: 1.1094 - val_accuracy: 0.4519 - lr: 1.2500e-04
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 77/77 [==============================] - ETA: 0s - loss: 1.1030 - accuracy: 0.5086
# Epoch 00019: val_loss improved from 1.10939 to 1.09752, saving model to models/lstm2_univar/classification/19.hdf5
# 77/77 [==============================] - 8s 105ms/step - loss: 1.1030 - accuracy: 0.5086 - val_loss: 1.0975 - val_accuracy: 0.4519 - lr: 1.2500e-04
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0929 - accuracy: 0.5098
# Epoch 00020: val_loss improved from 1.09752 to 1.09065, saving model to models/lstm2_univar/classification/20.hdf5
# 77/77 [==============================] - 8s 104ms/step - loss: 1.0929 - accuracy: 0.5098 - val_loss: 1.0907 - val_accuracy: 0.4519 - lr: 6.2500e-05
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0872 - accuracy: 0.5118
# Epoch 00021: val_loss improved from 1.09065 to 1.08509, saving model to models/lstm2_univar/classification/21.hdf5
# 77/77 [==============================] - 8s 105ms/step - loss: 1.0872 - accuracy: 0.5118 - val_loss: 1.0851 - val_accuracy: 0.4519 - lr: 6.2500e-05
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0814 - accuracy: 0.5098
# Epoch 00022: val_loss improved from 1.08509 to 1.07907, saving model to models/lstm2_univar/classification/22.hdf5
# 77/77 [==============================] - 8s 106ms/step - loss: 1.0814 - accuracy: 0.5098 - val_loss: 1.0791 - val_accuracy: 0.4519 - lr: 6.2500e-05
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0752 - accuracy: 0.5090
# Epoch 00023: val_loss improved from 1.07907 to 1.07355, saving model to models/lstm2_univar/classification/23.hdf5
# 77/77 [==============================] - 8s 107ms/step - loss: 1.0752 - accuracy: 0.5090 - val_loss: 1.0736 - val_accuracy: 0.4519 - lr: 6.2500e-05
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0697 - accuracy: 0.5102
# Epoch 00024: val_loss improved from 1.07355 to 1.06755, saving model to models/lstm2_univar/classification/24.hdf5
# 77/77 [==============================] - 8s 108ms/step - loss: 1.0697 - accuracy: 0.5102 - val_loss: 1.0675 - val_accuracy: 0.4519 - lr: 6.2500e-05
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0647 - accuracy: 0.5098
# Epoch 00025: val_loss improved from 1.06755 to 1.06413, saving model to models/lstm2_univar/classification/25.hdf5
# 77/77 [==============================] - 8s 107ms/step - loss: 1.0647 - accuracy: 0.5098 - val_loss: 1.0641 - val_accuracy: 0.4519 - lr: 3.1250e-05
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0618 - accuracy: 0.5098
# Epoch 00026: val_loss improved from 1.06413 to 1.06125, saving model to models/lstm2_univar/classification/26.hdf5
# 77/77 [==============================] - 8s 105ms/step - loss: 1.0618 - accuracy: 0.5098 - val_loss: 1.0612 - val_accuracy: 0.4519 - lr: 3.1250e-05
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0590 - accuracy: 0.5098
# Epoch 00027: val_loss improved from 1.06125 to 1.05829, saving model to models/lstm2_univar/classification/27.hdf5
# 77/77 [==============================] - 8s 107ms/step - loss: 1.0590 - accuracy: 0.5098 - val_loss: 1.0583 - val_accuracy: 0.4519 - lr: 3.1250e-05
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0560 - accuracy: 0.5090
# Epoch 00028: val_loss improved from 1.05829 to 1.05535, saving model to models/lstm2_univar/classification/28.hdf5
# 77/77 [==============================] - 8s 107ms/step - loss: 1.0560 - accuracy: 0.5090 - val_loss: 1.0553 - val_accuracy: 0.4519 - lr: 3.1250e-05
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0531 - accuracy: 0.5098
# Epoch 00029: val_loss improved from 1.05535 to 1.05240, saving model to models/lstm2_univar/classification/29.hdf5
# 77/77 [==============================] - 8s 107ms/step - loss: 1.0531 - accuracy: 0.5098 - val_loss: 1.0524 - val_accuracy: 0.4519 - lr: 3.1250e-05
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0507 - accuracy: 0.5098
# Epoch 00030: val_loss improved from 1.05240 to 1.05063, saving model to models/lstm2_univar/classification/30.hdf5
# 77/77 [==============================] - 8s 105ms/step - loss: 1.0507 - accuracy: 0.5098 - val_loss: 1.0506 - val_accuracy: 0.4519 - lr: 1.5625e-05
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0489 - accuracy: 0.5098
# Epoch 00031: val_loss improved from 1.05063 to 1.04918, saving model to models/lstm2_univar/classification/31.hdf5
# 77/77 [==============================] - 8s 107ms/step - loss: 1.0489 - accuracy: 0.5098 - val_loss: 1.0492 - val_accuracy: 0.4519 - lr: 1.5625e-05
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 77/77 [==============================] - ETA: 0s - loss: 1.0473 - accuracy: 0.5102
# Epoch 00032: val_loss improved from 1.04918 to 1.04768, saving model to models/lstm2_univar/classification/32.hdf5
# 77/77 [==============================] - 8s 108ms/step - loss: 1.0473 - accuracy: 0.5102 - val_loss: 1.0477 - val_accuracy: 0.4519 - lr: 1.5625e-05

# %%
def plot_clf_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'Loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'Accuracy', 'accuracy', 'val_accuracy')
    
plot_clf_history(clf_history);

# %% [markdown]
# ### Прогноз задачи классификации

# %% [markdown]
# *Здесь просто вышел на константное предсказание*.

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_classification_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %%
pred_direction_proba = univariate_classification_lstm.predict_generator(test_clf_gen, verbose=1)

true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 5/5 [==============================] - 0s 11ms/step
# 0.4914179

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([66, 82])), (array([0, 1]), array([75, 73])))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.47      0.53      0.50        66
#            1       0.58      0.51      0.54        82
#
#     accuracy                           0.52       148
#    macro avg       0.52      0.52      0.52       148
# weighted avg       0.53      0.52      0.52       148

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[35, 31],
#        [40, 42]])

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.46666667, 0.42465753],
#        [0.53333333, 0.57534247]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# ## Многозадачная модель: одновременно регрессия и классификация

# %%
model_class_name = 'multitask'

# %%
train_multi_gen = MultitaskGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_multi_gen = MultitaskGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_multi_gen = MultitaskGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_multitask_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=(16, 32))

    # первый выход: задача регрссии
    regr = Dense(64)(lstm)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    # второй выход: задача классификации
    clf = Dense(64)(lstm)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)
    
    return Model(inputs=[inp], outputs=[regr, clf])

# %%
univariate_multitask_lstm = build_multitask_model(train_multi_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
univariate_multitask_lstm.compile(optimizer=optimizer,
                                  loss={'regr': 'mse', 'clf': 'binary_crossentropy'},
                                  loss_weights={'regr': 2., 'clf': 1.},
                                  metrics={'regr': 'mae', 'clf' : 'accuracy'})

univariate_multitask_lstm.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 60, 1)]      0
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 60, 16)       1152        input[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 60, 32)       6272        lstm_4[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1920)         0           lstm_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           122944      flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           122944      flatten_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64)           256         dense_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64)           256         dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 64)           0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 64)           0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64)           0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64)           0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# regr (Dense)                    (None, 1)            65          dropout_2[0][0]
# __________________________________________________________________________________________________
# clf (Dense)                     (None, 1)            65          dropout_3[0][0]
# ==================================================================================================
# Total params: 253,954
# Trainable params: 253,698
# Non-trainable params: 256
# __________________________________________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
multitask_history = utils.train_model(univariate_multitask_lstm,
                                      model_save_dir, train_multi_gen, val_multi_gen,
                                      callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                      force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 77/77 [==============================] - ETA: 0s - loss: 13.2901 - regr_loss: 1.6872 - clf_loss: 0.8253 - regr_mae: 0.9981 - clf_accuracy: 0.5069
# Epoch 00001: val_loss improved from inf to 9.52170, saving model to models/lstm2_univar/multitask/01.hdf5
# 77/77 [==============================] - 9s 122ms/step - loss: 13.2901 - regr_loss: 1.6872 - clf_loss: 0.8253 - regr_mae: 0.9981 - clf_accuracy: 0.5069 - val_loss: 9.5217 - val_regr_loss: 0.6672 - val_clf_loss: 0.6952 - val_regr_mae: 0.6359 - val_clf_accuracy: 0.5481 - lr: 0.0010
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 77/77 [==============================] - ETA: 0s - loss: 9.4387 - regr_loss: 1.2535 - clf_loss: 0.8036 - regr_mae: 0.8349 - clf_accuracy: 0.4829
# Epoch 00002: val_loss improved from 9.52170 to 6.91889, saving model to models/lstm2_univar/multitask/02.hdf5
# 77/77 [==============================] - 9s 115ms/step - loss: 9.4387 - regr_loss: 1.2535 - clf_loss: 0.8036 - regr_mae: 0.8349 - clf_accuracy: 0.4829 - val_loss: 6.9189 - val_regr_loss: 0.6694 - val_clf_loss: 0.7034 - val_regr_mae: 0.6429 - val_clf_accuracy: 0.4519 - lr: 0.0010
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 77/77 [==============================] - ETA: 0s - loss: 6.8376 - regr_loss: 1.0554 - clf_loss: 0.7464 - regr_mae: 0.7421 - clf_accuracy: 0.5033
# Epoch 00003: val_loss improved from 6.91889 to 5.27853, saving model to models/lstm2_univar/multitask/03.hdf5
# 77/77 [==============================] - 9s 114ms/step - loss: 6.8376 - regr_loss: 1.0554 - clf_loss: 0.7464 - regr_mae: 0.7421 - clf_accuracy: 0.5033 - val_loss: 5.2785 - val_regr_loss: 0.6727 - val_clf_loss: 0.7240 - val_regr_mae: 0.6381 - val_clf_accuracy: 0.4519 - lr: 0.0010
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 77/77 [==============================] - ETA: 0s - loss: 5.3435 - regr_loss: 0.9725 - clf_loss: 0.7219 - regr_mae: 0.7026 - clf_accuracy: 0.5081
# Epoch 00004: val_loss improved from 5.27853 to 4.33244, saving model to models/lstm2_univar/multitask/04.hdf5
# 77/77 [==============================] - 9s 112ms/step - loss: 5.3435 - regr_loss: 0.9725 - clf_loss: 0.7219 - regr_mae: 0.7026 - clf_accuracy: 0.5081 - val_loss: 4.3324 - val_regr_loss: 0.7090 - val_clf_loss: 0.7004 - val_regr_mae: 0.6519 - val_clf_accuracy: 0.4519 - lr: 0.0010
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 77/77 [==============================] - ETA: 0s - loss: 4.5890 - regr_loss: 0.9311 - clf_loss: 0.7136 - regr_mae: 0.6803 - clf_accuracy: 0.4939
# Epoch 00005: val_loss improved from 4.33244 to 3.87896, saving model to models/lstm2_univar/multitask/05.hdf5
# 77/77 [==============================] - 9s 111ms/step - loss: 4.5890 - regr_loss: 0.9311 - clf_loss: 0.7136 - regr_mae: 0.6803 - clf_accuracy: 0.4939 - val_loss: 3.8790 - val_regr_loss: 0.6796 - val_clf_loss: 0.6924 - val_regr_mae: 0.6417 - val_clf_accuracy: 0.5769 - lr: 5.0000e-04
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 77/77 [==============================] - ETA: 0s - loss: 4.1784 - regr_loss: 0.9016 - clf_loss: 0.6991 - regr_mae: 0.6680 - clf_accuracy: 0.5265
# Epoch 00006: val_loss improved from 3.87896 to 3.60379, saving model to models/lstm2_univar/multitask/06.hdf5
# 77/77 [==============================] - 9s 111ms/step - loss: 4.1784 - regr_loss: 0.9016 - clf_loss: 0.6991 - regr_mae: 0.6680 - clf_accuracy: 0.5265 - val_loss: 3.6038 - val_regr_loss: 0.6795 - val_clf_loss: 0.7105 - val_regr_mae: 0.6418 - val_clf_accuracy: 0.4519 - lr: 5.0000e-04
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 77/77 [==============================] - ETA: 0s - loss: 3.8995 - regr_loss: 0.9004 - clf_loss: 0.6948 - regr_mae: 0.6665 - clf_accuracy: 0.5224
# Epoch 00007: val_loss improved from 3.60379 to 3.48428, saving model to models/lstm2_univar/multitask/07.hdf5
# 77/77 [==============================] - 9s 112ms/step - loss: 3.8995 - regr_loss: 0.9004 - clf_loss: 0.6948 - regr_mae: 0.6665 - clf_accuracy: 0.5224 - val_loss: 3.4843 - val_regr_loss: 0.7512 - val_clf_loss: 0.6984 - val_regr_mae: 0.6666 - val_clf_accuracy: 0.5481 - lr: 5.0000e-04
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 77/77 [==============================] - ETA: 0s - loss: 3.6928 - regr_loss: 0.9120 - clf_loss: 0.6905 - regr_mae: 0.6649 - clf_accuracy: 0.5318
# Epoch 00008: val_loss improved from 3.48428 to 3.28858, saving model to models/lstm2_univar/multitask/08.hdf5
# 77/77 [==============================] - 9s 111ms/step - loss: 3.6928 - regr_loss: 0.9120 - clf_loss: 0.6905 - regr_mae: 0.6649 - clf_accuracy: 0.5318 - val_loss: 3.2886 - val_regr_loss: 0.7338 - val_clf_loss: 0.7440 - val_regr_mae: 0.6594 - val_clf_accuracy: 0.5481 - lr: 5.0000e-04
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 77/77 [==============================] - ETA: 0s - loss: 3.4735 - regr_loss: 0.8917 - clf_loss: 0.6928 - regr_mae: 0.6602 - clf_accuracy: 0.5387
# Epoch 00009: val_loss improved from 3.28858 to 2.95528, saving model to models/lstm2_univar/multitask/09.hdf5
# 77/77 [==============================] - 9s 112ms/step - loss: 3.4735 - regr_loss: 0.8917 - clf_loss: 0.6928 - regr_mae: 0.6602 - clf_accuracy: 0.5387 - val_loss: 2.9553 - val_regr_loss: 0.6704 - val_clf_loss: 0.6951 - val_regr_mae: 0.6369 - val_clf_accuracy: 0.4615 - lr: 5.0000e-04
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 77/77 [==============================] - ETA: 0s - loss: 3.3613 - regr_loss: 0.8976 - clf_loss: 0.6917 - regr_mae: 0.6619 - clf_accuracy: 0.5318
# Epoch 00010: val_loss improved from 2.95528 to 2.91195, saving model to models/lstm2_univar/multitask/10.hdf5
# 77/77 [==============================] - 9s 112ms/step - loss: 3.3613 - regr_loss: 0.8976 - clf_loss: 0.6917 - regr_mae: 0.6619 - clf_accuracy: 0.5318 - val_loss: 2.9119 - val_regr_loss: 0.6901 - val_clf_loss: 0.6957 - val_regr_mae: 0.6608 - val_clf_accuracy: 0.4808 - lr: 2.5000e-04
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 77/77 [==============================] - ETA: 0s - loss: 3.2869 - regr_loss: 0.8966 - clf_loss: 0.6904 - regr_mae: 0.6635 - clf_accuracy: 0.5407
# Epoch 00011: val_loss improved from 2.91195 to 2.85754, saving model to models/lstm2_univar/multitask/11.hdf5
# 77/77 [==============================] - 9s 113ms/step - loss: 3.2869 - regr_loss: 0.8966 - clf_loss: 0.6904 - regr_mae: 0.6635 - clf_accuracy: 0.5407 - val_loss: 2.8575 - val_regr_loss: 0.6939 - val_clf_loss: 0.7003 - val_regr_mae: 0.6633 - val_clf_accuracy: 0.4327 - lr: 2.5000e-04
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 77/77 [==============================] - ETA: 0s - loss: 3.2188 - regr_loss: 0.8954 - clf_loss: 0.6896 - regr_mae: 0.6619 - clf_accuracy: 0.5395
# Epoch 00012: val_loss improved from 2.85754 to 2.82976, saving model to models/lstm2_univar/multitask/12.hdf5
# 77/77 [==============================] - 9s 114ms/step - loss: 3.2188 - regr_loss: 0.8954 - clf_loss: 0.6896 - regr_mae: 0.6619 - clf_accuracy: 0.5395 - val_loss: 2.8298 - val_regr_loss: 0.7064 - val_clf_loss: 0.7093 - val_regr_mae: 0.6725 - val_clf_accuracy: 0.4615 - lr: 2.5000e-04
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 77/77 [==============================] - ETA: 0s - loss: 3.1584 - regr_loss: 0.8943 - clf_loss: 0.6897 - regr_mae: 0.6607 - clf_accuracy: 0.5489
# Epoch 00013: val_loss improved from 2.82976 to 2.75658, saving model to models/lstm2_univar/multitask/13.hdf5
# 77/77 [==============================] - 9s 113ms/step - loss: 3.1584 - regr_loss: 0.8943 - clf_loss: 0.6897 - regr_mae: 0.6607 - clf_accuracy: 0.5489 - val_loss: 2.7566 - val_regr_loss: 0.6993 - val_clf_loss: 0.7062 - val_regr_mae: 0.6666 - val_clf_accuracy: 0.4615 - lr: 2.5000e-04
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 77/77 [==============================] - ETA: 0s - loss: 3.0813 - regr_loss: 0.8828 - clf_loss: 0.6871 - regr_mae: 0.6580 - clf_accuracy: 0.5497
# Epoch 00014: val_loss improved from 2.75658 to 2.72476, saving model to models/lstm2_univar/multitask/14.hdf5
# 77/77 [==============================] - 12s 150ms/step - loss: 3.0813 - regr_loss: 0.8828 - clf_loss: 0.6871 - regr_mae: 0.6580 - clf_accuracy: 0.5497 - val_loss: 2.7248 - val_regr_loss: 0.6982 - val_clf_loss: 0.7268 - val_regr_mae: 0.6650 - val_clf_accuracy: 0.4615 - lr: 2.5000e-04
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 77/77 [==============================] - ETA: 0s - loss: 3.0580 - regr_loss: 0.8907 - clf_loss: 0.6885 - regr_mae: 0.6593 - clf_accuracy: 0.5428
# Epoch 00015: val_loss improved from 2.72476 to 2.64104, saving model to models/lstm2_univar/multitask/15.hdf5
# 77/77 [==============================] - 9s 115ms/step - loss: 3.0580 - regr_loss: 0.8907 - clf_loss: 0.6885 - regr_mae: 0.6593 - clf_accuracy: 0.5428 - val_loss: 2.6410 - val_regr_loss: 0.6829 - val_clf_loss: 0.7009 - val_regr_mae: 0.6513 - val_clf_accuracy: 0.4327 - lr: 1.2500e-04
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 77/77 [==============================] - ETA: 0s - loss: 3.0261 - regr_loss: 0.8859 - clf_loss: 0.6905 - regr_mae: 0.6590 - clf_accuracy: 0.5289
# Epoch 00016: val_loss improved from 2.64104 to 2.60105, saving model to models/lstm2_univar/multitask/16.hdf5
# 77/77 [==============================] - 9s 114ms/step - loss: 3.0261 - regr_loss: 0.8859 - clf_loss: 0.6905 - regr_mae: 0.6590 - clf_accuracy: 0.5289 - val_loss: 2.6011 - val_regr_loss: 0.6764 - val_clf_loss: 0.6973 - val_regr_mae: 0.6432 - val_clf_accuracy: 0.4519 - lr: 1.2500e-04
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 77/77 [==============================] - ETA: 0s - loss: 2.9983 - regr_loss: 0.8846 - clf_loss: 0.6878 - regr_mae: 0.6568 - clf_accuracy: 0.5346
# Epoch 00017: val_loss improved from 2.60105 to 2.59173, saving model to models/lstm2_univar/multitask/17.hdf5
# 77/77 [==============================] - 9s 114ms/step - loss: 2.9983 - regr_loss: 0.8846 - clf_loss: 0.6878 - regr_mae: 0.6568 - clf_accuracy: 0.5346 - val_loss: 2.5917 - val_regr_loss: 0.6802 - val_clf_loss: 0.7009 - val_regr_mae: 0.6460 - val_clf_accuracy: 0.4423 - lr: 1.2500e-04
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 77/77 [==============================] - ETA: 0s - loss: 2.9692 - regr_loss: 0.8804 - clf_loss: 0.6879 - regr_mae: 0.6559 - clf_accuracy: 0.5391
# Epoch 00018: val_loss improved from 2.59173 to 2.59012, saving model to models/lstm2_univar/multitask/18.hdf5
# 77/77 [==============================] - 9s 113ms/step - loss: 2.9692 - regr_loss: 0.8804 - clf_loss: 0.6879 - regr_mae: 0.6559 - clf_accuracy: 0.5391 - val_loss: 2.5901 - val_regr_loss: 0.6870 - val_clf_loss: 0.7058 - val_regr_mae: 0.6539 - val_clf_accuracy: 0.4519 - lr: 1.2500e-04
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 77/77 [==============================] - ETA: 0s - loss: 2.9482 - regr_loss: 0.8801 - clf_loss: 0.6868 - regr_mae: 0.6557 - clf_accuracy: 0.5465
# Epoch 00019: val_loss improved from 2.59012 to 2.56866, saving model to models/lstm2_univar/multitask/19.hdf5
# 77/77 [==============================] - 9s 112ms/step - loss: 2.9482 - regr_loss: 0.8801 - clf_loss: 0.6868 - regr_mae: 0.6557 - clf_accuracy: 0.5465 - val_loss: 2.5687 - val_regr_loss: 0.6865 - val_clf_loss: 0.7041 - val_regr_mae: 0.6557 - val_clf_accuracy: 0.4519 - lr: 1.2500e-04
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 77/77 [==============================] - ETA: 0s - loss: 2.9305 - regr_loss: 0.8806 - clf_loss: 0.6845 - regr_mae: 0.6558 - clf_accuracy: 0.5391
# Epoch 00020: val_loss improved from 2.56866 to 2.54164, saving model to models/lstm2_univar/multitask/20.hdf5
# 77/77 [==============================] - 9s 112ms/step - loss: 2.9305 - regr_loss: 0.8806 - clf_loss: 0.6845 - regr_mae: 0.6558 - clf_accuracy: 0.5391 - val_loss: 2.5416 - val_regr_loss: 0.6821 - val_clf_loss: 0.6973 - val_regr_mae: 0.6514 - val_clf_accuracy: 0.4712 - lr: 6.2500e-05
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 77/77 [==============================] - ETA: 0s - loss: 2.9244 - regr_loss: 0.8811 - clf_loss: 0.6869 - regr_mae: 0.6565 - clf_accuracy: 0.5412
# Epoch 00021: val_loss did not improve from 2.54164
# 77/77 [==============================] - 9s 112ms/step - loss: 2.9244 - regr_loss: 0.8811 - clf_loss: 0.6869 - regr_mae: 0.6565 - clf_accuracy: 0.5412 - val_loss: 2.5422 - val_regr_loss: 0.6867 - val_clf_loss: 0.6977 - val_regr_mae: 0.6564 - val_clf_accuracy: 0.4519 - lr: 6.2500e-05
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 77/77 [==============================] - ETA: 0s - loss: 2.9188 - regr_loss: 0.8832 - clf_loss: 0.6863 - regr_mae: 0.6571 - clf_accuracy: 0.5522
# Epoch 00022: val_loss improved from 2.54164 to 2.52089, saving model to models/lstm2_univar/multitask/22.hdf5
# 77/77 [==============================] - 9s 112ms/step - loss: 2.9188 - regr_loss: 0.8832 - clf_loss: 0.6863 - regr_mae: 0.6571 - clf_accuracy: 0.5522 - val_loss: 2.5209 - val_regr_loss: 0.6817 - val_clf_loss: 0.6960 - val_regr_mae: 0.6506 - val_clf_accuracy: 0.4712 - lr: 6.2500e-05
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 77/77 [==============================] - ETA: 0s - loss: 2.9046 - regr_loss: 0.8811 - clf_loss: 0.6856 - regr_mae: 0.6565 - clf_accuracy: 0.5346
# Epoch 00023: val_loss improved from 2.52089 to 2.51072, saving model to models/lstm2_univar/multitask/23.hdf5
# 77/77 [==============================] - 9s 112ms/step - loss: 2.9046 - regr_loss: 0.8811 - clf_loss: 0.6856 - regr_mae: 0.6565 - clf_accuracy: 0.5346 - val_loss: 2.5107 - val_regr_loss: 0.6809 - val_clf_loss: 0.6962 - val_regr_mae: 0.6499 - val_clf_accuracy: 0.4808 - lr: 6.2500e-05
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 77/77 [==============================] - ETA: 0s - loss: 2.9001 - regr_loss: 0.8838 - clf_loss: 0.6848 - regr_mae: 0.6556 - clf_accuracy: 0.5509
# Epoch 00024: val_loss improved from 2.51072 to 2.50389, saving model to models/lstm2_univar/multitask/24.hdf5
# 77/77 [==============================] - 9s 112ms/step - loss: 2.9001 - regr_loss: 0.8838 - clf_loss: 0.6848 - regr_mae: 0.6556 - clf_accuracy: 0.5509 - val_loss: 2.5039 - val_regr_loss: 0.6824 - val_clf_loss: 0.6961 - val_regr_mae: 0.6512 - val_clf_accuracy: 0.4808 - lr: 6.2500e-05
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 77/77 [==============================] - ETA: 0s - loss: 2.9065 - regr_loss: 0.8906 - clf_loss: 0.6853 - regr_mae: 0.6579 - clf_accuracy: 0.5481
# Epoch 00025: val_loss improved from 2.50389 to 2.48848, saving model to models/lstm2_univar/multitask/25.hdf5
# 77/77 [==============================] - 9s 113ms/step - loss: 2.9065 - regr_loss: 0.8906 - clf_loss: 0.6853 - regr_mae: 0.6579 - clf_accuracy: 0.5481 - val_loss: 2.4885 - val_regr_loss: 0.6786 - val_clf_loss: 0.6939 - val_regr_mae: 0.6477 - val_clf_accuracy: 0.5096 - lr: 3.1250e-05
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 77/77 [==============================] - ETA: 0s - loss: 2.8981 - regr_loss: 0.8879 - clf_loss: 0.6869 - regr_mae: 0.6573 - clf_accuracy: 0.5395
# Epoch 00026: val_loss improved from 2.48848 to 2.48031, saving model to models/lstm2_univar/multitask/26.hdf5
# 77/77 [==============================] - 9s 113ms/step - loss: 2.8981 - regr_loss: 0.8879 - clf_loss: 0.6869 - regr_mae: 0.6573 - clf_accuracy: 0.5395 - val_loss: 2.4803 - val_regr_loss: 0.6770 - val_clf_loss: 0.6932 - val_regr_mae: 0.6460 - val_clf_accuracy: 0.5096 - lr: 3.1250e-05
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 77/77 [==============================] - ETA: 0s - loss: 2.8863 - regr_loss: 0.8847 - clf_loss: 0.6859 - regr_mae: 0.6564 - clf_accuracy: 0.5505
# Epoch 00027: val_loss improved from 2.48031 to 2.47594, saving model to models/lstm2_univar/multitask/27.hdf5
# 77/77 [==============================] - 9s 113ms/step - loss: 2.8863 - regr_loss: 0.8847 - clf_loss: 0.6859 - regr_mae: 0.6564 - clf_accuracy: 0.5505 - val_loss: 2.4759 - val_regr_loss: 0.6771 - val_clf_loss: 0.6934 - val_regr_mae: 0.6464 - val_clf_accuracy: 0.5096 - lr: 3.1250e-05
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 77/77 [==============================] - ETA: 0s - loss: 2.8803 - regr_loss: 0.8842 - clf_loss: 0.6856 - regr_mae: 0.6568 - clf_accuracy: 0.5595
# Epoch 00028: val_loss improved from 2.47594 to 2.47388, saving model to models/lstm2_univar/multitask/28.hdf5
# 77/77 [==============================] - 9s 112ms/step - loss: 2.8803 - regr_loss: 0.8842 - clf_loss: 0.6856 - regr_mae: 0.6568 - clf_accuracy: 0.5595 - val_loss: 2.4739 - val_regr_loss: 0.6782 - val_clf_loss: 0.6934 - val_regr_mae: 0.6476 - val_clf_accuracy: 0.5096 - lr: 3.1250e-05
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 77/77 [==============================] - ETA: 0s - loss: 2.8692 - regr_loss: 0.8811 - clf_loss: 0.6851 - regr_mae: 0.6569 - clf_accuracy: 0.5485
# Epoch 00029: val_loss improved from 2.47388 to 2.46818, saving model to models/lstm2_univar/multitask/29.hdf5
# 77/77 [==============================] - 9s 112ms/step - loss: 2.8692 - regr_loss: 0.8811 - clf_loss: 0.6851 - regr_mae: 0.6569 - clf_accuracy: 0.5485 - val_loss: 2.4682 - val_regr_loss: 0.6777 - val_clf_loss: 0.6930 - val_regr_mae: 0.6468 - val_clf_accuracy: 0.5096 - lr: 3.1250e-05
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 77/77 [==============================] - ETA: 0s - loss: 2.8700 - regr_loss: 0.8828 - clf_loss: 0.6862 - regr_mae: 0.6569 - clf_accuracy: 0.5513
# Epoch 00030: val_loss improved from 2.46818 to 2.46394, saving model to models/lstm2_univar/multitask/30.hdf5
# 77/77 [==============================] - 9s 111ms/step - loss: 2.8700 - regr_loss: 0.8828 - clf_loss: 0.6862 - regr_mae: 0.6569 - clf_accuracy: 0.5513 - val_loss: 2.4639 - val_regr_loss: 0.6771 - val_clf_loss: 0.6926 - val_regr_mae: 0.6462 - val_clf_accuracy: 0.4904 - lr: 1.5625e-05
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 77/77 [==============================] - ETA: 0s - loss: 2.8657 - regr_loss: 0.8823 - clf_loss: 0.6851 - regr_mae: 0.6569 - clf_accuracy: 0.5550
# Epoch 00031: val_loss improved from 2.46394 to 2.46076, saving model to models/lstm2_univar/multitask/31.hdf5
# 77/77 [==============================] - 9s 112ms/step - loss: 2.8657 - regr_loss: 0.8823 - clf_loss: 0.6851 - regr_mae: 0.6569 - clf_accuracy: 0.5550 - val_loss: 2.4608 - val_regr_loss: 0.6767 - val_clf_loss: 0.6924 - val_regr_mae: 0.6456 - val_clf_accuracy: 0.5096 - lr: 1.5625e-05
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 77/77 [==============================] - ETA: 0s - loss: 2.8679 - regr_loss: 0.8837 - clf_loss: 0.6866 - regr_mae: 0.6570 - clf_accuracy: 0.5460
# Epoch 00032: val_loss improved from 2.46076 to 2.45870, saving model to models/lstm2_univar/multitask/32.hdf5
# 77/77 [==============================] - 9s 111ms/step - loss: 2.8679 - regr_loss: 0.8837 - clf_loss: 0.6866 - regr_mae: 0.6570 - clf_accuracy: 0.5460 - val_loss: 2.4587 - val_regr_loss: 0.6769 - val_clf_loss: 0.6922 - val_regr_mae: 0.6457 - val_clf_accuracy: 0.5096 - lr: 1.5625e-05

# %%
def plot_multitask_history(hist):
    fig, ax = plt.subplots(2, 2, figsize=(16, 12))
    plotHelpers.plot_train_history(ax[0, 0], hist, 'Total loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[0, 1], hist, 'Accuracy', 'clf_accuracy', 'val_clf_accuracy')
    plotHelpers.plot_train_history(ax[1, 0], hist, 'MSE', 'regr_loss', 'val_regr_loss')
    plotHelpers.plot_train_history(ax[1, 1], hist, 'MAE', 'regr_mae', 'val_regr_mae')
    
plot_multitask_history(multitask_history);

# %% [markdown]
# ### Прогноз

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_multitask_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret, pred_direction_proba = univariate_multitask_lstm.predict_generator(test_multi_gen, verbose=1)
# Out:
# 5/5 [==============================] - 0s 11ms/step

# %%
np.set_printoptions(precision=3, suppress=True)

np.column_stack([pred_log_ret, pred_direction_proba])[-10:]
# Out:
# array([[-0.093,  0.47 ],
#        [-0.071,  0.485],
#        [-0.037,  0.502],
#        [-0.048,  0.48 ],
#        [-0.025,  0.472],
#        [-0.002,  0.476],
#        [-0.003,  0.459],
#        [ 0.015,  0.467],
#        [ 0.045,  0.506],
#        [ 0.035,  0.504]], dtype=float32)

# %% [markdown]
# #### Прогноз задачи регрессии

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret, figsize=(16, 20))

# %% [markdown]
# #### Прогноз задачи классификации

# %% [markdown]
# *Разделяющая способность по-прежнему слабая*.

# %%
true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 0.48550528

# %%
true_direction = test_multi_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([66, 82])), (array([0, 1]), array([80, 68])))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.47      0.58      0.52        66
#            1       0.59      0.49      0.53        82
#
#     accuracy                           0.53       148
#    macro avg       0.53      0.53      0.53       148
# weighted avg       0.54      0.53      0.53       148

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[38, 28],
#        [42, 40]])

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.475, 0.412],
#        [0.525, 0.588]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# # Выводы
#
# 1.  Размер батча сильно влияет на скорость обучения.
# 2.  Инициализация весов (`bias_initializer`) в слое **LSTM** оказалась очень важным параметром.
# 3.  Модель регрессии в целом выходит на модель случайного блуждания.
# 4.  Точность классификации низкая.
# 5.  Но при этом многозадачная модель показала результат классификации лучше, чем однозадачная.

# %% [markdown]
# <a href="https://colab.research.google.com/github/rklepov/hse-cs-ml-2018-2019-grad-work/blob/MSFT-1yr/MSFT/daily1y/05-lstm2_univar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # *Одномерная модель на LSTM* (2 слоя)
#
# В качестве единственного признака используется сама цена.

# %%
import os
import glob
import datetime
import pickle

import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from pandas_datareader import data as pdr

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
tf.__version__
# Out:
# TensorFlow 2.x selected.
# '2.1.0'

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Input, Dense, LSTM, GRU, Flatten, ReLU, LeakyReLU, Dropout, BatchNormalization
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers import Nadam

# %%
from mdp import TimeSeries
from mdp import MarketData
from mdp import MovingWindowFeatures
from mdp import ClassificationGenerator, RegressionGenerator, MultitaskGenerator
from mdp import invert_log_ret

import mdp.utils as utils
import mdp.plotHelpers as plotHelpers

# %%
import importlib

import mdp

importlib.reload(mdp)
importlib.reload(mdp.datasetGenerator)
importlib.reload(mdp.marketData)
importlib.reload(mdp.movingWindowFeatures)
importlib.reload(mdp.timeSeries)
importlib.reload(mdp.plotHelpers)
importlib.reload(mdp.utils);

# %% [markdown]
# # *Параметры*

# %%
INSTRUMENT = 'MSFT' # Microsoft corp
START_FROM = '2018-11-14'
END_DATE = '2020-01-01'
WINDOW_SIZE = 10
FORECAST_OFFSET=1
BATCH_SIZE = 8
VAL_SPLIT = '2019-11-01'
TEST_SPLIT = '2019-12-01'
FORCE_TRAIN = False

# %% [markdown]
# # *Исходные данные*
#
# Загрузка данных и вычисление индикаторов.

# %%
instr = MarketData.create_from_tiingo(INSTRUMENT, start=START_FROM, end=END_DATE)

# %%
instr.feature_names
# Out:
# ['o',
#  'h',
#  'l',
#  'c',
#  'v',
#  'ema14',
#  'ema30',
#  'macd',
#  'macd_signal',
#  'rsi14',
#  'bband20_upper',
#  'bband20_middle',
#  'bband20_lower',
#  'willr14',
#  'stochk',
#  'stochd',
#  'adline',
#  'adosc']

# %% [markdown]
# ## Целевая переменная

# %% [markdown]
# Цена закрытия.

# %%
orig_target = instr.c

# %% [markdown]
# Переходим к логарифмической доходности.

# %%
transformed_target = instr.c.transform(transforms={'ratios' : {}, 'ln' : {}})

# %%
plotHelpers.plot_transformed_timeseries_unit(instr,
                                             transformed_target,
                                             'Daily close price, USD', 'Daily log return')

# %% [markdown]
# ## Трансформация признаков
#
# Из признаков выбираем только цену закрытия. Временной ряд цен преобразуется к ряду логарифмических доходностей (что также позволяет убрать нестационарность).

# %%
def make_feature_selector():
    price_transformer = lambda: {'ratios': {}, 'ln': {}}
    diff_transformer = lambda o: {'diffs': {'order': o}}
    identity_transformer = lambda: {}
    feature_transformations = {
        'c': price_transformer(),
    }
    return feature_transformations

# %%
instr_transformed = instr.select_transform(make_feature_selector())

# %%
transformed_target = instr_transformed.c

# %% [markdown]
# ## Обучающая, валидационная и тестовая выборки

# %%
instr_train, instr_val_test = instr_transformed.train_test_split(VAL_SPLIT, window_size=WINDOW_SIZE,
                                                                 scaler=StandardScaler)
#                                                                  scaler=MinMaxScaler,
#                                                                  scaler_kwargs={'feature_range': (-1, 1)})

instr_val, instr_test = instr_val_test.train_test_split(TEST_SPLIT, window_size=WINDOW_SIZE, scaler=None)

len(instr_train), len(instr_val), len(instr_test)
# Out:
# (208, 30, 31)

# %% [markdown]
# ## Признаки - скользящие окна

# %%
train_mwf = MovingWindowFeatures.create(instr_train.c, [instr_train], instr_train.feature_names, window_size=WINDOW_SIZE)
val_mwf = MovingWindowFeatures.create(instr_val.c, [instr_val], instr_val.feature_names, window_size=WINDOW_SIZE)
test_mwf = MovingWindowFeatures.create(instr_test.c, [instr_test], instr_test.feature_names, window_size=WINDOW_SIZE)

len(instr_train), len(train_mwf), train_mwf.features.shape
# Out:
# (208, 198, (198, 10, 1))

# %% [markdown]
# Проверка, что скользящие окна соответствуют исходным данным.
#
# Возьмём произвольный признак и произвольное окно (строка #**41**). Проверим, что данные в точности совпадают:

# %%
def check_data(md, mwf, row):
    col = np.random.randint(len(mwf.feature_names))
    feature = mwf.feature_names[col]
    check = (getattr(md, feature).data[row:row + mwf.window_size] == mwf.features[row, :, col]).all()
    assert check
    return feature, check

check_data(instr_train, train_mwf, 41)
# Out:
# ('c', True)

# %% [markdown]
# # *Модели*

# %% [markdown]
# Модель с двумя LSTM слоями.

# %%
def build_lstm_layers(input_shape, latent_dim=(8, 16)):
    # формат входа: наша матрица (окно; признак)
    inp = Input(input_shape, name='input')

    # стекаем два уровня LSTM
    lstm = LSTM(latent_dim[0], return_sequences=True, 
                    recurrent_dropout=0.2, dropout=0.2, 
                    bias_initializer='he_uniform',
                    bias_regularizer=L1L2(0.01, 0.02),
                    kernel_regularizer=L1L2(0.01, 0.02),
                    recurrent_regularizer=L1L2(0.02, 0.02)
               )(inp)

    lstm = LSTM(latent_dim[1], return_sequences=True,
                    recurrent_dropout=0.2, dropout=0.2,
                    bias_initializer='he_uniform',
                    bias_regularizer=L1L2(0.01, 0.02),
                    kernel_regularizer=L1L2(0.01, 0.02),
                    recurrent_regularizer=L1L2(0.01, 0.02)
               )(lstm)
    
    lstm = Flatten()(lstm)
    
    return inp, lstm

# %% [markdown]
# #### Пути сохранения моделей:

# %%
model_path_root = 'models'
model_type_name = 'lstm2_univar'

def make_model_save_dir(path_root, type_name, class_name):
    save_dir = os.path.join(path_root, type_name, class_name)
    os.makedirs(save_dir, exist_ok=True)
    return save_dir

# %% [markdown]
# #### Общие коллбэки:

# %%
# уменьшение learning rate в случае, если loss не изменяется
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001, verbose=1)

# уменьшение learning rate в 2 раза каждую 5-ю эпоху
def lr_decay(e, lr):
    return lr * (1 - 0.5 * (0 == (e + 1) % 5))

lr_scheduler = LearningRateScheduler(schedule=lr_decay, verbose=1)

# %% [markdown]
# ## Задача регрессии
#
# Непосредственное прогнозирование цены следующего периода.

# %%
train_regr_gen = RegressionGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_regr_gen = RegressionGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_regr_gen = RegressionGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# Следующие числа соответствуют значению параметра `steps_per_epoch` метода [`fit_generator`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit_generator "tf.keras.layers.SimpleRNN &nbsp;|&nbsp; TensorFlow Core r2.0") - то есть это число батчей, которые генератор выдаст за одну эпоху обучения (если класс генератора поддерживает метод `len()`, то данный параметр можно не указывать).

# %%
len(train_regr_gen), len(val_regr_gen), len(test_regr_gen)
# Out:
# (25, 3, 3)

# %% [markdown]
# Один сэмпл данных представляет собой матрицу размером *(длина окна; число признаков)*

# %%
train_regr_gen.input_shape
# Out:
# (10, 1)

# %% [markdown]
# ### Модель для задачи регрессии

# %%
model_class_name = 'regression'

# %%
def build_regression_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=(16, 16))

    regr = Dense(32)(lstm)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    return Model(inputs=[inp], outputs=[regr])

# %%
univariate_regression_lstm = build_regression_model(train_regr_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:
# [`Nadam`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Nadam) (*Adam with Nestrov momentum*).

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Функция потерь:
#
# В качестве функции потерь будем использовать [MSE](https://www.tensorflow.org/api_docs/python/tf/keras/losses/MSE) (чтобы штрафовать за большие отклонения). Xотя хорошая функция потерь в контексте темы данной задачи - это [вопрос сложный](https://github.com/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Chapter5_LossFunctions/Ch5_LossFunctions_PyMC3.ipynb). В частности, здесь нам, очевидно, помимо абсолютного значения отклонения также важен его знак.

# %%
univariate_regression_lstm.compile(optimizer=optimizer,
                                   loss={'regr': 'mse'},
                                   metrics={'regr': 'mae'})

univariate_regression_lstm.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 10, 1)]           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 10, 16)            1152
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 16)            2112
# _________________________________________________________________
# flatten (Flatten)            (None, 160)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                5152
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32)                128
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 32)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# regr (Dense)                 (None, 1)                 33
# =================================================================
# Total params: 8,577
# Trainable params: 8,513
# Non-trainable params: 64
# _________________________________________________________________

# %% [markdown]
# #### Обучение:

# %%
regr_history = utils.train_model(univariate_regression_lstm,
                                 model_save_dir, train_regr_gen, val_regr_gen,
                                 callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                 force_train=FORCE_TRAIN, verbose=1)
# Out:
# WARNING:tensorflow:From /content/hse-cs-ml-2018-2019-grad-work/mdp/utils.py:79: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 25 steps, validate for 3 steps
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 21/25 [========================>.....] - ETA: 0s - loss: 8.6040 - mae: 1.0570
# Epoch 00001: val_loss improved from inf to 6.70387, saving model to models/lstm2_univar/regression/01.hdf5
# 25/25 [==============================] - 5s 206ms/step - loss: 8.4987 - mae: 1.0446 - val_loss: 6.7039 - val_mae: 0.2824
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 22/25 [=========================>....] - ETA: 0s - loss: 7.8090 - mae: 1.0055
# Epoch 00002: val_loss improved from 6.70387 to 6.11408, saving model to models/lstm2_univar/regression/02.hdf5
# 25/25 [==============================] - 0s 19ms/step - loss: 7.8402 - mae: 1.0160 - val_loss: 6.1141 - val_mae: 0.2775
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 23/25 [==========================>...] - ETA: 0s - loss: 7.1478 - mae: 0.9552
# Epoch 00003: val_loss improved from 6.11408 to 5.56214, saving model to models/lstm2_univar/regression/03.hdf5
# 25/25 [==============================] - 1s 25ms/step - loss: 7.0611 - mae: 0.9338 - val_loss: 5.5621 - val_mae: 0.2886
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 23/25 [==========================>...] - ETA: 0s - loss: 6.4851 - mae: 0.8957
# Epoch 00004: val_loss improved from 5.56214 to 5.06793, saving model to models/lstm2_univar/regression/04.hdf5
# 25/25 [==============================] - 0s 19ms/step - loss: 6.4207 - mae: 0.8823 - val_loss: 5.0679 - val_mae: 0.2803
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 22/25 [=========================>....] - ETA: 0s - loss: 6.1181 - mae: 0.9163
# Epoch 00005: val_loss improved from 5.06793 to 4.83248, saving model to models/lstm2_univar/regression/05.hdf5
# 25/25 [==============================] - 0s 18ms/step - loss: 6.0258 - mae: 0.8851 - val_loss: 4.8325 - val_mae: 0.2827
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 22/25 [=========================>....] - ETA: 0s - loss: 5.8487 - mae: 0.8803
# Epoch 00006: val_loss improved from 4.83248 to 4.60709, saving model to models/lstm2_univar/regression/06.hdf5
# 25/25 [==============================] - 0s 19ms/step - loss: 5.7657 - mae: 0.8507 - val_loss: 4.6071 - val_mae: 0.2930
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 24/25 [===========================>..] - ETA: 0s - loss: 5.5104 - mae: 0.8613
# Epoch 00007: val_loss improved from 4.60709 to 4.39715, saving model to models/lstm2_univar/regression/07.hdf5
# 25/25 [==============================] - 0s 19ms/step - loss: 5.4862 - mae: 0.8571 - val_loss: 4.3971 - val_mae: 0.3049
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 23/25 [==========================>...] - ETA: 0s - loss: 5.4350 - mae: 0.8780
# Epoch 00008: val_loss improved from 4.39715 to 4.19729, saving model to models/lstm2_univar/regression/08.hdf5
# 25/25 [==============================] - 0s 19ms/step - loss: 5.5021 - mae: 0.9051 - val_loss: 4.1973 - val_mae: 0.3023
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 23/25 [==========================>...] - ETA: 0s - loss: 5.3295 - mae: 0.9324
# Epoch 00009: val_loss improved from 4.19729 to 4.01063, saving model to models/lstm2_univar/regression/09.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 5.2604 - mae: 0.9142 - val_loss: 4.0106 - val_mae: 0.3077
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 23/25 [==========================>...] - ETA: 0s - loss: 5.0634 - mae: 0.8701
# Epoch 00010: val_loss improved from 4.01063 to 3.91762, saving model to models/lstm2_univar/regression/10.hdf5
# 25/25 [==============================] - 1s 20ms/step - loss: 5.0409 - mae: 0.8694 - val_loss: 3.9176 - val_mae: 0.3011
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 21/25 [========================>.....] - ETA: 0s - loss: 5.0051 - mae: 0.8760
# Epoch 00011: val_loss improved from 3.91762 to 3.82972, saving model to models/lstm2_univar/regression/11.hdf5
# 25/25 [==============================] - 0s 19ms/step - loss: 5.0179 - mae: 0.8854 - val_loss: 3.8297 - val_mae: 0.2815
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 22/25 [=========================>....] - ETA: 0s - loss: 4.9016 - mae: 0.9045
# Epoch 00012: val_loss improved from 3.82972 to 3.75500, saving model to models/lstm2_univar/regression/12.hdf5
# 25/25 [==============================] - 0s 19ms/step - loss: 4.8611 - mae: 0.8834 - val_loss: 3.7550 - val_mae: 0.2776
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 23/25 [==========================>...] - ETA: 0s - loss: 4.8107 - mae: 0.8603
# Epoch 00013: val_loss improved from 3.75500 to 3.67284, saving model to models/lstm2_univar/regression/13.hdf5
# 25/25 [==============================] - 0s 18ms/step - loss: 4.8055 - mae: 0.8679 - val_loss: 3.6728 - val_mae: 0.2773
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 22/25 [=========================>....] - ETA: 0s - loss: 4.6528 - mae: 0.8639
# Epoch 00014: val_loss improved from 3.67284 to 3.58233, saving model to models/lstm2_univar/regression/14.hdf5
# 25/25 [==============================] - 0s 19ms/step - loss: 4.6001 - mae: 0.8315 - val_loss: 3.5823 - val_mae: 0.2768
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 23/25 [==========================>...] - ETA: 0s - loss: 4.5841 - mae: 0.8281
# Epoch 00015: val_loss improved from 3.58233 to 3.53860, saving model to models/lstm2_univar/regression/15.hdf5
# 25/25 [==============================] - 0s 18ms/step - loss: 4.5451 - mae: 0.8170 - val_loss: 3.5386 - val_mae: 0.2910
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.5951 - mae: 0.8610
# Epoch 00016: val_loss improved from 3.53860 to 3.50042, saving model to models/lstm2_univar/regression/16.hdf5
# 25/25 [==============================] - 0s 19ms/step - loss: 4.5792 - mae: 0.8562 - val_loss: 3.5004 - val_mae: 0.2954
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 21/25 [========================>.....] - ETA: 0s - loss: 4.4850 - mae: 0.8708
# Epoch 00017: val_loss improved from 3.50042 to 3.46088, saving model to models/lstm2_univar/regression/17.hdf5
# 25/25 [==============================] - 0s 19ms/step - loss: 4.5237 - mae: 0.8788 - val_loss: 3.4609 - val_mae: 0.2870
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 21/25 [========================>.....] - ETA: 0s - loss: 4.4518 - mae: 0.8088
# Epoch 00018: val_loss improved from 3.46088 to 3.42346, saving model to models/lstm2_univar/regression/18.hdf5
# 25/25 [==============================] - 0s 18ms/step - loss: 4.4272 - mae: 0.8106 - val_loss: 3.4235 - val_mae: 0.2823
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.5397 - mae: 0.8906
# Epoch 00019: val_loss improved from 3.42346 to 3.38587, saving model to models/lstm2_univar/regression/19.hdf5
# 25/25 [==============================] - 0s 19ms/step - loss: 4.5091 - mae: 0.8788 - val_loss: 3.3859 - val_mae: 0.2787
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 23/25 [==========================>...] - ETA: 0s - loss: 4.3644 - mae: 0.8581
# Epoch 00020: val_loss improved from 3.38587 to 3.36652, saving model to models/lstm2_univar/regression/20.hdf5
# 25/25 [==============================] - 0s 19ms/step - loss: 4.3364 - mae: 0.8470 - val_loss: 3.3665 - val_mae: 0.2764
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 23/25 [==========================>...] - ETA: 0s - loss: 4.4599 - mae: 0.8668
# Epoch 00021: val_loss improved from 3.36652 to 3.34915, saving model to models/lstm2_univar/regression/21.hdf5
# 25/25 [==============================] - 0s 19ms/step - loss: 4.4672 - mae: 0.8660 - val_loss: 3.3491 - val_mae: 0.2730
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.3797 - mae: 0.8469
# Epoch 00022: val_loss improved from 3.34915 to 3.32712, saving model to models/lstm2_univar/regression/22.hdf5
# 25/25 [==============================] - 0s 19ms/step - loss: 4.4320 - mae: 0.8592 - val_loss: 3.3271 - val_mae: 0.2785
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 22/25 [=========================>....] - ETA: 0s - loss: 4.4107 - mae: 0.8808
# Epoch 00023: val_loss improved from 3.32712 to 3.31133, saving model to models/lstm2_univar/regression/23.hdf5
# 25/25 [==============================] - 0s 20ms/step - loss: 4.3853 - mae: 0.8751 - val_loss: 3.3113 - val_mae: 0.2731
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.2970 - mae: 0.8403
# Epoch 00024: val_loss improved from 3.31133 to 3.29365, saving model to models/lstm2_univar/regression/24.hdf5
# 25/25 [==============================] - 0s 18ms/step - loss: 4.2635 - mae: 0.8296 - val_loss: 3.2937 - val_mae: 0.2732
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.3623 - mae: 0.8568
# Epoch 00025: val_loss improved from 3.29365 to 3.28247, saving model to models/lstm2_univar/regression/25.hdf5
# 25/25 [==============================] - 0s 19ms/step - loss: 4.3553 - mae: 0.8588 - val_loss: 3.2825 - val_mae: 0.2724
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 23/25 [==========================>...] - ETA: 0s - loss: 4.3129 - mae: 0.8473
# Epoch 00026: val_loss improved from 3.28247 to 3.27296, saving model to models/lstm2_univar/regression/26.hdf5
# 25/25 [==============================] - 0s 19ms/step - loss: 4.3251 - mae: 0.8517 - val_loss: 3.2730 - val_mae: 0.2719
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 21/25 [========================>.....] - ETA: 0s - loss: 4.2719 - mae: 0.8405
# Epoch 00027: val_loss improved from 3.27296 to 3.26487, saving model to models/lstm2_univar/regression/27.hdf5
# 25/25 [==============================] - 0s 19ms/step - loss: 4.2727 - mae: 0.8286 - val_loss: 3.2649 - val_mae: 0.2691
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.2434 - mae: 0.8273
# Epoch 00028: val_loss improved from 3.26487 to 3.25447, saving model to models/lstm2_univar/regression/28.hdf5
# 25/25 [==============================] - 0s 18ms/step - loss: 4.2110 - mae: 0.8167 - val_loss: 3.2545 - val_mae: 0.2676
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 21/25 [========================>.....] - ETA: 0s - loss: 4.3176 - mae: 0.8798
# Epoch 00029: val_loss improved from 3.25447 to 3.23853, saving model to models/lstm2_univar/regression/29.hdf5
# 25/25 [==============================] - 0s 18ms/step - loss: 4.2905 - mae: 0.8759 - val_loss: 3.2385 - val_mae: 0.2730
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 21/25 [========================>.....] - ETA: 0s - loss: 4.2982 - mae: 0.8326
# Epoch 00030: val_loss improved from 3.23853 to 3.23275, saving model to models/lstm2_univar/regression/30.hdf5
# 25/25 [==============================] - 0s 18ms/step - loss: 4.2421 - mae: 0.8194 - val_loss: 3.2328 - val_mae: 0.2746
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 21/25 [========================>.....] - ETA: 0s - loss: 4.3725 - mae: 0.9109
# Epoch 00031: val_loss improved from 3.23275 to 3.22951, saving model to models/lstm2_univar/regression/31.hdf5
# 25/25 [==============================] - 0s 20ms/step - loss: 4.3590 - mae: 0.8978 - val_loss: 3.2295 - val_mae: 0.2705
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 23/25 [==========================>...] - ETA: 0s - loss: 4.3202 - mae: 0.8733
# Epoch 00032: val_loss improved from 3.22951 to 3.22882, saving model to models/lstm2_univar/regression/32.hdf5
# 25/25 [==============================] - 0s 19ms/step - loss: 4.2615 - mae: 0.8538 - val_loss: 3.2288 - val_mae: 0.2667

# %%
def plot_regr_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'MSE', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'MAE', 'mae', 'val_mae')
    
plot_regr_history(regr_history);

# %% [markdown]
# ### Прогноз задачи регрессии

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_regression_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret_test = univariate_regression_lstm.predict_generator(test_regr_gen, verbose=1)
# Out:
# WARNING:tensorflow:From <ipython-input-39-c831dcaf40ce>:1: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.
# 3/3 [==============================] - 0s 118ms/step

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret_test, figsize=(16, 10), datetime_unit='D')

# %% [markdown]
# ## Задача классификации
#
# Прогнозируем направление изменения цены по сравнению с предыдущим периодом (**0** - снижение, **1** - рост).

# %%
model_class_name = 'classification'

# %%
train_clf_gen = ClassificationGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_clf_gen = ClassificationGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_clf_gen = ClassificationGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_classification_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=(16, 16))

    clf = Dense(32)(lstm)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)

    return Model(inputs=[inp], outputs=[clf])

# %%
univariate_classification_lstm = build_classification_model(test_clf_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
univariate_classification_lstm.compile(optimizer=optimizer,
                                       loss={'clf': 'binary_crossentropy'},
                                       metrics={'clf': 'accuracy'})

univariate_classification_lstm.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 10, 1)]           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 10, 16)            1152
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 10, 16)            2112
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 160)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                5152
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32)                128
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 32)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# clf (Dense)                  (None, 1)                 33
# =================================================================
# Total params: 8,577
# Trainable params: 8,513
# Non-trainable params: 64
# _________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
clf_history = utils.train_model(univariate_classification_lstm,
                                model_save_dir, train_clf_gen, val_clf_gen,
                                callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                force_train=FORCE_TRAIN, verbose=1)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 25 steps, validate for 3 steps
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 21/25 [========================>.....] - ETA: 0s - loss: 7.4925 - accuracy: 0.4881
# Epoch 00001: val_loss improved from inf to 6.80951, saving model to models/lstm2_univar/classification/01.hdf5
# 25/25 [==============================] - 5s 204ms/step - loss: 7.4210 - accuracy: 0.5000 - val_loss: 6.8095 - val_accuracy: 0.5000
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 23/25 [==========================>...] - ETA: 0s - loss: 6.4749 - accuracy: 0.5326
# Epoch 00002: val_loss improved from 6.80951 to 5.85950, saving model to models/lstm2_univar/classification/02.hdf5
# 25/25 [==============================] - 0s 19ms/step - loss: 6.4309 - accuracy: 0.5354 - val_loss: 5.8595 - val_accuracy: 0.5000
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 23/25 [==========================>...] - ETA: 0s - loss: 5.6358 - accuracy: 0.4674
# Epoch 00003: val_loss improved from 5.85950 to 5.06476, saving model to models/lstm2_univar/classification/03.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 5.5823 - accuracy: 0.4899 - val_loss: 5.0648 - val_accuracy: 0.5000
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 23/25 [==========================>...] - ETA: 0s - loss: 4.8530 - accuracy: 0.4402
# Epoch 00004: val_loss improved from 5.06476 to 4.37840, saving model to models/lstm2_univar/classification/04.hdf5
# 25/25 [==============================] - 0s 20ms/step - loss: 4.8209 - accuracy: 0.4545 - val_loss: 4.3784 - val_accuracy: 0.7500
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 23/25 [==========================>...] - ETA: 0s - loss: 4.2882 - accuracy: 0.5489
# Epoch 00005: val_loss improved from 4.37840 to 4.08076, saving model to models/lstm2_univar/classification/05.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 4.2795 - accuracy: 0.5303 - val_loss: 4.0808 - val_accuracy: 0.5000
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 23/25 [==========================>...] - ETA: 0s - loss: 4.0477 - accuracy: 0.4457
# Epoch 00006: val_loss improved from 4.08076 to 3.81140, saving model to models/lstm2_univar/classification/06.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 4.0288 - accuracy: 0.4545 - val_loss: 3.8114 - val_accuracy: 0.5000
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 23/25 [==========================>...] - ETA: 0s - loss: 3.7707 - accuracy: 0.5272
# Epoch 00007: val_loss improved from 3.81140 to 3.56341, saving model to models/lstm2_univar/classification/07.hdf5
# 25/25 [==============================] - 1s 20ms/step - loss: 3.7693 - accuracy: 0.5202 - val_loss: 3.5634 - val_accuracy: 0.5000
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 22/25 [=========================>....] - ETA: 0s - loss: 3.5283 - accuracy: 0.4886
# Epoch 00008: val_loss improved from 3.56341 to 3.33677, saving model to models/lstm2_univar/classification/08.hdf5
# 25/25 [==============================] - 1s 20ms/step - loss: 3.5049 - accuracy: 0.4899 - val_loss: 3.3368 - val_accuracy: 0.5500
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 23/25 [==========================>...] - ETA: 0s - loss: 3.3043 - accuracy: 0.5326
# Epoch 00009: val_loss improved from 3.33677 to 3.13175, saving model to models/lstm2_univar/classification/09.hdf5
# 25/25 [==============================] - 0s 20ms/step - loss: 3.2925 - accuracy: 0.5354 - val_loss: 3.1317 - val_accuracy: 0.6500
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 22/25 [=========================>....] - ETA: 0s - loss: 3.1025 - accuracy: 0.5341
# Epoch 00010: val_loss improved from 3.13175 to 3.03281, saving model to models/lstm2_univar/classification/10.hdf5
# 25/25 [==============================] - 1s 20ms/step - loss: 3.1004 - accuracy: 0.5303 - val_loss: 3.0328 - val_accuracy: 0.5000
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 22/25 [=========================>....] - ETA: 0s - loss: 3.0409 - accuracy: 0.5170
# Epoch 00011: val_loss improved from 3.03281 to 2.94315, saving model to models/lstm2_univar/classification/11.hdf5
# 25/25 [==============================] - 1s 20ms/step - loss: 3.0331 - accuracy: 0.5000 - val_loss: 2.9431 - val_accuracy: 0.5000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 22/25 [=========================>....] - ETA: 0s - loss: 2.9521 - accuracy: 0.5000
# Epoch 00012: val_loss improved from 2.94315 to 2.85898, saving model to models/lstm2_univar/classification/12.hdf5
# 25/25 [==============================] - 0s 19ms/step - loss: 2.9494 - accuracy: 0.5000 - val_loss: 2.8590 - val_accuracy: 0.5000
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 23/25 [==========================>...] - ETA: 0s - loss: 2.8540 - accuracy: 0.5489
# Epoch 00013: val_loss improved from 2.85898 to 2.77775, saving model to models/lstm2_univar/classification/13.hdf5
# 25/25 [==============================] - 0s 20ms/step - loss: 2.8599 - accuracy: 0.5354 - val_loss: 2.7777 - val_accuracy: 0.5000
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 23/25 [==========================>...] - ETA: 0s - loss: 2.8153 - accuracy: 0.5272
# Epoch 00014: val_loss improved from 2.77775 to 2.70079, saving model to models/lstm2_univar/classification/14.hdf5
# 25/25 [==============================] - 0s 20ms/step - loss: 2.8162 - accuracy: 0.5152 - val_loss: 2.7008 - val_accuracy: 0.5000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 23/25 [==========================>...] - ETA: 0s - loss: 2.6905 - accuracy: 0.5435
# Epoch 00015: val_loss improved from 2.70079 to 2.66278, saving model to models/lstm2_univar/classification/15.hdf5
# 25/25 [==============================] - 0s 20ms/step - loss: 2.6856 - accuracy: 0.5404 - val_loss: 2.6628 - val_accuracy: 0.5000
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 23/25 [==========================>...] - ETA: 0s - loss: 2.6738 - accuracy: 0.5326
# Epoch 00016: val_loss improved from 2.66278 to 2.62607, saving model to models/lstm2_univar/classification/16.hdf5
# 25/25 [==============================] - 0s 20ms/step - loss: 2.6753 - accuracy: 0.5354 - val_loss: 2.6261 - val_accuracy: 0.5000
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.6142 - accuracy: 0.5312
# Epoch 00017: val_loss improved from 2.62607 to 2.58983, saving model to models/lstm2_univar/classification/17.hdf5
# 25/25 [==============================] - 1s 20ms/step - loss: 2.6130 - accuracy: 0.5303 - val_loss: 2.5898 - val_accuracy: 0.5000
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 22/25 [=========================>....] - ETA: 0s - loss: 2.5846 - accuracy: 0.5398
# Epoch 00018: val_loss improved from 2.58983 to 2.55604, saving model to models/lstm2_univar/classification/18.hdf5
# 25/25 [==============================] - 1s 20ms/step - loss: 2.5868 - accuracy: 0.5404 - val_loss: 2.5560 - val_accuracy: 0.5000
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 22/25 [=========================>....] - ETA: 0s - loss: 2.5868 - accuracy: 0.4659
# Epoch 00019: val_loss improved from 2.55604 to 2.52062, saving model to models/lstm2_univar/classification/19.hdf5
# 25/25 [==============================] - 1s 20ms/step - loss: 2.5757 - accuracy: 0.4848 - val_loss: 2.5206 - val_accuracy: 0.5000
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 22/25 [=========================>....] - ETA: 0s - loss: 2.5625 - accuracy: 0.5284
# Epoch 00020: val_loss improved from 2.52062 to 2.50268, saving model to models/lstm2_univar/classification/20.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.5583 - accuracy: 0.5303 - val_loss: 2.5027 - val_accuracy: 0.5000
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 23/25 [==========================>...] - ETA: 0s - loss: 2.4996 - accuracy: 0.5598
# Epoch 00021: val_loss improved from 2.50268 to 2.48622, saving model to models/lstm2_univar/classification/21.hdf5
# 25/25 [==============================] - 1s 20ms/step - loss: 2.4961 - accuracy: 0.5657 - val_loss: 2.4862 - val_accuracy: 0.5000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 22/25 [=========================>....] - ETA: 0s - loss: 2.5176 - accuracy: 0.4943
# Epoch 00022: val_loss improved from 2.48622 to 2.47044, saving model to models/lstm2_univar/classification/22.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.5105 - accuracy: 0.5101 - val_loss: 2.4704 - val_accuracy: 0.5000
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 22/25 [=========================>....] - ETA: 0s - loss: 2.4932 - accuracy: 0.4886
# Epoch 00023: val_loss improved from 2.47044 to 2.45488, saving model to models/lstm2_univar/classification/23.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.4930 - accuracy: 0.4949 - val_loss: 2.4549 - val_accuracy: 0.4500
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 22/25 [=========================>....] - ETA: 0s - loss: 2.5068 - accuracy: 0.4716
# Epoch 00024: val_loss improved from 2.45488 to 2.44250, saving model to models/lstm2_univar/classification/24.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.5045 - accuracy: 0.4596 - val_loss: 2.4425 - val_accuracy: 0.5000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 24/25 [===========================>..] - ETA: 0s - loss: 2.4545 - accuracy: 0.4896
# Epoch 00025: val_loss improved from 2.44250 to 2.43420, saving model to models/lstm2_univar/classification/25.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 2.4603 - accuracy: 0.4899 - val_loss: 2.4342 - val_accuracy: 0.5000
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 22/25 [=========================>....] - ETA: 0s - loss: 2.4646 - accuracy: 0.4886
# Epoch 00026: val_loss improved from 2.43420 to 2.42574, saving model to models/lstm2_univar/classification/26.hdf5
# 25/25 [==============================] - 0s 20ms/step - loss: 2.4655 - accuracy: 0.4798 - val_loss: 2.4257 - val_accuracy: 0.5500
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 23/25 [==========================>...] - ETA: 0s - loss: 2.4564 - accuracy: 0.4837
# Epoch 00027: val_loss improved from 2.42574 to 2.41711, saving model to models/lstm2_univar/classification/27.hdf5
# 25/25 [==============================] - 0s 20ms/step - loss: 2.4514 - accuracy: 0.5000 - val_loss: 2.4171 - val_accuracy: 0.5500
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 22/25 [=========================>....] - ETA: 0s - loss: 2.3945 - accuracy: 0.5739
# Epoch 00028: val_loss improved from 2.41711 to 2.40808, saving model to models/lstm2_univar/classification/28.hdf5
# 25/25 [==============================] - 1s 20ms/step - loss: 2.3930 - accuracy: 0.5859 - val_loss: 2.4081 - val_accuracy: 0.5500
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 23/25 [==========================>...] - ETA: 0s - loss: 2.4546 - accuracy: 0.5163
# Epoch 00029: val_loss improved from 2.40808 to 2.40025, saving model to models/lstm2_univar/classification/29.hdf5
# 25/25 [==============================] - 1s 20ms/step - loss: 2.4585 - accuracy: 0.5101 - val_loss: 2.4003 - val_accuracy: 0.5500
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 22/25 [=========================>....] - ETA: 0s - loss: 2.4511 - accuracy: 0.4886
# Epoch 00030: val_loss improved from 2.40025 to 2.39682, saving model to models/lstm2_univar/classification/30.hdf5
# 25/25 [==============================] - 1s 20ms/step - loss: 2.4524 - accuracy: 0.4848 - val_loss: 2.3968 - val_accuracy: 0.5500
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 23/25 [==========================>...] - ETA: 0s - loss: 2.4379 - accuracy: 0.4891
# Epoch 00031: val_loss improved from 2.39682 to 2.39337, saving model to models/lstm2_univar/classification/31.hdf5
# 25/25 [==============================] - 0s 20ms/step - loss: 2.4320 - accuracy: 0.4949 - val_loss: 2.3934 - val_accuracy: 0.6000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 22/25 [=========================>....] - ETA: 0s - loss: 2.3761 - accuracy: 0.5852
# Epoch 00032: val_loss improved from 2.39337 to 2.38895, saving model to models/lstm2_univar/classification/32.hdf5
# 25/25 [==============================] - 1s 20ms/step - loss: 2.3834 - accuracy: 0.5707 - val_loss: 2.3890 - val_accuracy: 0.6000

# %%
def plot_clf_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'Loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'Accuracy', 'accuracy', 'val_accuracy')
    
plot_clf_history(clf_history);

# %% [markdown]
# ### Прогноз задачи классификации

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_classification_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %%
pred_direction_proba = univariate_classification_lstm.predict_generator(test_clf_gen, verbose=1)

true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 3/3 [==============================] - 0s 128ms/step
# 0.49361765

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([11, 10])), (array([0, 1]), array([13,  8])))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.73      0.67        11
#            1       0.62      0.50      0.56        10
#
#     accuracy                           0.62        21
#    macro avg       0.62      0.61      0.61        21
# weighted avg       0.62      0.62      0.61        21

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[8, 3],
#        [5, 5]])

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.61538462, 0.375     ],
#        [0.38461538, 0.625     ]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# ## Многозадачная модель: одновременно регрессия и классификация

# %%
model_class_name = 'multitask'

# %%
train_multi_gen = MultitaskGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_multi_gen = MultitaskGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_multi_gen = MultitaskGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_multitask_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=(16, 16))

    # первый выход: задача регрссии
    regr = Dense(32)(lstm)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    # второй выход: задача классификации
    clf = Dense(32)(lstm)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)
    
    return Model(inputs=[inp], outputs=[regr, clf])

# %%
univariate_multitask_lstm = build_multitask_model(train_multi_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
univariate_multitask_lstm.compile(optimizer=optimizer,
                                  loss={'regr': 'mse', 'clf': 'binary_crossentropy'},
                                  loss_weights={'regr': 2., 'clf': 1.},
                                  metrics={'regr': 'mae', 'clf' : 'accuracy'})

univariate_multitask_lstm.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 10, 1)]      0
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 10, 16)       1152        input[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 10, 16)       2112        lstm_4[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 160)          0           lstm_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 32)           5152        flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 32)           5152        flatten_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32)           128         dense_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32)           128         dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 32)           0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 32)           0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32)           0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 32)           0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# regr (Dense)                    (None, 1)            33          dropout_2[0][0]
# __________________________________________________________________________________________________
# clf (Dense)                     (None, 1)            33          dropout_3[0][0]
# ==================================================================================================
# Total params: 13,890
# Trainable params: 13,762
# Non-trainable params: 128
# __________________________________________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
multitask_history = utils.train_model(univariate_multitask_lstm,
                                      model_save_dir, train_multi_gen, val_multi_gen,
                                      callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                      force_train=FORCE_TRAIN, verbose=1)
# Out:
# Train for 25 steps, validate for 3 steps
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 23/25 [==========================>...] - ETA: 0s - loss: 12.2790 - regr_loss: 2.2172 - clf_loss: 0.8143 - regr_mae: 1.1886 - clf_accuracy: 0.4946
# Epoch 00001: val_loss improved from inf to 7.99142, saving model to models/lstm2_univar/multitask/01.hdf5
# 25/25 [==============================] - 6s 252ms/step - loss: 12.2787 - regr_loss: 2.2334 - clf_loss: 0.7949 - regr_mae: 1.1902 - clf_accuracy: 0.5101 - val_loss: 7.9914 - val_regr_loss: 0.2140 - val_clf_loss: 0.7026 - val_regr_mae: 0.3284 - val_clf_accuracy: 0.5000
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 21/25 [========================>.....] - ETA: 0s - loss: 10.7846 - regr_loss: 1.6084 - clf_loss: 0.8406 - regr_mae: 1.0165 - clf_accuracy: 0.4167
# Epoch 00002: val_loss improved from 7.99142 to 7.63989, saving model to models/lstm2_univar/multitask/02.hdf5
# 25/25 [==============================] - 1s 20ms/step - loss: 10.7758 - regr_loss: 1.6294 - clf_loss: 0.8167 - regr_mae: 1.0305 - clf_accuracy: 0.4343 - val_loss: 7.6399 - val_regr_loss: 0.2114 - val_clf_loss: 0.6946 - val_regr_mae: 0.3261 - val_clf_accuracy: 0.5000
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 21/25 [========================>.....] - ETA: 0s - loss: 10.2451 - regr_loss: 1.5834 - clf_loss: 0.6916 - regr_mae: 0.9867 - clf_accuracy: 0.6012
# Epoch 00003: val_loss improved from 7.63989 to 7.25877, saving model to models/lstm2_univar/multitask/03.hdf5
# 25/25 [==============================] - 1s 20ms/step - loss: 10.3404 - regr_loss: 1.6326 - clf_loss: 0.7152 - regr_mae: 1.0127 - clf_accuracy: 0.5859 - val_loss: 7.2588 - val_regr_loss: 0.1898 - val_clf_loss: 0.6944 - val_regr_mae: 0.3016 - val_clf_accuracy: 0.5000
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 24/25 [===========================>..] - ETA: 0s - loss: 9.9651 - regr_loss: 1.5849 - clf_loss: 0.7579 - regr_mae: 0.9968 - clf_accuracy: 0.5156
# Epoch 00004: val_loss improved from 7.25877 to 7.05198, saving model to models/lstm2_univar/multitask/04.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 9.9545 - regr_loss: 1.5823 - clf_loss: 0.7588 - regr_mae: 1.0004 - clf_accuracy: 0.5202 - val_loss: 7.0520 - val_regr_loss: 0.2428 - val_clf_loss: 0.6996 - val_regr_mae: 0.3592 - val_clf_accuracy: 0.5000
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 24/25 [===========================>..] - ETA: 0s - loss: 10.0796 - regr_loss: 1.7692 - clf_loss: 0.7463 - regr_mae: 1.0865 - clf_accuracy: 0.5208
# Epoch 00005: val_loss improved from 7.05198 to 6.78383, saving model to models/lstm2_univar/multitask/05.hdf5
# 25/25 [==============================] - 0s 20ms/step - loss: 10.1831 - regr_loss: 1.8219 - clf_loss: 0.7484 - regr_mae: 1.0975 - clf_accuracy: 0.5152 - val_loss: 6.7838 - val_regr_loss: 0.1900 - val_clf_loss: 0.6925 - val_regr_mae: 0.3026 - val_clf_accuracy: 0.6500
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 22/25 [=========================>....] - ETA: 0s - loss: 9.2931 - regr_loss: 1.4383 - clf_loss: 0.7690 - regr_mae: 0.9228 - clf_accuracy: 0.4489
# Epoch 00006: val_loss improved from 6.78383 to 6.58239, saving model to models/lstm2_univar/multitask/06.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 9.2139 - regr_loss: 1.4061 - clf_loss: 0.7627 - regr_mae: 0.9141 - clf_accuracy: 0.4444 - val_loss: 6.5824 - val_regr_loss: 0.1666 - val_clf_loss: 0.6892 - val_regr_mae: 0.2865 - val_clf_accuracy: 0.5000
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 22/25 [=========================>....] - ETA: 0s - loss: 9.6456 - regr_loss: 1.7016 - clf_loss: 0.7465 - regr_mae: 0.9920 - clf_accuracy: 0.5114
# Epoch 00007: val_loss improved from 6.58239 to 6.45434, saving model to models/lstm2_univar/multitask/07.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 9.5883 - regr_loss: 1.6808 - clf_loss: 0.7386 - regr_mae: 0.9786 - clf_accuracy: 0.5202 - val_loss: 6.4543 - val_regr_loss: 0.1784 - val_clf_loss: 0.6890 - val_regr_mae: 0.2913 - val_clf_accuracy: 0.5000
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 23/25 [==========================>...] - ETA: 0s - loss: 9.2905 - regr_loss: 1.6094 - clf_loss: 0.7265 - regr_mae: 1.0257 - clf_accuracy: 0.5217
# Epoch 00008: val_loss improved from 6.45434 to 6.27175, saving model to models/lstm2_univar/multitask/08.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 9.4321 - regr_loss: 1.6839 - clf_loss: 0.7241 - regr_mae: 1.0424 - clf_accuracy: 0.5253 - val_loss: 6.2718 - val_regr_loss: 0.1589 - val_clf_loss: 0.6891 - val_regr_mae: 0.2850 - val_clf_accuracy: 0.5000
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 24/25 [===========================>..] - ETA: 0s - loss: 8.8818 - regr_loss: 1.4877 - clf_loss: 0.7047 - regr_mae: 0.9759 - clf_accuracy: 0.5625
# Epoch 00009: val_loss improved from 6.27175 to 6.13235, saving model to models/lstm2_univar/multitask/09.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 8.8751 - regr_loss: 1.4872 - clf_loss: 0.7016 - regr_mae: 0.9768 - clf_accuracy: 0.5657 - val_loss: 6.1324 - val_regr_loss: 0.1563 - val_clf_loss: 0.6914 - val_regr_mae: 0.2885 - val_clf_accuracy: 0.5000
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 22/25 [=========================>....] - ETA: 0s - loss: 8.9423 - regr_loss: 1.5613 - clf_loss: 0.7205 - regr_mae: 0.9785 - clf_accuracy: 0.5455
# Epoch 00010: val_loss improved from 6.13235 to 6.08791, saving model to models/lstm2_univar/multitask/10.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 8.7461 - regr_loss: 1.4529 - clf_loss: 0.7443 - regr_mae: 0.9491 - clf_accuracy: 0.5202 - val_loss: 6.0879 - val_regr_loss: 0.1675 - val_clf_loss: 0.6937 - val_regr_mae: 0.2835 - val_clf_accuracy: 0.5000
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 23/25 [==========================>...] - ETA: 0s - loss: 8.4796 - regr_loss: 1.3581 - clf_loss: 0.7339 - regr_mae: 0.9300 - clf_accuracy: 0.5109
# Epoch 00011: val_loss improved from 6.08791 to 6.00151, saving model to models/lstm2_univar/multitask/11.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 8.4266 - regr_loss: 1.3327 - clf_loss: 0.7344 - regr_mae: 0.9218 - clf_accuracy: 0.5152 - val_loss: 6.0015 - val_regr_loss: 0.1587 - val_clf_loss: 0.6931 - val_regr_mae: 0.2870 - val_clf_accuracy: 0.5000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 22/25 [=========================>....] - ETA: 0s - loss: 8.6500 - regr_loss: 1.4757 - clf_loss: 0.7354 - regr_mae: 0.9329 - clf_accuracy: 0.5170
# Epoch 00012: val_loss improved from 6.00151 to 5.93021, saving model to models/lstm2_univar/multitask/12.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 8.5190 - regr_loss: 1.4067 - clf_loss: 0.7459 - regr_mae: 0.9180 - clf_accuracy: 0.5000 - val_loss: 5.9302 - val_regr_loss: 0.1558 - val_clf_loss: 0.6940 - val_regr_mae: 0.2918 - val_clf_accuracy: 0.5000
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 22/25 [=========================>....] - ETA: 0s - loss: 8.5110 - regr_loss: 1.4308 - clf_loss: 0.7528 - regr_mae: 0.9202 - clf_accuracy: 0.4545
# Epoch 00013: val_loss improved from 5.93021 to 5.86192, saving model to models/lstm2_univar/multitask/13.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 8.4431 - regr_loss: 1.3996 - clf_loss: 0.7508 - regr_mae: 0.9174 - clf_accuracy: 0.4596 - val_loss: 5.8619 - val_regr_loss: 0.1547 - val_clf_loss: 0.6943 - val_regr_mae: 0.2949 - val_clf_accuracy: 0.5000
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 22/25 [=========================>....] - ETA: 0s - loss: 8.6703 - regr_loss: 1.5301 - clf_loss: 0.7798 - regr_mae: 0.9645 - clf_accuracy: 0.4716
# Epoch 00014: val_loss improved from 5.86192 to 5.79201, saving model to models/lstm2_univar/multitask/14.hdf5
# 25/25 [==============================] - 1s 21ms/step - loss: 8.5868 - regr_loss: 1.4917 - clf_loss: 0.7777 - regr_mae: 0.9440 - clf_accuracy: 0.4747 - val_loss: 5.7920 - val_regr_loss: 0.1556 - val_clf_loss: 0.6885 - val_regr_mae: 0.2984 - val_clf_accuracy: 0.5000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 22/25 [=========================>....] - ETA: 0s - loss: 8.6474 - regr_loss: 1.5771 - clf_loss: 0.7152 - regr_mae: 0.9681 - clf_accuracy: 0.5568
# Epoch 00015: val_loss improved from 5.79201 to 5.75867, saving model to models/lstm2_univar/multitask/15.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 8.4945 - regr_loss: 1.4959 - clf_loss: 0.7260 - regr_mae: 0.9448 - clf_accuracy: 0.5556 - val_loss: 5.7587 - val_regr_loss: 0.1557 - val_clf_loss: 0.6884 - val_regr_mae: 0.2974 - val_clf_accuracy: 0.5000
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 22/25 [=========================>....] - ETA: 0s - loss: 8.2082 - regr_loss: 1.3771 - clf_loss: 0.7087 - regr_mae: 0.8946 - clf_accuracy: 0.5284
# Epoch 00016: val_loss improved from 5.75867 to 5.73557, saving model to models/lstm2_univar/multitask/16.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 8.3834 - regr_loss: 1.4688 - clf_loss: 0.7022 - regr_mae: 0.9320 - clf_accuracy: 0.5354 - val_loss: 5.7356 - val_regr_loss: 0.1602 - val_clf_loss: 0.6886 - val_regr_mae: 0.2869 - val_clf_accuracy: 0.5000
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 22/25 [=========================>....] - ETA: 0s - loss: 8.1190 - regr_loss: 1.3653 - clf_loss: 0.6754 - regr_mae: 0.9296 - clf_accuracy: 0.5795
# Epoch 00017: val_loss improved from 5.73557 to 5.72282, saving model to models/lstm2_univar/multitask/17.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 8.0731 - regr_loss: 1.3427 - clf_loss: 0.6764 - regr_mae: 0.9204 - clf_accuracy: 0.5758 - val_loss: 5.7228 - val_regr_loss: 0.1693 - val_clf_loss: 0.6900 - val_regr_mae: 0.2885 - val_clf_accuracy: 0.5500
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 22/25 [=========================>....] - ETA: 0s - loss: 7.9550 - regr_loss: 1.2506 - clf_loss: 0.7729 - regr_mae: 0.8981 - clf_accuracy: 0.4432
# Epoch 00018: val_loss improved from 5.72282 to 5.68898, saving model to models/lstm2_univar/multitask/18.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 7.9016 - regr_loss: 1.2344 - clf_loss: 0.7532 - regr_mae: 0.8848 - clf_accuracy: 0.4747 - val_loss: 5.6890 - val_regr_loss: 0.1682 - val_clf_loss: 0.6905 - val_regr_mae: 0.2860 - val_clf_accuracy: 0.5500
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 22/25 [=========================>....] - ETA: 0s - loss: 7.9396 - regr_loss: 1.2874 - clf_loss: 0.7163 - regr_mae: 0.8884 - clf_accuracy: 0.5795
# Epoch 00019: val_loss improved from 5.68898 to 5.65536, saving model to models/lstm2_univar/multitask/19.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 7.8571 - regr_loss: 1.2406 - clf_loss: 0.7290 - regr_mae: 0.8758 - clf_accuracy: 0.5657 - val_loss: 5.6554 - val_regr_loss: 0.1676 - val_clf_loss: 0.6905 - val_regr_mae: 0.2877 - val_clf_accuracy: 0.5000
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 22/25 [=========================>....] - ETA: 0s - loss: 7.6148 - regr_loss: 1.1266 - clf_loss: 0.7387 - regr_mae: 0.8349 - clf_accuracy: 0.5284
# Epoch 00020: val_loss did not improve from 5.65536
# 25/25 [==============================] - 1s 20ms/step - loss: 7.6779 - regr_loss: 1.1591 - clf_loss: 0.7373 - regr_mae: 0.8495 - clf_accuracy: 0.5354 - val_loss: 5.6697 - val_regr_loss: 0.1806 - val_clf_loss: 0.6947 - val_regr_mae: 0.2932 - val_clf_accuracy: 0.5000
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 22/25 [=========================>....] - ETA: 0s - loss: 8.2920 - regr_loss: 1.4940 - clf_loss: 0.6971 - regr_mae: 0.9201 - clf_accuracy: 0.5625
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.2500000593718141e-05.
#
# Epoch 00021: val_loss did not improve from 5.65536
# 25/25 [==============================] - 1s 20ms/step - loss: 8.1524 - regr_loss: 1.4225 - clf_loss: 0.7012 - regr_mae: 0.9066 - clf_accuracy: 0.5657 - val_loss: 5.6571 - val_regr_loss: 0.1828 - val_clf_loss: 0.6938 - val_regr_mae: 0.2931 - val_clf_accuracy: 0.5000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 22/32
# 22/25 [=========================>....] - ETA: 0s - loss: 7.9305 - regr_loss: 1.3096 - clf_loss: 0.7153 - regr_mae: 0.9063 - clf_accuracy: 0.5341
# Epoch 00022: val_loss improved from 5.65536 to 5.64988, saving model to models/lstm2_univar/multitask/22.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 8.0884 - regr_loss: 1.3875 - clf_loss: 0.7179 - regr_mae: 0.9359 - clf_accuracy: 0.5354 - val_loss: 5.6499 - val_regr_loss: 0.1809 - val_clf_loss: 0.6939 - val_regr_mae: 0.2928 - val_clf_accuracy: 0.5500
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 23/32
# 22/25 [=========================>....] - ETA: 0s - loss: 7.6423 - regr_loss: 1.1476 - clf_loss: 0.7543 - regr_mae: 0.8506 - clf_accuracy: 0.5114
# Epoch 00023: val_loss improved from 5.64988 to 5.64614, saving model to models/lstm2_univar/multitask/23.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 7.6546 - regr_loss: 1.1542 - clf_loss: 0.7537 - regr_mae: 0.8534 - clf_accuracy: 0.5051 - val_loss: 5.6461 - val_regr_loss: 0.1811 - val_clf_loss: 0.6929 - val_regr_mae: 0.2935 - val_clf_accuracy: 0.5500
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 24/32
# 22/25 [=========================>....] - ETA: 0s - loss: 8.5534 - regr_loss: 1.6115 - clf_loss: 0.7409 - regr_mae: 0.9666 - clf_accuracy: 0.5284
# Epoch 00024: val_loss improved from 5.64614 to 5.64136, saving model to models/lstm2_univar/multitask/24.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 8.4524 - regr_loss: 1.5569 - clf_loss: 0.7489 - regr_mae: 0.9485 - clf_accuracy: 0.5253 - val_loss: 5.6414 - val_regr_loss: 0.1808 - val_clf_loss: 0.6922 - val_regr_mae: 0.2932 - val_clf_accuracy: 0.5500
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 25/32
# 22/25 [=========================>....] - ETA: 0s - loss: 7.8819 - regr_loss: 1.2644 - clf_loss: 0.7662 - regr_mae: 0.8980 - clf_accuracy: 0.4773
# Epoch 00025: val_loss improved from 5.64136 to 5.63675, saving model to models/lstm2_univar/multitask/25.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 8.0483 - regr_loss: 1.3549 - clf_loss: 0.7514 - regr_mae: 0.9279 - clf_accuracy: 0.4949 - val_loss: 5.6367 - val_regr_loss: 0.1793 - val_clf_loss: 0.6923 - val_regr_mae: 0.2925 - val_clf_accuracy: 0.5500
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 26/32
# 22/25 [=========================>....] - ETA: 0s - loss: 8.0168 - regr_loss: 1.3504 - clf_loss: 0.7308 - regr_mae: 0.9120 - clf_accuracy: 0.5057
# Epoch 00026: val_loss improved from 5.63675 to 5.63376, saving model to models/lstm2_univar/multitask/26.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 8.0674 - regr_loss: 1.3633 - clf_loss: 0.7555 - regr_mae: 0.9175 - clf_accuracy: 0.4899 - val_loss: 5.6338 - val_regr_loss: 0.1791 - val_clf_loss: 0.6914 - val_regr_mae: 0.2924 - val_clf_accuracy: 0.5500
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 27/32
# 22/25 [=========================>....] - ETA: 0s - loss: 8.0616 - regr_loss: 1.3732 - clf_loss: 0.7316 - regr_mae: 0.9379 - clf_accuracy: 0.5284
# Epoch 00027: val_loss improved from 5.63376 to 5.63240, saving model to models/lstm2_univar/multitask/27.hdf5
# 25/25 [==============================] - 1s 22ms/step - loss: 8.0431 - regr_loss: 1.3625 - clf_loss: 0.7348 - regr_mae: 0.9293 - clf_accuracy: 0.5253 - val_loss: 5.6324 - val_regr_loss: 0.1797 - val_clf_loss: 0.6905 - val_regr_mae: 0.2929 - val_clf_accuracy: 0.5500
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 28/32
# 22/25 [=========================>....] - ETA: 0s - loss: 8.3639 - regr_loss: 1.5200 - clf_loss: 0.7420 - regr_mae: 0.9883 - clf_accuracy: 0.5114
# Epoch 00028: val_loss did not improve from 5.63240
# 25/25 [==============================] - 1s 20ms/step - loss: 8.3836 - regr_loss: 1.5350 - clf_loss: 0.7308 - regr_mae: 0.9828 - clf_accuracy: 0.5152 - val_loss: 5.6380 - val_regr_loss: 0.1833 - val_clf_loss: 0.6906 - val_regr_mae: 0.2950 - val_clf_accuracy: 0.5500
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 29/32
# 22/25 [=========================>....] - ETA: 0s - loss: 7.9643 - regr_loss: 1.3173 - clf_loss: 0.7495 - regr_mae: 0.8993 - clf_accuracy: 0.5057
# Epoch 00029: val_loss did not improve from 5.63240
# 25/25 [==============================] - 1s 20ms/step - loss: 7.9620 - regr_loss: 1.3115 - clf_loss: 0.7589 - regr_mae: 0.8972 - clf_accuracy: 0.5000 - val_loss: 5.6436 - val_regr_loss: 0.1870 - val_clf_loss: 0.6904 - val_regr_mae: 0.2972 - val_clf_accuracy: 0.5500
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 3.1250001484295353e-06.
# Epoch 30/32
# 22/25 [=========================>....] - ETA: 0s - loss: 8.1378 - regr_loss: 1.4111 - clf_loss: 0.7369 - regr_mae: 0.9349 - clf_accuracy: 0.4602
# Epoch 00030: val_loss did not improve from 5.63240
# 25/25 [==============================] - 1s 21ms/step - loss: 7.9375 - regr_loss: 1.3127 - clf_loss: 0.7325 - regr_mae: 0.8986 - clf_accuracy: 0.4798 - val_loss: 5.6335 - val_regr_loss: 0.1828 - val_clf_loss: 0.6897 - val_regr_mae: 0.2943 - val_clf_accuracy: 0.5500
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 3.1250001484295353e-06.
# Epoch 31/32
# 22/25 [=========================>....] - ETA: 0s - loss: 7.6706 - regr_loss: 1.1928 - clf_loss: 0.7070 - regr_mae: 0.8608 - clf_accuracy: 0.4716
# Epoch 00031: val_loss did not improve from 5.63240
# 25/25 [==============================] - 1s 21ms/step - loss: 7.8239 - regr_loss: 1.2632 - clf_loss: 0.7193 - regr_mae: 0.8866 - clf_accuracy: 0.4545 - val_loss: 5.6357 - val_regr_loss: 0.1841 - val_clf_loss: 0.6900 - val_regr_mae: 0.2950 - val_clf_accuracy: 0.5500
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 3.1250001484295353e-06.
# Epoch 32/32
# 22/25 [=========================>....] - ETA: 0s - loss: 8.3351 - regr_loss: 1.5327 - clf_loss: 0.6926 - regr_mae: 0.9674 - clf_accuracy: 0.6080
# Epoch 00032: val_loss did not improve from 5.63240
# 25/25 [==============================] - 1s 21ms/step - loss: 8.4001 - regr_loss: 1.5611 - clf_loss: 0.7007 - regr_mae: 0.9871 - clf_accuracy: 0.5909 - val_loss: 5.6342 - val_regr_loss: 0.1838 - val_clf_loss: 0.6901 - val_regr_mae: 0.2944 - val_clf_accuracy: 0.5500
# Epoch 00032: early stopping

# %%
def plot_multitask_history(hist):
    fig, ax = plt.subplots(2, 2, figsize=(16, 12))
    plotHelpers.plot_train_history(ax[0, 0], hist, 'Total loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[0, 1], hist, 'Accuracy', 'clf_accuracy', 'val_clf_accuracy')
    plotHelpers.plot_train_history(ax[1, 0], hist, 'MSE', 'regr_loss', 'val_regr_loss')
    plotHelpers.plot_train_history(ax[1, 1], hist, 'MAE', 'regr_mae', 'val_regr_mae')
    
plot_multitask_history(multitask_history);

# %% [markdown]
# ### Прогноз

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_multitask_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret, pred_direction_proba = univariate_multitask_lstm.predict_generator(test_multi_gen, verbose=1)
# Out:
# 3/3 [==============================] - 0s 129ms/step

# %%
np.set_printoptions(precision=3, suppress=True)

np.column_stack([pred_log_ret, pred_direction_proba])[-10:]
# Out:
# array([[-0.041,  0.495],
#        [-0.031,  0.49 ],
#        [-0.04 ,  0.485],
#        [-0.061,  0.47 ],
#        [-0.068,  0.488],
#        [-0.017,  0.496],
#        [ 0.016,  0.489],
#        [-0.008,  0.473],
#        [-0.053,  0.475],
#        [-0.056,  0.492]], dtype=float32)

# %% [markdown]
# #### Прогноз задачи регрессии

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret, figsize=(16, 10), datetime_unit='D')

# %% [markdown]
# #### Прогноз задачи классификации

# %%
true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 0.4947686

# %%
true_direction = test_multi_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([11, 10])), (array([0, 1]), array([10, 11])))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.45      0.48        11
#            1       0.45      0.50      0.48        10
#
#     accuracy                           0.48        21
#    macro avg       0.48      0.48      0.48        21
# weighted avg       0.48      0.48      0.48        21

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[5, 6],
#        [5, 5]])

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.5  , 0.545],
#        [0.5  , 0.455]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# # Выводы
#
# 1.  Инициализация весов (`bias_initializer`) в слое **LSTM** оказалась очень важным параметром.
# 2.  Обучение моделей классификации (как отдельной, так и комбинированной с моделью регрессии) довольно нестабильное: на разных запусках получаются различные значения метрик.

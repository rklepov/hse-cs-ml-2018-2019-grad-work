# %% [markdown]
# <a href="https://colab.research.google.com/github/rklepov/hse-cs-ml-2018-2019-grad-work/blob/MSFT-1yr/MSFT/daily1y/06-lstm2_multivar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # *Многомерная модель на LSTM* (2 слоя)
#
# В качестве признаков используются цены, объём торгов и некоторое число индикаторов (всего 18 признаков)

# %%
import os
import glob
import datetime
import pickle

import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from pandas_datareader import data as pdr

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
tf.__version__
# Out:
# TensorFlow 2.x selected.
# '2.1.0'

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Input, Dense, LSTM, GRU, Flatten, ReLU, LeakyReLU, Dropout, BatchNormalization
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers import Nadam

# %%
import mdp

from mdp import TimeSeries
from mdp import MarketData
from mdp import MovingWindowFeatures
from mdp import ClassificationGenerator, RegressionGenerator, MultitaskGenerator
from mdp import invert_log_ret

import mdp.utils as utils
import mdp.plotHelpers as plotHelpers

# %%
import importlib

import mdp

importlib.reload(mdp)
importlib.reload(mdp.datasetGenerator)
importlib.reload(mdp.marketData)
importlib.reload(mdp.movingWindowFeatures)
importlib.reload(mdp.timeSeries)
importlib.reload(mdp.plotHelpers)
importlib.reload(mdp.utils);

# %% [markdown]
# # *Параметры*

# %%
INSTRUMENT = 'MSFT' # Microsoft corp
START_FROM = '2018-11-14'
END_DATE = '2020-01-01'
WINDOW_SIZE = 10
FORECAST_OFFSET=1
BATCH_SIZE = 8
VAL_SPLIT = '2019-11-01'
TEST_SPLIT = '2019-12-01'
FORCE_TRAIN = False

# %% [markdown]
# # *Исходные данные*
#
# Загрузка данных и вычисление индикаторов.

# %%
instr = MarketData.create_from_tiingo(INSTRUMENT, start=START_FROM, end=END_DATE)

# %%
instr.feature_names
# Out:
# ['o',
#  'h',
#  'l',
#  'c',
#  'v',
#  'ema14',
#  'ema30',
#  'macd',
#  'macd_signal',
#  'rsi14',
#  'bband20_upper',
#  'bband20_middle',
#  'bband20_lower',
#  'willr14',
#  'stochk',
#  'stochd',
#  'adline',
#  'adosc']

# %% [markdown]
# ## Целевая переменная

# %% [markdown]
# Цена закрытия.

# %%
orig_target = instr.c

# %%
def plot_transformed_series(instrument, series, orig_display_name, transformed_display_name):
    plotHelpers.plot_transformed_timeseries(
        instrument.instrument,
        series,
        title_orig = orig_display_name,
        xlabel_orig = 'Date',
        ylabel_orig = orig_display_name,
        title_transformed = transformed_display_name,
        xlabel_transformed = 'Date',
        ylabel_transformed = transformed_display_name
    )

# %% [markdown]
# Переходим к логарифмической доходности.

# %%
transformed_target = instr.c.transform(transforms={'ratios' : {}, 'ln' : {}})

# %%
plotHelpers.plot_transformed_timeseries_unit(instr,
                                             transformed_target,
                                             'Daily close price, USD', 'Daily log return')

# %% [markdown]
# ## Трансформация признаков
#
# Приведение временных рядов к стационарности.

# %%
def make_feature_selector():
    price_transformer = lambda: {'ratios': {}, 'ln': {}}
    diff_transformer = lambda o: {'diffs': {'order': o}}
    identity_transformer = lambda: {}
    feature_transformations = {
        'o': price_transformer(),
        'h': price_transformer(),
        'l': price_transformer(),
        'c': price_transformer(),
        'v': diff_transformer(1),
        'ema14': diff_transformer(1),
        'ema30': diff_transformer(1),
        'macd': diff_transformer(1),
        'macd_signal': diff_transformer(1),
        'rsi14': diff_transformer(1),
        'bband20_upper': diff_transformer(1),
        'bband20_middle': diff_transformer(1),
        'bband20_lower': diff_transformer(1),
        'willr14': identity_transformer(),
        'stochd': diff_transformer(1),
        'stochk': diff_transformer(1),
        'adline': diff_transformer(1),
        'adosc': diff_transformer(1)
    }
    return feature_transformations

# %%
instr_transformed = instr.select_transform(make_feature_selector())

# %%
transformed_target = instr_transformed.c

# %% [markdown]
# ## Обучающая, валидационная и тестовая выборки

# %%
instr_train, instr_val_test = instr_transformed.train_test_split(VAL_SPLIT, window_size=WINDOW_SIZE,
                                                                 scaler=StandardScaler)
#                                                                  scaler=MinMaxScaler,
#                                                                  scaler_kwargs={'feature_range': (-1, 1)})

instr_val, instr_test = instr_val_test.train_test_split(TEST_SPLIT, window_size=WINDOW_SIZE, scaler=None)

len(instr_train), len(instr_val), len(instr_test)
# Out:
# (208, 30, 31)

# %% [markdown]
# Все отмасштабированные признаки на одном графике (для валидационного датасета):

# %%
plotHelpers.plot_all_features(instr_val)

# %% [markdown]
# ## Признаки - скользящие окна

# %%
train_mwf = MovingWindowFeatures.create(instr_train.c, [instr_train], instr_train.feature_names, window_size=WINDOW_SIZE)
val_mwf = MovingWindowFeatures.create(instr_val.c, [instr_val], instr_val.feature_names, window_size=WINDOW_SIZE)
test_mwf = MovingWindowFeatures.create(instr_test.c, [instr_test], instr_test.feature_names, window_size=WINDOW_SIZE)

len(instr_train), len(train_mwf), train_mwf.features.shape
# Out:
# (208, 198, (198, 10, 18))

# %% [markdown]
# Проверка, что скользящие окна соответствуют исходным данным.
#
# Возьмём произвольный признак и произвольное окно (строка #**41**). Проверим, что данные в точности совпадают:

# %%
def check_data(md, mwf, row):
    col = np.random.randint(len(mwf.feature_names))
    feature = mwf.feature_names[col]
    check = (getattr(md, feature).data[row:row + mwf.window_size] == mwf.features[row, :, col]).all()
    assert check
    return feature, check

check_data(instr_train, train_mwf, 41)
# Out:
# ('l', True)

# %% [markdown]
# # *Модели*

# %% [markdown]
# Модель с двумя LSTM слоями.

# %%
def build_lstm_layers(input_shape, latent_dim=(16, 32)):
    # формат входа: наша матрица (окно; признак)
    inp = Input(input_shape, name='input')

    # стекаем два уровня LSTM
    lstm = LSTM(latent_dim[0], return_sequences=True, 
                    recurrent_dropout=0.2, dropout=0.2, 
                    bias_initializer='he_uniform',
                    bias_regularizer=L1L2(0.01, 0.02),
                    kernel_regularizer=L1L2(0.01, 0.02),
                    recurrent_regularizer=L1L2(0.01, 0.02)
               )(inp)

    lstm = LSTM(latent_dim[1], return_sequences=True,
                    recurrent_dropout=0.2, dropout=0.2,
                    bias_initializer='he_uniform',
                    bias_regularizer=L1L2(0.01, 0.02),
                    kernel_regularizer=L1L2(0.01, 0.02),
                    recurrent_regularizer=L1L2(0.01, 0.02)
               )(lstm)
    
    lstm = Flatten()(lstm)
    
    return inp, lstm

# %% [markdown]
# #### Пути сохранения моделей:

# %%
model_path_root = 'models'
model_type_name = 'lstm2_multivar'

def make_model_save_dir(path_root, type_name, class_name):
    save_dir = os.path.join(path_root, type_name, class_name)
    os.makedirs(save_dir, exist_ok=True)
    return save_dir

# %% [markdown]
# #### Общие коллбэки:

# %%
# уменьшение learning rate в случае, если loss не изменяется
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001, verbose=1)

# уменьшение learning rate в 2 раза каждую 5-ю эпоху
def lr_decay(e, lr):
    return lr * (1 - 0.5 * (0 == (e + 1) % 5))

lr_scheduler = LearningRateScheduler(schedule=lr_decay, verbose=1)

# %% [markdown]
# ## Задача регрессии
#
# Непосредственное прогнозирование цены следующего периода.

# %%
train_regr_gen = RegressionGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_regr_gen = RegressionGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_regr_gen = RegressionGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# Следующие числа соответствуют значению параметра `steps_per_epoch` метода [`fit_generator`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit_generator "tf.keras.layers.SimpleRNN &nbsp;|&nbsp; TensorFlow Core r2.0") - то есть это число батчей, которые генератор выдаст за одну эпоху обучения (если класс генератора поддерживает метод `len()`, то данный параметр можно не указывать).

# %%
len(train_regr_gen), len(val_regr_gen), len(test_regr_gen)
# Out:
# (25, 3, 3)

# %% [markdown]
# Один сэмпл данных представляет собой матрицу размером *(длина окна; число признаков)*

# %%
train_regr_gen.input_shape
# Out:
# (10, 18)

# %% [markdown]
# ### Модель для задачи регрессии

# %%
model_class_name = 'regression'

# %%
def build_regression_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=(16, 32))

    regr = Dense(64)(lstm)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    return Model(inputs=[inp], outputs=[regr])

# %%
multivariate_regression_lstm = build_regression_model(train_regr_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:
# [`Nadam`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Nadam) (*Adam with Nestrov momentum*).

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Функция потерь:
#
# В качестве функции потерь будем использовать [MSE](https://www.tensorflow.org/api_docs/python/tf/keras/losses/MSE) (чтобы штрафовать за большие отклонения). Xотя хорошая функция потерь в контексте темы данной задачи - это [вопрос сложный](https://github.com/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Chapter5_LossFunctions/Ch5_LossFunctions_PyMC3.ipynb). В частности, здесь нам, очевидно, помимо абсолютного значения отклонения также важен его знак.

# %%
multivariate_regression_lstm.compile(optimizer=optimizer,
                                     loss={'regr': 'mse'},
                                     metrics={'regr': 'mae'})

multivariate_regression_lstm.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 10, 18)]          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 10, 16)            2240
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 32)            6272
# _________________________________________________________________
# flatten (Flatten)            (None, 320)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                20544
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64)                256
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 64)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# regr (Dense)                 (None, 1)                 65
# =================================================================
# Total params: 29,377
# Trainable params: 29,249
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# #### Обучение:

# %%
regr_history = utils.train_model(multivariate_regression_lstm,
                                 model_save_dir, train_regr_gen, val_regr_gen,
                                 callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                 force_train=FORCE_TRAIN, verbose=1)
# Out:
# WARNING:tensorflow:From /content/hse-cs-ml-2018-2019-grad-work/mdp/utils.py:79: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 25 steps, validate for 3 steps
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 23/25 [==========================>...] - ETA: 0s - loss: 13.9731 - mae: 1.2636
# Epoch 00001: val_loss improved from inf to 10.97549, saving model to models/lstm2_multivar/regression/01.hdf5
# 25/25 [==============================] - 5s 219ms/step - loss: 13.8187 - mae: 1.2365 - val_loss: 10.9755 - val_mae: 0.2838
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 23/25 [==========================>...] - ETA: 0s - loss: 12.5646 - mae: 1.1634
# Epoch 00002: val_loss improved from 10.97549 to 10.18818, saving model to models/lstm2_multivar/regression/02.hdf5
# 25/25 [==============================] - 1s 41ms/step - loss: 12.5623 - mae: 1.1612 - val_loss: 10.1882 - val_mae: 0.3090
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 24/25 [===========================>..] - ETA: 0s - loss: 11.4256 - mae: 1.0311
# Epoch 00003: val_loss improved from 10.18818 to 9.41741, saving model to models/lstm2_multivar/regression/03.hdf5
# 25/25 [==============================] - 1s 41ms/step - loss: 11.4743 - mae: 1.0410 - val_loss: 9.4174 - val_mae: 0.3058
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 23/25 [==========================>...] - ETA: 0s - loss: 10.8418 - mae: 1.0813
# Epoch 00004: val_loss improved from 9.41741 to 8.78917, saving model to models/lstm2_multivar/regression/04.hdf5
# 25/25 [==============================] - 1s 41ms/step - loss: 10.7633 - mae: 1.0732 - val_loss: 8.7892 - val_mae: 0.3741
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 23/25 [==========================>...] - ETA: 0s - loss: 9.9332 - mae: 0.9759
# Epoch 00005: val_loss improved from 8.78917 to 8.52277, saving model to models/lstm2_multivar/regression/05.hdf5
# 25/25 [==============================] - 1s 41ms/step - loss: 9.9157 - mae: 0.9765 - val_loss: 8.5228 - val_mae: 0.4393
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 24/25 [===========================>..] - ETA: 0s - loss: 10.0277 - mae: 1.0532
# Epoch 00006: val_loss improved from 8.52277 to 8.12441, saving model to models/lstm2_multivar/regression/06.hdf5
# 25/25 [==============================] - 1s 42ms/step - loss: 10.0926 - mae: 1.0770 - val_loss: 8.1244 - val_mae: 0.3514
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 24/25 [===========================>..] - ETA: 0s - loss: 9.4876 - mae: 1.0703
# Epoch 00007: val_loss improved from 8.12441 to 7.83774, saving model to models/lstm2_multivar/regression/07.hdf5
# 25/25 [==============================] - 1s 42ms/step - loss: 9.4719 - mae: 1.0709 - val_loss: 7.8377 - val_mae: 0.3620
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 24/25 [===========================>..] - ETA: 0s - loss: 9.0057 - mae: 0.9846
# Epoch 00008: val_loss improved from 7.83774 to 7.54884, saving model to models/lstm2_multivar/regression/08.hdf5
# 25/25 [==============================] - 1s 45ms/step - loss: 8.9663 - mae: 0.9711 - val_loss: 7.5488 - val_mae: 0.3659
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 23/25 [==========================>...] - ETA: 0s - loss: 8.8074 - mae: 1.0049
# Epoch 00009: val_loss improved from 7.54884 to 7.31541, saving model to models/lstm2_multivar/regression/09.hdf5
# 25/25 [==============================] - 1s 53ms/step - loss: 8.8118 - mae: 1.0136 - val_loss: 7.3154 - val_mae: 0.4082
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 24/25 [===========================>..] - ETA: 0s - loss: 8.5356 - mae: 0.9762
# Epoch 00010: val_loss improved from 7.31541 to 7.13176, saving model to models/lstm2_multivar/regression/10.hdf5
# 25/25 [==============================] - 1s 45ms/step - loss: 8.5414 - mae: 0.9806 - val_loss: 7.1318 - val_mae: 0.3571
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 24/25 [===========================>..] - ETA: 0s - loss: 8.4999 - mae: 1.0063
# Epoch 00011: val_loss improved from 7.13176 to 6.99872, saving model to models/lstm2_multivar/regression/11.hdf5
# 25/25 [==============================] - 1s 44ms/step - loss: 8.4929 - mae: 1.0078 - val_loss: 6.9987 - val_mae: 0.3549
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 23/25 [==========================>...] - ETA: 0s - loss: 8.3388 - mae: 0.9994
# Epoch 00012: val_loss improved from 6.99872 to 6.87816, saving model to models/lstm2_multivar/regression/12.hdf5
# 25/25 [==============================] - 1s 45ms/step - loss: 8.3612 - mae: 1.0138 - val_loss: 6.8782 - val_mae: 0.3625
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 23/25 [==========================>...] - ETA: 0s - loss: 7.8516 - mae: 0.8819
# Epoch 00013: val_loss improved from 6.87816 to 6.76563, saving model to models/lstm2_multivar/regression/13.hdf5
# 25/25 [==============================] - 1s 44ms/step - loss: 7.9074 - mae: 0.8981 - val_loss: 6.7656 - val_mae: 0.3766
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 24/25 [===========================>..] - ETA: 0s - loss: 8.0035 - mae: 0.9569
# Epoch 00014: val_loss improved from 6.76563 to 6.63815, saving model to models/lstm2_multivar/regression/14.hdf5
# 25/25 [==============================] - 1s 44ms/step - loss: 7.9861 - mae: 0.9587 - val_loss: 6.6381 - val_mae: 0.3706
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 23/25 [==========================>...] - ETA: 0s - loss: 7.9194 - mae: 0.9913
# Epoch 00015: val_loss improved from 6.63815 to 6.56878, saving model to models/lstm2_multivar/regression/15.hdf5
# 25/25 [==============================] - 1s 42ms/step - loss: 7.9224 - mae: 0.9930 - val_loss: 6.5688 - val_mae: 0.3629
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 23/25 [==========================>...] - ETA: 0s - loss: 7.7578 - mae: 0.9685
# Epoch 00016: val_loss improved from 6.56878 to 6.48744, saving model to models/lstm2_multivar/regression/16.hdf5
# 25/25 [==============================] - 1s 44ms/step - loss: 7.7696 - mae: 0.9663 - val_loss: 6.4874 - val_mae: 0.3381
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 23/25 [==========================>...] - ETA: 0s - loss: 7.8510 - mae: 0.9683
# Epoch 00017: val_loss improved from 6.48744 to 6.42524, saving model to models/lstm2_multivar/regression/17.hdf5
# 25/25 [==============================] - 1s 45ms/step - loss: 7.8079 - mae: 0.9606 - val_loss: 6.4252 - val_mae: 0.3347
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.6773 - mae: 0.9753
# Epoch 00018: val_loss improved from 6.42524 to 6.38908, saving model to models/lstm2_multivar/regression/18.hdf5
# 25/25 [==============================] - 1s 46ms/step - loss: 7.7330 - mae: 0.9925 - val_loss: 6.3891 - val_mae: 0.3583
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.5052 - mae: 0.9411
# Epoch 00019: val_loss improved from 6.38908 to 6.31377, saving model to models/lstm2_multivar/regression/19.hdf5
# 25/25 [==============================] - 1s 41ms/step - loss: 7.5074 - mae: 0.9451 - val_loss: 6.3138 - val_mae: 0.3398
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 23/25 [==========================>...] - ETA: 0s - loss: 7.6630 - mae: 1.0055
# Epoch 00020: val_loss did not improve from 6.31377
# 25/25 [==============================] - 1s 39ms/step - loss: 7.6344 - mae: 1.0023 - val_loss: 6.3186 - val_mae: 0.3725
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 23/25 [==========================>...] - ETA: 0s - loss: 7.4792 - mae: 0.9571
# Epoch 00021: val_loss improved from 6.31377 to 6.28039, saving model to models/lstm2_multivar/regression/21.hdf5
# 25/25 [==============================] - 1s 42ms/step - loss: 7.4786 - mae: 0.9598 - val_loss: 6.2804 - val_mae: 0.3614
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 23/25 [==========================>...] - ETA: 0s - loss: 7.5369 - mae: 0.9900
# Epoch 00022: val_loss improved from 6.28039 to 6.24440, saving model to models/lstm2_multivar/regression/22.hdf5
# 25/25 [==============================] - 1s 41ms/step - loss: 7.5403 - mae: 0.9879 - val_loss: 6.2444 - val_mae: 0.3519
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 23/25 [==========================>...] - ETA: 0s - loss: 7.4730 - mae: 0.9650
# Epoch 00023: val_loss improved from 6.24440 to 6.21545, saving model to models/lstm2_multivar/regression/23.hdf5
# 25/25 [==============================] - 1s 42ms/step - loss: 7.4499 - mae: 0.9534 - val_loss: 6.2155 - val_mae: 0.3501
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 23/25 [==========================>...] - ETA: 0s - loss: 7.4555 - mae: 0.9631
# Epoch 00024: val_loss improved from 6.21545 to 6.19040, saving model to models/lstm2_multivar/regression/24.hdf5
# 25/25 [==============================] - 1s 42ms/step - loss: 7.5169 - mae: 0.9818 - val_loss: 6.1904 - val_mae: 0.3539
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.5899 - mae: 0.9767
# Epoch 00025: val_loss improved from 6.19040 to 6.18426, saving model to models/lstm2_multivar/regression/25.hdf5
# 25/25 [==============================] - 1s 47ms/step - loss: 7.5534 - mae: 0.9692 - val_loss: 6.1843 - val_mae: 0.3618
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 23/25 [==========================>...] - ETA: 0s - loss: 7.3767 - mae: 0.9214
# Epoch 00026: val_loss improved from 6.18426 to 6.16538, saving model to models/lstm2_multivar/regression/26.hdf5
# 25/25 [==============================] - 1s 47ms/step - loss: 7.3336 - mae: 0.9141 - val_loss: 6.1654 - val_mae: 0.3545
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.4164 - mae: 0.9715
# Epoch 00027: val_loss improved from 6.16538 to 6.15377, saving model to models/lstm2_multivar/regression/27.hdf5
# 25/25 [==============================] - 1s 47ms/step - loss: 7.4398 - mae: 0.9778 - val_loss: 6.1538 - val_mae: 0.3564
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 23/25 [==========================>...] - ETA: 0s - loss: 7.4836 - mae: 0.9663
# Epoch 00028: val_loss improved from 6.15377 to 6.13633, saving model to models/lstm2_multivar/regression/28.hdf5
# 25/25 [==============================] - 1s 47ms/step - loss: 7.4542 - mae: 0.9669 - val_loss: 6.1363 - val_mae: 0.3512
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 23/25 [==========================>...] - ETA: 0s - loss: 7.2326 - mae: 0.8918
# Epoch 00029: val_loss did not improve from 6.13633
# 25/25 [==============================] - 1s 47ms/step - loss: 7.2749 - mae: 0.9076 - val_loss: 6.1381 - val_mae: 0.3664
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.2390 - mae: 0.9197
# Epoch 00030: val_loss improved from 6.13633 to 6.13173, saving model to models/lstm2_multivar/regression/30.hdf5
# 25/25 [==============================] - 1s 48ms/step - loss: 7.2705 - mae: 0.9289 - val_loss: 6.1317 - val_mae: 0.3670
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.2770 - mae: 0.9218
# Epoch 00031: val_loss did not improve from 6.13173
# 25/25 [==============================] - 1s 45ms/step - loss: 7.2443 - mae: 0.9149 - val_loss: 6.1368 - val_mae: 0.3773
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 24/25 [===========================>..] - ETA: 0s - loss: 7.1487 - mae: 0.9104
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00032: val_loss did not improve from 6.13173
# 25/25 [==============================] - 1s 42ms/step - loss: 7.2387 - mae: 0.9288 - val_loss: 6.1323 - val_mae: 0.3791

# %%
def plot_regr_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'MSE', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'MAE', 'mae', 'val_mae')
    
plot_regr_history(regr_history);

# %% [markdown]
# ### Прогноз задачи регрессии

# %%
# загружаем последнюю эпоху с минимальным лоссом
multivariate_regression_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret_test = multivariate_regression_lstm.predict_generator(test_regr_gen, verbose=1)
# Out:
# WARNING:tensorflow:From <ipython-input-41-1dd2bb6c022e>:1: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.
# 3/3 [==============================] - 0s 111ms/step

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret_test, figsize=(16, 10), datetime_unit='D')

# %% [markdown]
# ## Задача классификации
#
# Прогнозируем направление изменения цены по сравнению с предыдущим периодом (**0** - снижение, **1** - рост).

# %%
model_class_name = 'classification'

# %%
train_clf_gen = ClassificationGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_clf_gen = ClassificationGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_clf_gen = ClassificationGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_classification_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=(16, 32))

    clf = Dense(64)(lstm)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)

    return Model(inputs=[inp], outputs=[clf])

# %%
multivariate_classification_lstm = build_classification_model(test_clf_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
multivariate_classification_lstm.compile(optimizer=optimizer,
                                         loss={'clf': 'binary_crossentropy'},
                                         metrics={'clf': 'accuracy'})

multivariate_classification_lstm.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 10, 18)]          0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 10, 16)            2240
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 10, 32)            6272
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 320)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                20544
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# clf (Dense)                  (None, 1)                 65
# =================================================================
# Total params: 29,377
# Trainable params: 29,249
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
clf_history = utils.train_model(multivariate_classification_lstm,
                                model_save_dir, train_clf_gen, val_clf_gen,
                                callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                force_train=FORCE_TRAIN, verbose=1)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 25 steps, validate for 3 steps
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 23/25 [==========================>...] - ETA: 0s - loss: 11.5072 - accuracy: 0.4130
# Epoch 00001: val_loss improved from inf to 10.31612, saving model to models/lstm2_multivar/classification/01.hdf5
# 25/25 [==============================] - 5s 213ms/step - loss: 11.4488 - accuracy: 0.4040 - val_loss: 10.3161 - val_accuracy: 0.6000
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 23/25 [==========================>...] - ETA: 0s - loss: 9.6755 - accuracy: 0.5163
# Epoch 00002: val_loss improved from 10.31612 to 8.65034, saving model to models/lstm2_multivar/classification/02.hdf5
# 25/25 [==============================] - 1s 42ms/step - loss: 9.6080 - accuracy: 0.5202 - val_loss: 8.6503 - val_accuracy: 0.6500
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 23/25 [==========================>...] - ETA: 0s - loss: 8.0713 - accuracy: 0.5272
# Epoch 00003: val_loss improved from 8.65034 to 7.27727, saving model to models/lstm2_multivar/classification/03.hdf5
# 25/25 [==============================] - 1s 46ms/step - loss: 8.0432 - accuracy: 0.5202 - val_loss: 7.2773 - val_accuracy: 0.6500
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 23/25 [==========================>...] - ETA: 0s - loss: 6.8764 - accuracy: 0.5109
# Epoch 00004: val_loss improved from 7.27727 to 6.18587, saving model to models/lstm2_multivar/classification/04.hdf5
# 25/25 [==============================] - 1s 42ms/step - loss: 6.8324 - accuracy: 0.5101 - val_loss: 6.1859 - val_accuracy: 0.5000
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 24/25 [===========================>..] - ETA: 0s - loss: 6.0106 - accuracy: 0.5573
# Epoch 00005: val_loss improved from 6.18587 to 5.71594, saving model to models/lstm2_multivar/classification/05.hdf5
# 25/25 [==============================] - 1s 43ms/step - loss: 5.9961 - accuracy: 0.5505 - val_loss: 5.7159 - val_accuracy: 0.5000
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 24/25 [===========================>..] - ETA: 0s - loss: 5.6068 - accuracy: 0.4948
# Epoch 00006: val_loss improved from 5.71594 to 5.30247, saving model to models/lstm2_multivar/classification/06.hdf5
# 25/25 [==============================] - 1s 43ms/step - loss: 5.6063 - accuracy: 0.4848 - val_loss: 5.3025 - val_accuracy: 0.5000
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 23/25 [==========================>...] - ETA: 0s - loss: 5.1683 - accuracy: 0.5272
# Epoch 00007: val_loss improved from 5.30247 to 4.91845, saving model to models/lstm2_multivar/classification/07.hdf5
# 25/25 [==============================] - 1s 42ms/step - loss: 5.1517 - accuracy: 0.5202 - val_loss: 4.9185 - val_accuracy: 0.5000
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 23/25 [==========================>...] - ETA: 0s - loss: 4.7967 - accuracy: 0.5489
# Epoch 00008: val_loss improved from 4.91845 to 4.57940, saving model to models/lstm2_multivar/classification/08.hdf5
# 25/25 [==============================] - 1s 43ms/step - loss: 4.7851 - accuracy: 0.5455 - val_loss: 4.5794 - val_accuracy: 0.5000
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 24/25 [===========================>..] - ETA: 0s - loss: 4.4555 - accuracy: 0.5521
# Epoch 00009: val_loss improved from 4.57940 to 4.27112, saving model to models/lstm2_multivar/classification/09.hdf5
# 25/25 [==============================] - 1s 43ms/step - loss: 4.4491 - accuracy: 0.5556 - val_loss: 4.2711 - val_accuracy: 0.6000
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 23/25 [==========================>...] - ETA: 0s - loss: 4.2217 - accuracy: 0.5815
# Epoch 00010: val_loss improved from 4.27112 to 4.12681, saving model to models/lstm2_multivar/classification/10.hdf5
# 25/25 [==============================] - 1s 42ms/step - loss: 4.2135 - accuracy: 0.5859 - val_loss: 4.1268 - val_accuracy: 0.6000
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 23/25 [==========================>...] - ETA: 0s - loss: 4.0928 - accuracy: 0.5435
# Epoch 00011: val_loss improved from 4.12681 to 3.99355, saving model to models/lstm2_multivar/classification/11.hdf5
# 25/25 [==============================] - 1s 42ms/step - loss: 4.0876 - accuracy: 0.5404 - val_loss: 3.9936 - val_accuracy: 0.7000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.9634 - accuracy: 0.5729
# Epoch 00012: val_loss improved from 3.99355 to 3.87015, saving model to models/lstm2_multivar/classification/12.hdf5
# 25/25 [==============================] - 1s 42ms/step - loss: 3.9646 - accuracy: 0.5707 - val_loss: 3.8702 - val_accuracy: 0.5500
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.8244 - accuracy: 0.6302
# Epoch 00013: val_loss improved from 3.87015 to 3.75411, saving model to models/lstm2_multivar/classification/13.hdf5
# 25/25 [==============================] - 1s 50ms/step - loss: 3.8203 - accuracy: 0.6263 - val_loss: 3.7541 - val_accuracy: 0.6000
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 23/25 [==========================>...] - ETA: 0s - loss: 3.7305 - accuracy: 0.5815
# Epoch 00014: val_loss improved from 3.75411 to 3.64181, saving model to models/lstm2_multivar/classification/14.hdf5
# 25/25 [==============================] - 1s 42ms/step - loss: 3.7268 - accuracy: 0.5707 - val_loss: 3.6418 - val_accuracy: 0.6000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 23/25 [==========================>...] - ETA: 0s - loss: 3.6039 - accuracy: 0.5978
# Epoch 00015: val_loss improved from 3.64181 to 3.58502, saving model to models/lstm2_multivar/classification/15.hdf5
# 25/25 [==============================] - 1s 42ms/step - loss: 3.6184 - accuracy: 0.5909 - val_loss: 3.5850 - val_accuracy: 0.6500
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.5716 - accuracy: 0.5781
# Epoch 00016: val_loss improved from 3.58502 to 3.53170, saving model to models/lstm2_multivar/classification/16.hdf5
# 25/25 [==============================] - 1s 43ms/step - loss: 3.5671 - accuracy: 0.5808 - val_loss: 3.5317 - val_accuracy: 0.6500
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 23/25 [==========================>...] - ETA: 0s - loss: 3.5731 - accuracy: 0.5380
# Epoch 00017: val_loss improved from 3.53170 to 3.48330, saving model to models/lstm2_multivar/classification/17.hdf5
# 25/25 [==============================] - 1s 43ms/step - loss: 3.5657 - accuracy: 0.5505 - val_loss: 3.4833 - val_accuracy: 0.6000
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.4618 - accuracy: 0.6094
# Epoch 00018: val_loss improved from 3.48330 to 3.43760, saving model to models/lstm2_multivar/classification/18.hdf5
# 25/25 [==============================] - 1s 42ms/step - loss: 3.4620 - accuracy: 0.6111 - val_loss: 3.4376 - val_accuracy: 0.5500
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 23/25 [==========================>...] - ETA: 0s - loss: 3.4392 - accuracy: 0.5652
# Epoch 00019: val_loss improved from 3.43760 to 3.39425, saving model to models/lstm2_multivar/classification/19.hdf5
# 25/25 [==============================] - 1s 43ms/step - loss: 3.4270 - accuracy: 0.5707 - val_loss: 3.3942 - val_accuracy: 0.5500
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.3949 - accuracy: 0.5677
# Epoch 00020: val_loss improved from 3.39425 to 3.36692, saving model to models/lstm2_multivar/classification/20.hdf5
# 25/25 [==============================] - 1s 42ms/step - loss: 3.3990 - accuracy: 0.5657 - val_loss: 3.3669 - val_accuracy: 0.5500
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.3973 - accuracy: 0.5469
# Epoch 00021: val_loss improved from 3.36692 to 3.34627, saving model to models/lstm2_multivar/classification/21.hdf5
# 25/25 [==============================] - 1s 44ms/step - loss: 3.3950 - accuracy: 0.5455 - val_loss: 3.3463 - val_accuracy: 0.5000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 23/25 [==========================>...] - ETA: 0s - loss: 3.3441 - accuracy: 0.5707
# Epoch 00022: val_loss improved from 3.34627 to 3.32387, saving model to models/lstm2_multivar/classification/22.hdf5
# 25/25 [==============================] - 1s 43ms/step - loss: 3.3387 - accuracy: 0.5758 - val_loss: 3.3239 - val_accuracy: 0.5500
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.3426 - accuracy: 0.5417
# Epoch 00023: val_loss improved from 3.32387 to 3.30367, saving model to models/lstm2_multivar/classification/23.hdf5
# 25/25 [==============================] - 1s 44ms/step - loss: 3.3375 - accuracy: 0.5404 - val_loss: 3.3037 - val_accuracy: 0.5500
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 23/25 [==========================>...] - ETA: 0s - loss: 3.2625 - accuracy: 0.6141
# Epoch 00024: val_loss improved from 3.30367 to 3.28211, saving model to models/lstm2_multivar/classification/24.hdf5
# 25/25 [==============================] - 1s 43ms/step - loss: 3.2650 - accuracy: 0.6162 - val_loss: 3.2821 - val_accuracy: 0.5500
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 23/25 [==========================>...] - ETA: 0s - loss: 3.2808 - accuracy: 0.5761
# Epoch 00025: val_loss improved from 3.28211 to 3.26746, saving model to models/lstm2_multivar/classification/25.hdf5
# 25/25 [==============================] - 1s 42ms/step - loss: 3.2872 - accuracy: 0.5657 - val_loss: 3.2675 - val_accuracy: 0.5500
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 23/25 [==========================>...] - ETA: 0s - loss: 3.2438 - accuracy: 0.5543
# Epoch 00026: val_loss improved from 3.26746 to 3.25665, saving model to models/lstm2_multivar/classification/26.hdf5
# 25/25 [==============================] - 1s 43ms/step - loss: 3.2417 - accuracy: 0.5606 - val_loss: 3.2566 - val_accuracy: 0.5500
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.2776 - accuracy: 0.5469
# Epoch 00027: val_loss improved from 3.25665 to 3.24346, saving model to models/lstm2_multivar/classification/27.hdf5
# 25/25 [==============================] - 1s 44ms/step - loss: 3.2709 - accuracy: 0.5505 - val_loss: 3.2435 - val_accuracy: 0.5500
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.2144 - accuracy: 0.6771
# Epoch 00028: val_loss improved from 3.24346 to 3.23430, saving model to models/lstm2_multivar/classification/28.hdf5
# 25/25 [==============================] - 1s 44ms/step - loss: 3.2067 - accuracy: 0.6818 - val_loss: 3.2343 - val_accuracy: 0.5500
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 23/25 [==========================>...] - ETA: 0s - loss: 3.1998 - accuracy: 0.6196
# Epoch 00029: val_loss improved from 3.23430 to 3.22092, saving model to models/lstm2_multivar/classification/29.hdf5
# 25/25 [==============================] - 1s 43ms/step - loss: 3.1994 - accuracy: 0.6162 - val_loss: 3.2209 - val_accuracy: 0.5500
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 23/25 [==========================>...] - ETA: 0s - loss: 3.2303 - accuracy: 0.5707
# Epoch 00030: val_loss improved from 3.22092 to 3.21536, saving model to models/lstm2_multivar/classification/30.hdf5
# 25/25 [==============================] - 1s 44ms/step - loss: 3.2186 - accuracy: 0.5758 - val_loss: 3.2154 - val_accuracy: 0.5500
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 24/25 [===========================>..] - ETA: 0s - loss: 3.1893 - accuracy: 0.6042
# Epoch 00031: val_loss improved from 3.21536 to 3.21114, saving model to models/lstm2_multivar/classification/31.hdf5
# 25/25 [==============================] - 1s 44ms/step - loss: 3.1873 - accuracy: 0.6111 - val_loss: 3.2111 - val_accuracy: 0.5500
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 23/25 [==========================>...] - ETA: 0s - loss: 3.1923 - accuracy: 0.6250
# Epoch 00032: val_loss improved from 3.21114 to 3.20654, saving model to models/lstm2_multivar/classification/32.hdf5
# 25/25 [==============================] - 1s 43ms/step - loss: 3.1872 - accuracy: 0.6364 - val_loss: 3.2065 - val_accuracy: 0.5500

# %%
def plot_clf_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'Loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'Accuracy', 'accuracy', 'val_accuracy')
    
plot_clf_history(clf_history);

# %% [markdown]
# ### Прогноз задачи классификации

# %%
# загружаем последнюю эпоху с минимальным лоссом
multivariate_classification_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %%
pred_direction_proba = multivariate_classification_lstm.predict_generator(test_clf_gen, verbose=1)

true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 3/3 [==============================] - 0s 120ms/step
# 0.48240733

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([11, 10])), (array([0, 1]), array([11, 10])))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.36      0.36      0.36        11
#            1       0.30      0.30      0.30        10
#
#     accuracy                           0.33        21
#    macro avg       0.33      0.33      0.33        21
# weighted avg       0.33      0.33      0.33        21

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[4, 7],
#        [7, 3]])

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.36363636, 0.7       ],
#        [0.63636364, 0.3       ]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# ## Многозадачная модель: одновременно регрессия и классификация

# %%
model_class_name = 'multitask'

# %%
train_multi_gen = MultitaskGenerator.create(train_mwf, batch_size=BATCH_SIZE)
val_multi_gen = MultitaskGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_multi_gen = MultitaskGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_multitask_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=(16, 32))

    # первый выход: задача регрссии
    regr = Dense(64)(lstm)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    # второй выход: задача классификации
    clf = Dense(64)(lstm)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)
    
    return Model(inputs=[inp], outputs=[regr, clf])

# %%
multivariate_multitask_lstm = build_multitask_model(train_multi_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
multivariate_multitask_lstm.compile(optimizer=optimizer,
                                    loss={'regr': 'mse', 'clf': 'binary_crossentropy'},
                                    loss_weights={'regr': 2., 'clf': 1.},
                                    metrics={'regr': 'mae', 'clf' : 'accuracy'})

multivariate_multitask_lstm.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 10, 18)]     0
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 10, 16)       2240        input[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 10, 32)       6272        lstm_4[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 320)          0           lstm_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           20544       flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           20544       flatten_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64)           256         dense_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64)           256         dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 64)           0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 64)           0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64)           0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64)           0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# regr (Dense)                    (None, 1)            65          dropout_2[0][0]
# __________________________________________________________________________________________________
# clf (Dense)                     (None, 1)            65          dropout_3[0][0]
# ==================================================================================================
# Total params: 50,242
# Trainable params: 49,986
# Non-trainable params: 256
# __________________________________________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
multitask_history = utils.train_model(multivariate_multitask_lstm,
                                      model_save_dir, train_multi_gen, val_multi_gen,
                                      callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                      force_train=FORCE_TRAIN, verbose=1)
# Out:
# Train for 25 steps, validate for 3 steps
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 23/25 [==========================>...] - ETA: 0s - loss: 17.4049 - regr_loss: 2.5172 - clf_loss: 0.8959 - regr_mae: 1.2651 - clf_accuracy: 0.4620
# Epoch 00001: val_loss improved from inf to 12.26477, saving model to models/lstm2_multivar/multitask/01.hdf5
# 25/25 [==============================] - 6s 247ms/step - loss: 17.2572 - regr_loss: 2.4521 - clf_loss: 0.8939 - regr_mae: 1.2526 - clf_accuracy: 0.4545 - val_loss: 12.2648 - val_regr_loss: 0.1631 - val_clf_loss: 0.6956 - val_regr_mae: 0.3020 - val_clf_accuracy: 0.5000
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 23/25 [==========================>...] - ETA: 0s - loss: 15.9732 - regr_loss: 2.0707 - clf_loss: 0.7848 - regr_mae: 1.0798 - clf_accuracy: 0.5380
# Epoch 00002: val_loss improved from 12.26477 to 11.81689, saving model to models/lstm2_multivar/multitask/02.hdf5
# 25/25 [==============================] - 1s 46ms/step - loss: 15.8555 - regr_loss: 2.0210 - clf_loss: 0.7839 - regr_mae: 1.0712 - clf_accuracy: 0.5455 - val_loss: 11.8169 - val_regr_loss: 0.1633 - val_clf_loss: 0.6958 - val_regr_mae: 0.2938 - val_clf_accuracy: 0.5500
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 23/25 [==========================>...] - ETA: 0s - loss: 15.9205 - regr_loss: 2.2693 - clf_loss: 0.7854 - regr_mae: 1.2161 - clf_accuracy: 0.4946
# Epoch 00003: val_loss improved from 11.81689 to 11.38786, saving model to models/lstm2_multivar/multitask/03.hdf5
# 25/25 [==============================] - 1s 47ms/step - loss: 15.7249 - regr_loss: 2.1708 - clf_loss: 0.8038 - regr_mae: 1.1860 - clf_accuracy: 0.4949 - val_loss: 11.3879 - val_regr_loss: 0.1646 - val_clf_loss: 0.7088 - val_regr_mae: 0.2924 - val_clf_accuracy: 0.5000
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 23/25 [==========================>...] - ETA: 0s - loss: 14.5897 - regr_loss: 1.7927 - clf_loss: 0.8443 - regr_mae: 1.0534 - clf_accuracy: 0.5054
# Epoch 00004: val_loss improved from 11.38786 to 10.99050, saving model to models/lstm2_multivar/multitask/04.hdf5
# 25/25 [==============================] - 1s 45ms/step - loss: 14.5929 - regr_loss: 1.7974 - clf_loss: 0.8546 - regr_mae: 1.0533 - clf_accuracy: 0.4848 - val_loss: 10.9905 - val_regr_loss: 0.1779 - val_clf_loss: 0.7134 - val_regr_mae: 0.2897 - val_clf_accuracy: 0.5000
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 24/25 [===========================>..] - ETA: 0s - loss: 14.5171 - regr_loss: 1.9681 - clf_loss: 0.7591 - regr_mae: 1.1263 - clf_accuracy: 0.5260
# Epoch 00005: val_loss improved from 10.99050 to 10.75772, saving model to models/lstm2_multivar/multitask/05.hdf5
# 25/25 [==============================] - 1s 45ms/step - loss: 14.6020 - regr_loss: 2.0121 - clf_loss: 0.7611 - regr_mae: 1.1364 - clf_accuracy: 0.5253 - val_loss: 10.7577 - val_regr_loss: 0.1711 - val_clf_loss: 0.7090 - val_regr_mae: 0.3005 - val_clf_accuracy: 0.5000
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 24/25 [===========================>..] - ETA: 0s - loss: 14.0794 - regr_loss: 1.8462 - clf_loss: 0.7795 - regr_mae: 1.0499 - clf_accuracy: 0.5417
# Epoch 00006: val_loss improved from 10.75772 to 10.52824, saving model to models/lstm2_multivar/multitask/06.hdf5
# 25/25 [==============================] - 1s 46ms/step - loss: 14.5375 - regr_loss: 2.0780 - clf_loss: 0.7827 - regr_mae: 1.0943 - clf_accuracy: 0.5404 - val_loss: 10.5282 - val_regr_loss: 0.1663 - val_clf_loss: 0.7000 - val_regr_mae: 0.3194 - val_clf_accuracy: 0.5000
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 24/25 [===========================>..] - ETA: 0s - loss: 13.8482 - regr_loss: 1.8175 - clf_loss: 0.8121 - regr_mae: 1.0259 - clf_accuracy: 0.4688
# Epoch 00007: val_loss improved from 10.52824 to 10.32757, saving model to models/lstm2_multivar/multitask/07.hdf5
# 25/25 [==============================] - 1s 48ms/step - loss: 13.7677 - regr_loss: 1.7810 - clf_loss: 0.8080 - regr_mae: 1.0182 - clf_accuracy: 0.4697 - val_loss: 10.3276 - val_regr_loss: 0.1669 - val_clf_loss: 0.7050 - val_regr_mae: 0.3090 - val_clf_accuracy: 0.5000
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 24/25 [===========================>..] - ETA: 0s - loss: 13.1802 - regr_loss: 1.6045 - clf_loss: 0.7783 - regr_mae: 0.9734 - clf_accuracy: 0.5052
# Epoch 00008: val_loss improved from 10.32757 to 10.13050, saving model to models/lstm2_multivar/multitask/08.hdf5
# 25/25 [==============================] - 1s 46ms/step - loss: 13.1467 - regr_loss: 1.5913 - clf_loss: 0.7750 - regr_mae: 0.9762 - clf_accuracy: 0.5051 - val_loss: 10.1305 - val_regr_loss: 0.1713 - val_clf_loss: 0.7067 - val_regr_mae: 0.3209 - val_clf_accuracy: 0.5000
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 23/25 [==========================>...] - ETA: 0s - loss: 12.8110 - regr_loss: 1.5257 - clf_loss: 0.7676 - regr_mae: 0.9605 - clf_accuracy: 0.4946
# Epoch 00009: val_loss improved from 10.13050 to 9.92960, saving model to models/lstm2_multivar/multitask/09.hdf5
# 25/25 [==============================] - 1s 46ms/step - loss: 12.9308 - regr_loss: 1.5971 - clf_loss: 0.7533 - regr_mae: 0.9810 - clf_accuracy: 0.5051 - val_loss: 9.9296 - val_regr_loss: 0.1691 - val_clf_loss: 0.7129 - val_regr_mae: 0.3248 - val_clf_accuracy: 0.5000
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 23/25 [==========================>...] - ETA: 0s - loss: 13.3672 - regr_loss: 1.8931 - clf_loss: 0.7483 - regr_mae: 1.1075 - clf_accuracy: 0.5272
# Epoch 00010: val_loss improved from 9.92960 to 9.83187, saving model to models/lstm2_multivar/multitask/10.hdf5
# 25/25 [==============================] - 1s 44ms/step - loss: 13.3169 - regr_loss: 1.8650 - clf_loss: 0.7582 - regr_mae: 1.1042 - clf_accuracy: 0.5202 - val_loss: 9.8319 - val_regr_loss: 0.1729 - val_clf_loss: 0.7115 - val_regr_mae: 0.3338 - val_clf_accuracy: 0.5000
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 23/25 [==========================>...] - ETA: 0s - loss: 12.7954 - regr_loss: 1.6452 - clf_loss: 0.7756 - regr_mae: 1.0289 - clf_accuracy: 0.4891
# Epoch 00011: val_loss improved from 9.83187 to 9.74254, saving model to models/lstm2_multivar/multitask/11.hdf5
# 25/25 [==============================] - 1s 46ms/step - loss: 12.7115 - regr_loss: 1.6076 - clf_loss: 0.7708 - regr_mae: 1.0164 - clf_accuracy: 0.5000 - val_loss: 9.7425 - val_regr_loss: 0.1776 - val_clf_loss: 0.7151 - val_regr_mae: 0.3314 - val_clf_accuracy: 0.5000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 23/25 [==========================>...] - ETA: 0s - loss: 12.1004 - regr_loss: 1.3947 - clf_loss: 0.6846 - regr_mae: 0.9400 - clf_accuracy: 0.5870
# Epoch 00012: val_loss improved from 9.74254 to 9.65638, saving model to models/lstm2_multivar/multitask/12.hdf5
# 25/25 [==============================] - 1s 46ms/step - loss: 12.2061 - regr_loss: 1.4484 - clf_loss: 0.6870 - regr_mae: 0.9617 - clf_accuracy: 0.5859 - val_loss: 9.6564 - val_regr_loss: 0.1818 - val_clf_loss: 0.7231 - val_regr_mae: 0.3164 - val_clf_accuracy: 0.5000
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 23/25 [==========================>...] - ETA: 0s - loss: 12.4850 - regr_loss: 1.6157 - clf_loss: 0.7284 - regr_mae: 0.9902 - clf_accuracy: 0.5435
# Epoch 00013: val_loss improved from 9.65638 to 9.58447, saving model to models/lstm2_multivar/multitask/13.hdf5
# 25/25 [==============================] - 1s 48ms/step - loss: 12.2985 - regr_loss: 1.5264 - clf_loss: 0.7237 - regr_mae: 0.9628 - clf_accuracy: 0.5404 - val_loss: 9.5845 - val_regr_loss: 0.1891 - val_clf_loss: 0.7370 - val_regr_mae: 0.3123 - val_clf_accuracy: 0.5000
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 23/25 [==========================>...] - ETA: 0s - loss: 12.2496 - regr_loss: 1.5436 - clf_loss: 0.7358 - regr_mae: 0.9891 - clf_accuracy: 0.5815
# Epoch 00014: val_loss improved from 9.58447 to 9.46697, saving model to models/lstm2_multivar/multitask/14.hdf5
# 25/25 [==============================] - 1s 47ms/step - loss: 12.4288 - regr_loss: 1.6420 - clf_loss: 0.7236 - regr_mae: 1.0150 - clf_accuracy: 0.5859 - val_loss: 9.4670 - val_regr_loss: 0.1802 - val_clf_loss: 0.7364 - val_regr_mae: 0.3082 - val_clf_accuracy: 0.5000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 23/25 [==========================>...] - ETA: 0s - loss: 12.7656 - regr_loss: 1.8414 - clf_loss: 0.7352 - regr_mae: 1.0592 - clf_accuracy: 0.5435
# Epoch 00015: val_loss improved from 9.46697 to 9.42283, saving model to models/lstm2_multivar/multitask/15.hdf5
# 25/25 [==============================] - 1s 45ms/step - loss: 12.8713 - regr_loss: 1.9031 - clf_loss: 0.7205 - regr_mae: 1.0624 - clf_accuracy: 0.5556 - val_loss: 9.4228 - val_regr_loss: 0.1859 - val_clf_loss: 0.7309 - val_regr_mae: 0.3105 - val_clf_accuracy: 0.4500
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 23/25 [==========================>...] - ETA: 0s - loss: 12.0237 - regr_loss: 1.4943 - clf_loss: 0.7370 - regr_mae: 0.9741 - clf_accuracy: 0.5489
# Epoch 00016: val_loss improved from 9.42283 to 9.38025, saving model to models/lstm2_multivar/multitask/16.hdf5
# 25/25 [==============================] - 1s 46ms/step - loss: 11.9781 - regr_loss: 1.4744 - clf_loss: 0.7332 - regr_mae: 0.9671 - clf_accuracy: 0.5505 - val_loss: 9.3802 - val_regr_loss: 0.1910 - val_clf_loss: 0.7282 - val_regr_mae: 0.3175 - val_clf_accuracy: 0.4500
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 23/25 [==========================>...] - ETA: 0s - loss: 11.9366 - regr_loss: 1.4790 - clf_loss: 0.7305 - regr_mae: 0.9771 - clf_accuracy: 0.6033
# Epoch 00017: val_loss improved from 9.38025 to 9.33697, saving model to models/lstm2_multivar/multitask/17.hdf5
# 25/25 [==============================] - 1s 45ms/step - loss: 11.8866 - regr_loss: 1.4616 - clf_loss: 0.7165 - regr_mae: 0.9784 - clf_accuracy: 0.6111 - val_loss: 9.3370 - val_regr_loss: 0.1948 - val_clf_loss: 0.7265 - val_regr_mae: 0.3218 - val_clf_accuracy: 0.4500
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 24/25 [===========================>..] - ETA: 0s - loss: 12.0997 - regr_loss: 1.6047 - clf_loss: 0.6922 - regr_mae: 1.0069 - clf_accuracy: 0.5729
# Epoch 00018: val_loss improved from 9.33697 to 9.32276, saving model to models/lstm2_multivar/multitask/18.hdf5
# 25/25 [==============================] - 1s 48ms/step - loss: 12.0780 - regr_loss: 1.5949 - clf_loss: 0.6908 - regr_mae: 1.0014 - clf_accuracy: 0.5758 - val_loss: 9.3228 - val_regr_loss: 0.2072 - val_clf_loss: 0.7368 - val_regr_mae: 0.3289 - val_clf_accuracy: 0.5000
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 23/25 [==========================>...] - ETA: 0s - loss: 12.1343 - regr_loss: 1.6499 - clf_loss: 0.6851 - regr_mae: 1.0546 - clf_accuracy: 0.5924
# Epoch 00019: val_loss improved from 9.32276 to 9.28514, saving model to models/lstm2_multivar/multitask/19.hdf5
# 25/25 [==============================] - 1s 47ms/step - loss: 12.0861 - regr_loss: 1.6250 - clf_loss: 0.6884 - regr_mae: 1.0514 - clf_accuracy: 0.5859 - val_loss: 9.2851 - val_regr_loss: 0.2134 - val_clf_loss: 0.7366 - val_regr_mae: 0.3357 - val_clf_accuracy: 0.5000
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 23/25 [==========================>...] - ETA: 0s - loss: 11.9717 - regr_loss: 1.5543 - clf_loss: 0.7527 - regr_mae: 0.9912 - clf_accuracy: 0.5598
# Epoch 00020: val_loss improved from 9.28514 to 9.26555, saving model to models/lstm2_multivar/multitask/20.hdf5
# 25/25 [==============================] - 1s 46ms/step - loss: 11.9638 - regr_loss: 1.5456 - clf_loss: 0.7623 - regr_mae: 0.9903 - clf_accuracy: 0.5556 - val_loss: 9.2656 - val_regr_loss: 0.2133 - val_clf_loss: 0.7430 - val_regr_mae: 0.3410 - val_clf_accuracy: 0.5000
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 24/25 [===========================>..] - ETA: 0s - loss: 11.8411 - regr_loss: 1.4982 - clf_loss: 0.7603 - regr_mae: 0.9635 - clf_accuracy: 0.5417
# Epoch 00021: val_loss improved from 9.26555 to 9.25613, saving model to models/lstm2_multivar/multitask/21.hdf5
# 25/25 [==============================] - 1s 46ms/step - loss: 11.7674 - regr_loss: 1.4651 - clf_loss: 0.7526 - regr_mae: 0.9564 - clf_accuracy: 0.5505 - val_loss: 9.2561 - val_regr_loss: 0.2177 - val_clf_loss: 0.7498 - val_regr_mae: 0.3467 - val_clf_accuracy: 0.5000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 24/25 [===========================>..] - ETA: 0s - loss: 11.7679 - regr_loss: 1.4710 - clf_loss: 0.7665 - regr_mae: 0.9770 - clf_accuracy: 0.5312
# Epoch 00022: val_loss did not improve from 9.25613
# 25/25 [==============================] - 1s 45ms/step - loss: 11.6780 - regr_loss: 1.4238 - clf_loss: 0.7705 - regr_mae: 0.9612 - clf_accuracy: 0.5253 - val_loss: 9.2608 - val_regr_loss: 0.2309 - val_clf_loss: 0.7532 - val_regr_mae: 0.3556 - val_clf_accuracy: 0.5000
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 23/25 [==========================>...] - ETA: 0s - loss: 11.9508 - regr_loss: 1.5756 - clf_loss: 0.7647 - regr_mae: 1.0024 - clf_accuracy: 0.5217
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.2500000593718141e-05.
#
# Epoch 00023: val_loss did not improve from 9.25613
# 25/25 [==============================] - 1s 45ms/step - loss: 11.8903 - regr_loss: 1.5531 - clf_loss: 0.7496 - regr_mae: 0.9919 - clf_accuracy: 0.5404 - val_loss: 9.2631 - val_regr_loss: 0.2448 - val_clf_loss: 0.7527 - val_regr_mae: 0.3626 - val_clf_accuracy: 0.5000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 24/32
# 23/25 [==========================>...] - ETA: 0s - loss: 11.7324 - regr_loss: 1.4828 - clf_loss: 0.7483 - regr_mae: 0.9840 - clf_accuracy: 0.5272
# Epoch 00024: val_loss did not improve from 9.25613
# 25/25 [==============================] - 1s 44ms/step - loss: 12.0698 - regr_loss: 1.6439 - clf_loss: 0.7645 - regr_mae: 1.0151 - clf_accuracy: 0.5253 - val_loss: 9.2619 - val_regr_loss: 0.2461 - val_clf_loss: 0.7542 - val_regr_mae: 0.3642 - val_clf_accuracy: 0.5000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 25/32
# 24/25 [===========================>..] - ETA: 0s - loss: 11.8415 - regr_loss: 1.5448 - clf_loss: 0.7378 - regr_mae: 0.9703 - clf_accuracy: 0.5312
# Epoch 00025: val_loss did not improve from 9.25613
# 25/25 [==============================] - 1s 46ms/step - loss: 12.0122 - regr_loss: 1.6320 - clf_loss: 0.7358 - regr_mae: 0.9888 - clf_accuracy: 0.5354 - val_loss: 9.2688 - val_regr_loss: 0.2494 - val_clf_loss: 0.7574 - val_regr_mae: 0.3672 - val_clf_accuracy: 0.5000
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 26/32
# 24/25 [===========================>..] - ETA: 0s - loss: 11.9822 - regr_loss: 1.6022 - clf_loss: 0.7663 - regr_mae: 0.9740 - clf_accuracy: 0.4844
# Epoch 00026: val_loss did not improve from 9.25613
# 25/25 [==============================] - 1s 47ms/step - loss: 11.9127 - regr_loss: 1.5726 - clf_loss: 0.7554 - regr_mae: 0.9683 - clf_accuracy: 0.4899 - val_loss: 9.2732 - val_regr_loss: 0.2526 - val_clf_loss: 0.7579 - val_regr_mae: 0.3699 - val_clf_accuracy: 0.5000
# Epoch 00026: early stopping

# %%
def plot_multitask_history(hist):
    fig, ax = plt.subplots(2, 2, figsize=(16, 12))
    plotHelpers.plot_train_history(ax[0, 0], hist, 'Total loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[0, 1], hist, 'Accuracy', 'clf_accuracy', 'val_clf_accuracy')
    plotHelpers.plot_train_history(ax[1, 0], hist, 'MSE', 'regr_loss', 'val_regr_loss')
    plotHelpers.plot_train_history(ax[1, 1], hist, 'MAE', 'regr_mae', 'val_regr_mae')
    
plot_multitask_history(multitask_history);

# %% [markdown]
# ### Прогноз

# %%
# загружаем последнюю эпоху с минимальным лоссом
multivariate_multitask_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret, pred_direction_proba = multivariate_multitask_lstm.predict_generator(test_multi_gen, verbose=1)
# Out:
# 3/3 [==============================] - 0s 132ms/step

# %%
np.set_printoptions(precision=3, suppress=True)

np.column_stack([pred_log_ret, pred_direction_proba])[-10:]
# Out:
# array([[ 0.119,  0.496],
#        [ 0.042,  0.541],
#        [ 0.141,  0.558],
#        [ 0.116,  0.511],
#        [ 0.089,  0.482],
#        [ 0.272,  0.514],
#        [ 0.23 ,  0.53 ],
#        [ 0.045,  0.557],
#        [-0.038,  0.539],
#        [ 0.05 ,  0.514]], dtype=float32)

# %% [markdown]
# #### Прогноз задачи регрессии

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret, figsize=(16, 10), datetime_unit='D')

# %% [markdown]
# #### Прогноз задачи классификации

# %%
true_direction = test_multi_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 0.50040907

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([11, 10])), (array([0, 1]), array([ 9, 12])))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.36      0.36      0.36        11
#            1       0.30      0.30      0.30        10
#
#     accuracy                           0.33        21
#    macro avg       0.33      0.33      0.33        21
# weighted avg       0.33      0.33      0.33        21

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[6, 5],
#        [3, 7]])

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.66666667, 0.41666667],
#        [0.33333333, 0.58333333]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# # Выводы
#
# 1.  Инициализация весов (`bias_initializer`) в слое **LSTM** оказалась очень важным параметром.
# 2.  Обучение моделей на задачу классификации даёт нестабильный результат. Как можно видеть, для конкретного запуска отдельная модель для задачи классфикации выдаёт, можно сказать, обратный прогноз. В то же время для комбинированной задачи регрессии/классификации результат по метрике ROC-AUC получился даже довольно неплохой.

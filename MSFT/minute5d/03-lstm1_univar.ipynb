# %% [markdown]
# # *Одномерная модель на LSTM* (1 слой)
#
# В качестве единственного признака используется сама цена.

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import os
import glob
import datetime
import pickle

import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
from pandas_datareader import data as pdr

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
import tensorflow as tf
# tf.test.is_gpu_available()
tf.__version__
# Out:
# '2.0.0'

# %%
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Input, Dense, LSTM, GRU, Flatten, ReLU, LeakyReLU, Dropout, BatchNormalization
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers import Nadam

# %%
from mdp import TimeSeries
from mdp import MarketData
from mdp import MovingWindowFeatures
from mdp import ClassificationGenerator, RegressionGenerator, MultitaskGenerator
from mdp import invert_log_ret

import mdp.utils as utils
import mdp.plotHelpers as plotHelpers

# %%
import importlib

import mdp

importlib.reload(mdp)
importlib.reload(mdp.datasetGenerator)
importlib.reload(mdp.marketData)
importlib.reload(mdp.movingWindowFeatures)
importlib.reload(mdp.timeSeries)
importlib.reload(mdp.plotHelpers)
importlib.reload(mdp.utils);

# %% [markdown]
# # *Параметры*

# %%
INSTRUMENT = 'MSFT' # Microsoft corp
START_FROM = np.datetime64('today') - 7
WINDOW_SIZE = 120
FORECAST_OFFSET=1
BATCH_SIZE = 32
FORCE_TRAIN = True

# %% [markdown]
# # *Исходные данные*
#
# Загрузка данных и вычисление индикаторов.

# %%
instr = MarketData.create_from_alphavantage_intraday(INSTRUMENT, start=START_FROM)

# %%
instr.feature_names
# Out:
# ['o',
#  'h',
#  'l',
#  'c',
#  'v',
#  'ema14',
#  'ema30',
#  'macd',
#  'macd_signal',
#  'rsi14',
#  'bband20_upper',
#  'bband20_middle',
#  'bband20_lower',
#  'willr14',
#  'stochk',
#  'stochd',
#  'adline',
#  'adosc']

# %% [markdown]
# Здесь не будем делить отдельно на тест и валидацию, поскольку данных у нас только 5 дней.

# %%
dates_unique = np.unique(instr.timestamps.astype('datetime64[D]'))

START_FROM = dates_unique[0]
VAL_TEST_SPLIT = dates_unique[-1]

START_FROM, VAL_TEST_SPLIT
# Out:
# (numpy.datetime64('2020-04-08'), numpy.datetime64('2020-04-14'))

# %% [markdown]
# ## Целевая переменная

# %% [markdown]
# Цена закрытия.

# %%
orig_target = instr.c

# %% [markdown]
# Переходим к логарифмической доходности.

# %%
transformed_target = instr.c.transform(transforms={'ratios' : {}, 'ln' : {}})

# %%
plotHelpers.plot_transformed_timeseries_unit(instr,
                                             transformed_target,
                                             'Close price, USD', 'Log return',
                                             datetime_unit='m', rotation=45)

# %% [markdown]
# ## Трансформация признаков
#
# Выбираем только один признак: цену закрытия.
# Временной ряд цены преобразуется к логарифмической доходности (что также позволяет убрать нестационарность).

# %%
def make_feature_selector():
    price_transformer = lambda: {'ratios': {}, 'ln': {}}
    diff_transformer = lambda o: {'diffs': {'order': o}}
    identity_transformer = lambda: {}
    feature_transformations = {
        'c': price_transformer(),
    }
    return feature_transformations

# %%
instr_transformed = instr.select_transform(make_feature_selector())

# %%
transformed_target = instr_transformed.c

# %% [markdown]
# ## Обучающая, валидационная и тестовая выборки

# %%
instr_train, instr_test = instr_transformed.train_test_split(VAL_TEST_SPLIT, window_size=WINDOW_SIZE,
                                                             scaler=StandardScaler)
#                                                              scaler=MinMaxScaler,
#                                                              scaler_kwargs={'feature_range': (-1, 1)})

# instr_val, instr_test = instr_val_test.train_test_split(TEST_SPLIT, window_size=WINDOW_SIZE, scaler=None)

len(instr_train), len(instr_test)
# Out:
# (1136, 506)

# %% [markdown]
# ## Признаки - скользящие окна

# %%
train_mwf = MovingWindowFeatures.create(instr_train.c, [instr_train], instr_train.feature_names, window_size=WINDOW_SIZE)
# val_mwf = MovingWindowFeatures.create(instr_val.c, [instr_val], instr_val.feature_names, window_size=WINDOW_SIZE)
test_mwf = MovingWindowFeatures.create(instr_test.c, [instr_test], instr_test.feature_names, window_size=WINDOW_SIZE)

len(instr_train), len(train_mwf), train_mwf.features.shape
# Out:
# (1136, 1016, (1016, 120, 1))

# %% [markdown]
# Проверка, что скользящие окна соответствуют исходным данным.
#
# Возьмём произвольный признак и произвольное окно (строка #**41**). Проверим, что данные в точности совпадают:

# %%
def check_data(md, mwf, row):
    col = np.random.randint(len(mwf.feature_names))
    feature = mwf.feature_names[col]
    check = (getattr(md, feature).data[row:row + mwf.window_size] == mwf.features[row, :, col]).all()
    assert check
    return feature, check

check_data(instr_train, train_mwf, 41)
# Out:
# ('c', True)

# %% [markdown]
# # *Модели*

# %% [markdown]
# Модель с одним LSTM слоем.

# %%
def build_lstm_layers(input_shape, latent_dim=32):
    # формат входа: матрица (окно; признак)
    inp = Input(input_shape, name='input')

    lstm = LSTM(latent_dim, return_sequences=True,
                    recurrent_dropout=0.2, dropout=0.2,
                    bias_initializer='he_uniform',
                    bias_regularizer=L1L2(0.01, 0.02),
                    kernel_regularizer=L1L2(0.01, 0.02),
                    recurrent_regularizer=L1L2(0.01, 0.02)
               )(inp)
    
    lstm = Flatten()(lstm)
    
    return inp, lstm

# %% [markdown]
# #### Пути сохранения моделей:

# %%
model_path_root = 'models'
model_type_name = 'lstm1_univar'

def make_model_save_dir(path_root, type_name, class_name):
    save_dir = os.path.join(path_root, type_name, class_name)
    os.makedirs(save_dir, exist_ok=True)
    return save_dir

# %% [markdown]
# #### Общие коллбэки:

# %%
# уменьшение learning rate в случае, если loss не изменяется
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001, verbose=1)

# уменьшение learning rate в 2 раза каждую 5-ю эпоху
def lr_decay(e, lr):
    return lr * (1 - 0.5 * (0 == (e + 1) % 5))

lr_scheduler = LearningRateScheduler(schedule=lr_decay, verbose=1)

# %% [markdown]
# ## Задача регрессии
#
# Непосредственное прогнозирование цены следующего периода.

# %%
train_regr_gen = RegressionGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_regr_gen = RegressionGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_regr_gen = RegressionGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# Следующие числа соответствуют значению параметра `steps_per_epoch` метода [`fit_generator`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit_generator "tf.keras.layers.SimpleRNN &nbsp;|&nbsp; TensorFlow Core r2.0") - то есть это число батчей, которые генератор выдаст за одну эпоху обучения (если класс генератора поддерживает метод `len()`, то данный параметр можно не указывать).

# %%
len(train_regr_gen), len(test_regr_gen)
# Out:
# (32, 13)

# %% [markdown]
# Один сэмпл данных представляет собой матрицу размером *(длина окна; число признаков)*

# %%
train_regr_gen.input_shape
# Out:
# (120, 1)

# %% [markdown]
# ### Модель для задачи регрессии

# %%
model_class_name = 'regression'

# %%
def build_regression_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=32)

    regr = Dense(64)(lstm)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    return Model(inputs=[inp], outputs=[regr])

# %%
univariate_regression_lstm = build_regression_model(train_regr_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:
# [`Nadam`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Nadam) (*Adam with Nestrov momentum*).

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Функция потерь:
#
# Попробуем использовать MAE.

# %%
univariate_regression_lstm.compile(optimizer=optimizer,
                                   loss={'regr': 'mae'},
                                   metrics={'regr': 'mse'})

univariate_regression_lstm.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 120, 1)]          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 120, 32)           4352
# _________________________________________________________________
# flatten (Flatten)            (None, 3840)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                245824
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64)                256
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 64)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# regr (Dense)                 (None, 1)                 65
# =================================================================
# Total params: 250,497
# Trainable params: 250,369
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# #### Обучение:

# %%
regr_history = utils.train_model(univariate_regression_lstm,
                                 model_save_dir, train_regr_gen, test_regr_gen,
                                 callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                 force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.6792 - mse: 2.5103
# Epoch 00001: val_loss improved from inf to 4.55880, saving model to models\lstm1_univar\regression\01.hdf5
# 32/32 [==============================] - 19s 587ms/step - loss: 5.6633 - mse: 2.5002 - val_loss: 4.5588 - val_mse: 1.5230
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.5527 - mse: 1.9786
# Epoch 00002: val_loss improved from 4.55880 to 3.65887, saving model to models\lstm1_univar\regression\02.hdf5
# 32/32 [==============================] - 20s 626ms/step - loss: 4.5330 - mse: 1.9716 - val_loss: 3.6589 - val_mse: 1.5175
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.6975 - mse: 1.7502
# Epoch 00003: val_loss improved from 3.65887 to 3.00893, saving model to models\lstm1_univar\regression\03.hdf5
# 32/32 [==============================] - 18s 566ms/step - loss: 3.6920 - mse: 1.7547 - val_loss: 3.0089 - val_mse: 1.5264
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.1033 - mse: 1.5539
# Epoch 00004: val_loss improved from 3.00893 to 2.63792, saving model to models\lstm1_univar\regression\04.hdf5
# 32/32 [==============================] - 18s 570ms/step - loss: 3.0919 - mse: 1.5393 - val_loss: 2.6379 - val_mse: 1.6831
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.7424 - mse: 1.4401
# Epoch 00005: val_loss improved from 2.63792 to 2.37217, saving model to models\lstm1_univar\regression\05.hdf5
# 32/32 [==============================] - 18s 563ms/step - loss: 2.7413 - mse: 1.4542 - val_loss: 2.3722 - val_mse: 1.5240
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.5340 - mse: 1.3899
# Epoch 00006: val_loss improved from 2.37217 to 2.33759, saving model to models\lstm1_univar\regression\06.hdf5
# 32/32 [==============================] - 17s 535ms/step - loss: 2.5336 - mse: 1.4094 - val_loss: 2.3376 - val_mse: 1.7801
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.3762 - mse: 1.3159
# Epoch 00007: val_loss improved from 2.33759 to 2.26201, saving model to models\lstm1_univar\regression\07.hdf5
# 32/32 [==============================] - 17s 535ms/step - loss: 2.3779 - mse: 1.3228 - val_loss: 2.2620 - val_mse: 1.9054
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2657 - mse: 1.3435
# Epoch 00008: val_loss improved from 2.26201 to 2.03267, saving model to models\lstm1_univar\regression\08.hdf5
# 32/32 [==============================] - 18s 557ms/step - loss: 2.2636 - mse: 1.3398 - val_loss: 2.0327 - val_mse: 1.6977
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1217 - mse: 1.2509
# Epoch 00009: val_loss improved from 2.03267 to 1.92046, saving model to models\lstm1_univar\regression\09.hdf5
# 32/32 [==============================] - 18s 568ms/step - loss: 2.1212 - mse: 1.2526 - val_loss: 1.9205 - val_mse: 1.6407
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0357 - mse: 1.2053
# Epoch 00010: val_loss did not improve from 1.92046
# 32/32 [==============================] - 17s 542ms/step - loss: 2.0351 - mse: 1.2054 - val_loss: 1.9483 - val_mse: 1.8594
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0099 - mse: 1.3071
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 5.0000002374872565e-05.
#
# Epoch 00011: val_loss did not improve from 1.92046
# 32/32 [==============================] - 18s 554ms/step - loss: 2.0129 - mse: 1.3132 - val_loss: 2.0332 - val_mse: 2.1172
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 5.0000002374872565e-05.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9216 - mse: 1.1290
# Epoch 00012: val_loss did not improve from 1.92046
# 32/32 [==============================] - 18s 556ms/step - loss: 1.9269 - mse: 1.1360 - val_loss: 1.9486 - val_mse: 1.9748
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 5.0000002374872565e-05.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9363 - mse: 1.1766
# Epoch 00013: val_loss improved from 1.92046 to 1.90360, saving model to models\lstm1_univar\regression\13.hdf5
# 32/32 [==============================] - 18s 560ms/step - loss: 1.9416 - mse: 1.1809 - val_loss: 1.9036 - val_mse: 1.9191
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 5.0000002374872565e-05.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9390 - mse: 1.1833
# Epoch 00014: val_loss improved from 1.90360 to 1.83296, saving model to models\lstm1_univar\regression\14.hdf5
# 32/32 [==============================] - 20s 633ms/step - loss: 1.9401 - mse: 1.1902 - val_loss: 1.8330 - val_mse: 1.7913
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.8900 - mse: 1.1218
# Epoch 00015: val_loss improved from 1.83296 to 1.82405, saving model to models\lstm1_univar\regression\15.hdf5
# 32/32 [==============================] - 19s 579ms/step - loss: 1.8949 - mse: 1.1267 - val_loss: 1.8241 - val_mse: 1.7821
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9044 - mse: 1.1786
# Epoch 00016: val_loss did not improve from 1.82405
# 32/32 [==============================] - 17s 524ms/step - loss: 1.9054 - mse: 1.1790 - val_loss: 1.8413 - val_mse: 1.8410
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9045 - mse: 1.1799
# Epoch 00017: val_loss improved from 1.82405 to 1.80775, saving model to models\lstm1_univar\regression\17.hdf5
# 32/32 [==============================] - 17s 531ms/step - loss: 1.9098 - mse: 1.1958 - val_loss: 1.8078 - val_mse: 1.7613
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9039 - mse: 1.2190
# Epoch 00018: val_loss improved from 1.80775 to 1.79395, saving model to models\lstm1_univar\regression\18.hdf5
# 32/32 [==============================] - 17s 528ms/step - loss: 1.9059 - mse: 1.2157 - val_loss: 1.7940 - val_mse: 1.7284
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.8833 - mse: 1.1082
# Epoch 00019: val_loss improved from 1.79395 to 1.79370, saving model to models\lstm1_univar\regression\19.hdf5
# 32/32 [==============================] - 17s 538ms/step - loss: 1.8861 - mse: 1.1089 - val_loss: 1.7937 - val_mse: 1.7390
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.8919 - mse: 1.1816
# Epoch 00020: val_loss did not improve from 1.79370
# 32/32 [==============================] - 16s 515ms/step - loss: 1.8854 - mse: 1.1673 - val_loss: 1.7963 - val_mse: 1.7555
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.8775 - mse: 1.1214
# Epoch 00021: val_loss improved from 1.79370 to 1.78482, saving model to models\lstm1_univar\regression\21.hdf5
# 32/32 [==============================] - 17s 529ms/step - loss: 1.8799 - mse: 1.1296 - val_loss: 1.7848 - val_mse: 1.7229
# Epoch 00022: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 22/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.8944 - mse: 1.2023
# Epoch 00022: val_loss did not improve from 1.78482
# 32/32 [==============================] - 17s 533ms/step - loss: 1.8838 - mse: 1.1825 - val_loss: 1.7899 - val_mse: 1.7488
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 23/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.8755 - mse: 1.1233
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00023: val_loss did not improve from 1.78482
# 32/32 [==============================] - 17s 517ms/step - loss: 1.8741 - mse: 1.1164 - val_loss: 1.7875 - val_mse: 1.7488
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 9.999999747378752e-06.
# Epoch 24/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.8929 - mse: 1.1985
# Epoch 00024: val_loss did not improve from 1.78482
# 32/32 [==============================] - 20s 619ms/step - loss: 1.8955 - mse: 1.1939 - val_loss: 1.7851 - val_mse: 1.7462
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 4.999999873689376e-06.
# Epoch 25/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.8534 - mse: 1.1103
# Epoch 00025: val_loss did not improve from 1.78482
# 32/32 [==============================] - 16s 515ms/step - loss: 1.8617 - mse: 1.1211 - val_loss: 1.7861 - val_mse: 1.7529
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 4.999999873689376e-06.
# Epoch 26/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.8512 - mse: 1.1103
# Epoch 00026: val_loss did not improve from 1.78482
# 32/32 [==============================] - 16s 512ms/step - loss: 1.8485 - mse: 1.1011 - val_loss: 1.7872 - val_mse: 1.7594
# Epoch 00026: early stopping

# %%
def plot_regr_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'MAE', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'MSE', 'mse', 'val_mse')
    
plot_regr_history(regr_history);

# %% [markdown]
# ### Прогноз задачи регрессии

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_regression_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret_test = univariate_regression_lstm.predict_generator(test_regr_gen, verbose=1)
# Out:
# 13/13 [==============================] - 3s 228ms/step

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret_test, figsize=(16, 20),
                                  datetime_unit='m', plot_data_slice=slice(1, None))

# %% [markdown]
# ## Задача классификации
#
# Прогнозируем направление изменения цены по сравнению с предыдущим периодом (**0** - снижение, **1** - рост).

# %%
model_class_name = 'classification'

# %%
train_clf_gen = ClassificationGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_clf_gen = ClassificationGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_clf_gen = ClassificationGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_classification_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape)

    clf = Dense(64)(lstm)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)

    return Model(inputs=[inp], outputs=[clf])

# %%
univariate_classification_lstm = build_classification_model(test_clf_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
univariate_classification_lstm.compile(optimizer=optimizer,
                                         loss={'clf': 'binary_crossentropy'},
                                         metrics={'clf': 'accuracy'})

univariate_classification_lstm.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 120, 1)]          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 120, 32)           4352
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3840)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                245824
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# clf (Dense)                  (None, 1)                 65
# =================================================================
# Total params: 250,497
# Trainable params: 250,369
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
clf_history = utils.train_model(univariate_classification_lstm,
                                model_save_dir, train_clf_gen, test_clf_gen,
                                callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.3170 - accuracy: 0.4788
# Epoch 00001: val_loss improved from inf to 4.45638, saving model to models\lstm1_univar\classification\01.hdf5
# 32/32 [==============================] - 17s 528ms/step - loss: 5.2931 - accuracy: 0.4803 - val_loss: 4.4564 - val_accuracy: 0.5518
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.0874 - accuracy: 0.5403
# Epoch 00002: val_loss improved from 4.45638 to 3.63132, saving model to models\lstm1_univar\classification\02.hdf5
# 32/32 [==============================] - 16s 515ms/step - loss: 4.0725 - accuracy: 0.5394 - val_loss: 3.6313 - val_accuracy: 0.4352
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.2182 - accuracy: 0.5756
# Epoch 00003: val_loss improved from 3.63132 to 2.87702, saving model to models\lstm1_univar\classification\03.hdf5
# 32/32 [==============================] - 17s 516ms/step - loss: 3.2122 - accuracy: 0.5728 - val_loss: 2.8770 - val_accuracy: 0.4378
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.6379 - accuracy: 0.5565
# Epoch 00004: val_loss improved from 2.87702 to 2.37332, saving model to models\lstm1_univar\classification\04.hdf5
# 32/32 [==============================] - 17s 516ms/step - loss: 2.6267 - accuracy: 0.5591 - val_loss: 2.3733 - val_accuracy: 0.5155
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2714 - accuracy: 0.5867
# Epoch 00005: val_loss improved from 2.37332 to 2.19835, saving model to models\lstm1_univar\classification\05.hdf5
# 32/32 [==============================] - 17s 517ms/step - loss: 2.2673 - accuracy: 0.5876 - val_loss: 2.1983 - val_accuracy: 0.4689
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1087 - accuracy: 0.5837
# Epoch 00006: val_loss improved from 2.19835 to 2.08993, saving model to models\lstm1_univar\classification\06.hdf5
# 32/32 [==============================] - 17s 531ms/step - loss: 2.1039 - accuracy: 0.5837 - val_loss: 2.0899 - val_accuracy: 0.4223
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9616 - accuracy: 0.5726
# Epoch 00007: val_loss improved from 2.08993 to 1.98828, saving model to models\lstm1_univar\classification\07.hdf5
# 32/32 [==============================] - 17s 518ms/step - loss: 1.9586 - accuracy: 0.5728 - val_loss: 1.9883 - val_accuracy: 0.4326
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.8319 - accuracy: 0.6240
# Epoch 00008: val_loss improved from 1.98828 to 1.86321, saving model to models\lstm1_univar\classification\08.hdf5
# 32/32 [==============================] - 16s 513ms/step - loss: 1.8303 - accuracy: 0.6220 - val_loss: 1.8632 - val_accuracy: 0.4119
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7331 - accuracy: 0.6018
# Epoch 00009: val_loss improved from 1.86321 to 1.74123, saving model to models\lstm1_univar\classification\09.hdf5
# 32/32 [==============================] - 19s 594ms/step - loss: 1.7315 - accuracy: 0.6014 - val_loss: 1.7412 - val_accuracy: 0.5389
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.6714 - accuracy: 0.5766
# Epoch 00010: val_loss improved from 1.74123 to 1.73474, saving model to models\lstm1_univar\classification\10.hdf5
# 32/32 [==============================] - 18s 556ms/step - loss: 1.6715 - accuracy: 0.5768 - val_loss: 1.7347 - val_accuracy: 0.4560
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.6127 - accuracy: 0.6169
# Epoch 00011: val_loss did not improve from 1.73474
# 32/32 [==============================] - 18s 575ms/step - loss: 1.6125 - accuracy: 0.6171 - val_loss: 1.7368 - val_accuracy: 0.4352
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.5690 - accuracy: 0.6179
# Epoch 00012: val_loss improved from 1.73474 to 1.73075, saving model to models\lstm1_univar\classification\12.hdf5
# 32/32 [==============================] - 18s 558ms/step - loss: 1.5665 - accuracy: 0.6161 - val_loss: 1.7307 - val_accuracy: 0.4404
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.5528 - accuracy: 0.5917
# Epoch 00013: val_loss improved from 1.73075 to 1.64826, saving model to models\lstm1_univar\classification\13.hdf5
# 32/32 [==============================] - 19s 603ms/step - loss: 1.5588 - accuracy: 0.5866 - val_loss: 1.6483 - val_accuracy: 0.4611
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.5168 - accuracy: 0.6190
# Epoch 00014: val_loss improved from 1.64826 to 1.59340, saving model to models\lstm1_univar\classification\14.hdf5
# 32/32 [==============================] - 18s 577ms/step - loss: 1.5147 - accuracy: 0.6201 - val_loss: 1.5934 - val_accuracy: 0.4896
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.4598 - accuracy: 0.6331
# Epoch 00015: val_loss did not improve from 1.59340
# 32/32 [==============================] - 18s 560ms/step - loss: 1.4613 - accuracy: 0.6299 - val_loss: 1.5990 - val_accuracy: 0.4974
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.4563 - accuracy: 0.6240
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 2.5000001187436283e-05.
#
# Epoch 00016: val_loss did not improve from 1.59340
# 32/32 [==============================] - 22s 679ms/step - loss: 1.4572 - accuracy: 0.6260 - val_loss: 1.5961 - val_accuracy: 0.4948
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.4440 - accuracy: 0.6129
# Epoch 00017: val_loss did not improve from 1.59340
# 32/32 [==============================] - 22s 689ms/step - loss: 1.4462 - accuracy: 0.6142 - val_loss: 1.6039 - val_accuracy: 0.4896
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.4462 - accuracy: 0.6310
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00018: val_loss did not improve from 1.59340
# 32/32 [==============================] - 30s 929ms/step - loss: 1.4451 - accuracy: 0.6289 - val_loss: 1.6117 - val_accuracy: 0.4767
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 9.999999747378752e-06.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.4231 - accuracy: 0.6411
# Epoch 00019: val_loss did not improve from 1.59340
# 32/32 [==============================] - 24s 759ms/step - loss: 1.4269 - accuracy: 0.6407 - val_loss: 1.6147 - val_accuracy: 0.4870
# Epoch 00019: early stopping

# %%
def plot_clf_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'Loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'Accuracy', 'accuracy', 'val_accuracy')
    
plot_clf_history(clf_history);

# %% [markdown]
# ### Прогноз задачи классификации

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_classification_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %%
pred_direction_proba = univariate_classification_lstm.predict_generator(test_clf_gen, verbose=1)

true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 13/13 [==============================] - 5s 364ms/step
# 0.49802378

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([168, 218], dtype=int64)),
#  (array([0, 1]), array([175, 211], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.42      0.43      0.43       168
#            1       0.55      0.53      0.54       218
#
#     accuracy                           0.49       386
#    macro avg       0.48      0.48      0.48       386
# weighted avg       0.49      0.49      0.49       386

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[ 73,  95],
#        [102, 116]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.41714286, 0.45023697],
#        [0.58285714, 0.54976303]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# ## Многозадачная модель: одновременно регрессия и классификация
#
# Пытаемся одновременно предсказать и значение цены, и направление изменения, предполагая, что комбинированная ошибка позволит точнее скорректировать веса рекуррентных слоёв.

# %%
model_class_name = 'multitask'

# %%
train_multi_gen = MultitaskGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_multi_gen = MultitaskGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_multi_gen = MultitaskGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_multitask_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=32)

    # первый выход: задача регрссии
    regr = Dense(64)(lstm)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    # второй выход: задача классификации
    clf = Dense(64)(lstm)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)
    
    return Model(inputs=[inp], outputs=[regr, clf])

# %%
univariate_multitask_lstm = build_multitask_model(train_multi_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
univariate_multitask_lstm.compile(optimizer=optimizer,
                                  loss={'regr': 'mae', 'clf': 'binary_crossentropy'},
                                  loss_weights={'regr': 1., 'clf': 1.},
                                  metrics={'regr': 'mse', 'clf' : 'accuracy'})

univariate_multitask_lstm.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 120, 1)]     0
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 120, 32)      4352        input[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 3840)         0           lstm_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           245824      flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           245824      flatten_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64)           256         dense_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64)           256         dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 64)           0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 64)           0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64)           0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64)           0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# regr (Dense)                    (None, 1)            65          dropout_2[0][0]
# __________________________________________________________________________________________________
# clf (Dense)                     (None, 1)            65          dropout_3[0][0]
# ==================================================================================================
# Total params: 496,642
# Trainable params: 496,386
# Non-trainable params: 256
# __________________________________________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
multitask_history = utils.train_model(univariate_multitask_lstm,
                                      model_save_dir, train_multi_gen, test_multi_gen,
                                      callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                      force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.6824 - regr_loss: 1.3143 - clf_loss: 0.8859 - regr_mse: 2.8954 - clf_accuracy: 0.5232
# Epoch 00001: val_loss improved from inf to 5.40459, saving model to models\lstm1_univar\multitask\01.hdf5
# 32/32 [==============================] - 20s 627ms/step - loss: 6.6629 - regr_loss: 1.3100 - clf_loss: 0.8860 - regr_mse: 2.8801 - clf_accuracy: 0.5207 - val_loss: 5.4046 - val_regr_loss: 0.6549 - val_clf_loss: 0.7911 - val_regr_mse: 1.5050 - val_clf_accuracy: 0.5648
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.4248 - regr_loss: 1.0925 - clf_loss: 0.7923 - regr_mse: 1.9850 - clf_accuracy: 0.5141
# Epoch 00002: val_loss improved from 5.40459 to 4.65094, saving model to models\lstm1_univar\multitask\02.hdf5
# 32/32 [==============================] - 21s 670ms/step - loss: 5.4119 - regr_loss: 1.0957 - clf_loss: 0.7889 - regr_mse: 1.9812 - clf_accuracy: 0.5177 - val_loss: 4.6509 - val_regr_loss: 0.7749 - val_clf_loss: 0.7689 - val_regr_mse: 1.7436 - val_clf_accuracy: 0.5648
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.5980 - regr_loss: 1.0327 - clf_loss: 0.7732 - regr_mse: 1.8548 - clf_accuracy: 0.5282
# Epoch 00003: val_loss improved from 4.65094 to 3.82170, saving model to models\lstm1_univar\multitask\03.hdf5
# 32/32 [==============================] - 21s 670ms/step - loss: 4.5840 - regr_loss: 1.0311 - clf_loss: 0.7701 - regr_mse: 1.8529 - clf_accuracy: 0.5285 - val_loss: 3.8217 - val_regr_loss: 0.6453 - val_clf_loss: 0.7022 - val_regr_mse: 1.5021 - val_clf_accuracy: 0.5674
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.9977 - regr_loss: 0.9961 - clf_loss: 0.7542 - regr_mse: 1.7088 - clf_accuracy: 0.5514
# Epoch 00004: val_loss improved from 3.82170 to 3.48227, saving model to models\lstm1_univar\multitask\04.hdf5
# 32/32 [==============================] - 21s 659ms/step - loss: 3.9851 - regr_loss: 0.9927 - clf_loss: 0.7516 - regr_mse: 1.6987 - clf_accuracy: 0.5531 - val_loss: 3.4823 - val_regr_loss: 0.6986 - val_clf_loss: 0.7629 - val_regr_mse: 1.6306 - val_clf_accuracy: 0.4352
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.5729 - regr_loss: 0.9307 - clf_loss: 0.7099 - regr_mse: 1.5464 - clf_accuracy: 0.5655
# Epoch 00005: val_loss improved from 3.48227 to 3.24072, saving model to models\lstm1_univar\multitask\05.hdf5
# 32/32 [==============================] - 21s 649ms/step - loss: 3.5825 - regr_loss: 0.9359 - clf_loss: 0.7171 - regr_mse: 1.5634 - clf_accuracy: 0.5610 - val_loss: 3.2407 - val_regr_loss: 0.6511 - val_clf_loss: 0.7489 - val_regr_mse: 1.5300 - val_clf_accuracy: 0.4508
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.4167 - regr_loss: 0.9360 - clf_loss: 0.7152 - regr_mse: 1.5425 - clf_accuracy: 0.5645
# Epoch 00006: val_loss improved from 3.24072 to 3.08464, saving model to models\lstm1_univar\multitask\06.hdf5
# 32/32 [==============================] - 21s 650ms/step - loss: 3.4158 - regr_loss: 0.9339 - clf_loss: 0.7187 - regr_mse: 1.5319 - clf_accuracy: 0.5640 - val_loss: 3.0846 - val_regr_loss: 0.6466 - val_clf_loss: 0.7526 - val_regr_mse: 1.5341 - val_clf_accuracy: 0.4456
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.2635 - regr_loss: 0.9160 - clf_loss: 0.7260 - regr_mse: 1.4421 - clf_accuracy: 0.5746
# Epoch 00007: val_loss improved from 3.08464 to 2.93703, saving model to models\lstm1_univar\multitask\07.hdf5
# 32/32 [==============================] - 21s 660ms/step - loss: 3.2530 - regr_loss: 0.9109 - clf_loss: 0.7225 - regr_mse: 1.4292 - clf_accuracy: 0.5768 - val_loss: 2.9370 - val_regr_loss: 0.6628 - val_clf_loss: 0.7211 - val_regr_mse: 1.5771 - val_clf_accuracy: 0.4482
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.0800 - regr_loss: 0.8799 - clf_loss: 0.7032 - regr_mse: 1.4273 - clf_accuracy: 0.5595
# Epoch 00008: val_loss improved from 2.93703 to 2.85554, saving model to models\lstm1_univar\multitask\08.hdf5
# 32/32 [==============================] - 21s 648ms/step - loss: 3.0723 - regr_loss: 0.8749 - clf_loss: 0.7023 - regr_mse: 1.4130 - clf_accuracy: 0.5620 - val_loss: 2.8555 - val_regr_loss: 0.6564 - val_clf_loss: 0.7630 - val_regr_mse: 1.5403 - val_clf_accuracy: 0.4560
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.9878 - regr_loss: 0.8972 - clf_loss: 0.7030 - regr_mse: 1.4023 - clf_accuracy: 0.5746
# Epoch 00009: val_loss improved from 2.85554 to 2.76134, saving model to models\lstm1_univar\multitask\09.hdf5
# 32/32 [==============================] - 21s 653ms/step - loss: 2.9786 - regr_loss: 0.8898 - clf_loss: 0.7028 - regr_mse: 1.3859 - clf_accuracy: 0.5728 - val_loss: 2.7613 - val_regr_loss: 0.6548 - val_clf_loss: 0.7713 - val_regr_mse: 1.5552 - val_clf_accuracy: 0.4508
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.8416 - regr_loss: 0.8532 - clf_loss: 0.6772 - regr_mse: 1.2525 - clf_accuracy: 0.5917
# Epoch 00010: val_loss did not improve from 2.76134
# 32/32 [==============================] - 25s 785ms/step - loss: 2.8499 - regr_loss: 0.8614 - clf_loss: 0.6781 - regr_mse: 1.2693 - clf_accuracy: 0.5925 - val_loss: 2.8099 - val_regr_loss: 0.7005 - val_clf_loss: 0.8227 - val_regr_mse: 1.6471 - val_clf_accuracy: 0.4430
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.8006 - regr_loss: 0.8465 - clf_loss: 0.6882 - regr_mse: 1.2720 - clf_accuracy: 0.5948
# Epoch 00011: val_loss improved from 2.76134 to 2.71048, saving model to models\lstm1_univar\multitask\11.hdf5
# 32/32 [==============================] - 21s 663ms/step - loss: 2.8058 - regr_loss: 0.8507 - clf_loss: 0.6898 - regr_mse: 1.2797 - clf_accuracy: 0.5915 - val_loss: 2.7105 - val_regr_loss: 0.6542 - val_clf_loss: 0.8130 - val_regr_mse: 1.5591 - val_clf_accuracy: 0.4456
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.7537 - regr_loss: 0.8549 - clf_loss: 0.6751 - regr_mse: 1.2900 - clf_accuracy: 0.6048
# Epoch 00012: val_loss improved from 2.71048 to 2.59729, saving model to models\lstm1_univar\multitask\12.hdf5
# 32/32 [==============================] - 22s 694ms/step - loss: 2.7524 - regr_loss: 0.8590 - clf_loss: 0.6704 - regr_mse: 1.2897 - clf_accuracy: 0.6063 - val_loss: 2.5973 - val_regr_loss: 0.6526 - val_clf_loss: 0.7430 - val_regr_mse: 1.5525 - val_clf_accuracy: 0.4715
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.6842 - regr_loss: 0.8184 - clf_loss: 0.6829 - regr_mse: 1.2176 - clf_accuracy: 0.5907
# Epoch 00013: val_loss improved from 2.59729 to 2.56755, saving model to models\lstm1_univar\multitask\13.hdf5
# 32/32 [==============================] - 21s 671ms/step - loss: 2.6812 - regr_loss: 0.8152 - clf_loss: 0.6837 - regr_mse: 1.2066 - clf_accuracy: 0.5896 - val_loss: 2.5675 - val_regr_loss: 0.6608 - val_clf_loss: 0.7445 - val_regr_mse: 1.6008 - val_clf_accuracy: 0.5311
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.6473 - regr_loss: 0.8356 - clf_loss: 0.6668 - regr_mse: 1.2196 - clf_accuracy: 0.6058
# Epoch 00014: val_loss improved from 2.56755 to 2.54511, saving model to models\lstm1_univar\multitask\14.hdf5
# 32/32 [==============================] - 23s 724ms/step - loss: 2.6407 - regr_loss: 0.8329 - clf_loss: 0.6635 - regr_mse: 1.2114 - clf_accuracy: 0.6093 - val_loss: 2.5451 - val_regr_loss: 0.6837 - val_clf_loss: 0.7361 - val_regr_mse: 1.6623 - val_clf_accuracy: 0.5311
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.5459 - regr_loss: 0.8031 - clf_loss: 0.6273 - regr_mse: 1.1558 - clf_accuracy: 0.6200
# Epoch 00015: val_loss did not improve from 2.54511
# 32/32 [==============================] - 22s 700ms/step - loss: 2.5390 - regr_loss: 0.7942 - clf_loss: 0.6295 - regr_mse: 1.1393 - clf_accuracy: 0.6191 - val_loss: 2.5587 - val_regr_loss: 0.6878 - val_clf_loss: 0.7652 - val_regr_mse: 1.6756 - val_clf_accuracy: 0.4689
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.5858 - regr_loss: 0.8220 - clf_loss: 0.6666 - regr_mse: 1.1861 - clf_accuracy: 0.6109
# Epoch 00016: val_loss improved from 2.54511 to 2.51598, saving model to models\lstm1_univar\multitask\16.hdf5
# 32/32 [==============================] - 21s 669ms/step - loss: 2.5849 - regr_loss: 0.8233 - clf_loss: 0.6647 - regr_mse: 1.1902 - clf_accuracy: 0.6102 - val_loss: 2.5160 - val_regr_loss: 0.6773 - val_clf_loss: 0.7510 - val_regr_mse: 1.6472 - val_clf_accuracy: 0.5130
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.4815 - regr_loss: 0.7714 - clf_loss: 0.6307 - regr_mse: 1.0655 - clf_accuracy: 0.6321
# Epoch 00017: val_loss did not improve from 2.51598
# 32/32 [==============================] - 21s 648ms/step - loss: 2.4877 - regr_loss: 0.7751 - clf_loss: 0.6334 - regr_mse: 1.0695 - clf_accuracy: 0.6289 - val_loss: 2.5297 - val_regr_loss: 0.7054 - val_clf_loss: 0.7539 - val_regr_mse: 1.7116 - val_clf_accuracy: 0.5233
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.4967 - regr_loss: 0.7823 - clf_loss: 0.6522 - regr_mse: 1.1011 - clf_accuracy: 0.6119
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 2.5000001187436283e-05.
#
# Epoch 00018: val_loss did not improve from 2.51598
# 32/32 [==============================] - 22s 687ms/step - loss: 2.4943 - regr_loss: 0.7837 - clf_loss: 0.6487 - regr_mse: 1.1021 - clf_accuracy: 0.6152 - val_loss: 2.5507 - val_regr_loss: 0.7333 - val_clf_loss: 0.7644 - val_regr_mse: 1.7625 - val_clf_accuracy: 0.5181
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.4829 - regr_loss: 0.7866 - clf_loss: 0.6458 - regr_mse: 1.1285 - clf_accuracy: 0.6109
# Epoch 00019: val_loss did not improve from 2.51598
# 32/32 [==============================] - 20s 639ms/step - loss: 2.4916 - regr_loss: 0.7879 - clf_loss: 0.6533 - regr_mse: 1.1303 - clf_accuracy: 0.6073 - val_loss: 2.5301 - val_regr_loss: 0.7085 - val_clf_loss: 0.7731 - val_regr_mse: 1.7161 - val_clf_accuracy: 0.4974
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.4848 - regr_loss: 0.7972 - clf_loss: 0.6400 - regr_mse: 1.1427 - clf_accuracy: 0.6250
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00020: val_loss did not improve from 2.51598
# 32/32 [==============================] - 21s 653ms/step - loss: 2.4874 - regr_loss: 0.8032 - clf_loss: 0.6366 - regr_mse: 1.1728 - clf_accuracy: 0.6270 - val_loss: 2.5295 - val_regr_loss: 0.6985 - val_clf_loss: 0.7843 - val_regr_mse: 1.6923 - val_clf_accuracy: 0.4819
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 9.999999747378752e-06.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.5118 - regr_loss: 0.8286 - clf_loss: 0.6372 - regr_mse: 1.2055 - clf_accuracy: 0.6361
# Epoch 00021: val_loss did not improve from 2.51598
# 32/32 [==============================] - 20s 634ms/step - loss: 2.5182 - regr_loss: 0.8312 - clf_loss: 0.6411 - regr_mse: 1.2073 - clf_accuracy: 0.6280 - val_loss: 2.5282 - val_regr_loss: 0.6930 - val_clf_loss: 0.7900 - val_regr_mse: 1.6814 - val_clf_accuracy: 0.4793
# Epoch 00021: early stopping

# %%
def plot_multitask_history(hist):
    fig, ax = plt.subplots(2, 2, figsize=(16, 12))
    plotHelpers.plot_train_history(ax[0, 0], hist, 'Total loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[0, 1], hist, 'Accuracy', 'clf_accuracy', 'val_clf_accuracy')
    plotHelpers.plot_train_history(ax[1, 0], hist, 'MAE', 'regr_loss', 'val_regr_loss')
    plotHelpers.plot_train_history(ax[1, 1], hist, 'MSE', 'regr_mse', 'val_regr_mse')
    
plot_multitask_history(multitask_history);

# %% [markdown]
# ### Прогноз

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_multitask_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret, pred_direction_proba = univariate_multitask_lstm.predict_generator(test_multi_gen, verbose=1)
# Out:
# 13/13 [==============================] - 3s 264ms/step

# %%
np.set_printoptions(precision=3, suppress=True)

np.column_stack([pred_log_ret, pred_direction_proba])[-10:]
# Out:
# array([[0.136, 0.55 ],
#        [0.45 , 0.651],
#        [0.429, 0.652],
#        [0.141, 0.582],
#        [0.181, 0.721],
#        [0.086, 0.593],
#        [0.174, 0.699],
#        [0.277, 0.591],
#        [0.079, 0.656],
#        [0.217, 0.652]], dtype=float32)

# %% [markdown]
# #### Прогноз задачи регрессии

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret, figsize=(16, 20),
                                  datetime_unit='m', plot_data_slice=slice(1, None))

# %% [markdown]
# #### Прогноз задачи классификации

# %%
true_direction = test_multi_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 0.50736785

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([168, 218], dtype=int64)),
#  (array([0, 1]), array([169, 217], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.44      0.45      0.45       168
#            1       0.57      0.57      0.57       218
#
#     accuracy                           0.52       386
#    macro avg       0.51      0.51      0.51       386
# weighted avg       0.52      0.52      0.52       386

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[ 75,  93],
#        [ 94, 124]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.444, 0.429],
#        [0.556, 0.571]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# # Выводы
#
# 1.  Размер батча влияет на скорость обучения.
# 2.  Инициализация весов (`bias_initializer`) в слое **LSTM** оказалась очень важным параметром.
# 3.  Модель регрессии близка к модели случайного блуждания.
# 4.  Задача классификации не решается удовлетворительно.
# 5.  Комбинированная (многозадачная) модель не смогла что-то улучшить.

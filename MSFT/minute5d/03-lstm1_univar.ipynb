# %% [markdown]
# # *Одномерная модель на LSTM* (1 слой)
#
# В качестве единственного признака используется сама цена.

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import os
import glob
import datetime
import pickle

import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
from pandas_datareader import data as pdr

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
import tensorflow as tf
# tf.test.is_gpu_available()
tf.__version__
# Out:
# '2.0.0'

# %%
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Input, Dense, LSTM, GRU, Flatten, ReLU, LeakyReLU, Dropout, BatchNormalization
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers import Nadam

# %%
from mdp import TimeSeries
from mdp import MarketData
from mdp import MovingWindowFeatures
from mdp import ClassificationGenerator, RegressionGenerator, MultitaskGenerator
from mdp import invert_log_ret

import mdp.utils as utils
import mdp.plotHelpers as plotHelpers

# %%
import importlib

import mdp

importlib.reload(mdp)
importlib.reload(mdp.datasetGenerator)
importlib.reload(mdp.marketData)
importlib.reload(mdp.movingWindowFeatures)
importlib.reload(mdp.timeSeries)
importlib.reload(mdp.plotHelpers)
importlib.reload(mdp.utils);

# %% [markdown]
# # *Параметры*

# %%
INSTRUMENT = 'MSFT' # Microsoft corp
START_FROM = np.datetime64('today') - 7
WINDOW_SIZE = 120
FORECAST_OFFSET=1
BATCH_SIZE = 32
FORCE_TRAIN = True

# %% [markdown]
# # *Исходные данные*
#
# Загрузка данных и вычисление индикаторов.

# %%
instr = MarketData.create_from_alphavantage_intraday(INSTRUMENT, start=START_FROM)

# %%
instr.feature_names
# Out:
# ['o',
#  'h',
#  'l',
#  'c',
#  'v',
#  'ema14',
#  'ema30',
#  'macd',
#  'macd_signal',
#  'rsi14',
#  'bband20_upper',
#  'bband20_middle',
#  'bband20_lower',
#  'willr14',
#  'stochk',
#  'stochd',
#  'adline',
#  'adosc']

# %% [markdown]
# Здесь не будем делить отдельно на тест и валидацию, поскольку данных у нас только 5 дней.

# %%
dates_unique = np.unique(instr.timestamps.astype('datetime64[D]'))

START_FROM = dates_unique[0]
VAL_TEST_SPLIT = dates_unique[-1]

START_FROM, VAL_TEST_SPLIT
# Out:
# (numpy.datetime64('2020-04-09'), numpy.datetime64('2020-04-15'))

# %% [markdown]
# ## Целевая переменная

# %% [markdown]
# Цена закрытия.

# %%
orig_target = instr.c

# %% [markdown]
# Переходим к логарифмической доходности.

# %%
transformed_target = instr.c.transform(transforms={'ratios' : {}, 'ln' : {}})

# %%
plotHelpers.plot_transformed_timeseries_unit(instr,
                                             transformed_target,
                                             'Close price, USD', 'Log return',
                                             datetime_unit='m', rotation=45)

# %% [markdown]
# ## Трансформация признаков
#
# Выбираем только один признак: цену закрытия.
# Временной ряд цены преобразуется к логарифмической доходности (что также позволяет убрать нестационарность).

# %%
def make_feature_selector():
    price_transformer = lambda: {'ratios': {}, 'ln': {}}
    diff_transformer = lambda o: {'diffs': {'order': o}}
    identity_transformer = lambda: {}
    feature_transformations = {
        'c': price_transformer(),
    }
    return feature_transformations

# %%
instr_transformed = instr.select_transform(make_feature_selector())

# %%
transformed_target = instr_transformed.c

# %% [markdown]
# ## Обучающая, валидационная и тестовая выборки

# %%
instr_train, instr_test = instr_transformed.train_test_split(VAL_TEST_SPLIT, window_size=WINDOW_SIZE,
                                                             scaler=StandardScaler)
#                                                              scaler=MinMaxScaler,
#                                                              scaler_kwargs={'feature_range': (-1, 1)})

# instr_val, instr_test = instr_val_test.train_test_split(TEST_SPLIT, window_size=WINDOW_SIZE, scaler=None)

len(instr_train), len(instr_test)
# Out:
# (1132, 509)

# %% [markdown]
# ## Признаки - скользящие окна

# %%
train_mwf = MovingWindowFeatures.create(instr_train.c, [instr_train], instr_train.feature_names, window_size=WINDOW_SIZE)
# val_mwf = MovingWindowFeatures.create(instr_val.c, [instr_val], instr_val.feature_names, window_size=WINDOW_SIZE)
test_mwf = MovingWindowFeatures.create(instr_test.c, [instr_test], instr_test.feature_names, window_size=WINDOW_SIZE)

len(instr_train), len(train_mwf), train_mwf.features.shape
# Out:
# (1132, 1012, (1012, 120, 1))

# %% [markdown]
# Проверка, что скользящие окна соответствуют исходным данным.
#
# Возьмём произвольный признак и произвольное окно (строка #**41**). Проверим, что данные в точности совпадают:

# %%
def check_data(md, mwf, row):
    col = np.random.randint(len(mwf.feature_names))
    feature = mwf.feature_names[col]
    check = (getattr(md, feature).data[row:row + mwf.window_size] == mwf.features[row, :, col]).all()
    assert check
    return feature, check

check_data(instr_train, train_mwf, 41)
# Out:
# ('c', True)

# %% [markdown]
# # *Модели*

# %% [markdown]
# Модель с одним LSTM слоем.

# %%
def build_lstm_layers(input_shape, latent_dim=32):
    # формат входа: матрица (окно; признак)
    inp = Input(input_shape, name='input')

    lstm = LSTM(latent_dim, return_sequences=True,
                    recurrent_dropout=0.2, dropout=0.2,
                    bias_initializer='he_uniform',
                    bias_regularizer=L1L2(0.01, 0.02),
                    kernel_regularizer=L1L2(0.01, 0.02),
                    recurrent_regularizer=L1L2(0.01, 0.02)
               )(inp)
    
    lstm = Flatten()(lstm)
    
    return inp, lstm

# %% [markdown]
# #### Пути сохранения моделей:

# %%
model_path_root = 'models'
model_type_name = 'lstm1_univar'

def make_model_save_dir(path_root, type_name, class_name):
    save_dir = os.path.join(path_root, type_name, class_name)
    os.makedirs(save_dir, exist_ok=True)
    return save_dir

# %% [markdown]
# #### Общие коллбэки:

# %%
# уменьшение learning rate в случае, если loss не изменяется
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001, verbose=1)

# уменьшение learning rate в 2 раза каждую 5-ю эпоху
def lr_decay(e, lr):
    return lr * (1 - 0.5 * (0 == (e + 1) % 5))

lr_scheduler = LearningRateScheduler(schedule=lr_decay, verbose=1)

# %% [markdown]
# ## Задача регрессии
#
# Непосредственное прогнозирование цены следующего периода.

# %%
train_regr_gen = RegressionGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_regr_gen = RegressionGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_regr_gen = RegressionGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# Следующие числа соответствуют значению параметра `steps_per_epoch` метода [`fit_generator`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit_generator "tf.keras.layers.SimpleRNN &nbsp;|&nbsp; TensorFlow Core r2.0") - то есть это число батчей, которые генератор выдаст за одну эпоху обучения (если класс генератора поддерживает метод `len()`, то данный параметр можно не указывать).

# %%
len(train_regr_gen), len(test_regr_gen)
# Out:
# (32, 13)

# %% [markdown]
# Один сэмпл данных представляет собой матрицу размером *(длина окна; число признаков)*

# %%
train_regr_gen.input_shape
# Out:
# (120, 1)

# %% [markdown]
# ### Модель для задачи регрессии

# %%
model_class_name = 'regression'

# %%
def build_regression_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=32)

    regr = Dense(64)(lstm)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    return Model(inputs=[inp], outputs=[regr])

# %%
univariate_regression_lstm = build_regression_model(train_regr_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:
# [`Nadam`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Nadam) (*Adam with Nestrov momentum*).

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Функция потерь:
#
# Попробуем использовать MAE.

# %%
univariate_regression_lstm.compile(optimizer=optimizer,
                                   loss={'regr': 'mae'},
                                   metrics={'regr': 'mse'})

univariate_regression_lstm.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 120, 1)]          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 120, 32)           4352
# _________________________________________________________________
# flatten (Flatten)            (None, 3840)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                245824
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64)                256
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 64)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# regr (Dense)                 (None, 1)                 65
# =================================================================
# Total params: 250,497
# Trainable params: 250,369
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# #### Обучение:

# %%
regr_history = utils.train_model(univariate_regression_lstm,
                                 model_save_dir, train_regr_gen, test_regr_gen,
                                 callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                 force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.6843 - mse: 3.0494
# Epoch 00001: val_loss improved from inf to 4.69267, saving model to models\lstm1_univar\regression\01.hdf5
# 32/32 [==============================] - 18s 577ms/step - loss: 5.6629 - mse: 3.0235 - val_loss: 4.6927 - val_mse: 1.4380
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.4954 - mse: 2.2706
# Epoch 00002: val_loss improved from 4.69267 to 3.63355, saving model to models\lstm1_univar\regression\02.hdf5
# 32/32 [==============================] - 17s 536ms/step - loss: 4.4855 - mse: 2.2655 - val_loss: 3.6335 - val_mse: 1.1428
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.6623 - mse: 2.0489
# Epoch 00003: val_loss improved from 3.63355 to 3.00004, saving model to models\lstm1_univar\regression\03.hdf5
# 32/32 [==============================] - 18s 557ms/step - loss: 3.6445 - mse: 2.0310 - val_loss: 3.0000 - val_mse: 1.1390
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.0483 - mse: 1.7616
# Epoch 00004: val_loss improved from 3.00004 to 2.57110, saving model to models\lstm1_univar\regression\04.hdf5
# 32/32 [==============================] - 18s 561ms/step - loss: 3.0378 - mse: 1.7497 - val_loss: 2.5711 - val_mse: 1.1768
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.6933 - mse: 1.6082
# Epoch 00005: val_loss improved from 2.57110 to 2.37467, saving model to models\lstm1_univar\regression\05.hdf5
# 32/32 [==============================] - 17s 535ms/step - loss: 2.6845 - mse: 1.5937 - val_loss: 2.3747 - val_mse: 1.1286
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.5313 - mse: 1.6462
# Epoch 00006: val_loss improved from 2.37467 to 2.25544, saving model to models\lstm1_univar\regression\06.hdf5
# 32/32 [==============================] - 18s 575ms/step - loss: 2.5298 - mse: 1.6376 - val_loss: 2.2554 - val_mse: 1.2212
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.3572 - mse: 1.5592
# Epoch 00007: val_loss improved from 2.25544 to 2.09727, saving model to models\lstm1_univar\regression\07.hdf5
# 32/32 [==============================] - 18s 549ms/step - loss: 2.3465 - mse: 1.5385 - val_loss: 2.0973 - val_mse: 1.1420
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1976 - mse: 1.4112
# Epoch 00008: val_loss improved from 2.09727 to 2.02181, saving model to models\lstm1_univar\regression\08.hdf5
# 32/32 [==============================] - 18s 550ms/step - loss: 2.1901 - mse: 1.3999 - val_loss: 2.0218 - val_mse: 1.2284
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0438 - mse: 1.3380
# Epoch 00009: val_loss did not improve from 2.02181
# 32/32 [==============================] - 17s 529ms/step - loss: 2.0408 - mse: 1.3256 - val_loss: 2.2254 - val_mse: 1.9370
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9882 - mse: 1.3514
# Epoch 00010: val_loss improved from 2.02181 to 1.92117, saving model to models\lstm1_univar\regression\10.hdf5
# 32/32 [==============================] - 17s 536ms/step - loss: 1.9870 - mse: 1.3496 - val_loss: 1.9212 - val_mse: 1.3142
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9636 - mse: 1.4261
# Epoch 00011: val_loss improved from 1.92117 to 1.88551, saving model to models\lstm1_univar\regression\11.hdf5
# 32/32 [==============================] - 17s 534ms/step - loss: 1.9604 - mse: 1.4186 - val_loss: 1.8855 - val_mse: 1.3281
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.8814 - mse: 1.2920
# Epoch 00012: val_loss improved from 1.88551 to 1.83871, saving model to models\lstm1_univar\regression\12.hdf5
# 32/32 [==============================] - 17s 532ms/step - loss: 1.8834 - mse: 1.2888 - val_loss: 1.8387 - val_mse: 1.3079
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.8519 - mse: 1.3544
# Epoch 00013: val_loss improved from 1.83871 to 1.73476, saving model to models\lstm1_univar\regression\13.hdf5
# 32/32 [==============================] - 17s 542ms/step - loss: 1.8569 - mse: 1.3538 - val_loss: 1.7348 - val_mse: 1.1567
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7893 - mse: 0.9907
# Epoch 00014: val_loss improved from 1.73476 to 1.70056, saving model to models\lstm1_univar\regression\14.hdf5
# 32/32 [==============================] - 18s 550ms/step - loss: 1.8243 - mse: 1.3054 - val_loss: 1.7006 - val_mse: 1.1538
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7695 - mse: 1.2916
# Epoch 00015: val_loss improved from 1.70056 to 1.68957, saving model to models\lstm1_univar\regression\15.hdf5
# 32/32 [==============================] - 17s 545ms/step - loss: 1.7748 - mse: 1.2895 - val_loss: 1.6896 - val_mse: 1.1690
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7764 - mse: 1.3584
# Epoch 00016: val_loss did not improve from 1.68957
# 32/32 [==============================] - 17s 533ms/step - loss: 1.7790 - mse: 1.3538 - val_loss: 1.7000 - val_mse: 1.2335
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7484 - mse: 1.2854
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 2.5000001187436283e-05.
#
# Epoch 00017: val_loss did not improve from 1.68957
# 32/32 [==============================] - 17s 536ms/step - loss: 1.7538 - mse: 1.2888 - val_loss: 1.7034 - val_mse: 1.2842
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7368 - mse: 1.3094
# Epoch 00018: val_loss improved from 1.68957 to 1.68022, saving model to models\lstm1_univar\regression\18.hdf5
# 32/32 [==============================] - 17s 536ms/step - loss: 1.7324 - mse: 1.2934 - val_loss: 1.6802 - val_mse: 1.2384
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7412 - mse: 1.2522
# Epoch 00019: val_loss improved from 1.68022 to 1.65921, saving model to models\lstm1_univar\regression\19.hdf5
# 32/32 [==============================] - 17s 540ms/step - loss: 1.7364 - mse: 1.2388 - val_loss: 1.6592 - val_mse: 1.1925
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7079 - mse: 1.2599
# Epoch 00020: val_loss improved from 1.65921 to 1.65473, saving model to models\lstm1_univar\regression\20.hdf5
# 32/32 [==============================] - 17s 533ms/step - loss: 1.7028 - mse: 1.2441 - val_loss: 1.6547 - val_mse: 1.1854
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7114 - mse: 1.2817
# Epoch 00021: val_loss improved from 1.65473 to 1.65225, saving model to models\lstm1_univar\regression\21.hdf5
# 32/32 [==============================] - 17s 533ms/step - loss: 1.7159 - mse: 1.2765 - val_loss: 1.6523 - val_mse: 1.1839
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 22/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7221 - mse: 1.3355
# Epoch 00022: val_loss improved from 1.65225 to 1.64952, saving model to models\lstm1_univar\regression\22.hdf5
# 32/32 [==============================] - 17s 533ms/step - loss: 1.7177 - mse: 1.3237 - val_loss: 1.6495 - val_mse: 1.1798
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 23/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7018 - mse: 1.2760
# Epoch 00023: val_loss improved from 1.64952 to 1.64729, saving model to models\lstm1_univar\regression\23.hdf5
# 32/32 [==============================] - 18s 554ms/step - loss: 1.7013 - mse: 1.2702 - val_loss: 1.6473 - val_mse: 1.1771
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 24/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7153 - mse: 1.1994
# Epoch 00024: val_loss improved from 1.64729 to 1.64652, saving model to models\lstm1_univar\regression\24.hdf5
# 32/32 [==============================] - 18s 550ms/step - loss: 1.7141 - mse: 1.1907 - val_loss: 1.6465 - val_mse: 1.1805
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 25/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7096 - mse: 1.2297
# Epoch 00025: val_loss improved from 1.64652 to 1.64528, saving model to models\lstm1_univar\regression\25.hdf5
# 32/32 [==============================] - 18s 572ms/step - loss: 1.7143 - mse: 1.2492 - val_loss: 1.6453 - val_mse: 1.1800
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 26/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7289 - mse: 1.3460
# Epoch 00026: val_loss improved from 1.64528 to 1.64393, saving model to models\lstm1_univar\regression\26.hdf5
# 32/32 [==============================] - 22s 694ms/step - loss: 1.7301 - mse: 1.3392 - val_loss: 1.6439 - val_mse: 1.1776
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 27/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7294 - mse: 1.2828
# Epoch 00027: val_loss did not improve from 1.64393
# 32/32 [==============================] - 20s 630ms/step - loss: 1.7269 - mse: 1.2704 - val_loss: 1.6440 - val_mse: 1.1788
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 28/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7148 - mse: 1.2854
# Epoch 00028: val_loss improved from 1.64393 to 1.64324, saving model to models\lstm1_univar\regression\28.hdf5
# 32/32 [==============================] - 19s 578ms/step - loss: 1.7210 - mse: 1.3019 - val_loss: 1.6432 - val_mse: 1.1794
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 29/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.6809 - mse: 1.1843
# Epoch 00029: val_loss improved from 1.64324 to 1.64239, saving model to models\lstm1_univar\regression\29.hdf5
# 32/32 [==============================] - 18s 552ms/step - loss: 1.6907 - mse: 1.1986 - val_loss: 1.6424 - val_mse: 1.1792
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 3.1250001484295353e-06.
# Epoch 30/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.6789 - mse: 1.1703
# Epoch 00030: val_loss improved from 1.64239 to 1.64193, saving model to models\lstm1_univar\regression\30.hdf5
# 32/32 [==============================] - 18s 562ms/step - loss: 1.6780 - mse: 1.1615 - val_loss: 1.6419 - val_mse: 1.1805
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 3.1250001484295353e-06.
# Epoch 31/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7135 - mse: 1.2593
# Epoch 00031: val_loss improved from 1.64193 to 1.64148, saving model to models\lstm1_univar\regression\31.hdf5
# 32/32 [==============================] - 19s 598ms/step - loss: 1.7174 - mse: 1.2620 - val_loss: 1.6415 - val_mse: 1.1812
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 3.1250001484295353e-06.
# Epoch 32/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7157 - mse: 1.2590
# Epoch 00032: val_loss improved from 1.64148 to 1.64125, saving model to models\lstm1_univar\regression\32.hdf5
# 32/32 [==============================] - 18s 575ms/step - loss: 1.7191 - mse: 1.2552 - val_loss: 1.6412 - val_mse: 1.1813

# %%
def plot_regr_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'MAE', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'MSE', 'mse', 'val_mse')
    
plot_regr_history(regr_history);

# %% [markdown]
# ### Прогноз задачи регрессии

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_regression_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret_test = univariate_regression_lstm.predict_generator(test_regr_gen, verbose=1)
# Out:
# 13/13 [==============================] - 3s 263ms/step

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret_test, figsize=(16, 20),
                                  datetime_unit='m', plot_data_slice=slice(1, None))

# %% [markdown]
# ## Задача классификации
#
# Прогнозируем направление изменения цены по сравнению с предыдущим периодом (**0** - снижение, **1** - рост).

# %%
model_class_name = 'classification'

# %%
train_clf_gen = ClassificationGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_clf_gen = ClassificationGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_clf_gen = ClassificationGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_classification_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape)

    clf = Dense(64)(lstm)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)

    return Model(inputs=[inp], outputs=[clf])

# %%
univariate_classification_lstm = build_classification_model(test_clf_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
univariate_classification_lstm.compile(optimizer=optimizer,
                                         loss={'clf': 'binary_crossentropy'},
                                         metrics={'clf': 'accuracy'})

univariate_classification_lstm.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 120, 1)]          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 120, 32)           4352
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3840)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                245824
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# clf (Dense)                  (None, 1)                 65
# =================================================================
# Total params: 250,497
# Trainable params: 250,369
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
clf_history = utils.train_model(univariate_classification_lstm,
                                model_save_dir, train_clf_gen, test_clf_gen,
                                callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.4159 - accuracy: 0.4849
# Epoch 00001: val_loss improved from inf to 4.59936, saving model to models\lstm1_univar\classification\01.hdf5
# 32/32 [==============================] - 18s 570ms/step - loss: 5.3905 - accuracy: 0.4872 - val_loss: 4.5994 - val_accuracy: 0.5219
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.2828 - accuracy: 0.5433
# Epoch 00002: val_loss improved from 4.59936 to 3.77936, saving model to models\lstm1_univar\classification\02.hdf5
# 32/32 [==============================] - 18s 562ms/step - loss: 4.2668 - accuracy: 0.5455 - val_loss: 3.7794 - val_accuracy: 0.4781
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.4294 - accuracy: 0.5554
# Epoch 00003: val_loss improved from 3.77936 to 3.24627, saving model to models\lstm1_univar\classification\03.hdf5
# 32/32 [==============================] - 17s 538ms/step - loss: 3.4203 - accuracy: 0.5534 - val_loss: 3.2463 - val_accuracy: 0.4781
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.8694 - accuracy: 0.5302
# Epoch 00004: val_loss improved from 3.24627 to 2.54075, saving model to models\lstm1_univar\classification\04.hdf5
# 32/32 [==============================] - 18s 553ms/step - loss: 2.8645 - accuracy: 0.5277 - val_loss: 2.5408 - val_accuracy: 0.4961
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.5163 - accuracy: 0.5504
# Epoch 00005: val_loss improved from 2.54075 to 2.34304, saving model to models\lstm1_univar\classification\05.hdf5
# 32/32 [==============================] - 19s 598ms/step - loss: 2.5155 - accuracy: 0.5474 - val_loss: 2.3430 - val_accuracy: 0.5064
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2948 - accuracy: 0.5827
# Epoch 00006: val_loss improved from 2.34304 to 2.19808, saving model to models\lstm1_univar\classification\06.hdf5
# 32/32 [==============================] - 19s 583ms/step - loss: 2.2947 - accuracy: 0.5850 - val_loss: 2.1981 - val_accuracy: 0.5321
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1830 - accuracy: 0.5383
# Epoch 00007: val_loss improved from 2.19808 to 2.08609, saving model to models\lstm1_univar\classification\07.hdf5
# 32/32 [==============================] - 18s 551ms/step - loss: 2.1811 - accuracy: 0.5375 - val_loss: 2.0861 - val_accuracy: 0.4730
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0239 - accuracy: 0.5726
# Epoch 00008: val_loss improved from 2.08609 to 1.94945, saving model to models\lstm1_univar\classification\08.hdf5
# 32/32 [==============================] - 18s 562ms/step - loss: 2.0269 - accuracy: 0.5721 - val_loss: 1.9495 - val_accuracy: 0.5244
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9141 - accuracy: 0.5756
# Epoch 00009: val_loss improved from 1.94945 to 1.86174, saving model to models\lstm1_univar\classification\09.hdf5
# 32/32 [==============================] - 18s 575ms/step - loss: 1.9117 - accuracy: 0.5751 - val_loss: 1.8617 - val_accuracy: 0.4833
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.8326 - accuracy: 0.5726
# Epoch 00010: val_loss did not improve from 1.86174
# 32/32 [==============================] - 17s 545ms/step - loss: 1.8269 - accuracy: 0.5751 - val_loss: 1.8962 - val_accuracy: 0.4679
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7837 - accuracy: 0.5817
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 5.0000002374872565e-05.
#
# Epoch 00011: val_loss did not improve from 1.86174
# 32/32 [==============================] - 18s 573ms/step - loss: 1.7775 - accuracy: 0.5850 - val_loss: 1.8901 - val_accuracy: 0.4704
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 5.0000002374872565e-05.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7533 - accuracy: 0.5867
# Epoch 00012: val_loss improved from 1.86174 to 1.82994, saving model to models\lstm1_univar\classification\12.hdf5
# 32/32 [==============================] - 18s 549ms/step - loss: 1.7543 - accuracy: 0.5870 - val_loss: 1.8299 - val_accuracy: 0.4602
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 5.0000002374872565e-05.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7106 - accuracy: 0.6048
# Epoch 00013: val_loss improved from 1.82994 to 1.80659, saving model to models\lstm1_univar\classification\13.hdf5
# 32/32 [==============================] - 18s 560ms/step - loss: 1.7145 - accuracy: 0.6028 - val_loss: 1.8066 - val_accuracy: 0.4627
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 5.0000002374872565e-05.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7323 - accuracy: 0.5917
# Epoch 00014: val_loss improved from 1.80659 to 1.78604, saving model to models\lstm1_univar\classification\14.hdf5
# 32/32 [==============================] - 18s 570ms/step - loss: 1.7317 - accuracy: 0.5919 - val_loss: 1.7860 - val_accuracy: 0.4884
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.6890 - accuracy: 0.6210
# Epoch 00015: val_loss improved from 1.78604 to 1.77293, saving model to models\lstm1_univar\classification\15.hdf5
# 32/32 [==============================] - 20s 619ms/step - loss: 1.6901 - accuracy: 0.6225 - val_loss: 1.7729 - val_accuracy: 0.4833
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.6921 - accuracy: 0.6200
# Epoch 00016: val_loss did not improve from 1.77293
# 32/32 [==============================] - 21s 662ms/step - loss: 1.6933 - accuracy: 0.6196 - val_loss: 1.7777 - val_accuracy: 0.4781
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7241 - accuracy: 0.5917
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00017: val_loss did not improve from 1.77293
# 32/32 [==============================] - 18s 565ms/step - loss: 1.7175 - accuracy: 0.5958 - val_loss: 1.7743 - val_accuracy: 0.4781
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 9.999999747378752e-06.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7077 - accuracy: 0.5948
# Epoch 00018: val_loss improved from 1.77293 to 1.77236, saving model to models\lstm1_univar\classification\18.hdf5
# 32/32 [==============================] - 19s 582ms/step - loss: 1.7079 - accuracy: 0.5939 - val_loss: 1.7724 - val_accuracy: 0.4833
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 9.999999747378752e-06.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7061 - accuracy: 0.5786
# Epoch 00019: val_loss improved from 1.77236 to 1.77155, saving model to models\lstm1_univar\classification\19.hdf5
# 32/32 [==============================] - 19s 583ms/step - loss: 1.7089 - accuracy: 0.5781 - val_loss: 1.7716 - val_accuracy: 0.5090
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 4.999999873689376e-06.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.6999 - accuracy: 0.5998
# Epoch 00020: val_loss did not improve from 1.77155
# 32/32 [==============================] - 18s 563ms/step - loss: 1.7001 - accuracy: 0.6008 - val_loss: 1.7735 - val_accuracy: 0.5064
# Epoch 00021: LearningRateScheduler reducing learning rate to 4.999999873689376e-06.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.6915 - accuracy: 0.6008
# Epoch 00021: val_loss did not improve from 1.77155
# 32/32 [==============================] - 18s 569ms/step - loss: 1.6914 - accuracy: 0.6018 - val_loss: 1.7758 - val_accuracy: 0.5013
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 4.999999873689376e-06.
# Epoch 22/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.6849 - accuracy: 0.6089
# Epoch 00022: val_loss did not improve from 1.77155
# 32/32 [==============================] - 18s 559ms/step - loss: 1.6858 - accuracy: 0.6087 - val_loss: 1.7770 - val_accuracy: 0.4961
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 4.999999873689376e-06.
# Epoch 23/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7033 - accuracy: 0.5887
# Epoch 00023: val_loss did not improve from 1.77155
# 32/32 [==============================] - 19s 584ms/step - loss: 1.7062 - accuracy: 0.5860 - val_loss: 1.7766 - val_accuracy: 0.4987
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 4.999999873689376e-06.
# Epoch 24/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.6927 - accuracy: 0.6210
# Epoch 00024: val_loss did not improve from 1.77155
# 32/32 [==============================] - 19s 580ms/step - loss: 1.6897 - accuracy: 0.6225 - val_loss: 1.7761 - val_accuracy: 0.5039
# Epoch 00024: early stopping

# %%
def plot_clf_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'Loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'Accuracy', 'accuracy', 'val_accuracy')
    
plot_clf_history(clf_history);

# %% [markdown]
# ### Прогноз задачи классификации

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_classification_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %%
pred_direction_proba = univariate_classification_lstm.predict_generator(test_clf_gen, verbose=1)

true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 13/13 [==============================] - 3s 264ms/step
# 0.52242416

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([203, 186], dtype=int64)),
#  (array([0, 1]), array([196, 193], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.51      0.52       203
#            1       0.48      0.50      0.49       186
#
#     accuracy                           0.50       389
#    macro avg       0.50      0.50      0.50       389
# weighted avg       0.50      0.50      0.50       389

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[103, 100],
#        [ 93,  93]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.5255102 , 0.51813472],
#        [0.4744898 , 0.48186528]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# ## Многозадачная модель: одновременно регрессия и классификация
#
# Пытаемся одновременно предсказать и значение цены, и направление изменения, предполагая, что комбинированная ошибка позволит точнее скорректировать веса рекуррентных слоёв.

# %%
model_class_name = 'multitask'

# %%
train_multi_gen = MultitaskGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_multi_gen = MultitaskGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_multi_gen = MultitaskGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_multitask_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=32)

    # первый выход: задача регрссии
    regr = Dense(64)(lstm)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    # второй выход: задача классификации
    clf = Dense(64)(lstm)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)
    
    return Model(inputs=[inp], outputs=[regr, clf])

# %%
univariate_multitask_lstm = build_multitask_model(train_multi_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
univariate_multitask_lstm.compile(optimizer=optimizer,
                                  loss={'regr': 'mae', 'clf': 'binary_crossentropy'},
                                  loss_weights={'regr': 1., 'clf': 1.},
                                  metrics={'regr': 'mse', 'clf' : 'accuracy'})

univariate_multitask_lstm.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 120, 1)]     0
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 120, 32)      4352        input[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 3840)         0           lstm_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           245824      flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           245824      flatten_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64)           256         dense_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64)           256         dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 64)           0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 64)           0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64)           0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64)           0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# regr (Dense)                    (None, 1)            65          dropout_2[0][0]
# __________________________________________________________________________________________________
# clf (Dense)                     (None, 1)            65          dropout_3[0][0]
# ==================================================================================================
# Total params: 496,642
# Trainable params: 496,386
# Non-trainable params: 256
# __________________________________________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
multitask_history = utils.train_model(univariate_multitask_lstm,
                                      model_save_dir, train_multi_gen, test_multi_gen,
                                      callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                      force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.5574 - regr_loss: 1.1834 - clf_loss: 0.9133 - regr_mse: 2.5452 - clf_accuracy: 0.4819
# Epoch 00001: val_loss improved from inf to 5.37064, saving model to models\lstm1_univar\multitask\01.hdf5
# 32/32 [==============================] - 19s 604ms/step - loss: 6.5366 - regr_loss: 1.1807 - clf_loss: 0.9111 - regr_mse: 2.5345 - clf_accuracy: 0.4822 - val_loss: 5.3706 - val_regr_loss: 0.7577 - val_clf_loss: 0.6991 - val_regr_mse: 1.3720 - val_clf_accuracy: 0.5219
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.2959 - regr_loss: 1.0257 - clf_loss: 0.7892 - regr_mse: 2.0794 - clf_accuracy: 0.5444
# Epoch 00002: val_loss improved from 5.37064 to 4.60174, saving model to models\lstm1_univar\multitask\02.hdf5
# 32/32 [==============================] - 19s 591ms/step - loss: 5.2753 - regr_loss: 1.0177 - clf_loss: 0.7895 - regr_mse: 2.0561 - clf_accuracy: 0.5445 - val_loss: 4.6017 - val_regr_loss: 0.8668 - val_clf_loss: 0.6971 - val_regr_mse: 1.6469 - val_clf_accuracy: 0.4704
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.3985 - regr_loss: 0.9196 - clf_loss: 0.7592 - regr_mse: 1.6837 - clf_accuracy: 0.5484
# Epoch 00003: val_loss improved from 4.60174 to 3.88362, saving model to models\lstm1_univar\multitask\03.hdf5
# 32/32 [==============================] - 18s 563ms/step - loss: 4.4100 - regr_loss: 0.9338 - clf_loss: 0.7661 - regr_mse: 1.7169 - clf_accuracy: 0.5464 - val_loss: 3.8836 - val_regr_loss: 0.7404 - val_clf_loss: 0.7427 - val_regr_mse: 1.3496 - val_clf_accuracy: 0.4704
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.7605 - regr_loss: 0.8543 - clf_loss: 0.7292 - regr_mse: 1.4539 - clf_accuracy: 0.5736
# Epoch 00004: val_loss improved from 3.88362 to 3.33828, saving model to models\lstm1_univar\multitask\04.hdf5
# 32/32 [==============================] - 19s 581ms/step - loss: 3.7529 - regr_loss: 0.8567 - clf_loss: 0.7259 - regr_mse: 1.4580 - clf_accuracy: 0.5741 - val_loss: 3.3383 - val_regr_loss: 0.6872 - val_clf_loss: 0.6995 - val_regr_mse: 1.2113 - val_clf_accuracy: 0.4833
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.3917 - regr_loss: 0.8005 - clf_loss: 0.7287 - regr_mse: 1.3872 - clf_accuracy: 0.5605
# Epoch 00005: val_loss improved from 3.33828 to 3.12728, saving model to models\lstm1_univar\multitask\05.hdf5
# 32/32 [==============================] - 21s 652ms/step - loss: 3.3915 - regr_loss: 0.7978 - clf_loss: 0.7339 - regr_mse: 1.3778 - clf_accuracy: 0.5593 - val_loss: 3.1273 - val_regr_loss: 0.6503 - val_clf_loss: 0.7057 - val_regr_mse: 1.1187 - val_clf_accuracy: 0.4833
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.1733 - regr_loss: 0.7906 - clf_loss: 0.6851 - regr_mse: 1.3352 - clf_accuracy: 0.5756
# Epoch 00006: val_loss improved from 3.12728 to 3.00047, saving model to models\lstm1_univar\multitask\06.hdf5
# 32/32 [==============================] - 22s 686ms/step - loss: 3.1793 - regr_loss: 0.7946 - clf_loss: 0.6896 - regr_mse: 1.3335 - clf_accuracy: 0.5731 - val_loss: 3.0005 - val_regr_loss: 0.6736 - val_clf_loss: 0.7079 - val_regr_mse: 1.1491 - val_clf_accuracy: 0.5424
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.0197 - regr_loss: 0.7852 - clf_loss: 0.6783 - regr_mse: 1.2868 - clf_accuracy: 0.5877
# Epoch 00007: val_loss improved from 3.00047 to 2.92570, saving model to models\lstm1_univar\multitask\07.hdf5
# 32/32 [==============================] - 20s 628ms/step - loss: 3.0146 - regr_loss: 0.7796 - clf_loss: 0.6807 - regr_mse: 1.2730 - clf_accuracy: 0.5879 - val_loss: 2.9257 - val_regr_loss: 0.6762 - val_clf_loss: 0.7606 - val_regr_mse: 1.1818 - val_clf_accuracy: 0.4756
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.8530 - regr_loss: 0.7536 - clf_loss: 0.6644 - regr_mse: 1.2676 - clf_accuracy: 0.5827
# Epoch 00008: val_loss improved from 2.92570 to 2.76956, saving model to models\lstm1_univar\multitask\08.hdf5
# 32/32 [==============================] - 20s 629ms/step - loss: 2.8567 - regr_loss: 0.7589 - clf_loss: 0.6645 - regr_mse: 1.2687 - clf_accuracy: 0.5840 - val_loss: 2.7696 - val_regr_loss: 0.6589 - val_clf_loss: 0.7335 - val_regr_mse: 1.1414 - val_clf_accuracy: 0.4756
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.7544 - regr_loss: 0.7367 - clf_loss: 0.6874 - regr_mse: 1.1934 - clf_accuracy: 0.5776
# Epoch 00009: val_loss improved from 2.76956 to 2.63246, saving model to models\lstm1_univar\multitask\09.hdf5
# 32/32 [==============================] - 19s 596ms/step - loss: 2.7424 - regr_loss: 0.7298 - clf_loss: 0.6837 - regr_mse: 1.1783 - clf_accuracy: 0.5791 - val_loss: 2.6325 - val_regr_loss: 0.6526 - val_clf_loss: 0.6994 - val_regr_mse: 1.1290 - val_clf_accuracy: 0.5270
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.6367 - regr_loss: 0.7039 - clf_loss: 0.6753 - regr_mse: 1.1521 - clf_accuracy: 0.5806
# Epoch 00010: val_loss improved from 2.63246 to 2.60765, saving model to models\lstm1_univar\multitask\10.hdf5
# 32/32 [==============================] - 20s 640ms/step - loss: 2.6485 - regr_loss: 0.7109 - clf_loss: 0.6809 - regr_mse: 1.1585 - clf_accuracy: 0.5791 - val_loss: 2.6076 - val_regr_loss: 0.6643 - val_clf_loss: 0.7089 - val_regr_mse: 1.1437 - val_clf_accuracy: 0.5501
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.6012 - regr_loss: 0.7385 - clf_loss: 0.6481 - regr_mse: 1.2329 - clf_accuracy: 0.5927
# Epoch 00011: val_loss did not improve from 2.60765
# 32/32 [==============================] - 18s 561ms/step - loss: 2.5956 - regr_loss: 0.7329 - clf_loss: 0.6486 - regr_mse: 1.2188 - clf_accuracy: 0.5939 - val_loss: 2.6111 - val_regr_loss: 0.7097 - val_clf_loss: 0.7083 - val_regr_mse: 1.2744 - val_clf_accuracy: 0.5347
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.5450 - regr_loss: 0.7127 - clf_loss: 0.6583 - regr_mse: 1.1719 - clf_accuracy: 0.6119
# Epoch 00012: val_loss improved from 2.60765 to 2.54977, saving model to models\lstm1_univar\multitask\12.hdf5
# 32/32 [==============================] - 19s 601ms/step - loss: 2.5412 - regr_loss: 0.7082 - clf_loss: 0.6595 - regr_mse: 1.1601 - clf_accuracy: 0.6107 - val_loss: 2.5498 - val_regr_loss: 0.6826 - val_clf_loss: 0.7137 - val_regr_mse: 1.2191 - val_clf_accuracy: 0.5296
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.4868 - regr_loss: 0.6956 - clf_loss: 0.6554 - regr_mse: 1.1381 - clf_accuracy: 0.6099
# Epoch 00013: val_loss improved from 2.54977 to 2.54529, saving model to models\lstm1_univar\multitask\13.hdf5
# 32/32 [==============================] - 20s 611ms/step - loss: 2.4760 - regr_loss: 0.6874 - clf_loss: 0.6534 - regr_mse: 1.1214 - clf_accuracy: 0.6087 - val_loss: 2.5453 - val_regr_loss: 0.7127 - val_clf_loss: 0.7162 - val_regr_mse: 1.2890 - val_clf_accuracy: 0.5296
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.4200 - regr_loss: 0.6784 - clf_loss: 0.6419 - regr_mse: 0.8206 - clf_accuracy: 0.6139
# Epoch 00014: val_loss did not improve from 2.54529
# 32/32 [==============================] - 19s 609ms/step - loss: 2.4454 - regr_loss: 0.7037 - clf_loss: 0.6428 - regr_mse: 1.1156 - clf_accuracy: 0.6126 - val_loss: 2.5583 - val_regr_loss: 0.7224 - val_clf_loss: 0.7546 - val_regr_mse: 1.3150 - val_clf_accuracy: 0.5527
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.3887 - regr_loss: 0.6868 - clf_loss: 0.6299 - regr_mse: 1.1383 - clf_accuracy: 0.6492
# Epoch 00015: val_loss improved from 2.54529 to 2.48597, saving model to models\lstm1_univar\multitask\15.hdf5
# 32/32 [==============================] - 20s 635ms/step - loss: 2.3913 - regr_loss: 0.6894 - clf_loss: 0.6302 - regr_mse: 1.1343 - clf_accuracy: 0.6462 - val_loss: 2.4860 - val_regr_loss: 0.6882 - val_clf_loss: 0.7350 - val_regr_mse: 1.2363 - val_clf_accuracy: 0.5347
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.3649 - regr_loss: 0.6729 - clf_loss: 0.6374 - regr_mse: 1.0943 - clf_accuracy: 0.6300
# Epoch 00016: val_loss improved from 2.48597 to 2.44953, saving model to models\lstm1_univar\multitask\16.hdf5
# 32/32 [==============================] - 20s 635ms/step - loss: 2.3762 - regr_loss: 0.6828 - clf_loss: 0.6392 - regr_mse: 1.1048 - clf_accuracy: 0.6275 - val_loss: 2.4495 - val_regr_loss: 0.6659 - val_clf_loss: 0.7381 - val_regr_mse: 1.1839 - val_clf_accuracy: 0.5167
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.3479 - regr_loss: 0.6739 - clf_loss: 0.6364 - regr_mse: 1.0705 - clf_accuracy: 0.6139
# Epoch 00017: val_loss improved from 2.44953 to 2.43696, saving model to models\lstm1_univar\multitask\17.hdf5
# 32/32 [==============================] - 20s 620ms/step - loss: 2.3492 - regr_loss: 0.6723 - clf_loss: 0.6396 - regr_mse: 1.0635 - clf_accuracy: 0.6146 - val_loss: 2.4370 - val_regr_loss: 0.6710 - val_clf_loss: 0.7371 - val_regr_mse: 1.1819 - val_clf_accuracy: 0.5270
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.3242 - regr_loss: 0.6643 - clf_loss: 0.6390 - regr_mse: 1.0456 - clf_accuracy: 0.6058
# Epoch 00018: val_loss improved from 2.43696 to 2.42729, saving model to models\lstm1_univar\multitask\18.hdf5
# 32/32 [==============================] - 20s 627ms/step - loss: 2.3264 - regr_loss: 0.6662 - clf_loss: 0.6395 - regr_mse: 1.0416 - clf_accuracy: 0.6047 - val_loss: 2.4273 - val_regr_loss: 0.6698 - val_clf_loss: 0.7452 - val_regr_mse: 1.1776 - val_clf_accuracy: 0.5321
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2789 - regr_loss: 0.6505 - clf_loss: 0.6238 - regr_mse: 1.0071 - clf_accuracy: 0.6462
# Epoch 00019: val_loss improved from 2.42729 to 2.41616, saving model to models\lstm1_univar\multitask\19.hdf5
# 32/32 [==============================] - 24s 742ms/step - loss: 2.2755 - regr_loss: 0.6481 - clf_loss: 0.6230 - regr_mse: 0.9987 - clf_accuracy: 0.6453 - val_loss: 2.4162 - val_regr_loss: 0.6808 - val_clf_loss: 0.7392 - val_regr_mse: 1.2091 - val_clf_accuracy: 0.5296
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2868 - regr_loss: 0.6559 - clf_loss: 0.6393 - regr_mse: 1.0513 - clf_accuracy: 0.6069
# Epoch 00020: val_loss improved from 2.41616 to 2.40236, saving model to models\lstm1_univar\multitask\20.hdf5
# 32/32 [==============================] - 21s 648ms/step - loss: 2.2857 - regr_loss: 0.6571 - clf_loss: 0.6371 - regr_mse: 1.0440 - clf_accuracy: 0.6077 - val_loss: 2.4024 - val_regr_loss: 0.6754 - val_clf_loss: 0.7397 - val_regr_mse: 1.1925 - val_clf_accuracy: 0.5270
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2536 - regr_loss: 0.6590 - clf_loss: 0.6110 - regr_mse: 1.0477 - clf_accuracy: 0.6442
# Epoch 00021: val_loss improved from 2.40236 to 2.39499, saving model to models\lstm1_univar\multitask\21.hdf5
# 32/32 [==============================] - 19s 593ms/step - loss: 2.2531 - regr_loss: 0.6587 - clf_loss: 0.6110 - regr_mse: 1.0402 - clf_accuracy: 0.6433 - val_loss: 2.3950 - val_regr_loss: 0.6750 - val_clf_loss: 0.7407 - val_regr_mse: 1.1929 - val_clf_accuracy: 0.5039
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2503 - regr_loss: 0.6525 - clf_loss: 0.6222 - regr_mse: 1.0378 - clf_accuracy: 0.6321
# Epoch 00022: val_loss did not improve from 2.39499
# 32/32 [==============================] - 19s 587ms/step - loss: 2.2438 - regr_loss: 0.6484 - clf_loss: 0.6199 - regr_mse: 1.0247 - clf_accuracy: 0.6314 - val_loss: 2.3955 - val_regr_loss: 0.6781 - val_clf_loss: 0.7460 - val_regr_mse: 1.1950 - val_clf_accuracy: 0.5064
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2420 - regr_loss: 0.6485 - clf_loss: 0.6258 - regr_mse: 1.0510 - clf_accuracy: 0.6310
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.2500000593718141e-05.
#
# Epoch 00023: val_loss did not improve from 2.39499
# 32/32 [==============================] - 20s 611ms/step - loss: 2.2473 - regr_loss: 0.6504 - clf_loss: 0.6295 - regr_mse: 1.0464 - clf_accuracy: 0.6285 - val_loss: 2.3969 - val_regr_loss: 0.6853 - val_clf_loss: 0.7482 - val_regr_mse: 1.2118 - val_clf_accuracy: 0.5039
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 24/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2325 - regr_loss: 0.6635 - clf_loss: 0.6068 - regr_mse: 1.0931 - clf_accuracy: 0.6653
# Epoch 00024: val_loss improved from 2.39499 to 2.39061, saving model to models\lstm1_univar\multitask\24.hdf5
# 32/32 [==============================] - 21s 645ms/step - loss: 2.2279 - regr_loss: 0.6606 - clf_loss: 0.6051 - regr_mse: 1.0814 - clf_accuracy: 0.6680 - val_loss: 2.3906 - val_regr_loss: 0.6815 - val_clf_loss: 0.7478 - val_regr_mse: 1.2009 - val_clf_accuracy: 0.5090
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 25/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2052 - regr_loss: 0.6269 - clf_loss: 0.6175 - regr_mse: 0.9969 - clf_accuracy: 0.6270
# Epoch 00025: val_loss improved from 2.39061 to 2.38980, saving model to models\lstm1_univar\multitask\25.hdf5
# 32/32 [==============================] - 20s 617ms/step - loss: 2.2206 - regr_loss: 0.6434 - clf_loss: 0.6165 - regr_mse: 1.0438 - clf_accuracy: 0.6255 - val_loss: 2.3898 - val_regr_loss: 0.6817 - val_clf_loss: 0.7478 - val_regr_mse: 1.1989 - val_clf_accuracy: 0.5167
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 26/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2330 - regr_loss: 0.6586 - clf_loss: 0.6145 - regr_mse: 1.0736 - clf_accuracy: 0.6522
# Epoch 00026: val_loss improved from 2.38980 to 2.38958, saving model to models\lstm1_univar\multitask\26.hdf5
# 32/32 [==============================] - 20s 611ms/step - loss: 2.2380 - regr_loss: 0.6617 - clf_loss: 0.6165 - regr_mse: 1.0753 - clf_accuracy: 0.6482 - val_loss: 2.3896 - val_regr_loss: 0.6824 - val_clf_loss: 0.7477 - val_regr_mse: 1.1992 - val_clf_accuracy: 0.5141
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 27/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2195 - regr_loss: 0.6454 - clf_loss: 0.6150 - regr_mse: 1.0035 - clf_accuracy: 0.6371
# Epoch 00027: val_loss improved from 2.38958 to 2.38914, saving model to models\lstm1_univar\multitask\27.hdf5
# 32/32 [==============================] - 19s 582ms/step - loss: 2.2142 - regr_loss: 0.6408 - clf_loss: 0.6143 - regr_mse: 0.9914 - clf_accuracy: 0.6383 - val_loss: 2.3891 - val_regr_loss: 0.6824 - val_clf_loss: 0.7481 - val_regr_mse: 1.1994 - val_clf_accuracy: 0.5167
# Epoch 00028: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 28/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2734 - regr_loss: 0.6792 - clf_loss: 0.6359 - regr_mse: 1.0858 - clf_accuracy: 0.6220
# Epoch 00028: val_loss did not improve from 2.38914
# 32/32 [==============================] - 19s 583ms/step - loss: 2.2746 - regr_loss: 0.6788 - clf_loss: 0.6375 - regr_mse: 1.0787 - clf_accuracy: 0.6215 - val_loss: 2.3893 - val_regr_loss: 0.6830 - val_clf_loss: 0.7485 - val_regr_mse: 1.1998 - val_clf_accuracy: 0.5193
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 29/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2361 - regr_loss: 0.6685 - clf_loss: 0.6102 - regr_mse: 1.0949 - clf_accuracy: 0.6472
# Epoch 00029: val_loss did not improve from 2.38914
# 32/32 [==============================] - 19s 583ms/step - loss: 2.2338 - regr_loss: 0.6671 - clf_loss: 0.6092 - regr_mse: 1.0871 - clf_accuracy: 0.6462 - val_loss: 2.3894 - val_regr_loss: 0.6835 - val_clf_loss: 0.7488 - val_regr_mse: 1.2002 - val_clf_accuracy: 0.5167
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 3.1250001484295353e-06.
# Epoch 30/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2005 - regr_loss: 0.6327 - clf_loss: 0.6110 - regr_mse: 0.9801 - clf_accuracy: 0.6391
# Epoch 00030: val_loss improved from 2.38914 to 2.38886, saving model to models\lstm1_univar\multitask\30.hdf5
# 32/32 [==============================] - 19s 609ms/step - loss: 2.2057 - regr_loss: 0.6419 - clf_loss: 0.6071 - regr_mse: 0.9988 - clf_accuracy: 0.6423 - val_loss: 2.3889 - val_regr_loss: 0.6835 - val_clf_loss: 0.7488 - val_regr_mse: 1.2004 - val_clf_accuracy: 0.5167
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 3.1250001484295353e-06.
# Epoch 31/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2289 - regr_loss: 0.6560 - clf_loss: 0.6165 - regr_mse: 1.0456 - clf_accuracy: 0.6310
# Epoch 00031: val_loss improved from 2.38886 to 2.38867, saving model to models\lstm1_univar\multitask\31.hdf5
# 32/32 [==============================] - 19s 609ms/step - loss: 2.2298 - regr_loss: 0.6578 - clf_loss: 0.6156 - regr_mse: 1.0413 - clf_accuracy: 0.6294 - val_loss: 2.3887 - val_regr_loss: 0.6835 - val_clf_loss: 0.7490 - val_regr_mse: 1.2003 - val_clf_accuracy: 0.5167
# Epoch 00031: early stopping

# %%
def plot_multitask_history(hist):
    fig, ax = plt.subplots(2, 2, figsize=(16, 12))
    plotHelpers.plot_train_history(ax[0, 0], hist, 'Total loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[0, 1], hist, 'Accuracy', 'clf_accuracy', 'val_clf_accuracy')
    plotHelpers.plot_train_history(ax[1, 0], hist, 'MAE', 'regr_loss', 'val_regr_loss')
    plotHelpers.plot_train_history(ax[1, 1], hist, 'MSE', 'regr_mse', 'val_regr_mse')
    
plot_multitask_history(multitask_history);

# %% [markdown]
# ### Прогноз

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_multitask_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret, pred_direction_proba = univariate_multitask_lstm.predict_generator(test_multi_gen, verbose=1)
# Out:
# 13/13 [==============================] - 3s 241ms/step

# %%
np.set_printoptions(precision=3, suppress=True)

np.column_stack([pred_log_ret, pred_direction_proba])[-10:]
# Out:
# array([[-0.094,  0.571],
#        [ 0.169,  0.509],
#        [-0.104,  0.438],
#        [-0.036,  0.523],
#        [ 0.246,  0.695],
#        [ 0.251,  0.76 ],
#        [-0.078,  0.522],
#        [-0.047,  0.623],
#        [ 0.011,  0.573],
#        [ 0.066,  0.603]], dtype=float32)

# %% [markdown]
# #### Прогноз задачи регрессии

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret, figsize=(16, 20),
                                  datetime_unit='m', plot_data_slice=slice(1, None))

# %% [markdown]
# #### Прогноз задачи классификации

# %%
true_direction = test_multi_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 0.49528405

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([203, 186], dtype=int64)),
#  (array([0, 1]), array([200, 189], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.53      0.54       203
#            1       0.50      0.51      0.50       186
#
#     accuracy                           0.52       389
#    macro avg       0.52      0.52      0.52       389
# weighted avg       0.52      0.52      0.52       389

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[108,  95],
#        [ 92,  94]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.54 , 0.503],
#        [0.46 , 0.497]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# # Выводы
#
# 1.  Размер батча влияет на скорость обучения.
# 2.  Инициализация весов (`bias_initializer`) в слое **LSTM** оказалась очень важным параметром.
# 3.  Модель регрессии близка к модели случайного блуждания.
# 4.  Задача классификации не решается удовлетворительно.
# 5.  Комбинированная (многозадачная) модель не смогла что-то улучшить.

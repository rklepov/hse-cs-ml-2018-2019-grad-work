# %% [markdown]
# # *Одномерная модель на LSTM* (2 слоя)
#
# В качестве единственного признака используется сама цена.

# %%
import os
import glob
import datetime
import pickle

import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from pandas_datareader import data as pdr

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
import tensorflow as tf
# tf.test.is_gpu_available()
tf.__version__
# Out:
# '2.0.0'

# %%
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Input, Dense, LSTM, GRU, Flatten, ReLU, LeakyReLU, Dropout, BatchNormalization
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers import Nadam

# %%
from mdp import TimeSeries
from mdp import MarketData
from mdp import MovingWindowFeatures
from mdp import ClassificationGenerator, RegressionGenerator, MultitaskGenerator
from mdp import invert_log_ret

import mdp.utils as utils
import mdp.plotHelpers as plotHelpers

# %%
import importlib

import mdp

importlib.reload(mdp)
importlib.reload(mdp.datasetGenerator)
importlib.reload(mdp.marketData)
importlib.reload(mdp.movingWindowFeatures)
importlib.reload(mdp.timeSeries)
importlib.reload(mdp.plotHelpers)
importlib.reload(mdp.utils);

# %% [markdown]
# # *Параметры*

# %%
INSTRUMENT = 'MSFT' # Microsoft corp
START_FROM = np.datetime64('today') - 7
WINDOW_SIZE = 120
FORECAST_OFFSET=1
BATCH_SIZE = 32
FORCE_TRAIN = True

# %% [markdown]
# # *Исходные данные*
#
# Загрузка данных и вычисление индикаторов.

# %%
instr = MarketData.create_from_alphavantage_intraday(INSTRUMENT, start=START_FROM)

# %%
instr.feature_names
# Out:
# ['o',
#  'h',
#  'l',
#  'c',
#  'v',
#  'ema14',
#  'ema30',
#  'macd',
#  'macd_signal',
#  'rsi14',
#  'bband20_upper',
#  'bband20_middle',
#  'bband20_lower',
#  'willr14',
#  'stochk',
#  'stochd',
#  'adline',
#  'adosc']

# %% [markdown]
# Здесь не будем делить отдельно на тест и валидацию, поскольку данных у нас только 5 дней.

# %%
dates_unique = np.unique(instr.timestamps.astype('datetime64[D]'))

START_FROM = dates_unique[0]
VAL_TEST_SPLIT = dates_unique[-1]

START_FROM, VAL_TEST_SPLIT
# Out:
# (numpy.datetime64('2020-04-08'), numpy.datetime64('2020-04-14'))

# %% [markdown]
# ## Целевая переменная

# %% [markdown]
# Цена закрытия.

# %%
orig_target = instr.c

# %% [markdown]
# Переходим к логарифмической доходности.

# %%
transformed_target = instr.c.transform(transforms={'ratios' : {}, 'ln' : {}})

# %%
plotHelpers.plot_transformed_timeseries_unit(instr,
                                             transformed_target,
                                             'Close price, USD', 'Log return',
                                             datetime_unit='m', rotation=45)

# %% [markdown]
# ## Трансформация признаков
#
# Из признаков выбираем только цену закрытия. Временной ряд цен преобразуется к ряду логарифмических доходностей (что также позволяет убрать нестационарность).

# %%
def make_feature_selector():
    price_transformer = lambda: {'ratios': {}, 'ln': {}}
    diff_transformer = lambda o: {'diffs': {'order': o}}
    identity_transformer = lambda: {}
    feature_transformations = {
        'c': price_transformer(),
    }
    return feature_transformations

# %%
instr_transformed = instr.select_transform(make_feature_selector())

# %%
transformed_target = instr_transformed.c

# %% [markdown]
# ## Обучающая, валидационная и тестовая выборки

# %%
instr_train, instr_test = instr_transformed.train_test_split(VAL_TEST_SPLIT, window_size=WINDOW_SIZE,
                                                             scaler=StandardScaler)
#                                                              scaler=MinMaxScaler,
#                                                              scaler_kwargs={'feature_range': (-1, 1)})

# instr_val, instr_test = instr_val_test.train_test_split(TEST_SPLIT, window_size=WINDOW_SIZE, scaler=None)

len(instr_train), len(instr_test)
# Out:
# (1136, 506)

# %% [markdown]
# ## Признаки - скользящие окна

# %%
train_mwf = MovingWindowFeatures.create(instr_train.c, [instr_train], instr_train.feature_names, window_size=WINDOW_SIZE)
# val_mwf = MovingWindowFeatures.create(instr_val.c, [instr_val], instr_val.feature_names, window_size=WINDOW_SIZE)
test_mwf = MovingWindowFeatures.create(instr_test.c, [instr_test], instr_test.feature_names, window_size=WINDOW_SIZE)

len(instr_train), len(train_mwf), train_mwf.features.shape
# Out:
# (1136, 1016, (1016, 120, 1))

# %% [markdown]
# Проверка, что скользящие окна соответствуют исходным данным.
#
# Возьмём произвольный признак и произвольное окно (строка #**41**). Проверим, что данные в точности совпадают:

# %%
def check_data(md, mwf, row):
    col = np.random.randint(len(mwf.feature_names))
    feature = mwf.feature_names[col]
    check = (getattr(md, feature).data[row:row + mwf.window_size] == mwf.features[row, :, col]).all()
    assert check
    return feature, check

check_data(instr_train, train_mwf, 41)
# Out:
# ('c', True)

# %% [markdown]
# # *Модели*

# %% [markdown]
# Модель с двумя LSTM слоями.

# %%
def build_lstm_layers(input_shape, latent_dim=(8, 16)):
    # формат входа: наша матрица (окно; признак)
    inp = Input(input_shape, name='input')

    # стекаем два уровня LSTM
    lstm = LSTM(latent_dim[0], return_sequences=True, 
                    recurrent_dropout=0.2, dropout=0.2, 
                    bias_initializer='he_uniform',
                    bias_regularizer=L1L2(0.01, 0.02),
                    kernel_regularizer=L1L2(0.01, 0.02),
                    recurrent_regularizer=L1L2(0.02, 0.02)
               )(inp)

    lstm = LSTM(latent_dim[1], return_sequences=True,
                    recurrent_dropout=0.2, dropout=0.2,
                    bias_initializer='he_uniform',
                    bias_regularizer=L1L2(0.01, 0.02),
                    kernel_regularizer=L1L2(0.01, 0.02),
                    recurrent_regularizer=L1L2(0.01, 0.02)
               )(lstm)
    
    lstm = Flatten()(lstm)
    
    return inp, lstm

# %% [markdown]
# #### Пути сохранения моделей:

# %%
model_path_root = 'models'
model_type_name = 'lstm2_univar'

def make_model_save_dir(path_root, type_name, class_name):
    save_dir = os.path.join(path_root, type_name, class_name)
    os.makedirs(save_dir, exist_ok=True)
    return save_dir

# %% [markdown]
# #### Общие коллбэки:

# %%
# уменьшение learning rate в случае, если loss не изменяется
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001, verbose=1)

# уменьшение learning rate в 2 раза каждую 5-ю эпоху
def lr_decay(e, lr):
    return lr * (1 - 0.5 * (0 == (e + 1) % 5))

lr_scheduler = LearningRateScheduler(schedule=lr_decay, verbose=1)

# %% [markdown]
# ## Задача регрессии
#
# Непосредственное прогнозирование цены следующего периода.

# %%
train_regr_gen = RegressionGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_regr_gen = RegressionGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_regr_gen = RegressionGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# Следующие числа соответствуют значению параметра `steps_per_epoch` метода [`fit_generator`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit_generator "tf.keras.layers.SimpleRNN &nbsp;|&nbsp; TensorFlow Core r2.0") - то есть это число батчей, которые генератор выдаст за одну эпоху обучения (если класс генератора поддерживает метод `len()`, то данный параметр можно не указывать).

# %%
len(train_regr_gen), (test_regr_gen)
# Out:
# (32, <mdp.datasetGenerator.RegressionGenerator at 0x17485d264c8>)

# %% [markdown]
# Один сэмпл данных представляет собой матрицу размером *(длина окна; число признаков)*

# %%
train_regr_gen.input_shape
# Out:
# (120, 1)

# %% [markdown]
# ### Модель для задачи регрессии

# %%
model_class_name = 'regression'

# %%
def build_regression_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=(16, 32))

    regr = Dense(64)(lstm)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    return Model(inputs=[inp], outputs=[regr])

# %%
univariate_regression_lstm = build_regression_model(train_regr_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:
# [`Nadam`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Nadam) (*Adam with Nestrov momentum*).

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Функция потерь:
#
# В качестве функции потерь будем использовать [MSE](https://www.tensorflow.org/api_docs/python/tf/keras/losses/MSE) (чтобы штрафовать за большие отклонения). Xотя хорошая функция потерь в контексте темы данной задачи - это [вопрос сложный](https://github.com/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Chapter5_LossFunctions/Ch5_LossFunctions_PyMC3.ipynb). В частности, здесь нам, очевидно, помимо абсолютного значения отклонения также важен его знак.

# %%
univariate_regression_lstm.compile(optimizer=optimizer,
                                   loss={'regr': 'mse'},
                                   metrics={'regr': 'mae'})

univariate_regression_lstm.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 120, 1)]          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 120, 16)           1152
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 120, 32)           6272
# _________________________________________________________________
# flatten (Flatten)            (None, 3840)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                245824
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64)                256
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 64)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# regr (Dense)                 (None, 1)                 65
# =================================================================
# Total params: 253,569
# Trainable params: 253,441
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# #### Обучение:

# %%
regr_history = utils.train_model(univariate_regression_lstm,
                                 model_save_dir, train_regr_gen, test_regr_gen,
                                 callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                 force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 1s - loss: 12.1808 - mae: 1.1572
# Epoch 00001: val_loss improved from inf to 10.65556, saving model to models\lstm2_univar\regression\01.hdf5
# 32/32 [==============================] - 72s 2s/step - loss: 12.2327 - mae: 1.1674 - val_loss: 10.6556 - val_mae: 0.6364
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 1s - loss: 10.3143 - mae: 1.0494
# Epoch 00002: val_loss improved from 10.65556 to 9.99902, saving model to models\lstm2_univar\regression\02.hdf5
# 32/32 [==============================] - 74s 2s/step - loss: 10.2709 - mae: 1.0453 - val_loss: 9.9990 - val_mae: 1.1012
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 2s - loss: 8.7014 - mae: 0.9630
# Epoch 00003: val_loss improved from 9.99902 to 7.92575, saving model to models\lstm2_univar\regression\03.hdf5
# 32/32 [==============================] - 86s 3s/step - loss: 8.6551 - mae: 0.9561 - val_loss: 7.9258 - val_mae: 0.6611
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 2s - loss: 7.6015 - mae: 0.9874
# Epoch 00004: val_loss improved from 7.92575 to 7.01519, saving model to models\lstm2_univar\regression\04.hdf5
# 32/32 [==============================] - 86s 3s/step - loss: 7.5669 - mae: 0.9812 - val_loss: 7.0152 - val_mae: 0.7088
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 2s - loss: 6.6741 - mae: 0.9275
# Epoch 00005: val_loss improved from 7.01519 to 6.41154, saving model to models\lstm2_univar\regression\05.hdf5
# 32/32 [==============================] - 85s 3s/step - loss: 6.6611 - mae: 0.9266 - val_loss: 6.4115 - val_mae: 0.6639
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 2s - loss: 6.2463 - mae: 0.9264
# Epoch 00006: val_loss improved from 6.41154 to 5.94253, saving model to models\lstm2_univar\regression\06.hdf5
# 32/32 [==============================] - 84s 3s/step - loss: 6.2243 - mae: 0.9250 - val_loss: 5.9425 - val_mae: 0.6259
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 2s - loss: 5.7748 - mae: 0.9072
# Epoch 00007: val_loss improved from 5.94253 to 5.57451, saving model to models\lstm2_univar\regression\07.hdf5
# 32/32 [==============================] - 85s 3s/step - loss: 5.7665 - mae: 0.9074 - val_loss: 5.5745 - val_mae: 0.6259
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 2s - loss: 5.3810 - mae: 0.8882
# Epoch 00008: val_loss improved from 5.57451 to 5.23376, saving model to models\lstm2_univar\regression\08.hdf5
# 32/32 [==============================] - 81s 3s/step - loss: 5.3685 - mae: 0.8868 - val_loss: 5.2338 - val_mae: 0.6258
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 2s - loss: 5.0061 - mae: 0.8800
# Epoch 00009: val_loss improved from 5.23376 to 4.92732, saving model to models\lstm2_univar\regression\09.hdf5
# 32/32 [==============================] - 82s 3s/step - loss: 4.9788 - mae: 0.8738 - val_loss: 4.9273 - val_mae: 0.6244
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 2s - loss: 4.7304 - mae: 0.8654
# Epoch 00010: val_loss improved from 4.92732 to 4.80047, saving model to models\lstm2_univar\regression\10.hdf5
# 32/32 [==============================] - 81s 3s/step - loss: 4.7260 - mae: 0.8637 - val_loss: 4.8005 - val_mae: 0.6429
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 2s - loss: 4.5652 - mae: 0.8620
# Epoch 00011: val_loss improved from 4.80047 to 4.65225, saving model to models\lstm2_univar\regression\11.hdf5
# 32/32 [==============================] - 81s 3s/step - loss: 4.5975 - mae: 0.8706 - val_loss: 4.6523 - val_mae: 0.6245
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 2s - loss: 4.4726 - mae: 0.8664
# Epoch 00012: val_loss improved from 4.65225 to 4.52629, saving model to models\lstm2_univar\regression\12.hdf5
# 32/32 [==============================] - 81s 3s/step - loss: 4.4754 - mae: 0.8664 - val_loss: 4.5263 - val_mae: 0.6265
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 1s - loss: 4.2576 - mae: 0.8266
# Epoch 00013: val_loss improved from 4.52629 to 4.40719, saving model to models\lstm2_univar\regression\13.hdf5
# 32/32 [==============================] - 69s 2s/step - loss: 4.2492 - mae: 0.8279 - val_loss: 4.4072 - val_mae: 0.6255
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 2s - loss: 4.2061 - mae: 0.8592
# Epoch 00014: val_loss did not improve from 4.40719
# 32/32 [==============================] - 83s 3s/step - loss: 4.2081 - mae: 0.8602 - val_loss: 4.4705 - val_mae: 0.7023
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 1s - loss: 4.1103 - mae: 0.8602
# Epoch 00015: val_loss improved from 4.40719 to 4.34128, saving model to models\lstm2_univar\regression\15.hdf5
# 32/32 [==============================] - 65s 2s/step - loss: 4.0972 - mae: 0.8531 - val_loss: 4.3413 - val_mae: 0.6696
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 1s - loss: 4.0505 - mae: 0.8457
# Epoch 00016: val_loss improved from 4.34128 to 4.19217, saving model to models\lstm2_univar\regression\16.hdf5
# 32/32 [==============================] - 64s 2s/step - loss: 4.0333 - mae: 0.8406 - val_loss: 4.1922 - val_mae: 0.6267
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 2s - loss: 4.0810 - mae: 0.8728
# Epoch 00017: val_loss improved from 4.19217 to 4.13596, saving model to models\lstm2_univar\regression\17.hdf5
# 32/32 [==============================] - 84s 3s/step - loss: 4.0583 - mae: 0.8659 - val_loss: 4.1360 - val_mae: 0.6269
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 2s - loss: 3.9715 - mae: 0.8644
# Epoch 00018: val_loss improved from 4.13596 to 4.08509, saving model to models\lstm2_univar\regression\18.hdf5
# 32/32 [==============================] - 83s 3s/step - loss: 3.9529 - mae: 0.8577 - val_loss: 4.0851 - val_mae: 0.6262
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 2s - loss: 3.8869 - mae: 0.8291
# Epoch 00019: val_loss improved from 4.08509 to 4.03483, saving model to models\lstm2_univar\regression\19.hdf5
# 32/32 [==============================] - 84s 3s/step - loss: 3.8805 - mae: 0.8292 - val_loss: 4.0348 - val_mae: 0.6267
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 2s - loss: 3.8181 - mae: 0.8166
# Epoch 00020: val_loss improved from 4.03483 to 4.01383, saving model to models\lstm2_univar\regression\20.hdf5
# 32/32 [==============================] - 85s 3s/step - loss: 3.8301 - mae: 0.8181 - val_loss: 4.0138 - val_mae: 0.6250
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 1s - loss: 3.8245 - mae: 0.8383
# Epoch 00021: val_loss improved from 4.01383 to 3.98919, saving model to models\lstm2_univar\regression\21.hdf5
# 32/32 [==============================] - 69s 2s/step - loss: 3.8409 - mae: 0.8437 - val_loss: 3.9892 - val_mae: 0.6246
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.8499 - mae: 0.8527
# Epoch 00022: val_loss did not improve from 3.98919
# 32/32 [==============================] - 37s 1s/step - loss: 3.8339 - mae: 0.8495 - val_loss: 4.0111 - val_mae: 0.6448
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.7626 - mae: 0.8297
# Epoch 00023: val_loss improved from 3.98919 to 3.98369, saving model to models\lstm2_univar\regression\23.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 3.7866 - mae: 0.8326 - val_loss: 3.9837 - val_mae: 0.6429
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.7128 - mae: 0.8261
# Epoch 00024: val_loss improved from 3.98369 to 3.91467, saving model to models\lstm2_univar\regression\24.hdf5
# 32/32 [==============================] - 36s 1s/step - loss: 3.7316 - mae: 0.8313 - val_loss: 3.9147 - val_mae: 0.6234
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.6933 - mae: 0.8324
# Epoch 00025: val_loss improved from 3.91467 to 3.90674, saving model to models\lstm2_univar\regression\25.hdf5
# 32/32 [==============================] - 36s 1s/step - loss: 3.6768 - mae: 0.8279 - val_loss: 3.9067 - val_mae: 0.6244
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 31/32 [============================>.] - ETA: 1s - loss: 3.6693 - mae: 0.8260
# Epoch 00026: val_loss improved from 3.90674 to 3.89812, saving model to models\lstm2_univar\regression\26.hdf5
# 32/32 [==============================] - 46s 1s/step - loss: 3.6543 - mae: 0.8220 - val_loss: 3.8981 - val_mae: 0.6254
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.6589 - mae: 0.8231
# Epoch 00027: val_loss did not improve from 3.89812
# 32/32 [==============================] - 34s 1s/step - loss: 3.6706 - mae: 0.8241 - val_loss: 3.9115 - val_mae: 0.6361
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.6687 - mae: 0.8339
# Epoch 00028: val_loss improved from 3.89812 to 3.88480, saving model to models\lstm2_univar\regression\28.hdf5
# 32/32 [==============================] - 36s 1s/step - loss: 3.6583 - mae: 0.8326 - val_loss: 3.8848 - val_mae: 0.6294
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.6392 - mae: 0.8117
# Epoch 00029: val_loss improved from 3.88480 to 3.86522, saving model to models\lstm2_univar\regression\29.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 3.6185 - mae: 0.8067 - val_loss: 3.8652 - val_mae: 0.6260
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.6557 - mae: 0.8356
# Epoch 00030: val_loss improved from 3.86522 to 3.85824, saving model to models\lstm2_univar\regression\30.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 3.6506 - mae: 0.8352 - val_loss: 3.8582 - val_mae: 0.6258
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.6931 - mae: 0.8390
# Epoch 00031: val_loss improved from 3.85824 to 3.85518, saving model to models\lstm2_univar\regression\31.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 3.6840 - mae: 0.8379 - val_loss: 3.8552 - val_mae: 0.6265
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.6374 - mae: 0.8271
# Epoch 00032: val_loss improved from 3.85518 to 3.84504, saving model to models\lstm2_univar\regression\32.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 3.6505 - mae: 0.8292 - val_loss: 3.8450 - val_mae: 0.6249

# %%
def plot_regr_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'MSE', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'MAE', 'mae', 'val_mae')
    
plot_regr_history(regr_history);

# %% [markdown]
# ### Прогноз задачи регрессии

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_regression_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret_test = univariate_regression_lstm.predict_generator(test_regr_gen, verbose=1)
# Out:
# 13/13 [==============================] - 6s 455ms/step

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret_test, figsize=(16, 10),
                                  datetime_unit='m', plot_data_slice=slice(1, None))

# %% [markdown]
# ## Задача классификации
#
# Прогнозируем направление изменения цены по сравнению с предыдущим периодом (**0** - снижение, **1** - рост).

# %%
model_class_name = 'classification'

# %%
train_clf_gen = ClassificationGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_clf_gen = ClassificationGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_clf_gen = ClassificationGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_classification_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=(16, 32))

    clf = Dense(64)(lstm)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)

    return Model(inputs=[inp], outputs=[clf])

# %%
univariate_classification_lstm = build_classification_model(test_clf_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
univariate_classification_lstm.compile(optimizer=optimizer,
                                       loss={'clf': 'binary_crossentropy'},
                                       metrics={'clf': 'accuracy'})

univariate_classification_lstm.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 120, 1)]          0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 120, 16)           1152
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 120, 32)           6272
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3840)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                245824
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# clf (Dense)                  (None, 1)                 65
# =================================================================
# Total params: 253,569
# Trainable params: 253,441
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
clf_history = utils.train_model(univariate_classification_lstm,
                                model_save_dir, train_clf_gen, test_clf_gen,
                                callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 0s - loss: 10.4559 - accuracy: 0.5000
# Epoch 00001: val_loss improved from inf to 8.96328, saving model to models\lstm2_univar\classification\01.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 10.4158 - accuracy: 0.5030 - val_loss: 8.9633 - val_accuracy: 0.4456
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.0370 - accuracy: 0.5192
# Epoch 00002: val_loss improved from 8.96328 to 6.91085, saving model to models\lstm2_univar\classification\02.hdf5
# 32/32 [==============================] - 32s 1000ms/step - loss: 8.0080 - accuracy: 0.5157 - val_loss: 6.9109 - val_accuracy: 0.4352
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.1850 - accuracy: 0.4990
# Epoch 00003: val_loss improved from 6.91085 to 5.38263, saving model to models\lstm2_univar\classification\03.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 6.1639 - accuracy: 0.4970 - val_loss: 5.3826 - val_accuracy: 0.4352
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.7970 - accuracy: 0.4940
# Epoch 00004: val_loss improved from 5.38263 to 4.21422, saving model to models\lstm2_univar\classification\04.hdf5
# 32/32 [==============================] - 32s 999ms/step - loss: 4.7794 - accuracy: 0.4951 - val_loss: 4.2142 - val_accuracy: 0.4352
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.0053 - accuracy: 0.5020
# Epoch 00005: val_loss improved from 4.21422 to 3.71284, saving model to models\lstm2_univar\classification\05.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 3.9987 - accuracy: 0.5020 - val_loss: 3.7128 - val_accuracy: 0.4352
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.5526 - accuracy: 0.5111
# Epoch 00006: val_loss improved from 3.71284 to 3.31086, saving model to models\lstm2_univar\classification\06.hdf5
# 32/32 [==============================] - 38s 1s/step - loss: 3.5443 - accuracy: 0.5118 - val_loss: 3.3109 - val_accuracy: 0.4352
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.2035 - accuracy: 0.5192
# Epoch 00007: val_loss improved from 3.31086 to 2.98177, saving model to models\lstm2_univar\classification\07.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 3.2018 - accuracy: 0.5167 - val_loss: 2.9818 - val_accuracy: 0.5648
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.9139 - accuracy: 0.5181
# Epoch 00008: val_loss improved from 2.98177 to 2.73097, saving model to models\lstm2_univar\classification\08.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 2.9097 - accuracy: 0.5207 - val_loss: 2.7310 - val_accuracy: 0.4482
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.6747 - accuracy: 0.4980
# Epoch 00009: val_loss improved from 2.73097 to 2.51639, saving model to models\lstm2_univar\classification\09.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 2.6674 - accuracy: 0.5020 - val_loss: 2.5164 - val_accuracy: 0.5648
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.5227 - accuracy: 0.5161
# Epoch 00010: val_loss improved from 2.51639 to 2.40985, saving model to models\lstm2_univar\classification\10.hdf5
# 32/32 [==============================] - 36s 1s/step - loss: 2.5214 - accuracy: 0.5157 - val_loss: 2.4098 - val_accuracy: 0.5648
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.4384 - accuracy: 0.4919
# Epoch 00011: val_loss improved from 2.40985 to 2.33122, saving model to models\lstm2_univar\classification\11.hdf5
# 32/32 [==============================] - 36s 1s/step - loss: 2.4374 - accuracy: 0.4921 - val_loss: 2.3312 - val_accuracy: 0.5648
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.3319 - accuracy: 0.5192
# Epoch 00012: val_loss improved from 2.33122 to 2.25466, saving model to models\lstm2_univar\classification\12.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 2.3311 - accuracy: 0.5177 - val_loss: 2.2547 - val_accuracy: 0.5518
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2937 - accuracy: 0.5020
# Epoch 00013: val_loss improved from 2.25466 to 2.19578, saving model to models\lstm2_univar\classification\13.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 2.2924 - accuracy: 0.5010 - val_loss: 2.1958 - val_accuracy: 0.4896
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2135 - accuracy: 0.4980
# Epoch 00014: val_loss improved from 2.19578 to 2.12951, saving model to models\lstm2_univar\classification\14.hdf5
# 32/32 [==============================] - 36s 1s/step - loss: 2.2127 - accuracy: 0.4990 - val_loss: 2.1295 - val_accuracy: 0.5466
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1478 - accuracy: 0.5202
# Epoch 00015: val_loss improved from 2.12951 to 2.09738, saving model to models\lstm2_univar\classification\15.hdf5
# 32/32 [==============================] - 36s 1s/step - loss: 2.1465 - accuracy: 0.5226 - val_loss: 2.0974 - val_accuracy: 0.5648
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1321 - accuracy: 0.5212
# Epoch 00016: val_loss improved from 2.09738 to 2.07019, saving model to models\lstm2_univar\classification\16.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 2.1298 - accuracy: 0.5226 - val_loss: 2.0702 - val_accuracy: 0.5648
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0907 - accuracy: 0.5181
# Epoch 00017: val_loss improved from 2.07019 to 2.06059, saving model to models\lstm2_univar\classification\17.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 2.0896 - accuracy: 0.5197 - val_loss: 2.0606 - val_accuracy: 0.4430
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0918 - accuracy: 0.4909
# Epoch 00018: val_loss improved from 2.06059 to 2.02988, saving model to models\lstm2_univar\classification\18.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 2.0921 - accuracy: 0.4892 - val_loss: 2.0299 - val_accuracy: 0.4637
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0574 - accuracy: 0.4808
# Epoch 00019: val_loss improved from 2.02988 to 2.00944, saving model to models\lstm2_univar\classification\19.hdf5
# 32/32 [==============================] - 36s 1s/step - loss: 2.0572 - accuracy: 0.4813 - val_loss: 2.0094 - val_accuracy: 0.4430
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0195 - accuracy: 0.5202
# Epoch 00020: val_loss improved from 2.00944 to 1.98303, saving model to models\lstm2_univar\classification\20.hdf5
# 32/32 [==============================] - 32s 1s/step - loss: 2.0202 - accuracy: 0.5226 - val_loss: 1.9830 - val_accuracy: 0.5363
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0186 - accuracy: 0.5030
# Epoch 00021: val_loss improved from 1.98303 to 1.96817, saving model to models\lstm2_univar\classification\21.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 2.0197 - accuracy: 0.5000 - val_loss: 1.9682 - val_accuracy: 0.5648
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9935 - accuracy: 0.5323
# Epoch 00022: val_loss improved from 1.96817 to 1.95698, saving model to models\lstm2_univar\classification\22.hdf5
# 32/32 [==============================] - 32s 1s/step - loss: 1.9911 - accuracy: 0.5344 - val_loss: 1.9570 - val_accuracy: 0.5440
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9795 - accuracy: 0.5151
# Epoch 00023: val_loss improved from 1.95698 to 1.94757, saving model to models\lstm2_univar\classification\23.hdf5
# 32/32 [==============================] - 32s 1s/step - loss: 1.9780 - accuracy: 0.5148 - val_loss: 1.9476 - val_accuracy: 0.5440
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9472 - accuracy: 0.5635
# Epoch 00024: val_loss improved from 1.94757 to 1.93723, saving model to models\lstm2_univar\classification\24.hdf5
# 32/32 [==============================] - 32s 1s/step - loss: 1.9505 - accuracy: 0.5610 - val_loss: 1.9372 - val_accuracy: 0.5389
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9646 - accuracy: 0.5272
# Epoch 00025: val_loss improved from 1.93723 to 1.92738, saving model to models\lstm2_univar\classification\25.hdf5
# 32/32 [==============================] - 32s 1s/step - loss: 1.9644 - accuracy: 0.5256 - val_loss: 1.9274 - val_accuracy: 0.5492
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9605 - accuracy: 0.5292
# Epoch 00026: val_loss improved from 1.92738 to 1.92219, saving model to models\lstm2_univar\classification\26.hdf5
# 32/32 [==============================] - 32s 1s/step - loss: 1.9613 - accuracy: 0.5266 - val_loss: 1.9222 - val_accuracy: 0.5415
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9593 - accuracy: 0.5252
# Epoch 00027: val_loss improved from 1.92219 to 1.91668, saving model to models\lstm2_univar\classification\27.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 1.9627 - accuracy: 0.5197 - val_loss: 1.9167 - val_accuracy: 0.5440
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9621 - accuracy: 0.5081
# Epoch 00028: val_loss improved from 1.91668 to 1.91241, saving model to models\lstm2_univar\classification\28.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 1.9587 - accuracy: 0.5118 - val_loss: 1.9124 - val_accuracy: 0.5648
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9383 - accuracy: 0.5302
# Epoch 00029: val_loss improved from 1.91241 to 1.90566, saving model to models\lstm2_univar\classification\29.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 1.9396 - accuracy: 0.5276 - val_loss: 1.9057 - val_accuracy: 0.5518
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9366 - accuracy: 0.5323
# Epoch 00030: val_loss improved from 1.90566 to 1.90269, saving model to models\lstm2_univar\classification\30.hdf5
# 32/32 [==============================] - 37s 1s/step - loss: 1.9375 - accuracy: 0.5315 - val_loss: 1.9027 - val_accuracy: 0.5415
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9520 - accuracy: 0.5141
# Epoch 00031: val_loss improved from 1.90269 to 1.90126, saving model to models\lstm2_univar\classification\31.hdf5
# 32/32 [==============================] - 38s 1s/step - loss: 1.9500 - accuracy: 0.5157 - val_loss: 1.9013 - val_accuracy: 0.5363
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 31/32 [============================>.] - ETA: 1s - loss: 1.9460 - accuracy: 0.4950
# Epoch 00032: val_loss improved from 1.90126 to 1.89721, saving model to models\lstm2_univar\classification\32.hdf5
# 32/32 [==============================] - 38s 1s/step - loss: 1.9478 - accuracy: 0.4921 - val_loss: 1.8972 - val_accuracy: 0.5466

# %%
def plot_clf_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'Loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'Accuracy', 'accuracy', 'val_accuracy')
    
plot_clf_history(clf_history);

# %% [markdown]
# ### Прогноз задачи классификации

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_classification_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %%
pred_direction_proba = univariate_classification_lstm.predict_generator(test_clf_gen, verbose=1)

true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 13/13 [==============================] - 6s 450ms/step
# 0.5564169

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([168, 218], dtype=int64)),
#  (array([0, 1]), array([177, 209], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.42      0.45      0.43       168
#            1       0.56      0.53      0.54       218
#
#     accuracy                           0.49       386
#    macro avg       0.49      0.49      0.49       386
# weighted avg       0.50      0.49      0.50       386

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[ 75,  93],
#        [102, 116]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.42372881, 0.44497608],
#        [0.57627119, 0.55502392]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# ## Многозадачная модель: одновременно регрессия и классификация

# %%
model_class_name = 'multitask'

# %%
train_multi_gen = MultitaskGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_multi_gen = MultitaskGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_multi_gen = MultitaskGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_multitask_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=(16, 32))

    # первый выход: задача регрссии
    regr = Dense(64)(lstm)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    # второй выход: задача классификации
    clf = Dense(64)(lstm)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)
    
    return Model(inputs=[inp], outputs=[regr, clf])

# %%
univariate_multitask_lstm = build_multitask_model(train_multi_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
univariate_multitask_lstm.compile(optimizer=optimizer,
                                  loss={'regr': 'mse', 'clf': 'binary_crossentropy'},
                                  loss_weights={'regr': 2., 'clf': 1.},
                                  metrics={'regr': 'mae', 'clf' : 'accuracy'})

univariate_multitask_lstm.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 120, 1)]     0
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 120, 16)      1152        input[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 120, 32)      6272        lstm_4[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 3840)         0           lstm_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           245824      flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           245824      flatten_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64)           256         dense_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64)           256         dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 64)           0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 64)           0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64)           0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64)           0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# regr (Dense)                    (None, 1)            65          dropout_2[0][0]
# __________________________________________________________________________________________________
# clf (Dense)                     (None, 1)            65          dropout_3[0][0]
# ==================================================================================================
# Total params: 499,714
# Trainable params: 499,458
# Non-trainable params: 256
# __________________________________________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
multitask_history = utils.train_model(univariate_multitask_lstm,
                                      model_save_dir, train_multi_gen, test_multi_gen,
                                      callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                      force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 0s - loss: 15.7686 - regr_loss: 2.2818 - clf_loss: 0.9752 - regr_mae: 1.1795 - clf_accuracy: 0.5071
# Epoch 00001: val_loss improved from inf to 13.21299, saving model to models\lstm2_univar\multitask\01.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 15.7010 - regr_loss: 2.2574 - clf_loss: 0.9710 - regr_mae: 1.1731 - clf_accuracy: 0.5069 - val_loss: 13.2130 - val_regr_loss: 1.4030 - val_clf_loss: 0.6937 - val_regr_mae: 0.6251 - val_clf_accuracy: 0.5207
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 0s - loss: 13.8773 - regr_loss: 1.9078 - clf_loss: 0.8489 - regr_mae: 1.0598 - clf_accuracy: 0.5081
# Epoch 00002: val_loss did not improve from 13.21299
# 32/32 [==============================] - 33s 1s/step - loss: 13.8470 - regr_loss: 1.8971 - clf_loss: 0.8565 - regr_mae: 1.0565 - clf_accuracy: 0.5069 - val_loss: 13.5589 - val_regr_loss: 2.0101 - val_clf_loss: 0.8878 - val_regr_mae: 0.9012 - val_clf_accuracy: 0.4352
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 12.6893 - regr_loss: 1.8246 - clf_loss: 0.8591 - regr_mae: 1.0371 - clf_accuracy: 0.4960
# Epoch 00003: val_loss improved from 13.21299 to 11.18333, saving model to models\lstm2_univar\multitask\03.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 12.6243 - regr_loss: 1.8003 - clf_loss: 0.8574 - regr_mae: 1.0321 - clf_accuracy: 0.4970 - val_loss: 11.1833 - val_regr_loss: 1.4153 - val_clf_loss: 0.6902 - val_regr_mae: 0.6268 - val_clf_accuracy: 0.5648
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 11.2924 - regr_loss: 1.6143 - clf_loss: 0.8236 - regr_mae: 0.9752 - clf_accuracy: 0.5040
# Epoch 00004: val_loss did not improve from 11.18333
# 32/32 [==============================] - 33s 1s/step - loss: 11.2807 - regr_loss: 1.6137 - clf_loss: 0.8267 - regr_mae: 0.9741 - clf_accuracy: 0.5020 - val_loss: 11.6804 - val_regr_loss: 1.9714 - val_clf_loss: 0.9606 - val_regr_mae: 0.9596 - val_clf_accuracy: 0.5648
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 10.4596 - regr_loss: 1.5514 - clf_loss: 0.7764 - regr_mae: 0.9559 - clf_accuracy: 0.5373
# Epoch 00005: val_loss improved from 11.18333 to 9.95933, saving model to models\lstm2_univar\multitask\05.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 10.4678 - regr_loss: 1.5580 - clf_loss: 0.7778 - regr_mae: 0.9574 - clf_accuracy: 0.5344 - val_loss: 9.9593 - val_regr_loss: 1.4090 - val_clf_loss: 0.7760 - val_regr_mae: 0.6249 - val_clf_accuracy: 0.5648
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 9.8407 - regr_loss: 1.4409 - clf_loss: 0.7789 - regr_mae: 0.9285 - clf_accuracy: 0.5020
# Epoch 00006: val_loss improved from 9.95933 to 9.52898, saving model to models\lstm2_univar\multitask\06.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 9.8298 - regr_loss: 1.4406 - clf_loss: 0.7745 - regr_mae: 0.9291 - clf_accuracy: 0.5049 - val_loss: 9.5290 - val_regr_loss: 1.4271 - val_clf_loss: 0.6990 - val_regr_mae: 0.6317 - val_clf_accuracy: 0.5648
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 9.4948 - regr_loss: 1.4626 - clf_loss: 0.7682 - regr_mae: 0.9232 - clf_accuracy: 0.5252
# Epoch 00007: val_loss improved from 9.52898 to 9.13900, saving model to models\lstm2_univar\multitask\07.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 9.4693 - regr_loss: 1.4544 - clf_loss: 0.7645 - regr_mae: 0.9228 - clf_accuracy: 0.5295 - val_loss: 9.1390 - val_regr_loss: 1.4100 - val_clf_loss: 0.7083 - val_regr_mae: 0.6270 - val_clf_accuracy: 0.4430
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 9.0896 - regr_loss: 1.4320 - clf_loss: 0.7758 - regr_mae: 0.9075 - clf_accuracy: 0.5101
# Epoch 00008: val_loss did not improve from 9.13900
# 32/32 [==============================] - 33s 1s/step - loss: 9.0709 - regr_loss: 1.4262 - clf_loss: 0.7739 - regr_mae: 0.9072 - clf_accuracy: 0.5108 - val_loss: 9.7302 - val_regr_loss: 1.6372 - val_clf_loss: 1.1842 - val_regr_mae: 0.7242 - val_clf_accuracy: 0.4352
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.5991 - regr_loss: 1.3354 - clf_loss: 0.8056 - regr_mae: 0.8827 - clf_accuracy: 0.4829
# Epoch 00009: val_loss improved from 9.13900 to 8.74288, saving model to models\lstm2_univar\multitask\09.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 8.5554 - regr_loss: 1.3163 - clf_loss: 0.8046 - regr_mae: 0.8774 - clf_accuracy: 0.4852 - val_loss: 8.7429 - val_regr_loss: 1.5338 - val_clf_loss: 0.7175 - val_regr_mae: 0.6759 - val_clf_accuracy: 0.4404
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.5369 - regr_loss: 1.4265 - clf_loss: 0.7979 - regr_mae: 0.9058 - clf_accuracy: 0.4889
# Epoch 00010: val_loss improved from 8.74288 to 8.48435, saving model to models\lstm2_univar\multitask\10.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 8.5241 - regr_loss: 1.4218 - clf_loss: 0.7967 - regr_mae: 0.9058 - clf_accuracy: 0.4872 - val_loss: 8.4844 - val_regr_loss: 1.4788 - val_clf_loss: 0.7184 - val_regr_mae: 0.6526 - val_clf_accuracy: 0.4404
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.1691 - regr_loss: 1.3275 - clf_loss: 0.7745 - regr_mae: 0.8608 - clf_accuracy: 0.4909
# Epoch 00011: val_loss improved from 8.48435 to 8.43969, saving model to models\lstm2_univar\multitask\11.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 8.1910 - regr_loss: 1.3409 - clf_loss: 0.7720 - regr_mae: 0.8655 - clf_accuracy: 0.4921 - val_loss: 8.4397 - val_regr_loss: 1.5160 - val_clf_loss: 0.7428 - val_regr_mae: 0.6678 - val_clf_accuracy: 0.4352
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 1s - loss: 8.0590 - regr_loss: 1.3523 - clf_loss: 0.7558 - regr_mae: 0.8778 - clf_accuracy: 0.5292
# Epoch 00012: val_loss did not improve from 8.43969
# 32/32 [==============================] - 42s 1s/step - loss: 8.0253 - regr_loss: 1.3354 - clf_loss: 0.7577 - regr_mae: 0.8742 - clf_accuracy: 0.5266 - val_loss: 8.5370 - val_regr_loss: 1.6261 - val_clf_loss: 0.7598 - val_regr_mae: 0.7183 - val_clf_accuracy: 0.4352
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 1s - loss: 7.7659 - regr_loss: 1.2668 - clf_loss: 0.7707 - regr_mae: 0.8625 - clf_accuracy: 0.4748
# Epoch 00013: val_loss improved from 8.43969 to 8.07863, saving model to models\lstm2_univar\multitask\13.hdf5
# 32/32 [==============================] - 38s 1s/step - loss: 7.8330 - regr_loss: 1.3004 - clf_loss: 0.7731 - regr_mae: 0.8642 - clf_accuracy: 0.4705 - val_loss: 8.0786 - val_regr_loss: 1.4939 - val_clf_loss: 0.6988 - val_regr_mae: 0.6578 - val_clf_accuracy: 0.4767
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.7224 - regr_loss: 1.3183 - clf_loss: 0.7548 - regr_mae: 0.8675 - clf_accuracy: 0.5202
# Epoch 00014: val_loss improved from 8.07863 to 7.88526, saving model to models\lstm2_univar\multitask\14.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 7.6876 - regr_loss: 1.2992 - clf_loss: 0.7598 - regr_mae: 0.8626 - clf_accuracy: 0.5157 - val_loss: 7.8853 - val_regr_loss: 1.4383 - val_clf_loss: 0.7449 - val_regr_mae: 0.6325 - val_clf_accuracy: 0.4352
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.6952 - regr_loss: 1.3508 - clf_loss: 0.7611 - regr_mae: 0.8796 - clf_accuracy: 0.5121
# Epoch 00015: val_loss improved from 7.88526 to 7.82224, saving model to models\lstm2_univar\multitask\15.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 7.6925 - regr_loss: 1.3500 - clf_loss: 0.7610 - regr_mae: 0.8792 - clf_accuracy: 0.5128 - val_loss: 7.8222 - val_regr_loss: 1.4423 - val_clf_loss: 0.7389 - val_regr_mae: 0.6334 - val_clf_accuracy: 0.4404
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.4721 - regr_loss: 1.2620 - clf_loss: 0.7787 - regr_mae: 0.8539 - clf_accuracy: 0.5030
# Epoch 00016: val_loss improved from 7.82224 to 7.66800, saving model to models\lstm2_univar\multitask\16.hdf5
# 32/32 [==============================] - 37s 1s/step - loss: 7.4461 - regr_loss: 1.2489 - clf_loss: 0.7797 - regr_mae: 0.8523 - clf_accuracy: 0.5030 - val_loss: 7.6680 - val_regr_loss: 1.4200 - val_clf_loss: 0.6920 - val_regr_mae: 0.6249 - val_clf_accuracy: 0.5544
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.4161 - regr_loss: 1.2702 - clf_loss: 0.7689 - regr_mae: 0.8530 - clf_accuracy: 0.4778
# Epoch 00017: val_loss improved from 7.66800 to 7.59679, saving model to models\lstm2_univar\multitask\17.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 7.4238 - regr_loss: 1.2735 - clf_loss: 0.7709 - regr_mae: 0.8536 - clf_accuracy: 0.4764 - val_loss: 7.5968 - val_regr_loss: 1.4168 - val_clf_loss: 0.6890 - val_regr_mae: 0.6272 - val_clf_accuracy: 0.5596
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.3533 - regr_loss: 1.2731 - clf_loss: 0.7616 - regr_mae: 0.8517 - clf_accuracy: 0.4909
# Epoch 00018: val_loss did not improve from 7.59679
# 32/32 [==============================] - 35s 1s/step - loss: 7.3526 - regr_loss: 1.2732 - clf_loss: 0.7615 - regr_mae: 0.8514 - clf_accuracy: 0.4911 - val_loss: 7.6618 - val_regr_loss: 1.4447 - val_clf_loss: 0.7587 - val_regr_mae: 0.6345 - val_clf_accuracy: 0.4352
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.3100 - regr_loss: 1.2836 - clf_loss: 0.7576 - regr_mae: 0.8645 - clf_accuracy: 0.5252
# Epoch 00019: val_loss improved from 7.59679 to 7.57357, saving model to models\lstm2_univar\multitask\19.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 7.2700 - regr_loss: 1.2657 - clf_loss: 0.7540 - regr_mae: 0.8596 - clf_accuracy: 0.5276 - val_loss: 7.5736 - val_regr_loss: 1.4332 - val_clf_loss: 0.7536 - val_regr_mae: 0.6298 - val_clf_accuracy: 0.4352
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.1796 - regr_loss: 1.2343 - clf_loss: 0.7721 - regr_mae: 0.8376 - clf_accuracy: 0.5020
# Epoch 00020: val_loss improved from 7.57357 to 7.51242, saving model to models\lstm2_univar\multitask\20.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 7.1661 - regr_loss: 1.2264 - clf_loss: 0.7748 - regr_mae: 0.8360 - clf_accuracy: 0.5000 - val_loss: 7.5124 - val_regr_loss: 1.4279 - val_clf_loss: 0.7336 - val_regr_mae: 0.6277 - val_clf_accuracy: 0.4404
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.2559 - regr_loss: 1.2884 - clf_loss: 0.7700 - regr_mae: 0.8673 - clf_accuracy: 0.5121
# Epoch 00021: val_loss improved from 7.51242 to 7.46511, saving model to models\lstm2_univar\multitask\21.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 7.2472 - regr_loss: 1.2840 - clf_loss: 0.7706 - regr_mae: 0.8657 - clf_accuracy: 0.5108 - val_loss: 7.4651 - val_regr_loss: 1.4341 - val_clf_loss: 0.7037 - val_regr_mae: 0.6303 - val_clf_accuracy: 0.4585
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.1032 - regr_loss: 1.2399 - clf_loss: 0.7439 - regr_mae: 0.8303 - clf_accuracy: 0.5131
# Epoch 00022: val_loss did not improve from 7.46511
# 32/32 [==============================] - 36s 1s/step - loss: 7.1193 - regr_loss: 1.2487 - clf_loss: 0.7430 - regr_mae: 0.8338 - clf_accuracy: 0.5128 - val_loss: 7.4956 - val_regr_loss: 1.4558 - val_clf_loss: 0.7201 - val_regr_mae: 0.6393 - val_clf_accuracy: 0.4430
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.0987 - regr_loss: 1.2528 - clf_loss: 0.7433 - regr_mae: 0.8432 - clf_accuracy: 0.5232
# Epoch 00023: val_loss improved from 7.46511 to 7.41772, saving model to models\lstm2_univar\multitask\23.hdf5
# 32/32 [==============================] - 38s 1s/step - loss: 7.0847 - regr_loss: 1.2436 - clf_loss: 0.7481 - regr_mae: 0.8419 - clf_accuracy: 0.5197 - val_loss: 7.4177 - val_regr_loss: 1.4402 - val_clf_loss: 0.7033 - val_regr_mae: 0.6319 - val_clf_accuracy: 0.4793
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.9114 - regr_loss: 1.1695 - clf_loss: 0.7526 - regr_mae: 0.8183 - clf_accuracy: 0.5101
# Epoch 00024: val_loss improved from 7.41772 to 7.34969, saving model to models\lstm2_univar\multitask\24.hdf5
# 32/32 [==============================] - 39s 1s/step - loss: 6.9232 - regr_loss: 1.1758 - clf_loss: 0.7523 - regr_mae: 0.8208 - clf_accuracy: 0.5098 - val_loss: 7.3497 - val_regr_loss: 1.4194 - val_clf_loss: 0.7067 - val_regr_mae: 0.6239 - val_clf_accuracy: 0.4534
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.0206 - regr_loss: 1.2367 - clf_loss: 0.7506 - regr_mae: 0.8434 - clf_accuracy: 0.5161
# Epoch 00025: val_loss did not improve from 7.34969
# 32/32 [==============================] - 37s 1s/step - loss: 7.0136 - regr_loss: 1.2334 - clf_loss: 0.7504 - regr_mae: 0.8429 - clf_accuracy: 0.5148 - val_loss: 7.4263 - val_regr_loss: 1.4544 - val_clf_loss: 0.7288 - val_regr_mae: 0.6390 - val_clf_accuracy: 0.4378
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.0720 - regr_loss: 1.2763 - clf_loss: 0.7377 - regr_mae: 0.8532 - clf_accuracy: 0.5141
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00026: val_loss did not improve from 7.34969
# 32/32 [==============================] - 36s 1s/step - loss: 7.0304 - regr_loss: 1.2546 - clf_loss: 0.7394 - regr_mae: 0.8487 - clf_accuracy: 0.5128 - val_loss: 7.3777 - val_regr_loss: 1.4382 - val_clf_loss: 0.7276 - val_regr_mae: 0.6321 - val_clf_accuracy: 0.4430
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 9.999999747378752e-06.
# Epoch 27/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.8758 - regr_loss: 1.1841 - clf_loss: 0.7364 - regr_mae: 0.8226 - clf_accuracy: 0.5272
# Epoch 00027: val_loss did not improve from 7.34969
# 32/32 [==============================] - 38s 1s/step - loss: 6.8599 - regr_loss: 1.1750 - clf_loss: 0.7387 - regr_mae: 0.8201 - clf_accuracy: 0.5266 - val_loss: 7.3615 - val_regr_loss: 1.4353 - val_clf_loss: 0.7222 - val_regr_mae: 0.6308 - val_clf_accuracy: 0.4430
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 9.999999747378752e-06.
# Epoch 28/32
# 31/32 [============================>.] - ETA: 1s - loss: 7.0588 - regr_loss: 1.2702 - clf_loss: 0.7519 - regr_mae: 0.8549 - clf_accuracy: 0.5091
# Epoch 00028: val_loss did not improve from 7.34969
# 32/32 [==============================] - 39s 1s/step - loss: 7.0318 - regr_loss: 1.2583 - clf_loss: 0.7487 - regr_mae: 0.8518 - clf_accuracy: 0.5108 - val_loss: 7.3528 - val_regr_loss: 1.4358 - val_clf_loss: 0.7173 - val_regr_mae: 0.6312 - val_clf_accuracy: 0.4352
# Epoch 00029: LearningRateScheduler reducing learning rate to 9.999999747378752e-06.
# Epoch 29/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.9225 - regr_loss: 1.2238 - clf_loss: 0.7133 - regr_mae: 0.8459 - clf_accuracy: 0.5534
# Epoch 00029: val_loss improved from 7.34969 to 7.34939, saving model to models\lstm2_univar\multitask\29.hdf5
# 32/32 [==============================] - 40s 1s/step - loss: 6.9198 - regr_loss: 1.2228 - clf_loss: 0.7128 - regr_mae: 0.8478 - clf_accuracy: 0.5512 - val_loss: 7.3494 - val_regr_loss: 1.4386 - val_clf_loss: 0.7132 - val_regr_mae: 0.6326 - val_clf_accuracy: 0.4378
# Epoch 00029: early stopping

# %%
def plot_multitask_history(hist):
    fig, ax = plt.subplots(2, 2, figsize=(16, 12))
    plotHelpers.plot_train_history(ax[0, 0], hist, 'Total loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[0, 1], hist, 'Accuracy', 'clf_accuracy', 'val_clf_accuracy')
    plotHelpers.plot_train_history(ax[1, 0], hist, 'MSE', 'regr_loss', 'val_regr_loss')
    plotHelpers.plot_train_history(ax[1, 1], hist, 'MAE', 'regr_mae', 'val_regr_mae')
    
plot_multitask_history(multitask_history);

# %% [markdown]
# ### Прогноз

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_multitask_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret, pred_direction_proba = univariate_multitask_lstm.predict_generator(test_multi_gen, verbose=1)
# Out:
# 13/13 [==============================] - 7s 543ms/step

# %%
np.set_printoptions(precision=3, suppress=True)

np.column_stack([pred_log_ret, pred_direction_proba])[-10:]
# Out:
# array([[ 0.062,  0.469],
#        [ 0.077,  0.472],
#        [ 0.088,  0.478],
#        [ 0.087,  0.48 ],
#        [ 0.082,  0.478],
#        [ 0.071,  0.465],
#        [ 0.056,  0.457],
#        [ 0.036,  0.446],
#        [ 0.016,  0.437],
#        [-0.002,  0.43 ]], dtype=float32)

# %% [markdown]
# #### Прогноз задачи регрессии

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret, figsize=(16, 10),
                                  datetime_unit='m', plot_data_slice=slice(1, None))

# %% [markdown]
# #### Прогноз задачи классификации

# %%
true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 0.44975618

# %%
true_direction = test_multi_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([168, 218], dtype=int64)),
#  (array([0, 1]), array([201, 185], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.45      0.54      0.49       168
#            1       0.58      0.49      0.53       218
#
#     accuracy                           0.51       386
#    macro avg       0.51      0.51      0.51       386
# weighted avg       0.52      0.51      0.51       386

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[ 90,  78],
#        [111, 107]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.448, 0.422],
#        [0.552, 0.578]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# # Выводы
#
# 1.  Размер батча влияет на скорость обучения.
# 2.  Инициализация весов (`bias_initializer`) в слое **LSTM** оказалась очень важным параметром.
# 3.  Модель регрессии просто выходит на модель случайного блуждания.
# 4.  Модель классификации получились слабая.
# 5.  Комбинированная модель не улучшила качество.
# 6.  В целом добавление второго слоя не принесло улучшения качества по сравнению с однослойной одномерной моделью.

# %% [markdown]
# # *Одномерная модель на LSTM* (2 слоя)
#
# В качестве единственного признака используется сама цена.

# %%
import os
import glob
import datetime
import pickle

import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from pandas_datareader import data as pdr

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
import tensorflow as tf
# tf.test.is_gpu_available()
tf.__version__
# Out:
# '2.0.0'

# %%
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Input, Dense, LSTM, GRU, Flatten, ReLU, LeakyReLU, Dropout, BatchNormalization
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers import Nadam

# %%
from mdp import TimeSeries
from mdp import MarketData
from mdp import MovingWindowFeatures
from mdp import ClassificationGenerator, RegressionGenerator, MultitaskGenerator
from mdp import invert_log_ret

import mdp.utils as utils
import mdp.plotHelpers as plotHelpers

# %%
import importlib

import mdp

importlib.reload(mdp)
importlib.reload(mdp.datasetGenerator)
importlib.reload(mdp.marketData)
importlib.reload(mdp.movingWindowFeatures)
importlib.reload(mdp.timeSeries)
importlib.reload(mdp.plotHelpers)
importlib.reload(mdp.utils);

# %% [markdown]
# # *Параметры*

# %%
INSTRUMENT = 'MSFT' # Microsoft corp
START_FROM = np.datetime64('today') - 7
WINDOW_SIZE = 120
FORECAST_OFFSET=1
BATCH_SIZE = 32
FORCE_TRAIN = True

# %% [markdown]
# # *Исходные данные*
#
# Загрузка данных и вычисление индикаторов.

# %%
instr = MarketData.create_from_alphavantage_intraday(INSTRUMENT, start=START_FROM)

# %%
instr.feature_names
# Out:
# ['o',
#  'h',
#  'l',
#  'c',
#  'v',
#  'ema14',
#  'ema30',
#  'macd',
#  'macd_signal',
#  'rsi14',
#  'bband20_upper',
#  'bband20_middle',
#  'bband20_lower',
#  'willr14',
#  'stochk',
#  'stochd',
#  'adline',
#  'adosc']

# %% [markdown]
# Здесь не будем делить отдельно на тест и валидацию, поскольку данных у нас только 5 дней.

# %%
dates_unique = np.unique(instr.timestamps.astype('datetime64[D]'))

START_FROM = dates_unique[0]
VAL_TEST_SPLIT = dates_unique[-1]

START_FROM, VAL_TEST_SPLIT
# Out:
# (numpy.datetime64('2020-04-09'), numpy.datetime64('2020-04-15'))

# %% [markdown]
# ## Целевая переменная

# %% [markdown]
# Цена закрытия.

# %%
orig_target = instr.c

# %% [markdown]
# Переходим к логарифмической доходности.

# %%
transformed_target = instr.c.transform(transforms={'ratios' : {}, 'ln' : {}})

# %%
plotHelpers.plot_transformed_timeseries_unit(instr,
                                             transformed_target,
                                             'Close price, USD', 'Log return',
                                             datetime_unit='m', rotation=45)

# %% [markdown]
# ## Трансформация признаков
#
# Из признаков выбираем только цену закрытия. Временной ряд цен преобразуется к ряду логарифмических доходностей (что также позволяет убрать нестационарность).

# %%
def make_feature_selector():
    price_transformer = lambda: {'ratios': {}, 'ln': {}}
    diff_transformer = lambda o: {'diffs': {'order': o}}
    identity_transformer = lambda: {}
    feature_transformations = {
        'c': price_transformer(),
    }
    return feature_transformations

# %%
instr_transformed = instr.select_transform(make_feature_selector())

# %%
transformed_target = instr_transformed.c

# %% [markdown]
# ## Обучающая, валидационная и тестовая выборки

# %%
instr_train, instr_test = instr_transformed.train_test_split(VAL_TEST_SPLIT, window_size=WINDOW_SIZE,
                                                             scaler=StandardScaler)
#                                                              scaler=MinMaxScaler,
#                                                              scaler_kwargs={'feature_range': (-1, 1)})

# instr_val, instr_test = instr_val_test.train_test_split(TEST_SPLIT, window_size=WINDOW_SIZE, scaler=None)

len(instr_train), len(instr_test)
# Out:
# (1132, 509)

# %% [markdown]
# ## Признаки - скользящие окна

# %%
train_mwf = MovingWindowFeatures.create(instr_train.c, [instr_train], instr_train.feature_names, window_size=WINDOW_SIZE)
# val_mwf = MovingWindowFeatures.create(instr_val.c, [instr_val], instr_val.feature_names, window_size=WINDOW_SIZE)
test_mwf = MovingWindowFeatures.create(instr_test.c, [instr_test], instr_test.feature_names, window_size=WINDOW_SIZE)

len(instr_train), len(train_mwf), train_mwf.features.shape
# Out:
# (1132, 1012, (1012, 120, 1))

# %% [markdown]
# Проверка, что скользящие окна соответствуют исходным данным.
#
# Возьмём произвольный признак и произвольное окно (строка #**41**). Проверим, что данные в точности совпадают:

# %%
def check_data(md, mwf, row):
    col = np.random.randint(len(mwf.feature_names))
    feature = mwf.feature_names[col]
    check = (getattr(md, feature).data[row:row + mwf.window_size] == mwf.features[row, :, col]).all()
    assert check
    return feature, check

check_data(instr_train, train_mwf, 41)
# Out:
# ('c', True)

# %% [markdown]
# # *Модели*

# %% [markdown]
# Модель с двумя LSTM слоями.

# %%
def build_lstm_layers(input_shape, latent_dim=(8, 16)):
    # формат входа: наша матрица (окно; признак)
    inp = Input(input_shape, name='input')

    # стекаем два уровня LSTM
    lstm = LSTM(latent_dim[0], return_sequences=True, 
                    recurrent_dropout=0.2, dropout=0.2, 
                    bias_initializer='he_uniform',
                    bias_regularizer=L1L2(0.01, 0.02),
                    kernel_regularizer=L1L2(0.01, 0.02),
                    recurrent_regularizer=L1L2(0.02, 0.02)
               )(inp)

    lstm = LSTM(latent_dim[1], return_sequences=True,
                    recurrent_dropout=0.2, dropout=0.2,
                    bias_initializer='he_uniform',
                    bias_regularizer=L1L2(0.01, 0.02),
                    kernel_regularizer=L1L2(0.01, 0.02),
                    recurrent_regularizer=L1L2(0.01, 0.02)
               )(lstm)
    
    lstm = Flatten()(lstm)
    
    return inp, lstm

# %% [markdown]
# #### Пути сохранения моделей:

# %%
model_path_root = 'models'
model_type_name = 'lstm2_univar'

def make_model_save_dir(path_root, type_name, class_name):
    save_dir = os.path.join(path_root, type_name, class_name)
    os.makedirs(save_dir, exist_ok=True)
    return save_dir

# %% [markdown]
# #### Общие коллбэки:

# %%
# уменьшение learning rate в случае, если loss не изменяется
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001, verbose=1)

# уменьшение learning rate в 2 раза каждую 5-ю эпоху
def lr_decay(e, lr):
    return lr * (1 - 0.5 * (0 == (e + 1) % 5))

lr_scheduler = LearningRateScheduler(schedule=lr_decay, verbose=1)

# %% [markdown]
# ## Задача регрессии
#
# Непосредственное прогнозирование цены следующего периода.

# %%
train_regr_gen = RegressionGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_regr_gen = RegressionGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_regr_gen = RegressionGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# Следующие числа соответствуют значению параметра `steps_per_epoch` метода [`fit_generator`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit_generator "tf.keras.layers.SimpleRNN &nbsp;|&nbsp; TensorFlow Core r2.0") - то есть это число батчей, которые генератор выдаст за одну эпоху обучения (если класс генератора поддерживает метод `len()`, то данный параметр можно не указывать).

# %%
len(train_regr_gen), (test_regr_gen)
# Out:
# (32, <mdp.datasetGenerator.RegressionGenerator at 0x1e5d8612888>)

# %% [markdown]
# Один сэмпл данных представляет собой матрицу размером *(длина окна; число признаков)*

# %%
train_regr_gen.input_shape
# Out:
# (120, 1)

# %% [markdown]
# ### Модель для задачи регрессии

# %%
model_class_name = 'regression'

# %%
def build_regression_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=(16, 32))

    regr = Dense(64)(lstm)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    return Model(inputs=[inp], outputs=[regr])

# %%
univariate_regression_lstm = build_regression_model(train_regr_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:
# [`Nadam`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Nadam) (*Adam with Nestrov momentum*).

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Функция потерь:
#
# В качестве функции потерь будем использовать [MSE](https://www.tensorflow.org/api_docs/python/tf/keras/losses/MSE) (чтобы штрафовать за большие отклонения). Xотя хорошая функция потерь в контексте темы данной задачи - это [вопрос сложный](https://github.com/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Chapter5_LossFunctions/Ch5_LossFunctions_PyMC3.ipynb). В частности, здесь нам, очевидно, помимо абсолютного значения отклонения также важен его знак.

# %%
univariate_regression_lstm.compile(optimizer=optimizer,
                                   loss={'regr': 'mse'},
                                   metrics={'regr': 'mae'})

univariate_regression_lstm.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 120, 1)]          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 120, 16)           1152
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 120, 32)           6272
# _________________________________________________________________
# flatten (Flatten)            (None, 3840)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                245824
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64)                256
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 64)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# regr (Dense)                 (None, 1)                 65
# =================================================================
# Total params: 253,569
# Trainable params: 253,441
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# #### Обучение:

# %%
regr_history = utils.train_model(univariate_regression_lstm,
                                 model_save_dir, train_regr_gen, test_regr_gen,
                                 callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                 force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 0s - loss: 12.8545 - mae: 1.2176
# Epoch 00001: val_loss improved from inf to 10.59954, saving model to models\lstm2_univar\regression\01.hdf5
# 32/32 [==============================] - 38s 1s/step - loss: 12.7912 - mae: 1.2114 - val_loss: 10.5995 - val_mae: 0.6971
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 0s - loss: 10.8271 - mae: 1.0400
# Epoch 00002: val_loss improved from 10.59954 to 9.17861, saving model to models\lstm2_univar\regression\02.hdf5
# 32/32 [==============================] - 37s 1s/step - loss: 10.7821 - mae: 1.0377 - val_loss: 9.1786 - val_mae: 0.6562
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 9.5791 - mae: 1.0040
# Epoch 00003: val_loss improved from 9.17861 to 8.07466, saving model to models\lstm2_univar\regression\03.hdf5
# 32/32 [==============================] - 36s 1s/step - loss: 9.5413 - mae: 1.0020 - val_loss: 8.0747 - val_mae: 0.6889
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.2907 - mae: 0.9521
# Epoch 00004: val_loss improved from 8.07466 to 7.01579, saving model to models\lstm2_univar\regression\04.hdf5
# 32/32 [==============================] - 36s 1s/step - loss: 8.2453 - mae: 0.9484 - val_loss: 7.0158 - val_mae: 0.6557
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.4080 - mae: 0.9052
# Epoch 00005: val_loss improved from 7.01579 to 6.77551, saving model to models\lstm2_univar\regression\05.hdf5
# 32/32 [==============================] - 36s 1s/step - loss: 7.3903 - mae: 0.9054 - val_loss: 6.7755 - val_mae: 0.7519
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.8909 - mae: 0.8843
# Epoch 00006: val_loss improved from 6.77551 to 6.20276, saving model to models\lstm2_univar\regression\06.hdf5
# 32/32 [==============================] - 37s 1s/step - loss: 6.8828 - mae: 0.8853 - val_loss: 6.2028 - val_mae: 0.6722
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.4652 - mae: 0.8589
# Epoch 00007: val_loss improved from 6.20276 to 5.98225, saving model to models\lstm2_univar\regression\07.hdf5
# 32/32 [==============================] - 37s 1s/step - loss: 6.4492 - mae: 0.8598 - val_loss: 5.9823 - val_mae: 0.7539
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.0776 - mae: 0.8711
# Epoch 00008: val_loss improved from 5.98225 to 5.73285, saving model to models\lstm2_univar\regression\08.hdf5
# 32/32 [==============================] - 36s 1s/step - loss: 6.0407 - mae: 0.8655 - val_loss: 5.7328 - val_mae: 0.7848
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.6629 - mae: 0.8217
# Epoch 00009: val_loss improved from 5.73285 to 5.16873, saving model to models\lstm2_univar\regression\09.hdf5
# 32/32 [==============================] - 38s 1s/step - loss: 5.6279 - mae: 0.8165 - val_loss: 5.1687 - val_mae: 0.6612
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.5610 - mae: 0.8579
# Epoch 00010: val_loss did not improve from 5.16873
# 32/32 [==============================] - 38s 1s/step - loss: 5.5592 - mae: 0.8614 - val_loss: 5.4196 - val_mae: 0.8640
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.2631 - mae: 0.8164
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 5.0000002374872565e-05.
#
# Epoch 00011: val_loss did not improve from 5.16873
# 32/32 [==============================] - 35s 1s/step - loss: 5.2440 - mae: 0.8147 - val_loss: 5.3376 - val_mae: 0.8888
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 5.0000002374872565e-05.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.1841 - mae: 0.8198
# Epoch 00012: val_loss improved from 5.16873 to 5.10979, saving model to models\lstm2_univar\regression\12.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 5.1644 - mae: 0.8173 - val_loss: 5.1098 - val_mae: 0.7906
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 5.0000002374872565e-05.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.1565 - mae: 0.7984
# Epoch 00013: val_loss improved from 5.10979 to 4.82760, saving model to models\lstm2_univar\regression\13.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 5.1428 - mae: 0.7971 - val_loss: 4.8276 - val_mae: 0.6585
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 5.0000002374872565e-05.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.0998 - mae: 0.8018
# Epoch 00014: val_loss improved from 4.82760 to 4.79910, saving model to models\lstm2_univar\regression\14.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 5.0949 - mae: 0.8026 - val_loss: 4.7991 - val_mae: 0.6575
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.1743 - mae: 0.8384
# Epoch 00015: val_loss did not improve from 4.79910
# 32/32 [==============================] - 35s 1s/step - loss: 5.1521 - mae: 0.8366 - val_loss: 4.8004 - val_mae: 0.6643
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.0610 - mae: 0.7915
# Epoch 00016: val_loss improved from 4.79910 to 4.79430, saving model to models\lstm2_univar\regression\16.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 5.0439 - mae: 0.7905 - val_loss: 4.7943 - val_mae: 0.6679
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.9915 - mae: 0.7929
# Epoch 00017: val_loss improved from 4.79430 to 4.77052, saving model to models\lstm2_univar\regression\17.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 4.9787 - mae: 0.7914 - val_loss: 4.7705 - val_mae: 0.6640
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.9450 - mae: 0.7596
# Epoch 00018: val_loss did not improve from 4.77052
# 32/32 [==============================] - 34s 1s/step - loss: 4.9314 - mae: 0.7584 - val_loss: 4.7739 - val_mae: 0.6724
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.0082 - mae: 0.8028
# Epoch 00019: val_loss improved from 4.77052 to 4.73466, saving model to models\lstm2_univar\regression\19.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 4.9909 - mae: 0.8003 - val_loss: 4.7347 - val_mae: 0.6610
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.0632 - mae: 0.8089
# Epoch 00020: val_loss improved from 4.73466 to 4.72169, saving model to models\lstm2_univar\regression\20.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 5.0484 - mae: 0.8083 - val_loss: 4.7217 - val_mae: 0.6590
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.0038 - mae: 0.8027
# Epoch 00021: val_loss did not improve from 4.72169
# 32/32 [==============================] - 33s 1s/step - loss: 4.9898 - mae: 0.8014 - val_loss: 4.7219 - val_mae: 0.6624
# Epoch 00022: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 22/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.0719 - mae: 0.8124
# Epoch 00022: val_loss improved from 4.72169 to 4.70845, saving model to models\lstm2_univar\regression\22.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 5.0667 - mae: 0.8149 - val_loss: 4.7084 - val_mae: 0.6587
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 23/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.9865 - mae: 0.8045
# Epoch 00023: val_loss improved from 4.70845 to 4.69896, saving model to models\lstm2_univar\regression\23.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 5.0390 - mae: 0.8101 - val_loss: 4.6990 - val_mae: 0.6582
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 24/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.9513 - mae: 0.7884
# Epoch 00024: val_loss did not improve from 4.69896
# 32/32 [==============================] - 34s 1s/step - loss: 4.9443 - mae: 0.7885 - val_loss: 4.7041 - val_mae: 0.6647
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 25/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.9632 - mae: 0.7954
# Epoch 00025: val_loss improved from 4.69896 to 4.69426, saving model to models\lstm2_univar\regression\25.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 4.9720 - mae: 0.8002 - val_loss: 4.6943 - val_mae: 0.6617
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 26/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.9700 - mae: 0.8017
# Epoch 00026: val_loss improved from 4.69426 to 4.68420, saving model to models\lstm2_univar\regression\26.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 4.9602 - mae: 0.8029 - val_loss: 4.6842 - val_mae: 0.6583
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 27/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.9602 - mae: 0.8058
# Epoch 00027: val_loss improved from 4.68420 to 4.67970, saving model to models\lstm2_univar\regression\27.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 5.0196 - mae: 0.8152 - val_loss: 4.6797 - val_mae: 0.6578
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 28/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.8764 - mae: 0.7861
# Epoch 00028: val_loss improved from 4.67970 to 4.67664, saving model to models\lstm2_univar\regression\28.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 4.8550 - mae: 0.7822 - val_loss: 4.6766 - val_mae: 0.6584
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 29/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.9405 - mae: 0.8058
# Epoch 00029: val_loss improved from 4.67664 to 4.67495, saving model to models\lstm2_univar\regression\29.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 4.9423 - mae: 0.8077 - val_loss: 4.6750 - val_mae: 0.6591
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 3.1250001484295353e-06.
# Epoch 30/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.9400 - mae: 0.7967
# Epoch 00030: val_loss improved from 4.67495 to 4.67199, saving model to models\lstm2_univar\regression\30.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 4.9343 - mae: 0.7970 - val_loss: 4.6720 - val_mae: 0.6585
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 3.1250001484295353e-06.
# Epoch 31/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.8614 - mae: 0.7789
# Epoch 00031: val_loss improved from 4.67199 to 4.67052, saving model to models\lstm2_univar\regression\31.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 4.8678 - mae: 0.7810 - val_loss: 4.6705 - val_mae: 0.6588
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 3.1250001484295353e-06.
# Epoch 32/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.9783 - mae: 0.8226
# Epoch 00032: val_loss improved from 4.67052 to 4.66752, saving model to models\lstm2_univar\regression\32.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 4.9571 - mae: 0.8188 - val_loss: 4.6675 - val_mae: 0.6584

# %%
def plot_regr_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'MSE', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'MAE', 'mae', 'val_mae')
    
plot_regr_history(regr_history);

# %% [markdown]
# ### Прогноз задачи регрессии

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_regression_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret_test = univariate_regression_lstm.predict_generator(test_regr_gen, verbose=1)
# Out:
# 13/13 [==============================] - 6s 455ms/step

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret_test, figsize=(16, 10),
                                  datetime_unit='m', plot_data_slice=slice(1, None))

# %% [markdown]
# ## Задача классификации
#
# Прогнозируем направление изменения цены по сравнению с предыдущим периодом (**0** - снижение, **1** - рост).

# %%
model_class_name = 'classification'

# %%
train_clf_gen = ClassificationGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_clf_gen = ClassificationGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_clf_gen = ClassificationGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_classification_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=(16, 32))

    clf = Dense(64)(lstm)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)

    return Model(inputs=[inp], outputs=[clf])

# %%
univariate_classification_lstm = build_classification_model(test_clf_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
univariate_classification_lstm.compile(optimizer=optimizer,
                                       loss={'clf': 'binary_crossentropy'},
                                       metrics={'clf': 'accuracy'})

univariate_classification_lstm.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 120, 1)]          0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 120, 16)           1152
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 120, 32)           6272
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3840)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                245824
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# clf (Dense)                  (None, 1)                 65
# =================================================================
# Total params: 253,569
# Trainable params: 253,441
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
clf_history = utils.train_model(univariate_classification_lstm,
                                model_save_dir, train_clf_gen, test_clf_gen,
                                callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 0s - loss: 10.3973 - accuracy: 0.5091
# Epoch 00001: val_loss improved from inf to 8.93319, saving model to models\lstm2_univar\classification\01.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 10.3668 - accuracy: 0.5059 - val_loss: 8.9332 - val_accuracy: 0.5116
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.0639 - accuracy: 0.5131
# Epoch 00002: val_loss improved from 8.93319 to 6.92143, saving model to models\lstm2_univar\classification\02.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 8.0367 - accuracy: 0.5119 - val_loss: 6.9214 - val_accuracy: 0.5219
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.2231 - accuracy: 0.5121
# Epoch 00003: val_loss improved from 6.92143 to 5.32770, saving model to models\lstm2_univar\classification\03.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 6.2031 - accuracy: 0.5128 - val_loss: 5.3277 - val_accuracy: 0.4781
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.8916 - accuracy: 0.4829
# Epoch 00004: val_loss improved from 5.32770 to 4.26181, saving model to models\lstm2_univar\classification\04.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 4.8716 - accuracy: 0.4812 - val_loss: 4.2618 - val_accuracy: 0.5219
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.0526 - accuracy: 0.5151
# Epoch 00005: val_loss improved from 4.26181 to 3.74420, saving model to models\lstm2_univar\classification\05.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 4.0441 - accuracy: 0.5138 - val_loss: 3.7442 - val_accuracy: 0.5116
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.6269 - accuracy: 0.5151
# Epoch 00006: val_loss improved from 3.74420 to 3.42306, saving model to models\lstm2_univar\classification\06.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 3.6240 - accuracy: 0.5148 - val_loss: 3.4231 - val_accuracy: 0.4781
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.2743 - accuracy: 0.5464
# Epoch 00007: val_loss improved from 3.42306 to 3.10069, saving model to models\lstm2_univar\classification\07.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 3.2685 - accuracy: 0.5464 - val_loss: 3.1007 - val_accuracy: 0.4781
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.9776 - accuracy: 0.5413
# Epoch 00008: val_loss improved from 3.10069 to 2.81646, saving model to models\lstm2_univar\classification\08.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 2.9761 - accuracy: 0.5395 - val_loss: 2.8165 - val_accuracy: 0.4781
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.7548 - accuracy: 0.4980
# Epoch 00009: val_loss improved from 2.81646 to 2.66153, saving model to models\lstm2_univar\classification\09.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 2.7548 - accuracy: 0.4970 - val_loss: 2.6615 - val_accuracy: 0.4781
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.5885 - accuracy: 0.5060
# Epoch 00010: val_loss improved from 2.66153 to 2.51325, saving model to models\lstm2_univar\classification\10.hdf5
# 32/32 [==============================] - 38s 1s/step - loss: 2.5862 - accuracy: 0.5069 - val_loss: 2.5132 - val_accuracy: 0.4781
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.4920 - accuracy: 0.5282
# Epoch 00011: val_loss improved from 2.51325 to 2.42666, saving model to models\lstm2_univar\classification\11.hdf5
# 32/32 [==============================] - 41s 1s/step - loss: 2.4901 - accuracy: 0.5306 - val_loss: 2.4267 - val_accuracy: 0.4781
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.4349 - accuracy: 0.4879
# Epoch 00012: val_loss improved from 2.42666 to 2.35343, saving model to models\lstm2_univar\classification\12.hdf5
# 32/32 [==============================] - 37s 1s/step - loss: 2.4367 - accuracy: 0.4862 - val_loss: 2.3534 - val_accuracy: 0.4781
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.3315 - accuracy: 0.5181
# Epoch 00013: val_loss improved from 2.35343 to 2.28361, saving model to models\lstm2_univar\classification\13.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 2.3302 - accuracy: 0.5188 - val_loss: 2.2836 - val_accuracy: 0.4781
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2948 - accuracy: 0.4889
# Epoch 00014: val_loss improved from 2.28361 to 2.22084, saving model to models\lstm2_univar\classification\14.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 2.2964 - accuracy: 0.4852 - val_loss: 2.2208 - val_accuracy: 0.4781
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2324 - accuracy: 0.5040
# Epoch 00015: val_loss improved from 2.22084 to 2.16564, saving model to models\lstm2_univar\classification\15.hdf5
# 32/32 [==============================] - 36s 1s/step - loss: 2.2345 - accuracy: 0.5030 - val_loss: 2.1656 - val_accuracy: 0.5167
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2229 - accuracy: 0.5081
# Epoch 00016: val_loss improved from 2.16564 to 2.14255, saving model to models\lstm2_univar\classification\16.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 2.2261 - accuracy: 0.5089 - val_loss: 2.1425 - val_accuracy: 0.4807
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1791 - accuracy: 0.4879
# Epoch 00017: val_loss improved from 2.14255 to 2.11984, saving model to models\lstm2_univar\classification\17.hdf5
# 32/32 [==============================] - 37s 1s/step - loss: 2.1814 - accuracy: 0.4842 - val_loss: 2.1198 - val_accuracy: 0.4781
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1479 - accuracy: 0.4980
# Epoch 00018: val_loss improved from 2.11984 to 2.08857, saving model to models\lstm2_univar\classification\18.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 2.1450 - accuracy: 0.5000 - val_loss: 2.0886 - val_accuracy: 0.4807
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1154 - accuracy: 0.5111
# Epoch 00019: val_loss improved from 2.08857 to 2.05854, saving model to models\lstm2_univar\classification\19.hdf5
# 32/32 [==============================] - 36s 1s/step - loss: 2.1141 - accuracy: 0.5128 - val_loss: 2.0585 - val_accuracy: 0.5219
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0950 - accuracy: 0.5030
# Epoch 00020: val_loss improved from 2.05854 to 2.04600, saving model to models\lstm2_univar\classification\20.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 2.0948 - accuracy: 0.5010 - val_loss: 2.0460 - val_accuracy: 0.5219
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0744 - accuracy: 0.5161
# Epoch 00021: val_loss improved from 2.04600 to 2.03142, saving model to models\lstm2_univar\classification\21.hdf5
# 32/32 [==============================] - 37s 1s/step - loss: 2.0767 - accuracy: 0.5138 - val_loss: 2.0314 - val_accuracy: 0.5116
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0661 - accuracy: 0.5232
# Epoch 00022: val_loss improved from 2.03142 to 2.02422, saving model to models\lstm2_univar\classification\22.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 2.0655 - accuracy: 0.5237 - val_loss: 2.0242 - val_accuracy: 0.5219
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0407 - accuracy: 0.5393
# Epoch 00023: val_loss improved from 2.02422 to 2.01594, saving model to models\lstm2_univar\classification\23.hdf5
# 32/32 [==============================] - 37s 1s/step - loss: 2.0388 - accuracy: 0.5405 - val_loss: 2.0159 - val_accuracy: 0.5219
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0521 - accuracy: 0.4960
# Epoch 00024: val_loss improved from 2.01594 to 2.00891, saving model to models\lstm2_univar\classification\24.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 2.0493 - accuracy: 0.4990 - val_loss: 2.0089 - val_accuracy: 0.5219
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0441 - accuracy: 0.4929
# Epoch 00025: val_loss improved from 2.00891 to 1.98841, saving model to models\lstm2_univar\classification\25.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 2.0422 - accuracy: 0.4931 - val_loss: 1.9884 - val_accuracy: 0.5193
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0396 - accuracy: 0.4990
# Epoch 00026: val_loss improved from 1.98841 to 1.98197, saving model to models\lstm2_univar\classification\26.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 2.0390 - accuracy: 0.4990 - val_loss: 1.9820 - val_accuracy: 0.5167
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0181 - accuracy: 0.5131
# Epoch 00027: val_loss improved from 1.98197 to 1.97672, saving model to models\lstm2_univar\classification\27.hdf5
# 32/32 [==============================] - 37s 1s/step - loss: 2.0160 - accuracy: 0.5138 - val_loss: 1.9767 - val_accuracy: 0.5219
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0270 - accuracy: 0.4950
# Epoch 00028: val_loss improved from 1.97672 to 1.96967, saving model to models\lstm2_univar\classification\28.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 2.0264 - accuracy: 0.4951 - val_loss: 1.9697 - val_accuracy: 0.5141
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0026 - accuracy: 0.5192
# Epoch 00029: val_loss improved from 1.96967 to 1.96529, saving model to models\lstm2_univar\classification\29.hdf5
# 32/32 [==============================] - 37s 1s/step - loss: 1.9989 - accuracy: 0.5227 - val_loss: 1.9653 - val_accuracy: 0.5193
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0074 - accuracy: 0.5131
# Epoch 00030: val_loss improved from 1.96529 to 1.95864, saving model to models\lstm2_univar\classification\30.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 2.0044 - accuracy: 0.5168 - val_loss: 1.9586 - val_accuracy: 0.5219
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9974 - accuracy: 0.4980
# Epoch 00031: val_loss improved from 1.95864 to 1.95509, saving model to models\lstm2_univar\classification\31.hdf5
# 32/32 [==============================] - 36s 1s/step - loss: 1.9970 - accuracy: 0.4990 - val_loss: 1.9551 - val_accuracy: 0.5244
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9890 - accuracy: 0.5101
# Epoch 00032: val_loss improved from 1.95509 to 1.95213, saving model to models\lstm2_univar\classification\32.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 1.9899 - accuracy: 0.5089 - val_loss: 1.9521 - val_accuracy: 0.5296

# %%
def plot_clf_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'Loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'Accuracy', 'accuracy', 'val_accuracy')
    
plot_clf_history(clf_history);

# %% [markdown]
# ### Прогноз задачи классификации

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_classification_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %%
pred_direction_proba = univariate_classification_lstm.predict_generator(test_clf_gen, verbose=1)

true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 13/13 [==============================] - 7s 574ms/step
# 0.49490184

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([203, 186], dtype=int64)),
#  (array([0, 1]), array([201, 188], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.56      0.56       203
#            1       0.52      0.53      0.52       186
#
#     accuracy                           0.54       389
#    macro avg       0.54      0.54      0.54       389
# weighted avg       0.54      0.54      0.54       389

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[113,  90],
#        [ 88,  98]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.56218905, 0.4787234 ],
#        [0.43781095, 0.5212766 ]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# ## Многозадачная модель: одновременно регрессия и классификация

# %%
model_class_name = 'multitask'

# %%
train_multi_gen = MultitaskGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_multi_gen = MultitaskGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_multi_gen = MultitaskGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_multitask_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=(16, 32))

    # первый выход: задача регрссии
    regr = Dense(64)(lstm)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    # второй выход: задача классификации
    clf = Dense(64)(lstm)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)
    
    return Model(inputs=[inp], outputs=[regr, clf])

# %%
univariate_multitask_lstm = build_multitask_model(train_multi_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
univariate_multitask_lstm.compile(optimizer=optimizer,
                                  loss={'regr': 'mse', 'clf': 'binary_crossentropy'},
                                  loss_weights={'regr': 2., 'clf': 1.},
                                  metrics={'regr': 'mae', 'clf' : 'accuracy'})

univariate_multitask_lstm.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 120, 1)]     0
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 120, 16)      1152        input[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 120, 32)      6272        lstm_4[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 3840)         0           lstm_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           245824      flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           245824      flatten_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64)           256         dense_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64)           256         dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 64)           0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 64)           0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64)           0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64)           0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# regr (Dense)                    (None, 1)            65          dropout_2[0][0]
# __________________________________________________________________________________________________
# clf (Dense)                     (None, 1)            65          dropout_3[0][0]
# ==================================================================================================
# Total params: 499,714
# Trainable params: 499,458
# Non-trainable params: 256
# __________________________________________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
multitask_history = utils.train_model(univariate_multitask_lstm,
                                      model_save_dir, train_multi_gen, test_multi_gen,
                                      callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                      force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 1s - loss: 15.9616 - regr_loss: 2.3628 - clf_loss: 0.9377 - regr_mae: 1.1361 - clf_accuracy: 0.5161
# Epoch 00001: val_loss improved from inf to 14.88597, saving model to models\lstm2_univar\multitask\01.hdf5
# 32/32 [==============================] - 40s 1s/step - loss: 15.9151 - regr_loss: 2.3485 - clf_loss: 0.9347 - regr_mae: 1.1365 - clf_accuracy: 0.5158 - val_loss: 14.8860 - val_regr_loss: 2.1956 - val_clf_loss: 0.7246 - val_regr_mae: 1.1847 - val_clf_accuracy: 0.5219
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 0s - loss: 14.2560 - regr_loss: 2.0741 - clf_loss: 0.8339 - regr_mae: 1.0603 - clf_accuracy: 0.5242
# Epoch 00002: val_loss improved from 14.88597 to 12.16734, saving model to models\lstm2_univar\multitask\02.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 14.2179 - regr_loss: 2.0645 - clf_loss: 0.8307 - regr_mae: 1.0599 - clf_accuracy: 0.5257 - val_loss: 12.1673 - val_regr_loss: 1.3574 - val_clf_loss: 0.7250 - val_regr_mae: 0.8049 - val_clf_accuracy: 0.5219
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 12.6749 - regr_loss: 1.7926 - clf_loss: 0.8239 - regr_mae: 0.9732 - clf_accuracy: 0.5101
# Epoch 00003: val_loss improved from 12.16734 to 10.75799, saving model to models\lstm2_univar\multitask\03.hdf5
# 32/32 [==============================] - 36s 1s/step - loss: 12.7036 - regr_loss: 1.8122 - clf_loss: 0.8286 - regr_mae: 0.9768 - clf_accuracy: 0.5059 - val_loss: 10.7580 - val_regr_loss: 1.0770 - val_clf_loss: 0.8446 - val_regr_mae: 0.6585 - val_clf_accuracy: 0.5219
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 11.5785 - regr_loss: 1.7053 - clf_loss: 0.8279 - regr_mae: 0.9177 - clf_accuracy: 0.5020
# Epoch 00004: val_loss did not improve from 10.75799
# 32/32 [==============================] - 35s 1s/step - loss: 11.5236 - regr_loss: 1.6819 - clf_loss: 0.8326 - regr_mae: 0.9142 - clf_accuracy: 0.5000 - val_loss: 10.8368 - val_regr_loss: 1.5643 - val_clf_loss: 0.8187 - val_regr_mae: 0.9078 - val_clf_accuracy: 0.5219
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 10.4140 - regr_loss: 1.4698 - clf_loss: 0.7812 - regr_mae: 0.8664 - clf_accuracy: 0.5071
# Epoch 00005: val_loss improved from 10.75799 to 9.41368, saving model to models\lstm2_univar\multitask\05.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 10.4195 - regr_loss: 1.4739 - clf_loss: 0.7850 - regr_mae: 0.8697 - clf_accuracy: 0.5040 - val_loss: 9.4137 - val_regr_loss: 1.0961 - val_clf_loss: 0.7426 - val_regr_mae: 0.6680 - val_clf_accuracy: 0.5219
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 10.2791 - regr_loss: 1.5946 - clf_loss: 0.7946 - regr_mae: 0.8805 - clf_accuracy: 0.5282
# Epoch 00006: val_loss did not improve from 9.41368
# 32/32 [==============================] - 35s 1s/step - loss: 10.2456 - regr_loss: 1.5789 - clf_loss: 0.7983 - regr_mae: 0.8801 - clf_accuracy: 0.5257 - val_loss: 9.4663 - val_regr_loss: 1.3284 - val_clf_loss: 0.7192 - val_regr_mae: 0.7746 - val_clf_accuracy: 0.5219
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 9.9136 - regr_loss: 1.5986 - clf_loss: 0.7979 - regr_mae: 0.8701 - clf_accuracy: 0.4950
# Epoch 00007: val_loss improved from 9.41368 to 8.94577, saving model to models\lstm2_univar\multitask\07.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 9.8428 - regr_loss: 1.5691 - clf_loss: 0.7908 - regr_mae: 0.8649 - clf_accuracy: 0.5000 - val_loss: 8.9458 - val_regr_loss: 1.2526 - val_clf_loss: 0.7115 - val_regr_mae: 0.7378 - val_clf_accuracy: 0.4781
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 9.2399 - regr_loss: 1.4448 - clf_loss: 0.7825 - regr_mae: 0.8269 - clf_accuracy: 0.5050
# Epoch 00008: val_loss improved from 8.94577 to 8.62341, saving model to models\lstm2_univar\multitask\08.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 9.2127 - regr_loss: 1.4333 - clf_loss: 0.7832 - regr_mae: 0.8285 - clf_accuracy: 0.5040 - val_loss: 8.6234 - val_regr_loss: 1.2484 - val_clf_loss: 0.7370 - val_regr_mae: 0.7458 - val_clf_accuracy: 0.4781
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.8598 - regr_loss: 1.4241 - clf_loss: 0.7727 - regr_mae: 0.8432 - clf_accuracy: 0.5091
# Epoch 00009: val_loss did not improve from 8.62341
# 32/32 [==============================] - 35s 1s/step - loss: 8.8047 - regr_loss: 1.3991 - clf_loss: 0.7717 - regr_mae: 0.8377 - clf_accuracy: 0.5138 - val_loss: 9.3748 - val_regr_loss: 1.7857 - val_clf_loss: 0.7292 - val_regr_mae: 1.0078 - val_clf_accuracy: 0.5219
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.5130 - regr_loss: 1.3742 - clf_loss: 0.7641 - regr_mae: 0.7978 - clf_accuracy: 0.5192
# Epoch 00010: val_loss improved from 8.62341 to 7.80998, saving model to models\lstm2_univar\multitask\10.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 8.4711 - regr_loss: 1.3573 - clf_loss: 0.7579 - regr_mae: 0.7967 - clf_accuracy: 0.5227 - val_loss: 7.8100 - val_regr_loss: 1.0935 - val_clf_loss: 0.7019 - val_regr_mae: 0.6651 - val_clf_accuracy: 0.4807
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.4037 - regr_loss: 1.3968 - clf_loss: 0.7579 - regr_mae: 0.8141 - clf_accuracy: 0.5131
# Epoch 00011: val_loss did not improve from 7.80998
# 32/32 [==============================] - 35s 1s/step - loss: 8.3701 - regr_loss: 1.3834 - clf_loss: 0.7529 - regr_mae: 0.8134 - clf_accuracy: 0.5168 - val_loss: 8.2424 - val_regr_loss: 1.3861 - val_clf_loss: 0.6943 - val_regr_mae: 0.8180 - val_clf_accuracy: 0.5193
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.2226 - regr_loss: 1.3680 - clf_loss: 0.7766 - regr_mae: 0.8085 - clf_accuracy: 0.4909
# Epoch 00012: val_loss improved from 7.80998 to 7.60225, saving model to models\lstm2_univar\multitask\12.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 8.1705 - regr_loss: 1.3422 - clf_loss: 0.7778 - regr_mae: 0.8046 - clf_accuracy: 0.4911 - val_loss: 7.6023 - val_regr_loss: 1.0869 - val_clf_loss: 0.7926 - val_regr_mae: 0.6626 - val_clf_accuracy: 0.4781
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.1216 - regr_loss: 1.3901 - clf_loss: 0.7693 - regr_mae: 0.7954 - clf_accuracy: 0.4859
# Epoch 00013: val_loss did not improve from 7.60225
# 32/32 [==============================] - 35s 1s/step - loss: 8.0815 - regr_loss: 1.3719 - clf_loss: 0.7672 - regr_mae: 0.7945 - clf_accuracy: 0.4862 - val_loss: 7.7129 - val_regr_loss: 1.2596 - val_clf_loss: 0.6932 - val_regr_mae: 0.7421 - val_clf_accuracy: 0.5013
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.9788 - regr_loss: 1.3823 - clf_loss: 0.7740 - regr_mae: 0.7904 - clf_accuracy: 0.5020
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 5.0000002374872565e-05.
#
# Epoch 00014: val_loss did not improve from 7.60225
# 32/32 [==============================] - 35s 1s/step - loss: 7.9742 - regr_loss: 1.3806 - clf_loss: 0.7748 - regr_mae: 0.7912 - clf_accuracy: 0.5000 - val_loss: 7.6732 - val_regr_loss: 1.2616 - val_clf_loss: 0.7778 - val_regr_mae: 0.7414 - val_clf_accuracy: 0.4781
# Epoch 00015: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.8672 - regr_loss: 1.3719 - clf_loss: 0.7593 - regr_mae: 0.7870 - clf_accuracy: 0.5232
# Epoch 00015: val_loss improved from 7.60225 to 7.50892, saving model to models\lstm2_univar\multitask\15.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 7.8563 - regr_loss: 1.3648 - clf_loss: 0.7627 - regr_mae: 0.7878 - clf_accuracy: 0.5198 - val_loss: 7.5089 - val_regr_loss: 1.2092 - val_clf_loss: 0.7342 - val_regr_mae: 0.7170 - val_clf_accuracy: 0.4781
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.6612 - regr_loss: 1.2759 - clf_loss: 0.7592 - regr_mae: 0.7575 - clf_accuracy: 0.5212
# Epoch 00016: val_loss improved from 7.50892 to 7.32634, saving model to models\lstm2_univar\multitask\16.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 7.6059 - regr_loss: 1.2493 - clf_loss: 0.7565 - regr_mae: 0.7525 - clf_accuracy: 0.5237 - val_loss: 7.3263 - val_regr_loss: 1.1387 - val_clf_loss: 0.7058 - val_regr_mae: 0.6855 - val_clf_accuracy: 0.4704
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.6054 - regr_loss: 1.2606 - clf_loss: 0.7471 - regr_mae: 0.7624 - clf_accuracy: 0.5121
# Epoch 00017: val_loss improved from 7.32634 to 7.28638, saving model to models\lstm2_univar\multitask\17.hdf5
# 32/32 [==============================] - 36s 1s/step - loss: 7.5802 - regr_loss: 1.2480 - clf_loss: 0.7472 - regr_mae: 0.7631 - clf_accuracy: 0.5089 - val_loss: 7.2864 - val_regr_loss: 1.1303 - val_clf_loss: 0.6959 - val_regr_mae: 0.6822 - val_clf_accuracy: 0.4807
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.6614 - regr_loss: 1.2921 - clf_loss: 0.7535 - regr_mae: 0.7756 - clf_accuracy: 0.5373
# Epoch 00018: val_loss improved from 7.28638 to 7.21614, saving model to models\lstm2_univar\multitask\18.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 7.6086 - regr_loss: 1.2666 - clf_loss: 0.7513 - regr_mae: 0.7713 - clf_accuracy: 0.5356 - val_loss: 7.2161 - val_regr_loss: 1.1027 - val_clf_loss: 0.6940 - val_regr_mae: 0.6694 - val_clf_accuracy: 0.5116
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 2.5000001187436283e-05.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.7445 - regr_loss: 1.3399 - clf_loss: 0.7545 - regr_mae: 0.7706 - clf_accuracy: 0.5020
# Epoch 00019: val_loss improved from 7.21614 to 7.19116, saving model to models\lstm2_univar\multitask\19.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 7.7143 - regr_loss: 1.3246 - clf_loss: 0.7546 - regr_mae: 0.7694 - clf_accuracy: 0.5020 - val_loss: 7.1912 - val_regr_loss: 1.0971 - val_clf_loss: 0.6936 - val_regr_mae: 0.6667 - val_clf_accuracy: 0.5116
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.5393 - regr_loss: 1.2455 - clf_loss: 0.7483 - regr_mae: 0.7624 - clf_accuracy: 0.5343
# Epoch 00020: val_loss did not improve from 7.19116
# 32/32 [==============================] - 35s 1s/step - loss: 7.5212 - regr_loss: 1.2368 - clf_loss: 0.7476 - regr_mae: 0.7629 - clf_accuracy: 0.5356 - val_loss: 7.1925 - val_regr_loss: 1.1016 - val_clf_loss: 0.6931 - val_regr_mae: 0.6694 - val_clf_accuracy: 0.5039
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.1077 - regr_loss: 1.0263 - clf_loss: 0.7621 - regr_mae: 0.7612 - clf_accuracy: 0.5091
# Epoch 00021: val_loss improved from 7.19116 to 7.16115, saving model to models\lstm2_univar\multitask\21.hdf5
# 32/32 [==============================] - 36s 1s/step - loss: 7.9408 - regr_loss: 1.4446 - clf_loss: 0.7681 - regr_mae: 0.7760 - clf_accuracy: 0.5069 - val_loss: 7.1611 - val_regr_loss: 1.0894 - val_clf_loss: 0.6927 - val_regr_mae: 0.6630 - val_clf_accuracy: 0.5167
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 22/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.5936 - regr_loss: 1.2728 - clf_loss: 0.7619 - regr_mae: 0.7623 - clf_accuracy: 0.5040
# Epoch 00022: val_loss improved from 7.16115 to 7.14107, saving model to models\lstm2_univar\multitask\22.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 7.5798 - regr_loss: 1.2664 - clf_loss: 0.7607 - regr_mae: 0.7648 - clf_accuracy: 0.5049 - val_loss: 7.1411 - val_regr_loss: 1.0827 - val_clf_loss: 0.6932 - val_regr_mae: 0.6602 - val_clf_accuracy: 0.5270
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 23/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.7132 - regr_loss: 1.3413 - clf_loss: 0.7515 - regr_mae: 0.7960 - clf_accuracy: 0.5282
# Epoch 00023: val_loss improved from 7.14107 to 7.13329, saving model to models\lstm2_univar\multitask\23.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 7.6622 - regr_loss: 1.3159 - clf_loss: 0.7507 - regr_mae: 0.7921 - clf_accuracy: 0.5296 - val_loss: 7.1333 - val_regr_loss: 1.0823 - val_clf_loss: 0.6931 - val_regr_mae: 0.6604 - val_clf_accuracy: 0.5296
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 1.2500000593718141e-05.
# Epoch 24/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.7779 - regr_loss: 1.3558 - clf_loss: 0.7940 - regr_mae: 0.8063 - clf_accuracy: 0.4718
# Epoch 00024: val_loss improved from 7.13329 to 7.12573, saving model to models\lstm2_univar\multitask\24.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 7.7395 - regr_loss: 1.3385 - clf_loss: 0.7899 - regr_mae: 0.8043 - clf_accuracy: 0.4733 - val_loss: 7.1257 - val_regr_loss: 1.0810 - val_clf_loss: 0.6951 - val_regr_mae: 0.6598 - val_clf_accuracy: 0.5193
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 25/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.8009 - regr_loss: 1.3835 - clf_loss: 0.7673 - regr_mae: 0.7973 - clf_accuracy: 0.4970
# Epoch 00025: val_loss did not improve from 7.12573
# 32/32 [==============================] - 35s 1s/step - loss: 7.7705 - regr_loss: 1.3683 - clf_loss: 0.7667 - regr_mae: 0.7943 - clf_accuracy: 0.4970 - val_loss: 7.1293 - val_regr_loss: 1.0849 - val_clf_loss: 0.6946 - val_regr_mae: 0.6614 - val_clf_accuracy: 0.5167
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 26/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.7219 - regr_loss: 1.3499 - clf_loss: 0.7588 - regr_mae: 0.7914 - clf_accuracy: 0.5071
# Epoch 00026: val_loss improved from 7.12573 to 7.12210, saving model to models\lstm2_univar\multitask\26.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 7.6987 - regr_loss: 1.3382 - clf_loss: 0.7588 - regr_mae: 0.7933 - clf_accuracy: 0.5059 - val_loss: 7.1221 - val_regr_loss: 1.0829 - val_clf_loss: 0.6949 - val_regr_mae: 0.6607 - val_clf_accuracy: 0.5167
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 27/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.6008 - regr_loss: 1.2884 - clf_loss: 0.7644 - regr_mae: 0.7742 - clf_accuracy: 0.5111
# Epoch 00027: val_loss improved from 7.12210 to 7.12007, saving model to models\lstm2_univar\multitask\27.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 7.5601 - regr_loss: 1.2677 - clf_loss: 0.7646 - regr_mae: 0.7714 - clf_accuracy: 0.5128 - val_loss: 7.1201 - val_regr_loss: 1.0834 - val_clf_loss: 0.6955 - val_regr_mae: 0.6610 - val_clf_accuracy: 0.5219
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 28/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.5358 - regr_loss: 1.2707 - clf_loss: 0.7384 - regr_mae: 0.7660 - clf_accuracy: 0.5282
# Epoch 00028: val_loss improved from 7.12007 to 7.11585, saving model to models\lstm2_univar\multitask\28.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 7.5194 - regr_loss: 1.2627 - clf_loss: 0.7379 - regr_mae: 0.7667 - clf_accuracy: 0.5247 - val_loss: 7.1159 - val_regr_loss: 1.0835 - val_clf_loss: 0.6948 - val_regr_mae: 0.6611 - val_clf_accuracy: 0.5141
# Epoch 00029: LearningRateScheduler reducing learning rate to 6.250000296859071e-06.
# Epoch 29/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.5457 - regr_loss: 1.2839 - clf_loss: 0.7256 - regr_mae: 0.7800 - clf_accuracy: 0.5444
# Epoch 00029: val_loss did not improve from 7.11585
# 32/32 [==============================] - 35s 1s/step - loss: 7.5289 - regr_loss: 1.2726 - clf_loss: 0.7312 - regr_mae: 0.7771 - clf_accuracy: 0.5425 - val_loss: 7.1202 - val_regr_loss: 1.0877 - val_clf_loss: 0.6944 - val_regr_mae: 0.6628 - val_clf_accuracy: 0.5141
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 3.1250001484295353e-06.
# Epoch 30/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.5198 - regr_loss: 1.2454 - clf_loss: 0.7796 - regr_mae: 0.7632 - clf_accuracy: 0.4909
# Epoch 00030: val_loss did not improve from 7.11585
# 32/32 [==============================] - 35s 1s/step - loss: 7.4866 - regr_loss: 1.2304 - clf_loss: 0.7760 - regr_mae: 0.7614 - clf_accuracy: 0.4941 - val_loss: 7.1159 - val_regr_loss: 1.0866 - val_clf_loss: 0.6942 - val_regr_mae: 0.6623 - val_clf_accuracy: 0.5141
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 3.1250001484295353e-06.
# Epoch 31/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.6081 - regr_loss: 1.3052 - clf_loss: 0.7501 - regr_mae: 0.7793 - clf_accuracy: 0.5040
# Epoch 00031: val_loss improved from 7.11585 to 7.11188, saving model to models\lstm2_univar\multitask\31.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 7.5687 - regr_loss: 1.2876 - clf_loss: 0.7456 - regr_mae: 0.7780 - clf_accuracy: 0.5109 - val_loss: 7.1119 - val_regr_loss: 1.0857 - val_clf_loss: 0.6938 - val_regr_mae: 0.6619 - val_clf_accuracy: 0.5167
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 3.1250001484295353e-06.
# Epoch 32/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.4904 - regr_loss: 1.2497 - clf_loss: 0.7453 - regr_mae: 0.7538 - clf_accuracy: 0.5333
# Epoch 00032: val_loss improved from 7.11188 to 7.10927, saving model to models\lstm2_univar\multitask\32.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 7.4811 - regr_loss: 1.2444 - clf_loss: 0.7464 - regr_mae: 0.7550 - clf_accuracy: 0.5296 - val_loss: 7.1093 - val_regr_loss: 1.0853 - val_clf_loss: 0.6938 - val_regr_mae: 0.6617 - val_clf_accuracy: 0.5116

# %%
def plot_multitask_history(hist):
    fig, ax = plt.subplots(2, 2, figsize=(16, 12))
    plotHelpers.plot_train_history(ax[0, 0], hist, 'Total loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[0, 1], hist, 'Accuracy', 'clf_accuracy', 'val_clf_accuracy')
    plotHelpers.plot_train_history(ax[1, 0], hist, 'MSE', 'regr_loss', 'val_regr_loss')
    plotHelpers.plot_train_history(ax[1, 1], hist, 'MAE', 'regr_mae', 'val_regr_mae')
    
plot_multitask_history(multitask_history);

# %% [markdown]
# ### Прогноз

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_multitask_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret, pred_direction_proba = univariate_multitask_lstm.predict_generator(test_multi_gen, verbose=1)
# Out:
# 13/13 [==============================] - 6s 461ms/step

# %%
np.set_printoptions(precision=3, suppress=True)

np.column_stack([pred_log_ret, pred_direction_proba])[-10:]
# Out:
# array([[0.052, 0.481],
#        [0.032, 0.473],
#        [0.022, 0.469],
#        [0.023, 0.466],
#        [0.024, 0.466],
#        [0.037, 0.471],
#        [0.039, 0.474],
#        [0.054, 0.482],
#        [0.072, 0.486],
#        [0.086, 0.485]], dtype=float32)

# %% [markdown]
# #### Прогноз задачи регрессии

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret, figsize=(16, 10),
                                  datetime_unit='m', plot_data_slice=slice(1, None))

# %% [markdown]
# #### Прогноз задачи классификации

# %%
true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 0.45824614

# %%
true_direction = test_multi_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([203, 186], dtype=int64)),
#  (array([0, 1]), array([207, 182], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.53      0.52       203
#            1       0.47      0.46      0.47       186
#
#     accuracy                           0.50       389
#    macro avg       0.49      0.49      0.49       389
# weighted avg       0.50      0.50      0.50       389

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[107,  96],
#        [100,  86]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.517, 0.527],
#        [0.483, 0.473]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# # Выводы
#
# 1.  Размер батча влияет на скорость обучения.
# 2.  Инициализация весов (`bias_initializer`) в слое **LSTM** оказалась очень важным параметром.
# 3.  Модель регрессии просто выходит на модель случайного блуждания.
# 4.  Модель классификации получились слабая.
# 5.  Комбинированная модель не улучшила качество.
# 6.  В целом добавление второго слоя не принесло улучшения качества по сравнению с однослойной одномерной моделью.

# %% [markdown]
# <a href="https://colab.research.google.com/github/rklepov/hse-cs-ml-2018-2019-grad-work/blob/CVX-1yr/CVX/daily1y/06-lstm2_multivar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # *Многомерная модель на LSTM* (2 слоя)
#
# В качестве признаков используются цены, объём торгов и некоторое число индикаторов (всего 18 признаков)

# %%
import os
import glob
import datetime
import pickle

import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from pandas_datareader import data as pdr

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
import tensorflow as tf
# tf.test.is_gpu_available()
tf.__version__
# Out:
# '2.0.0'

# %%
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Input, Dense, LSTM, GRU, Flatten, ReLU, LeakyReLU, Dropout, BatchNormalization
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers import Nadam

# %%
import mdp

from mdp import TimeSeries
from mdp import MarketData
from mdp import MovingWindowFeatures
from mdp import ClassificationGenerator, RegressionGenerator, MultitaskGenerator
from mdp import invert_log_ret

import mdp.utils as utils
import mdp.plotHelpers as plotHelpers

# %%
import importlib

import mdp

importlib.reload(mdp)
importlib.reload(mdp.datasetGenerator)
importlib.reload(mdp.marketData)
importlib.reload(mdp.movingWindowFeatures)
importlib.reload(mdp.timeSeries)
importlib.reload(mdp.plotHelpers)
importlib.reload(mdp.utils);

# %% [markdown]
# # *Параметры*

# %%
INSTRUMENT = 'MSFT' # Microsoft corp
START_FROM = np.datetime64('today') - 7
WINDOW_SIZE = 120
FORECAST_OFFSET=1
BATCH_SIZE = 32
FORCE_TRAIN = True

# %% [markdown]
# # *Исходные данные*
#
# Загрузка данных и вычисление индикаторов.

# %%
instr = MarketData.create_from_alphavantage_intraday(INSTRUMENT, start=START_FROM)

# %%
instr.feature_names
# Out:
# ['o',
#  'h',
#  'l',
#  'c',
#  'v',
#  'ema14',
#  'ema30',
#  'macd',
#  'macd_signal',
#  'rsi14',
#  'bband20_upper',
#  'bband20_middle',
#  'bband20_lower',
#  'willr14',
#  'stochk',
#  'stochd',
#  'adline',
#  'adosc']

# %% [markdown]
# Здесь не будем делить отдельно на тест и валидацию, поскольку данных у нас только 5 дней.

# %%
dates_unique = np.unique(instr.timestamps.astype('datetime64[D]'))

START_FROM = dates_unique[0]
VAL_TEST_SPLIT = dates_unique[-1]

START_FROM, VAL_TEST_SPLIT
# Out:
# (numpy.datetime64('2020-04-09'), numpy.datetime64('2020-04-15'))

# %% [markdown]
# ## Целевая переменная

# %% [markdown]
# Цена закрытия.

# %%
orig_target = instr.c

# %%
def plot_transformed_series(instrument, series, orig_display_name, transformed_display_name):
    plotHelpers.plot_transformed_timeseries(
        instrument.instrument,
        series,
        title_orig = orig_display_name,
        xlabel_orig = 'Date',
        ylabel_orig = orig_display_name,
        title_transformed = transformed_display_name,
        xlabel_transformed = 'Date',
        ylabel_transformed = transformed_display_name
    )

# %% [markdown]
# Переходим к логарифмической доходности.

# %%
transformed_target = instr.c.transform(transforms={'ratios' : {}, 'ln' : {}})

# %%
plotHelpers.plot_transformed_timeseries_unit(instr,
                                             transformed_target,
                                             'Close price, USD', 'Log return',
                                             datetime_unit='m', rotation=45)

# %% [markdown]
# ## Трансформация признаков
#
# Приведение временных рядов к стационарности.

# %%
def make_feature_selector():
    price_transformer = lambda: {'ratios': {}, 'ln': {}}
    diff_transformer = lambda o: {'diffs': {'order': o}}
    identity_transformer = lambda: {}
    feature_transformations = {
        'o': price_transformer(),
        'h': price_transformer(),
        'l': price_transformer(),
        'c': price_transformer(),
        'v': diff_transformer(1),
        'ema14': diff_transformer(1),
        'ema30': diff_transformer(1),
        'macd': identity_transformer(),
        'macd_signal': identity_transformer(),
        'rsi14': identity_transformer(),
        'bband20_upper': diff_transformer(1),
        'bband20_middle': diff_transformer(1),
        'bband20_lower': diff_transformer(1),
        'willr14': identity_transformer(),
        'stochd': identity_transformer(),
        'stochk': identity_transformer(),
        'adline': diff_transformer(1),
        'adosc': identity_transformer()
    }
    return feature_transformations

# %%
instr_transformed = instr.select_transform(make_feature_selector())

# %%
transformed_target = instr_transformed.c

# %% [markdown]
# ## Обучающая, валидационная и тестовая выборки

# %%
instr_train, instr_test = instr_transformed.train_test_split(VAL_TEST_SPLIT, window_size=WINDOW_SIZE,
                                                             scaler=StandardScaler)
#                                                              scaler=MinMaxScaler,
#                                                              scaler_kwargs={'feature_range': (-1, 1)})

# instr_val, instr_test = instr_val_test.train_test_split(TEST_SPLIT, window_size=WINDOW_SIZE, scaler=None)

len(instr_train), len(instr_test)
# Out:
# (1132, 509)

# %% [markdown]
# Все отмасштабированные признаки на одном графике (для валидационного датасета):

# %%
plotHelpers.plot_all_features(instr_test)

# %% [markdown]
# ## Признаки - скользящие окна

# %%
train_mwf = MovingWindowFeatures.create(instr_train.c, [instr_train], instr_train.feature_names, window_size=WINDOW_SIZE)
# val_mwf = MovingWindowFeatures.create(instr_val.c, [instr_val], instr_val.feature_names, window_size=WINDOW_SIZE)
test_mwf = MovingWindowFeatures.create(instr_test.c, [instr_test], instr_test.feature_names, window_size=WINDOW_SIZE)

len(instr_train), len(train_mwf), train_mwf.features.shape
# Out:
# (1132, 1012, (1012, 120, 18))

# %% [markdown]
# Проверка, что скользящие окна соответствуют исходным данным.
#
# Возьмём произвольный признак и произвольное окно (строка #**41**). Проверим, что данные в точности совпадают:

# %%
def check_data(md, mwf, row):
    col = np.random.randint(len(mwf.feature_names))
    feature = mwf.feature_names[col]
    check = (getattr(md, feature).data[row:row + mwf.window_size] == mwf.features[row, :, col]).all()
    assert check
    return feature, check

check_data(instr_train, train_mwf, 41)
# Out:
# ('h', True)

# %% [markdown]
# # *Модели*

# %% [markdown]
# Модель с двумя LSTM слоями.

# %%
def build_lstm_layers(input_shape, latent_dim=(16, 32)):
    # формат входа: наша матрица (окно; признак)
    inp = Input(input_shape, name='input')

    # стекаем два уровня LSTM
    lstm = LSTM(latent_dim[0], return_sequences=True, 
                    recurrent_dropout=0.2, dropout=0.2, 
                    bias_initializer='he_uniform',
                    bias_regularizer=L1L2(0.01, 0.02),
                    kernel_regularizer=L1L2(0.01, 0.02),
                    recurrent_regularizer=L1L2(0.01, 0.02)
               )(inp)

    lstm = LSTM(latent_dim[1], return_sequences=True,
                    recurrent_dropout=0.2, dropout=0.2,
                    bias_initializer='he_uniform',
                    bias_regularizer=L1L2(0.01, 0.02),
                    kernel_regularizer=L1L2(0.01, 0.02),
                    recurrent_regularizer=L1L2(0.01, 0.02)
               )(lstm)
    
    lstm = Flatten()(lstm)
    
    return inp, lstm

# %% [markdown]
# #### Пути сохранения моделей:

# %%
model_path_root = 'models'
model_type_name = 'lstm2_multivar'

def make_model_save_dir(path_root, type_name, class_name):
    save_dir = os.path.join(path_root, type_name, class_name)
    os.makedirs(save_dir, exist_ok=True)
    return save_dir

# %% [markdown]
# #### Общие коллбэки:

# %%
# уменьшение learning rate в случае, если loss не изменяется
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001, verbose=1)

# уменьшение learning rate в 2 раза каждую 5-ю эпоху
def lr_decay(e, lr):
    return lr * (1 - 0.5 * (0 == (e + 1) % 5))

lr_scheduler = LearningRateScheduler(schedule=lr_decay, verbose=1)

# %% [markdown]
# ## Задача регрессии
#
# Непосредственное прогнозирование цены следующего периода.

# %%
train_regr_gen = RegressionGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_regr_gen = RegressionGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_regr_gen = RegressionGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# Следующие числа соответствуют значению параметра `steps_per_epoch` метода [`fit_generator`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit_generator "tf.keras.layers.SimpleRNN &nbsp;|&nbsp; TensorFlow Core r2.0") - то есть это число батчей, которые генератор выдаст за одну эпоху обучения (если класс генератора поддерживает метод `len()`, то данный параметр можно не указывать).

# %%
len(train_regr_gen), len(test_regr_gen)
# Out:
# (32, 13)

# %% [markdown]
# Один сэмпл данных представляет собой матрицу размером *(длина окна; число признаков)*

# %%
train_regr_gen.input_shape
# Out:
# (120, 18)

# %% [markdown]
# ### Модель для задачи регрессии

# %%
model_class_name = 'regression'

# %%
def build_regression_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=(16, 32))

    regr = Dense(64)(lstm)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    return Model(inputs=[inp], outputs=[regr])

# %%
multivariate_regression_lstm = build_regression_model(train_regr_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:
# [`Nadam`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Nadam) (*Adam with Nestrov momentum*).

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Функция потерь:
#
# В качестве функции потерь будем использовать [MSE](https://www.tensorflow.org/api_docs/python/tf/keras/losses/MSE) (чтобы штрафовать за большие отклонения). Xотя хорошая функция потерь в контексте темы данной задачи - это [вопрос сложный](https://github.com/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Chapter5_LossFunctions/Ch5_LossFunctions_PyMC3.ipynb). В частности, здесь нам, очевидно, помимо абсолютного значения отклонения также важен его знак.

# %%
multivariate_regression_lstm.compile(optimizer=optimizer,
                                     loss={'regr': 'mse'},
                                     metrics={'regr': 'mae'})

multivariate_regression_lstm.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 120, 18)]         0
# _________________________________________________________________
# lstm (LSTM)                  (None, 120, 16)           2240
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 120, 32)           6272
# _________________________________________________________________
# flatten (Flatten)            (None, 3840)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                245824
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64)                256
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 64)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# regr (Dense)                 (None, 1)                 65
# =================================================================
# Total params: 254,657
# Trainable params: 254,529
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# #### Обучение:

# %%
regr_history = utils.train_model(multivariate_regression_lstm,
                                 model_save_dir, train_regr_gen, test_regr_gen,
                                 callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                 force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 0s - loss: 13.8125 - mae: 1.2187
# Epoch 00001: val_loss improved from inf to 11.79628, saving model to models\lstm2_multivar\regression\01.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 13.7625 - mae: 1.2161 - val_loss: 11.7963 - val_mae: 0.7899
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 0s - loss: 11.7880 - mae: 1.0166
# Epoch 00002: val_loss improved from 11.79628 to 10.87682, saving model to models\lstm2_multivar\regression\02.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 11.7477 - mae: 1.0159 - val_loss: 10.8768 - val_mae: 0.9365
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 10.2604 - mae: 0.9376
# Epoch 00003: val_loss improved from 10.87682 to 9.18742, saving model to models\lstm2_multivar\regression\03.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 10.2315 - mae: 0.9375 - val_loss: 9.1874 - val_mae: 0.7224
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 9.0523 - mae: 0.8890
# Epoch 00004: val_loss improved from 9.18742 to 8.35111, saving model to models\lstm2_multivar\regression\04.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 9.0245 - mae: 0.8892 - val_loss: 8.3511 - val_mae: 0.8748
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.1477 - mae: 0.8558
# Epoch 00005: val_loss improved from 8.35111 to 7.58102, saving model to models\lstm2_multivar\regression\05.hdf5
# 32/32 [==============================] - 36s 1s/step - loss: 8.1298 - mae: 0.8577 - val_loss: 7.5810 - val_mae: 0.7036
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.6013 - mae: 0.8349
# Epoch 00006: val_loss improved from 7.58102 to 7.14096, saving model to models\lstm2_multivar\regression\06.hdf5
# 32/32 [==============================] - 36s 1s/step - loss: 7.5856 - mae: 0.8360 - val_loss: 7.1410 - val_mae: 0.7017
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.2282 - mae: 0.8694
# Epoch 00007: val_loss improved from 7.14096 to 6.74609, saving model to models\lstm2_multivar\regression\07.hdf5
# 32/32 [==============================] - 36s 1s/step - loss: 7.2725 - mae: 0.8753 - val_loss: 6.7461 - val_mae: 0.7171
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.7895 - mae: 0.8300
# Epoch 00008: val_loss improved from 6.74609 to 6.31286, saving model to models\lstm2_multivar\regression\08.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 6.8050 - mae: 0.8331 - val_loss: 6.3129 - val_mae: 0.7262
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.3755 - mae: 0.8309
# Epoch 00009: val_loss improved from 6.31286 to 5.90121, saving model to models\lstm2_multivar\regression\09.hdf5
# 32/32 [==============================] - 36s 1s/step - loss: 6.3721 - mae: 0.8326 - val_loss: 5.9012 - val_mae: 0.7055
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.0533 - mae: 0.8283
# Epoch 00010: val_loss improved from 5.90121 to 5.71079, saving model to models\lstm2_multivar\regression\10.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 6.0397 - mae: 0.8257 - val_loss: 5.7108 - val_mae: 0.6859
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.8254 - mae: 0.7911
# Epoch 00011: val_loss improved from 5.71079 to 5.59560, saving model to models\lstm2_multivar\regression\11.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 5.8226 - mae: 0.7917 - val_loss: 5.5956 - val_mae: 0.7068
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.3612 - mae: 0.7677
# Epoch 00012: val_loss improved from 5.59560 to 5.44425, saving model to models\lstm2_multivar\regression\12.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 5.7615 - mae: 0.7781 - val_loss: 5.4442 - val_mae: 0.7028
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.4408 - mae: 0.7580
# Epoch 00013: val_loss improved from 5.44425 to 5.31224, saving model to models\lstm2_multivar\regression\13.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 5.4361 - mae: 0.7598 - val_loss: 5.3122 - val_mae: 0.7063
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.3261 - mae: 0.7519
# Epoch 00014: val_loss improved from 5.31224 to 5.12498, saving model to models\lstm2_multivar\regression\14.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 5.3141 - mae: 0.7526 - val_loss: 5.1250 - val_mae: 0.6960
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 1s - loss: 5.2470 - mae: 0.7704
# Epoch 00015: val_loss improved from 5.12498 to 5.05339, saving model to models\lstm2_multivar\regression\15.hdf5
# 32/32 [==============================] - 39s 1s/step - loss: 5.2287 - mae: 0.7679 - val_loss: 5.0534 - val_mae: 0.6995
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.1182 - mae: 0.7449
# Epoch 00016: val_loss improved from 5.05339 to 5.00478, saving model to models\lstm2_multivar\regression\16.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 5.1173 - mae: 0.7478 - val_loss: 5.0048 - val_mae: 0.6993
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.0770 - mae: 0.7689
# Epoch 00017: val_loss improved from 5.00478 to 4.94101, saving model to models\lstm2_multivar\regression\17.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 5.0557 - mae: 0.7676 - val_loss: 4.9410 - val_mae: 0.7012
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.9667 - mae: 0.7363
# Epoch 00018: val_loss improved from 4.94101 to 4.87940, saving model to models\lstm2_multivar\regression\18.hdf5
# 32/32 [==============================] - 36s 1s/step - loss: 4.9655 - mae: 0.7387 - val_loss: 4.8794 - val_mae: 0.7067
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.9022 - mae: 0.7438
# Epoch 00019: val_loss improved from 4.87940 to 4.86111, saving model to models\lstm2_multivar\regression\19.hdf5
# 32/32 [==============================] - 36s 1s/step - loss: 4.8954 - mae: 0.7456 - val_loss: 4.8611 - val_mae: 0.7261
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.9914 - mae: 0.7997
# Epoch 00020: val_loss improved from 4.86111 to 4.79502, saving model to models\lstm2_multivar\regression\20.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 4.9681 - mae: 0.7954 - val_loss: 4.7950 - val_mae: 0.7098
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.8786 - mae: 0.7711
# Epoch 00021: val_loss improved from 4.79502 to 4.74211, saving model to models\lstm2_multivar\regression\21.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 4.8741 - mae: 0.7732 - val_loss: 4.7421 - val_mae: 0.7002
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.7911 - mae: 0.7632
# Epoch 00022: val_loss improved from 4.74211 to 4.71882, saving model to models\lstm2_multivar\regression\22.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 4.7743 - mae: 0.7628 - val_loss: 4.7188 - val_mae: 0.7035
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.7287 - mae: 0.7481
# Epoch 00023: val_loss improved from 4.71882 to 4.68477, saving model to models\lstm2_multivar\regression\23.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 4.7091 - mae: 0.7452 - val_loss: 4.6848 - val_mae: 0.7036
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.6622 - mae: 0.7333
# Epoch 00024: val_loss improved from 4.68477 to 4.64538, saving model to models\lstm2_multivar\regression\24.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 4.6541 - mae: 0.7345 - val_loss: 4.6454 - val_mae: 0.6992
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.6714 - mae: 0.7457
# Epoch 00025: val_loss improved from 4.64538 to 4.62423, saving model to models\lstm2_multivar\regression\25.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 4.6621 - mae: 0.7467 - val_loss: 4.6242 - val_mae: 0.6967
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.6491 - mae: 0.7381
# Epoch 00026: val_loss improved from 4.62423 to 4.61277, saving model to models\lstm2_multivar\regression\26.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 4.6553 - mae: 0.7440 - val_loss: 4.6128 - val_mae: 0.6989
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.6475 - mae: 0.7706
# Epoch 00027: val_loss improved from 4.61277 to 4.59443, saving model to models\lstm2_multivar\regression\27.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 4.6496 - mae: 0.7740 - val_loss: 4.5944 - val_mae: 0.6976
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.6499 - mae: 0.7401
# Epoch 00028: val_loss improved from 4.59443 to 4.56973, saving model to models\lstm2_multivar\regression\28.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 4.6428 - mae: 0.7412 - val_loss: 4.5697 - val_mae: 0.6946
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.5450 - mae: 0.7339
# Epoch 00029: val_loss improved from 4.56973 to 4.55364, saving model to models\lstm2_multivar\regression\29.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 4.5318 - mae: 0.7331 - val_loss: 4.5536 - val_mae: 0.6953
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.5361 - mae: 0.7153
# Epoch 00030: val_loss improved from 4.55364 to 4.54203, saving model to models\lstm2_multivar\regression\30.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 4.5319 - mae: 0.7159 - val_loss: 4.5420 - val_mae: 0.6941
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.5300 - mae: 0.7323
# Epoch 00031: val_loss improved from 4.54203 to 4.52990, saving model to models\lstm2_multivar\regression\31.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 4.5372 - mae: 0.7351 - val_loss: 4.5299 - val_mae: 0.6933
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.5637 - mae: 0.7429
# Epoch 00032: val_loss improved from 4.52990 to 4.52033, saving model to models\lstm2_multivar\regression\32.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 4.5545 - mae: 0.7425 - val_loss: 4.5203 - val_mae: 0.6929

# %%
def plot_regr_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'MSE', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'MAE', 'mae', 'val_mae')
    
plot_regr_history(regr_history);

# %% [markdown]
# ### Прогноз задачи регрессии

# %% [markdown]
# *Судя по всему, просто выходит на модель случайного блуждания*

# %%
# загружаем последнюю эпоху с минимальным лоссом
multivariate_regression_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret_test = multivariate_regression_lstm.predict_generator(test_regr_gen, verbose=1)
# Out:
# 13/13 [==============================] - 6s 497ms/step

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret_test, figsize=(16, 10),
                                  datetime_unit='m', plot_data_slice=slice(1, None))

# %% [markdown]
# ## Задача классификации
#
# Прогнозируем направление изменения цены по сравнению с предыдущим периодом (**0** - снижение, **1** - рост).

# %%
model_class_name = 'classification'

# %%
train_clf_gen = ClassificationGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_clf_gen = ClassificationGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_clf_gen = ClassificationGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_classification_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=(16, 32))

    clf = Dense(64)(lstm)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)

    return Model(inputs=[inp], outputs=[clf])

# %%
multivariate_classification_lstm = build_classification_model(test_clf_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
multivariate_classification_lstm.compile(optimizer=optimizer,
                                         loss={'clf': 'binary_crossentropy'},
                                         metrics={'clf': 'accuracy'})

multivariate_classification_lstm.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 120, 18)]         0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 120, 16)           2240
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 120, 32)           6272
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3840)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                245824
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# clf (Dense)                  (None, 1)                 65
# =================================================================
# Total params: 254,657
# Trainable params: 254,529
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
clf_history = utils.train_model(multivariate_classification_lstm,
                                model_save_dir, train_clf_gen, test_clf_gen,
                                callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 0s - loss: 11.3106 - accuracy: 0.4929
# Epoch 00001: val_loss improved from inf to 9.78671, saving model to models\lstm2_multivar\classification\01.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 11.2700 - accuracy: 0.4931 - val_loss: 9.7867 - val_accuracy: 0.5321
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.8569 - accuracy: 0.4909
# Epoch 00002: val_loss improved from 9.78671 to 7.76786, saving model to models\lstm2_multivar\classification\02.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 8.8295 - accuracy: 0.4891 - val_loss: 7.7679 - val_accuracy: 0.4781
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.9042 - accuracy: 0.5232
# Epoch 00003: val_loss improved from 7.76786 to 6.00363, saving model to models\lstm2_multivar\classification\03.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 6.8754 - accuracy: 0.5247 - val_loss: 6.0036 - val_accuracy: 0.5039
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.4592 - accuracy: 0.5464
# Epoch 00004: val_loss improved from 6.00363 to 4.80494, saving model to models\lstm2_multivar\classification\04.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 5.4432 - accuracy: 0.5445 - val_loss: 4.8049 - val_accuracy: 0.5167
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.6156 - accuracy: 0.5252
# Epoch 00005: val_loss improved from 4.80494 to 4.30197, saving model to models\lstm2_multivar\classification\05.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 4.6106 - accuracy: 0.5217 - val_loss: 4.3020 - val_accuracy: 0.5193
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.1200 - accuracy: 0.5353
# Epoch 00006: val_loss improved from 4.30197 to 3.86435, saving model to models\lstm2_multivar\classification\06.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 4.1136 - accuracy: 0.5356 - val_loss: 3.8643 - val_accuracy: 0.5090
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.7308 - accuracy: 0.5514
# Epoch 00007: val_loss improved from 3.86435 to 3.49471, saving model to models\lstm2_multivar\classification\07.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 3.7254 - accuracy: 0.5494 - val_loss: 3.4947 - val_accuracy: 0.5244
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.3930 - accuracy: 0.5433
# Epoch 00008: val_loss improved from 3.49471 to 3.20390, saving model to models\lstm2_multivar\classification\08.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 3.3913 - accuracy: 0.5395 - val_loss: 3.2039 - val_accuracy: 0.4961
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.1026 - accuracy: 0.5514
# Epoch 00009: val_loss improved from 3.20390 to 2.93076, saving model to models\lstm2_multivar\classification\09.hdf5
# 32/32 [==============================] - 38s 1s/step - loss: 3.0984 - accuracy: 0.5524 - val_loss: 2.9308 - val_accuracy: 0.5321
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.9255 - accuracy: 0.5413
# Epoch 00010: val_loss improved from 2.93076 to 2.81346, saving model to models\lstm2_multivar\classification\10.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 2.9221 - accuracy: 0.5415 - val_loss: 2.8135 - val_accuracy: 0.5244
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.8165 - accuracy: 0.5262
# Epoch 00011: val_loss improved from 2.81346 to 2.73111, saving model to models\lstm2_multivar\classification\11.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 2.8096 - accuracy: 0.5296 - val_loss: 2.7311 - val_accuracy: 0.4781
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.6756 - accuracy: 0.5474
# Epoch 00012: val_loss improved from 2.73111 to 2.61393, saving model to models\lstm2_multivar\classification\12.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 2.6722 - accuracy: 0.5474 - val_loss: 2.6139 - val_accuracy: 0.5244
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.5771 - accuracy: 0.5696
# Epoch 00013: val_loss improved from 2.61393 to 2.56049, saving model to models\lstm2_multivar\classification\13.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 2.5758 - accuracy: 0.5682 - val_loss: 2.5605 - val_accuracy: 0.4807
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.5096 - accuracy: 0.5615
# Epoch 00014: val_loss improved from 2.56049 to 2.46034, saving model to models\lstm2_multivar\classification\14.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 2.5051 - accuracy: 0.5642 - val_loss: 2.4603 - val_accuracy: 0.5244
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.4518 - accuracy: 0.5444
# Epoch 00015: val_loss improved from 2.46034 to 2.41412, saving model to models\lstm2_multivar\classification\15.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 2.4504 - accuracy: 0.5455 - val_loss: 2.4141 - val_accuracy: 0.5141
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.4046 - accuracy: 0.5685
# Epoch 00016: val_loss improved from 2.41412 to 2.38800, saving model to models\lstm2_multivar\classification\16.hdf5
# 32/32 [==============================] - 38s 1s/step - loss: 2.4042 - accuracy: 0.5692 - val_loss: 2.3880 - val_accuracy: 0.5244
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 1s - loss: 2.3903 - accuracy: 0.5312
# Epoch 00017: val_loss improved from 2.38800 to 2.36763, saving model to models\lstm2_multivar\classification\17.hdf5
# 32/32 [==============================] - 39s 1s/step - loss: 2.3889 - accuracy: 0.5326 - val_loss: 2.3676 - val_accuracy: 0.5013
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.3348 - accuracy: 0.5484
# Epoch 00018: val_loss improved from 2.36763 to 2.30495, saving model to models\lstm2_multivar\classification\18.hdf5
# 32/32 [==============================] - 37s 1s/step - loss: 2.3310 - accuracy: 0.5514 - val_loss: 2.3049 - val_accuracy: 0.4910
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.3111 - accuracy: 0.5292
# Epoch 00019: val_loss improved from 2.30495 to 2.27883, saving model to models\lstm2_multivar\classification\19.hdf5
# 32/32 [==============================] - 37s 1s/step - loss: 2.3108 - accuracy: 0.5296 - val_loss: 2.2788 - val_accuracy: 0.5270
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 1s - loss: 2.2767 - accuracy: 0.5413
# Epoch 00020: val_loss improved from 2.27883 to 2.26175, saving model to models\lstm2_multivar\classification\20.hdf5
# 32/32 [==============================] - 40s 1s/step - loss: 2.2742 - accuracy: 0.5435 - val_loss: 2.2618 - val_accuracy: 0.5270
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2595 - accuracy: 0.5534
# Epoch 00021: val_loss improved from 2.26175 to 2.23294, saving model to models\lstm2_multivar\classification\21.hdf5
# 32/32 [==============================] - 38s 1s/step - loss: 2.2580 - accuracy: 0.5514 - val_loss: 2.2329 - val_accuracy: 0.4961
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2488 - accuracy: 0.5464
# Epoch 00022: val_loss improved from 2.23294 to 2.22182, saving model to models\lstm2_multivar\classification\22.hdf5
# 32/32 [==============================] - 37s 1s/step - loss: 2.2483 - accuracy: 0.5445 - val_loss: 2.2218 - val_accuracy: 0.5039
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2245 - accuracy: 0.5595
# Epoch 00023: val_loss improved from 2.22182 to 2.20667, saving model to models\lstm2_multivar\classification\23.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 2.2229 - accuracy: 0.5613 - val_loss: 2.2067 - val_accuracy: 0.5013
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2098 - accuracy: 0.5514
# Epoch 00024: val_loss improved from 2.20667 to 2.19499, saving model to models\lstm2_multivar\classification\24.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 2.2060 - accuracy: 0.5553 - val_loss: 2.1950 - val_accuracy: 0.4987
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1933 - accuracy: 0.5575
# Epoch 00025: val_loss improved from 2.19499 to 2.18966, saving model to models\lstm2_multivar\classification\25.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 2.1890 - accuracy: 0.5593 - val_loss: 2.1897 - val_accuracy: 0.5167
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1911 - accuracy: 0.5625
# Epoch 00026: val_loss improved from 2.18966 to 2.18335, saving model to models\lstm2_multivar\classification\26.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 2.1860 - accuracy: 0.5672 - val_loss: 2.1833 - val_accuracy: 0.5244
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1828 - accuracy: 0.5423
# Epoch 00027: val_loss improved from 2.18335 to 2.18009, saving model to models\lstm2_multivar\classification\27.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 2.1859 - accuracy: 0.5395 - val_loss: 2.1801 - val_accuracy: 0.5167
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1827 - accuracy: 0.5252
# Epoch 00028: val_loss improved from 2.18009 to 2.16478, saving model to models\lstm2_multivar\classification\28.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 2.1811 - accuracy: 0.5277 - val_loss: 2.1648 - val_accuracy: 0.5013
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1597 - accuracy: 0.5565
# Epoch 00029: val_loss improved from 2.16478 to 2.15697, saving model to models\lstm2_multivar\classification\29.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 2.1594 - accuracy: 0.5573 - val_loss: 2.1570 - val_accuracy: 0.4961
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1547 - accuracy: 0.5403
# Epoch 00030: val_loss improved from 2.15697 to 2.15169, saving model to models\lstm2_multivar\classification\30.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 2.1513 - accuracy: 0.5425 - val_loss: 2.1517 - val_accuracy: 0.4987
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1585 - accuracy: 0.5575
# Epoch 00031: val_loss improved from 2.15169 to 2.14638, saving model to models\lstm2_multivar\classification\31.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 2.1585 - accuracy: 0.5583 - val_loss: 2.1464 - val_accuracy: 0.4987
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1425 - accuracy: 0.5433
# Epoch 00032: val_loss improved from 2.14638 to 2.14297, saving model to models\lstm2_multivar\classification\32.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 2.1408 - accuracy: 0.5425 - val_loss: 2.1430 - val_accuracy: 0.5013

# %%
def plot_clf_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'Loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'Accuracy', 'accuracy', 'val_accuracy')
    
plot_clf_history(clf_history);

# %% [markdown]
# ### Прогноз задачи классификации

# %%
# загружаем последнюю эпоху с минимальным лоссом
multivariate_classification_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %%
pred_direction_proba = multivariate_classification_lstm.predict_generator(test_clf_gen, verbose=1)

true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 13/13 [==============================] - 6s 449ms/step
# 0.5134252

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([203, 186], dtype=int64)),
#  (array([0, 1]), array([201, 188], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.51      0.51       203
#            1       0.47      0.47      0.47       186
#
#     accuracy                           0.49       389
#    macro avg       0.49      0.49      0.49       389
# weighted avg       0.49      0.49      0.49       389

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[103, 100],
#        [ 98,  88]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.51243781, 0.53191489],
#        [0.48756219, 0.46808511]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# ## Многозадачная модель: одновременно регрессия и классификация

# %%
model_class_name = 'multitask'

# %%
train_multi_gen = MultitaskGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_multi_gen = MultitaskGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_multi_gen = MultitaskGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_multitask_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=(16, 32))

    # первый выход: задача регрссии
    regr = Dense(64)(lstm)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    # второй выход: задача классификации
    clf = Dense(64)(lstm)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)
    
    return Model(inputs=[inp], outputs=[regr, clf])

# %%
multivariate_multitask_lstm = build_multitask_model(train_multi_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
multivariate_multitask_lstm.compile(optimizer=optimizer,
                                    loss={'regr': 'mse', 'clf': 'binary_crossentropy'},
                                    loss_weights={'regr': 2., 'clf': 1.},
                                    metrics={'regr': 'mae', 'clf' : 'accuracy'})

multivariate_multitask_lstm.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 120, 18)]    0
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 120, 16)      2240        input[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 120, 32)      6272        lstm_4[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 3840)         0           lstm_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           245824      flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           245824      flatten_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64)           256         dense_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64)           256         dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 64)           0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 64)           0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64)           0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64)           0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# regr (Dense)                    (None, 1)            65          dropout_2[0][0]
# __________________________________________________________________________________________________
# clf (Dense)                     (None, 1)            65          dropout_3[0][0]
# ==================================================================================================
# Total params: 500,802
# Trainable params: 500,546
# Non-trainable params: 256
# __________________________________________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
multitask_history = utils.train_model(multivariate_multitask_lstm,
                                      model_save_dir, train_multi_gen, test_multi_gen,
                                      callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                      force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 0s - loss: 17.0087 - regr_loss: 2.4198 - clf_loss: 0.9134 - regr_mae: 1.1466 - clf_accuracy: 0.5312
# Epoch 00001: val_loss improved from inf to 13.78179, saving model to models\lstm2_multivar\multitask\01.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 16.9334 - regr_loss: 2.3899 - clf_loss: 0.9102 - regr_mae: 1.1438 - clf_accuracy: 0.5316 - val_loss: 13.7818 - val_regr_loss: 1.1357 - val_clf_loss: 0.7089 - val_regr_mae: 0.6789 - val_clf_accuracy: 0.5090
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 0s - loss: 15.1912 - regr_loss: 2.0087 - clf_loss: 0.8394 - regr_mae: 1.0524 - clf_accuracy: 0.4859
# Epoch 00002: val_loss improved from 13.78179 to 12.83869, saving model to models\lstm2_multivar\multitask\02.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 15.1038 - regr_loss: 1.9764 - clf_loss: 0.8313 - regr_mae: 1.0475 - clf_accuracy: 0.4901 - val_loss: 12.8387 - val_regr_loss: 1.1674 - val_clf_loss: 0.7075 - val_regr_mae: 0.6950 - val_clf_accuracy: 0.5039
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 13.6297 - regr_loss: 1.7627 - clf_loss: 0.7819 - regr_mae: 0.9527 - clf_accuracy: 0.5292
# Epoch 00003: val_loss improved from 12.83869 to 12.07742, saving model to models\lstm2_multivar\multitask\03.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 13.5683 - regr_loss: 1.7422 - clf_loss: 0.7763 - regr_mae: 0.9502 - clf_accuracy: 0.5316 - val_loss: 12.0774 - val_regr_loss: 1.2808 - val_clf_loss: 0.7208 - val_regr_mae: 0.7275 - val_clf_accuracy: 0.4961
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 12.2441 - regr_loss: 1.5544 - clf_loss: 0.7831 - regr_mae: 0.8838 - clf_accuracy: 0.5071
# Epoch 00004: val_loss improved from 12.07742 to 10.83118, saving model to models\lstm2_multivar\multitask\04.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 12.2289 - regr_loss: 1.5529 - clf_loss: 0.7850 - regr_mae: 0.8856 - clf_accuracy: 0.5069 - val_loss: 10.8312 - val_regr_loss: 1.1203 - val_clf_loss: 0.7220 - val_regr_mae: 0.6711 - val_clf_accuracy: 0.5193
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 11.6116 - regr_loss: 1.5965 - clf_loss: 0.7572 - regr_mae: 0.8851 - clf_accuracy: 0.5403
# Epoch 00005: val_loss improved from 10.83118 to 10.52774, saving model to models\lstm2_multivar\multitask\05.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 11.5446 - regr_loss: 1.5677 - clf_loss: 0.7537 - regr_mae: 0.8810 - clf_accuracy: 0.5405 - val_loss: 10.5277 - val_regr_loss: 1.1913 - val_clf_loss: 0.7134 - val_regr_mae: 0.7004 - val_clf_accuracy: 0.5270
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 10.7597 - regr_loss: 1.3871 - clf_loss: 0.7521 - regr_mae: 0.8411 - clf_accuracy: 0.5433
# Epoch 00006: val_loss improved from 10.52774 to 10.12293, saving model to models\lstm2_multivar\multitask\06.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 10.8240 - regr_loss: 1.4201 - clf_loss: 0.7577 - regr_mae: 0.8448 - clf_accuracy: 0.5395 - val_loss: 10.1229 - val_regr_loss: 1.1989 - val_clf_loss: 0.7149 - val_regr_mae: 0.7117 - val_clf_accuracy: 0.5039
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 10.4359 - regr_loss: 1.4205 - clf_loss: 0.7748 - regr_mae: 0.8358 - clf_accuracy: 0.5171
# Epoch 00007: val_loss improved from 10.12293 to 9.62519, saving model to models\lstm2_multivar\multitask\07.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 10.3838 - regr_loss: 1.3966 - clf_loss: 0.7760 - regr_mae: 0.8313 - clf_accuracy: 0.5148 - val_loss: 9.6252 - val_regr_loss: 1.1543 - val_clf_loss: 0.7078 - val_regr_mae: 0.6886 - val_clf_accuracy: 0.5013
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 9.8937 - regr_loss: 1.3618 - clf_loss: 0.7393 - regr_mae: 0.8084 - clf_accuracy: 0.5333
# Epoch 00008: val_loss improved from 9.62519 to 9.22671, saving model to models\lstm2_multivar\multitask\08.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 9.8409 - regr_loss: 1.3364 - clf_loss: 0.7427 - regr_mae: 0.8057 - clf_accuracy: 0.5326 - val_loss: 9.2267 - val_regr_loss: 1.1449 - val_clf_loss: 0.7069 - val_regr_mae: 0.6922 - val_clf_accuracy: 0.4961
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 9.4462 - regr_loss: 1.3310 - clf_loss: 0.7245 - regr_mae: 0.7976 - clf_accuracy: 0.5534
# Epoch 00009: val_loss did not improve from 9.22671
# 32/32 [==============================] - 35s 1s/step - loss: 9.4005 - regr_loss: 1.3108 - clf_loss: 0.7242 - regr_mae: 0.7939 - clf_accuracy: 0.5524 - val_loss: 9.2549 - val_regr_loss: 1.3338 - val_clf_loss: 0.7171 - val_regr_mae: 0.7636 - val_clf_accuracy: 0.5090
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 9.2428 - regr_loss: 1.3546 - clf_loss: 0.7465 - regr_mae: 0.7916 - clf_accuracy: 0.5393
# Epoch 00010: val_loss improved from 9.22671 to 8.85744, saving model to models\lstm2_multivar\multitask\10.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 9.2026 - regr_loss: 1.3380 - clf_loss: 0.7418 - regr_mae: 0.7910 - clf_accuracy: 0.5385 - val_loss: 8.8574 - val_regr_loss: 1.2282 - val_clf_loss: 0.7063 - val_regr_mae: 0.7209 - val_clf_accuracy: 0.5193
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.9581 - regr_loss: 1.3054 - clf_loss: 0.7324 - regr_mae: 0.7604 - clf_accuracy: 0.5302
# Epoch 00011: val_loss improved from 8.85744 to 8.61471, saving model to models\lstm2_multivar\multitask\11.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 8.9125 - regr_loss: 1.2842 - clf_loss: 0.7315 - regr_mae: 0.7571 - clf_accuracy: 0.5316 - val_loss: 8.6147 - val_regr_loss: 1.1923 - val_clf_loss: 0.7054 - val_regr_mae: 0.7082 - val_clf_accuracy: 0.4961
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.7552 - regr_loss: 1.2906 - clf_loss: 0.7281 - regr_mae: 0.7759 - clf_accuracy: 0.5595
# Epoch 00012: val_loss improved from 8.61471 to 8.49892, saving model to models\lstm2_multivar\multitask\12.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 8.6986 - regr_loss: 1.2657 - clf_loss: 0.7230 - regr_mae: 0.7715 - clf_accuracy: 0.5613 - val_loss: 8.4989 - val_regr_loss: 1.2167 - val_clf_loss: 0.7081 - val_regr_mae: 0.7150 - val_clf_accuracy: 0.5193
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.6201 - regr_loss: 1.3049 - clf_loss: 0.7291 - regr_mae: 0.7533 - clf_accuracy: 0.5292
# Epoch 00013: val_loss improved from 8.49892 to 8.30699, saving model to models\lstm2_multivar\multitask\13.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 8.5986 - regr_loss: 1.2947 - clf_loss: 0.7301 - regr_mae: 0.7549 - clf_accuracy: 0.5277 - val_loss: 8.3070 - val_regr_loss: 1.2033 - val_clf_loss: 0.7046 - val_regr_mae: 0.7143 - val_clf_accuracy: 0.5039
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.5247 - regr_loss: 1.3367 - clf_loss: 0.7307 - regr_mae: 0.7799 - clf_accuracy: 0.5252
# Epoch 00014: val_loss improved from 8.30699 to 8.16771, saving model to models\lstm2_multivar\multitask\14.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 8.5056 - regr_loss: 1.3292 - clf_loss: 0.7287 - regr_mae: 0.7814 - clf_accuracy: 0.5267 - val_loss: 8.1677 - val_regr_loss: 1.2091 - val_clf_loss: 0.7112 - val_regr_mae: 0.7189 - val_clf_accuracy: 0.4807
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.1721 - regr_loss: 1.2302 - clf_loss: 0.7117 - regr_mae: 0.7611 - clf_accuracy: 0.5655
# Epoch 00015: val_loss improved from 8.16771 to 8.04925, saving model to models\lstm2_multivar\multitask\15.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 8.1339 - regr_loss: 1.2084 - clf_loss: 0.7179 - regr_mae: 0.7571 - clf_accuracy: 0.5623 - val_loss: 8.0493 - val_regr_loss: 1.1898 - val_clf_loss: 0.7116 - val_regr_mae: 0.7095 - val_clf_accuracy: 0.4987
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.9873 - regr_loss: 1.1737 - clf_loss: 0.7183 - regr_mae: 0.7368 - clf_accuracy: 0.5504
# Epoch 00016: val_loss improved from 8.04925 to 8.00983, saving model to models\lstm2_multivar\multitask\16.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 7.9601 - regr_loss: 1.1601 - clf_loss: 0.7191 - regr_mae: 0.7354 - clf_accuracy: 0.5504 - val_loss: 8.0098 - val_regr_loss: 1.2038 - val_clf_loss: 0.7208 - val_regr_mae: 0.7150 - val_clf_accuracy: 0.4730
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.0920 - regr_loss: 1.2444 - clf_loss: 0.7582 - regr_mae: 0.7567 - clf_accuracy: 0.4950
# Epoch 00017: val_loss improved from 8.00983 to 7.94135, saving model to models\lstm2_multivar\multitask\17.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 8.0660 - regr_loss: 1.2323 - clf_loss: 0.7572 - regr_mae: 0.7544 - clf_accuracy: 0.4970 - val_loss: 7.9414 - val_regr_loss: 1.2110 - val_clf_loss: 0.7148 - val_regr_mae: 0.7178 - val_clf_accuracy: 0.4781
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.9756 - regr_loss: 1.2445 - clf_loss: 0.7180 - regr_mae: 0.7558 - clf_accuracy: 0.5685
# Epoch 00018: val_loss improved from 7.94135 to 7.92285, saving model to models\lstm2_multivar\multitask\18.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 7.9249 - regr_loss: 1.2208 - clf_loss: 0.7153 - regr_mae: 0.7533 - clf_accuracy: 0.5692 - val_loss: 7.9228 - val_regr_loss: 1.2441 - val_clf_loss: 0.7063 - val_regr_mae: 0.7316 - val_clf_accuracy: 0.5013
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.7813 - regr_loss: 1.1858 - clf_loss: 0.7168 - regr_mae: 0.7417 - clf_accuracy: 0.5534
# Epoch 00019: val_loss improved from 7.92285 to 7.74995, saving model to models\lstm2_multivar\multitask\19.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 7.7415 - regr_loss: 1.1651 - clf_loss: 0.7191 - regr_mae: 0.7386 - clf_accuracy: 0.5504 - val_loss: 7.7499 - val_regr_loss: 1.1974 - val_clf_loss: 0.7022 - val_regr_mae: 0.7123 - val_clf_accuracy: 0.5193
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.7528 - regr_loss: 1.1972 - clf_loss: 0.7239 - regr_mae: 0.7619 - clf_accuracy: 0.5413
# Epoch 00020: val_loss improved from 7.74995 to 7.71942, saving model to models\lstm2_multivar\multitask\20.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 7.7134 - regr_loss: 1.1758 - clf_loss: 0.7274 - regr_mae: 0.7586 - clf_accuracy: 0.5375 - val_loss: 7.7194 - val_regr_loss: 1.2009 - val_clf_loss: 0.7031 - val_regr_mae: 0.7147 - val_clf_accuracy: 0.5167
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.6642 - regr_loss: 1.1823 - clf_loss: 0.7024 - regr_mae: 0.7579 - clf_accuracy: 0.5786
# Epoch 00021: val_loss improved from 7.71942 to 7.70304, saving model to models\lstm2_multivar\multitask\21.hdf5
# 32/32 [==============================] - 37s 1s/step - loss: 7.6353 - regr_loss: 1.1705 - clf_loss: 0.6972 - regr_mae: 0.7585 - clf_accuracy: 0.5830 - val_loss: 7.7030 - val_regr_loss: 1.2097 - val_clf_loss: 0.7065 - val_regr_mae: 0.7172 - val_clf_accuracy: 0.5064
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 31/32 [============================>.] - ETA: 1s - loss: 7.7682 - regr_loss: 1.2500 - clf_loss: 0.7085 - regr_mae: 0.7730 - clf_accuracy: 0.5817
# Epoch 00022: val_loss improved from 7.70304 to 7.62203, saving model to models\lstm2_multivar\multitask\22.hdf5
# 32/32 [==============================] - 41s 1s/step - loss: 7.7222 - regr_loss: 1.2253 - clf_loss: 0.7119 - regr_mae: 0.7672 - clf_accuracy: 0.5800 - val_loss: 7.6220 - val_regr_loss: 1.1870 - val_clf_loss: 0.7082 - val_regr_mae: 0.7081 - val_clf_accuracy: 0.5090
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.6260 - regr_loss: 1.1885 - clf_loss: 0.7267 - regr_mae: 0.7464 - clf_accuracy: 0.5192
# Epoch 00023: val_loss improved from 7.62203 to 7.58714, saving model to models\lstm2_multivar\multitask\23.hdf5
# 32/32 [==============================] - 38s 1s/step - loss: 7.5841 - regr_loss: 1.1682 - clf_loss: 0.7257 - regr_mae: 0.7426 - clf_accuracy: 0.5188 - val_loss: 7.5871 - val_regr_loss: 1.1877 - val_clf_loss: 0.7093 - val_regr_mae: 0.7086 - val_clf_accuracy: 0.5039
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.5120 - regr_loss: 1.1608 - clf_loss: 0.7056 - regr_mae: 0.7349 - clf_accuracy: 0.5635
# Epoch 00024: val_loss improved from 7.58714 to 7.56393, saving model to models\lstm2_multivar\multitask\24.hdf5
# 32/32 [==============================] - 36s 1s/step - loss: 7.6296 - regr_loss: 1.2197 - clf_loss: 0.7072 - regr_mae: 0.7457 - clf_accuracy: 0.5613 - val_loss: 7.5639 - val_regr_loss: 1.1951 - val_clf_loss: 0.7086 - val_regr_mae: 0.7118 - val_clf_accuracy: 0.4961
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.5423 - regr_loss: 1.1804 - clf_loss: 0.7257 - regr_mae: 0.7312 - clf_accuracy: 0.5433
# Epoch 00025: val_loss improved from 7.56393 to 7.55006, saving model to models\lstm2_multivar\multitask\25.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 7.5405 - regr_loss: 1.1798 - clf_loss: 0.7253 - regr_mae: 0.7335 - clf_accuracy: 0.5415 - val_loss: 7.5501 - val_regr_loss: 1.1979 - val_clf_loss: 0.7083 - val_regr_mae: 0.7132 - val_clf_accuracy: 0.4936
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 31/32 [============================>.] - ETA: 1s - loss: 7.5471 - regr_loss: 1.2011 - clf_loss: 0.7080 - regr_mae: 0.7658 - clf_accuracy: 0.5625
# Epoch 00026: val_loss improved from 7.55006 to 7.54449, saving model to models\lstm2_multivar\multitask\26.hdf5
# 32/32 [==============================] - 40s 1s/step - loss: 7.5110 - regr_loss: 1.1822 - clf_loss: 0.7096 - regr_mae: 0.7630 - clf_accuracy: 0.5603 - val_loss: 7.5445 - val_regr_loss: 1.2041 - val_clf_loss: 0.7094 - val_regr_mae: 0.7170 - val_clf_accuracy: 0.4910
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.4733 - regr_loss: 1.1621 - clf_loss: 0.7311 - regr_mae: 0.7290 - clf_accuracy: 0.5605
# Epoch 00027: val_loss improved from 7.54449 to 7.51310, saving model to models\lstm2_multivar\multitask\27.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 7.4538 - regr_loss: 1.1530 - clf_loss: 0.7298 - regr_mae: 0.7303 - clf_accuracy: 0.5613 - val_loss: 7.5131 - val_regr_loss: 1.1983 - val_clf_loss: 0.7086 - val_regr_mae: 0.7141 - val_clf_accuracy: 0.4884
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.6322 - regr_loss: 1.2616 - clf_loss: 0.7099 - regr_mae: 0.7643 - clf_accuracy: 0.5433
# Epoch 00028: val_loss improved from 7.51310 to 7.47891, saving model to models\lstm2_multivar\multitask\28.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 7.6065 - regr_loss: 1.2499 - clf_loss: 0.7076 - regr_mae: 0.7634 - clf_accuracy: 0.5445 - val_loss: 7.4789 - val_regr_loss: 1.1907 - val_clf_loss: 0.7084 - val_regr_mae: 0.7102 - val_clf_accuracy: 0.5013
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.4022 - regr_loss: 1.1538 - clf_loss: 0.7145 - regr_mae: 0.7388 - clf_accuracy: 0.5514
# Epoch 00029: val_loss improved from 7.47891 to 7.46442, saving model to models\lstm2_multivar\multitask\29.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 7.3819 - regr_loss: 1.1440 - clf_loss: 0.7139 - regr_mae: 0.7393 - clf_accuracy: 0.5514 - val_loss: 7.4644 - val_regr_loss: 1.1928 - val_clf_loss: 0.7087 - val_regr_mae: 0.7108 - val_clf_accuracy: 0.4961
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.4623 - regr_loss: 1.1936 - clf_loss: 0.7096 - regr_mae: 0.7388 - clf_accuracy: 0.5514
# Epoch 00030: val_loss improved from 7.46442 to 7.46402, saving model to models\lstm2_multivar\multitask\30.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 7.4184 - regr_loss: 1.1690 - clf_loss: 0.7147 - regr_mae: 0.7334 - clf_accuracy: 0.5455 - val_loss: 7.4640 - val_regr_loss: 1.1973 - val_clf_loss: 0.7092 - val_regr_mae: 0.7128 - val_clf_accuracy: 0.4961
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.4313 - regr_loss: 1.1903 - clf_loss: 0.6950 - regr_mae: 0.7425 - clf_accuracy: 0.5655
# Epoch 00031: val_loss improved from 7.46402 to 7.46161, saving model to models\lstm2_multivar\multitask\31.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 7.4381 - regr_loss: 1.1937 - clf_loss: 0.6951 - regr_mae: 0.7456 - clf_accuracy: 0.5652 - val_loss: 7.4616 - val_regr_loss: 1.2005 - val_clf_loss: 0.7100 - val_regr_mae: 0.7142 - val_clf_accuracy: 0.4884
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.4266 - regr_loss: 1.1793 - clf_loss: 0.7219 - regr_mae: 0.7218 - clf_accuracy: 0.5393
# Epoch 00032: val_loss improved from 7.46161 to 7.45463, saving model to models\lstm2_multivar\multitask\32.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 7.4070 - regr_loss: 1.1681 - clf_loss: 0.7245 - regr_mae: 0.7215 - clf_accuracy: 0.5366 - val_loss: 7.4546 - val_regr_loss: 1.2015 - val_clf_loss: 0.7107 - val_regr_mae: 0.7146 - val_clf_accuracy: 0.4936

# %%
def plot_multitask_history(hist):
    fig, ax = plt.subplots(2, 2, figsize=(16, 12))
    plotHelpers.plot_train_history(ax[0, 0], hist, 'Total loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[0, 1], hist, 'Accuracy', 'clf_accuracy', 'val_clf_accuracy')
    plotHelpers.plot_train_history(ax[1, 0], hist, 'MSE', 'regr_loss', 'val_regr_loss')
    plotHelpers.plot_train_history(ax[1, 1], hist, 'MAE', 'regr_mae', 'val_regr_mae')
    
plot_multitask_history(multitask_history);

# %% [markdown]
# ### Прогноз

# %%
# загружаем последнюю эпоху с минимальным лоссом
multivariate_multitask_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret, pred_direction_proba = multivariate_multitask_lstm.predict_generator(test_multi_gen, verbose=1)
# Out:
# 13/13 [==============================] - 6s 462ms/step

# %%
np.set_printoptions(precision=3, suppress=True)

np.column_stack([pred_log_ret, pred_direction_proba])[-10:]
# Out:
# array([[ 0.107,  0.559],
#        [ 0.047,  0.546],
#        [-0.005,  0.54 ],
#        [-0.004,  0.543],
#        [ 0.012,  0.56 ],
#        [ 0.067,  0.583],
#        [ 0.127,  0.606],
#        [ 0.198,  0.611],
#        [ 0.267,  0.614],
#        [ 0.325,  0.612]], dtype=float32)

# %% [markdown]
# #### Прогноз задачи регрессии

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret, figsize=(16, 10),
                                  datetime_unit='m', plot_data_slice=slice(1, None))

# %% [markdown]
# #### Прогноз задачи классификации

# %%
true_direction = test_multi_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 0.5205574

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([203, 186], dtype=int64)),
#  (array([0, 1]), array([192, 197], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.49      0.51       203
#            1       0.48      0.51      0.49       186
#
#     accuracy                           0.50       389
#    macro avg       0.50      0.50      0.50       389
# weighted avg       0.50      0.50      0.50       389

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[100, 103],
#        [ 92,  94]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.521, 0.523],
#        [0.479, 0.477]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# # Выводы
#
# 1.  Размер батча сильно влияет на скорость обучения.
# 2.  Инициализация весов (`bias_initializer`) в слое **LSTM** оказалась очень важным параметром.
# 3.  Модель регрессии приближается к случайному блужданию.
# 4.  Задача классификации не решается удовлетворительно.

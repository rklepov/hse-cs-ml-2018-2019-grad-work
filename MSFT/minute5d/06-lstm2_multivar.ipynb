# %% [markdown]
# <a href="https://colab.research.google.com/github/rklepov/hse-cs-ml-2018-2019-grad-work/blob/CVX-1yr/CVX/daily1y/06-lstm2_multivar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # *Многомерная модель на LSTM* (2 слоя)
#
# В качестве признаков используются цены, объём торгов и некоторое число индикаторов (всего 18 признаков)

# %%
import os
import glob
import datetime
import pickle

import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from pandas_datareader import data as pdr

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
import tensorflow as tf
# tf.test.is_gpu_available()
tf.__version__
# Out:
# '2.0.0'

# %%
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Input, Dense, LSTM, GRU, Flatten, ReLU, LeakyReLU, Dropout, BatchNormalization
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers import Nadam

# %%
import mdp

from mdp import TimeSeries
from mdp import MarketData
from mdp import MovingWindowFeatures
from mdp import ClassificationGenerator, RegressionGenerator, MultitaskGenerator
from mdp import invert_log_ret

import mdp.utils as utils
import mdp.plotHelpers as plotHelpers

# %%
import importlib

import mdp

importlib.reload(mdp)
importlib.reload(mdp.datasetGenerator)
importlib.reload(mdp.marketData)
importlib.reload(mdp.movingWindowFeatures)
importlib.reload(mdp.timeSeries)
importlib.reload(mdp.plotHelpers)
importlib.reload(mdp.utils);

# %% [markdown]
# # *Параметры*

# %%
INSTRUMENT = 'MSFT' # Microsoft corp
START_FROM = np.datetime64('today') - 7
WINDOW_SIZE = 120
FORECAST_OFFSET=1
BATCH_SIZE = 32
FORCE_TRAIN = True

# %% [markdown]
# # *Исходные данные*
#
# Загрузка данных и вычисление индикаторов.

# %%
instr = MarketData.create_from_alphavantage_intraday(INSTRUMENT, start=START_FROM)

# %%
instr.feature_names
# Out:
# ['o',
#  'h',
#  'l',
#  'c',
#  'v',
#  'ema14',
#  'ema30',
#  'macd',
#  'macd_signal',
#  'rsi14',
#  'bband20_upper',
#  'bband20_middle',
#  'bband20_lower',
#  'willr14',
#  'stochk',
#  'stochd',
#  'adline',
#  'adosc']

# %% [markdown]
# Здесь не будем делить отдельно на тест и валидацию, поскольку данных у нас только 5 дней.

# %%
dates_unique = np.unique(instr.timestamps.astype('datetime64[D]'))

START_FROM = dates_unique[0]
VAL_TEST_SPLIT = dates_unique[-1]

START_FROM, VAL_TEST_SPLIT
# Out:
# (numpy.datetime64('2020-04-08'), numpy.datetime64('2020-04-14'))

# %% [markdown]
# ## Целевая переменная

# %% [markdown]
# Цена закрытия.

# %%
orig_target = instr.c

# %%
def plot_transformed_series(instrument, series, orig_display_name, transformed_display_name):
    plotHelpers.plot_transformed_timeseries(
        instrument.instrument,
        series,
        title_orig = orig_display_name,
        xlabel_orig = 'Date',
        ylabel_orig = orig_display_name,
        title_transformed = transformed_display_name,
        xlabel_transformed = 'Date',
        ylabel_transformed = transformed_display_name
    )

# %% [markdown]
# Переходим к логарифмической доходности.

# %%
transformed_target = instr.c.transform(transforms={'ratios' : {}, 'ln' : {}})

# %%
plotHelpers.plot_transformed_timeseries_unit(instr,
                                             transformed_target,
                                             'Close price, USD', 'Log return',
                                             datetime_unit='m', rotation=45)

# %% [markdown]
# ## Трансформация признаков
#
# Приведение временных рядов к стационарности.

# %%
def make_feature_selector():
    price_transformer = lambda: {'ratios': {}, 'ln': {}}
    diff_transformer = lambda o: {'diffs': {'order': o}}
    identity_transformer = lambda: {}
    feature_transformations = {
        'o': price_transformer(),
        'h': price_transformer(),
        'l': price_transformer(),
        'c': price_transformer(),
        'v': diff_transformer(1),
        'ema14': diff_transformer(1),
        'ema30': diff_transformer(1),
        'macd': identity_transformer(),
        'macd_signal': identity_transformer(),
        'rsi14': identity_transformer(),
        'bband20_upper': diff_transformer(1),
        'bband20_middle': diff_transformer(1),
        'bband20_lower': diff_transformer(1),
        'willr14': identity_transformer(),
        'stochd': identity_transformer(),
        'stochk': identity_transformer(),
        'adline': diff_transformer(1),
        'adosc': identity_transformer()
    }
    return feature_transformations

# %%
instr_transformed = instr.select_transform(make_feature_selector())

# %%
transformed_target = instr_transformed.c

# %% [markdown]
# ## Обучающая, валидационная и тестовая выборки

# %%
instr_train, instr_test = instr_transformed.train_test_split(VAL_TEST_SPLIT, window_size=WINDOW_SIZE,
                                                             scaler=StandardScaler)
#                                                              scaler=MinMaxScaler,
#                                                              scaler_kwargs={'feature_range': (-1, 1)})

# instr_val, instr_test = instr_val_test.train_test_split(TEST_SPLIT, window_size=WINDOW_SIZE, scaler=None)

len(instr_train), len(instr_test)
# Out:
# (1134, 508)

# %% [markdown]
# Все отмасштабированные признаки на одном графике (для валидационного датасета):

# %%
plotHelpers.plot_all_features(instr_test)

# %% [markdown]
# ## Признаки - скользящие окна

# %%
train_mwf = MovingWindowFeatures.create(instr_train.c, [instr_train], instr_train.feature_names, window_size=WINDOW_SIZE)
# val_mwf = MovingWindowFeatures.create(instr_val.c, [instr_val], instr_val.feature_names, window_size=WINDOW_SIZE)
test_mwf = MovingWindowFeatures.create(instr_test.c, [instr_test], instr_test.feature_names, window_size=WINDOW_SIZE)

len(instr_train), len(train_mwf), train_mwf.features.shape
# Out:
# (1134, 1014, (1014, 120, 18))

# %% [markdown]
# Проверка, что скользящие окна соответствуют исходным данным.
#
# Возьмём произвольный признак и произвольное окно (строка #**41**). Проверим, что данные в точности совпадают:

# %%
def check_data(md, mwf, row):
    col = np.random.randint(len(mwf.feature_names))
    feature = mwf.feature_names[col]
    check = (getattr(md, feature).data[row:row + mwf.window_size] == mwf.features[row, :, col]).all()
    assert check
    return feature, check

check_data(instr_train, train_mwf, 41)
# Out:
# ('bband20_middle', True)

# %% [markdown]
# # *Модели*

# %% [markdown]
# Модель с двумя LSTM слоями.

# %%
def build_lstm_layers(input_shape, latent_dim=(16, 32)):
    # формат входа: наша матрица (окно; признак)
    inp = Input(input_shape, name='input')

    # стекаем два уровня LSTM
    lstm = LSTM(latent_dim[0], return_sequences=True, 
                    recurrent_dropout=0.2, dropout=0.2, 
                    bias_initializer='he_uniform',
                    bias_regularizer=L1L2(0.01, 0.02),
                    kernel_regularizer=L1L2(0.01, 0.02),
                    recurrent_regularizer=L1L2(0.01, 0.02)
               )(inp)

    lstm = LSTM(latent_dim[1], return_sequences=True,
                    recurrent_dropout=0.2, dropout=0.2,
                    bias_initializer='he_uniform',
                    bias_regularizer=L1L2(0.01, 0.02),
                    kernel_regularizer=L1L2(0.01, 0.02),
                    recurrent_regularizer=L1L2(0.01, 0.02)
               )(lstm)
    
    lstm = Flatten()(lstm)
    
    return inp, lstm

# %% [markdown]
# #### Пути сохранения моделей:

# %%
model_path_root = 'models'
model_type_name = 'lstm2_multivar'

def make_model_save_dir(path_root, type_name, class_name):
    save_dir = os.path.join(path_root, type_name, class_name)
    os.makedirs(save_dir, exist_ok=True)
    return save_dir

# %% [markdown]
# #### Общие коллбэки:

# %%
# уменьшение learning rate в случае, если loss не изменяется
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001, verbose=1)

# уменьшение learning rate в 2 раза каждую 5-ю эпоху
def lr_decay(e, lr):
    return lr * (1 - 0.5 * (0 == (e + 1) % 5))

lr_scheduler = LearningRateScheduler(schedule=lr_decay, verbose=1)

# %% [markdown]
# ## Задача регрессии
#
# Непосредственное прогнозирование цены следующего периода.

# %%
train_regr_gen = RegressionGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_regr_gen = RegressionGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_regr_gen = RegressionGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# Следующие числа соответствуют значению параметра `steps_per_epoch` метода [`fit_generator`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit_generator "tf.keras.layers.SimpleRNN &nbsp;|&nbsp; TensorFlow Core r2.0") - то есть это число батчей, которые генератор выдаст за одну эпоху обучения (если класс генератора поддерживает метод `len()`, то данный параметр можно не указывать).

# %%
len(train_regr_gen), len(test_regr_gen)
# Out:
# (32, 13)

# %% [markdown]
# Один сэмпл данных представляет собой матрицу размером *(длина окна; число признаков)*

# %%
train_regr_gen.input_shape
# Out:
# (120, 18)

# %% [markdown]
# ### Модель для задачи регрессии

# %%
model_class_name = 'regression'

# %%
def build_regression_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=(16, 32))

    regr = Dense(64)(lstm)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    return Model(inputs=[inp], outputs=[regr])

# %%
multivariate_regression_lstm = build_regression_model(train_regr_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:
# [`Nadam`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Nadam) (*Adam with Nestrov momentum*).

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Функция потерь:
#
# В качестве функции потерь будем использовать [MSE](https://www.tensorflow.org/api_docs/python/tf/keras/losses/MSE) (чтобы штрафовать за большие отклонения). Xотя хорошая функция потерь в контексте темы данной задачи - это [вопрос сложный](https://github.com/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Chapter5_LossFunctions/Ch5_LossFunctions_PyMC3.ipynb). В частности, здесь нам, очевидно, помимо абсолютного значения отклонения также важен его знак.

# %%
multivariate_regression_lstm.compile(optimizer=optimizer,
                                     loss={'regr': 'mse'},
                                     metrics={'regr': 'mae'})

multivariate_regression_lstm.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 120, 18)]         0
# _________________________________________________________________
# lstm (LSTM)                  (None, 120, 16)           2240
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 120, 32)           6272
# _________________________________________________________________
# flatten (Flatten)            (None, 3840)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                245824
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64)                256
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 64)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# regr (Dense)                 (None, 1)                 65
# =================================================================
# Total params: 254,657
# Trainable params: 254,529
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# #### Обучение:

# %%
regr_history = utils.train_model(multivariate_regression_lstm,
                                 model_save_dir, train_regr_gen, test_regr_gen,
                                 callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                 force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 1s - loss: 13.4478 - mae: 1.2447
# Epoch 00001: val_loss improved from inf to 11.78116, saving model to models\lstm2_multivar\regression\01.hdf5
# 32/32 [==============================] - 41s 1s/step - loss: 13.4108 - mae: 1.2414 - val_loss: 11.7812 - val_mae: 0.7195
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 0s - loss: 11.5253 - mae: 1.1081
# Epoch 00002: val_loss improved from 11.78116 to 10.51591, saving model to models\lstm2_multivar\regression\02.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 11.5200 - mae: 1.1098 - val_loss: 10.5159 - val_mae: 0.7899
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 9.8706 - mae: 0.9844
# Epoch 00003: val_loss improved from 10.51591 to 8.95914, saving model to models\lstm2_multivar\regression\03.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 9.8451 - mae: 0.9856 - val_loss: 8.9591 - val_mae: 0.6407
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.5667 - mae: 0.9521
# Epoch 00004: val_loss improved from 8.95914 to 8.04213, saving model to models\lstm2_multivar\regression\04.hdf5
# 32/32 [==============================] - 32s 1s/step - loss: 8.5539 - mae: 0.9511 - val_loss: 8.0421 - val_mae: 0.7450
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.7403 - mae: 0.9535
# Epoch 00005: val_loss improved from 8.04213 to 7.37693, saving model to models\lstm2_multivar\regression\05.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 7.7579 - mae: 0.9558 - val_loss: 7.3769 - val_mae: 0.6559
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.1738 - mae: 0.9355
# Epoch 00006: val_loss improved from 7.37693 to 6.93206, saving model to models\lstm2_multivar\regression\06.hdf5
# 32/32 [==============================] - 32s 993ms/step - loss: 7.1556 - mae: 0.9332 - val_loss: 6.9321 - val_mae: 0.6680
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.6957 - mae: 0.9077
# Epoch 00007: val_loss improved from 6.93206 to 6.66986, saving model to models\lstm2_multivar\regression\07.hdf5
# 32/32 [==============================] - 32s 996ms/step - loss: 6.6735 - mae: 0.9060 - val_loss: 6.6699 - val_mae: 0.7278
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.3154 - mae: 0.9116
# Epoch 00008: val_loss improved from 6.66986 to 6.10757, saving model to models\lstm2_multivar\regression\08.hdf5
# 32/32 [==============================] - 32s 992ms/step - loss: 6.2939 - mae: 0.9092 - val_loss: 6.1076 - val_mae: 0.6477
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.8414 - mae: 0.8706
# Epoch 00009: val_loss improved from 6.10757 to 5.82684, saving model to models\lstm2_multivar\regression\09.hdf5
# 32/32 [==============================] - 32s 996ms/step - loss: 5.8196 - mae: 0.8680 - val_loss: 5.8268 - val_mae: 0.6529
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.6264 - mae: 0.8734
# Epoch 00010: val_loss improved from 5.82684 to 5.77794, saving model to models\lstm2_multivar\regression\10.hdf5
# 32/32 [==============================] - 32s 999ms/step - loss: 5.6153 - mae: 0.8734 - val_loss: 5.7779 - val_mae: 0.7205
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.4351 - mae: 0.8657
# Epoch 00011: val_loss improved from 5.77794 to 5.49054, saving model to models\lstm2_multivar\regression\11.hdf5
# 32/32 [==============================] - 32s 996ms/step - loss: 5.4199 - mae: 0.8628 - val_loss: 5.4905 - val_mae: 0.6468
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.2988 - mae: 0.8588
# Epoch 00012: val_loss improved from 5.49054 to 5.43062, saving model to models\lstm2_multivar\regression\12.hdf5
# 32/32 [==============================] - 32s 1s/step - loss: 5.2902 - mae: 0.8582 - val_loss: 5.4306 - val_mae: 0.6945
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.1328 - mae: 0.8520
# Epoch 00013: val_loss improved from 5.43062 to 5.31259, saving model to models\lstm2_multivar\regression\13.hdf5
# 32/32 [==============================] - 32s 996ms/step - loss: 5.1266 - mae: 0.8515 - val_loss: 5.3126 - val_mae: 0.7037
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.9153 - mae: 0.8266
# Epoch 00014: val_loss did not improve from 5.31259
# 32/32 [==============================] - 33s 1s/step - loss: 4.9212 - mae: 0.8299 - val_loss: 5.4318 - val_mae: 0.8169
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.7827 - mae: 0.8258
# Epoch 00015: val_loss improved from 5.31259 to 5.22028, saving model to models\lstm2_multivar\regression\15.hdf5
# 32/32 [==============================] - 32s 1s/step - loss: 4.8049 - mae: 0.8273 - val_loss: 5.2203 - val_mae: 0.7545
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.7773 - mae: 0.8347
# Epoch 00016: val_loss improved from 5.22028 to 5.02908, saving model to models\lstm2_multivar\regression\16.hdf5
# 32/32 [==============================] - 32s 990ms/step - loss: 4.7792 - mae: 0.8359 - val_loss: 5.0291 - val_mae: 0.7052
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.6629 - mae: 0.8283
# Epoch 00017: val_loss improved from 5.02908 to 4.96733, saving model to models\lstm2_multivar\regression\17.hdf5
# 32/32 [==============================] - 32s 999ms/step - loss: 4.6482 - mae: 0.8256 - val_loss: 4.9673 - val_mae: 0.7041
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.6272 - mae: 0.8333
# Epoch 00018: val_loss improved from 4.96733 to 4.85852, saving model to models\lstm2_multivar\regression\18.hdf5
# 32/32 [==============================] - 32s 1s/step - loss: 4.6165 - mae: 0.8307 - val_loss: 4.8585 - val_mae: 0.6825
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.5818 - mae: 0.8344
# Epoch 00019: val_loss improved from 4.85852 to 4.80517, saving model to models\lstm2_multivar\regression\19.hdf5
# 32/32 [==============================] - 32s 1s/step - loss: 4.6165 - mae: 0.8397 - val_loss: 4.8052 - val_mae: 0.6869
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.4893 - mae: 0.8212
# Epoch 00020: val_loss improved from 4.80517 to 4.77783, saving model to models\lstm2_multivar\regression\20.hdf5
# 32/32 [==============================] - 32s 1s/step - loss: 4.4656 - mae: 0.8150 - val_loss: 4.7778 - val_mae: 0.6882
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.4702 - mae: 0.8195
# Epoch 00021: val_loss improved from 4.77783 to 4.74118, saving model to models\lstm2_multivar\regression\21.hdf5
# 32/32 [==============================] - 39s 1s/step - loss: 4.4852 - mae: 0.8234 - val_loss: 4.7412 - val_mae: 0.6847
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.4366 - mae: 0.8175
# Epoch 00022: val_loss improved from 4.74118 to 4.70092, saving model to models\lstm2_multivar\regression\22.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 4.4191 - mae: 0.8143 - val_loss: 4.7009 - val_mae: 0.6766
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.3832 - mae: 0.8205
# Epoch 00023: val_loss improved from 4.70092 to 4.66640, saving model to models\lstm2_multivar\regression\23.hdf5
# 32/32 [==============================] - 31s 982ms/step - loss: 4.3955 - mae: 0.8244 - val_loss: 4.6664 - val_mae: 0.6713
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.3299 - mae: 0.8098
# Epoch 00024: val_loss improved from 4.66640 to 4.62804, saving model to models\lstm2_multivar\regression\24.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 4.3550 - mae: 0.8156 - val_loss: 4.6280 - val_mae: 0.6674
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.3589 - mae: 0.8226
# Epoch 00025: val_loss improved from 4.62804 to 4.60727, saving model to models\lstm2_multivar\regression\25.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 4.3850 - mae: 0.8297 - val_loss: 4.6073 - val_mae: 0.6644
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.2786 - mae: 0.8006
# Epoch 00026: val_loss improved from 4.60727 to 4.59421, saving model to models\lstm2_multivar\regression\26.hdf5
# 32/32 [==============================] - 32s 993ms/step - loss: 4.2659 - mae: 0.7986 - val_loss: 4.5942 - val_mae: 0.6665
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.2605 - mae: 0.8002
# Epoch 00027: val_loss improved from 4.59421 to 4.58512, saving model to models\lstm2_multivar\regression\27.hdf5
# 32/32 [==============================] - 31s 979ms/step - loss: 4.2520 - mae: 0.8000 - val_loss: 4.5851 - val_mae: 0.6708
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.2912 - mae: 0.8245
# Epoch 00028: val_loss did not improve from 4.58512
# 32/32 [==============================] - 32s 985ms/step - loss: 4.2802 - mae: 0.8228 - val_loss: 4.5998 - val_mae: 0.6843
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.2708 - mae: 0.8262
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00029: val_loss did not improve from 4.58512
# 32/32 [==============================] - 36s 1s/step - loss: 4.2491 - mae: 0.8207 - val_loss: 4.5914 - val_mae: 0.6869
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 4.999999873689376e-06.
# Epoch 30/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.2474 - mae: 0.8133
# Epoch 00030: val_loss did not improve from 4.58512
# 32/32 [==============================] - 32s 1s/step - loss: 4.2553 - mae: 0.8174 - val_loss: 4.5911 - val_mae: 0.6879
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 4.999999873689376e-06.
# Epoch 31/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.2285 - mae: 0.8092
# Epoch 00031: val_loss did not improve from 4.58512
# 32/32 [==============================] - 33s 1s/step - loss: 4.2397 - mae: 0.8130 - val_loss: 4.5882 - val_mae: 0.6884
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 4.999999873689376e-06.
# Epoch 32/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.2010 - mae: 0.8085
# Epoch 00032: val_loss improved from 4.58512 to 4.58357, saving model to models\lstm2_multivar\regression\32.hdf5
# 32/32 [==============================] - 32s 993ms/step - loss: 4.1962 - mae: 0.8078 - val_loss: 4.5836 - val_mae: 0.6872

# %%
def plot_regr_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'MSE', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'MAE', 'mae', 'val_mae')
    
plot_regr_history(regr_history);

# %% [markdown]
# ### Прогноз задачи регрессии

# %% [markdown]
# *Судя по всему, просто выходит на модель случайного блуждания*

# %%
# загружаем последнюю эпоху с минимальным лоссом
multivariate_regression_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret_test = multivariate_regression_lstm.predict_generator(test_regr_gen, verbose=1)
# Out:
# 13/13 [==============================] - 6s 442ms/step

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret_test, figsize=(16, 10),
                                  datetime_unit='m', plot_data_slice=slice(1, None))

# %% [markdown]
# ## Задача классификации
#
# Прогнозируем направление изменения цены по сравнению с предыдущим периодом (**0** - снижение, **1** - рост).

# %%
model_class_name = 'classification'

# %%
train_clf_gen = ClassificationGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_clf_gen = ClassificationGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_clf_gen = ClassificationGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_classification_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=(16, 32))

    clf = Dense(64)(lstm)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)

    return Model(inputs=[inp], outputs=[clf])

# %%
multivariate_classification_lstm = build_classification_model(test_clf_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
multivariate_classification_lstm.compile(optimizer=optimizer,
                                         loss={'clf': 'binary_crossentropy'},
                                         metrics={'clf': 'accuracy'})

multivariate_classification_lstm.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 120, 18)]         0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 120, 16)           2240
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 120, 32)           6272
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3840)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                245824
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# clf (Dense)                  (None, 1)                 65
# =================================================================
# Total params: 254,657
# Trainable params: 254,529
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
clf_history = utils.train_model(multivariate_classification_lstm,
                                model_save_dir, train_clf_gen, test_clf_gen,
                                callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 0s - loss: 11.2937 - accuracy: 0.5171
# Epoch 00001: val_loss improved from inf to 9.80282, saving model to models\lstm2_multivar\classification\01.hdf5
# 32/32 [==============================] - 36s 1s/step - loss: 11.2552 - accuracy: 0.5187 - val_loss: 9.8028 - val_accuracy: 0.5696
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.9439 - accuracy: 0.4929
# Epoch 00002: val_loss improved from 9.80282 to 7.71024, saving model to models\lstm2_multivar\classification\02.hdf5
# 32/32 [==============================] - 32s 994ms/step - loss: 8.9080 - accuracy: 0.4961 - val_loss: 7.7102 - val_accuracy: 0.5232
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.0150 - accuracy: 0.5202
# Epoch 00003: val_loss improved from 7.71024 to 6.09104, saving model to models\lstm2_multivar\classification\03.hdf5
# 32/32 [==============================] - 32s 1s/step - loss: 7.0032 - accuracy: 0.5148 - val_loss: 6.0910 - val_accuracy: 0.5077
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.5675 - accuracy: 0.5444
# Epoch 00004: val_loss improved from 6.09104 to 4.86466, saving model to models\lstm2_multivar\classification\04.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 5.5537 - accuracy: 0.5424 - val_loss: 4.8647 - val_accuracy: 0.5052
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.6978 - accuracy: 0.5192
# Epoch 00005: val_loss improved from 4.86466 to 4.36047, saving model to models\lstm2_multivar\classification\05.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 4.6904 - accuracy: 0.5207 - val_loss: 4.3605 - val_accuracy: 0.5026
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.1900 - accuracy: 0.5675
# Epoch 00006: val_loss improved from 4.36047 to 3.95084, saving model to models\lstm2_multivar\classification\06.hdf5
# 32/32 [==============================] - 32s 1s/step - loss: 4.1865 - accuracy: 0.5621 - val_loss: 3.9508 - val_accuracy: 0.4510
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.7940 - accuracy: 0.5565
# Epoch 00007: val_loss improved from 3.95084 to 3.57055, saving model to models\lstm2_multivar\classification\07.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 3.7932 - accuracy: 0.5542 - val_loss: 3.5706 - val_accuracy: 0.4639
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.4726 - accuracy: 0.5171
# Epoch 00008: val_loss improved from 3.57055 to 3.23280, saving model to models\lstm2_multivar\classification\08.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 3.4706 - accuracy: 0.5168 - val_loss: 3.2328 - val_accuracy: 0.5490
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.1682 - accuracy: 0.5413
# Epoch 00009: val_loss improved from 3.23280 to 2.96665, saving model to models\lstm2_multivar\classification\09.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 3.1616 - accuracy: 0.5424 - val_loss: 2.9666 - val_accuracy: 0.5206
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.9457 - accuracy: 0.5373
# Epoch 00010: val_loss improved from 2.96665 to 2.84549, saving model to models\lstm2_multivar\classification\10.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 2.9385 - accuracy: 0.5385 - val_loss: 2.8455 - val_accuracy: 0.5284
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.8522 - accuracy: 0.5121
# Epoch 00011: val_loss improved from 2.84549 to 2.73710, saving model to models\lstm2_multivar\classification\11.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 2.8523 - accuracy: 0.5128 - val_loss: 2.7371 - val_accuracy: 0.5155
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.7352 - accuracy: 0.5373
# Epoch 00012: val_loss improved from 2.73710 to 2.65151, saving model to models\lstm2_multivar\classification\12.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 2.7362 - accuracy: 0.5365 - val_loss: 2.6515 - val_accuracy: 0.4820
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.6273 - accuracy: 0.5464
# Epoch 00013: val_loss improved from 2.65151 to 2.56560, saving model to models\lstm2_multivar\classification\13.hdf5
# 32/32 [==============================] - 32s 991ms/step - loss: 2.6241 - accuracy: 0.5483 - val_loss: 2.5656 - val_accuracy: 0.4948
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.5410 - accuracy: 0.5333
# Epoch 00014: val_loss improved from 2.56560 to 2.50949, saving model to models\lstm2_multivar\classification\14.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 2.5413 - accuracy: 0.5335 - val_loss: 2.5095 - val_accuracy: 0.4562
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.4850 - accuracy: 0.5312
# Epoch 00015: val_loss improved from 2.50949 to 2.47576, saving model to models\lstm2_multivar\classification\15.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 2.4849 - accuracy: 0.5296 - val_loss: 2.4758 - val_accuracy: 0.4536
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.4353 - accuracy: 0.5383
# Epoch 00016: val_loss improved from 2.47576 to 2.44481, saving model to models\lstm2_multivar\classification\16.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 2.4333 - accuracy: 0.5404 - val_loss: 2.4448 - val_accuracy: 0.4459
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.4029 - accuracy: 0.5373
# Epoch 00017: val_loss improved from 2.44481 to 2.43273, saving model to models\lstm2_multivar\classification\17.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 2.4038 - accuracy: 0.5365 - val_loss: 2.4327 - val_accuracy: 0.4433
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.3770 - accuracy: 0.5222
# Epoch 00018: val_loss improved from 2.43273 to 2.39721, saving model to models\lstm2_multivar\classification\18.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 2.3788 - accuracy: 0.5207 - val_loss: 2.3972 - val_accuracy: 0.4485
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.3165 - accuracy: 0.5403
# Epoch 00019: val_loss improved from 2.39721 to 2.37602, saving model to models\lstm2_multivar\classification\19.hdf5
# 32/32 [==============================] - 32s 989ms/step - loss: 2.3153 - accuracy: 0.5424 - val_loss: 2.3760 - val_accuracy: 0.4536
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2918 - accuracy: 0.5665
# Epoch 00020: val_loss improved from 2.37602 to 2.33592, saving model to models\lstm2_multivar\classification\20.hdf5
# 32/32 [==============================] - 32s 1s/step - loss: 2.2908 - accuracy: 0.5651 - val_loss: 2.3359 - val_accuracy: 0.4536
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2861 - accuracy: 0.5323
# Epoch 00021: val_loss improved from 2.33592 to 2.30470, saving model to models\lstm2_multivar\classification\21.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 2.2865 - accuracy: 0.5325 - val_loss: 2.3047 - val_accuracy: 0.4433
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2471 - accuracy: 0.5605
# Epoch 00022: val_loss improved from 2.30470 to 2.28765, saving model to models\lstm2_multivar\classification\22.hdf5
# 32/32 [==============================] - 38s 1s/step - loss: 2.2497 - accuracy: 0.5582 - val_loss: 2.2877 - val_accuracy: 0.4407
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2431 - accuracy: 0.5393
# Epoch 00023: val_loss improved from 2.28765 to 2.27974, saving model to models\lstm2_multivar\classification\23.hdf5
# 32/32 [==============================] - 32s 1s/step - loss: 2.2430 - accuracy: 0.5375 - val_loss: 2.2797 - val_accuracy: 0.4381
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 31/32 [============================>.] - ETA: 1s - loss: 2.2155 - accuracy: 0.5696
# Epoch 00024: val_loss improved from 2.27974 to 2.25514, saving model to models\lstm2_multivar\classification\24.hdf5
# 32/32 [==============================] - 46s 1s/step - loss: 2.2138 - accuracy: 0.5700 - val_loss: 2.2551 - val_accuracy: 0.4433
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2142 - accuracy: 0.5524
# Epoch 00025: val_loss improved from 2.25514 to 2.24562, saving model to models\lstm2_multivar\classification\25.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 2.2144 - accuracy: 0.5533 - val_loss: 2.2456 - val_accuracy: 0.4459
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 31/32 [============================>.] - ETA: 1s - loss: 2.2039 - accuracy: 0.5484
# Epoch 00026: val_loss did not improve from 2.24562
# 32/32 [==============================] - 41s 1s/step - loss: 2.2010 - accuracy: 0.5513 - val_loss: 2.2496 - val_accuracy: 0.4407
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 31/32 [============================>.] - ETA: 1s - loss: 2.1906 - accuracy: 0.5716
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00027: val_loss did not improve from 2.24562
# 32/32 [==============================] - 41s 1s/step - loss: 2.1894 - accuracy: 0.5740 - val_loss: 2.2515 - val_accuracy: 0.4433
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 9.999999747378752e-06.
# Epoch 28/32
# 31/32 [============================>.] - ETA: 1s - loss: 2.2021 - accuracy: 0.5323
# Epoch 00028: val_loss did not improve from 2.24562
# 32/32 [==============================] - 40s 1s/step - loss: 2.2058 - accuracy: 0.5256 - val_loss: 2.2485 - val_accuracy: 0.4407
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 9.999999747378752e-06.
# Epoch 29/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2046 - accuracy: 0.5433
# Epoch 00029: val_loss did not improve from 2.24562
# 32/32 [==============================] - 34s 1s/step - loss: 2.2055 - accuracy: 0.5424 - val_loss: 2.2460 - val_accuracy: 0.4356
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 4.999999873689376e-06.
# Epoch 30/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1690 - accuracy: 0.5665
# Epoch 00030: val_loss improved from 2.24562 to 2.24371, saving model to models\lstm2_multivar\classification\30.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 2.1678 - accuracy: 0.5690 - val_loss: 2.2437 - val_accuracy: 0.4407
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 4.999999873689376e-06.
# Epoch 31/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1798 - accuracy: 0.5544
# Epoch 00031: val_loss improved from 2.24371 to 2.24197, saving model to models\lstm2_multivar\classification\31.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 2.1840 - accuracy: 0.5533 - val_loss: 2.2420 - val_accuracy: 0.4381
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 4.999999873689376e-06.
# Epoch 32/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1939 - accuracy: 0.5403
# Epoch 00032: val_loss improved from 2.24197 to 2.24115, saving model to models\lstm2_multivar\classification\32.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 2.1913 - accuracy: 0.5434 - val_loss: 2.2412 - val_accuracy: 0.4381

# %%
def plot_clf_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'Loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'Accuracy', 'accuracy', 'val_accuracy')
    
plot_clf_history(clf_history);

# %% [markdown]
# ### Прогноз задачи классификации

# %%
# загружаем последнюю эпоху с минимальным лоссом
multivariate_classification_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %%
pred_direction_proba = multivariate_classification_lstm.predict_generator(test_clf_gen, verbose=1)

true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 13/13 [==============================] - 7s 549ms/step
# 0.38707373

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([166, 222], dtype=int64)),
#  (array([0, 1]), array([210, 178], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.45      0.57      0.51       166
#            1       0.60      0.48      0.54       222
#
#     accuracy                           0.52       388
#    macro avg       0.53      0.53      0.52       388
# weighted avg       0.54      0.52      0.52       388

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[ 95,  71],
#        [115, 107]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.45238095, 0.3988764 ],
#        [0.54761905, 0.6011236 ]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# ## Многозадачная модель: одновременно регрессия и классификация

# %%
model_class_name = 'multitask'

# %%
train_multi_gen = MultitaskGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_multi_gen = MultitaskGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_multi_gen = MultitaskGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_multitask_model(input_shape):
    inp, lstm = build_lstm_layers(input_shape, latent_dim=(16, 32))

    # первый выход: задача регрссии
    regr = Dense(64)(lstm)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.5)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    # второй выход: задача классификации
    clf = Dense(64)(lstm)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.5)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)
    
    return Model(inputs=[inp], outputs=[regr, clf])

# %%
multivariate_multitask_lstm = build_multitask_model(train_multi_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
multivariate_multitask_lstm.compile(optimizer=optimizer,
                                    loss={'regr': 'mse', 'clf': 'binary_crossentropy'},
                                    loss_weights={'regr': 2., 'clf': 1.},
                                    metrics={'regr': 'mae', 'clf' : 'accuracy'})

multivariate_multitask_lstm.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 120, 18)]    0
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 120, 16)      2240        input[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 120, 32)      6272        lstm_4[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 3840)         0           lstm_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           245824      flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           245824      flatten_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64)           256         dense_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64)           256         dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 64)           0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 64)           0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64)           0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64)           0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# regr (Dense)                    (None, 1)            65          dropout_2[0][0]
# __________________________________________________________________________________________________
# clf (Dense)                     (None, 1)            65          dropout_3[0][0]
# ==================================================================================================
# Total params: 500,802
# Trainable params: 500,546
# Non-trainable params: 256
# __________________________________________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
multitask_history = utils.train_model(multivariate_multitask_lstm,
                                      model_save_dir, train_multi_gen, test_multi_gen,
                                      callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                      force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 0s - loss: 17.5011 - regr_loss: 2.6760 - clf_loss: 0.9779 - regr_mae: 1.2640 - clf_accuracy: 0.4980
# Epoch 00001: val_loss improved from inf to 15.15836, saving model to models\lstm2_multivar\multitask\01.hdf5
# 32/32 [==============================] - 40s 1s/step - loss: 17.5194 - regr_loss: 2.6900 - clf_loss: 0.9817 - regr_mae: 1.2672 - clf_accuracy: 0.4961 - val_loss: 15.1584 - val_regr_loss: 1.7858 - val_clf_loss: 0.8681 - val_regr_mae: 0.8124 - val_clf_accuracy: 0.4278
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 1s - loss: 14.9948 - regr_loss: 1.9325 - clf_loss: 0.8663 - regr_mae: 1.0625 - clf_accuracy: 0.5121
# Epoch 00002: val_loss improved from 15.15836 to 13.57291, saving model to models\lstm2_multivar\multitask\02.hdf5
# 32/32 [==============================] - 42s 1s/step - loss: 15.0345 - regr_loss: 1.9601 - clf_loss: 0.8663 - regr_mae: 1.0666 - clf_accuracy: 0.5118 - val_loss: 13.5729 - val_regr_loss: 1.5127 - val_clf_loss: 0.8016 - val_regr_mae: 0.6722 - val_clf_accuracy: 0.4433
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 13.6004 - regr_loss: 1.7490 - clf_loss: 0.8105 - regr_mae: 0.9990 - clf_accuracy: 0.5040
# Epoch 00003: val_loss improved from 13.57291 to 12.80699, saving model to models\lstm2_multivar\multitask\03.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 13.6153 - regr_loss: 1.7652 - clf_loss: 0.8080 - regr_mae: 0.9994 - clf_accuracy: 0.5049 - val_loss: 12.8070 - val_regr_loss: 1.5665 - val_clf_loss: 0.8838 - val_regr_mae: 0.6898 - val_clf_accuracy: 0.4278
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 12.6533 - regr_loss: 1.7500 - clf_loss: 0.7832 - regr_mae: 1.0241 - clf_accuracy: 0.5121
# Epoch 00004: val_loss improved from 12.80699 to 11.97622, saving model to models\lstm2_multivar\multitask\04.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 12.6729 - regr_loss: 1.7653 - clf_loss: 0.7859 - regr_mae: 1.0257 - clf_accuracy: 0.5089 - val_loss: 11.9762 - val_regr_loss: 1.5872 - val_clf_loss: 0.8895 - val_regr_mae: 0.6935 - val_clf_accuracy: 0.4278
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 11.6592 - regr_loss: 1.5919 - clf_loss: 0.7631 - regr_mae: 0.9685 - clf_accuracy: 0.5302
# Epoch 00005: val_loss improved from 11.97622 to 11.23744, saving model to models\lstm2_multivar\multitask\05.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 11.6336 - regr_loss: 1.5835 - clf_loss: 0.7605 - regr_mae: 0.9649 - clf_accuracy: 0.5286 - val_loss: 11.2374 - val_regr_loss: 1.4419 - val_clf_loss: 0.8613 - val_regr_mae: 0.6418 - val_clf_accuracy: 0.4278
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 11.0863 - regr_loss: 1.5272 - clf_loss: 0.7307 - regr_mae: 0.9446 - clf_accuracy: 0.5413
# Epoch 00006: val_loss improved from 11.23744 to 10.81741, saving model to models\lstm2_multivar\multitask\06.hdf5
# 32/32 [==============================] - 39s 1s/step - loss: 11.0299 - regr_loss: 1.5024 - clf_loss: 0.7296 - regr_mae: 0.9401 - clf_accuracy: 0.5434 - val_loss: 10.8174 - val_regr_loss: 1.4666 - val_clf_loss: 0.7967 - val_regr_mae: 0.6450 - val_clf_accuracy: 0.4278
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 10.5828 - regr_loss: 1.4693 - clf_loss: 0.7386 - regr_mae: 0.8957 - clf_accuracy: 0.5383
# Epoch 00007: val_loss improved from 10.81741 to 10.45013, saving model to models\lstm2_multivar\multitask\07.hdf5
# 32/32 [==============================] - 37s 1s/step - loss: 10.5467 - regr_loss: 1.4538 - clf_loss: 0.7391 - regr_mae: 0.8923 - clf_accuracy: 0.5404 - val_loss: 10.4501 - val_regr_loss: 1.4874 - val_clf_loss: 0.7732 - val_regr_mae: 0.6577 - val_clf_accuracy: 0.4356
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 10.1558 - regr_loss: 1.4267 - clf_loss: 0.7739 - regr_mae: 0.9232 - clf_accuracy: 0.5020
# Epoch 00008: val_loss improved from 10.45013 to 9.95358, saving model to models\lstm2_multivar\multitask\08.hdf5
# 32/32 [==============================] - 38s 1s/step - loss: 10.2351 - regr_loss: 1.4689 - clf_loss: 0.7753 - regr_mae: 0.9278 - clf_accuracy: 0.5020 - val_loss: 9.9536 - val_regr_loss: 1.4419 - val_clf_loss: 0.7341 - val_regr_mae: 0.6488 - val_clf_accuracy: 0.4510
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 9.7869 - regr_loss: 1.4300 - clf_loss: 0.7555 - regr_mae: 0.9062 - clf_accuracy: 0.5192
# Epoch 00009: val_loss improved from 9.95358 to 9.55359, saving model to models\lstm2_multivar\multitask\09.hdf5
# 32/32 [==============================] - 38s 1s/step - loss: 9.7821 - regr_loss: 1.4267 - clf_loss: 0.7625 - regr_mae: 0.9060 - clf_accuracy: 0.5178 - val_loss: 9.5536 - val_regr_loss: 1.4166 - val_clf_loss: 0.7303 - val_regr_mae: 0.6299 - val_clf_accuracy: 0.4871
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 9.4549 - regr_loss: 1.3941 - clf_loss: 0.7569 - regr_mae: 0.8837 - clf_accuracy: 0.5050
# Epoch 00010: val_loss improved from 9.55359 to 9.34404, saving model to models\lstm2_multivar\multitask\10.hdf5
# 32/32 [==============================] - 37s 1s/step - loss: 9.5246 - regr_loss: 1.4311 - clf_loss: 0.7558 - regr_mae: 0.8916 - clf_accuracy: 0.5069 - val_loss: 9.3440 - val_regr_loss: 1.3970 - val_clf_loss: 0.7280 - val_regr_mae: 0.6274 - val_clf_accuracy: 0.4948
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 9.2069 - regr_loss: 1.3600 - clf_loss: 0.7410 - regr_mae: 0.8732 - clf_accuracy: 0.5151
# Epoch 00011: val_loss improved from 9.34404 to 9.27744, saving model to models\lstm2_multivar\multitask\11.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 9.1945 - regr_loss: 1.3550 - clf_loss: 0.7409 - regr_mae: 0.8750 - clf_accuracy: 0.5138 - val_loss: 9.2774 - val_regr_loss: 1.4187 - val_clf_loss: 0.7797 - val_regr_mae: 0.6393 - val_clf_accuracy: 0.4562
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.9186 - regr_loss: 1.3092 - clf_loss: 0.7152 - regr_mae: 0.8676 - clf_accuracy: 0.5675
# Epoch 00012: val_loss improved from 9.27744 to 9.09476, saving model to models\lstm2_multivar\multitask\12.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 8.9201 - regr_loss: 1.3104 - clf_loss: 0.7166 - regr_mae: 0.8686 - clf_accuracy: 0.5690 - val_loss: 9.0948 - val_regr_loss: 1.4193 - val_clf_loss: 0.7551 - val_regr_mae: 0.6302 - val_clf_accuracy: 0.4459
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.7503 - regr_loss: 1.3026 - clf_loss: 0.7176 - regr_mae: 0.8599 - clf_accuracy: 0.5373
# Epoch 00013: val_loss improved from 9.09476 to 8.98321, saving model to models\lstm2_multivar\multitask\13.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 8.7218 - regr_loss: 1.2917 - clf_loss: 0.7129 - regr_mae: 0.8584 - clf_accuracy: 0.5394 - val_loss: 8.9832 - val_regr_loss: 1.4550 - val_clf_loss: 0.7269 - val_regr_mae: 0.6386 - val_clf_accuracy: 0.4742
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.5474 - regr_loss: 1.2723 - clf_loss: 0.7287 - regr_mae: 0.8522 - clf_accuracy: 0.5444
# Epoch 00014: val_loss improved from 8.98321 to 8.85256, saving model to models\lstm2_multivar\multitask\14.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 8.5495 - regr_loss: 1.2755 - clf_loss: 0.7269 - regr_mae: 0.8529 - clf_accuracy: 0.5473 - val_loss: 8.8526 - val_regr_loss: 1.4557 - val_clf_loss: 0.7475 - val_regr_mae: 0.6422 - val_clf_accuracy: 0.4613
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 1s - loss: 8.3190 - regr_loss: 1.2231 - clf_loss: 0.7153 - regr_mae: 0.8300 - clf_accuracy: 0.5474
# Epoch 00015: val_loss improved from 8.85256 to 8.76440, saving model to models\lstm2_multivar\multitask\15.hdf5
# 32/32 [==============================] - 39s 1s/step - loss: 8.3585 - regr_loss: 1.2408 - clf_loss: 0.7208 - regr_mae: 0.8358 - clf_accuracy: 0.5424 - val_loss: 8.7644 - val_regr_loss: 1.4461 - val_clf_loss: 0.7542 - val_regr_mae: 0.6383 - val_clf_accuracy: 0.4665
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.3474 - regr_loss: 1.2618 - clf_loss: 0.7409 - regr_mae: 0.8369 - clf_accuracy: 0.5343
# Epoch 00016: val_loss improved from 8.76440 to 8.68101, saving model to models\lstm2_multivar\multitask\16.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 8.3174 - regr_loss: 1.2465 - clf_loss: 0.7424 - regr_mae: 0.8354 - clf_accuracy: 0.5345 - val_loss: 8.6810 - val_regr_loss: 1.4433 - val_clf_loss: 0.7509 - val_regr_mae: 0.6371 - val_clf_accuracy: 0.4716
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.3421 - regr_loss: 1.3021 - clf_loss: 0.7288 - regr_mae: 0.8506 - clf_accuracy: 0.5423
# Epoch 00017: val_loss improved from 8.68101 to 8.61244, saving model to models\lstm2_multivar\multitask\17.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 8.3270 - regr_loss: 1.2961 - clf_loss: 0.7268 - regr_mae: 0.8509 - clf_accuracy: 0.5434 - val_loss: 8.6124 - val_regr_loss: 1.4409 - val_clf_loss: 0.7605 - val_regr_mae: 0.6365 - val_clf_accuracy: 0.4794
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.0402 - regr_loss: 1.1911 - clf_loss: 0.7222 - regr_mae: 0.8161 - clf_accuracy: 0.5353
# Epoch 00018: val_loss improved from 8.61244 to 8.54624, saving model to models\lstm2_multivar\multitask\18.hdf5
# 32/32 [==============================] - 37s 1s/step - loss: 8.0762 - regr_loss: 1.2104 - clf_loss: 0.7210 - regr_mae: 0.8185 - clf_accuracy: 0.5365 - val_loss: 8.5462 - val_regr_loss: 1.4485 - val_clf_loss: 0.7521 - val_regr_mae: 0.6393 - val_clf_accuracy: 0.4716
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.9588 - regr_loss: 1.1944 - clf_loss: 0.7069 - regr_mae: 0.8207 - clf_accuracy: 0.5565
# Epoch 00019: val_loss improved from 8.54624 to 8.45715, saving model to models\lstm2_multivar\multitask\19.hdf5
# 32/32 [==============================] - 37s 1s/step - loss: 7.9148 - regr_loss: 1.1725 - clf_loss: 0.7074 - regr_mae: 0.8144 - clf_accuracy: 0.5542 - val_loss: 8.4571 - val_regr_loss: 1.4471 - val_clf_loss: 0.7381 - val_regr_mae: 0.6395 - val_clf_accuracy: 0.4742
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.8675 - regr_loss: 1.1692 - clf_loss: 0.7217 - regr_mae: 0.8137 - clf_accuracy: 0.5635
# Epoch 00020: val_loss improved from 8.45715 to 8.40756, saving model to models\lstm2_multivar\multitask\20.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 7.9570 - regr_loss: 1.2153 - clf_loss: 0.7205 - regr_mae: 0.8192 - clf_accuracy: 0.5641 - val_loss: 8.4076 - val_regr_loss: 1.4427 - val_clf_loss: 0.7339 - val_regr_mae: 0.6378 - val_clf_accuracy: 0.4768
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.0287 - regr_loss: 1.2748 - clf_loss: 0.7080 - regr_mae: 0.8552 - clf_accuracy: 0.5625
# Epoch 00021: val_loss improved from 8.40756 to 8.37634, saving model to models\lstm2_multivar\multitask\21.hdf5
# 32/32 [==============================] - 35s 1s/step - loss: 7.9973 - regr_loss: 1.2593 - clf_loss: 0.7078 - regr_mae: 0.8533 - clf_accuracy: 0.5621 - val_loss: 8.3763 - val_regr_loss: 1.4466 - val_clf_loss: 0.7312 - val_regr_mae: 0.6378 - val_clf_accuracy: 0.4845
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.8360 - regr_loss: 1.1954 - clf_loss: 0.7102 - regr_mae: 0.8339 - clf_accuracy: 0.5776
# Epoch 00022: val_loss improved from 8.37634 to 8.34394, saving model to models\lstm2_multivar\multitask\22.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 7.8331 - regr_loss: 1.1933 - clf_loss: 0.7120 - regr_mae: 0.8338 - clf_accuracy: 0.5740 - val_loss: 8.3439 - val_regr_loss: 1.4445 - val_clf_loss: 0.7392 - val_regr_mae: 0.6374 - val_clf_accuracy: 0.4871
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.9072 - regr_loss: 1.2527 - clf_loss: 0.7029 - regr_mae: 0.8427 - clf_accuracy: 0.5625
# Epoch 00023: val_loss improved from 8.34394 to 8.29123, saving model to models\lstm2_multivar\multitask\23.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 7.9005 - regr_loss: 1.2494 - clf_loss: 0.7032 - regr_mae: 0.8427 - clf_accuracy: 0.5611 - val_loss: 8.2912 - val_regr_loss: 1.4373 - val_clf_loss: 0.7368 - val_regr_mae: 0.6360 - val_clf_accuracy: 0.4871
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 31/32 [============================>.] - ETA: 1s - loss: 7.8592 - regr_loss: 1.2462 - clf_loss: 0.7038 - regr_mae: 0.8314 - clf_accuracy: 0.5635
# Epoch 00024: val_loss improved from 8.29123 to 8.25815, saving model to models\lstm2_multivar\multitask\24.hdf5
# 32/32 [==============================] - 42s 1s/step - loss: 7.8521 - regr_loss: 1.2427 - clf_loss: 0.7043 - regr_mae: 0.8330 - clf_accuracy: 0.5641 - val_loss: 8.2582 - val_regr_loss: 1.4370 - val_clf_loss: 0.7403 - val_regr_mae: 0.6363 - val_clf_accuracy: 0.4768
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.7998 - regr_loss: 1.2253 - clf_loss: 0.7142 - regr_mae: 0.8336 - clf_accuracy: 0.5685
# Epoch 00025: val_loss improved from 8.25815 to 8.24947, saving model to models\lstm2_multivar\multitask\25.hdf5
# 32/32 [==============================] - 38s 1s/step - loss: 7.7634 - regr_loss: 1.2081 - clf_loss: 0.7121 - regr_mae: 0.8301 - clf_accuracy: 0.5710 - val_loss: 8.2495 - val_regr_loss: 1.4405 - val_clf_loss: 0.7432 - val_regr_mae: 0.6376 - val_clf_accuracy: 0.4820
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.8555 - regr_loss: 1.2490 - clf_loss: 0.7408 - regr_mae: 0.8328 - clf_accuracy: 0.5131
# Epoch 00026: val_loss improved from 8.24947 to 8.24213, saving model to models\lstm2_multivar\multitask\26.hdf5
# 32/32 [==============================] - 34s 1s/step - loss: 7.8299 - regr_loss: 1.2360 - clf_loss: 0.7414 - regr_mae: 0.8298 - clf_accuracy: 0.5128 - val_loss: 8.2421 - val_regr_loss: 1.4468 - val_clf_loss: 0.7417 - val_regr_mae: 0.6402 - val_clf_accuracy: 0.4871
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.6928 - regr_loss: 1.1975 - clf_loss: 0.6995 - regr_mae: 0.8281 - clf_accuracy: 0.5806
# Epoch 00027: val_loss improved from 8.24213 to 8.22784, saving model to models\lstm2_multivar\multitask\27.hdf5
# 32/32 [==============================] - 36s 1s/step - loss: 7.8000 - regr_loss: 1.2508 - clf_loss: 0.7015 - regr_mae: 0.8348 - clf_accuracy: 0.5799 - val_loss: 8.2278 - val_regr_loss: 1.4508 - val_clf_loss: 0.7376 - val_regr_mae: 0.6419 - val_clf_accuracy: 0.4742
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.7142 - regr_loss: 1.2108 - clf_loss: 0.7129 - regr_mae: 0.8115 - clf_accuracy: 0.5756
# Epoch 00028: val_loss did not improve from 8.22784
# 32/32 [==============================] - 37s 1s/step - loss: 7.7225 - regr_loss: 1.2144 - clf_loss: 0.7143 - regr_mae: 0.8116 - clf_accuracy: 0.5750 - val_loss: 8.2381 - val_regr_loss: 1.4649 - val_clf_loss: 0.7382 - val_regr_mae: 0.6474 - val_clf_accuracy: 0.4794
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.7573 - regr_loss: 1.2451 - clf_loss: 0.7059 - regr_mae: 0.8209 - clf_accuracy: 0.5333
# Epoch 00029: val_loss improved from 8.22784 to 8.21688, saving model to models\lstm2_multivar\multitask\29.hdf5
# 32/32 [==============================] - 33s 1s/step - loss: 7.7832 - regr_loss: 1.2587 - clf_loss: 0.7050 - regr_mae: 0.8260 - clf_accuracy: 0.5335 - val_loss: 8.2169 - val_regr_loss: 1.4634 - val_clf_loss: 0.7387 - val_regr_mae: 0.6462 - val_clf_accuracy: 0.4820
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 31/32 [============================>.] - ETA: 1s - loss: 7.5987 - regr_loss: 1.1657 - clf_loss: 0.7204 - regr_mae: 0.8180 - clf_accuracy: 0.5534
# Epoch 00030: val_loss did not improve from 8.21688
# 32/32 [==============================] - 40s 1s/step - loss: 7.5799 - regr_loss: 1.1553 - clf_loss: 0.7223 - regr_mae: 0.8155 - clf_accuracy: 0.5513 - val_loss: 8.2201 - val_regr_loss: 1.4681 - val_clf_loss: 0.7420 - val_regr_mae: 0.6481 - val_clf_accuracy: 0.4794
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.5893 - regr_loss: 1.1699 - clf_loss: 0.7119 - regr_mae: 0.8146 - clf_accuracy: 0.5353
# Epoch 00031: val_loss improved from 8.21688 to 8.20727, saving model to models\lstm2_multivar\multitask\31.hdf5
# 32/32 [==============================] - 37s 1s/step - loss: 7.6155 - regr_loss: 1.1827 - clf_loss: 0.7130 - regr_mae: 0.8188 - clf_accuracy: 0.5345 - val_loss: 8.2073 - val_regr_loss: 1.4662 - val_clf_loss: 0.7423 - val_regr_mae: 0.6471 - val_clf_accuracy: 0.4820
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 31/32 [============================>.] - ETA: 1s - loss: 7.6756 - regr_loss: 1.2160 - clf_loss: 0.7154 - regr_mae: 0.8321 - clf_accuracy: 0.5524
# Epoch 00032: val_loss improved from 8.20727 to 8.19552, saving model to models\lstm2_multivar\multitask\32.hdf5
# 32/32 [==============================] - 39s 1s/step - loss: 7.6527 - regr_loss: 1.2057 - clf_loss: 0.7131 - regr_mae: 0.8302 - clf_accuracy: 0.5552 - val_loss: 8.1955 - val_regr_loss: 1.4654 - val_clf_loss: 0.7414 - val_regr_mae: 0.6462 - val_clf_accuracy: 0.4845

# %%
def plot_multitask_history(hist):
    fig, ax = plt.subplots(2, 2, figsize=(16, 12))
    plotHelpers.plot_train_history(ax[0, 0], hist, 'Total loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[0, 1], hist, 'Accuracy', 'clf_accuracy', 'val_clf_accuracy')
    plotHelpers.plot_train_history(ax[1, 0], hist, 'MSE', 'regr_loss', 'val_regr_loss')
    plotHelpers.plot_train_history(ax[1, 1], hist, 'MAE', 'regr_mae', 'val_regr_mae')
    
plot_multitask_history(multitask_history);

# %% [markdown]
# ### Прогноз

# %%
# загружаем последнюю эпоху с минимальным лоссом
multivariate_multitask_lstm.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret, pred_direction_proba = multivariate_multitask_lstm.predict_generator(test_multi_gen, verbose=1)
# Out:
# 13/13 [==============================] - 7s 521ms/step

# %%
np.set_printoptions(precision=3, suppress=True)

np.column_stack([pred_log_ret, pred_direction_proba])[-10:]
# Out:
# array([[ 0.138,  0.539],
#        [ 0.139,  0.555],
#        [ 0.136,  0.568],
#        [ 0.111,  0.574],
#        [ 0.057,  0.57 ],
#        [-0.021,  0.56 ],
#        [-0.111,  0.537],
#        [-0.25 ,  0.491],
#        [-0.371,  0.439],
#        [-0.462,  0.397]], dtype=float32)

# %% [markdown]
# #### Прогноз задачи регрессии

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret, figsize=(16, 10),
                                  datetime_unit='m', plot_data_slice=slice(1, None))

# %% [markdown]
# #### Прогноз задачи классификации

# %%
true_direction = test_multi_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 0.41337836

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([166, 222], dtype=int64)),
#  (array([0, 1]), array([202, 186], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.45      0.54      0.49       166
#            1       0.59      0.50      0.54       222
#
#     accuracy                           0.52       388
#    macro avg       0.52      0.52      0.51       388
# weighted avg       0.53      0.52      0.52       388

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[ 90,  76],
#        [112, 110]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.446, 0.409],
#        [0.554, 0.591]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# # Выводы
#
# 1.  Размер батча сильно влияет на скорость обучения.
# 2.  Инициализация весов (`bias_initializer`) в слое **LSTM** оказалась очень важным параметром.
# 3.  Модель регрессии приближается к случайному блужданию.
# 4.  Задача классификации не решается удовлетворительно.

# %% [markdown]
# # *Одномерная модель на 1D свёрточных слоях*
#
# В качестве единственного признака используется сама цена.

# %%
import os
import glob
import datetime
import pickle

import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from pandas_datareader import data as pdr

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
import tensorflow as tf
# tf.test.is_gpu_available()
tf.__version__
# Out:
# '2.0.0'

# %%
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import (Input, Dense, Convolution1D, MaxPooling1D, Flatten,
                                     ReLU, LeakyReLU, Dropout, BatchNormalization)
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers import Nadam

# %%
from mdp import TimeSeries
from mdp import MarketData
from mdp import MovingWindowFeatures
from mdp import ClassificationGenerator, RegressionGenerator, MultitaskGenerator
from mdp import invert_log_ret

import mdp.utils as utils
import mdp.plotHelpers as plotHelpers

# %%
import importlib

import mdp

importlib.reload(mdp)
importlib.reload(mdp.datasetGenerator)
importlib.reload(mdp.marketData)
importlib.reload(mdp.movingWindowFeatures)
importlib.reload(mdp.timeSeries)
importlib.reload(mdp.plotHelpers)
importlib.reload(mdp.utils);

# %% [markdown]
# # *Параметры*

# %%
INSTRUMENT = 'MSFT' # Microsoft corp
START_FROM = np.datetime64('today') - 7
WINDOW_SIZE = 120
FORECAST_OFFSET=1
BATCH_SIZE = 32
FORCE_TRAIN = True

# %% [markdown]
# # *Исходные данные*
#
# Загрузка данных и вычисление индикаторов.

# %%
instr = MarketData.create_from_alphavantage_intraday(INSTRUMENT, start=START_FROM)

# %%
instr.feature_names
# Out:
# ['o',
#  'h',
#  'l',
#  'c',
#  'v',
#  'ema14',
#  'ema30',
#  'macd',
#  'macd_signal',
#  'rsi14',
#  'bband20_upper',
#  'bband20_middle',
#  'bband20_lower',
#  'willr14',
#  'stochk',
#  'stochd',
#  'adline',
#  'adosc']

# %% [markdown]
# Здесь не будем делить отдельно на тест и валидацию, поскольку данных у нас только 5 дней.

# %%
dates_unique = np.unique(instr.timestamps.astype('datetime64[D]'))

START_FROM = dates_unique[0]
VAL_TEST_SPLIT = dates_unique[-1]

START_FROM, VAL_TEST_SPLIT
# Out:
# (numpy.datetime64('2020-04-09'), numpy.datetime64('2020-04-15'))

# %% [markdown]
# ## Целевая переменная

# %% [markdown]
# Цена закрытия.

# %%
orig_target = instr.c

# %% [markdown]
# Переходим к логарифмической доходности.

# %%
transformed_target = instr.c.transform(transforms={'ratios' : {}, 'ln' : {}})

# %%
plotHelpers.plot_transformed_timeseries_unit(instr,
                                             transformed_target,
                                             'Close price, USD', 'Log return',
                                             datetime_unit='m', rotation=45)

# %% [markdown]
# ## Трансформация признаков
#
# Из признаков выбираем только цену закрытия. Временной ряд цен преобразуется к ряду логарифмических доходностей (что также позволяет убрать нестационарность).

# %%
def make_feature_selector():
    price_transformer = lambda: {'ratios': {}, 'ln': {}}
    diff_transformer = lambda o: {'diffs': {'order': o}}
    identity_transformer = lambda: {}
    feature_transformations = {
        'c': price_transformer(),
    }
    return feature_transformations

# %%
instr_transformed = instr.select_transform(make_feature_selector())

# %%
transformed_target = instr_transformed.c

# %% [markdown]
# ## Обучающая, валидационная и тестовая выборки

# %%
instr_train, instr_test = instr_transformed.train_test_split(VAL_TEST_SPLIT, window_size=WINDOW_SIZE,
                                                             scaler=StandardScaler)
#                                                              scaler=MinMaxScaler,
#                                                              scaler_kwargs={'feature_range': (-1, 1)})

# instr_val, instr_test = instr_val_test.train_test_split(TEST_SPLIT, window_size=WINDOW_SIZE, scaler=None)

len(instr_train), len(instr_test)
# Out:
# (1132, 509)

# %% [markdown]
# ## Признаки - скользящие окна

# %%
train_mwf = MovingWindowFeatures.create(instr_train.c, [instr_train], instr_train.feature_names, window_size=WINDOW_SIZE)
# val_mwf = MovingWindowFeatures.create(instr_val.c, [instr_val], instr_val.feature_names, window_size=WINDOW_SIZE)
test_mwf = MovingWindowFeatures.create(instr_test.c, [instr_test], instr_test.feature_names, window_size=WINDOW_SIZE)

len(instr_train), len(train_mwf), train_mwf.features.shape
# Out:
# (1132, 1012, (1012, 120, 1))

# %% [markdown]
# Проверка, что скользящие окна соответствуют исходным данным.
#
# Возьмём произвольный признак и произвольное окно (строка #**41**). Проверим, что данные в точности совпадают:

# %%
def check_data(md, mwf, row):
    col = np.random.randint(len(mwf.feature_names))
    feature = mwf.feature_names[col]
    check = (getattr(md, feature).data[row:row + mwf.window_size] == mwf.features[row, :, col]).all()
    assert check
    return feature, check

check_data(instr_train, train_mwf, 41)
# Out:
# ('c', True)

# %% [markdown]
# # *Модели*

# %% [markdown]
# Модель с двумя 1D свёрточными слоями.

# %%
def build_conv1d_layers(input_shape, filters=(32, 16, 8), kernel_size=3, pool_size=2):
    # формат входа: наша матрица (окно; признак)
    inp = Input(input_shape, name='input')

    filter_blocks = np.array(filters)
    filter_blocks = np.lib.stride_tricks.as_strided(filter_blocks, 
                                                    (filter_blocks.shape[0] - 1, 2), 
                                                    2 * [filter_blocks.strides[0]])
    conv1d = inp
    # стекаем слои Conv1D: блоками Conv1D-Conv1D-MaxPool
    for filter_block in filter_blocks:
        for f in filter_block:
            conv1d = Convolution1D(filters=f,
                                   kernel_size=kernel_size,
                                   padding='same',
                                   bias_initializer='he_uniform',
                                   bias_regularizer=L1L2(0.01, 0.02),
                                   kernel_regularizer=L1L2(0.01, 0.02)
                                  )(conv1d)
            conv1d = BatchNormalization()(conv1d)
            conv1d = LeakyReLU()(conv1d)
            conv1d = Dropout(0.25)(conv1d)
        conv1d = MaxPooling1D(pool_size=pool_size)(conv1d)
    
    conv1d = Flatten()(conv1d)
    
    return inp, conv1d

# %% [markdown]
# #### Пути сохранения моделей:

# %%
model_path_root = 'models'
model_type_name = 'conv1d_univar'

def make_model_save_dir(path_root, type_name, class_name):
    save_dir = os.path.join(path_root, type_name, class_name)
    os.makedirs(save_dir, exist_ok=True)
    return save_dir

# %% [markdown]
# #### Общие коллбэки:

# %%
# уменьшение learning rate в случае, если loss не изменяется
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001, verbose=1)

# уменьшение learning rate в 2 раза каждую 5-ю эпоху
def lr_decay(e, lr):
    return lr * (1 - 0.5 * (0 == (e + 1) % 5))

lr_scheduler = LearningRateScheduler(schedule=lr_decay, verbose=1)

# %% [markdown]
# ## Задача регрессии
#
# Непосредственное прогнозирование цены следующего периода.

# %%
train_regr_gen = RegressionGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_regr_gen = RegressionGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_regr_gen = RegressionGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# Следующие числа соответствуют значению параметра `steps_per_epoch` метода [`fit_generator`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit_generator "tf.keras.layers.SimpleRNN &nbsp;|&nbsp; TensorFlow Core r2.0") - то есть это число батчей, которые генератор выдаст за одну эпоху обучения (если класс генератора поддерживает метод `len()`, то данный параметр можно не указывать).

# %%
len(train_regr_gen), len(test_regr_gen)
# Out:
# (32, 13)

# %% [markdown]
# Один сэмпл данных представляет собой матрицу размером *(длина окна; число признаков)*

# %%
train_regr_gen.input_shape
# Out:
# (120, 1)

# %% [markdown]
# ### Модель для задачи регрессии

# %%
model_class_name = 'regression'

# %%
def build_regression_model(input_shape):
    inp, conv1d = build_conv1d_layers(input_shape, filters=(32, 16, 8))

    regr = Dense(64)(conv1d)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.25)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    return Model(inputs=[inp], outputs=[regr])

# %%
univariate_regression_conv1d = build_regression_model(train_regr_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:
# [`Nadam`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Nadam) (*Adam with Nestrov momentum*).

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Функция потерь:
#
# В качестве функции потерь будем использовать [MSE](https://www.tensorflow.org/api_docs/python/tf/keras/losses/MSE) (чтобы штрафовать за большие отклонения). Xотя хорошая функция потерь в контексте темы данной задачи - это [вопрос сложный](https://github.com/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Chapter5_LossFunctions/Ch5_LossFunctions_PyMC3.ipynb). В частности, здесь нам, очевидно, помимо абсолютного значения отклонения также важен его знак.

# %%
univariate_regression_conv1d.compile(optimizer=optimizer,
                                   loss={'regr': 'mse'},
                                   metrics={'regr': 'mae'})

univariate_regression_conv1d.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 120, 1)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 120, 32)           128
# _________________________________________________________________
# batch_normalization (BatchNo (None, 120, 32)           128
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 120, 32)           0
# _________________________________________________________________
# dropout (Dropout)            (None, 120, 32)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 120, 16)           1552
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 120, 16)           64
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 120, 16)           0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 120, 16)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 60, 16)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 60, 16)            784
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 60, 16)            64
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 60, 16)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 60, 16)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 60, 8)             392
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 60, 8)             32
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 60, 8)             0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 60, 8)             0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 30, 8)             0
# _________________________________________________________________
# flatten (Flatten)            (None, 240)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                15424
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# regr (Dense)                 (None, 1)                 65
# =================================================================
# Total params: 18,889
# Trainable params: 18,617
# Non-trainable params: 272
# _________________________________________________________________

# %% [markdown]
# #### Обучение:

# %%
regr_history = utils.train_model(univariate_regression_conv1d,
                                 model_save_dir, train_regr_gen, test_regr_gen,
                                 callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                 force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.4259 - mae: 0.9473
# Epoch 00001: val_loss improved from inf to 5.53601, saving model to models\conv1d_univar\regression\01.hdf5
# 32/32 [==============================] - 10s 311ms/step - loss: 6.4023 - mae: 0.9446 - val_loss: 5.5360 - val_mae: 0.6746
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.8330 - mae: 0.8409
# Epoch 00002: val_loss improved from 5.53601 to 5.37115, saving model to models\conv1d_univar\regression\02.hdf5
# 32/32 [==============================] - 5s 164ms/step - loss: 5.8174 - mae: 0.8398 - val_loss: 5.3712 - val_mae: 0.6717
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.5587 - mae: 0.8100
# Epoch 00003: val_loss improved from 5.37115 to 5.21736, saving model to models\conv1d_univar\regression\03.hdf5
# 32/32 [==============================] - 5s 162ms/step - loss: 5.5331 - mae: 0.8058 - val_loss: 5.2174 - val_mae: 0.6761
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.4483 - mae: 0.8146
# Epoch 00004: val_loss improved from 5.21736 to 5.03759, saving model to models\conv1d_univar\regression\04.hdf5
# 32/32 [==============================] - 5s 152ms/step - loss: 5.4194 - mae: 0.8113 - val_loss: 5.0376 - val_mae: 0.6733
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.1369 - mae: 0.7704
# Epoch 00005: val_loss improved from 5.03759 to 4.94511, saving model to models\conv1d_univar\regression\05.hdf5
# 32/32 [==============================] - 5s 149ms/step - loss: 5.1357 - mae: 0.7717 - val_loss: 4.9451 - val_mae: 0.6700
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.0311 - mae: 0.7694
# Epoch 00006: val_loss improved from 4.94511 to 4.85251, saving model to models\conv1d_univar\regression\06.hdf5
# 32/32 [==============================] - 5s 150ms/step - loss: 5.0193 - mae: 0.7698 - val_loss: 4.8525 - val_mae: 0.6696
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.9528 - mae: 0.7609
# Epoch 00007: val_loss improved from 4.85251 to 4.76633, saving model to models\conv1d_univar\regression\07.hdf5
# 32/32 [==============================] - 5s 159ms/step - loss: 4.9474 - mae: 0.7626 - val_loss: 4.7663 - val_mae: 0.6716
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.7219 - mae: 0.7005
# Epoch 00008: val_loss improved from 4.76633 to 4.68042, saving model to models\conv1d_univar\regression\08.hdf5
# 32/32 [==============================] - 5s 151ms/step - loss: 4.7086 - mae: 0.6988 - val_loss: 4.6804 - val_mae: 0.6751
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.7334 - mae: 0.7307
# Epoch 00009: val_loss improved from 4.68042 to 4.59863, saving model to models\conv1d_univar\regression\09.hdf5
# 32/32 [==============================] - 5s 153ms/step - loss: 4.7535 - mae: 0.7342 - val_loss: 4.5986 - val_mae: 0.6765
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.5540 - mae: 0.7122
# Epoch 00010: val_loss improved from 4.59863 to 4.57059, saving model to models\conv1d_univar\regression\10.hdf5
# 32/32 [==============================] - 5s 154ms/step - loss: 4.5537 - mae: 0.7162 - val_loss: 4.5706 - val_mae: 0.6864
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.5584 - mae: 0.7110
# Epoch 00011: val_loss improved from 4.57059 to 4.52991, saving model to models\conv1d_univar\regression\11.hdf5
# 32/32 [==============================] - 5s 164ms/step - loss: 4.5574 - mae: 0.7104 - val_loss: 4.5299 - val_mae: 0.6882
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.5113 - mae: 0.7115
# Epoch 00012: val_loss improved from 4.52991 to 4.48816, saving model to models\conv1d_univar\regression\12.hdf5
# 32/32 [==============================] - 5s 161ms/step - loss: 4.4910 - mae: 0.7090 - val_loss: 4.4882 - val_mae: 0.6922
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.5011 - mae: 0.7284
# Epoch 00013: val_loss improved from 4.48816 to 4.44816, saving model to models\conv1d_univar\regression\13.hdf5
# 32/32 [==============================] - 5s 160ms/step - loss: 4.4961 - mae: 0.7309 - val_loss: 4.4482 - val_mae: 0.6964
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.3936 - mae: 0.7176
# Epoch 00014: val_loss improved from 4.44816 to 4.40741, saving model to models\conv1d_univar\regression\14.hdf5
# 32/32 [==============================] - 5s 161ms/step - loss: 4.3716 - mae: 0.7135 - val_loss: 4.4074 - val_mae: 0.6979
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.3549 - mae: 0.6939
# Epoch 00015: val_loss improved from 4.40741 to 4.38618, saving model to models\conv1d_univar\regression\15.hdf5
# 32/32 [==============================] - 5s 166ms/step - loss: 4.3448 - mae: 0.6946 - val_loss: 4.3862 - val_mae: 0.6975
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.3205 - mae: 0.7089
# Epoch 00016: val_loss improved from 4.38618 to 4.36805, saving model to models\conv1d_univar\regression\16.hdf5
# 32/32 [==============================] - 5s 153ms/step - loss: 4.3092 - mae: 0.7086 - val_loss: 4.3681 - val_mae: 0.6988
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.2144 - mae: 0.6838
# Epoch 00017: val_loss improved from 4.36805 to 4.34777, saving model to models\conv1d_univar\regression\17.hdf5
# 32/32 [==============================] - 5s 155ms/step - loss: 4.1963 - mae: 0.6807 - val_loss: 4.3478 - val_mae: 0.6999
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.2152 - mae: 0.6741
# Epoch 00018: val_loss improved from 4.34777 to 4.32822, saving model to models\conv1d_univar\regression\18.hdf5
# 32/32 [==============================] - 5s 161ms/step - loss: 4.2346 - mae: 0.6780 - val_loss: 4.3282 - val_mae: 0.7016
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.2246 - mae: 0.6965
# Epoch 00019: val_loss improved from 4.32822 to 4.30411, saving model to models\conv1d_univar\regression\19.hdf5
# 32/32 [==============================] - 5s 160ms/step - loss: 4.2006 - mae: 0.6926 - val_loss: 4.3041 - val_mae: 0.7019
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.2186 - mae: 0.6777
# Epoch 00020: val_loss improved from 4.30411 to 4.29337, saving model to models\conv1d_univar\regression\20.hdf5
# 32/32 [==============================] - 5s 151ms/step - loss: 4.2192 - mae: 0.6791 - val_loss: 4.2934 - val_mae: 0.7018
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.1541 - mae: 0.7061
# Epoch 00021: val_loss improved from 4.29337 to 4.28273, saving model to models\conv1d_univar\regression\21.hdf5
# 32/32 [==============================] - 5s 156ms/step - loss: 4.1377 - mae: 0.7037 - val_loss: 4.2827 - val_mae: 0.7025
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.2590 - mae: 0.7147
# Epoch 00022: val_loss improved from 4.28273 to 4.26953, saving model to models\conv1d_univar\regression\22.hdf5
# 32/32 [==============================] - 5s 155ms/step - loss: 4.2518 - mae: 0.7135 - val_loss: 4.2695 - val_mae: 0.7017
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.1531 - mae: 0.6895
# Epoch 00023: val_loss improved from 4.26953 to 4.25914, saving model to models\conv1d_univar\regression\23.hdf5
# 32/32 [==============================] - 5s 154ms/step - loss: 4.1647 - mae: 0.6957 - val_loss: 4.2591 - val_mae: 0.7024
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.0916 - mae: 0.6805
# Epoch 00024: val_loss improved from 4.25914 to 4.25038, saving model to models\conv1d_univar\regression\24.hdf5
# 32/32 [==============================] - 5s 158ms/step - loss: 4.0959 - mae: 0.6857 - val_loss: 4.2504 - val_mae: 0.7039
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.1376 - mae: 0.7005
# Epoch 00025: val_loss improved from 4.25038 to 4.24521, saving model to models\conv1d_univar\regression\25.hdf5
# 32/32 [==============================] - 5s 164ms/step - loss: 4.1229 - mae: 0.6990 - val_loss: 4.2452 - val_mae: 0.7037
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.1400 - mae: 0.6916
# Epoch 00026: val_loss improved from 4.24521 to 4.24296, saving model to models\conv1d_univar\regression\26.hdf5
# 32/32 [==============================] - 5s 162ms/step - loss: 4.1344 - mae: 0.6908 - val_loss: 4.2430 - val_mae: 0.7055
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.1706 - mae: 0.6958
# Epoch 00027: val_loss improved from 4.24296 to 4.23762, saving model to models\conv1d_univar\regression\27.hdf5
# 32/32 [==============================] - 5s 156ms/step - loss: 4.1670 - mae: 0.7000 - val_loss: 4.2376 - val_mae: 0.7058
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.1190 - mae: 0.6984
# Epoch 00028: val_loss improved from 4.23762 to 4.23101, saving model to models\conv1d_univar\regression\28.hdf5
# 32/32 [==============================] - 5s 160ms/step - loss: 4.1033 - mae: 0.6974 - val_loss: 4.2310 - val_mae: 0.7057
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.0555 - mae: 0.6865
# Epoch 00029: val_loss improved from 4.23101 to 4.22391, saving model to models\conv1d_univar\regression\29.hdf5
# 32/32 [==============================] - 5s 163ms/step - loss: 4.0348 - mae: 0.6827 - val_loss: 4.2239 - val_mae: 0.7054
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.1255 - mae: 0.6971
# Epoch 00030: val_loss improved from 4.22391 to 4.22080, saving model to models\conv1d_univar\regression\30.hdf5
# 32/32 [==============================] - 5s 157ms/step - loss: 4.1108 - mae: 0.6953 - val_loss: 4.2208 - val_mae: 0.7055
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.0986 - mae: 0.7025
# Epoch 00031: val_loss improved from 4.22080 to 4.21932, saving model to models\conv1d_univar\regression\31.hdf5
# 32/32 [==============================] - 5s 164ms/step - loss: 4.0856 - mae: 0.7025 - val_loss: 4.2193 - val_mae: 0.7060
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.0836 - mae: 0.6860
# Epoch 00032: val_loss improved from 4.21932 to 4.21656, saving model to models\conv1d_univar\regression\32.hdf5
# 32/32 [==============================] - 5s 164ms/step - loss: 4.0722 - mae: 0.6849 - val_loss: 4.2166 - val_mae: 0.7059

# %%
def plot_regr_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'MSE', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'MAE', 'mae', 'val_mae')
    
plot_regr_history(regr_history);

# %% [markdown]
# ### Прогноз задачи регрессии

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_regression_conv1d.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret_test = univariate_regression_conv1d.predict_generator(test_regr_gen, verbose=1)
# Out:
# 13/13 [==============================] - 0s 30ms/step

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret_test, figsize=(16, 10),
                                  datetime_unit='m', plot_data_slice=slice(1, None))

# %% [markdown]
# ## Задача классификации
#
# Прогнозируем направление изменения цены по сравнению с предыдущим периодом (**0** - снижение, **1** - рост).

# %%
model_class_name = 'classification'

# %%
train_clf_gen = ClassificationGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_clf_gen = ClassificationGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_clf_gen = ClassificationGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_classification_model(input_shape):
    inp, conv1d = build_conv1d_layers(input_shape, filters=(32, 16, 8))

    clf = Dense(64)(conv1d)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.25)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)

    return Model(inputs=[inp], outputs=[clf])

# %%
univariate_classification_conv1d = build_classification_model(test_clf_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
univariate_classification_conv1d.compile(optimizer=optimizer,
                                         loss={'clf': 'binary_crossentropy'},
                                         metrics={'clf': 'accuracy'})

univariate_classification_conv1d.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 120, 1)]          0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 120, 32)           128
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 120, 32)           128
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 120, 32)           0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 120, 32)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 120, 16)           1552
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 120, 16)           64
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 120, 16)           0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 120, 16)           0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 60, 16)            0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 60, 16)            784
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 60, 16)            64
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 60, 16)            0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 60, 16)            0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 60, 8)             392
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 60, 8)             32
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 60, 8)             0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 60, 8)             0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 30, 8)             0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 240)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                15424
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 64)                0
# _________________________________________________________________
# clf (Dense)                  (None, 1)                 65
# =================================================================
# Total params: 18,889
# Trainable params: 18,617
# Non-trainable params: 272
# _________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
clf_history = utils.train_model(univariate_classification_conv1d,
                                model_save_dir, train_clf_gen, test_clf_gen,
                                callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.0951 - accuracy: 0.4970
# Epoch 00001: val_loss improved from inf to 4.71653, saving model to models\conv1d_univar\classification\01.hdf5
# 32/32 [==============================] - 7s 205ms/step - loss: 5.0811 - accuracy: 0.4990 - val_loss: 4.7165 - val_accuracy: 0.5219
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.4991 - accuracy: 0.5312
# Epoch 00002: val_loss improved from 4.71653 to 4.14993, saving model to models\conv1d_univar\classification\02.hdf5
# 32/32 [==============================] - 5s 169ms/step - loss: 4.4976 - accuracy: 0.5247 - val_loss: 4.1499 - val_accuracy: 0.5476
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.9860 - accuracy: 0.5151
# Epoch 00003: val_loss improved from 4.14993 to 3.65869, saving model to models\conv1d_univar\classification\03.hdf5
# 32/32 [==============================] - 5s 165ms/step - loss: 3.9797 - accuracy: 0.5099 - val_loss: 3.6587 - val_accuracy: 0.5244
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.4840 - accuracy: 0.5272
# Epoch 00004: val_loss improved from 3.65869 to 3.22330, saving model to models\conv1d_univar\classification\04.hdf5
# 32/32 [==============================] - 5s 168ms/step - loss: 3.4773 - accuracy: 0.5267 - val_loss: 3.2233 - val_accuracy: 0.5219
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.1497 - accuracy: 0.5363
# Epoch 00005: val_loss improved from 3.22330 to 3.01754, saving model to models\conv1d_univar\classification\05.hdf5
# 32/32 [==============================] - 5s 165ms/step - loss: 3.1477 - accuracy: 0.5316 - val_loss: 3.0175 - val_accuracy: 0.5219
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.9602 - accuracy: 0.5171
# Epoch 00006: val_loss improved from 3.01754 to 2.82485, saving model to models\conv1d_univar\classification\06.hdf5
# 32/32 [==============================] - 5s 160ms/step - loss: 2.9548 - accuracy: 0.5198 - val_loss: 2.8249 - val_accuracy: 0.5219
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.7683 - accuracy: 0.5131
# Epoch 00007: val_loss improved from 2.82485 to 2.64414, saving model to models\conv1d_univar\classification\07.hdf5
# 32/32 [==============================] - 5s 158ms/step - loss: 2.7659 - accuracy: 0.5138 - val_loss: 2.6441 - val_accuracy: 0.5270
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.5777 - accuracy: 0.5433
# Epoch 00008: val_loss improved from 2.64414 to 2.47424, saving model to models\conv1d_univar\classification\08.hdf5
# 32/32 [==============================] - 5s 169ms/step - loss: 2.5752 - accuracy: 0.5445 - val_loss: 2.4742 - val_accuracy: 0.5244
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.4181 - accuracy: 0.5101
# Epoch 00009: val_loss improved from 2.47424 to 2.31588, saving model to models\conv1d_univar\classification\09.hdf5
# 32/32 [==============================] - 5s 166ms/step - loss: 2.4153 - accuracy: 0.5109 - val_loss: 2.3159 - val_accuracy: 0.5219
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2757 - accuracy: 0.5575
# Epoch 00010: val_loss improved from 2.31588 to 2.23768, saving model to models\conv1d_univar\classification\10.hdf5
# 32/32 [==============================] - 5s 165ms/step - loss: 2.2723 - accuracy: 0.5603 - val_loss: 2.2377 - val_accuracy: 0.5270
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2005 - accuracy: 0.5746
# Epoch 00011: val_loss improved from 2.23768 to 2.16506, saving model to models\conv1d_univar\classification\11.hdf5
# 32/32 [==============================] - 5s 166ms/step - loss: 2.1987 - accuracy: 0.5731 - val_loss: 2.1651 - val_accuracy: 0.5244
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1404 - accuracy: 0.5665
# Epoch 00012: val_loss improved from 2.16506 to 2.09495, saving model to models\conv1d_univar\classification\12.hdf5
# 32/32 [==============================] - 6s 173ms/step - loss: 2.1359 - accuracy: 0.5702 - val_loss: 2.0949 - val_accuracy: 0.5193
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0676 - accuracy: 0.5262
# Epoch 00013: val_loss improved from 2.09495 to 2.02832, saving model to models\conv1d_univar\classification\13.hdf5
# 32/32 [==============================] - 5s 166ms/step - loss: 2.0693 - accuracy: 0.5227 - val_loss: 2.0283 - val_accuracy: 0.5219
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0015 - accuracy: 0.5252
# Epoch 00014: val_loss improved from 2.02832 to 1.96288, saving model to models\conv1d_univar\classification\14.hdf5
# 32/32 [==============================] - 5s 160ms/step - loss: 2.0013 - accuracy: 0.5247 - val_loss: 1.9629 - val_accuracy: 0.5244
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9319 - accuracy: 0.5605
# Epoch 00015: val_loss improved from 1.96288 to 1.92939, saving model to models\conv1d_univar\classification\15.hdf5
# 32/32 [==============================] - 5s 159ms/step - loss: 1.9332 - accuracy: 0.5613 - val_loss: 1.9294 - val_accuracy: 0.5296
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9176 - accuracy: 0.5413
# Epoch 00016: val_loss improved from 1.92939 to 1.89829, saving model to models\conv1d_univar\classification\16.hdf5
# 32/32 [==============================] - 5s 160ms/step - loss: 1.9163 - accuracy: 0.5415 - val_loss: 1.8983 - val_accuracy: 0.5270
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9002 - accuracy: 0.5292
# Epoch 00017: val_loss improved from 1.89829 to 1.86693, saving model to models\conv1d_univar\classification\17.hdf5
# 32/32 [==============================] - 5s 159ms/step - loss: 1.8965 - accuracy: 0.5296 - val_loss: 1.8669 - val_accuracy: 0.5373
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.8491 - accuracy: 0.5746
# Epoch 00018: val_loss improved from 1.86693 to 1.83733, saving model to models\conv1d_univar\classification\18.hdf5
# 32/32 [==============================] - 5s 159ms/step - loss: 1.8474 - accuracy: 0.5721 - val_loss: 1.8373 - val_accuracy: 0.5398
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.8283 - accuracy: 0.5585
# Epoch 00019: val_loss improved from 1.83733 to 1.80814, saving model to models\conv1d_univar\classification\19.hdf5
# 32/32 [==============================] - 5s 167ms/step - loss: 1.8253 - accuracy: 0.5583 - val_loss: 1.8081 - val_accuracy: 0.5527
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.8229 - accuracy: 0.5060
# Epoch 00020: val_loss improved from 1.80814 to 1.79406, saving model to models\conv1d_univar\classification\20.hdf5
# 32/32 [==============================] - 5s 157ms/step - loss: 1.8215 - accuracy: 0.5079 - val_loss: 1.7941 - val_accuracy: 0.5501
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7944 - accuracy: 0.5393
# Epoch 00021: val_loss improved from 1.79406 to 1.77949, saving model to models\conv1d_univar\classification\21.hdf5
# 32/32 [==============================] - 5s 159ms/step - loss: 1.7904 - accuracy: 0.5455 - val_loss: 1.7795 - val_accuracy: 0.5501
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7900 - accuracy: 0.5323
# Epoch 00022: val_loss improved from 1.77949 to 1.76495, saving model to models\conv1d_univar\classification\22.hdf5
# 32/32 [==============================] - 5s 160ms/step - loss: 1.7876 - accuracy: 0.5326 - val_loss: 1.7649 - val_accuracy: 0.5424
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7768 - accuracy: 0.5252
# Epoch 00023: val_loss improved from 1.76495 to 1.75188, saving model to models\conv1d_univar\classification\23.hdf5
# 32/32 [==============================] - 5s 158ms/step - loss: 1.7730 - accuracy: 0.5277 - val_loss: 1.7519 - val_accuracy: 0.5321
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7428 - accuracy: 0.5464
# Epoch 00024: val_loss improved from 1.75188 to 1.73846, saving model to models\conv1d_univar\classification\24.hdf5
# 32/32 [==============================] - 5s 160ms/step - loss: 1.7415 - accuracy: 0.5494 - val_loss: 1.7385 - val_accuracy: 0.5398
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7288 - accuracy: 0.5554
# Epoch 00025: val_loss improved from 1.73846 to 1.73148, saving model to models\conv1d_univar\classification\25.hdf5
# 32/32 [==============================] - 5s 158ms/step - loss: 1.7271 - accuracy: 0.5573 - val_loss: 1.7315 - val_accuracy: 0.5373
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7262 - accuracy: 0.5524
# Epoch 00026: val_loss improved from 1.73148 to 1.72526, saving model to models\conv1d_univar\classification\26.hdf5
# 32/32 [==============================] - 5s 159ms/step - loss: 1.7263 - accuracy: 0.5514 - val_loss: 1.7253 - val_accuracy: 0.5373
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7189 - accuracy: 0.5444
# Epoch 00027: val_loss improved from 1.72526 to 1.71847, saving model to models\conv1d_univar\classification\27.hdf5
# 32/32 [==============================] - 5s 159ms/step - loss: 1.7190 - accuracy: 0.5464 - val_loss: 1.7185 - val_accuracy: 0.5347
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7131 - accuracy: 0.5343
# Epoch 00028: val_loss improved from 1.71847 to 1.71174, saving model to models\conv1d_univar\classification\28.hdf5
# 32/32 [==============================] - 5s 164ms/step - loss: 1.7145 - accuracy: 0.5326 - val_loss: 1.7117 - val_accuracy: 0.5398
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7079 - accuracy: 0.5635
# Epoch 00029: val_loss improved from 1.71174 to 1.70550, saving model to models\conv1d_univar\classification\29.hdf5
# 32/32 [==============================] - 5s 165ms/step - loss: 1.7070 - accuracy: 0.5672 - val_loss: 1.7055 - val_accuracy: 0.5424
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7106 - accuracy: 0.5413
# Epoch 00030: val_loss improved from 1.70550 to 1.70216, saving model to models\conv1d_univar\classification\30.hdf5
# 32/32 [==============================] - 5s 163ms/step - loss: 1.7083 - accuracy: 0.5435 - val_loss: 1.7022 - val_accuracy: 0.5424
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7002 - accuracy: 0.5504
# Epoch 00031: val_loss improved from 1.70216 to 1.69908, saving model to models\conv1d_univar\classification\31.hdf5
# 32/32 [==============================] - 5s 171ms/step - loss: 1.6996 - accuracy: 0.5484 - val_loss: 1.6991 - val_accuracy: 0.5450
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.7064 - accuracy: 0.5333
# Epoch 00032: val_loss improved from 1.69908 to 1.69602, saving model to models\conv1d_univar\classification\32.hdf5
# 32/32 [==============================] - 6s 178ms/step - loss: 1.7124 - accuracy: 0.5316 - val_loss: 1.6960 - val_accuracy: 0.5424

# %%
def plot_clf_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'Loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'Accuracy', 'accuracy', 'val_accuracy')
    
plot_clf_history(clf_history);

# %% [markdown]
# ### Прогноз задачи классификации

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_classification_conv1d.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %%
pred_direction_proba = univariate_classification_conv1d.predict_generator(test_clf_gen, verbose=1)

true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 13/13 [==============================] - 0s 23ms/step
# 0.4832678

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([203, 186], dtype=int64)),
#  (array([0, 1]), array([211, 178], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.56      0.55       203
#            1       0.49      0.47      0.48       186
#
#     accuracy                           0.52       389
#    macro avg       0.51      0.51      0.51       389
# weighted avg       0.52      0.52      0.52       389

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[113,  90],
#        [ 98,  88]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.53554502, 0.50561798],
#        [0.46445498, 0.49438202]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# ## Многозадачная модель: одновременно регрессия и классификация

# %%
model_class_name = 'multitask'

# %%
train_multi_gen = MultitaskGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_multi_gen = MultitaskGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_multi_gen = MultitaskGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_multitask_model(input_shape):
    inp, conv1d = build_conv1d_layers(input_shape, filters=(32, 16, 8))

    # первый выход: задача регрссии
    regr = Dense(64)(conv1d)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.25)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    # второй выход: задача классификации
    clf = Dense(64)(conv1d)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.25)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)
    
    return Model(inputs=[inp], outputs=[regr, clf])

# %%
univariate_multitask_conv1d = build_multitask_model(train_multi_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
univariate_multitask_conv1d.compile(optimizer=optimizer,
                                    loss={'regr': 'mse', 'clf': 'binary_crossentropy'},
                                    loss_weights={'regr': 1., 'clf': 1.},
                                    metrics={'regr': 'mae', 'clf' : 'accuracy'})

univariate_multitask_conv1d.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 120, 1)]     0
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 120, 32)      128         input[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 120, 32)      128         conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 120, 32)      0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 120, 32)      0           leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 120, 16)      1552        dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 120, 16)      64          conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 120, 16)      0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 120, 16)      0           leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 60, 16)       0           dropout_11[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 60, 16)       784         max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 60, 16)       64          conv1d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 60, 16)       0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 60, 16)       0           leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 60, 8)        392         dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 60, 8)        32          conv1d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 60, 8)        0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 60, 8)        0           leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 30, 8)        0           dropout_13[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 240)          0           max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           15424       flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           15424       flatten_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64)           256         dense_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64)           256         dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 64)           0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 64)           0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 64)           0           leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 64)           0           leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# regr (Dense)                    (None, 1)            65          dropout_14[0][0]
# __________________________________________________________________________________________________
# clf (Dense)                     (None, 1)            65          dropout_15[0][0]
# ==================================================================================================
# Total params: 34,634
# Trainable params: 34,234
# Non-trainable params: 400
# __________________________________________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
multitask_history = utils.train_model(univariate_multitask_conv1d,
                                      model_save_dir, train_multi_gen, test_multi_gen,
                                      callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                      force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.3767 - regr_loss: 2.0653 - clf_loss: 0.7824 - regr_mae: 0.9848 - clf_accuracy: 0.5020
# Epoch 00001: val_loss improved from inf to 6.26928, saving model to models\conv1d_univar\multitask\01.hdf5
# 32/32 [==============================] - 7s 208ms/step - loss: 7.3643 - regr_loss: 2.0533 - clf_loss: 0.7839 - regr_mae: 0.9862 - clf_accuracy: 0.5010 - val_loss: 6.2693 - val_regr_loss: 1.1083 - val_clf_loss: 0.7027 - val_regr_mae: 0.6773 - val_clf_accuracy: 0.4499
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.7390 - regr_loss: 1.5938 - clf_loss: 0.7566 - regr_mae: 0.8655 - clf_accuracy: 0.5101 ETA: 5s - loss: 6.7663 - regr_loss: 1.6034 -
# Epoch 00002: val_loss improved from 6.26928 to 6.08726, saving model to models\conv1d_univar\multitask\02.hdf5
# 32/32 [==============================] - 7s 206ms/step - loss: 6.7133 - regr_loss: 1.5695 - clf_loss: 0.7574 - regr_mae: 0.8631 - clf_accuracy: 0.5099 - val_loss: 6.0873 - val_regr_loss: 1.0823 - val_clf_loss: 0.6963 - val_regr_mae: 0.6591 - val_clf_accuracy: 0.4961
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.3030 - regr_loss: 1.3255 - clf_loss: 0.7427 - regr_mae: 0.7793 - clf_accuracy: 0.4940
# Epoch 00003: val_loss improved from 6.08726 to 5.93379, saving model to models\conv1d_univar\multitask\03.hdf5
# 32/32 [==============================] - 6s 200ms/step - loss: 6.2814 - regr_loss: 1.3020 - clf_loss: 0.7469 - regr_mae: 0.7761 - clf_accuracy: 0.4931 - val_loss: 5.9338 - val_regr_loss: 1.0892 - val_clf_loss: 0.6943 - val_regr_mae: 0.6606 - val_clf_accuracy: 0.5141
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.1189 - regr_loss: 1.2986 - clf_loss: 0.7443 - regr_mae: 0.7744 - clf_accuracy: 0.5343
# Epoch 00004: val_loss improved from 5.93379 to 5.77865, saving model to models\conv1d_univar\multitask\04.hdf5
# 32/32 [==============================] - 6s 197ms/step - loss: 6.0968 - regr_loss: 1.2810 - clf_loss: 0.7421 - regr_mae: 0.7733 - clf_accuracy: 0.5356 - val_loss: 5.7787 - val_regr_loss: 1.0917 - val_clf_loss: 0.6958 - val_regr_mae: 0.6637 - val_clf_accuracy: 0.5270
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.0635 - regr_loss: 1.3742 - clf_loss: 0.7369 - regr_mae: 0.7687 - clf_accuracy: 0.5030
# Epoch 00005: val_loss improved from 5.77865 to 5.70384, saving model to models\conv1d_univar\multitask\05.hdf5
# 32/32 [==============================] - 6s 194ms/step - loss: 6.0474 - regr_loss: 1.3581 - clf_loss: 0.7381 - regr_mae: 0.7686 - clf_accuracy: 0.5030 - val_loss: 5.7038 - val_regr_loss: 1.0992 - val_clf_loss: 0.6963 - val_regr_mae: 0.6673 - val_clf_accuracy: 0.4859
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.7902 - regr_loss: 1.2066 - clf_loss: 0.7141 - regr_mae: 0.7418 - clf_accuracy: 0.5363
# Epoch 00006: val_loss improved from 5.70384 to 5.63620, saving model to models\conv1d_univar\multitask\06.hdf5
# 32/32 [==============================] - 6s 198ms/step - loss: 5.7767 - regr_loss: 1.1933 - clf_loss: 0.7150 - regr_mae: 0.7395 - clf_accuracy: 0.5356 - val_loss: 5.6362 - val_regr_loss: 1.1139 - val_clf_loss: 0.6963 - val_regr_mae: 0.6739 - val_clf_accuracy: 0.5064
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.6825 - regr_loss: 1.1829 - clf_loss: 0.7131 - regr_mae: 0.7261 - clf_accuracy: 0.5212
# Epoch 00007: val_loss improved from 5.63620 to 5.56333, saving model to models\conv1d_univar\multitask\07.hdf5
# 32/32 [==============================] - 6s 197ms/step - loss: 5.6737 - regr_loss: 1.1714 - clf_loss: 0.7172 - regr_mae: 0.7251 - clf_accuracy: 0.5198 - val_loss: 5.5633 - val_regr_loss: 1.1262 - val_clf_loss: 0.6955 - val_regr_mae: 0.6808 - val_clf_accuracy: 0.5167
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.6596 - regr_loss: 1.2463 - clf_loss: 0.7122 - regr_mae: 0.7390 - clf_accuracy: 0.5323
# Epoch 00008: val_loss improved from 5.56333 to 5.48344, saving model to models\conv1d_univar\multitask\08.hdf5
# 32/32 [==============================] - 6s 200ms/step - loss: 5.6371 - regr_loss: 1.2257 - clf_loss: 0.7114 - regr_mae: 0.7364 - clf_accuracy: 0.5326 - val_loss: 5.4834 - val_regr_loss: 1.1308 - val_clf_loss: 0.6976 - val_regr_mae: 0.6818 - val_clf_accuracy: 0.4859
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.5181 - regr_loss: 1.1859 - clf_loss: 0.7179 - regr_mae: 0.7222 - clf_accuracy: 0.5222
# Epoch 00009: val_loss improved from 5.48344 to 5.39360, saving model to models\conv1d_univar\multitask\09.hdf5
# 32/32 [==============================] - 6s 197ms/step - loss: 5.5044 - regr_loss: 1.1757 - clf_loss: 0.7156 - regr_mae: 0.7214 - clf_accuracy: 0.5267 - val_loss: 5.3936 - val_regr_loss: 1.1262 - val_clf_loss: 0.6988 - val_regr_mae: 0.6779 - val_clf_accuracy: 0.4910
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.4580 - regr_loss: 1.1910 - clf_loss: 0.7186 - regr_mae: 0.7258 - clf_accuracy: 0.5252
# Epoch 00010: val_loss improved from 5.39360 to 5.34985, saving model to models\conv1d_univar\multitask\10.hdf5
# 32/32 [==============================] - 6s 202ms/step - loss: 5.4399 - regr_loss: 1.1759 - clf_loss: 0.7160 - regr_mae: 0.7240 - clf_accuracy: 0.5277 - val_loss: 5.3498 - val_regr_loss: 1.1256 - val_clf_loss: 0.6990 - val_regr_mae: 0.6769 - val_clf_accuracy: 0.5090
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.4501 - regr_loss: 1.2471 - clf_loss: 0.6987 - regr_mae: 0.7258 - clf_accuracy: 0.5423
# Epoch 00011: val_loss improved from 5.34985 to 5.31632, saving model to models\conv1d_univar\multitask\11.hdf5
# 32/32 [==============================] - 7s 206ms/step - loss: 5.4436 - regr_loss: 1.2396 - clf_loss: 0.7003 - regr_mae: 0.7258 - clf_accuracy: 0.5415 - val_loss: 5.3163 - val_regr_loss: 1.1358 - val_clf_loss: 0.6998 - val_regr_mae: 0.6803 - val_clf_accuracy: 0.5090
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.4272 - regr_loss: 1.2453 - clf_loss: 0.7217 - regr_mae: 0.7330 - clf_accuracy: 0.5101
# Epoch 00012: val_loss improved from 5.31632 to 5.27321, saving model to models\conv1d_univar\multitask\12.hdf5
# 32/32 [==============================] - 8s 242ms/step - loss: 5.4207 - regr_loss: 1.2412 - clf_loss: 0.7200 - regr_mae: 0.7342 - clf_accuracy: 0.5119 - val_loss: 5.2732 - val_regr_loss: 1.1370 - val_clf_loss: 0.6998 - val_regr_mae: 0.6793 - val_clf_accuracy: 0.5116
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.2356 - regr_loss: 1.1200 - clf_loss: 0.7001 - regr_mae: 0.6928 - clf_accuracy: 0.5433
# Epoch 00013: val_loss improved from 5.27321 to 5.22682, saving model to models\conv1d_univar\multitask\13.hdf5
# 32/32 [==============================] - 7s 210ms/step - loss: 5.2268 - regr_loss: 1.1128 - clf_loss: 0.6992 - regr_mae: 0.6942 - clf_accuracy: 0.5445 - val_loss: 5.2268 - val_regr_loss: 1.1355 - val_clf_loss: 0.7001 - val_regr_mae: 0.6772 - val_clf_accuracy: 0.5116
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.1825 - regr_loss: 1.1125 - clf_loss: 0.6999 - regr_mae: 0.6939 - clf_accuracy: 0.5252
# Epoch 00014: val_loss improved from 5.22682 to 5.18131, saving model to models\conv1d_univar\multitask\14.hdf5
# 32/32 [==============================] - 6s 202ms/step - loss: 5.1752 - regr_loss: 1.1056 - clf_loss: 0.7001 - regr_mae: 0.6941 - clf_accuracy: 0.5267 - val_loss: 5.1813 - val_regr_loss: 1.1362 - val_clf_loss: 0.6991 - val_regr_mae: 0.6766 - val_clf_accuracy: 0.4961
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.2047 - regr_loss: 1.1709 - clf_loss: 0.6986 - regr_mae: 0.7160 - clf_accuracy: 0.5292
# Epoch 00015: val_loss improved from 5.18131 to 5.15815, saving model to models\conv1d_univar\multitask\15.hdf5
# 32/32 [==============================] - 6s 198ms/step - loss: 5.2127 - regr_loss: 1.1816 - clf_loss: 0.6963 - regr_mae: 0.7179 - clf_accuracy: 0.5336 - val_loss: 5.1581 - val_regr_loss: 1.1363 - val_clf_loss: 0.6989 - val_regr_mae: 0.6769 - val_clf_accuracy: 0.4936
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.8773 - regr_loss: 0.8658 - clf_loss: 0.6994 - regr_mae: 0.6828 - clf_accuracy: 0.5181
# Epoch 00016: val_loss improved from 5.15815 to 5.13996, saving model to models\conv1d_univar\multitask\16.hdf5
# 32/32 [==============================] - 7s 211ms/step - loss: 5.2677 - regr_loss: 1.2614 - clf_loss: 0.6990 - regr_mae: 0.6999 - clf_accuracy: 0.5178 - val_loss: 5.1400 - val_regr_loss: 1.1404 - val_clf_loss: 0.6994 - val_regr_mae: 0.6772 - val_clf_accuracy: 0.5013
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.0612 - regr_loss: 1.0742 - clf_loss: 0.6977 - regr_mae: 0.6698 - clf_accuracy: 0.5101
# Epoch 00017: val_loss improved from 5.13996 to 5.11732, saving model to models\conv1d_univar\multitask\17.hdf5
# 32/32 [==============================] - 7s 208ms/step - loss: 5.0565 - regr_loss: 1.0726 - clf_loss: 0.6949 - regr_mae: 0.6727 - clf_accuracy: 0.5138 - val_loss: 5.1173 - val_regr_loss: 1.1406 - val_clf_loss: 0.6998 - val_regr_mae: 0.6777 - val_clf_accuracy: 0.5039
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.0138 - regr_loss: 1.0594 - clf_loss: 0.6882 - regr_mae: 0.6883 - clf_accuracy: 0.5534
# Epoch 00018: val_loss improved from 5.11732 to 5.09050, saving model to models\conv1d_univar\multitask\18.hdf5
# 32/32 [==============================] - 7s 209ms/step - loss: 4.9975 - regr_loss: 1.0447 - clf_loss: 0.6867 - regr_mae: 0.6864 - clf_accuracy: 0.5563 - val_loss: 5.0905 - val_regr_loss: 1.1371 - val_clf_loss: 0.6994 - val_regr_mae: 0.6773 - val_clf_accuracy: 0.4961
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.0125 - regr_loss: 1.0743 - clf_loss: 0.6952 - regr_mae: 0.6740 - clf_accuracy: 0.5363
# Epoch 00019: val_loss improved from 5.09050 to 5.07045, saving model to models\conv1d_univar\multitask\19.hdf5
# 32/32 [==============================] - 7s 206ms/step - loss: 5.0012 - regr_loss: 1.0642 - clf_loss: 0.6942 - regr_mae: 0.6732 - clf_accuracy: 0.5375 - val_loss: 5.0705 - val_regr_loss: 1.1407 - val_clf_loss: 0.6992 - val_regr_mae: 0.6784 - val_clf_accuracy: 0.5039
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.0205 - regr_loss: 1.0961 - clf_loss: 0.6995 - regr_mae: 0.6942 - clf_accuracy: 0.5403
# Epoch 00020: val_loss improved from 5.07045 to 5.06294, saving model to models\conv1d_univar\multitask\20.hdf5
# 32/32 [==============================] - 7s 208ms/step - loss: 5.0058 - regr_loss: 1.0832 - clf_loss: 0.6976 - regr_mae: 0.6938 - clf_accuracy: 0.5425 - val_loss: 5.0629 - val_regr_loss: 1.1448 - val_clf_loss: 0.6996 - val_regr_mae: 0.6799 - val_clf_accuracy: 0.5116
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.0131 - regr_loss: 1.1094 - clf_loss: 0.6908 - regr_mae: 0.6867 - clf_accuracy: 0.5242
# Epoch 00021: val_loss improved from 5.06294 to 5.04915, saving model to models\conv1d_univar\multitask\21.hdf5
# 32/32 [==============================] - 7s 210ms/step - loss: 5.0000 - regr_loss: 1.0950 - clf_loss: 0.6922 - regr_mae: 0.6852 - clf_accuracy: 0.5257 - val_loss: 5.0492 - val_regr_loss: 1.1424 - val_clf_loss: 0.7003 - val_regr_mae: 0.6788 - val_clf_accuracy: 0.5039
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.0285 - regr_loss: 1.1351 - clf_loss: 0.6926 - regr_mae: 0.6826 - clf_accuracy: 0.5353
# Epoch 00022: val_loss improved from 5.04915 to 5.03436, saving model to models\conv1d_univar\multitask\22.hdf5
# 32/32 [==============================] - 6s 198ms/step - loss: 5.0125 - regr_loss: 1.1174 - clf_loss: 0.6943 - regr_mae: 0.6802 - clf_accuracy: 0.5356 - val_loss: 5.0344 - val_regr_loss: 1.1400 - val_clf_loss: 0.7001 - val_regr_mae: 0.6773 - val_clf_accuracy: 0.5116
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.9546 - regr_loss: 1.0683 - clf_loss: 0.6976 - regr_mae: 0.6673 - clf_accuracy: 0.5353
# Epoch 00023: val_loss improved from 5.03436 to 5.02403, saving model to models\conv1d_univar\multitask\23.hdf5
# 32/32 [==============================] - 6s 201ms/step - loss: 4.9360 - regr_loss: 1.0520 - clf_loss: 0.6954 - regr_mae: 0.6654 - clf_accuracy: 0.5366 - val_loss: 5.0240 - val_regr_loss: 1.1418 - val_clf_loss: 0.7002 - val_regr_mae: 0.6777 - val_clf_accuracy: 0.5167
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.7091 - regr_loss: 0.8381 - clf_loss: 0.6947 - regr_mae: 0.6640 - clf_accuracy: 0.5151
# Epoch 00024: val_loss improved from 5.02403 to 5.01245, saving model to models\conv1d_univar\multitask\24.hdf5
# 32/32 [==============================] - 6s 198ms/step - loss: 5.1343 - regr_loss: 1.2683 - clf_loss: 0.6947 - regr_mae: 0.6791 - clf_accuracy: 0.5158 - val_loss: 5.0124 - val_regr_loss: 1.1425 - val_clf_loss: 0.7002 - val_regr_mae: 0.6776 - val_clf_accuracy: 0.5090
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.9692 - regr_loss: 1.1086 - clf_loss: 0.6937 - regr_mae: 0.6816 - clf_accuracy: 0.5444
# Epoch 00025: val_loss improved from 5.01245 to 5.00674, saving model to models\conv1d_univar\multitask\25.hdf5
# 32/32 [==============================] - 6s 199ms/step - loss: 4.9551 - regr_loss: 1.0964 - clf_loss: 0.6918 - regr_mae: 0.6805 - clf_accuracy: 0.5435 - val_loss: 5.0067 - val_regr_loss: 1.1429 - val_clf_loss: 0.7003 - val_regr_mae: 0.6775 - val_clf_accuracy: 0.5090
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.9001 - regr_loss: 1.0471 - clf_loss: 0.6924 - regr_mae: 0.6837 - clf_accuracy: 0.5504
# Epoch 00026: val_loss improved from 5.00674 to 5.00018, saving model to models\conv1d_univar\multitask\26.hdf5
# 32/32 [==============================] - 7s 209ms/step - loss: 4.9122 - regr_loss: 1.0583 - clf_loss: 0.6935 - regr_mae: 0.6893 - clf_accuracy: 0.5494 - val_loss: 5.0002 - val_regr_loss: 1.1427 - val_clf_loss: 0.7003 - val_regr_mae: 0.6773 - val_clf_accuracy: 0.5141
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.8915 - regr_loss: 1.0437 - clf_loss: 0.6936 - regr_mae: 0.6474 - clf_accuracy: 0.5433
# Epoch 00027: val_loss improved from 5.00018 to 4.99559, saving model to models\conv1d_univar\multitask\27.hdf5
# 32/32 [==============================] - 7s 203ms/step - loss: 4.8765 - regr_loss: 1.0262 - clf_loss: 0.6960 - regr_mae: 0.6458 - clf_accuracy: 0.5435 - val_loss: 4.9956 - val_regr_loss: 1.1444 - val_clf_loss: 0.7003 - val_regr_mae: 0.6780 - val_clf_accuracy: 0.5141
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.8994 - regr_loss: 1.0569 - clf_loss: 0.6946 - regr_mae: 0.6765 - clf_accuracy: 0.5393
# Epoch 00028: val_loss improved from 4.99559 to 4.99040, saving model to models\conv1d_univar\multitask\28.hdf5
# 32/32 [==============================] - 7s 210ms/step - loss: 4.8936 - regr_loss: 1.0524 - clf_loss: 0.6933 - regr_mae: 0.6778 - clf_accuracy: 0.5395 - val_loss: 4.9904 - val_regr_loss: 1.1455 - val_clf_loss: 0.7005 - val_regr_mae: 0.6779 - val_clf_accuracy: 0.5116
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.8874 - regr_loss: 1.0563 - clf_loss: 0.6897 - regr_mae: 0.6784 - clf_accuracy: 0.5393
# Epoch 00029: val_loss improved from 4.99040 to 4.98526, saving model to models\conv1d_univar\multitask\29.hdf5
# 32/32 [==============================] - 6s 200ms/step - loss: 4.8947 - regr_loss: 1.0656 - clf_loss: 0.6878 - regr_mae: 0.6835 - clf_accuracy: 0.5445 - val_loss: 4.9853 - val_regr_loss: 1.1467 - val_clf_loss: 0.7006 - val_regr_mae: 0.6779 - val_clf_accuracy: 0.4987
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.9318 - regr_loss: 1.0980 - clf_loss: 0.6973 - regr_mae: 0.6854 - clf_accuracy: 0.5393
# Epoch 00030: val_loss improved from 4.98526 to 4.98251, saving model to models\conv1d_univar\multitask\30.hdf5
# 32/32 [==============================] - 6s 199ms/step - loss: 4.9330 - regr_loss: 1.0993 - clf_loss: 0.6973 - regr_mae: 0.6888 - clf_accuracy: 0.5395 - val_loss: 4.9825 - val_regr_loss: 1.1471 - val_clf_loss: 0.7006 - val_regr_mae: 0.6782 - val_clf_accuracy: 0.4936
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.8984 - regr_loss: 1.0686 - clf_loss: 0.6966 - regr_mae: 0.6743 - clf_accuracy: 0.5242
# Epoch 00031: val_loss improved from 4.98251 to 4.97915, saving model to models\conv1d_univar\multitask\31.hdf5
# 32/32 [==============================] - 6s 196ms/step - loss: 4.8778 - regr_loss: 1.0481 - clf_loss: 0.6963 - regr_mae: 0.6715 - clf_accuracy: 0.5198 - val_loss: 4.9791 - val_regr_loss: 1.1470 - val_clf_loss: 0.7007 - val_regr_mae: 0.6784 - val_clf_accuracy: 0.5064
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.9409 - regr_loss: 1.1096 - clf_loss: 0.7014 - regr_mae: 0.6810 - clf_accuracy: 0.5363
# Epoch 00032: val_loss improved from 4.97915 to 4.97572, saving model to models\conv1d_univar\multitask\32.hdf5
# 32/32 [==============================] - 6s 195ms/step - loss: 4.9350 - regr_loss: 1.1042 - clf_loss: 0.7008 - regr_mae: 0.6824 - clf_accuracy: 0.5346 - val_loss: 4.9757 - val_regr_loss: 1.1469 - val_clf_loss: 0.7006 - val_regr_mae: 0.6784 - val_clf_accuracy: 0.5090

# %%
def plot_multitask_history(hist):
    fig, ax = plt.subplots(2, 2, figsize=(16, 12))
    plotHelpers.plot_train_history(ax[0, 0], hist, 'Total loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[0, 1], hist, 'Accuracy', 'clf_accuracy', 'val_clf_accuracy')
    plotHelpers.plot_train_history(ax[1, 0], hist, 'MSE', 'regr_loss', 'val_regr_loss')
    plotHelpers.plot_train_history(ax[1, 1], hist, 'MAE', 'regr_mae', 'val_regr_mae')
    
plot_multitask_history(multitask_history);

# %% [markdown]
# ### Прогноз

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_multitask_conv1d.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret, pred_direction_proba = univariate_multitask_conv1d.predict_generator(test_multi_gen, verbose=1)
# Out:
# 13/13 [==============================] - 0s 28ms/step

# %%
np.set_printoptions(precision=3, suppress=True)

np.column_stack([pred_log_ret, pred_direction_proba])[-10:]
# Out:
# array([[-0.005,  0.498],
#        [ 0.046,  0.473],
#        [ 0.031,  0.503],
#        [-0.024,  0.447],
#        [ 0.003,  0.482],
#        [-0.187,  0.463],
#        [-0.133,  0.47 ],
#        [-0.052,  0.488],
#        [ 0.023,  0.501],
#        [ 0.079,  0.489]], dtype=float32)

# %% [markdown]
# #### Прогноз задачи регрессии

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret, figsize=(16, 10),
                                  datetime_unit='m', plot_data_slice=slice(1, None))

# %% [markdown]
# #### Прогноз задачи классификации

# %%
true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 0.49645203

# %%
true_direction = test_multi_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([203, 186], dtype=int64)),
#  (array([0, 1]), array([204, 185], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.51      0.51       203
#            1       0.46      0.46      0.46       186
#
#     accuracy                           0.49       389
#    macro avg       0.49      0.49      0.49       389
# weighted avg       0.49      0.49      0.49       389

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[104,  99],
#        [100,  86]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.51 , 0.535],
#        [0.49 , 0.465]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# # Выводы
#
# 1.  Модель с 1D свёртками обучается гораздо быстрее модели LSTM
# 2.  Задача классификации не решается удовлетворительно.

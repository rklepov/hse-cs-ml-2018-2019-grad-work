# %% [markdown]
# # *Одномерная модель на 1D свёрточных слоях*
#
# В качестве единственного признака используется сама цена.

# %%
import os
import glob
import datetime
import pickle

import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from pandas_datareader import data as pdr

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
import tensorflow as tf
# tf.test.is_gpu_available()
tf.__version__
# Out:
# '2.0.0'

# %%
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import (Input, Dense, Convolution1D, MaxPooling1D, Flatten,
                                     ReLU, LeakyReLU, Dropout, BatchNormalization)
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers import Nadam

# %%
from mdp import TimeSeries
from mdp import MarketData
from mdp import MovingWindowFeatures
from mdp import ClassificationGenerator, RegressionGenerator, MultitaskGenerator
from mdp import invert_log_ret

import mdp.utils as utils
import mdp.plotHelpers as plotHelpers

# %%
import importlib

import mdp

importlib.reload(mdp)
importlib.reload(mdp.datasetGenerator)
importlib.reload(mdp.marketData)
importlib.reload(mdp.movingWindowFeatures)
importlib.reload(mdp.timeSeries)
importlib.reload(mdp.plotHelpers)
importlib.reload(mdp.utils);

# %% [markdown]
# # *Параметры*

# %%
INSTRUMENT = 'MSFT' # Microsoft corp
START_FROM = np.datetime64('today') - 7
WINDOW_SIZE = 120
FORECAST_OFFSET=1
BATCH_SIZE = 32
FORCE_TRAIN = True

# %% [markdown]
# # *Исходные данные*
#
# Загрузка данных и вычисление индикаторов.

# %%
instr = MarketData.create_from_alphavantage_intraday(INSTRUMENT, start=START_FROM)

# %%
instr.feature_names
# Out:
# ['o',
#  'h',
#  'l',
#  'c',
#  'v',
#  'ema14',
#  'ema30',
#  'macd',
#  'macd_signal',
#  'rsi14',
#  'bband20_upper',
#  'bband20_middle',
#  'bband20_lower',
#  'willr14',
#  'stochk',
#  'stochd',
#  'adline',
#  'adosc']

# %% [markdown]
# Здесь не будем делить отдельно на тест и валидацию, поскольку данных у нас только 5 дней.

# %%
dates_unique = np.unique(instr.timestamps.astype('datetime64[D]'))

START_FROM = dates_unique[0]
VAL_TEST_SPLIT = dates_unique[-1]

START_FROM, VAL_TEST_SPLIT
# Out:
# (numpy.datetime64('2020-04-08'), numpy.datetime64('2020-04-14'))

# %% [markdown]
# ## Целевая переменная

# %% [markdown]
# Цена закрытия.

# %%
orig_target = instr.c

# %% [markdown]
# Переходим к логарифмической доходности.

# %%
transformed_target = instr.c.transform(transforms={'ratios' : {}, 'ln' : {}})

# %%
plotHelpers.plot_transformed_timeseries_unit(instr,
                                             transformed_target,
                                             'Close price, USD', 'Log return',
                                             datetime_unit='m', rotation=45)

# %% [markdown]
# ## Трансформация признаков
#
# Из признаков выбираем только цену закрытия. Временной ряд цен преобразуется к ряду логарифмических доходностей (что также позволяет убрать нестационарность).

# %%
def make_feature_selector():
    price_transformer = lambda: {'ratios': {}, 'ln': {}}
    diff_transformer = lambda o: {'diffs': {'order': o}}
    identity_transformer = lambda: {}
    feature_transformations = {
        'c': price_transformer(),
    }
    return feature_transformations

# %%
instr_transformed = instr.select_transform(make_feature_selector())

# %%
transformed_target = instr_transformed.c

# %% [markdown]
# ## Обучающая, валидационная и тестовая выборки

# %%
instr_train, instr_test = instr_transformed.train_test_split(VAL_TEST_SPLIT, window_size=WINDOW_SIZE,
                                                             scaler=StandardScaler)
#                                                              scaler=MinMaxScaler,
#                                                              scaler_kwargs={'feature_range': (-1, 1)})

# instr_val, instr_test = instr_val_test.train_test_split(TEST_SPLIT, window_size=WINDOW_SIZE, scaler=None)

len(instr_train), len(instr_test)
# Out:
# (1136, 506)

# %% [markdown]
# ## Признаки - скользящие окна

# %%
train_mwf = MovingWindowFeatures.create(instr_train.c, [instr_train], instr_train.feature_names, window_size=WINDOW_SIZE)
# val_mwf = MovingWindowFeatures.create(instr_val.c, [instr_val], instr_val.feature_names, window_size=WINDOW_SIZE)
test_mwf = MovingWindowFeatures.create(instr_test.c, [instr_test], instr_test.feature_names, window_size=WINDOW_SIZE)

len(instr_train), len(train_mwf), train_mwf.features.shape
# Out:
# (1136, 1016, (1016, 120, 1))

# %% [markdown]
# Проверка, что скользящие окна соответствуют исходным данным.
#
# Возьмём произвольный признак и произвольное окно (строка #**41**). Проверим, что данные в точности совпадают:

# %%
def check_data(md, mwf, row):
    col = np.random.randint(len(mwf.feature_names))
    feature = mwf.feature_names[col]
    check = (getattr(md, feature).data[row:row + mwf.window_size] == mwf.features[row, :, col]).all()
    assert check
    return feature, check

check_data(instr_train, train_mwf, 41)
# Out:
# ('c', True)

# %% [markdown]
# # *Модели*

# %% [markdown]
# Модель с двумя 1D свёрточными слоями.

# %%
def build_conv1d_layers(input_shape, filters=(32, 16, 8), kernel_size=3, pool_size=2):
    # формат входа: наша матрица (окно; признак)
    inp = Input(input_shape, name='input')

    filter_blocks = np.array(filters)
    filter_blocks = np.lib.stride_tricks.as_strided(filter_blocks, 
                                                    (filter_blocks.shape[0] - 1, 2), 
                                                    2 * [filter_blocks.strides[0]])
    conv1d = inp
    # стекаем слои Conv1D: блоками Conv1D-Conv1D-MaxPool
    for filter_block in filter_blocks:
        for f in filter_block:
            conv1d = Convolution1D(filters=f,
                                   kernel_size=kernel_size,
                                   padding='same',
                                   bias_initializer='he_uniform',
                                   bias_regularizer=L1L2(0.01, 0.02),
                                   kernel_regularizer=L1L2(0.01, 0.02)
                                  )(conv1d)
            conv1d = BatchNormalization()(conv1d)
            conv1d = LeakyReLU()(conv1d)
            conv1d = Dropout(0.25)(conv1d)
        conv1d = MaxPooling1D(pool_size=pool_size)(conv1d)
    
    conv1d = Flatten()(conv1d)
    
    return inp, conv1d

# %% [markdown]
# #### Пути сохранения моделей:

# %%
model_path_root = 'models'
model_type_name = 'conv1d_univar'

def make_model_save_dir(path_root, type_name, class_name):
    save_dir = os.path.join(path_root, type_name, class_name)
    os.makedirs(save_dir, exist_ok=True)
    return save_dir

# %% [markdown]
# #### Общие коллбэки:

# %%
# уменьшение learning rate в случае, если loss не изменяется
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001, verbose=1)

# уменьшение learning rate в 2 раза каждую 5-ю эпоху
def lr_decay(e, lr):
    return lr * (1 - 0.5 * (0 == (e + 1) % 5))

lr_scheduler = LearningRateScheduler(schedule=lr_decay, verbose=1)

# %% [markdown]
# ## Задача регрессии
#
# Непосредственное прогнозирование цены следующего периода.

# %%
train_regr_gen = RegressionGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_regr_gen = RegressionGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_regr_gen = RegressionGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# Следующие числа соответствуют значению параметра `steps_per_epoch` метода [`fit_generator`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit_generator "tf.keras.layers.SimpleRNN &nbsp;|&nbsp; TensorFlow Core r2.0") - то есть это число батчей, которые генератор выдаст за одну эпоху обучения (если класс генератора поддерживает метод `len()`, то данный параметр можно не указывать).

# %%
len(train_regr_gen), len(test_regr_gen)
# Out:
# (32, 13)

# %% [markdown]
# Один сэмпл данных представляет собой матрицу размером *(длина окна; число признаков)*

# %%
train_regr_gen.input_shape
# Out:
# (120, 1)

# %% [markdown]
# ### Модель для задачи регрессии

# %%
model_class_name = 'regression'

# %%
def build_regression_model(input_shape):
    inp, conv1d = build_conv1d_layers(input_shape, filters=(32, 16, 8))

    regr = Dense(64)(conv1d)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.25)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    return Model(inputs=[inp], outputs=[regr])

# %%
univariate_regression_conv1d = build_regression_model(train_regr_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:
# [`Nadam`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Nadam) (*Adam with Nestrov momentum*).

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Функция потерь:
#
# В качестве функции потерь будем использовать [MSE](https://www.tensorflow.org/api_docs/python/tf/keras/losses/MSE) (чтобы штрафовать за большие отклонения). Xотя хорошая функция потерь в контексте темы данной задачи - это [вопрос сложный](https://github.com/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Chapter5_LossFunctions/Ch5_LossFunctions_PyMC3.ipynb). В частности, здесь нам, очевидно, помимо абсолютного значения отклонения также важен его знак.

# %%
univariate_regression_conv1d.compile(optimizer=optimizer,
                                   loss={'regr': 'mse'},
                                   metrics={'regr': 'mae'})

univariate_regression_conv1d.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 120, 1)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 120, 32)           128
# _________________________________________________________________
# batch_normalization (BatchNo (None, 120, 32)           128
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 120, 32)           0
# _________________________________________________________________
# dropout (Dropout)            (None, 120, 32)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 120, 16)           1552
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 120, 16)           64
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 120, 16)           0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 120, 16)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 60, 16)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 60, 16)            784
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 60, 16)            64
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 60, 16)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 60, 16)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 60, 8)             392
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 60, 8)             32
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 60, 8)             0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 60, 8)             0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 30, 8)             0
# _________________________________________________________________
# flatten (Flatten)            (None, 240)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                15424
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# regr (Dense)                 (None, 1)                 65
# =================================================================
# Total params: 18,889
# Trainable params: 18,617
# Non-trainable params: 272
# _________________________________________________________________

# %% [markdown]
# #### Обучение:

# %%
regr_history = utils.train_model(univariate_regression_conv1d,
                                 model_save_dir, train_regr_gen, test_regr_gen,
                                 callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                 force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.3913 - mae: 1.0599
# Epoch 00001: val_loss improved from inf to 5.83526, saving model to models\conv1d_univar\regression\01.hdf5
# 32/32 [==============================] - 7s 230ms/step - loss: 6.3769 - mae: 1.0580 - val_loss: 5.8353 - val_mae: 0.6563
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.7777 - mae: 0.9231
# Epoch 00002: val_loss improved from 5.83526 to 5.72011, saving model to models\conv1d_univar\regression\02.hdf5
# 32/32 [==============================] - 6s 173ms/step - loss: 5.7793 - mae: 0.9266 - val_loss: 5.7201 - val_mae: 0.6735
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.5815 - mae: 0.9105
# Epoch 00003: val_loss improved from 5.72011 to 5.59666, saving model to models\conv1d_univar\regression\03.hdf5
# 32/32 [==============================] - 5s 155ms/step - loss: 5.5541 - mae: 0.9040 - val_loss: 5.5967 - val_mae: 0.6933
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.2815 - mae: 0.8665
# Epoch 00004: val_loss improved from 5.59666 to 5.38086, saving model to models\conv1d_univar\regression\04.hdf5
# 32/32 [==============================] - 5s 151ms/step - loss: 5.2883 - mae: 0.8675 - val_loss: 5.3809 - val_mae: 0.6640
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.0879 - mae: 0.8271
# Epoch 00005: val_loss improved from 5.38086 to 5.26659, saving model to models\conv1d_univar\regression\05.hdf5
# 32/32 [==============================] - 5s 158ms/step - loss: 5.1171 - mae: 0.8355 - val_loss: 5.2666 - val_mae: 0.6542
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.0913 - mae: 0.8811
# Epoch 00006: val_loss improved from 5.26659 to 5.18570, saving model to models\conv1d_univar\regression\06.hdf5
# 32/32 [==============================] - 5s 162ms/step - loss: 5.0842 - mae: 0.8783 - val_loss: 5.1857 - val_mae: 0.6552
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.8884 - mae: 0.8344
# Epoch 00007: val_loss improved from 5.18570 to 5.11026, saving model to models\conv1d_univar\regression\07.hdf5
# 32/32 [==============================] - 5s 164ms/step - loss: 4.8936 - mae: 0.8362 - val_loss: 5.1103 - val_mae: 0.6606
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.8017 - mae: 0.8311
# Epoch 00008: val_loss improved from 5.11026 to 5.00604, saving model to models\conv1d_univar\regression\08.hdf5
# 32/32 [==============================] - 5s 162ms/step - loss: 4.7824 - mae: 0.8258 - val_loss: 5.0060 - val_mae: 0.6548
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.7196 - mae: 0.8379
# Epoch 00009: val_loss improved from 5.00604 to 4.90723, saving model to models\conv1d_univar\regression\09.hdf5
# 32/32 [==============================] - 5s 160ms/step - loss: 4.7048 - mae: 0.8360 - val_loss: 4.9072 - val_mae: 0.6541
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.5466 - mae: 0.7937
# Epoch 00010: val_loss improved from 4.90723 to 4.86571, saving model to models\conv1d_univar\regression\10.hdf5
# 32/32 [==============================] - 5s 160ms/step - loss: 4.5486 - mae: 0.7948 - val_loss: 4.8657 - val_mae: 0.6577
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.5646 - mae: 0.8014
# Epoch 00011: val_loss improved from 4.86571 to 4.82792, saving model to models\conv1d_univar\regression\11.hdf5
# 32/32 [==============================] - 5s 161ms/step - loss: 4.5506 - mae: 0.8003 - val_loss: 4.8279 - val_mae: 0.6617
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.5106 - mae: 0.8134
# Epoch 00012: val_loss improved from 4.82792 to 4.77960, saving model to models\conv1d_univar\regression\12.hdf5
# 32/32 [==============================] - 5s 161ms/step - loss: 4.5150 - mae: 0.8147 - val_loss: 4.7796 - val_mae: 0.6603
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.3868 - mae: 0.7816
# Epoch 00013: val_loss improved from 4.77960 to 4.72906, saving model to models\conv1d_univar\regression\13.hdf5
# 32/32 [==============================] - 5s 161ms/step - loss: 4.4074 - mae: 0.7892 - val_loss: 4.7291 - val_mae: 0.6591
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.3962 - mae: 0.8151
# Epoch 00014: val_loss improved from 4.72906 to 4.67482, saving model to models\conv1d_univar\regression\14.hdf5
# 32/32 [==============================] - 5s 156ms/step - loss: 4.4123 - mae: 0.8174 - val_loss: 4.6748 - val_mae: 0.6565
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.3493 - mae: 0.8038
# Epoch 00015: val_loss improved from 4.67482 to 4.65754, saving model to models\conv1d_univar\regression\15.hdf5
# 32/32 [==============================] - 5s 155ms/step - loss: 4.3533 - mae: 0.8051 - val_loss: 4.6575 - val_mae: 0.6597
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.2993 - mae: 0.7988
# Epoch 00016: val_loss improved from 4.65754 to 4.64297, saving model to models\conv1d_univar\regression\16.hdf5
# 32/32 [==============================] - 5s 169ms/step - loss: 4.2874 - mae: 0.7959 - val_loss: 4.6430 - val_mae: 0.6635
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.2571 - mae: 0.7901
# Epoch 00017: val_loss improved from 4.64297 to 4.62730, saving model to models\conv1d_univar\regression\17.hdf5
# 32/32 [==============================] - 5s 167ms/step - loss: 4.2544 - mae: 0.7923 - val_loss: 4.6273 - val_mae: 0.6663
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.2765 - mae: 0.7989
# Epoch 00018: val_loss improved from 4.62730 to 4.60606, saving model to models\conv1d_univar\regression\18.hdf5
# 32/32 [==============================] - 5s 164ms/step - loss: 4.2571 - mae: 0.7948 - val_loss: 4.6061 - val_mae: 0.6675
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.2255 - mae: 0.7910
# Epoch 00019: val_loss improved from 4.60606 to 4.57629, saving model to models\conv1d_univar\regression\19.hdf5
# 32/32 [==============================] - 5s 163ms/step - loss: 4.2279 - mae: 0.7941 - val_loss: 4.5763 - val_mae: 0.6661
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.2098 - mae: 0.8062
# Epoch 00020: val_loss improved from 4.57629 to 4.56782, saving model to models\conv1d_univar\regression\20.hdf5
# 32/32 [==============================] - 5s 158ms/step - loss: 4.1995 - mae: 0.8022 - val_loss: 4.5678 - val_mae: 0.6676
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.1726 - mae: 0.7824
# Epoch 00021: val_loss improved from 4.56782 to 4.55514, saving model to models\conv1d_univar\regression\21.hdf5
# 32/32 [==============================] - 5s 160ms/step - loss: 4.1643 - mae: 0.7820 - val_loss: 4.5551 - val_mae: 0.6674
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.2143 - mae: 0.7971
# Epoch 00022: val_loss improved from 4.55514 to 4.54310, saving model to models\conv1d_univar\regression\22.hdf5
# 32/32 [==============================] - 5s 161ms/step - loss: 4.1971 - mae: 0.7924 - val_loss: 4.5431 - val_mae: 0.6678
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.2240 - mae: 0.8107
# Epoch 00023: val_loss improved from 4.54310 to 4.52715, saving model to models\conv1d_univar\regression\23.hdf5
# 32/32 [==============================] - 6s 173ms/step - loss: 4.2126 - mae: 0.8085 - val_loss: 4.5272 - val_mae: 0.6669
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.1598 - mae: 0.7747
# Epoch 00024: val_loss improved from 4.52715 to 4.51443, saving model to models\conv1d_univar\regression\24.hdf5
# 32/32 [==============================] - 5s 168ms/step - loss: 4.1472 - mae: 0.7728 - val_loss: 4.5144 - val_mae: 0.6674
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.1766 - mae: 0.8061
# Epoch 00025: val_loss improved from 4.51443 to 4.50731, saving model to models\conv1d_univar\regression\25.hdf5
# 32/32 [==============================] - 6s 186ms/step - loss: 4.1669 - mae: 0.8021 - val_loss: 4.5073 - val_mae: 0.6672
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.0951 - mae: 0.7751
# Epoch 00026: val_loss improved from 4.50731 to 4.50311, saving model to models\conv1d_univar\regression\26.hdf5
# 32/32 [==============================] - 5s 155ms/step - loss: 4.1151 - mae: 0.7803 - val_loss: 4.5031 - val_mae: 0.6681
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.0973 - mae: 0.7769
# Epoch 00027: val_loss improved from 4.50311 to 4.49786, saving model to models\conv1d_univar\regression\27.hdf5
# 32/32 [==============================] - 6s 178ms/step - loss: 4.0770 - mae: 0.7713 - val_loss: 4.4979 - val_mae: 0.6684
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.1106 - mae: 0.7887
# Epoch 00028: val_loss improved from 4.49786 to 4.48967, saving model to models\conv1d_univar\regression\28.hdf5
# 32/32 [==============================] - 5s 151ms/step - loss: 4.1251 - mae: 0.7908 - val_loss: 4.4897 - val_mae: 0.6680
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.1375 - mae: 0.7898
# Epoch 00029: val_loss improved from 4.48967 to 4.48258, saving model to models\conv1d_univar\regression\29.hdf5
# 32/32 [==============================] - 6s 173ms/step - loss: 4.1233 - mae: 0.7880 - val_loss: 4.4826 - val_mae: 0.6676
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.1731 - mae: 0.8053
# Epoch 00030: val_loss improved from 4.48258 to 4.47979, saving model to models\conv1d_univar\regression\30.hdf5
# 32/32 [==============================] - 5s 157ms/step - loss: 4.1755 - mae: 0.8065 - val_loss: 4.4798 - val_mae: 0.6676
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.1404 - mae: 0.8075
# Epoch 00031: val_loss improved from 4.47979 to 4.47867, saving model to models\conv1d_univar\regression\31.hdf5
# 32/32 [==============================] - 5s 162ms/step - loss: 4.1539 - mae: 0.8111 - val_loss: 4.4787 - val_mae: 0.6683
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.0864 - mae: 0.7837
# Epoch 00032: val_loss improved from 4.47867 to 4.47517, saving model to models\conv1d_univar\regression\32.hdf5
# 32/32 [==============================] - 5s 153ms/step - loss: 4.1135 - mae: 0.7919 - val_loss: 4.4752 - val_mae: 0.6680

# %%
def plot_regr_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'MSE', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'MAE', 'mae', 'val_mae')
    
plot_regr_history(regr_history);

# %% [markdown]
# ### Прогноз задачи регрессии

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_regression_conv1d.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret_test = univariate_regression_conv1d.predict_generator(test_regr_gen, verbose=1)
# Out:
# 13/13 [==============================] - 0s 27ms/step

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret_test, figsize=(16, 10),
                                  datetime_unit='m', plot_data_slice=slice(1, None))

# %% [markdown]
# ## Задача классификации
#
# Прогнозируем направление изменения цены по сравнению с предыдущим периодом (**0** - снижение, **1** - рост).

# %%
model_class_name = 'classification'

# %%
train_clf_gen = ClassificationGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_clf_gen = ClassificationGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_clf_gen = ClassificationGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_classification_model(input_shape):
    inp, conv1d = build_conv1d_layers(input_shape, filters=(32, 16, 8))

    clf = Dense(64)(conv1d)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.25)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)

    return Model(inputs=[inp], outputs=[clf])

# %%
univariate_classification_conv1d = build_classification_model(test_clf_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
univariate_classification_conv1d.compile(optimizer=optimizer,
                                         loss={'clf': 'binary_crossentropy'},
                                         metrics={'clf': 'accuracy'})

univariate_classification_conv1d.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 120, 1)]          0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 120, 32)           128
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 120, 32)           128
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 120, 32)           0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 120, 32)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 120, 16)           1552
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 120, 16)           64
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 120, 16)           0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 120, 16)           0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 60, 16)            0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 60, 16)            784
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 60, 16)            64
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 60, 16)            0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 60, 16)            0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 60, 8)             392
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 60, 8)             32
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 60, 8)             0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 60, 8)             0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 30, 8)             0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 240)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                15424
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 64)                0
# _________________________________________________________________
# clf (Dense)                  (None, 1)                 65
# =================================================================
# Total params: 18,889
# Trainable params: 18,617
# Non-trainable params: 272
# _________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
clf_history = utils.train_model(univariate_classification_conv1d,
                                model_save_dir, train_clf_gen, test_clf_gen,
                                callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.2257 - accuracy: 0.5101
# Epoch 00001: val_loss improved from inf to 4.84269, saving model to models\conv1d_univar\classification\01.hdf5
# 32/32 [==============================] - 6s 190ms/step - loss: 5.2118 - accuracy: 0.5138 - val_loss: 4.8427 - val_accuracy: 0.4534
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.7122 - accuracy: 0.4899
# Epoch 00002: val_loss improved from 4.84269 to 4.37072, saving model to models\conv1d_univar\classification\02.hdf5
# 32/32 [==============================] - 6s 202ms/step - loss: 4.7067 - accuracy: 0.4921 - val_loss: 4.3707 - val_accuracy: 0.4456
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.1958 - accuracy: 0.5433
# Epoch 00003: val_loss improved from 4.37072 to 3.91937, saving model to models\conv1d_univar\classification\03.hdf5
# 32/32 [==============================] - 6s 191ms/step - loss: 4.1878 - accuracy: 0.5453 - val_loss: 3.9194 - val_accuracy: 0.4482
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.7452 - accuracy: 0.5242
# Epoch 00004: val_loss improved from 3.91937 to 3.49440, saving model to models\conv1d_univar\classification\04.hdf5
# 32/32 [==============================] - 5s 159ms/step - loss: 3.7372 - accuracy: 0.5256 - val_loss: 3.4944 - val_accuracy: 0.4508
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.4355 - accuracy: 0.5444
# Epoch 00005: val_loss improved from 3.49440 to 3.29718, saving model to models\conv1d_univar\classification\05.hdf5
# 32/32 [==============================] - 5s 171ms/step - loss: 3.4343 - accuracy: 0.5404 - val_loss: 3.2972 - val_accuracy: 0.4611
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.2288 - accuracy: 0.5433
# Epoch 00006: val_loss improved from 3.29718 to 3.10938, saving model to models\conv1d_univar\classification\06.hdf5
# 32/32 [==============================] - 5s 150ms/step - loss: 3.2289 - accuracy: 0.5423 - val_loss: 3.1094 - val_accuracy: 0.4585
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.0443 - accuracy: 0.5343
# Epoch 00007: val_loss improved from 3.10938 to 2.93268, saving model to models\conv1d_univar\classification\07.hdf5
# 32/32 [==============================] - 5s 162ms/step - loss: 3.0452 - accuracy: 0.5305 - val_loss: 2.9327 - val_accuracy: 0.4585
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.8451 - accuracy: 0.5575
# Epoch 00008: val_loss improved from 2.93268 to 2.76546, saving model to models\conv1d_univar\classification\08.hdf5
# 32/32 [==============================] - 6s 178ms/step - loss: 2.8377 - accuracy: 0.5620 - val_loss: 2.7655 - val_accuracy: 0.4508
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.6971 - accuracy: 0.5302
# Epoch 00009: val_loss improved from 2.76546 to 2.60978, saving model to models\conv1d_univar\classification\09.hdf5
# 32/32 [==============================] - 5s 147ms/step - loss: 2.6912 - accuracy: 0.5315 - val_loss: 2.6098 - val_accuracy: 0.4482
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.5898 - accuracy: 0.5444
# Epoch 00010: val_loss improved from 2.60978 to 2.52941, saving model to models\conv1d_univar\classification\10.hdf5
# 32/32 [==============================] - 5s 146ms/step - loss: 2.5831 - accuracy: 0.5492 - val_loss: 2.5294 - val_accuracy: 0.4534
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.5106 - accuracy: 0.5474
# Epoch 00011: val_loss improved from 2.52941 to 2.45569, saving model to models\conv1d_univar\classification\11.hdf5
# 32/32 [==============================] - 5s 153ms/step - loss: 2.5134 - accuracy: 0.5492 - val_loss: 2.4557 - val_accuracy: 0.4611
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.4298 - accuracy: 0.5484
# Epoch 00012: val_loss improved from 2.45569 to 2.38526, saving model to models\conv1d_univar\classification\12.hdf5
# 32/32 [==============================] - 5s 146ms/step - loss: 2.4269 - accuracy: 0.5482 - val_loss: 2.3853 - val_accuracy: 0.4534
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.3508 - accuracy: 0.5524
# Epoch 00013: val_loss improved from 2.38526 to 2.31917, saving model to models\conv1d_univar\classification\13.hdf5
# 32/32 [==============================] - 5s 161ms/step - loss: 2.3497 - accuracy: 0.5502 - val_loss: 2.3192 - val_accuracy: 0.4482
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2884 - accuracy: 0.5524
# Epoch 00014: val_loss improved from 2.31917 to 2.25463, saving model to models\conv1d_univar\classification\14.hdf5
# 32/32 [==============================] - 6s 175ms/step - loss: 2.2872 - accuracy: 0.5502 - val_loss: 2.2546 - val_accuracy: 0.4482
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2288 - accuracy: 0.5484
# Epoch 00015: val_loss improved from 2.25463 to 2.22062, saving model to models\conv1d_univar\classification\15.hdf5
# 32/32 [==============================] - 6s 178ms/step - loss: 2.2264 - accuracy: 0.5482 - val_loss: 2.2206 - val_accuracy: 0.4482
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1871 - accuracy: 0.5494
# Epoch 00016: val_loss improved from 2.22062 to 2.19079, saving model to models\conv1d_univar\classification\16.hdf5
# 32/32 [==============================] - 6s 179ms/step - loss: 2.1866 - accuracy: 0.5492 - val_loss: 2.1908 - val_accuracy: 0.4456
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1518 - accuracy: 0.5484
# Epoch 00017: val_loss improved from 2.19079 to 2.16095, saving model to models\conv1d_univar\classification\17.hdf5
# 32/32 [==============================] - 5s 171ms/step - loss: 2.1525 - accuracy: 0.5472 - val_loss: 2.1610 - val_accuracy: 0.4378
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1300 - accuracy: 0.5524
# Epoch 00018: val_loss improved from 2.16095 to 2.13354, saving model to models\conv1d_univar\classification\18.hdf5
# 32/32 [==============================] - 5s 162ms/step - loss: 2.1325 - accuracy: 0.5502 - val_loss: 2.1335 - val_accuracy: 0.4378
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1092 - accuracy: 0.5565
# Epoch 00019: val_loss improved from 2.13354 to 2.10481, saving model to models\conv1d_univar\classification\19.hdf5
# 32/32 [==============================] - 5s 156ms/step - loss: 2.1082 - accuracy: 0.5541 - val_loss: 2.1048 - val_accuracy: 0.4508
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0573 - accuracy: 0.5685
# Epoch 00020: val_loss improved from 2.10481 to 2.09180, saving model to models\conv1d_univar\classification\20.hdf5
# 32/32 [==============================] - 7s 209ms/step - loss: 2.0569 - accuracy: 0.5659 - val_loss: 2.0918 - val_accuracy: 0.4534
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0705 - accuracy: 0.5343
# Epoch 00021: val_loss improved from 2.09180 to 2.07803, saving model to models\conv1d_univar\classification\21.hdf5
# 32/32 [==============================] - 6s 200ms/step - loss: 2.0720 - accuracy: 0.5305 - val_loss: 2.0780 - val_accuracy: 0.4560
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0400 - accuracy: 0.5454
# Epoch 00022: val_loss improved from 2.07803 to 2.06565, saving model to models\conv1d_univar\classification\22.hdf5
# 32/32 [==============================] - 7s 212ms/step - loss: 2.0446 - accuracy: 0.5394 - val_loss: 2.0657 - val_accuracy: 0.4508
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0346 - accuracy: 0.5615
# Epoch 00023: val_loss improved from 2.06565 to 2.05162, saving model to models\conv1d_univar\classification\23.hdf5
# 32/32 [==============================] - 6s 180ms/step - loss: 2.0383 - accuracy: 0.5591 - val_loss: 2.0516 - val_accuracy: 0.4534
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0008 - accuracy: 0.5917
# Epoch 00024: val_loss improved from 2.05162 to 2.03821, saving model to models\conv1d_univar\classification\24.hdf5
# 32/32 [==============================] - 5s 149ms/step - loss: 2.0016 - accuracy: 0.5906 - val_loss: 2.0382 - val_accuracy: 0.4611
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0174 - accuracy: 0.5333
# Epoch 00025: val_loss improved from 2.03821 to 2.03232, saving model to models\conv1d_univar\classification\25.hdf5
# 32/32 [==============================] - 5s 168ms/step - loss: 2.0206 - accuracy: 0.5276 - val_loss: 2.0323 - val_accuracy: 0.4534
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9859 - accuracy: 0.5575
# Epoch 00026: val_loss improved from 2.03232 to 2.02536, saving model to models\conv1d_univar\classification\26.hdf5
# 32/32 [==============================] - 5s 153ms/step - loss: 1.9888 - accuracy: 0.5561 - val_loss: 2.0254 - val_accuracy: 0.4508
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9953 - accuracy: 0.5302
# Epoch 00027: val_loss improved from 2.02536 to 2.01840, saving model to models\conv1d_univar\classification\27.hdf5
# 32/32 [==============================] - 5s 161ms/step - loss: 1.9964 - accuracy: 0.5295 - val_loss: 2.0184 - val_accuracy: 0.4508
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9645 - accuracy: 0.5796
# Epoch 00028: val_loss improved from 2.01840 to 2.01212, saving model to models\conv1d_univar\classification\28.hdf5
# 32/32 [==============================] - 5s 171ms/step - loss: 1.9656 - accuracy: 0.5778 - val_loss: 2.0121 - val_accuracy: 0.4534
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9608 - accuracy: 0.5696
# Epoch 00029: val_loss improved from 2.01212 to 2.00623, saving model to models\conv1d_univar\classification\29.hdf5
# 32/32 [==============================] - 5s 151ms/step - loss: 1.9591 - accuracy: 0.5699 - val_loss: 2.0062 - val_accuracy: 0.4560
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9637 - accuracy: 0.5696
# Epoch 00030: val_loss improved from 2.00623 to 2.00345, saving model to models\conv1d_univar\classification\30.hdf5
# 32/32 [==============================] - 5s 151ms/step - loss: 1.9629 - accuracy: 0.5679 - val_loss: 2.0035 - val_accuracy: 0.4508
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9546 - accuracy: 0.5716
# Epoch 00031: val_loss improved from 2.00345 to 2.00036, saving model to models\conv1d_univar\classification\31.hdf5
# 32/32 [==============================] - 5s 161ms/step - loss: 1.9525 - accuracy: 0.5728 - val_loss: 2.0004 - val_accuracy: 0.4534
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9672 - accuracy: 0.5494
# Epoch 00032: val_loss improved from 2.00036 to 1.99705, saving model to models\conv1d_univar\classification\32.hdf5
# 32/32 [==============================] - 6s 173ms/step - loss: 1.9690 - accuracy: 0.5453 - val_loss: 1.9971 - val_accuracy: 0.4611

# %%
def plot_clf_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'Loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'Accuracy', 'accuracy', 'val_accuracy')
    
plot_clf_history(clf_history);

# %% [markdown]
# ### Прогноз задачи классификации

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_classification_conv1d.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %%
pred_direction_proba = univariate_classification_conv1d.predict_generator(test_clf_gen, verbose=1)

true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 13/13 [==============================] - 0s 22ms/step
# 0.47765154

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([168, 218], dtype=int64)),
#  (array([0, 1]), array([206, 180], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.43      0.52      0.47       168
#            1       0.56      0.46      0.50       218
#
#     accuracy                           0.49       386
#    macro avg       0.49      0.49      0.49       386
# weighted avg       0.50      0.49      0.49       386

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[ 88,  80],
#        [118, 100]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.42718447, 0.44444444],
#        [0.57281553, 0.55555556]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# ## Многозадачная модель: одновременно регрессия и классификация

# %%
model_class_name = 'multitask'

# %%
train_multi_gen = MultitaskGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_multi_gen = MultitaskGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_multi_gen = MultitaskGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_multitask_model(input_shape):
    inp, conv1d = build_conv1d_layers(input_shape, filters=(32, 16, 8))

    # первый выход: задача регрссии
    regr = Dense(64)(conv1d)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.25)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    # второй выход: задача классификации
    clf = Dense(64)(conv1d)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.25)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)
    
    return Model(inputs=[inp], outputs=[regr, clf])

# %%
univariate_multitask_conv1d = build_multitask_model(train_multi_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
univariate_multitask_conv1d.compile(optimizer=optimizer,
                                    loss={'regr': 'mse', 'clf': 'binary_crossentropy'},
                                    loss_weights={'regr': 1., 'clf': 1.},
                                    metrics={'regr': 'mae', 'clf' : 'accuracy'})

univariate_multitask_conv1d.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 120, 1)]     0
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 120, 32)      128         input[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 120, 32)      128         conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 120, 32)      0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 120, 32)      0           leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 120, 16)      1552        dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 120, 16)      64          conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 120, 16)      0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 120, 16)      0           leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 60, 16)       0           dropout_11[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 60, 16)       784         max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 60, 16)       64          conv1d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 60, 16)       0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 60, 16)       0           leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 60, 8)        392         dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 60, 8)        32          conv1d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 60, 8)        0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 60, 8)        0           leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 30, 8)        0           dropout_13[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 240)          0           max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           15424       flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           15424       flatten_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64)           256         dense_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64)           256         dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 64)           0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 64)           0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 64)           0           leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 64)           0           leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# regr (Dense)                    (None, 1)            65          dropout_14[0][0]
# __________________________________________________________________________________________________
# clf (Dense)                     (None, 1)            65          dropout_15[0][0]
# ==================================================================================================
# Total params: 34,634
# Trainable params: 34,234
# Non-trainable params: 400
# __________________________________________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
multitask_history = utils.train_model(univariate_multitask_conv1d,
                                      model_save_dir, train_multi_gen, test_multi_gen,
                                      callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                      force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.6081 - regr_loss: 2.3164 - clf_loss: 0.7937 - regr_mae: 1.1979 - clf_accuracy: 0.4869
# Epoch 00001: val_loss improved from inf to 6.79344, saving model to models\conv1d_univar\multitask\01.hdf5
# 32/32 [==============================] - 6s 198ms/step - loss: 7.5724 - regr_loss: 2.2816 - clf_loss: 0.7946 - regr_mae: 1.1900 - clf_accuracy: 0.4862 - val_loss: 6.7934 - val_regr_loss: 1.6799 - val_clf_loss: 0.6855 - val_regr_mae: 0.7984 - val_clf_accuracy: 0.5570
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.8318 - regr_loss: 1.6961 - clf_loss: 0.7767 - regr_mae: 0.9944 - clf_accuracy: 0.4849
# Epoch 00002: val_loss improved from 6.79344 to 6.45357, saving model to models\conv1d_univar\multitask\02.hdf5
# 32/32 [==============================] - 6s 186ms/step - loss: 6.8235 - regr_loss: 1.6868 - clf_loss: 0.7800 - regr_mae: 0.9935 - clf_accuracy: 0.4813 - val_loss: 6.4536 - val_regr_loss: 1.4870 - val_clf_loss: 0.6869 - val_regr_mae: 0.6834 - val_clf_accuracy: 0.5699
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.4134 - regr_loss: 1.4536 - clf_loss: 0.7505 - regr_mae: 0.9123 - clf_accuracy: 0.5000
# Epoch 00003: val_loss improved from 6.45357 to 6.23100, saving model to models\conv1d_univar\multitask\03.hdf5
# 32/32 [==============================] - 6s 189ms/step - loss: 6.4197 - regr_loss: 1.4598 - clf_loss: 0.7532 - regr_mae: 0.9152 - clf_accuracy: 0.4990 - val_loss: 6.2310 - val_regr_loss: 1.4122 - val_clf_loss: 0.6914 - val_regr_mae: 0.6278 - val_clf_accuracy: 0.5078
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.2398 - regr_loss: 1.4555 - clf_loss: 0.7295 - regr_mae: 0.9187 - clf_accuracy: 0.5282
# Epoch 00004: val_loss improved from 6.23100 to 6.09490, saving model to models\conv1d_univar\multitask\04.hdf5
# 32/32 [==============================] - 6s 192ms/step - loss: 6.2310 - regr_loss: 1.4483 - clf_loss: 0.7302 - regr_mae: 0.9166 - clf_accuracy: 0.5256 - val_loss: 6.0949 - val_regr_loss: 1.4202 - val_clf_loss: 0.7019 - val_regr_mae: 0.6318 - val_clf_accuracy: 0.4715
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.0000 - regr_loss: 1.3341 - clf_loss: 0.7301 - regr_mae: 0.8751 - clf_accuracy: 0.5192
# Epoch 00005: val_loss improved from 6.09490 to 6.02371, saving model to models\conv1d_univar\multitask\05.hdf5
# 32/32 [==============================] - 7s 218ms/step - loss: 5.9965 - regr_loss: 1.3294 - clf_loss: 0.7324 - regr_mae: 0.8741 - clf_accuracy: 0.5187 - val_loss: 6.0237 - val_regr_loss: 1.4278 - val_clf_loss: 0.7019 - val_regr_mae: 0.6326 - val_clf_accuracy: 0.4560
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.8919 - regr_loss: 1.3216 - clf_loss: 0.7130 - regr_mae: 0.8779 - clf_accuracy: 0.5585
# Epoch 00006: val_loss improved from 6.02371 to 5.95679, saving model to models\conv1d_univar\multitask\06.hdf5
# 32/32 [==============================] - 7s 211ms/step - loss: 5.8723 - regr_loss: 1.3058 - clf_loss: 0.7104 - regr_mae: 0.8753 - clf_accuracy: 0.5630 - val_loss: 5.9568 - val_regr_loss: 1.4432 - val_clf_loss: 0.6981 - val_regr_mae: 0.6396 - val_clf_accuracy: 0.4845
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.8560 - regr_loss: 1.3263 - clf_loss: 0.7525 - regr_mae: 0.8662 - clf_accuracy: 0.4899
# Epoch 00007: val_loss improved from 5.95679 to 5.89417, saving model to models\conv1d_univar\multitask\07.hdf5
# 32/32 [==============================] - 6s 195ms/step - loss: 5.8438 - regr_loss: 1.3141 - clf_loss: 0.7536 - regr_mae: 0.8643 - clf_accuracy: 0.4872 - val_loss: 5.8942 - val_regr_loss: 1.4547 - val_clf_loss: 0.7053 - val_regr_mae: 0.6416 - val_clf_accuracy: 0.4534
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.7026 - regr_loss: 1.2888 - clf_loss: 0.7176 - regr_mae: 0.8522 - clf_accuracy: 0.5514
# Epoch 00008: val_loss improved from 5.89417 to 5.83161, saving model to models\conv1d_univar\multitask\08.hdf5
# 32/32 [==============================] - 6s 185ms/step - loss: 5.6942 - regr_loss: 1.2814 - clf_loss: 0.7177 - regr_mae: 0.8514 - clf_accuracy: 0.5502 - val_loss: 5.8316 - val_regr_loss: 1.4711 - val_clf_loss: 0.7074 - val_regr_mae: 0.6478 - val_clf_accuracy: 0.4611
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.6141 - regr_loss: 1.2762 - clf_loss: 0.7233 - regr_mae: 0.8457 - clf_accuracy: 0.5192
# Epoch 00009: val_loss improved from 5.83161 to 5.74403, saving model to models\conv1d_univar\multitask\09.hdf5
# 32/32 [==============================] - 6s 197ms/step - loss: 5.6218 - regr_loss: 1.2884 - clf_loss: 0.7202 - regr_mae: 0.8479 - clf_accuracy: 0.5226 - val_loss: 5.7440 - val_regr_loss: 1.4647 - val_clf_loss: 0.7078 - val_regr_mae: 0.6482 - val_clf_accuracy: 0.4663
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.4899 - regr_loss: 1.2070 - clf_loss: 0.7308 - regr_mae: 0.8243 - clf_accuracy: 0.5192
# Epoch 00010: val_loss improved from 5.74403 to 5.71297, saving model to models\conv1d_univar\multitask\10.hdf5
# 32/32 [==============================] - 6s 201ms/step - loss: 5.4777 - regr_loss: 1.1937 - clf_loss: 0.7324 - regr_mae: 0.8219 - clf_accuracy: 0.5167 - val_loss: 5.7130 - val_regr_loss: 1.4699 - val_clf_loss: 0.7129 - val_regr_mae: 0.6511 - val_clf_accuracy: 0.4611
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.4344 - regr_loss: 1.2038 - clf_loss: 0.7197 - regr_mae: 0.8256 - clf_accuracy: 0.5323
# Epoch 00011: val_loss improved from 5.71297 to 5.67307, saving model to models\conv1d_univar\multitask\11.hdf5
# 32/32 [==============================] - 6s 194ms/step - loss: 5.4713 - regr_loss: 1.2422 - clf_loss: 0.7192 - regr_mae: 0.8339 - clf_accuracy: 0.5344 - val_loss: 5.6731 - val_regr_loss: 1.4705 - val_clf_loss: 0.7136 - val_regr_mae: 0.6543 - val_clf_accuracy: 0.4611
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.4465 - regr_loss: 1.2634 - clf_loss: 0.7136 - regr_mae: 0.8449 - clf_accuracy: 0.5444
# Epoch 00012: val_loss improved from 5.67307 to 5.64044, saving model to models\conv1d_univar\multitask\12.hdf5
# 32/32 [==============================] - 6s 191ms/step - loss: 5.4501 - regr_loss: 1.2648 - clf_loss: 0.7163 - regr_mae: 0.8455 - clf_accuracy: 0.5423 - val_loss: 5.6404 - val_regr_loss: 1.4780 - val_clf_loss: 0.7149 - val_regr_mae: 0.6616 - val_clf_accuracy: 0.4715
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.3886 - regr_loss: 1.2396 - clf_loss: 0.7212 - regr_mae: 0.8469 - clf_accuracy: 0.5323
# Epoch 00013: val_loss improved from 5.64044 to 5.59659, saving model to models\conv1d_univar\multitask\13.hdf5
# 32/32 [==============================] - 6s 194ms/step - loss: 5.3812 - regr_loss: 1.2307 - clf_loss: 0.7232 - regr_mae: 0.8452 - clf_accuracy: 0.5256 - val_loss: 5.5966 - val_regr_loss: 1.4757 - val_clf_loss: 0.7156 - val_regr_mae: 0.6613 - val_clf_accuracy: 0.4663
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.2952 - regr_loss: 1.1966 - clf_loss: 0.7128 - regr_mae: 0.8263 - clf_accuracy: 0.5151
# Epoch 00014: val_loss improved from 5.59659 to 5.55523, saving model to models\conv1d_univar\multitask\14.hdf5
# 32/32 [==============================] - 6s 196ms/step - loss: 5.3036 - regr_loss: 1.2069 - clf_loss: 0.7117 - regr_mae: 0.8306 - clf_accuracy: 0.5157 - val_loss: 5.5552 - val_regr_loss: 1.4782 - val_clf_loss: 0.7135 - val_regr_mae: 0.6640 - val_clf_accuracy: 0.4922
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.1786 - regr_loss: 1.1305 - clf_loss: 0.6947 - regr_mae: 0.8038 - clf_accuracy: 0.5504
# Epoch 00015: val_loss improved from 5.55523 to 5.53679, saving model to models\conv1d_univar\multitask\15.hdf5
# 32/32 [==============================] - 7s 216ms/step - loss: 5.1999 - regr_loss: 1.1528 - clf_loss: 0.6943 - regr_mae: 0.8087 - clf_accuracy: 0.5502 - val_loss: 5.5368 - val_regr_loss: 1.4817 - val_clf_loss: 0.7132 - val_regr_mae: 0.6655 - val_clf_accuracy: 0.4948
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.1274 - regr_loss: 1.0932 - clf_loss: 0.7024 - regr_mae: 0.7944 - clf_accuracy: 0.5333
# Epoch 00016: val_loss improved from 5.53679 to 5.52049, saving model to models\conv1d_univar\multitask\16.hdf5
# 32/32 [==============================] - 6s 195ms/step - loss: 5.1392 - regr_loss: 1.1073 - clf_loss: 0.7005 - regr_mae: 0.7980 - clf_accuracy: 0.5354 - val_loss: 5.5205 - val_regr_loss: 1.4865 - val_clf_loss: 0.7138 - val_regr_mae: 0.6682 - val_clf_accuracy: 0.4948
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.1739 - regr_loss: 1.1595 - clf_loss: 0.7043 - regr_mae: 0.8045 - clf_accuracy: 0.5333
# Epoch 00017: val_loss improved from 5.52049 to 5.51338, saving model to models\conv1d_univar\multitask\17.hdf5
# 32/32 [==============================] - 7s 209ms/step - loss: 5.1589 - regr_loss: 1.1451 - clf_loss: 0.7039 - regr_mae: 0.8032 - clf_accuracy: 0.5305 - val_loss: 5.5134 - val_regr_loss: 1.4992 - val_clf_loss: 0.7156 - val_regr_mae: 0.6722 - val_clf_accuracy: 0.4974
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.1673 - regr_loss: 1.1868 - clf_loss: 0.6920 - regr_mae: 0.8105 - clf_accuracy: 0.5655
# Epoch 00018: val_loss improved from 5.51338 to 5.49780, saving model to models\conv1d_univar\multitask\18.hdf5
# 32/32 [==============================] - 7s 203ms/step - loss: 5.1571 - regr_loss: 1.1753 - clf_loss: 0.6937 - regr_mae: 0.8081 - clf_accuracy: 0.5630 - val_loss: 5.4978 - val_regr_loss: 1.5037 - val_clf_loss: 0.7172 - val_regr_mae: 0.6733 - val_clf_accuracy: 0.4922
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.1488 - regr_loss: 1.1765 - clf_loss: 0.7057 - regr_mae: 0.8166 - clf_accuracy: 0.5433
# Epoch 00019: val_loss improved from 5.49780 to 5.47434, saving model to models\conv1d_univar\multitask\19.hdf5
# 32/32 [==============================] - 6s 190ms/step - loss: 5.1713 - regr_loss: 1.1965 - clf_loss: 0.7087 - regr_mae: 0.8218 - clf_accuracy: 0.5423 - val_loss: 5.4743 - val_regr_loss: 1.5022 - val_clf_loss: 0.7171 - val_regr_mae: 0.6736 - val_clf_accuracy: 0.4922
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.1689 - regr_loss: 1.1963 - clf_loss: 0.7228 - regr_mae: 0.8260 - clf_accuracy: 0.5071
# Epoch 00020: val_loss improved from 5.47434 to 5.46264, saving model to models\conv1d_univar\multitask\20.hdf5
# 32/32 [==============================] - 6s 192ms/step - loss: 5.1532 - regr_loss: 1.1823 - clf_loss: 0.7212 - regr_mae: 0.8226 - clf_accuracy: 0.5089 - val_loss: 5.4626 - val_regr_loss: 1.5010 - val_clf_loss: 0.7178 - val_regr_mae: 0.6742 - val_clf_accuracy: 0.4948
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.1165 - regr_loss: 1.1654 - clf_loss: 0.7124 - regr_mae: 0.8037 - clf_accuracy: 0.5333
# Epoch 00021: val_loss improved from 5.46264 to 5.45313, saving model to models\conv1d_univar\multitask\21.hdf5
# 32/32 [==============================] - 7s 227ms/step - loss: 5.1194 - regr_loss: 1.1659 - clf_loss: 0.7151 - regr_mae: 0.8038 - clf_accuracy: 0.5285 - val_loss: 5.4531 - val_regr_loss: 1.5028 - val_clf_loss: 0.7177 - val_regr_mae: 0.6753 - val_clf_accuracy: 0.5000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.1554 - regr_loss: 1.2216 - clf_loss: 0.7063 - regr_mae: 0.8243 - clf_accuracy: 0.5403
# Epoch 00022: val_loss improved from 5.45313 to 5.43534, saving model to models\conv1d_univar\multitask\22.hdf5
# 32/32 [==============================] - 6s 194ms/step - loss: 5.1433 - regr_loss: 1.2090 - clf_loss: 0.7069 - regr_mae: 0.8210 - clf_accuracy: 0.5374 - val_loss: 5.4353 - val_regr_loss: 1.4970 - val_clf_loss: 0.7168 - val_regr_mae: 0.6733 - val_clf_accuracy: 0.4948
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.0640 - regr_loss: 1.1677 - clf_loss: 0.6799 - regr_mae: 0.8163 - clf_accuracy: 0.5736
# Epoch 00023: val_loss improved from 5.43534 to 5.42562, saving model to models\conv1d_univar\multitask\23.hdf5
# 32/32 [==============================] - 6s 185ms/step - loss: 5.0522 - regr_loss: 1.1516 - clf_loss: 0.6844 - regr_mae: 0.8132 - clf_accuracy: 0.5699 - val_loss: 5.4256 - val_regr_loss: 1.4978 - val_clf_loss: 0.7175 - val_regr_mae: 0.6743 - val_clf_accuracy: 0.4948
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.0816 - regr_loss: 1.1788 - clf_loss: 0.6977 - regr_mae: 0.8174 - clf_accuracy: 0.5585
# Epoch 00024: val_loss improved from 5.42562 to 5.41452, saving model to models\conv1d_univar\multitask\24.hdf5
# 32/32 [==============================] - 6s 183ms/step - loss: 5.1083 - regr_loss: 1.2059 - clf_loss: 0.6976 - regr_mae: 0.8202 - clf_accuracy: 0.5571 - val_loss: 5.4145 - val_regr_loss: 1.4976 - val_clf_loss: 0.7179 - val_regr_mae: 0.6743 - val_clf_accuracy: 0.4922
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.0927 - regr_loss: 1.1875 - clf_loss: 0.7087 - regr_mae: 0.8235 - clf_accuracy: 0.5444
# Epoch 00025: val_loss improved from 5.41452 to 5.40997, saving model to models\conv1d_univar\multitask\25.hdf5
# 32/32 [==============================] - 7s 231ms/step - loss: 5.0787 - regr_loss: 1.1737 - clf_loss: 0.7084 - regr_mae: 0.8211 - clf_accuracy: 0.5443 - val_loss: 5.4100 - val_regr_loss: 1.4988 - val_clf_loss: 0.7177 - val_regr_mae: 0.6751 - val_clf_accuracy: 0.4948
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.9719 - regr_loss: 1.0786 - clf_loss: 0.7026 - regr_mae: 0.7804 - clf_accuracy: 0.5474
# Epoch 00026: val_loss improved from 5.40997 to 5.40734, saving model to models\conv1d_univar\multitask\26.hdf5
# 32/32 [==============================] - 7s 214ms/step - loss: 4.9934 - regr_loss: 1.0961 - clf_loss: 0.7068 - regr_mae: 0.7859 - clf_accuracy: 0.5443 - val_loss: 5.4073 - val_regr_loss: 1.5013 - val_clf_loss: 0.7183 - val_regr_mae: 0.6755 - val_clf_accuracy: 0.4922
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.0434 - regr_loss: 1.1510 - clf_loss: 0.7073 - regr_mae: 0.7978 - clf_accuracy: 0.5323
# Epoch 00027: val_loss improved from 5.40734 to 5.40155, saving model to models\conv1d_univar\multitask\27.hdf5
# 32/32 [==============================] - 6s 194ms/step - loss: 5.0444 - regr_loss: 1.1514 - clf_loss: 0.7080 - regr_mae: 0.7995 - clf_accuracy: 0.5315 - val_loss: 5.4016 - val_regr_loss: 1.5005 - val_clf_loss: 0.7191 - val_regr_mae: 0.6755 - val_clf_accuracy: 0.4974
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.0964 - regr_loss: 1.2064 - clf_loss: 0.7108 - regr_mae: 0.8206 - clf_accuracy: 0.5312
# Epoch 00028: val_loss improved from 5.40155 to 5.39600, saving model to models\conv1d_univar\multitask\28.hdf5
# 32/32 [==============================] - 6s 190ms/step - loss: 5.0821 - regr_loss: 1.1921 - clf_loss: 0.7107 - regr_mae: 0.8163 - clf_accuracy: 0.5325 - val_loss: 5.3960 - val_regr_loss: 1.4997 - val_clf_loss: 0.7201 - val_regr_mae: 0.6757 - val_clf_accuracy: 0.4974
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.0565 - regr_loss: 1.1830 - clf_loss: 0.7000 - regr_mae: 0.8098 - clf_accuracy: 0.5514
# Epoch 00029: val_loss improved from 5.39600 to 5.39130, saving model to models\conv1d_univar\multitask\29.hdf5
# 32/32 [==============================] - 6s 190ms/step - loss: 5.0290 - regr_loss: 1.1544 - clf_loss: 0.7010 - regr_mae: 0.8003 - clf_accuracy: 0.5502 - val_loss: 5.3913 - val_regr_loss: 1.4998 - val_clf_loss: 0.7210 - val_regr_mae: 0.6755 - val_clf_accuracy: 0.5000
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.0204 - regr_loss: 1.1469 - clf_loss: 0.7044 - regr_mae: 0.8057 - clf_accuracy: 0.5494
# Epoch 00030: val_loss improved from 5.39130 to 5.38841, saving model to models\conv1d_univar\multitask\30.hdf5
# 32/32 [==============================] - 6s 187ms/step - loss: 5.0392 - regr_loss: 1.1672 - clf_loss: 0.7030 - regr_mae: 0.8115 - clf_accuracy: 0.5502 - val_loss: 5.3884 - val_regr_loss: 1.4997 - val_clf_loss: 0.7212 - val_regr_mae: 0.6756 - val_clf_accuracy: 0.4974
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.0150 - regr_loss: 1.1559 - clf_loss: 0.6928 - regr_mae: 0.7997 - clf_accuracy: 0.5494
# Epoch 00031: val_loss improved from 5.38841 to 5.38764, saving model to models\conv1d_univar\multitask\31.hdf5
# 32/32 [==============================] - 6s 183ms/step - loss: 5.0079 - regr_loss: 1.1481 - clf_loss: 0.6936 - regr_mae: 0.7989 - clf_accuracy: 0.5502 - val_loss: 5.3876 - val_regr_loss: 1.5013 - val_clf_loss: 0.7217 - val_regr_mae: 0.6762 - val_clf_accuracy: 0.4948
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.0827 - regr_loss: 1.2170 - clf_loss: 0.7025 - regr_mae: 0.8260 - clf_accuracy: 0.5212 ETA: 3s - loss: 5.2787 - regr_loss: 1.4064 - clf_loss: 0.7081
# Epoch 00032: val_loss improved from 5.38764 to 5.38439, saving model to models\conv1d_univar\multitask\32.hdf5
# 32/32 [==============================] - 7s 203ms/step - loss: 5.0741 - regr_loss: 1.2089 - clf_loss: 0.7019 - regr_mae: 0.8249 - clf_accuracy: 0.5207 - val_loss: 5.3844 - val_regr_loss: 1.5012 - val_clf_loss: 0.7215 - val_regr_mae: 0.6758 - val_clf_accuracy: 0.4922

# %%
def plot_multitask_history(hist):
    fig, ax = plt.subplots(2, 2, figsize=(16, 12))
    plotHelpers.plot_train_history(ax[0, 0], hist, 'Total loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[0, 1], hist, 'Accuracy', 'clf_accuracy', 'val_clf_accuracy')
    plotHelpers.plot_train_history(ax[1, 0], hist, 'MSE', 'regr_loss', 'val_regr_loss')
    plotHelpers.plot_train_history(ax[1, 1], hist, 'MAE', 'regr_mae', 'val_regr_mae')
    
plot_multitask_history(multitask_history);

# %% [markdown]
# ### Прогноз

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_multitask_conv1d.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret, pred_direction_proba = univariate_multitask_conv1d.predict_generator(test_multi_gen, verbose=1)
# Out:
# 13/13 [==============================] - 0s 27ms/step

# %%
np.set_printoptions(precision=3, suppress=True)

np.column_stack([pred_log_ret, pred_direction_proba])[-10:]
# Out:
# array([[ 0.002,  0.475],
#        [ 0.154,  0.499],
#        [ 0.143,  0.526],
#        [ 0.211,  0.562],
#        [ 0.141,  0.543],
#        [-0.013,  0.491],
#        [-0.129,  0.489],
#        [-0.066,  0.486],
#        [-0.219,  0.448],
#        [-0.037,  0.451]], dtype=float32)

# %% [markdown]
# #### Прогноз задачи регрессии

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret, figsize=(16, 10),
                                  datetime_unit='m', plot_data_slice=slice(1, None))

# %% [markdown]
# #### Прогноз задачи классификации

# %%
true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 0.4601983

# %%
true_direction = test_multi_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([168, 218], dtype=int64)),
#  (array([0, 1]), array([200, 186], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.46      0.54      0.49       168
#            1       0.59      0.50      0.54       218
#
#     accuracy                           0.52       386
#    macro avg       0.52      0.52      0.52       386
# weighted avg       0.53      0.52      0.52       386

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[ 91,  77],
#        [109, 109]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.455, 0.414],
#        [0.545, 0.586]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# # Выводы
#
# 1.  Модель с 1D свёртками обучается гораздо быстрее модели LSTM
# 2.  Задача классификации не решается удовлетворительно.

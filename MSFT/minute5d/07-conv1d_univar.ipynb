# %% [markdown]
# # *Одномерная модель на 1D свёрточных слоях*
#
# В качестве единственного признака используется сама цена.

# %%
import os
import glob
import datetime
import pickle

import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from pandas_datareader import data as pdr

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
import tensorflow as tf
# tf.test.is_gpu_available()
tf.__version__
# Out:
# '2.0.0'

# %%
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import (Input, Dense, Convolution1D, MaxPooling1D, Flatten,
                                     ReLU, LeakyReLU, Dropout, BatchNormalization)
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers import Nadam

# %%
from mdp import TimeSeries
from mdp import MarketData
from mdp import MovingWindowFeatures
from mdp import ClassificationGenerator, RegressionGenerator, MultitaskGenerator
from mdp import invert_log_ret

import mdp.utils as utils
import mdp.plotHelpers as plotHelpers

# %%
import importlib

import mdp

importlib.reload(mdp)
importlib.reload(mdp.datasetGenerator)
importlib.reload(mdp.marketData)
importlib.reload(mdp.movingWindowFeatures)
importlib.reload(mdp.timeSeries)
importlib.reload(mdp.plotHelpers)
importlib.reload(mdp.utils);

# %% [markdown]
# # *Параметры*

# %%
INSTRUMENT = 'MSFT' # Microsoft corp
START_FROM = np.datetime64('today') - 7
WINDOW_SIZE = 60
FORECAST_OFFSET=1
BATCH_SIZE = 32
FORCE_TRAIN = False

# %% [markdown]
# # *Исходные данные*
#
# Загрузка данных и вычисление индикаторов.

# %%
instr = MarketData.create_from_alphavantage_intraday(INSTRUMENT, start=START_FROM)

# %%
instr.feature_names
# Out:
# ['o',
#  'h',
#  'l',
#  'c',
#  'v',
#  'ema14',
#  'ema30',
#  'macd',
#  'macd_signal',
#  'rsi14',
#  'bband20_upper',
#  'bband20_middle',
#  'bband20_lower',
#  'willr14',
#  'stochk',
#  'stochd',
#  'adline',
#  'adosc']

# %% [markdown]
# Здесь не будем делить отдельно на тест и валидацию, поскольку данных у нас только 5 дней.

# %%
dates_unique = np.unique(instr.timestamps.astype('datetime64[D]'))

START_FROM = dates_unique[0]
VAL_TEST_SPLIT = dates_unique[-1]

START_FROM, VAL_TEST_SPLIT
# Out:
# (numpy.datetime64('2020-03-23'), numpy.datetime64('2020-03-27'))

# %% [markdown]
# ## Целевая переменная

# %% [markdown]
# Цена закрытия.

# %%
orig_target = instr.c

# %% [markdown]
# Переходим к логарифмической доходности.

# %%
transformed_target = instr.c.transform(transforms={'ratios' : {}, 'ln' : {}})

# %%
plotHelpers.plot_transformed_timeseries_unit(instr,
                                             transformed_target,
                                             'Close price, USD', 'Log return',
                                             datetime_unit='m', rotation=45)

# %% [markdown]
# ## Трансформация признаков
#
# Из признаков выбираем только цену закрытия. Временной ряд цен преобразуется к ряду логарифмических доходностей (что также позволяет убрать нестационарность).

# %%
def make_feature_selector():
    price_transformer = lambda: {'ratios': {}, 'ln': {}}
    diff_transformer = lambda o: {'diffs': {'order': o}}
    identity_transformer = lambda: {}
    feature_transformations = {
        'c': price_transformer(),
    }
    return feature_transformations

# %%
instr_transformed = instr.select_transform(make_feature_selector())

# %%
transformed_target = instr_transformed.c

# %% [markdown]
# ## Обучающая, валидационная и тестовая выборки

# %%
instr_train, instr_test = instr_transformed.train_test_split(VAL_TEST_SPLIT, window_size=WINDOW_SIZE,
                                                             scaler=StandardScaler)
#                                                              scaler=MinMaxScaler,
#                                                              scaler_kwargs={'feature_range': (-1, 1)})

# instr_val, instr_test = instr_val_test.train_test_split(TEST_SPLIT, window_size=WINDOW_SIZE, scaler=None)

len(instr_train), len(instr_test)
# Out:
# (1524, 448)

# %% [markdown]
# ## Признаки - скользящие окна

# %%
train_mwf = MovingWindowFeatures.create(instr_train.c, [instr_train], instr_train.feature_names, window_size=WINDOW_SIZE)
# val_mwf = MovingWindowFeatures.create(instr_val.c, [instr_val], instr_val.feature_names, window_size=WINDOW_SIZE)
test_mwf = MovingWindowFeatures.create(instr_test.c, [instr_test], instr_test.feature_names, window_size=WINDOW_SIZE)

len(instr_train), len(train_mwf), train_mwf.features.shape
# Out:
# (1524, 1464, (1464, 60, 1))

# %% [markdown]
# Проверка, что скользящие окна соответствуют исходным данным.
#
# Возьмём произвольный признак и произвольное окно (строка #**41**). Проверим, что данные в точности совпадают:

# %%
def check_data(md, mwf, row):
    col = np.random.randint(len(mwf.feature_names))
    feature = mwf.feature_names[col]
    check = (getattr(md, feature).data[row:row + mwf.window_size] == mwf.features[row, :, col]).all()
    assert check
    return feature, check

check_data(instr_train, train_mwf, 41)
# Out:
# ('c', True)

# %% [markdown]
# # *Модели*

# %% [markdown]
# Модель с двумя 1D свёрточными слоями.

# %%
def build_conv1d_layers(input_shape, filters=(16, 8), kernel_size=5, pool_size=2):
    # формат входа: наша матрица (окно; признак)
    inp = Input(input_shape, name='input')

    # стекаем два уровня Conv1D
    conv1d = Convolution1D(filters=filters[0],
                           kernel_size=kernel_size,
                           padding='same',
                           bias_initializer='he_uniform',
                           bias_regularizer=L1L2(0.01, 0.02),
                           kernel_regularizer=L1L2(0.01, 0.02)
                          )(inp)
    conv1d = BatchNormalization()(conv1d)
    conv1d = LeakyReLU()(conv1d)
    conv1d = Dropout(0.25)(conv1d)

    conv1d = Convolution1D(filters=filters[1],
                           kernel_size=kernel_size,
                           padding='same',
                           bias_initializer='he_uniform',
                           bias_regularizer=L1L2(0.01, 0.02),
                           kernel_regularizer=L1L2(0.01, 0.02)
                          )(conv1d)
    conv1d = BatchNormalization()(conv1d)
    conv1d = LeakyReLU()(conv1d)
    conv1d = Dropout(0.25)(conv1d)
    
    conv1d = MaxPooling1D(pool_size=pool_size)(conv1d)
    
    conv1d = Flatten()(conv1d)
    
    return inp, conv1d

# %% [markdown]
# #### Пути сохранения моделей:

# %%
model_path_root = 'models'
model_type_name = 'conv1d_univar'

def make_model_save_dir(path_root, type_name, class_name):
    save_dir = os.path.join(path_root, type_name, class_name)
    os.makedirs(save_dir, exist_ok=True)
    return save_dir

# %% [markdown]
# #### Общие коллбэки:

# %%
# уменьшение learning rate в случае, если loss не изменяется
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001, verbose=1)

# уменьшение learning rate в 2 раза каждую 5-ю эпоху
def lr_decay(e, lr):
    return lr * (1 - 0.5 * (0 == (e + 1) % 5))

lr_scheduler = LearningRateScheduler(schedule=lr_decay, verbose=1)

# %% [markdown]
# ## Задача регрессии
#
# Непосредственное прогнозирование цены следующего периода.

# %%
train_regr_gen = RegressionGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_regr_gen = RegressionGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_regr_gen = RegressionGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# Следующие числа соответствуют значению параметра `steps_per_epoch` метода [`fit_generator`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit_generator "tf.keras.layers.SimpleRNN &nbsp;|&nbsp; TensorFlow Core r2.0") - то есть это число батчей, которые генератор выдаст за одну эпоху обучения (если класс генератора поддерживает метод `len()`, то данный параметр можно не указывать).

# %%
len(train_regr_gen), len(test_regr_gen)
# Out:
# (46, 13)

# %% [markdown]
# Один сэмпл данных представляет собой матрицу размером *(длина окна; число признаков)*

# %%
train_regr_gen.input_shape
# Out:
# (60, 1)

# %% [markdown]
# ### Модель для задачи регрессии

# %%
model_class_name = 'regression'

# %%
def build_regression_model(input_shape):
    inp, conv1d = build_conv1d_layers(input_shape, filters=(32, 16))

    regr = Dense(32)(conv1d)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.25)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    return Model(inputs=[inp], outputs=[regr])

# %%
univariate_regression_conv1d = build_regression_model(train_regr_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:
# [`Nadam`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Nadam) (*Adam with Nestrov momentum*).

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Функция потерь:
#
# В качестве функции потерь будем использовать [MSE](https://www.tensorflow.org/api_docs/python/tf/keras/losses/MSE) (чтобы штрафовать за большие отклонения). Xотя хорошая функция потерь в контексте темы данной задачи - это [вопрос сложный](https://github.com/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Chapter5_LossFunctions/Ch5_LossFunctions_PyMC3.ipynb). В частности, здесь нам, очевидно, помимо абсолютного значения отклонения также важен его знак.

# %%
univariate_regression_conv1d.compile(optimizer=optimizer,
                                   loss={'regr': 'mse'},
                                   metrics={'regr': 'mae'})

univariate_regression_conv1d.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 60, 1)]           0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 60, 32)            192
# _________________________________________________________________
# batch_normalization (BatchNo (None, 60, 32)            128
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 60, 32)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 60, 32)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 60, 16)            2576
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 60, 16)            64
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 60, 16)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 60, 16)            0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 30, 16)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 480)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                15392
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32)                128
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 32)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# regr (Dense)                 (None, 1)                 33
# =================================================================
# Total params: 18,513
# Trainable params: 18,353
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# #### Обучение:

# %%
regr_history = utils.train_model(univariate_regression_conv1d,
                                 model_save_dir, train_regr_gen, test_regr_gen,
                                 callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                 force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 45/46 [============================>.] - ETA: 0s - loss: 4.7706 - mae: 0.9414
# Epoch 00001: val_loss improved from inf to 3.28706, saving model to models\conv1d_univar\regression\01.hdf5
# 46/46 [==============================] - 8s 172ms/step - loss: 4.7654 - mae: 0.9431 - val_loss: 3.2871 - val_mae: 0.5035
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 45/46 [============================>.] - ETA: 0s - loss: 4.1955 - mae: 0.8431
# Epoch 00002: val_loss improved from 3.28706 to 3.09238, saving model to models\conv1d_univar\regression\02.hdf5
# 46/46 [==============================] - 5s 117ms/step - loss: 4.1802 - mae: 0.8419 - val_loss: 3.0924 - val_mae: 0.4738
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.7896 - mae: 0.7775
# Epoch 00003: val_loss improved from 3.09238 to 2.92532, saving model to models\conv1d_univar\regression\03.hdf5
# 46/46 [==============================] - 5s 116ms/step - loss: 3.7789 - mae: 0.7751 - val_loss: 2.9253 - val_mae: 0.4685
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.6219 - mae: 0.7615
# Epoch 00004: val_loss improved from 2.92532 to 2.76490, saving model to models\conv1d_univar\regression\04.hdf5
# 46/46 [==============================] - 5s 112ms/step - loss: 3.6072 - mae: 0.7601 - val_loss: 2.7649 - val_mae: 0.4753
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.4102 - mae: 0.7474
# Epoch 00005: val_loss improved from 2.76490 to 2.68161, saving model to models\conv1d_univar\regression\05.hdf5
# 46/46 [==============================] - 5s 109ms/step - loss: 3.4106 - mae: 0.7511 - val_loss: 2.6816 - val_mae: 0.4804
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.2648 - mae: 0.7265
# Epoch 00006: val_loss improved from 2.68161 to 2.58491, saving model to models\conv1d_univar\regression\06.hdf5
# 46/46 [==============================] - 5s 118ms/step - loss: 3.2646 - mae: 0.7273 - val_loss: 2.5849 - val_mae: 0.4785
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.1283 - mae: 0.7082
# Epoch 00007: val_loss improved from 2.58491 to 2.48829, saving model to models\conv1d_univar\regression\07.hdf5
# 46/46 [==============================] - 5s 116ms/step - loss: 3.1162 - mae: 0.7071 - val_loss: 2.4883 - val_mae: 0.4778
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.0371 - mae: 0.6873
# Epoch 00008: val_loss improved from 2.48829 to 2.41127, saving model to models\conv1d_univar\regression\08.hdf5
# 46/46 [==============================] - 5s 116ms/step - loss: 3.0321 - mae: 0.6884 - val_loss: 2.4113 - val_mae: 0.4874
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.8724 - mae: 0.6888
# Epoch 00009: val_loss improved from 2.41127 to 2.33245, saving model to models\conv1d_univar\regression\09.hdf5
# 46/46 [==============================] - 5s 118ms/step - loss: 2.8594 - mae: 0.6880 - val_loss: 2.3325 - val_mae: 0.4904
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.8526 - mae: 0.7098
# Epoch 00010: val_loss improved from 2.33245 to 2.27245, saving model to models\conv1d_univar\regression\10.hdf5
# 46/46 [==============================] - 6s 134ms/step - loss: 2.8420 - mae: 0.7086 - val_loss: 2.2724 - val_mae: 0.4842
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.7329 - mae: 0.6919
# Epoch 00011: val_loss improved from 2.27245 to 2.23516, saving model to models\conv1d_univar\regression\11.hdf5
# 46/46 [==============================] - 6s 131ms/step - loss: 2.7324 - mae: 0.6949 - val_loss: 2.2352 - val_mae: 0.4876
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.6882 - mae: 0.6921
# Epoch 00012: val_loss improved from 2.23516 to 2.19543, saving model to models\conv1d_univar\regression\12.hdf5
# 46/46 [==============================] - 5s 117ms/step - loss: 2.7629 - mae: 0.6993 - val_loss: 2.1954 - val_mae: 0.4898
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.6617 - mae: 0.6787
# Epoch 00013: val_loss improved from 2.19543 to 2.13226, saving model to models\conv1d_univar\regression\13.hdf5
# 46/46 [==============================] - 5s 114ms/step - loss: 2.6538 - mae: 0.6788 - val_loss: 2.1323 - val_mae: 0.4870
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.5524 - mae: 0.6658
# Epoch 00014: val_loss improved from 2.13226 to 2.08423, saving model to models\conv1d_univar\regression\14.hdf5
# 46/46 [==============================] - 5s 117ms/step - loss: 2.5602 - mae: 0.6674 - val_loss: 2.0842 - val_mae: 0.4863
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.5682 - mae: 0.6755
# Epoch 00015: val_loss improved from 2.08423 to 2.06286, saving model to models\conv1d_univar\regression\15.hdf5
# 46/46 [==============================] - 5s 117ms/step - loss: 2.5666 - mae: 0.6769 - val_loss: 2.0629 - val_mae: 0.4878
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.5480 - mae: 0.6880- ETA: 1s - loss: 2.7004
# Epoch 00016: val_loss improved from 2.06286 to 2.03670, saving model to models\conv1d_univar\regression\16.hdf5
# 46/46 [==============================] - 5s 111ms/step - loss: 2.5466 - mae: 0.6895 - val_loss: 2.0367 - val_mae: 0.4876
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.2498 - mae: 0.6604
# Epoch 00017: val_loss improved from 2.03670 to 2.01655, saving model to models\conv1d_univar\regression\17.hdf5
# 46/46 [==============================] - 5s 112ms/step - loss: 2.5324 - mae: 0.6748 - val_loss: 2.0166 - val_mae: 0.4886
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.5070 - mae: 0.6839
# Epoch 00018: val_loss improved from 2.01655 to 1.99216, saving model to models\conv1d_univar\regression\18.hdf5
# 46/46 [==============================] - 5s 116ms/step - loss: 2.5214 - mae: 0.6886 - val_loss: 1.9922 - val_mae: 0.4879
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.4760 - mae: 0.6801
# Epoch 00019: val_loss improved from 1.99216 to 1.96438, saving model to models\conv1d_univar\regression\19.hdf5
# 46/46 [==============================] - 5s 109ms/step - loss: 2.4632 - mae: 0.6783 - val_loss: 1.9644 - val_mae: 0.4872
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.4406 - mae: 0.6800
# Epoch 00020: val_loss improved from 1.96438 to 1.95765, saving model to models\conv1d_univar\regression\20.hdf5
# 46/46 [==============================] - 5s 114ms/step - loss: 2.4276 - mae: 0.6775 - val_loss: 1.9577 - val_mae: 0.4892
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.3920 - mae: 0.6602
# Epoch 00021: val_loss improved from 1.95765 to 1.94429, saving model to models\conv1d_univar\regression\21.hdf5
# 46/46 [==============================] - 5s 113ms/step - loss: 2.3783 - mae: 0.6571 - val_loss: 1.9443 - val_mae: 0.4888
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.3990 - mae: 0.6746
# Epoch 00022: val_loss improved from 1.94429 to 1.93042, saving model to models\conv1d_univar\regression\22.hdf5
# 46/46 [==============================] - 5s 111ms/step - loss: 2.3847 - mae: 0.6724 - val_loss: 1.9304 - val_mae: 0.4885
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.3899 - mae: 0.6798
# Epoch 00023: val_loss improved from 1.93042 to 1.91515, saving model to models\conv1d_univar\regression\23.hdf5
# 46/46 [==============================] - 5s 117ms/step - loss: 2.3758 - mae: 0.6760 - val_loss: 1.9152 - val_mae: 0.4875
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.3753 - mae: 0.6765
# Epoch 00024: val_loss improved from 1.91515 to 1.90422, saving model to models\conv1d_univar\regression\24.hdf5
# 46/46 [==============================] - 5s 112ms/step - loss: 2.3682 - mae: 0.6771 - val_loss: 1.9042 - val_mae: 0.4879
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.1472 - mae: 0.6652
# Epoch 00025: val_loss improved from 1.90422 to 1.89949, saving model to models\conv1d_univar\regression\25.hdf5
# 46/46 [==============================] - 5s 116ms/step - loss: 2.4323 - mae: 0.6774 - val_loss: 1.8995 - val_mae: 0.4886
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.3085 - mae: 0.6660
# Epoch 00026: val_loss improved from 1.89949 to 1.89325, saving model to models\conv1d_univar\regression\26.hdf5
# 46/46 [==============================] - 5s 118ms/step - loss: 2.3074 - mae: 0.6655 - val_loss: 1.8933 - val_mae: 0.4885
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.2919 - mae: 0.6469
# Epoch 00027: val_loss improved from 1.89325 to 1.88776, saving model to models\conv1d_univar\regression\27.hdf5
# 46/46 [==============================] - 5s 114ms/step - loss: 2.2966 - mae: 0.6500 - val_loss: 1.8878 - val_mae: 0.4884
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.3413 - mae: 0.6549
# Epoch 00028: val_loss improved from 1.88776 to 1.88324, saving model to models\conv1d_univar\regression\28.hdf5
# 46/46 [==============================] - 5s 119ms/step - loss: 2.3370 - mae: 0.6568 - val_loss: 1.8832 - val_mae: 0.4891
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.2983 - mae: 0.6548
# Epoch 00029: val_loss improved from 1.88324 to 1.87714, saving model to models\conv1d_univar\regression\29.hdf5
# 46/46 [==============================] - 6s 128ms/step - loss: 2.2905 - mae: 0.6541 - val_loss: 1.8771 - val_mae: 0.4896
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.3058 - mae: 0.6617
# Epoch 00030: val_loss improved from 1.87714 to 1.87391, saving model to models\conv1d_univar\regression\30.hdf5
# 46/46 [==============================] - 6s 120ms/step - loss: 2.3053 - mae: 0.6628 - val_loss: 1.8739 - val_mae: 0.4897
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.3772 - mae: 0.6798
# Epoch 00031: val_loss improved from 1.87391 to 1.87130, saving model to models\conv1d_univar\regression\31.hdf5
# 46/46 [==============================] - 6s 124ms/step - loss: 2.3779 - mae: 0.6819 - val_loss: 1.8713 - val_mae: 0.4900
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.1012 - mae: 0.6643
# Epoch 00032: val_loss improved from 1.87130 to 1.86750, saving model to models\conv1d_univar\regression\32.hdf5
# 46/46 [==============================] - 5s 120ms/step - loss: 2.3568 - mae: 0.6749 - val_loss: 1.8675 - val_mae: 0.4896

# %%
def plot_regr_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'MSE', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'MAE', 'mae', 'val_mae')
    
plot_regr_history(regr_history);

# %% [markdown]
# ### Прогноз задачи регрессии

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_regression_conv1d.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret_test = univariate_regression_conv1d.predict_generator(test_regr_gen, verbose=1)
# Out:
# 13/13 [==============================] - 0s 16ms/step

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret_test, figsize=(16, 10),
                                  datetime_unit='m', plot_data_slice=slice(1, None))

# %% [markdown]
# ## Задача классификации
#
# Прогнозируем направление изменения цены по сравнению с предыдущим периодом (**0** - снижение, **1** - рост).

# %%
model_class_name = 'classification'

# %%
train_clf_gen = ClassificationGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_clf_gen = ClassificationGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_clf_gen = ClassificationGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_classification_model(input_shape):
    inp, conv1d = build_conv1d_layers(input_shape, filters=(32, 16))

    clf = Dense(32)(conv1d)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.25)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)

    return Model(inputs=[inp], outputs=[clf])

# %%
univariate_classification_conv1d = build_classification_model(test_clf_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
univariate_classification_conv1d.compile(optimizer=optimizer,
                                         loss={'clf': 'binary_crossentropy'},
                                         metrics={'clf': 'accuracy'})

univariate_classification_conv1d.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 60, 1)]           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 60, 32)            192
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 60, 32)            128
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 60, 32)            0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 60, 32)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 60, 16)            2576
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 60, 16)            64
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 60, 16)            0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 60, 16)            0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 30, 16)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 480)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                15392
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32)                128
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 32)                0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 32)                0
# _________________________________________________________________
# clf (Dense)                  (None, 1)                 33
# =================================================================
# Total params: 18,513
# Trainable params: 18,353
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
clf_history = utils.train_model(univariate_classification_conv1d,
                                model_save_dir, train_clf_gen, test_clf_gen,
                                callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.3829 - accuracy: 0.5104
# Epoch 00001: val_loss improved from inf to 2.91980, saving model to models\conv1d_univar\classification\01.hdf5
# 46/46 [==============================] - 6s 124ms/step - loss: 3.3751 - accuracy: 0.5109 - val_loss: 2.9198 - val_accuracy: 0.5335
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.7280 - accuracy: 0.5028
# Epoch 00002: val_loss improved from 2.91980 to 2.36775, saving model to models\conv1d_univar\classification\02.hdf5
# 46/46 [==============================] - 5s 119ms/step - loss: 2.7211 - accuracy: 0.5041 - val_loss: 2.3678 - val_accuracy: 0.5258
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.1802 - accuracy: 0.5312
# Epoch 00003: val_loss improved from 2.36775 to 1.91523, saving model to models\conv1d_univar\classification\03.hdf5
# 46/46 [==============================] - 6s 122ms/step - loss: 2.1723 - accuracy: 0.5328 - val_loss: 1.9152 - val_accuracy: 0.5206
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 45/46 [============================>.] - ETA: 0s - loss: 1.7498 - accuracy: 0.5493
# Epoch 00004: val_loss improved from 1.91523 to 1.55742, saving model to models\conv1d_univar\classification\04.hdf5
# 46/46 [==============================] - 5s 119ms/step - loss: 1.7477 - accuracy: 0.5492 - val_loss: 1.5574 - val_accuracy: 0.5412
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 45/46 [============================>.] - ETA: 0s - loss: 1.4761 - accuracy: 0.5701
# Epoch 00005: val_loss improved from 1.55742 to 1.40398, saving model to models\conv1d_univar\classification\05.hdf5
# 46/46 [==============================] - 6s 123ms/step - loss: 1.4731 - accuracy: 0.5717 - val_loss: 1.4040 - val_accuracy: 0.5077
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 45/46 [============================>.] - ETA: 0s - loss: 1.3589 - accuracy: 0.5688
# Epoch 00006: val_loss improved from 1.40398 to 1.28264, saving model to models\conv1d_univar\classification\06.hdf5
# 46/46 [==============================] - 6s 126ms/step - loss: 1.3568 - accuracy: 0.5690 - val_loss: 1.2826 - val_accuracy: 0.5180
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 45/46 [============================>.] - ETA: 0s - loss: 1.2303 - accuracy: 0.5660
# Epoch 00007: val_loss improved from 1.28264 to 1.17920, saving model to models\conv1d_univar\classification\07.hdf5
# 46/46 [==============================] - 6s 122ms/step - loss: 1.2308 - accuracy: 0.5635 - val_loss: 1.1792 - val_accuracy: 0.5206
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 45/46 [============================>.] - ETA: 0s - loss: 1.1335 - accuracy: 0.5688
# Epoch 00008: val_loss improved from 1.17920 to 1.09521, saving model to models\conv1d_univar\classification\08.hdf5
# 46/46 [==============================] - 6s 124ms/step - loss: 1.1327 - accuracy: 0.5676 - val_loss: 1.0952 - val_accuracy: 0.5155
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 45/46 [============================>.] - ETA: 0s - loss: 1.0594 - accuracy: 0.5715
# Epoch 00009: val_loss improved from 1.09521 to 1.02687, saving model to models\conv1d_univar\classification\09.hdf5
# 46/46 [==============================] - 6s 122ms/step - loss: 1.0571 - accuracy: 0.5738 - val_loss: 1.0269 - val_accuracy: 0.5129
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.9979 - accuracy: 0.5729
# Epoch 00010: val_loss improved from 1.02687 to 0.99137, saving model to models\conv1d_univar\classification\10.hdf5
# 46/46 [==============================] - 6s 120ms/step - loss: 0.9961 - accuracy: 0.5751 - val_loss: 0.9914 - val_accuracy: 0.5155
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.9582 - accuracy: 0.5785
# Epoch 00011: val_loss improved from 0.99137 to 0.96545, saving model to models\conv1d_univar\classification\11.hdf5
# 46/46 [==============================] - 6s 136ms/step - loss: 0.9576 - accuracy: 0.5779 - val_loss: 0.9654 - val_accuracy: 0.5026
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.9281 - accuracy: 0.5806
# Epoch 00012: val_loss improved from 0.96545 to 0.94567, saving model to models\conv1d_univar\classification\12.hdf5
# 46/46 [==============================] - 6s 126ms/step - loss: 0.9296 - accuracy: 0.5806 - val_loss: 0.9457 - val_accuracy: 0.4948
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.9256 - accuracy: 0.5611
# Epoch 00013: val_loss improved from 0.94567 to 0.92890, saving model to models\conv1d_univar\classification\13.hdf5
# 46/46 [==============================] - 7s 153ms/step - loss: 0.9254 - accuracy: 0.5615 - val_loss: 0.9289 - val_accuracy: 0.5129
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.8887 - accuracy: 0.5826
# Epoch 00014: val_loss improved from 0.92890 to 0.91329, saving model to models\conv1d_univar\classification\14.hdf5
# 46/46 [==============================] - 6s 130ms/step - loss: 0.8862 - accuracy: 0.5847 - val_loss: 0.9133 - val_accuracy: 0.4974
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.8700 - accuracy: 0.5785
# Epoch 00015: val_loss improved from 0.91329 to 0.90276, saving model to models\conv1d_univar\classification\15.hdf5
# 46/46 [==============================] - 7s 148ms/step - loss: 0.8708 - accuracy: 0.5786 - val_loss: 0.9028 - val_accuracy: 0.5026
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.8566 - accuracy: 0.6021
# Epoch 00016: val_loss improved from 0.90276 to 0.89287, saving model to models\conv1d_univar\classification\16.hdf5
# 46/46 [==============================] - 6s 126ms/step - loss: 0.8556 - accuracy: 0.6038 - val_loss: 0.8929 - val_accuracy: 0.5052
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.8467 - accuracy: 0.5826
# Epoch 00017: val_loss improved from 0.89287 to 0.88929, saving model to models\conv1d_univar\classification\17.hdf5
# 46/46 [==============================] - 6s 129ms/step - loss: 0.8461 - accuracy: 0.5820 - val_loss: 0.8893 - val_accuracy: 0.4820
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.8413 - accuracy: 0.5806
# Epoch 00018: val_loss improved from 0.88929 to 0.88454, saving model to models\conv1d_univar\classification\18.hdf5
# 46/46 [==============================] - 5s 119ms/step - loss: 0.8404 - accuracy: 0.5827 - val_loss: 0.8845 - val_accuracy: 0.4665
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.8361 - accuracy: 0.5840
# Epoch 00019: val_loss improved from 0.88454 to 0.87777, saving model to models\conv1d_univar\classification\19.hdf5
# 46/46 [==============================] - 5s 117ms/step - loss: 0.8347 - accuracy: 0.5861 - val_loss: 0.8778 - val_accuracy: 0.4691
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.8390 - accuracy: 0.5826
# Epoch 00020: val_loss improved from 0.87777 to 0.87512, saving model to models\conv1d_univar\classification\20.hdf5
# 46/46 [==============================] - 6s 140ms/step - loss: 0.8393 - accuracy: 0.5827 - val_loss: 0.8751 - val_accuracy: 0.4716
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.8128 - accuracy: 0.6069
# Epoch 00021: val_loss improved from 0.87512 to 0.87244, saving model to models\conv1d_univar\classification\21.hdf5
# 46/46 [==============================] - 6s 124ms/step - loss: 0.8122 - accuracy: 0.6066 - val_loss: 0.8724 - val_accuracy: 0.4768
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.8140 - accuracy: 0.6062
# Epoch 00022: val_loss improved from 0.87244 to 0.86658, saving model to models\conv1d_univar\classification\22.hdf5
# 46/46 [==============================] - 8s 171ms/step - loss: 0.8131 - accuracy: 0.6072 - val_loss: 0.8666 - val_accuracy: 0.4794
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.8130 - accuracy: 0.5875
# Epoch 00023: val_loss improved from 0.86658 to 0.86466, saving model to models\conv1d_univar\classification\23.hdf5
# 46/46 [==============================] - 5s 115ms/step - loss: 0.8138 - accuracy: 0.5861 - val_loss: 0.8647 - val_accuracy: 0.4716
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.8130 - accuracy: 0.5896
# Epoch 00024: val_loss improved from 0.86466 to 0.86332, saving model to models\conv1d_univar\classification\24.hdf5
# 46/46 [==============================] - 5s 103ms/step - loss: 0.8140 - accuracy: 0.5867 - val_loss: 0.8633 - val_accuracy: 0.4845
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.8099 - accuracy: 0.5938
# Epoch 00025: val_loss improved from 0.86332 to 0.86206, saving model to models\conv1d_univar\classification\25.hdf5
# 46/46 [==============================] - 5s 119ms/step - loss: 0.8080 - accuracy: 0.5970 - val_loss: 0.8621 - val_accuracy: 0.4716
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.7959 - accuracy: 0.6056
# Epoch 00026: val_loss improved from 0.86206 to 0.86121, saving model to models\conv1d_univar\classification\26.hdf5
# 46/46 [==============================] - 5s 102ms/step - loss: 0.7990 - accuracy: 0.6045 - val_loss: 0.8612 - val_accuracy: 0.4639
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.8068 - accuracy: 0.5722
# Epoch 00027: val_loss improved from 0.86121 to 0.85978, saving model to models\conv1d_univar\classification\27.hdf5
# 46/46 [==============================] - 4s 96ms/step - loss: 0.8075 - accuracy: 0.5731 - val_loss: 0.8598 - val_accuracy: 0.4716
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.7980 - accuracy: 0.5889
# Epoch 00028: val_loss improved from 0.85978 to 0.85861, saving model to models\conv1d_univar\classification\28.hdf5
# 46/46 [==============================] - 6s 123ms/step - loss: 0.7964 - accuracy: 0.5895 - val_loss: 0.8586 - val_accuracy: 0.4665
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.7937 - accuracy: 0.6090
# Epoch 00029: val_loss improved from 0.85861 to 0.85857, saving model to models\conv1d_univar\classification\29.hdf5
# 46/46 [==============================] - 5s 107ms/step - loss: 0.7958 - accuracy: 0.6072 - val_loss: 0.8586 - val_accuracy: 0.4639
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.8075 - accuracy: 0.5715
# Epoch 00030: val_loss improved from 0.85857 to 0.85733, saving model to models\conv1d_univar\classification\30.hdf5
# 46/46 [==============================] - 8s 177ms/step - loss: 0.8067 - accuracy: 0.5717 - val_loss: 0.8573 - val_accuracy: 0.4742
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.7968 - accuracy: 0.6014
# Epoch 00031: val_loss improved from 0.85733 to 0.85700, saving model to models\conv1d_univar\classification\31.hdf5
# 46/46 [==============================] - 7s 162ms/step - loss: 0.7981 - accuracy: 0.5997 - val_loss: 0.8570 - val_accuracy: 0.4691
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.7909 - accuracy: 0.6049
# Epoch 00032: val_loss improved from 0.85700 to 0.85674, saving model to models\conv1d_univar\classification\32.hdf5
# 46/46 [==============================] - 6s 128ms/step - loss: 0.7916 - accuracy: 0.6038 - val_loss: 0.8567 - val_accuracy: 0.4588

# %%
def plot_clf_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'Loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'Accuracy', 'accuracy', 'val_accuracy')
    
plot_clf_history(clf_history);

# %% [markdown]
# ### Прогноз задачи классификации

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_classification_conv1d.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %%
pred_direction_proba = univariate_classification_conv1d.predict_generator(test_clf_gen, verbose=1)

true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 13/13 [==============================] - 0s 19ms/step
# 0.5056517

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([210, 178], dtype=int64)),
#  (array([0, 1]), array([181, 207], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.44      0.47       210
#            1       0.43      0.50      0.46       178
#
#     accuracy                           0.47       388
#    macro avg       0.47      0.47      0.47       388
# weighted avg       0.47      0.47      0.47       388

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[ 92, 118],
#        [ 89,  89]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.50828729, 0.57004831],
#        [0.49171271, 0.42995169]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# ## Многозадачная модель: одновременно регрессия и классификация

# %%
model_class_name = 'multitask'

# %%
train_multi_gen = MultitaskGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_multi_gen = MultitaskGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_multi_gen = MultitaskGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_multitask_model(input_shape):
    inp, conv1d = build_conv1d_layers(input_shape, filters=(32, 16))

    # первый выход: задача регрссии
    regr = Dense(32)(conv1d)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.25)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    # второй выход: задача классификации
    clf = Dense(32)(conv1d)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.25)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)
    
    return Model(inputs=[inp], outputs=[regr, clf])

# %%
univariate_multitask_conv1d = build_multitask_model(train_multi_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
univariate_multitask_conv1d.compile(optimizer=optimizer,
                                    loss={'regr': 'mse', 'clf': 'binary_crossentropy'},
                                    loss_weights={'regr': 1., 'clf': 1.},
                                    metrics={'regr': 'mae', 'clf' : 'accuracy'})

univariate_multitask_conv1d.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 60, 1)]      0
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 60, 32)       192         input[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 60, 32)       128         conv1d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 60, 32)       0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 60, 32)       0           leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 60, 16)       2576        dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 60, 16)       64          conv1d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 60, 16)       0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 60, 16)       0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 30, 16)       0           dropout_7[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 480)          0           max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 32)           15392       flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 32)           15392       flatten_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32)           128         dense_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32)           128         dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 32)           0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 32)           0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 32)           0           leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 32)           0           leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# regr (Dense)                    (None, 1)            33          dropout_8[0][0]
# __________________________________________________________________________________________________
# clf (Dense)                     (None, 1)            33          dropout_9[0][0]
# ==================================================================================================
# Total params: 34,066
# Trainable params: 33,842
# Non-trainable params: 224
# __________________________________________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
multitask_history = utils.train_model(univariate_multitask_conv1d,
                                      model_save_dir, train_multi_gen, test_multi_gen,
                                      callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                      force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 45/46 [============================>.] - ETA: 0s - loss: 5.3720 - regr_loss: 1.8091 - clf_loss: 0.7802 - regr_mae: 0.9272 - clf_accuracy: 0.5014
# Epoch 00001: val_loss improved from inf to 3.95154, saving model to models\conv1d_univar\multitask\01.hdf5
# 46/46 [==============================] - 7s 158ms/step - loss: 5.3685 - regr_loss: 1.8066 - clf_loss: 0.7811 - regr_mae: 0.9274 - clf_accuracy: 0.5000 - val_loss: 3.9515 - val_regr_loss: 0.5513 - val_clf_loss: 0.7036 - val_regr_mae: 0.4800 - val_clf_accuracy: 0.4588
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 45/46 [============================>.] - ETA: 0s - loss: 4.8288 - regr_loss: 1.4737 - clf_loss: 0.7442 - regr_mae: 0.8183 - clf_accuracy: 0.5285
# Epoch 00002: val_loss improved from 3.95154 to 3.76278, saving model to models\conv1d_univar\multitask\02.hdf5
# 46/46 [==============================] - 8s 171ms/step - loss: 4.8128 - regr_loss: 1.4613 - clf_loss: 0.7426 - regr_mae: 0.8173 - clf_accuracy: 0.5294 - val_loss: 3.7628 - val_regr_loss: 0.5397 - val_clf_loss: 0.7078 - val_regr_mae: 0.4752 - val_clf_accuracy: 0.4485
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 45/46 [============================>.] - ETA: 0s - loss: 4.4399 - regr_loss: 1.2924 - clf_loss: 0.7237 - regr_mae: 0.7730 - clf_accuracy: 0.5431
# Epoch 00003: val_loss improved from 3.76278 to 3.59222, saving model to models\conv1d_univar\multitask\03.hdf5
# 46/46 [==============================] - 7s 157ms/step - loss: 4.4293 - regr_loss: 1.2844 - clf_loss: 0.7230 - regr_mae: 0.7725 - clf_accuracy: 0.5437 - val_loss: 3.5922 - val_regr_loss: 0.5627 - val_clf_loss: 0.7051 - val_regr_mae: 0.4823 - val_clf_accuracy: 0.4665
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 45/46 [============================>.] - ETA: 0s - loss: 4.2017 - regr_loss: 1.2564 - clf_loss: 0.7145 - regr_mae: 0.7473 - clf_accuracy: 0.5403
# Epoch 00004: val_loss improved from 3.59222 to 3.38345, saving model to models\conv1d_univar\multitask\04.hdf5
# 46/46 [==============================] - 7s 162ms/step - loss: 4.1830 - regr_loss: 1.2414 - clf_loss: 0.7129 - regr_mae: 0.7446 - clf_accuracy: 0.5417 - val_loss: 3.3834 - val_regr_loss: 0.5495 - val_clf_loss: 0.7050 - val_regr_mae: 0.4831 - val_clf_accuracy: 0.4562
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.9608 - regr_loss: 1.1808 - clf_loss: 0.6971 - regr_mae: 0.7346 - clf_accuracy: 0.5604
# Epoch 00005: val_loss improved from 3.38345 to 3.29253, saving model to models\conv1d_univar\multitask\05.hdf5
# 46/46 [==============================] - 8s 178ms/step - loss: 3.9619 - regr_loss: 1.1820 - clf_loss: 0.6981 - regr_mae: 0.7353 - clf_accuracy: 0.5594 - val_loss: 3.2925 - val_regr_loss: 0.5540 - val_clf_loss: 0.7076 - val_regr_mae: 0.4914 - val_clf_accuracy: 0.4716
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.8442 - regr_loss: 1.1592 - clf_loss: 0.7023 - regr_mae: 0.7093 - clf_accuracy: 0.5625
# Epoch 00006: val_loss improved from 3.29253 to 3.19095, saving model to models\conv1d_univar\multitask\06.hdf5
# 46/46 [==============================] - 7s 155ms/step - loss: 3.8334 - regr_loss: 1.1507 - clf_loss: 0.7010 - regr_mae: 0.7092 - clf_accuracy: 0.5622 - val_loss: 3.1909 - val_regr_loss: 0.5509 - val_clf_loss: 0.7093 - val_regr_mae: 0.4856 - val_clf_accuracy: 0.4820
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.7454 - regr_loss: 1.1539 - clf_loss: 0.7091 - regr_mae: 0.7115 - clf_accuracy: 0.5486
# Epoch 00007: val_loss improved from 3.19095 to 3.08756, saving model to models\conv1d_univar\multitask\07.hdf5
# 46/46 [==============================] - 8s 164ms/step - loss: 3.7327 - regr_loss: 1.1436 - clf_loss: 0.7077 - regr_mae: 0.7105 - clf_accuracy: 0.5492 - val_loss: 3.0876 - val_regr_loss: 0.5464 - val_clf_loss: 0.7107 - val_regr_mae: 0.4854 - val_clf_accuracy: 0.4897
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.5468 - regr_loss: 1.0821 - clf_loss: 0.6820 - regr_mae: 0.6836 - clf_accuracy: 0.5569
# Epoch 00008: val_loss improved from 3.08756 to 3.00510, saving model to models\conv1d_univar\multitask\08.hdf5
# 46/46 [==============================] - 7s 152ms/step - loss: 3.5357 - regr_loss: 1.0720 - clf_loss: 0.6820 - regr_mae: 0.6833 - clf_accuracy: 0.5574 - val_loss: 3.0051 - val_regr_loss: 0.5574 - val_clf_loss: 0.7165 - val_regr_mae: 0.4868 - val_clf_accuracy: 0.4536
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.4644 - regr_loss: 1.0781 - clf_loss: 0.7017 - regr_mae: 0.6770 - clf_accuracy: 0.5354
# Epoch 00009: val_loss improved from 3.00510 to 2.92116, saving model to models\conv1d_univar\multitask\09.hdf5
# 46/46 [==============================] - 10s 219ms/step - loss: 3.4655 - regr_loss: 1.0793 - clf_loss: 0.7027 - regr_mae: 0.6792 - clf_accuracy: 0.5362 - val_loss: 2.9212 - val_regr_loss: 0.5687 - val_clf_loss: 0.7196 - val_regr_mae: 0.4949 - val_clf_accuracy: 0.4742
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.4080 - regr_loss: 1.1170 - clf_loss: 0.6825 - regr_mae: 0.6817 - clf_accuracy: 0.5660
# Epoch 00010: val_loss improved from 2.92116 to 2.87671, saving model to models\conv1d_univar\multitask\10.hdf5
# 46/46 [==============================] - 11s 231ms/step - loss: 3.3940 - regr_loss: 1.1053 - clf_loss: 0.6807 - regr_mae: 0.6795 - clf_accuracy: 0.5669 - val_loss: 2.8767 - val_regr_loss: 0.5719 - val_clf_loss: 0.7230 - val_regr_mae: 0.4977 - val_clf_accuracy: 0.4459
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.3437 - regr_loss: 1.0994 - clf_loss: 0.6864 - regr_mae: 0.6852 - clf_accuracy: 0.5542
# Epoch 00011: val_loss improved from 2.87671 to 2.83310, saving model to models\conv1d_univar\multitask\11.hdf5
# 46/46 [==============================] - 7s 157ms/step - loss: 3.3333 - regr_loss: 1.0917 - clf_loss: 0.6842 - regr_mae: 0.6833 - clf_accuracy: 0.5560 - val_loss: 2.8331 - val_regr_loss: 0.5737 - val_clf_loss: 0.7275 - val_regr_mae: 0.4991 - val_clf_accuracy: 0.4381
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.3097 - regr_loss: 1.1191 - clf_loss: 0.6816 - regr_mae: 0.6911 - clf_accuracy: 0.5604
# Epoch 00012: val_loss improved from 2.83310 to 2.78841, saving model to models\conv1d_univar\multitask\12.hdf5
# 46/46 [==============================] - 7s 153ms/step - loss: 3.2994 - regr_loss: 1.1078 - clf_loss: 0.6830 - regr_mae: 0.6904 - clf_accuracy: 0.5608 - val_loss: 2.7884 - val_regr_loss: 0.5774 - val_clf_loss: 0.7276 - val_regr_mae: 0.4987 - val_clf_accuracy: 0.4562
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.1648 - regr_loss: 1.0168 - clf_loss: 0.6879 - regr_mae: 0.6763 - clf_accuracy: 0.5569
# Epoch 00013: val_loss improved from 2.78841 to 2.74121, saving model to models\conv1d_univar\multitask\13.hdf5
# 46/46 [==============================] - 8s 171ms/step - loss: 3.1574 - regr_loss: 1.0109 - clf_loss: 0.6869 - regr_mae: 0.6754 - clf_accuracy: 0.5560 - val_loss: 2.7412 - val_regr_loss: 0.5799 - val_clf_loss: 0.7273 - val_regr_mae: 0.4987 - val_clf_accuracy: 0.4356
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.1377 - regr_loss: 1.0426 - clf_loss: 0.6844 - regr_mae: 0.6710 - clf_accuracy: 0.5799
# Epoch 00014: val_loss improved from 2.74121 to 2.69600, saving model to models\conv1d_univar\multitask\14.hdf5
# 46/46 [==============================] - 7s 155ms/step - loss: 3.1278 - regr_loss: 1.0338 - clf_loss: 0.6838 - regr_mae: 0.6705 - clf_accuracy: 0.5779 - val_loss: 2.6960 - val_regr_loss: 0.5835 - val_clf_loss: 0.7263 - val_regr_mae: 0.5011 - val_clf_accuracy: 0.4356
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.0723 - regr_loss: 1.0173 - clf_loss: 0.6809 - regr_mae: 0.6605 - clf_accuracy: 0.5826
# Epoch 00015: val_loss improved from 2.69600 to 2.67671, saving model to models\conv1d_univar\multitask\15.hdf5
# 46/46 [==============================] - 8s 166ms/step - loss: 3.0640 - regr_loss: 1.0093 - clf_loss: 0.6809 - regr_mae: 0.6584 - clf_accuracy: 0.5820 - val_loss: 2.6767 - val_regr_loss: 0.5883 - val_clf_loss: 0.7276 - val_regr_mae: 0.5047 - val_clf_accuracy: 0.4433
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.0783 - regr_loss: 1.0585 - clf_loss: 0.6707 - regr_mae: 0.6667 - clf_accuracy: 0.5806
# Epoch 00016: val_loss improved from 2.67671 to 2.64945, saving model to models\conv1d_univar\multitask\16.hdf5
# 46/46 [==============================] - 8s 165ms/step - loss: 3.0667 - regr_loss: 1.0497 - clf_loss: 0.6682 - regr_mae: 0.6667 - clf_accuracy: 0.5840 - val_loss: 2.6495 - val_regr_loss: 0.5848 - val_clf_loss: 0.7288 - val_regr_mae: 0.5029 - val_clf_accuracy: 0.4433
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.0235 - regr_loss: 1.0240 - clf_loss: 0.6750 - regr_mae: 0.6691 - clf_accuracy: 0.5785
# Epoch 00017: val_loss improved from 2.64945 to 2.62922, saving model to models\conv1d_univar\multitask\17.hdf5
# 46/46 [==============================] - 8s 170ms/step - loss: 3.0357 - regr_loss: 1.0364 - clf_loss: 0.6751 - regr_mae: 0.6728 - clf_accuracy: 0.5779 - val_loss: 2.6292 - val_regr_loss: 0.5883 - val_clf_loss: 0.7290 - val_regr_mae: 0.5035 - val_clf_accuracy: 0.4536
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.0150 - regr_loss: 1.0351 - clf_loss: 0.6795 - regr_mae: 0.6694 - clf_accuracy: 0.5729
# Epoch 00018: val_loss improved from 2.62922 to 2.60166, saving model to models\conv1d_univar\multitask\18.hdf5
# 46/46 [==============================] - 7s 159ms/step - loss: 3.0179 - regr_loss: 1.0379 - clf_loss: 0.6799 - regr_mae: 0.6706 - clf_accuracy: 0.5710 - val_loss: 2.6017 - val_regr_loss: 0.5842 - val_clf_loss: 0.7299 - val_regr_mae: 0.5022 - val_clf_accuracy: 0.4716
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.0000 - regr_loss: 1.0486 - clf_loss: 0.6755 - regr_mae: 0.6717 - clf_accuracy: 0.5701
# Epoch 00019: val_loss improved from 2.60166 to 2.57073, saving model to models\conv1d_univar\multitask\19.hdf5
# 46/46 [==============================] - 7s 147ms/step - loss: 2.9871 - regr_loss: 1.0350 - clf_loss: 0.6763 - regr_mae: 0.6699 - clf_accuracy: 0.5676 - val_loss: 2.5707 - val_regr_loss: 0.5790 - val_clf_loss: 0.7283 - val_regr_mae: 0.5002 - val_clf_accuracy: 0.4794
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.9235 - regr_loss: 0.9936 - clf_loss: 0.6726 - regr_mae: 0.6534 - clf_accuracy: 0.5917
# Epoch 00020: val_loss improved from 2.57073 to 2.56240, saving model to models\conv1d_univar\multitask\20.hdf5
# 46/46 [==============================] - 8s 164ms/step - loss: 2.9120 - regr_loss: 0.9831 - clf_loss: 0.6717 - regr_mae: 0.6524 - clf_accuracy: 0.5929 - val_loss: 2.5624 - val_regr_loss: 0.5826 - val_clf_loss: 0.7289 - val_regr_mae: 0.5017 - val_clf_accuracy: 0.4742
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.9303 - regr_loss: 1.0147 - clf_loss: 0.6707 - regr_mae: 0.6511 - clf_accuracy: 0.5868
# Epoch 00021: val_loss improved from 2.56240 to 2.55117, saving model to models\conv1d_univar\multitask\21.hdf5
# 46/46 [==============================] - 7s 156ms/step - loss: 2.9214 - regr_loss: 1.0068 - clf_loss: 0.6699 - regr_mae: 0.6518 - clf_accuracy: 0.5867 - val_loss: 2.5512 - val_regr_loss: 0.5833 - val_clf_loss: 0.7297 - val_regr_mae: 0.5021 - val_clf_accuracy: 0.4665
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.9175 - regr_loss: 1.0151 - clf_loss: 0.6699 - regr_mae: 0.6547 - clf_accuracy: 0.5889
# Epoch 00022: val_loss improved from 2.55117 to 2.54030, saving model to models\conv1d_univar\multitask\22.hdf5
# 46/46 [==============================] - 7s 148ms/step - loss: 2.9127 - regr_loss: 1.0092 - clf_loss: 0.6711 - regr_mae: 0.6555 - clf_accuracy: 0.5867 - val_loss: 2.5403 - val_regr_loss: 0.5836 - val_clf_loss: 0.7306 - val_regr_mae: 0.5017 - val_clf_accuracy: 0.4536
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.8828 - regr_loss: 0.9911 - clf_loss: 0.6714 - regr_mae: 0.6552 - clf_accuracy: 0.5826
# Epoch 00023: val_loss improved from 2.54030 to 2.53057, saving model to models\conv1d_univar\multitask\23.hdf5
# 46/46 [==============================] - 7s 142ms/step - loss: 2.8710 - regr_loss: 0.9796 - clf_loss: 0.6711 - regr_mae: 0.6532 - clf_accuracy: 0.5820 - val_loss: 2.5306 - val_regr_loss: 0.5854 - val_clf_loss: 0.7313 - val_regr_mae: 0.5026 - val_clf_accuracy: 0.4485
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.8917 - regr_loss: 1.0089 - clf_loss: 0.6747 - regr_mae: 0.6552 - clf_accuracy: 0.5715
# Epoch 00024: val_loss improved from 2.53057 to 2.51908, saving model to models\conv1d_univar\multitask\24.hdf5
# 46/46 [==============================] - 7s 143ms/step - loss: 2.8774 - regr_loss: 0.9961 - clf_loss: 0.6734 - regr_mae: 0.6525 - clf_accuracy: 0.5745 - val_loss: 2.5191 - val_regr_loss: 0.5859 - val_clf_loss: 0.7315 - val_regr_mae: 0.5039 - val_clf_accuracy: 0.4381
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.9110 - regr_loss: 1.0363 - clf_loss: 0.6761 - regr_mae: 0.6620 - clf_accuracy: 0.5799
# Epoch 00025: val_loss improved from 2.51908 to 2.51388, saving model to models\conv1d_univar\multitask\25.hdf5
# 46/46 [==============================] - 7s 148ms/step - loss: 2.9019 - regr_loss: 1.0264 - clf_loss: 0.6768 - regr_mae: 0.6598 - clf_accuracy: 0.5792 - val_loss: 2.5139 - val_regr_loss: 0.5869 - val_clf_loss: 0.7315 - val_regr_mae: 0.5045 - val_clf_accuracy: 0.4459
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.8708 - regr_loss: 1.0104 - clf_loss: 0.6680 - regr_mae: 0.6530 - clf_accuracy: 0.5861
# Epoch 00026: val_loss improved from 2.51388 to 2.50881, saving model to models\conv1d_univar\multitask\26.hdf5
# 46/46 [==============================] - 7s 143ms/step - loss: 2.8591 - regr_loss: 0.9998 - clf_loss: 0.6668 - regr_mae: 0.6511 - clf_accuracy: 0.5874 - val_loss: 2.5088 - val_regr_loss: 0.5878 - val_clf_loss: 0.7318 - val_regr_mae: 0.5051 - val_clf_accuracy: 0.4433
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.8507 - regr_loss: 1.0086 - clf_loss: 0.6559 - regr_mae: 0.6494 - clf_accuracy: 0.5910
# Epoch 00027: val_loss improved from 2.50881 to 2.50415, saving model to models\conv1d_univar\multitask\27.hdf5
# 46/46 [==============================] - 7s 144ms/step - loss: 2.8356 - regr_loss: 0.9954 - clf_loss: 0.6540 - regr_mae: 0.6470 - clf_accuracy: 0.5915 - val_loss: 2.5042 - val_regr_loss: 0.5884 - val_clf_loss: 0.7328 - val_regr_mae: 0.5051 - val_clf_accuracy: 0.4510
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.8341 - regr_loss: 0.9848 - clf_loss: 0.6692 - regr_mae: 0.6495 - clf_accuracy: 0.5972
# Epoch 00028: val_loss improved from 2.50415 to 2.49852, saving model to models\conv1d_univar\multitask\28.hdf5
# 46/46 [==============================] - 7s 149ms/step - loss: 2.8582 - regr_loss: 1.0078 - clf_loss: 0.6705 - regr_mae: 0.6561 - clf_accuracy: 0.5963 - val_loss: 2.4985 - val_regr_loss: 0.5895 - val_clf_loss: 0.7322 - val_regr_mae: 0.5061 - val_clf_accuracy: 0.4459
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.9003 - regr_loss: 1.0403 - clf_loss: 0.6861 - regr_mae: 0.6628 - clf_accuracy: 0.5646
# Epoch 00029: val_loss improved from 2.49852 to 2.49139, saving model to models\conv1d_univar\multitask\29.hdf5
# 46/46 [==============================] - 8s 177ms/step - loss: 2.8891 - regr_loss: 1.0301 - clf_loss: 0.6851 - regr_mae: 0.6620 - clf_accuracy: 0.5656 - val_loss: 2.4914 - val_regr_loss: 0.5882 - val_clf_loss: 0.7324 - val_regr_mae: 0.5049 - val_clf_accuracy: 0.4407
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.8494 - regr_loss: 1.0019 - clf_loss: 0.6781 - regr_mae: 0.6388 - clf_accuracy: 0.5743
# Epoch 00030: val_loss improved from 2.49139 to 2.48724, saving model to models\conv1d_univar\multitask\30.hdf5
# 46/46 [==============================] - 7s 157ms/step - loss: 2.8458 - regr_loss: 0.9992 - clf_loss: 0.6773 - regr_mae: 0.6400 - clf_accuracy: 0.5738 - val_loss: 2.4872 - val_regr_loss: 0.5877 - val_clf_loss: 0.7320 - val_regr_mae: 0.5050 - val_clf_accuracy: 0.4485
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.7908 - regr_loss: 0.9664 - clf_loss: 0.6583 - regr_mae: 0.6405 - clf_accuracy: 0.6014
# Epoch 00031: val_loss improved from 2.48724 to 2.48335, saving model to models\conv1d_univar\multitask\31.hdf5
# 46/46 [==============================] - 7s 156ms/step - loss: 2.7842 - regr_loss: 0.9616 - clf_loss: 0.6565 - regr_mae: 0.6401 - clf_accuracy: 0.6045 - val_loss: 2.4833 - val_regr_loss: 0.5867 - val_clf_loss: 0.7322 - val_regr_mae: 0.5043 - val_clf_accuracy: 0.4407
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.8613 - regr_loss: 1.0257 - clf_loss: 0.6727 - regr_mae: 0.6597 - clf_accuracy: 0.5667
# Epoch 00032: val_loss improved from 2.48335 to 2.47930, saving model to models\conv1d_univar\multitask\32.hdf5
# 46/46 [==============================] - 6s 131ms/step - loss: 2.8462 - regr_loss: 1.0117 - clf_loss: 0.6715 - regr_mae: 0.6564 - clf_accuracy: 0.5690 - val_loss: 2.4793 - val_regr_loss: 0.5864 - val_clf_loss: 0.7315 - val_regr_mae: 0.5041 - val_clf_accuracy: 0.4433

# %%
def plot_multitask_history(hist):
    fig, ax = plt.subplots(2, 2, figsize=(16, 12))
    plotHelpers.plot_train_history(ax[0, 0], hist, 'Total loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[0, 1], hist, 'Accuracy', 'clf_accuracy', 'val_clf_accuracy')
    plotHelpers.plot_train_history(ax[1, 0], hist, 'MSE', 'regr_loss', 'val_regr_loss')
    plotHelpers.plot_train_history(ax[1, 1], hist, 'MAE', 'regr_mae', 'val_regr_mae')
    
plot_multitask_history(multitask_history);

# %% [markdown]
# ### Прогноз

# %%
# загружаем последнюю эпоху с минимальным лоссом
univariate_multitask_conv1d.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret, pred_direction_proba = univariate_multitask_conv1d.predict_generator(test_multi_gen, verbose=1)
# Out:
# 13/13 [==============================] - 0s 25ms/step

# %%
np.set_printoptions(precision=3, suppress=True)

np.column_stack([pred_log_ret, pred_direction_proba])[-10:]
# Out:
# array([[ 0.184,  0.558],
#        [ 0.299,  0.574],
#        [ 0.204,  0.556],
#        [ 0.288,  0.535],
#        [ 0.313,  0.504],
#        [-0.024,  0.382],
#        [-0.043,  0.425],
#        [-0.167,  0.435],
#        [-0.142,  0.375],
#        [-0.131,  0.352]], dtype=float32)

# %% [markdown]
# #### Прогноз задачи регрессии

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret, figsize=(16, 10),
                                  datetime_unit='m', plot_data_slice=slice(1, None))

# %% [markdown]
# #### Прогноз задачи классификации

# %%
true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 0.510734

# %%
true_direction = test_multi_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([210, 178], dtype=int64)),
#  (array([0, 1]), array([195, 193], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.47      0.48       210
#            1       0.42      0.46      0.44       178
#
#     accuracy                           0.46       388
#    macro avg       0.46      0.46      0.46       388
# weighted avg       0.46      0.46      0.46       388

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[ 98, 112],
#        [ 97,  81]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.503, 0.58 ],
#        [0.497, 0.42 ]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# # Выводы
#
# 1.  Модель с 1D свёртками обучается гораздо быстрее модели LSTM
# 2.  Задача классификации не решается удовлетворительно.

# %% [markdown]
# <a href="https://colab.research.google.com/github/rklepov/hse-cs-ml-2018-2019-grad-work/blob/CVX-1yr/CVX/daily1y/08_conv1d_multivar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # *Многомерная модель на 1D свёрточных слоях*
#
# В качестве признаков используются цены, объём торгов и некоторое число индикаторов (всего 18 признаков)

# %%
import os
import glob
import datetime
import pickle

import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from pandas_datareader import data as pdr

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
import tensorflow as tf
# tf.test.is_gpu_available()
tf.__version__
# Out:
# '2.0.0'

# %%
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import (Input, Dense, Convolution1D, MaxPooling1D, Flatten,
                                     ReLU, LeakyReLU, Dropout, BatchNormalization)
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers import Nadam

# %%
from mdp import TimeSeries
from mdp import MarketData
from mdp import MovingWindowFeatures
from mdp import ClassificationGenerator, RegressionGenerator, MultitaskGenerator
from mdp import invert_log_ret

import mdp.utils as utils
import mdp.plotHelpers as plotHelpers

# %%
import importlib

import mdp

importlib.reload(mdp)
importlib.reload(mdp.datasetGenerator)
importlib.reload(mdp.marketData)
importlib.reload(mdp.movingWindowFeatures)
importlib.reload(mdp.timeSeries)
importlib.reload(mdp.plotHelpers)
importlib.reload(mdp.utils);

# %% [markdown]
# # *Параметры*

# %%
INSTRUMENT = 'MSFT' # Microsoft corp
START_FROM = np.datetime64('today') - 7
WINDOW_SIZE = 60
FORECAST_OFFSET=1
BATCH_SIZE = 32
FORCE_TRAIN = True

# %% [markdown]
# # *Исходные данные*
#
# Загрузка данных и вычисление индикаторов.

# %%
instr = MarketData.create_from_alphavantage_intraday(INSTRUMENT, start=START_FROM)

# %%
instr.feature_names
# Out:
# ['o',
#  'h',
#  'l',
#  'c',
#  'v',
#  'ema14',
#  'ema30',
#  'macd',
#  'macd_signal',
#  'rsi14',
#  'bband20_upper',
#  'bband20_middle',
#  'bband20_lower',
#  'willr14',
#  'stochk',
#  'stochd',
#  'adline',
#  'adosc']

# %% [markdown]
# Здесь не будем делить отдельно на тест и валидацию, поскольку данных у нас только 5 дней.

# %%
dates_unique = np.unique(instr.timestamps.astype('datetime64[D]'))

START_FROM = dates_unique[0]
VAL_TEST_SPLIT = dates_unique[-1]

START_FROM, VAL_TEST_SPLIT
# Out:
# (numpy.datetime64('2020-03-23'), numpy.datetime64('2020-03-27'))

# %% [markdown]
# ## Целевая переменная

# %% [markdown]
# Цена закрытия.

# %%
orig_target = instr.c

# %%
def plot_transformed_series(instrument, series, orig_display_name, transformed_display_name):
    plotHelpers.plot_transformed_timeseries(
        instrument.instrument,
        series,
        title_orig = orig_display_name,
        xlabel_orig = 'Date',
        ylabel_orig = orig_display_name,
        title_transformed = transformed_display_name,
        xlabel_transformed = 'Date',
        ylabel_transformed = transformed_display_name
    )

# %% [markdown]
# Переходим к логарифмической доходности.

# %%
transformed_target = instr.c.transform(transforms={'ratios' : {}, 'ln' : {}})

# %%
plotHelpers.plot_transformed_timeseries_unit(instr,
                                             transformed_target,
                                             'Price, USD', 'Log return',
                                             datetime_unit='m', rotation=45)

# %% [markdown]
# ## Трансформация признаков
#
# Приведение временных рядов к стационарности.

# %%
def make_feature_selector():
    price_transformer = lambda: {'ratios': {}, 'ln': {}}
    diff_transformer = lambda o: {'diffs': {'order': o}}
    identity_transformer = lambda: {}
    feature_transformations = {
        'o': price_transformer(),
        'h': price_transformer(),
        'l': price_transformer(),
        'c': price_transformer(),
        'v': diff_transformer(1),
        'ema14': diff_transformer(1),
        'ema30': diff_transformer(1),
        'macd': identity_transformer(),
        'macd_signal': identity_transformer(),
        'rsi14': identity_transformer(),
        'bband20_upper': diff_transformer(1),
        'bband20_middle': diff_transformer(1),
        'bband20_lower': diff_transformer(1),
        'willr14': identity_transformer(),
        'stochd': identity_transformer(),
        'stochk': identity_transformer(),
        'adline': diff_transformer(1),
        'adosc': identity_transformer()
    }
    return feature_transformations

# %%
instr_transformed = instr.select_transform(make_feature_selector())

# %%
transformed_target = instr_transformed.c

# %% [markdown]
# ## Обучающая, валидационная и тестовая выборки

# %%
instr_train, instr_test = instr_transformed.train_test_split(VAL_TEST_SPLIT, window_size=WINDOW_SIZE,
                                                             scaler=StandardScaler)
#                                                              scaler=MinMaxScaler,
#                                                              scaler_kwargs={'feature_range': (-1, 1)})

# instr_val, instr_test = instr_val_test.train_test_split(TEST_SPLIT, window_size=WINDOW_SIZE, scaler=None)

len(instr_train), len(instr_test)
# Out:
# (1524, 448)

# %% [markdown]
# Все отмасштабированные признаки на одном графике (для валидационного датасета):

# %%
plotHelpers.plot_all_features(instr_test)

# %% [markdown]
# ## Признаки - скользящие окна

# %%
train_mwf = MovingWindowFeatures.create(instr_train.c, [instr_train], instr_train.feature_names, window_size=WINDOW_SIZE)
# val_mwf = MovingWindowFeatures.create(instr_val.c, [instr_val], instr_val.feature_names, window_size=WINDOW_SIZE)
test_mwf = MovingWindowFeatures.create(instr_test.c, [instr_test], instr_test.feature_names, window_size=WINDOW_SIZE)

len(instr_train), len(train_mwf), train_mwf.features.shape
# Out:
# (1524, 1464, (1464, 60, 18))

# %% [markdown]
# Проверка, что скользящие окна соответствуют исходным данным.
#
# Возьмём произвольный признак и произвольное окно (строка #**41**). Проверим, что данные в точности совпадают:

# %%
def check_data(md, mwf, row):
    col = np.random.randint(len(mwf.feature_names))
    feature = mwf.feature_names[col]
    check = (getattr(md, feature).data[row:row + mwf.window_size] == mwf.features[row, :, col]).all()
    assert check
    return feature, check

check_data(instr_train, train_mwf, 41)
# Out:
# ('bband20_middle', True)

# %% [markdown]
# # *Модели*

# %% [markdown]
# Модель с двумя 1D свёрточными слоями.

# %%
def build_conv1d_layers(input_shape, filters=(16, 8), kernel_size=5, pool_size=2):
    # формат входа: наша матрица (окно; признак)
    inp = Input(input_shape, name='input')

    # стекаем два уровня Conv1D
    conv1d = Convolution1D(filters=filters[0],
                           kernel_size=kernel_size,
                           padding='same',
                           bias_initializer='he_uniform',
                           bias_regularizer=L1L2(0.01, 0.02),
                           kernel_regularizer=L1L2(0.01, 0.02)
                          )(inp)
    conv1d = BatchNormalization()(conv1d)
    conv1d = LeakyReLU()(conv1d)
    conv1d = Dropout(0.25)(conv1d)

    conv1d = Convolution1D(filters=filters[1],
                           kernel_size=kernel_size,
                           padding='same',
                           bias_initializer='he_uniform',
                           bias_regularizer=L1L2(0.01, 0.02),
                           kernel_regularizer=L1L2(0.01, 0.02)
                          )(conv1d)
    conv1d = BatchNormalization()(conv1d)
    conv1d = LeakyReLU()(conv1d)
    conv1d = Dropout(0.25)(conv1d)
    
    conv1d = MaxPooling1D(pool_size=pool_size)(conv1d)
    
    conv1d = Flatten()(conv1d)
    
    return inp, conv1d

# %% [markdown]
# #### Пути:

# %%
model_path_root = 'models'
model_type_name = 'conv1d_multivar'

def make_model_save_dir(path_root, type_name, class_name):
    save_dir = os.path.join(path_root, type_name, class_name)
    os.makedirs(save_dir, exist_ok=True)
    return save_dir

# %% [markdown]
# #### Общие коллбэки:

# %%
# уменьшение learning rate в случае, если loss не изменяется
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001, verbose=1)

# уменьшение learning rate в 2 раза каждую 5-ю эпоху
def lr_decay(e, lr):
    return lr * (1 - 0.5 * (0 == (e + 1) % 5))

lr_scheduler = LearningRateScheduler(schedule=lr_decay, verbose=1)

# %% [markdown]
# ## Задача регрессии
#
# Непосредственное прогнозирование цены следующего периода.

# %%
train_regr_gen = RegressionGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_regr_gen = RegressionGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_regr_gen = RegressionGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# Следующие числа соответствуют значению параметра `steps_per_epoch` метода [`fit_generator`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit_generator "tf.keras.layers.SimpleRNN &nbsp;|&nbsp; TensorFlow Core r2.0") - то есть это число батчей, которые генератор выдаст за одну эпоху обучения (если класс генератора поддерживает метод `len()`, то данный параметр можно не указывать).

# %%
len(train_regr_gen), (test_regr_gen)
# Out:
# (46, <mdp.datasetGenerator.RegressionGenerator at 0x17b7429c788>)

# %% [markdown]
# Один сэмпл данных представляет собой матрицу размером *(длина окна; число признаков)*

# %%
train_regr_gen.input_shape
# Out:
# (60, 18)

# %% [markdown]
# ### Модель для задачи регрессии

# %%
model_class_name = 'regression'

# %%
def build_regression_model(input_shape):
    inp, conv1d = build_conv1d_layers(input_shape, filters=(32, 16))

    regr = Dense(32)(conv1d)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.25)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    return Model(inputs=[inp], outputs=[regr])

# %%
multivariate_regression_conv1d = build_regression_model(train_regr_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:
# [`Nadam`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Nadam) (*Adam with Nestrov momentum*).

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Функция потерь:
#
# В качестве функции потерь будем использовать [MSE](https://www.tensorflow.org/api_docs/python/tf/keras/losses/MSE) (чтобы штрафовать за большие отклонения). Xотя хорошая функция потерь в контексте темы данной задачи - это [вопрос сложный](https://github.com/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Chapter5_LossFunctions/Ch5_LossFunctions_PyMC3.ipynb). В частности, здесь нам, очевидно, помимо абсолютного значения отклонения также важен его знак.

# %%
multivariate_regression_conv1d.compile(optimizer=optimizer,
                                       loss={'regr': 'mse'},
                                       metrics={'regr': 'mae'})

multivariate_regression_conv1d.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 60, 18)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 60, 32)            2912
# _________________________________________________________________
# batch_normalization (BatchNo (None, 60, 32)            128
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 60, 32)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 60, 32)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 60, 16)            2576
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 60, 16)            64
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 60, 16)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 60, 16)            0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 30, 16)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 480)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                15392
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32)                128
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 32)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# regr (Dense)                 (None, 1)                 33
# =================================================================
# Total params: 21,233
# Trainable params: 21,073
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# #### Обучение:

# %%
regr_history = utils.train_model(multivariate_regression_conv1d,
                                 model_save_dir, train_regr_gen, test_regr_gen,
                                 callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                 force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 45/46 [============================>.] - ETA: 0s - loss: 7.2794 - mae: 0.9755
# Epoch 00001: val_loss improved from inf to 5.86982, saving model to models\conv1d_multivar\regression\01.hdf5
# 46/46 [==============================] - 9s 185ms/step - loss: 7.2666 - mae: 0.9758 - val_loss: 5.8698 - val_mae: 0.5834
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 45/46 [============================>.] - ETA: 0s - loss: 6.4800 - mae: 0.8204
# Epoch 00002: val_loss improved from 5.86982 to 5.42137, saving model to models\conv1d_multivar\regression\02.hdf5
# 46/46 [==============================] - 5s 109ms/step - loss: 6.4582 - mae: 0.8167 - val_loss: 5.4214 - val_mae: 0.5041
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 45/46 [============================>.] - ETA: 0s - loss: 5.9792 - mae: 0.7630
# Epoch 00003: val_loss improved from 5.42137 to 5.06233, saving model to models\conv1d_multivar\regression\03.hdf5
# 46/46 [==============================] - 6s 138ms/step - loss: 5.9589 - mae: 0.7595 - val_loss: 5.0623 - val_mae: 0.4895
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 45/46 [============================>.] - ETA: 0s - loss: 5.6960 - mae: 0.7827
# Epoch 00004: val_loss improved from 5.06233 to 4.73704, saving model to models\conv1d_multivar\regression\04.hdf5
# 46/46 [==============================] - 6s 124ms/step - loss: 5.6727 - mae: 0.7792 - val_loss: 4.7370 - val_mae: 0.4931
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 45/46 [============================>.] - ETA: 0s - loss: 5.1993 - mae: 0.7028
# Epoch 00005: val_loss improved from 4.73704 to 4.52333, saving model to models\conv1d_multivar\regression\05.hdf5
# 46/46 [==============================] - 8s 183ms/step - loss: 5.1916 - mae: 0.7038 - val_loss: 4.5233 - val_mae: 0.4781
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 45/46 [============================>.] - ETA: 0s - loss: 5.0553 - mae: 0.7332
# Epoch 00006: val_loss improved from 4.52333 to 4.32476, saving model to models\conv1d_multivar\regression\06.hdf5
# 46/46 [==============================] - 6s 127ms/step - loss: 5.0393 - mae: 0.7312 - val_loss: 4.3248 - val_mae: 0.4801
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 45/46 [============================>.] - ETA: 0s - loss: 4.7797 - mae: 0.6912
# Epoch 00007: val_loss improved from 4.32476 to 4.13259, saving model to models\conv1d_multivar\regression\07.hdf5
# 46/46 [==============================] - 12s 254ms/step - loss: 4.7714 - mae: 0.6924 - val_loss: 4.1326 - val_mae: 0.4833
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 45/46 [============================>.] - ETA: 0s - loss: 4.6018 - mae: 0.6849
# Epoch 00008: val_loss improved from 4.13259 to 3.93531, saving model to models\conv1d_multivar\regression\08.hdf5
# 46/46 [==============================] - 7s 148ms/step - loss: 4.5838 - mae: 0.6812 - val_loss: 3.9353 - val_mae: 0.4864
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 45/46 [============================>.] - ETA: 0s - loss: 4.3143 - mae: 0.6801
# Epoch 00009: val_loss improved from 3.93531 to 3.73032, saving model to models\conv1d_multivar\regression\09.hdf5
# 46/46 [==============================] - 7s 153ms/step - loss: 4.3069 - mae: 0.6807 - val_loss: 3.7303 - val_mae: 0.4839
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 45/46 [============================>.] - ETA: 0s - loss: 4.2076 - mae: 0.6815
# Epoch 00010: val_loss improved from 3.73032 to 3.63143, saving model to models\conv1d_multivar\regression\10.hdf5
# 46/46 [==============================] - 6s 123ms/step - loss: 4.1953 - mae: 0.6798 - val_loss: 3.6314 - val_mae: 0.4833
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 45/46 [============================>.] - ETA: 0s - loss: 4.0765 - mae: 0.6739
# Epoch 00011: val_loss improved from 3.63143 to 3.54913, saving model to models\conv1d_multivar\regression\11.hdf5
# 46/46 [==============================] - 6s 129ms/step - loss: 4.0719 - mae: 0.6762 - val_loss: 3.5491 - val_mae: 0.4892
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.9719 - mae: 0.6663
# Epoch 00012: val_loss improved from 3.54913 to 3.44977, saving model to models\conv1d_multivar\regression\12.hdf5
# 46/46 [==============================] - 7s 162ms/step - loss: 3.9686 - mae: 0.6679 - val_loss: 3.4498 - val_mae: 0.4890
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.9110 - mae: 0.6741
# Epoch 00013: val_loss improved from 3.44977 to 3.35431, saving model to models\conv1d_multivar\regression\13.hdf5
# 46/46 [==============================] - 8s 176ms/step - loss: 3.8987 - mae: 0.6735 - val_loss: 3.3543 - val_mae: 0.4891
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.7407 - mae: 0.6708
# Epoch 00014: val_loss improved from 3.35431 to 3.26272, saving model to models\conv1d_multivar\regression\14.hdf5
# 46/46 [==============================] - 7s 157ms/step - loss: 3.7329 - mae: 0.6704 - val_loss: 3.2627 - val_mae: 0.4917
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.6609 - mae: 0.6558
# Epoch 00015: val_loss improved from 3.26272 to 3.21399, saving model to models\conv1d_multivar\regression\15.hdf5
# 46/46 [==============================] - 7s 149ms/step - loss: 3.6440 - mae: 0.6515 - val_loss: 3.2140 - val_mae: 0.4929
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.6641 - mae: 0.6750
# Epoch 00016: val_loss improved from 3.21399 to 3.16188, saving model to models\conv1d_multivar\regression\16.hdf5
# 46/46 [==============================] - 7s 145ms/step - loss: 3.6438 - mae: 0.6693 - val_loss: 3.1619 - val_mae: 0.4918
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.5653 - mae: 0.6568
# Epoch 00017: val_loss improved from 3.16188 to 3.12097, saving model to models\conv1d_multivar\regression\17.hdf5
# 46/46 [==============================] - 8s 166ms/step - loss: 3.5507 - mae: 0.6543 - val_loss: 3.1210 - val_mae: 0.4941
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.4253 - mae: 0.6362
# Epoch 00018: val_loss improved from 3.12097 to 3.07796, saving model to models\conv1d_multivar\regression\18.hdf5
# 46/46 [==============================] - 6s 128ms/step - loss: 3.4860 - mae: 0.6430 - val_loss: 3.0780 - val_mae: 0.4964
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.4486 - mae: 0.6454
# Epoch 00019: val_loss improved from 3.07796 to 3.03059, saving model to models\conv1d_multivar\regression\19.hdf5
# 46/46 [==============================] - 7s 149ms/step - loss: 3.4396 - mae: 0.6456 - val_loss: 3.0306 - val_mae: 0.4971
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.3755 - mae: 0.6453
# Epoch 00020: val_loss improved from 3.03059 to 3.00373, saving model to models\conv1d_multivar\regression\20.hdf5
# 46/46 [==============================] - 6s 140ms/step - loss: 3.3720 - mae: 0.6459 - val_loss: 3.0037 - val_mae: 0.4968
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.4404 - mae: 0.6658
# Epoch 00021: val_loss improved from 3.00373 to 2.97289, saving model to models\conv1d_multivar\regression\21.hdf5
# 46/46 [==============================] - 7s 142ms/step - loss: 3.4344 - mae: 0.6660 - val_loss: 2.9729 - val_mae: 0.4955
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.3321 - mae: 0.6473
# Epoch 00022: val_loss improved from 2.97289 to 2.95141, saving model to models\conv1d_multivar\regression\22.hdf5
# 46/46 [==============================] - 6s 136ms/step - loss: 3.3232 - mae: 0.6458 - val_loss: 2.9514 - val_mae: 0.4966
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.3216 - mae: 0.6584
# Epoch 00023: val_loss improved from 2.95141 to 2.93202, saving model to models\conv1d_multivar\regression\23.hdf5
# 46/46 [==============================] - 6s 135ms/step - loss: 3.3218 - mae: 0.6602 - val_loss: 2.9320 - val_mae: 0.4978
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.2972 - mae: 0.6483
# Epoch 00024: val_loss improved from 2.93202 to 2.90871, saving model to models\conv1d_multivar\regression\24.hdf5
# 46/46 [==============================] - 6s 127ms/step - loss: 3.3007 - mae: 0.6491 - val_loss: 2.9087 - val_mae: 0.4971
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.3184 - mae: 0.6628
# Epoch 00025: val_loss improved from 2.90871 to 2.89607, saving model to models\conv1d_multivar\regression\25.hdf5
# 46/46 [==============================] - 6s 133ms/step - loss: 3.3209 - mae: 0.6659 - val_loss: 2.8961 - val_mae: 0.4970
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.3078 - mae: 0.6512
# Epoch 00026: val_loss improved from 2.89607 to 2.88702, saving model to models\conv1d_multivar\regression\26.hdf5
# 46/46 [==============================] - 9s 198ms/step - loss: 3.2907 - mae: 0.6473 - val_loss: 2.8870 - val_mae: 0.4983
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.2695 - mae: 0.6543
# Epoch 00027: val_loss improved from 2.88702 to 2.87549, saving model to models\conv1d_multivar\regression\27.hdf5
# 46/46 [==============================] - 8s 169ms/step - loss: 3.2734 - mae: 0.6558 - val_loss: 2.8755 - val_mae: 0.4983
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.2010 - mae: 0.6390
# Epoch 00028: val_loss improved from 2.87549 to 2.86149, saving model to models\conv1d_multivar\regression\28.hdf5
# 46/46 [==============================] - 6s 141ms/step - loss: 3.2074 - mae: 0.6421 - val_loss: 2.8615 - val_mae: 0.4977
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.2267 - mae: 0.6548
# Epoch 00029: val_loss improved from 2.86149 to 2.85018, saving model to models\conv1d_multivar\regression\29.hdf5
# 46/46 [==============================] - 7s 150ms/step - loss: 3.2159 - mae: 0.6538 - val_loss: 2.8502 - val_mae: 0.4981
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.2155 - mae: 0.6418
# Epoch 00030: val_loss improved from 2.85018 to 2.84513, saving model to models\conv1d_multivar\regression\30.hdf5
# 46/46 [==============================] - 7s 157ms/step - loss: 3.2072 - mae: 0.6408 - val_loss: 2.8451 - val_mae: 0.4986
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.0048 - mae: 0.6401
# Epoch 00031: val_loss improved from 2.84513 to 2.83689, saving model to models\conv1d_multivar\regression\31.hdf5
# 46/46 [==============================] - 8s 182ms/step - loss: 3.2543 - mae: 0.6494 - val_loss: 2.8369 - val_mae: 0.4977
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.1665 - mae: 0.6393
# Epoch 00032: val_loss improved from 2.83689 to 2.83155, saving model to models\conv1d_multivar\regression\32.hdf5
# 46/46 [==============================] - 7s 162ms/step - loss: 3.1643 - mae: 0.6400 - val_loss: 2.8315 - val_mae: 0.4982

# %%
def plot_regr_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'MSE', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'MAE', 'mae', 'val_mae')
    
plot_regr_history(regr_history);

# %% [markdown]
# ### Прогноз задачи регрессии

# %%
# загружаем последнюю эпоху с минимальным лоссом
multivariate_regression_conv1d.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret_test = multivariate_regression_conv1d.predict_generator(test_regr_gen, verbose=1)
# Out:
# 13/13 [==============================] - 0s 26ms/step

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret_test, figsize=(16, 10),
                                  datetime_unit='m', xlabel='Time', plot_data_slice=slice(1, None))

# %% [markdown]
# ## Задача классификации
#
# Прогнозируем направление изменения цены по сравнению с предыдущим периодом (**0** - снижение, **1** - рост).

# %%
model_class_name = 'classification'

# %%
train_clf_gen = ClassificationGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_clf_gen = ClassificationGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_clf_gen = ClassificationGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_classification_model(input_shape):
    inp, conv1d = build_conv1d_layers(input_shape, filters=(32, 16))

    clf = Dense(32)(conv1d)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.25)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)

    return Model(inputs=[inp], outputs=[clf])

# %%
multivariate_classification_conv1d = build_classification_model(test_clf_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
multivariate_classification_conv1d.compile(optimizer=optimizer,
                                           loss={'clf': 'binary_crossentropy'},
                                           metrics={'clf': 'accuracy'})

multivariate_classification_conv1d.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 60, 18)]          0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 60, 32)            2912
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 60, 32)            128
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 60, 32)            0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 60, 32)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 60, 16)            2576
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 60, 16)            64
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 60, 16)            0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 60, 16)            0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 30, 16)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 480)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                15392
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32)                128
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 32)                0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 32)                0
# _________________________________________________________________
# clf (Dense)                  (None, 1)                 33
# =================================================================
# Total params: 21,233
# Trainable params: 21,073
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
clf_history = utils.train_model(multivariate_classification_conv1d,
                                model_save_dir, train_clf_gen, test_clf_gen,
                                callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 45/46 [============================>.] - ETA: 0s - loss: 5.4877 - accuracy: 0.5097
# Epoch 00001: val_loss improved from inf to 4.69086, saving model to models\conv1d_multivar\classification\01.hdf5
# 46/46 [==============================] - 8s 181ms/step - loss: 5.4694 - accuracy: 0.5137 - val_loss: 4.6909 - val_accuracy: 0.5567
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 45/46 [============================>.] - ETA: 0s - loss: 4.1294 - accuracy: 0.5382
# Epoch 00002: val_loss improved from 4.69086 to 3.51103, saving model to models\conv1d_multivar\classification\02.hdf5
# 46/46 [==============================] - 7s 153ms/step - loss: 4.1160 - accuracy: 0.5383 - val_loss: 3.5110 - val_accuracy: 0.5438
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.0570 - accuracy: 0.5444
# Epoch 00003: val_loss improved from 3.51103 to 2.58642, saving model to models\conv1d_multivar\classification\03.hdf5
# 46/46 [==============================] - 7s 159ms/step - loss: 3.0478 - accuracy: 0.5430 - val_loss: 2.5864 - val_accuracy: 0.5026
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 45/46 [============================>.] - ETA: 0s - loss: 2.2548 - accuracy: 0.5479
# Epoch 00004: val_loss improved from 2.58642 to 1.93021, saving model to models\conv1d_multivar\classification\04.hdf5
# 46/46 [==============================] - 7s 161ms/step - loss: 2.2460 - accuracy: 0.5499 - val_loss: 1.9302 - val_accuracy: 0.4510
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 45/46 [============================>.] - ETA: 0s - loss: 1.7801 - accuracy: 0.5632
# Epoch 00005: val_loss improved from 1.93021 to 1.66326, saving model to models\conv1d_multivar\classification\05.hdf5
# 46/46 [==============================] - 7s 161ms/step - loss: 1.7754 - accuracy: 0.5642 - val_loss: 1.6633 - val_accuracy: 0.4639
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 45/46 [============================>.] - ETA: 0s - loss: 1.5552 - accuracy: 0.5743
# Epoch 00006: val_loss improved from 1.66326 to 1.47322, saving model to models\conv1d_multivar\classification\06.hdf5
# 46/46 [==============================] - 6s 136ms/step - loss: 1.5535 - accuracy: 0.5731 - val_loss: 1.4732 - val_accuracy: 0.4691
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 45/46 [============================>.] - ETA: 0s - loss: 1.3799 - accuracy: 0.5708
# Epoch 00007: val_loss improved from 1.47322 to 1.31867, saving model to models\conv1d_multivar\classification\07.hdf5
# 46/46 [==============================] - 8s 166ms/step - loss: 1.3792 - accuracy: 0.5704 - val_loss: 1.3187 - val_accuracy: 0.4639
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 45/46 [============================>.] - ETA: 0s - loss: 1.2545 - accuracy: 0.5722
# Epoch 00008: val_loss improved from 1.31867 to 1.20688, saving model to models\conv1d_multivar\classification\08.hdf5
# 46/46 [==============================] - 7s 149ms/step - loss: 1.2517 - accuracy: 0.5745 - val_loss: 1.2069 - val_accuracy: 0.4588
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 45/46 [============================>.] - ETA: 0s - loss: 1.1408 - accuracy: 0.5750
# Epoch 00009: val_loss improved from 1.20688 to 1.11755, saving model to models\conv1d_multivar\classification\09.hdf5
# 46/46 [==============================] - 7s 163ms/step - loss: 1.1398 - accuracy: 0.5745 - val_loss: 1.1175 - val_accuracy: 0.4510
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 45/46 [============================>.] - ETA: 0s - loss: 1.0545 - accuracy: 0.5924
# Epoch 00010: val_loss improved from 1.11755 to 1.06157, saving model to models\conv1d_multivar\classification\10.hdf5
# 46/46 [==============================] - 6s 129ms/step - loss: 1.0528 - accuracy: 0.5915 - val_loss: 1.0616 - val_accuracy: 0.4510
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 45/46 [============================>.] - ETA: 0s - loss: 1.0068 - accuracy: 0.5868
# Epoch 00011: val_loss improved from 1.06157 to 1.02523, saving model to models\conv1d_multivar\classification\11.hdf5
# 46/46 [==============================] - 7s 153ms/step - loss: 1.0066 - accuracy: 0.5867 - val_loss: 1.0252 - val_accuracy: 0.4510
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.9822 - accuracy: 0.5549
# Epoch 00012: val_loss improved from 1.02523 to 0.99247, saving model to models\conv1d_multivar\classification\12.hdf5
# 46/46 [==============================] - 6s 131ms/step - loss: 0.9823 - accuracy: 0.5533 - val_loss: 0.9925 - val_accuracy: 0.4613
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.9579 - accuracy: 0.5715
# Epoch 00013: val_loss improved from 0.99247 to 0.97656, saving model to models\conv1d_multivar\classification\13.hdf5
# 46/46 [==============================] - 7s 161ms/step - loss: 0.9557 - accuracy: 0.5745 - val_loss: 0.9766 - val_accuracy: 0.5000
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.9258 - accuracy: 0.5993
# Epoch 00014: val_loss improved from 0.97656 to 0.95278, saving model to models\conv1d_multivar\classification\14.hdf5
# 46/46 [==============================] - 7s 154ms/step - loss: 0.9258 - accuracy: 0.5984 - val_loss: 0.9528 - val_accuracy: 0.4716
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.8881 - accuracy: 0.6069
# Epoch 00015: val_loss improved from 0.95278 to 0.93354, saving model to models\conv1d_multivar\classification\15.hdf5
# 46/46 [==============================] - 7s 161ms/step - loss: 0.8885 - accuracy: 0.6072 - val_loss: 0.9335 - val_accuracy: 0.4716
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.8727 - accuracy: 0.5979
# Epoch 00016: val_loss improved from 0.93354 to 0.92066, saving model to models\conv1d_multivar\classification\16.hdf5
# 46/46 [==============================] - 8s 171ms/step - loss: 0.8732 - accuracy: 0.5997 - val_loss: 0.9207 - val_accuracy: 0.4820
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.8568 - accuracy: 0.6021
# Epoch 00017: val_loss improved from 0.92066 to 0.91011, saving model to models\conv1d_multivar\classification\17.hdf5
# 46/46 [==============================] - 8s 166ms/step - loss: 0.8578 - accuracy: 0.6025 - val_loss: 0.9101 - val_accuracy: 0.4794
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.8547 - accuracy: 0.6083
# Epoch 00018: val_loss improved from 0.91011 to 0.90810, saving model to models\conv1d_multivar\classification\18.hdf5
# 46/46 [==============================] - 7s 152ms/step - loss: 0.8549 - accuracy: 0.6086 - val_loss: 0.9081 - val_accuracy: 0.4691
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.8453 - accuracy: 0.6090
# Epoch 00019: val_loss improved from 0.90810 to 0.89909, saving model to models\conv1d_multivar\classification\19.hdf5
# 46/46 [==============================] - 7s 159ms/step - loss: 0.8475 - accuracy: 0.6066 - val_loss: 0.8991 - val_accuracy: 0.4691
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.8214 - accuracy: 0.6257
# Epoch 00020: val_loss improved from 0.89909 to 0.89092, saving model to models\conv1d_multivar\classification\20.hdf5
# 46/46 [==============================] - 7s 145ms/step - loss: 0.8222 - accuracy: 0.6257 - val_loss: 0.8909 - val_accuracy: 0.4742
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.8181 - accuracy: 0.6167
# Epoch 00021: val_loss improved from 0.89092 to 0.88446, saving model to models\conv1d_multivar\classification\21.hdf5
# 46/46 [==============================] - 7s 153ms/step - loss: 0.8199 - accuracy: 0.6134 - val_loss: 0.8845 - val_accuracy: 0.4820
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.8004 - accuracy: 0.6319
# Epoch 00022: val_loss improved from 0.88446 to 0.88142, saving model to models\conv1d_multivar\classification\22.hdf5
# 46/46 [==============================] - 7s 152ms/step - loss: 0.7987 - accuracy: 0.6332 - val_loss: 0.8814 - val_accuracy: 0.4691
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.8017 - accuracy: 0.6153
# Epoch 00023: val_loss improved from 0.88142 to 0.87877, saving model to models\conv1d_multivar\classification\23.hdf5
# 46/46 [==============================] - 7s 151ms/step - loss: 0.8023 - accuracy: 0.6148 - val_loss: 0.8788 - val_accuracy: 0.4820
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.8097 - accuracy: 0.6083
# Epoch 00024: val_loss improved from 0.87877 to 0.87847, saving model to models\conv1d_multivar\classification\24.hdf5
# 46/46 [==============================] - 7s 153ms/step - loss: 0.8101 - accuracy: 0.6086 - val_loss: 0.8785 - val_accuracy: 0.5103
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.7883 - accuracy: 0.6368
# Epoch 00025: val_loss improved from 0.87847 to 0.87627, saving model to models\conv1d_multivar\classification\25.hdf5
# 46/46 [==============================] - 7s 155ms/step - loss: 0.7877 - accuracy: 0.6366 - val_loss: 0.8763 - val_accuracy: 0.4794
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.7913 - accuracy: 0.6285
# Epoch 00026: val_loss improved from 0.87627 to 0.87526, saving model to models\conv1d_multivar\classification\26.hdf5
# 46/46 [==============================] - 7s 155ms/step - loss: 0.7897 - accuracy: 0.6291 - val_loss: 0.8753 - val_accuracy: 0.4871
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.7901 - accuracy: 0.6076
# Epoch 00027: val_loss improved from 0.87526 to 0.87334, saving model to models\conv1d_multivar\classification\27.hdf5
# 46/46 [==============================] - 7s 152ms/step - loss: 0.7898 - accuracy: 0.6066 - val_loss: 0.8733 - val_accuracy: 0.4897
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.7845 - accuracy: 0.6264
# Epoch 00028: val_loss improved from 0.87334 to 0.87310, saving model to models\conv1d_multivar\classification\28.hdf5
# 46/46 [==============================] - 7s 148ms/step - loss: 0.7836 - accuracy: 0.6284 - val_loss: 0.8731 - val_accuracy: 0.4845
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.7759 - accuracy: 0.6340
# Epoch 00029: val_loss improved from 0.87310 to 0.87194, saving model to models\conv1d_multivar\classification\29.hdf5
# 46/46 [==============================] - 7s 161ms/step - loss: 0.7743 - accuracy: 0.6359 - val_loss: 0.8719 - val_accuracy: 0.4639
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.7767 - accuracy: 0.6431
# Epoch 00030: val_loss improved from 0.87194 to 0.87028, saving model to models\conv1d_multivar\classification\30.hdf5
# 46/46 [==============================] - 7s 152ms/step - loss: 0.7761 - accuracy: 0.6407 - val_loss: 0.8703 - val_accuracy: 0.4691
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.7710 - accuracy: 0.6486
# Epoch 00031: val_loss improved from 0.87028 to 0.86973, saving model to models\conv1d_multivar\classification\31.hdf5
# 46/46 [==============================] - 7s 153ms/step - loss: 0.7705 - accuracy: 0.6496 - val_loss: 0.8697 - val_accuracy: 0.4716
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 45/46 [============================>.] - ETA: 0s - loss: 0.7724 - accuracy: 0.6410
# Epoch 00032: val_loss improved from 0.86973 to 0.86877, saving model to models\conv1d_multivar\classification\32.hdf5
# 46/46 [==============================] - 7s 149ms/step - loss: 0.7715 - accuracy: 0.6414 - val_loss: 0.8688 - val_accuracy: 0.4871

# %%
def plot_clf_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'Loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'Accuracy', 'accuracy', 'val_accuracy')
    
plot_clf_history(clf_history);

# %% [markdown]
# ### Прогноз задачи классификации

# %%
# загружаем последнюю эпоху с минимальным лоссом
multivariate_classification_conv1d.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %%
pred_direction_proba = multivariate_classification_conv1d.predict_generator(test_clf_gen, verbose=1)

true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 13/13 [==============================] - 0s 21ms/step
# 0.5052476

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([210, 178], dtype=int64)),
#  (array([0, 1]), array([166, 222], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.43      0.48       210
#            1       0.46      0.57      0.51       178
#
#     accuracy                           0.49       388
#    macro avg       0.50      0.50      0.49       388
# weighted avg       0.50      0.49      0.49       388

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[ 90, 120],
#        [ 76, 102]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.54216867, 0.54054054],
#        [0.45783133, 0.45945946]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# ## Многозадачная модель: одновременно регрессия и классификация

# %%
model_class_name = 'multitask'

# %%
train_multi_gen = MultitaskGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_multi_gen = MultitaskGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_multi_gen = MultitaskGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_multitask_model(input_shape):
    inp, conv1d = build_conv1d_layers(input_shape, filters=(32, 16))

    # первый выход: задача регрссии
    regr = Dense(32)(conv1d)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.25)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    # второй выход: задача классификации
    clf = Dense(32)(conv1d)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.25)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)
    
    return Model(inputs=[inp], outputs=[regr, clf])

# %%
multivariate_multitask_conv1d = build_multitask_model(train_multi_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
multivariate_multitask_conv1d.compile(optimizer=optimizer,
                                      loss={'regr': 'mse', 'clf': 'binary_crossentropy'},
                                      loss_weights={'regr': 1., 'clf': 1.},
                                      metrics={'regr': 'mae', 'clf' : 'accuracy'})

multivariate_multitask_conv1d.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 60, 18)]     0
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 60, 32)       2912        input[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 60, 32)       128         conv1d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 60, 32)       0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 60, 32)       0           leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 60, 16)       2576        dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 60, 16)       64          conv1d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 60, 16)       0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 60, 16)       0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 30, 16)       0           dropout_7[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 480)          0           max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 32)           15392       flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 32)           15392       flatten_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32)           128         dense_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32)           128         dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 32)           0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 32)           0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 32)           0           leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 32)           0           leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# regr (Dense)                    (None, 1)            33          dropout_8[0][0]
# __________________________________________________________________________________________________
# clf (Dense)                     (None, 1)            33          dropout_9[0][0]
# ==================================================================================================
# Total params: 36,786
# Trainable params: 36,562
# Non-trainable params: 224
# __________________________________________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
multitask_history = utils.train_model(multivariate_multitask_conv1d,
                                      model_save_dir, train_multi_gen, test_multi_gen,
                                      callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                      force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 45/46 [============================>.] - ETA: 0s - loss: 7.6664 - regr_loss: 1.6589 - clf_loss: 0.7990 - regr_mae: 0.8817 - clf_accuracy: 0.5049
# Epoch 00001: val_loss improved from inf to 6.36657, saving model to models\conv1d_multivar\multitask\01.hdf5
# 46/46 [==============================] - 9s 193ms/step - loss: 7.6407 - regr_loss: 1.6361 - clf_loss: 0.8000 - regr_mae: 0.8774 - clf_accuracy: 0.5061 - val_loss: 6.3666 - val_regr_loss: 0.6428 - val_clf_loss: 0.7080 - val_regr_mae: 0.5215 - val_clf_accuracy: 0.5103
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 45/46 [============================>.] - ETA: 0s - loss: 7.0182 - regr_loss: 1.4329 - clf_loss: 0.7666 - regr_mae: 0.7923 - clf_accuracy: 0.5236
# Epoch 00002: val_loss improved from 6.36657 to 5.92476, saving model to models\conv1d_multivar\multitask\02.hdf5
# 46/46 [==============================] - 9s 192ms/step - loss: 6.9893 - regr_loss: 1.4100 - clf_loss: 0.7650 - regr_mae: 0.7873 - clf_accuracy: 0.5246 - val_loss: 5.9248 - val_regr_loss: 0.6196 - val_clf_loss: 0.7074 - val_regr_mae: 0.5058 - val_clf_accuracy: 0.5077
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 45/46 [============================>.] - ETA: 0s - loss: 6.3430 - regr_loss: 1.2239 - clf_loss: 0.7332 - regr_mae: 0.7422 - clf_accuracy: 0.5132
# Epoch 00003: val_loss improved from 5.92476 to 5.46110, saving model to models\conv1d_multivar\multitask\03.hdf5
# 46/46 [==============================] - 10s 227ms/step - loss: 6.4336 - regr_loss: 1.3202 - clf_loss: 0.7329 - regr_mae: 0.7474 - clf_accuracy: 0.5123 - val_loss: 5.4611 - val_regr_loss: 0.5982 - val_clf_loss: 0.7091 - val_regr_mae: 0.4951 - val_clf_accuracy: 0.4974
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 45/46 [============================>.] - ETA: 0s - loss: 5.8121 - regr_loss: 1.1717 - clf_loss: 0.7019 - regr_mae: 0.7126 - clf_accuracy: 0.5535 ETA: 1s - loss: 5.9232 - regr_loss: 1.2484 - clf_loss: 0.6968 - regr_mae: 0.7266 - clf_
# Epoch 00004: val_loss improved from 5.46110 to 4.97896, saving model to models\conv1d_multivar\multitask\04.hdf5
# 46/46 [==============================] - 10s 218ms/step - loss: 5.7931 - regr_loss: 1.1583 - clf_loss: 0.7011 - regr_mae: 0.7106 - clf_accuracy: 0.5546 - val_loss: 4.9790 - val_regr_loss: 0.5688 - val_clf_loss: 0.7081 - val_regr_mae: 0.4816 - val_clf_accuracy: 0.5052
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 45/46 [============================>.] - ETA: 0s - loss: 5.4580 - regr_loss: 1.1641 - clf_loss: 0.7034 - regr_mae: 0.7039 - clf_accuracy: 0.5583
# Epoch 00005: val_loss improved from 4.97896 to 4.74437, saving model to models\conv1d_multivar\multitask\05.hdf5
# 46/46 [==============================] - 9s 200ms/step - loss: 5.4425 - regr_loss: 1.1509 - clf_loss: 0.7036 - regr_mae: 0.7030 - clf_accuracy: 0.5587 - val_loss: 4.7444 - val_regr_loss: 0.5678 - val_clf_loss: 0.7066 - val_regr_mae: 0.4839 - val_clf_accuracy: 0.5103
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 45/46 [============================>.] - ETA: 0s - loss: 5.1634 - regr_loss: 1.1112 - clf_loss: 0.6926 - regr_mae: 0.6806 - clf_accuracy: 0.5688
# Epoch 00006: val_loss improved from 4.74437 to 4.51702, saving model to models\conv1d_multivar\multitask\06.hdf5
# 46/46 [==============================] - 10s 224ms/step - loss: 5.1603 - regr_loss: 1.1105 - clf_loss: 0.6927 - regr_mae: 0.6826 - clf_accuracy: 0.5690 - val_loss: 4.5170 - val_regr_loss: 0.5733 - val_clf_loss: 0.7053 - val_regr_mae: 0.4860 - val_clf_accuracy: 0.4820
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 45/46 [============================>.] - ETA: 0s - loss: 4.8437 - regr_loss: 1.0239 - clf_loss: 0.6919 - regr_mae: 0.6596 - clf_accuracy: 0.5729
# Epoch 00007: val_loss improved from 4.51702 to 4.29402, saving model to models\conv1d_multivar\multitask\07.hdf5
# 46/46 [==============================] - 8s 179ms/step - loss: 4.8389 - regr_loss: 1.0195 - clf_loss: 0.6939 - regr_mae: 0.6612 - clf_accuracy: 0.5697 - val_loss: 4.2940 - val_regr_loss: 0.5787 - val_clf_loss: 0.7034 - val_regr_mae: 0.4855 - val_clf_accuracy: 0.5026
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 45/46 [============================>.] - ETA: 0s - loss: 4.6596 - regr_loss: 1.0646 - clf_loss: 0.6896 - regr_mae: 0.6785 - clf_accuracy: 0.5729
# Epoch 00008: val_loss improved from 4.29402 to 4.06601, saving model to models\conv1d_multivar\multitask\08.hdf5
# 46/46 [==============================] - 8s 165ms/step - loss: 4.6436 - regr_loss: 1.0525 - clf_loss: 0.6880 - regr_mae: 0.6775 - clf_accuracy: 0.5745 - val_loss: 4.0660 - val_regr_loss: 0.5691 - val_clf_loss: 0.7063 - val_regr_mae: 0.4801 - val_clf_accuracy: 0.4897
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 45/46 [============================>.] - ETA: 0s - loss: 4.4801 - regr_loss: 1.1055 - clf_loss: 0.6843 - regr_mae: 0.6824 - clf_accuracy: 0.5861
# Epoch 00009: val_loss improved from 4.06601 to 3.85045, saving model to models\conv1d_multivar\multitask\09.hdf5
# 46/46 [==============================] - 8s 171ms/step - loss: 4.4667 - regr_loss: 1.0948 - clf_loss: 0.6837 - regr_mae: 0.6811 - clf_accuracy: 0.5861 - val_loss: 3.8504 - val_regr_loss: 0.5640 - val_clf_loss: 0.7074 - val_regr_mae: 0.4784 - val_clf_accuracy: 0.4845
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 45/46 [============================>.] - ETA: 0s - loss: 4.2621 - regr_loss: 1.0486 - clf_loss: 0.6854 - regr_mae: 0.6565 - clf_accuracy: 0.5597
# Epoch 00010: val_loss improved from 3.85045 to 3.74666, saving model to models\conv1d_multivar\multitask\10.hdf5
# 46/46 [==============================] - 8s 174ms/step - loss: 4.2559 - regr_loss: 1.0434 - clf_loss: 0.6856 - regr_mae: 0.6562 - clf_accuracy: 0.5587 - val_loss: 3.7467 - val_regr_loss: 0.5634 - val_clf_loss: 0.7102 - val_regr_mae: 0.4771 - val_clf_accuracy: 0.4845
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 45/46 [============================>.] - ETA: 0s - loss: 4.1258 - regr_loss: 1.0235 - clf_loss: 0.6787 - regr_mae: 0.6635 - clf_accuracy: 0.5819
# Epoch 00011: val_loss improved from 3.74666 to 3.64694, saving model to models\conv1d_multivar\multitask\11.hdf5
# 46/46 [==============================] - 9s 196ms/step - loss: 4.1172 - regr_loss: 1.0153 - clf_loss: 0.6794 - regr_mae: 0.6628 - clf_accuracy: 0.5813 - val_loss: 3.6469 - val_regr_loss: 0.5660 - val_clf_loss: 0.7106 - val_regr_mae: 0.4785 - val_clf_accuracy: 0.5026
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 45/46 [============================>.] - ETA: 0s - loss: 4.0022 - regr_loss: 0.9958 - clf_loss: 0.6835 - regr_mae: 0.6545 - clf_accuracy: 0.5639
# Epoch 00012: val_loss improved from 3.64694 to 3.55753, saving model to models\conv1d_multivar\multitask\12.hdf5
# 46/46 [==============================] - 9s 191ms/step - loss: 3.9921 - regr_loss: 0.9873 - clf_loss: 0.6829 - regr_mae: 0.6538 - clf_accuracy: 0.5649 - val_loss: 3.5575 - val_regr_loss: 0.5726 - val_clf_loss: 0.7127 - val_regr_mae: 0.4818 - val_clf_accuracy: 0.5077
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.8237 - regr_loss: 0.9233 - clf_loss: 0.6752 - regr_mae: 0.6339 - clf_accuracy: 0.5785
# Epoch 00013: val_loss improved from 3.55753 to 3.46213, saving model to models\conv1d_multivar\multitask\13.hdf5
# 46/46 [==============================] - 9s 198ms/step - loss: 3.8148 - regr_loss: 0.9174 - clf_loss: 0.6732 - regr_mae: 0.6334 - clf_accuracy: 0.5806 - val_loss: 3.4621 - val_regr_loss: 0.5729 - val_clf_loss: 0.7128 - val_regr_mae: 0.4810 - val_clf_accuracy: 0.4974
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.7932 - regr_loss: 0.9910 - clf_loss: 0.6695 - regr_mae: 0.6490 - clf_accuracy: 0.5979
# Epoch 00014: val_loss improved from 3.46213 to 3.36623, saving model to models\conv1d_multivar\multitask\14.hdf5
# 46/46 [==============================] - 9s 191ms/step - loss: 3.7951 - regr_loss: 0.9922 - clf_loss: 0.6712 - regr_mae: 0.6522 - clf_accuracy: 0.5963 - val_loss: 3.3662 - val_regr_loss: 0.5683 - val_clf_loss: 0.7142 - val_regr_mae: 0.4797 - val_clf_accuracy: 0.4948
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.7153 - regr_loss: 0.9770 - clf_loss: 0.6780 - regr_mae: 0.6478 - clf_accuracy: 0.5708
# Epoch 00015: val_loss improved from 3.36623 to 3.32184, saving model to models\conv1d_multivar\multitask\15.hdf5
# 46/46 [==============================] - 8s 165ms/step - loss: 3.7132 - regr_loss: 0.9765 - clf_loss: 0.6767 - regr_mae: 0.6470 - clf_accuracy: 0.5717 - val_loss: 3.3218 - val_regr_loss: 0.5706 - val_clf_loss: 0.7157 - val_regr_mae: 0.4818 - val_clf_accuracy: 0.4923
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.6851 - regr_loss: 1.0009 - clf_loss: 0.6705 - regr_mae: 0.6481 - clf_accuracy: 0.5910
# Epoch 00016: val_loss improved from 3.32184 to 3.27841, saving model to models\conv1d_multivar\multitask\16.hdf5
# 46/46 [==============================] - 9s 185ms/step - loss: 3.6900 - regr_loss: 1.0051 - clf_loss: 0.6718 - regr_mae: 0.6492 - clf_accuracy: 0.5895 - val_loss: 3.2784 - val_regr_loss: 0.5734 - val_clf_loss: 0.7152 - val_regr_mae: 0.4824 - val_clf_accuracy: 0.4948
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.5953 - regr_loss: 0.9611 - clf_loss: 0.6655 - regr_mae: 0.6370 - clf_accuracy: 0.5889
# Epoch 00017: val_loss improved from 3.27841 to 3.23209, saving model to models\conv1d_multivar\multitask\17.hdf5
# 46/46 [==============================] - 8s 176ms/step - loss: 3.5948 - regr_loss: 0.9589 - clf_loss: 0.6677 - regr_mae: 0.6381 - clf_accuracy: 0.5854 - val_loss: 3.2321 - val_regr_loss: 0.5707 - val_clf_loss: 0.7163 - val_regr_mae: 0.4817 - val_clf_accuracy: 0.4974
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.5502 - regr_loss: 0.9599 - clf_loss: 0.6659 - regr_mae: 0.6442 - clf_accuracy: 0.5993
# Epoch 00018: val_loss improved from 3.23209 to 3.19033, saving model to models\conv1d_multivar\multitask\18.hdf5
# 46/46 [==============================] - 8s 175ms/step - loss: 3.5363 - regr_loss: 0.9453 - clf_loss: 0.6671 - regr_mae: 0.6409 - clf_accuracy: 0.5970 - val_loss: 3.1903 - val_regr_loss: 0.5710 - val_clf_loss: 0.7174 - val_regr_mae: 0.4817 - val_clf_accuracy: 0.4974
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.5369 - regr_loss: 0.9873 - clf_loss: 0.6673 - regr_mae: 0.6440 - clf_accuracy: 0.5931
# Epoch 00019: val_loss improved from 3.19033 to 3.15597, saving model to models\conv1d_multivar\multitask\19.hdf5
# 46/46 [==============================] - 9s 190ms/step - loss: 3.5235 - regr_loss: 0.9757 - clf_loss: 0.6659 - regr_mae: 0.6418 - clf_accuracy: 0.5936 - val_loss: 3.1560 - val_regr_loss: 0.5774 - val_clf_loss: 0.7174 - val_regr_mae: 0.4844 - val_clf_accuracy: 0.5103
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.5246 - regr_loss: 1.0138 - clf_loss: 0.6606 - regr_mae: 0.6565 - clf_accuracy: 0.5889
# Epoch 00020: val_loss improved from 3.15597 to 3.13303, saving model to models\conv1d_multivar\multitask\20.hdf5
# 46/46 [==============================] - 7s 161ms/step - loss: 3.5118 - regr_loss: 1.0019 - clf_loss: 0.6598 - regr_mae: 0.6541 - clf_accuracy: 0.5888 - val_loss: 3.1330 - val_regr_loss: 0.5763 - val_clf_loss: 0.7180 - val_regr_mae: 0.4840 - val_clf_accuracy: 0.5103
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.4295 - regr_loss: 0.9382 - clf_loss: 0.6633 - regr_mae: 0.6343 - clf_accuracy: 0.5882
# Epoch 00021: val_loss improved from 3.13303 to 3.11091, saving model to models\conv1d_multivar\multitask\21.hdf5
# 46/46 [==============================] - 7s 161ms/step - loss: 3.4206 - regr_loss: 0.9288 - clf_loss: 0.6640 - regr_mae: 0.6325 - clf_accuracy: 0.5861 - val_loss: 3.1109 - val_regr_loss: 0.5751 - val_clf_loss: 0.7190 - val_regr_mae: 0.4835 - val_clf_accuracy: 0.5077
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.4367 - regr_loss: 0.9648 - clf_loss: 0.6651 - regr_mae: 0.6413 - clf_accuracy: 0.5854
# Epoch 00022: val_loss improved from 3.11091 to 3.09367, saving model to models\conv1d_multivar\multitask\22.hdf5
# 46/46 [==============================] - 8s 164ms/step - loss: 3.4300 - regr_loss: 0.9554 - clf_loss: 0.6681 - regr_mae: 0.6407 - clf_accuracy: 0.5813 - val_loss: 3.0937 - val_regr_loss: 0.5775 - val_clf_loss: 0.7205 - val_regr_mae: 0.4846 - val_clf_accuracy: 0.4948
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.4182 - regr_loss: 0.9817 - clf_loss: 0.6506 - regr_mae: 0.6454 - clf_accuracy: 0.6083
# Epoch 00023: val_loss improved from 3.09367 to 3.07219, saving model to models\conv1d_multivar\multitask\23.hdf5
# 46/46 [==============================] - 7s 160ms/step - loss: 3.4057 - regr_loss: 0.9696 - clf_loss: 0.6504 - regr_mae: 0.6422 - clf_accuracy: 0.6086 - val_loss: 3.0722 - val_regr_loss: 0.5770 - val_clf_loss: 0.7204 - val_regr_mae: 0.4847 - val_clf_accuracy: 0.5077
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.3354 - regr_loss: 0.9223 - clf_loss: 0.6478 - regr_mae: 0.6228 - clf_accuracy: 0.6139
# Epoch 00024: val_loss improved from 3.07219 to 3.05529, saving model to models\conv1d_multivar\multitask\24.hdf5
# 46/46 [==============================] - 8s 175ms/step - loss: 3.3367 - regr_loss: 0.9239 - clf_loss: 0.6478 - regr_mae: 0.6237 - clf_accuracy: 0.6148 - val_loss: 3.0553 - val_regr_loss: 0.5791 - val_clf_loss: 0.7216 - val_regr_mae: 0.4857 - val_clf_accuracy: 0.5026
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.3512 - regr_loss: 0.9456 - clf_loss: 0.6560 - regr_mae: 0.6324 - clf_accuracy: 0.6069
# Epoch 00025: val_loss improved from 3.05529 to 3.04641, saving model to models\conv1d_multivar\multitask\25.hdf5
# 46/46 [==============================] - 7s 159ms/step - loss: 3.3497 - regr_loss: 0.9427 - clf_loss: 0.6577 - regr_mae: 0.6338 - clf_accuracy: 0.6045 - val_loss: 3.0464 - val_regr_loss: 0.5797 - val_clf_loss: 0.7229 - val_regr_mae: 0.4862 - val_clf_accuracy: 0.4897
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.3163 - regr_loss: 0.9156 - clf_loss: 0.6617 - regr_mae: 0.6226 - clf_accuracy: 0.5868
# Epoch 00026: val_loss improved from 3.04641 to 3.03884, saving model to models\conv1d_multivar\multitask\26.hdf5
# 46/46 [==============================] - 7s 160ms/step - loss: 3.3067 - regr_loss: 0.9066 - clf_loss: 0.6611 - regr_mae: 0.6221 - clf_accuracy: 0.5895 - val_loss: 3.0388 - val_regr_loss: 0.5820 - val_clf_loss: 0.7232 - val_regr_mae: 0.4866 - val_clf_accuracy: 0.4871
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.3680 - regr_loss: 0.9666 - clf_loss: 0.6726 - regr_mae: 0.6367 - clf_accuracy: 0.5889
# Epoch 00027: val_loss improved from 3.03884 to 3.03014, saving model to models\conv1d_multivar\multitask\27.hdf5
# 46/46 [==============================] - 7s 162ms/step - loss: 3.3697 - regr_loss: 0.9698 - clf_loss: 0.6712 - regr_mae: 0.6374 - clf_accuracy: 0.5895 - val_loss: 3.0301 - val_regr_loss: 0.5832 - val_clf_loss: 0.7235 - val_regr_mae: 0.4875 - val_clf_accuracy: 0.4794
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.3005 - regr_loss: 0.9266 - clf_loss: 0.6546 - regr_mae: 0.6326 - clf_accuracy: 0.6146
# Epoch 00028: val_loss improved from 3.03014 to 3.02028, saving model to models\conv1d_multivar\multitask\28.hdf5
# 46/46 [==============================] - 7s 161ms/step - loss: 3.2947 - regr_loss: 0.9199 - clf_loss: 0.6555 - regr_mae: 0.6321 - clf_accuracy: 0.6134 - val_loss: 3.0203 - val_regr_loss: 0.5834 - val_clf_loss: 0.7228 - val_regr_mae: 0.4883 - val_clf_accuracy: 0.4923
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.3174 - regr_loss: 0.9468 - clf_loss: 0.6611 - regr_mae: 0.6341 - clf_accuracy: 0.6125
# Epoch 00029: val_loss improved from 3.02028 to 3.01161, saving model to models\conv1d_multivar\multitask\29.hdf5
# 46/46 [==============================] - 7s 159ms/step - loss: 3.3046 - regr_loss: 0.9345 - clf_loss: 0.6606 - regr_mae: 0.6322 - clf_accuracy: 0.6134 - val_loss: 3.0116 - val_regr_loss: 0.5848 - val_clf_loss: 0.7224 - val_regr_mae: 0.4887 - val_clf_accuracy: 0.4923
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.2684 - regr_loss: 0.9147 - clf_loss: 0.6518 - regr_mae: 0.6218 - clf_accuracy: 0.6167
# Epoch 00030: val_loss improved from 3.01161 to 3.00891, saving model to models\conv1d_multivar\multitask\30.hdf5
# 46/46 [==============================] - 7s 161ms/step - loss: 3.2644 - regr_loss: 0.9095 - clf_loss: 0.6530 - regr_mae: 0.6232 - clf_accuracy: 0.6175 - val_loss: 3.0089 - val_regr_loss: 0.5864 - val_clf_loss: 0.7233 - val_regr_mae: 0.4897 - val_clf_accuracy: 0.4897
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.2878 - regr_loss: 0.9421 - clf_loss: 0.6489 - regr_mae: 0.6278 - clf_accuracy: 0.5993
# Epoch 00031: val_loss improved from 3.00891 to 3.00610, saving model to models\conv1d_multivar\multitask\31.hdf5
# 46/46 [==============================] - 7s 160ms/step - loss: 3.2790 - regr_loss: 0.9334 - clf_loss: 0.6487 - regr_mae: 0.6282 - clf_accuracy: 0.6004 - val_loss: 3.0061 - val_regr_loss: 0.5876 - val_clf_loss: 0.7242 - val_regr_mae: 0.4900 - val_clf_accuracy: 0.4845
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 45/46 [============================>.] - ETA: 0s - loss: 3.3229 - regr_loss: 0.9687 - clf_loss: 0.6622 - regr_mae: 0.6420 - clf_accuracy: 0.5951
# Epoch 00032: val_loss improved from 3.00610 to 3.00049, saving model to models\conv1d_multivar\multitask\32.hdf5
# 46/46 [==============================] - 7s 162ms/step - loss: 3.3070 - regr_loss: 0.9551 - clf_loss: 0.6599 - regr_mae: 0.6382 - clf_accuracy: 0.5943 - val_loss: 3.0005 - val_regr_loss: 0.5869 - val_clf_loss: 0.7242 - val_regr_mae: 0.4897 - val_clf_accuracy: 0.4845

# %%
def plot_multitask_history(hist):
    fig, ax = plt.subplots(2, 2, figsize=(16, 12))
    plotHelpers.plot_train_history(ax[0, 0], hist, 'Total loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[0, 1], hist, 'Accuracy', 'clf_accuracy', 'val_clf_accuracy')
    plotHelpers.plot_train_history(ax[1, 0], hist, 'MSE', 'regr_loss', 'val_regr_loss')
    plotHelpers.plot_train_history(ax[1, 1], hist, 'MAE', 'regr_mae', 'val_regr_mae')
    
plot_multitask_history(multitask_history);

# %% [markdown]
# ### Прогноз

# %%
# загружаем последнюю эпоху с минимальным лоссом
multivariate_multitask_conv1d.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret, pred_direction_proba = multivariate_multitask_conv1d.predict_generator(test_multi_gen, verbose=1)
# Out:
# 13/13 [==============================] - 0s 22ms/step

# %%
np.set_printoptions(precision=3, suppress=True)

np.column_stack([pred_log_ret, pred_direction_proba])[-10:]
# Out:
# array([[-0.013,  0.484],
#        [ 0.181,  0.41 ],
#        [ 0.322,  0.471],
#        [ 0.262,  0.465],
#        [ 0.378,  0.503],
#        [ 0.313,  0.448],
#        [ 0.069,  0.43 ],
#        [ 0.052,  0.524],
#        [ 0.171,  0.514],
#        [ 0.218,  0.412]], dtype=float32)

# %% [markdown]
# #### Прогноз задачи регрессии

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret, figsize=(16, 10),
                                  datetime_unit='m', xlabel='Time', plot_data_slice=slice(1, None))

# %% [markdown]
# #### Прогноз задачи классификации

# %%
true_direction = test_multi_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 0.48327884

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([210, 178], dtype=int64)),
#  (array([0, 1]), array([169, 219], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.39      0.43       210
#            1       0.42      0.51      0.46       178
#
#     accuracy                           0.45       388
#    macro avg       0.45      0.45      0.45       388
# weighted avg       0.45      0.45      0.44       388

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[ 82, 128],
#        [ 87,  91]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.485, 0.584],
#        [0.515, 0.416]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# # Выводы
#
# 1.  Модель с 1D свёртками обучается гораздо быстрее модели LSTM
# 2.  Задача классификации не решается удовлетворительно.

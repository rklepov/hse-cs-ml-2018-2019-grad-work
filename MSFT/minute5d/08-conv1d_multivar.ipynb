# %% [markdown]
# <a href="https://colab.research.google.com/github/rklepov/hse-cs-ml-2018-2019-grad-work/blob/CVX-1yr/CVX/daily1y/08_conv1d_multivar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # *Многомерная модель на 1D свёрточных слоях*
#
# В качестве признаков используются цены, объём торгов и некоторое число индикаторов (всего 18 признаков)

# %%
import os
import glob
import datetime
import pickle

import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from pandas_datareader import data as pdr

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
import tensorflow as tf
# tf.test.is_gpu_available()
tf.__version__
# Out:
# '2.0.0'

# %%
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import (Input, Dense, Convolution1D, MaxPooling1D, Flatten,
                                     ReLU, LeakyReLU, Dropout, BatchNormalization)
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers import Nadam

# %%
from mdp import TimeSeries
from mdp import MarketData
from mdp import MovingWindowFeatures
from mdp import ClassificationGenerator, RegressionGenerator, MultitaskGenerator
from mdp import invert_log_ret

import mdp.utils as utils
import mdp.plotHelpers as plotHelpers

# %%
import importlib

import mdp

importlib.reload(mdp)
importlib.reload(mdp.datasetGenerator)
importlib.reload(mdp.marketData)
importlib.reload(mdp.movingWindowFeatures)
importlib.reload(mdp.timeSeries)
importlib.reload(mdp.plotHelpers)
importlib.reload(mdp.utils);

# %% [markdown]
# # *Параметры*

# %%
INSTRUMENT = 'MSFT' # Microsoft corp
START_FROM = np.datetime64('today') - 7
WINDOW_SIZE = 120
FORECAST_OFFSET=1
BATCH_SIZE = 32
FORCE_TRAIN = True

# %% [markdown]
# # *Исходные данные*
#
# Загрузка данных и вычисление индикаторов.

# %%
instr = MarketData.create_from_alphavantage_intraday(INSTRUMENT, start=START_FROM)

# %%
instr.feature_names
# Out:
# ['o',
#  'h',
#  'l',
#  'c',
#  'v',
#  'ema14',
#  'ema30',
#  'macd',
#  'macd_signal',
#  'rsi14',
#  'bband20_upper',
#  'bband20_middle',
#  'bband20_lower',
#  'willr14',
#  'stochk',
#  'stochd',
#  'adline',
#  'adosc']

# %% [markdown]
# Здесь не будем делить отдельно на тест и валидацию, поскольку данных у нас только 5 дней.

# %%
dates_unique = np.unique(instr.timestamps.astype('datetime64[D]'))

START_FROM = dates_unique[0]
VAL_TEST_SPLIT = dates_unique[-1]

START_FROM, VAL_TEST_SPLIT
# Out:
# (numpy.datetime64('2020-04-09'), numpy.datetime64('2020-04-15'))

# %% [markdown]
# ## Целевая переменная

# %% [markdown]
# Цена закрытия.

# %%
orig_target = instr.c

# %%
def plot_transformed_series(instrument, series, orig_display_name, transformed_display_name):
    plotHelpers.plot_transformed_timeseries(
        instrument.instrument,
        series,
        title_orig = orig_display_name,
        xlabel_orig = 'Date',
        ylabel_orig = orig_display_name,
        title_transformed = transformed_display_name,
        xlabel_transformed = 'Date',
        ylabel_transformed = transformed_display_name
    )

# %% [markdown]
# Переходим к логарифмической доходности.

# %%
transformed_target = instr.c.transform(transforms={'ratios' : {}, 'ln' : {}})

# %%
plotHelpers.plot_transformed_timeseries_unit(instr,
                                             transformed_target,
                                             'Price, USD', 'Log return',
                                             datetime_unit='m', rotation=45)

# %% [markdown]
# ## Трансформация признаков
#
# Приведение временных рядов к стационарности.

# %%
def make_feature_selector():
    price_transformer = lambda: {'ratios': {}, 'ln': {}}
    diff_transformer = lambda o: {'diffs': {'order': o}}
    identity_transformer = lambda: {}
    feature_transformations = {
        'o': price_transformer(),
        'h': price_transformer(),
        'l': price_transformer(),
        'c': price_transformer(),
        'v': diff_transformer(1),
        'ema14': diff_transformer(1),
        'ema30': diff_transformer(1),
        'macd': identity_transformer(),
        'macd_signal': identity_transformer(),
        'rsi14': identity_transformer(),
        'bband20_upper': diff_transformer(1),
        'bband20_middle': diff_transformer(1),
        'bband20_lower': diff_transformer(1),
        'willr14': identity_transformer(),
        'stochd': identity_transformer(),
        'stochk': identity_transformer(),
        'adline': diff_transformer(1),
        'adosc': identity_transformer()
    }
    return feature_transformations

# %%
instr_transformed = instr.select_transform(make_feature_selector())

# %%
transformed_target = instr_transformed.c

# %% [markdown]
# ## Обучающая, валидационная и тестовая выборки

# %%
instr_train, instr_test = instr_transformed.train_test_split(VAL_TEST_SPLIT, window_size=WINDOW_SIZE,
                                                             scaler=StandardScaler)
#                                                              scaler=MinMaxScaler,
#                                                              scaler_kwargs={'feature_range': (-1, 1)})

# instr_val, instr_test = instr_val_test.train_test_split(TEST_SPLIT, window_size=WINDOW_SIZE, scaler=None)

len(instr_train), len(instr_test)
# Out:
# (1132, 509)

# %% [markdown]
# Все отмасштабированные признаки на одном графике (для валидационного датасета):

# %%
plotHelpers.plot_all_features(instr_test)

# %% [markdown]
# ## Признаки - скользящие окна

# %%
train_mwf = MovingWindowFeatures.create(instr_train.c, [instr_train], instr_train.feature_names, window_size=WINDOW_SIZE)
# val_mwf = MovingWindowFeatures.create(instr_val.c, [instr_val], instr_val.feature_names, window_size=WINDOW_SIZE)
test_mwf = MovingWindowFeatures.create(instr_test.c, [instr_test], instr_test.feature_names, window_size=WINDOW_SIZE)

len(instr_train), len(train_mwf), train_mwf.features.shape
# Out:
# (1132, 1012, (1012, 120, 18))

# %% [markdown]
# Проверка, что скользящие окна соответствуют исходным данным.
#
# Возьмём произвольный признак и произвольное окно (строка #**41**). Проверим, что данные в точности совпадают:

# %%
def check_data(md, mwf, row):
    col = np.random.randint(len(mwf.feature_names))
    feature = mwf.feature_names[col]
    check = (getattr(md, feature).data[row:row + mwf.window_size] == mwf.features[row, :, col]).all()
    assert check
    return feature, check

check_data(instr_train, train_mwf, 41)
# Out:
# ('bband20_middle', True)

# %% [markdown]
# # *Модели*

# %% [markdown]
# Модель с двумя 1D свёрточными слоями.

# %%
def build_conv1d_layers(input_shape, filters=(32, 16, 8), kernel_size=3, pool_size=2):
    # формат входа: наша матрица (окно; признак)
    inp = Input(input_shape, name='input')

    filter_blocks = np.array(filters)
    filter_blocks = np.lib.stride_tricks.as_strided(filter_blocks, 
                                                    (filter_blocks.shape[0] - 1, 2), 
                                                    2 * [filter_blocks.strides[0]])
    conv1d = inp
    # стекаем слои Conv1D: блоками Conv1D-Conv1D-MaxPool
    for filter_block in filter_blocks:
        for f in filter_block:
            conv1d = Convolution1D(filters=f,
                                   kernel_size=kernel_size,
                                   padding='same',
                                   bias_initializer='he_uniform',
                                   bias_regularizer=L1L2(0.01, 0.02),
                                   kernel_regularizer=L1L2(0.01, 0.02)
                                  )(conv1d)
            conv1d = BatchNormalization()(conv1d)
            conv1d = LeakyReLU()(conv1d)
            conv1d = Dropout(0.25)(conv1d)
        conv1d = MaxPooling1D(pool_size=pool_size)(conv1d)
    
    conv1d = Flatten()(conv1d)
    
    return inp, conv1d

# %% [markdown]
# #### Пути:

# %%
model_path_root = 'models'
model_type_name = 'conv1d_multivar'

def make_model_save_dir(path_root, type_name, class_name):
    save_dir = os.path.join(path_root, type_name, class_name)
    os.makedirs(save_dir, exist_ok=True)
    return save_dir

# %% [markdown]
# #### Общие коллбэки:

# %%
# уменьшение learning rate в случае, если loss не изменяется
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001, verbose=1)

# уменьшение learning rate в 2 раза каждую 5-ю эпоху
def lr_decay(e, lr):
    return lr * (1 - 0.5 * (0 == (e + 1) % 5))

lr_scheduler = LearningRateScheduler(schedule=lr_decay, verbose=1)

# %% [markdown]
# ## Задача регрессии
#
# Непосредственное прогнозирование цены следующего периода.

# %%
train_regr_gen = RegressionGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_regr_gen = RegressionGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_regr_gen = RegressionGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# Следующие числа соответствуют значению параметра `steps_per_epoch` метода [`fit_generator`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit_generator "tf.keras.layers.SimpleRNN &nbsp;|&nbsp; TensorFlow Core r2.0") - то есть это число батчей, которые генератор выдаст за одну эпоху обучения (если класс генератора поддерживает метод `len()`, то данный параметр можно не указывать).

# %%
len(train_regr_gen), (test_regr_gen)
# Out:
# (32, <mdp.datasetGenerator.RegressionGenerator at 0x1ecafe21488>)

# %% [markdown]
# Один сэмпл данных представляет собой матрицу размером *(длина окна; число признаков)*

# %%
train_regr_gen.input_shape
# Out:
# (120, 18)

# %% [markdown]
# ### Модель для задачи регрессии

# %%
model_class_name = 'regression'

# %%
def build_regression_model(input_shape):
    inp, conv1d = build_conv1d_layers(input_shape, filters=(32, 16, 8))

    regr = Dense(64)(conv1d)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.25)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    return Model(inputs=[inp], outputs=[regr])

# %%
multivariate_regression_conv1d = build_regression_model(train_regr_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:
# [`Nadam`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Nadam) (*Adam with Nestrov momentum*).

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Функция потерь:
#
# В качестве функции потерь будем использовать [MSE](https://www.tensorflow.org/api_docs/python/tf/keras/losses/MSE) (чтобы штрафовать за большие отклонения). Xотя хорошая функция потерь в контексте темы данной задачи - это [вопрос сложный](https://github.com/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Chapter5_LossFunctions/Ch5_LossFunctions_PyMC3.ipynb). В частности, здесь нам, очевидно, помимо абсолютного значения отклонения также важен его знак.

# %%
multivariate_regression_conv1d.compile(optimizer=optimizer,
                                       loss={'regr': 'mse'},
                                       metrics={'regr': 'mae'})

multivariate_regression_conv1d.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 120, 18)]         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 120, 32)           1760
# _________________________________________________________________
# batch_normalization (BatchNo (None, 120, 32)           128
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 120, 32)           0
# _________________________________________________________________
# dropout (Dropout)            (None, 120, 32)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 120, 16)           1552
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 120, 16)           64
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 120, 16)           0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 120, 16)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 60, 16)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 60, 16)            784
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 60, 16)            64
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 60, 16)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 60, 16)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 60, 8)             392
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 60, 8)             32
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 60, 8)             0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 60, 8)             0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 30, 8)             0
# _________________________________________________________________
# flatten (Flatten)            (None, 240)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                15424
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# regr (Dense)                 (None, 1)                 65
# =================================================================
# Total params: 20,521
# Trainable params: 20,249
# Non-trainable params: 272
# _________________________________________________________________

# %% [markdown]
# #### Обучение:

# %%
regr_history = utils.train_model(multivariate_regression_conv1d,
                                 model_save_dir, train_regr_gen, test_regr_gen,
                                 callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                 force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.3802 - mae: 0.9440
# Epoch 00001: val_loss improved from inf to 7.91935, saving model to models\conv1d_multivar\regression\01.hdf5
# 32/32 [==============================] - 15s 478ms/step - loss: 8.3580 - mae: 0.9408 - val_loss: 7.9194 - val_mae: 0.8760
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.8356 - mae: 0.8586
# Epoch 00002: val_loss improved from 7.91935 to 7.27565, saving model to models\conv1d_multivar\regression\02.hdf5
# 32/32 [==============================] - 11s 339ms/step - loss: 7.8123 - mae: 0.8563 - val_loss: 7.2757 - val_mae: 0.7016
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.3659 - mae: 0.7887
# Epoch 00003: val_loss improved from 7.27565 to 7.01904, saving model to models\conv1d_multivar\regression\03.hdf5
# 32/32 [==============================] - 11s 344ms/step - loss: 7.3289 - mae: 0.7810 - val_loss: 7.0190 - val_mae: 0.7040
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.1211 - mae: 0.7845
# Epoch 00004: val_loss improved from 7.01904 to 6.75197, saving model to models\conv1d_multivar\regression\04.hdf5
# 32/32 [==============================] - 11s 332ms/step - loss: 7.0905 - mae: 0.7799 - val_loss: 6.7520 - val_mae: 0.6985
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.9327 - mae: 0.7792
# Epoch 00005: val_loss improved from 6.75197 to 6.59597, saving model to models\conv1d_multivar\regression\05.hdf5
# 32/32 [==============================] - 11s 351ms/step - loss: 6.9158 - mae: 0.7798 - val_loss: 6.5960 - val_mae: 0.6852
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.7387 - mae: 0.7656
# Epoch 00006: val_loss improved from 6.59597 to 6.46369, saving model to models\conv1d_multivar\regression\06.hdf5
# 32/32 [==============================] - 11s 344ms/step - loss: 6.7344 - mae: 0.7661 - val_loss: 6.4637 - val_mae: 0.6868
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.5318 - mae: 0.7275
# Epoch 00007: val_loss improved from 6.46369 to 6.32854, saving model to models\conv1d_multivar\regression\07.hdf5
# 32/32 [==============================] - 11s 348ms/step - loss: 6.5047 - mae: 0.7235 - val_loss: 6.3285 - val_mae: 0.6839
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.3110 - mae: 0.7211
# Epoch 00008: val_loss improved from 6.32854 to 6.19883, saving model to models\conv1d_multivar\regression\08.hdf5
# 32/32 [==============================] - 11s 342ms/step - loss: 6.3010 - mae: 0.7223 - val_loss: 6.1988 - val_mae: 0.6851
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.2072 - mae: 0.7146
# Epoch 00009: val_loss improved from 6.19883 to 6.07757, saving model to models\conv1d_multivar\regression\09.hdf5
# 32/32 [==============================] - 11s 339ms/step - loss: 6.1892 - mae: 0.7134 - val_loss: 6.0776 - val_mae: 0.6914
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.1346 - mae: 0.7312
# Epoch 00010: val_loss improved from 6.07757 to 6.00038, saving model to models\conv1d_multivar\regression\10.hdf5
# 32/32 [==============================] - 11s 346ms/step - loss: 6.1142 - mae: 0.7287 - val_loss: 6.0004 - val_mae: 0.6872
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.9561 - mae: 0.7032
# Epoch 00011: val_loss improved from 6.00038 to 5.91658, saving model to models\conv1d_multivar\regression\11.hdf5
# 32/32 [==============================] - 11s 337ms/step - loss: 5.9368 - mae: 0.7015 - val_loss: 5.9166 - val_mae: 0.6819
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.9232 - mae: 0.7422
# Epoch 00012: val_loss improved from 5.91658 to 5.84430, saving model to models\conv1d_multivar\regression\12.hdf5
# 32/32 [==============================] - 11s 344ms/step - loss: 5.9021 - mae: 0.7390 - val_loss: 5.8443 - val_mae: 0.6828
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.8797 - mae: 0.7089
# Epoch 00013: val_loss improved from 5.84430 to 5.77296, saving model to models\conv1d_multivar\regression\13.hdf5
# 32/32 [==============================] - 11s 340ms/step - loss: 5.8571 - mae: 0.7071 - val_loss: 5.7730 - val_mae: 0.6830
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.7200 - mae: 0.6825
# Epoch 00014: val_loss improved from 5.77296 to 5.69903, saving model to models\conv1d_multivar\regression\14.hdf5
# 32/32 [==============================] - 11s 355ms/step - loss: 5.7037 - mae: 0.6819 - val_loss: 5.6990 - val_mae: 0.6826
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.6862 - mae: 0.7060
# Epoch 00015: val_loss improved from 5.69903 to 5.66313, saving model to models\conv1d_multivar\regression\15.hdf5
# 32/32 [==============================] - 11s 356ms/step - loss: 5.6674 - mae: 0.7036 - val_loss: 5.6631 - val_mae: 0.6827
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.7258 - mae: 0.7161
# Epoch 00016: val_loss improved from 5.66313 to 5.62695, saving model to models\conv1d_multivar\regression\16.hdf5
# 32/32 [==============================] - 11s 346ms/step - loss: 5.7088 - mae: 0.7157 - val_loss: 5.6269 - val_mae: 0.6829
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.6162 - mae: 0.7047- ETA: 3s - loss: 5.7897
# Epoch 00017: val_loss improved from 5.62695 to 5.59309, saving model to models\conv1d_multivar\regression\17.hdf5
# 32/32 [==============================] - 7s 231ms/step - loss: 5.6031 - mae: 0.7039 - val_loss: 5.5931 - val_mae: 0.6846
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.5682 - mae: 0.6880
# Epoch 00018: val_loss improved from 5.59309 to 5.55830, saving model to models\conv1d_multivar\regression\18.hdf5
# 32/32 [==============================] - 7s 221ms/step - loss: 5.5784 - mae: 0.6914 - val_loss: 5.5583 - val_mae: 0.6856
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.4834 - mae: 0.6831
# Epoch 00019: val_loss improved from 5.55830 to 5.52297, saving model to models\conv1d_multivar\regression\19.hdf5
# 32/32 [==============================] - 8s 252ms/step - loss: 5.4655 - mae: 0.6817 - val_loss: 5.5230 - val_mae: 0.6877
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.4598 - mae: 0.6829
# Epoch 00020: val_loss improved from 5.52297 to 5.50487, saving model to models\conv1d_multivar\regression\20.hdf5
# 32/32 [==============================] - 10s 303ms/step - loss: 5.4619 - mae: 0.6878 - val_loss: 5.5049 - val_mae: 0.6885
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.4806 - mae: 0.6828
# Epoch 00021: val_loss improved from 5.50487 to 5.48450, saving model to models\conv1d_multivar\regression\21.hdf5
# 32/32 [==============================] - 11s 349ms/step - loss: 5.4950 - mae: 0.6863 - val_loss: 5.4845 - val_mae: 0.6883
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.4248 - mae: 0.7060
# Epoch 00022: val_loss improved from 5.48450 to 5.46789, saving model to models\conv1d_multivar\regression\22.hdf5
# 32/32 [==============================] - 11s 335ms/step - loss: 5.4094 - mae: 0.7048 - val_loss: 5.4679 - val_mae: 0.6893
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.4170 - mae: 0.6876
# Epoch 00023: val_loss improved from 5.46789 to 5.44569, saving model to models\conv1d_multivar\regression\23.hdf5
# 32/32 [==============================] - 11s 340ms/step - loss: 5.4252 - mae: 0.6919 - val_loss: 5.4457 - val_mae: 0.6872
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.3898 - mae: 0.6838
# Epoch 00024: val_loss improved from 5.44569 to 5.42387, saving model to models\conv1d_multivar\regression\24.hdf5
# 32/32 [==============================] - 11s 342ms/step - loss: 5.3885 - mae: 0.6849 - val_loss: 5.4239 - val_mae: 0.6862
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.4383 - mae: 0.7053
# Epoch 00025: val_loss improved from 5.42387 to 5.41377, saving model to models\conv1d_multivar\regression\25.hdf5
# 32/32 [==============================] - 11s 347ms/step - loss: 5.4330 - mae: 0.7065 - val_loss: 5.4138 - val_mae: 0.6863
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.4413 - mae: 0.7163
# Epoch 00026: val_loss improved from 5.41377 to 5.40331, saving model to models\conv1d_multivar\regression\26.hdf5
# 32/32 [==============================] - 11s 345ms/step - loss: 5.4179 - mae: 0.7126 - val_loss: 5.4033 - val_mae: 0.6860
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.3738 - mae: 0.6925
# Epoch 00027: val_loss improved from 5.40331 to 5.39428, saving model to models\conv1d_multivar\regression\27.hdf5
# 32/32 [==============================] - 11s 339ms/step - loss: 5.3529 - mae: 0.6902 - val_loss: 5.3943 - val_mae: 0.6863
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.3509 - mae: 0.6919
# Epoch 00028: val_loss improved from 5.39428 to 5.38416, saving model to models\conv1d_multivar\regression\28.hdf5
# 32/32 [==============================] - 11s 350ms/step - loss: 5.3276 - mae: 0.6878 - val_loss: 5.3842 - val_mae: 0.6861
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.3585 - mae: 0.6893
# Epoch 00029: val_loss improved from 5.38416 to 5.37374, saving model to models\conv1d_multivar\regression\29.hdf5
# 32/32 [==============================] - 11s 353ms/step - loss: 5.3536 - mae: 0.6933 - val_loss: 5.3737 - val_mae: 0.6861
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.3154 - mae: 0.6775
# Epoch 00030: val_loss improved from 5.37374 to 5.36782, saving model to models\conv1d_multivar\regression\30.hdf5
# 32/32 [==============================] - 11s 354ms/step - loss: 5.3140 - mae: 0.6790 - val_loss: 5.3678 - val_mae: 0.6861
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.3240 - mae: 0.6784
# Epoch 00031: val_loss improved from 5.36782 to 5.36180, saving model to models\conv1d_multivar\regression\31.hdf5
# 32/32 [==============================] - 11s 344ms/step - loss: 5.3406 - mae: 0.6826 - val_loss: 5.3618 - val_mae: 0.6860
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.3078 - mae: 0.6957
# Epoch 00032: val_loss improved from 5.36180 to 5.35651, saving model to models\conv1d_multivar\regression\32.hdf5
# 32/32 [==============================] - 11s 346ms/step - loss: 5.2894 - mae: 0.6927 - val_loss: 5.3565 - val_mae: 0.6861

# %%
def plot_regr_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'MSE', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'MAE', 'mae', 'val_mae')
    
plot_regr_history(regr_history);

# %% [markdown]
# ### Прогноз задачи регрессии

# %%
# загружаем последнюю эпоху с минимальным лоссом
multivariate_regression_conv1d.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret_test = multivariate_regression_conv1d.predict_generator(test_regr_gen, verbose=1)
# Out:
# 13/13 [==============================] - 1s 63ms/step

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret_test, figsize=(16, 10),
                                  datetime_unit='m', xlabel='Time', plot_data_slice=slice(1, None))

# %% [markdown]
# ## Задача классификации
#
# Прогнозируем направление изменения цены по сравнению с предыдущим периодом (**0** - снижение, **1** - рост).

# %%
model_class_name = 'classification'

# %%
train_clf_gen = ClassificationGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_clf_gen = ClassificationGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_clf_gen = ClassificationGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_classification_model(input_shape):
    inp, conv1d = build_conv1d_layers(input_shape, filters=(32, 16, 8))

    clf = Dense(64)(conv1d)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.25)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)

    return Model(inputs=[inp], outputs=[clf])

# %%
multivariate_classification_conv1d = build_classification_model(test_clf_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
multivariate_classification_conv1d.compile(optimizer=optimizer,
                                           loss={'clf': 'binary_crossentropy'},
                                           metrics={'clf': 'accuracy'})

multivariate_classification_conv1d.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 120, 18)]         0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 120, 32)           1760
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 120, 32)           128
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 120, 32)           0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 120, 32)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 120, 16)           1552
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 120, 16)           64
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 120, 16)           0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 120, 16)           0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 60, 16)            0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 60, 16)            784
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 60, 16)            64
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 60, 16)            0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 60, 16)            0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 60, 8)             392
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 60, 8)             32
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 60, 8)             0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 60, 8)             0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 30, 8)             0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 240)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                15424
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 64)                0
# _________________________________________________________________
# clf (Dense)                  (None, 1)                 65
# =================================================================
# Total params: 20,521
# Trainable params: 20,249
# Non-trainable params: 272
# _________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
clf_history = utils.train_model(multivariate_classification_conv1d,
                                model_save_dir, train_clf_gen, test_clf_gen,
                                callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.1157 - accuracy: 0.4829
# Epoch 00001: val_loss improved from inf to 6.59346, saving model to models\conv1d_multivar\classification\01.hdf5
# 32/32 [==============================] - 11s 352ms/step - loss: 7.1007 - accuracy: 0.4842 - val_loss: 6.5935 - val_accuracy: 0.4781
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.1621 - accuracy: 0.5282
# Epoch 00002: val_loss improved from 6.59346 to 5.68951, saving model to models\conv1d_multivar\classification\02.hdf5
# 32/32 [==============================] - 11s 341ms/step - loss: 6.1511 - accuracy: 0.5287 - val_loss: 5.6895 - val_accuracy: 0.4679
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.3467 - accuracy: 0.5292
# Epoch 00003: val_loss improved from 5.68951 to 4.89500, saving model to models\conv1d_multivar\classification\03.hdf5
# 32/32 [==============================] - 11s 341ms/step - loss: 5.3379 - accuracy: 0.5247 - val_loss: 4.8950 - val_accuracy: 0.5116
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.5923 - accuracy: 0.5444
# Epoch 00004: val_loss improved from 4.89500 to 4.20118, saving model to models\conv1d_multivar\classification\04.hdf5
# 32/32 [==============================] - 11s 356ms/step - loss: 4.5812 - accuracy: 0.5455 - val_loss: 4.2012 - val_accuracy: 0.5167
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.0844 - accuracy: 0.5373
# Epoch 00005: val_loss improved from 4.20118 to 3.88166, saving model to models\conv1d_multivar\classification\05.hdf5
# 32/32 [==============================] - 11s 355ms/step - loss: 4.0794 - accuracy: 0.5346 - val_loss: 3.8817 - val_accuracy: 0.5270
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.7660 - accuracy: 0.5403
# Epoch 00006: val_loss improved from 3.88166 to 3.58674, saving model to models\conv1d_multivar\classification\06.hdf5
# 32/32 [==============================] - 11s 351ms/step - loss: 3.7608 - accuracy: 0.5415 - val_loss: 3.5867 - val_accuracy: 0.5321
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.4867 - accuracy: 0.5454
# Epoch 00007: val_loss improved from 3.58674 to 3.31228, saving model to models\conv1d_multivar\classification\07.hdf5
# 32/32 [==============================] - 12s 360ms/step - loss: 3.4790 - accuracy: 0.5494 - val_loss: 3.3123 - val_accuracy: 0.5244
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.2147 - accuracy: 0.5454
# Epoch 00008: val_loss improved from 3.31228 to 3.06044, saving model to models\conv1d_multivar\classification\08.hdf5
# 32/32 [==============================] - 13s 409ms/step - loss: 3.2096 - accuracy: 0.5474 - val_loss: 3.0604 - val_accuracy: 0.5347
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.9466 - accuracy: 0.5917
# Epoch 00009: val_loss improved from 3.06044 to 2.82710, saving model to models\conv1d_multivar\classification\09.hdf5
# 32/32 [==============================] - 10s 327ms/step - loss: 2.9445 - accuracy: 0.5879 - val_loss: 2.8271 - val_accuracy: 0.5244
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.7775 - accuracy: 0.5575
# Epoch 00010: val_loss improved from 2.82710 to 2.71220, saving model to models\conv1d_multivar\classification\10.hdf5
# 32/32 [==============================] - 11s 346ms/step - loss: 2.7792 - accuracy: 0.5553 - val_loss: 2.7122 - val_accuracy: 0.5219
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.6599 - accuracy: 0.5796
# Epoch 00011: val_loss improved from 2.71220 to 2.60678, saving model to models\conv1d_multivar\classification\11.hdf5
# 32/32 [==============================] - 12s 370ms/step - loss: 2.6664 - accuracy: 0.5741 - val_loss: 2.6068 - val_accuracy: 0.5296
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.5584 - accuracy: 0.5554
# Epoch 00012: val_loss improved from 2.60678 to 2.50703, saving model to models\conv1d_multivar\classification\12.hdf5
# 32/32 [==============================] - 11s 353ms/step - loss: 2.5558 - accuracy: 0.5573 - val_loss: 2.5070 - val_accuracy: 0.5167
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.4735 - accuracy: 0.5433
# Epoch 00013: val_loss improved from 2.50703 to 2.41062, saving model to models\conv1d_multivar\classification\13.hdf5
# 32/32 [==============================] - 12s 365ms/step - loss: 2.4713 - accuracy: 0.5435 - val_loss: 2.4106 - val_accuracy: 0.5321
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.3685 - accuracy: 0.5544
# Epoch 00014: val_loss improved from 2.41062 to 2.32306, saving model to models\conv1d_multivar\classification\14.hdf5
# 32/32 [==============================] - 11s 353ms/step - loss: 2.3678 - accuracy: 0.5553 - val_loss: 2.3231 - val_accuracy: 0.5244
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2913 - accuracy: 0.5938
# Epoch 00015: val_loss improved from 2.32306 to 2.27575, saving model to models\conv1d_multivar\classification\15.hdf5
# 32/32 [==============================] - 12s 366ms/step - loss: 2.2907 - accuracy: 0.5939 - val_loss: 2.2757 - val_accuracy: 0.5501
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2594 - accuracy: 0.5454
# Epoch 00016: val_loss improved from 2.27575 to 2.23205, saving model to models\conv1d_multivar\classification\16.hdf5
# 32/32 [==============================] - 12s 372ms/step - loss: 2.2572 - accuracy: 0.5455 - val_loss: 2.2320 - val_accuracy: 0.5604
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2136 - accuracy: 0.5726
# Epoch 00017: val_loss improved from 2.23205 to 2.19139, saving model to models\conv1d_multivar\classification\17.hdf5
# 32/32 [==============================] - 11s 351ms/step - loss: 2.2130 - accuracy: 0.5721 - val_loss: 2.1914 - val_accuracy: 0.5501
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1713 - accuracy: 0.5524
# Epoch 00018: val_loss improved from 2.19139 to 2.15198, saving model to models\conv1d_multivar\classification\18.hdf5
# 32/32 [==============================] - 11s 354ms/step - loss: 2.1703 - accuracy: 0.5514 - val_loss: 2.1520 - val_accuracy: 0.5501
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1213 - accuracy: 0.5454
# Epoch 00019: val_loss improved from 2.15198 to 2.11345, saving model to models\conv1d_multivar\classification\19.hdf5
# 32/32 [==============================] - 12s 364ms/step - loss: 2.1237 - accuracy: 0.5415 - val_loss: 2.1134 - val_accuracy: 0.5527
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1086 - accuracy: 0.5484
# Epoch 00020: val_loss improved from 2.11345 to 2.09266, saving model to models\conv1d_multivar\classification\20.hdf5
# 32/32 [==============================] - 12s 365ms/step - loss: 2.1102 - accuracy: 0.5484 - val_loss: 2.0927 - val_accuracy: 0.5553
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0735 - accuracy: 0.5917
# Epoch 00021: val_loss improved from 2.09266 to 2.07339, saving model to models\conv1d_multivar\classification\21.hdf5
# 32/32 [==============================] - 11s 343ms/step - loss: 2.0754 - accuracy: 0.5919 - val_loss: 2.0734 - val_accuracy: 0.5527
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0648 - accuracy: 0.5696
# Epoch 00022: val_loss improved from 2.07339 to 2.05528, saving model to models\conv1d_multivar\classification\22.hdf5
# 32/32 [==============================] - 12s 363ms/step - loss: 2.0628 - accuracy: 0.5702 - val_loss: 2.0553 - val_accuracy: 0.5424
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0319 - accuracy: 0.5887
# Epoch 00023: val_loss improved from 2.05528 to 2.03728, saving model to models\conv1d_multivar\classification\23.hdf5
# 32/32 [==============================] - 12s 362ms/step - loss: 2.0288 - accuracy: 0.5919 - val_loss: 2.0373 - val_accuracy: 0.5347
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0282 - accuracy: 0.5504
# Epoch 00024: val_loss improved from 2.03728 to 2.01993, saving model to models\conv1d_multivar\classification\24.hdf5
# 32/32 [==============================] - 12s 362ms/step - loss: 2.0287 - accuracy: 0.5474 - val_loss: 2.0199 - val_accuracy: 0.5244
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0075 - accuracy: 0.5927
# Epoch 00025: val_loss improved from 2.01993 to 2.00979, saving model to models\conv1d_multivar\classification\25.hdf5
# 32/32 [==============================] - 11s 358ms/step - loss: 2.0059 - accuracy: 0.5958 - val_loss: 2.0098 - val_accuracy: 0.5296
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9930 - accuracy: 0.5756
# Epoch 00026: val_loss improved from 2.00979 to 2.00107, saving model to models\conv1d_multivar\classification\26.hdf5
# 32/32 [==============================] - 11s 355ms/step - loss: 1.9932 - accuracy: 0.5731 - val_loss: 2.0011 - val_accuracy: 0.5373
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.0037 - accuracy: 0.5585
# Epoch 00027: val_loss improved from 2.00107 to 1.99237, saving model to models\conv1d_multivar\classification\27.hdf5
# 32/32 [==============================] - 12s 362ms/step - loss: 1.9988 - accuracy: 0.5632 - val_loss: 1.9924 - val_accuracy: 0.5347
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9834 - accuracy: 0.5494
# Epoch 00028: val_loss improved from 1.99237 to 1.98412, saving model to models\conv1d_multivar\classification\28.hdf5
# 32/32 [==============================] - 11s 354ms/step - loss: 1.9822 - accuracy: 0.5504 - val_loss: 1.9841 - val_accuracy: 0.5373
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9746 - accuracy: 0.5716
# Epoch 00029: val_loss improved from 1.98412 to 1.97583, saving model to models\conv1d_multivar\classification\29.hdf5
# 32/32 [==============================] - 11s 359ms/step - loss: 1.9730 - accuracy: 0.5721 - val_loss: 1.9758 - val_accuracy: 0.5398
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9635 - accuracy: 0.5766
# Epoch 00030: val_loss improved from 1.97583 to 1.97115, saving model to models\conv1d_multivar\classification\30.hdf5
# 32/32 [==============================] - 11s 349ms/step - loss: 1.9650 - accuracy: 0.5741 - val_loss: 1.9711 - val_accuracy: 0.5398
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9725 - accuracy: 0.5413
# Epoch 00031: val_loss improved from 1.97115 to 1.96686, saving model to models\conv1d_multivar\classification\31.hdf5
# 32/32 [==============================] - 11s 344ms/step - loss: 1.9714 - accuracy: 0.5425 - val_loss: 1.9669 - val_accuracy: 0.5424
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 31/32 [============================>.] - ETA: 0s - loss: 1.9588 - accuracy: 0.5635
# Epoch 00032: val_loss improved from 1.96686 to 1.96285, saving model to models\conv1d_multivar\classification\32.hdf5
# 32/32 [==============================] - 11s 346ms/step - loss: 1.9594 - accuracy: 0.5603 - val_loss: 1.9629 - val_accuracy: 0.5424

# %%
def plot_clf_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'Loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'Accuracy', 'accuracy', 'val_accuracy')
    
plot_clf_history(clf_history);

# %% [markdown]
# ### Прогноз задачи классификации

# %%
# загружаем последнюю эпоху с минимальным лоссом
multivariate_classification_conv1d.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %%
pred_direction_proba = multivariate_classification_conv1d.predict_generator(test_clf_gen, verbose=1)

true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 13/13 [==============================] - 1s 62ms/step
# 0.49232543

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([203, 186], dtype=int64)),
#  (array([0, 1]), array([204, 185], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.56      0.56       203
#            1       0.52      0.52      0.52       186
#
#     accuracy                           0.54       389
#    macro avg       0.54      0.54      0.54       389
# weighted avg       0.54      0.54      0.54       389

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[114,  89],
#        [ 90,  96]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.55882353, 0.48108108],
#        [0.44117647, 0.51891892]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# ## Многозадачная модель: одновременно регрессия и классификация

# %%
model_class_name = 'multitask'

# %%
train_multi_gen = MultitaskGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_multi_gen = MultitaskGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_multi_gen = MultitaskGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_multitask_model(input_shape):
    inp, conv1d = build_conv1d_layers(input_shape, filters=(32, 16, 8))

    # первый выход: задача регрссии
    regr = Dense(64)(conv1d)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.25)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    # второй выход: задача классификации
    clf = Dense(64)(conv1d)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.25)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)
    
    return Model(inputs=[inp], outputs=[regr, clf])

# %%
multivariate_multitask_conv1d = build_multitask_model(train_multi_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
multivariate_multitask_conv1d.compile(optimizer=optimizer,
                                      loss={'regr': 'mse', 'clf': 'binary_crossentropy'},
                                      loss_weights={'regr': 1., 'clf': 1.},
                                      metrics={'regr': 'mae', 'clf' : 'accuracy'})

multivariate_multitask_conv1d.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 120, 18)]    0
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 120, 32)      1760        input[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 120, 32)      128         conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 120, 32)      0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 120, 32)      0           leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 120, 16)      1552        dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 120, 16)      64          conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 120, 16)      0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 120, 16)      0           leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 60, 16)       0           dropout_11[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 60, 16)       784         max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 60, 16)       64          conv1d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 60, 16)       0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 60, 16)       0           leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 60, 8)        392         dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 60, 8)        32          conv1d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 60, 8)        0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 60, 8)        0           leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 30, 8)        0           dropout_13[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 240)          0           max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           15424       flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           15424       flatten_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64)           256         dense_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64)           256         dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 64)           0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 64)           0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 64)           0           leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 64)           0           leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# regr (Dense)                    (None, 1)            65          dropout_14[0][0]
# __________________________________________________________________________________________________
# clf (Dense)                     (None, 1)            65          dropout_15[0][0]
# ==================================================================================================
# Total params: 36,266
# Trainable params: 35,866
# Non-trainable params: 400
# __________________________________________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
multitask_history = utils.train_model(multivariate_multitask_conv1d,
                                      model_save_dir, train_multi_gen, test_multi_gen,
                                      callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                      force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 0s - loss: 9.1663 - regr_loss: 1.9516 - clf_loss: 0.7964 - regr_mae: 0.9622 - clf_accuracy: 0.5050
# Epoch 00001: val_loss improved from inf to 8.37377, saving model to models\conv1d_multivar\multitask\01.hdf5
# 32/32 [==============================] - 14s 436ms/step - loss: 9.1563 - regr_loss: 1.9469 - clf_loss: 0.7938 - regr_mae: 0.9655 - clf_accuracy: 0.5049 - val_loss: 8.3738 - val_regr_loss: 1.2841 - val_clf_loss: 0.7713 - val_regr_mae: 0.7564 - val_clf_accuracy: 0.4781
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.6220 - regr_loss: 1.6067 - clf_loss: 0.7978 - regr_mae: 0.8565 - clf_accuracy: 0.4929
# Epoch 00002: val_loss improved from 8.37377 to 8.01002, saving model to models\conv1d_multivar\multitask\02.hdf5
# 32/32 [==============================] - 14s 429ms/step - loss: 8.6222 - regr_loss: 1.6100 - clf_loss: 0.7981 - regr_mae: 0.8609 - clf_accuracy: 0.4911 - val_loss: 8.0100 - val_regr_loss: 1.1715 - val_clf_loss: 0.7372 - val_regr_mae: 0.7053 - val_clf_accuracy: 0.4807
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.2252 - regr_loss: 1.4654 - clf_loss: 0.7645 - regr_mae: 0.8201 - clf_accuracy: 0.5071
# Epoch 00003: val_loss improved from 8.01002 to 7.72201, saving model to models\conv1d_multivar\multitask\03.hdf5
# 32/32 [==============================] - 14s 422ms/step - loss: 8.2344 - regr_loss: 1.4766 - clf_loss: 0.7662 - regr_mae: 0.8251 - clf_accuracy: 0.5040 - val_loss: 7.7220 - val_regr_loss: 1.1348 - val_clf_loss: 0.7126 - val_regr_mae: 0.6892 - val_clf_accuracy: 0.4961
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.7509 - regr_loss: 1.2494 - clf_loss: 0.7363 - regr_mae: 0.7627 - clf_accuracy: 0.5353
# Epoch 00004: val_loss improved from 7.72201 to 7.48157, saving model to models\conv1d_multivar\multitask\04.hdf5
# 32/32 [==============================] - 14s 435ms/step - loss: 7.7432 - regr_loss: 1.2473 - clf_loss: 0.7343 - regr_mae: 0.7638 - clf_accuracy: 0.5356 - val_loss: 7.4816 - val_regr_loss: 1.1361 - val_clf_loss: 0.7055 - val_regr_mae: 0.6853 - val_clf_accuracy: 0.5244
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.5380 - regr_loss: 1.1995 - clf_loss: 0.7561 - regr_mae: 0.7450 - clf_accuracy: 0.5050
# Epoch 00005: val_loss improved from 7.48157 to 7.33280, saving model to models\conv1d_multivar\multitask\05.hdf5
# 32/32 [==============================] - 14s 428ms/step - loss: 7.5191 - regr_loss: 1.1818 - clf_loss: 0.7565 - regr_mae: 0.7432 - clf_accuracy: 0.5059 - val_loss: 7.3328 - val_regr_loss: 1.1192 - val_clf_loss: 0.6967 - val_regr_mae: 0.6755 - val_clf_accuracy: 0.5424
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.4850 - regr_loss: 1.2975 - clf_loss: 0.7295 - regr_mae: 0.7591 - clf_accuracy: 0.5454
# Epoch 00006: val_loss improved from 7.33280 to 7.20261, saving model to models\conv1d_multivar\multitask\06.hdf5
# 32/32 [==============================] - 14s 434ms/step - loss: 7.4866 - regr_loss: 1.2950 - clf_loss: 0.7356 - regr_mae: 0.7606 - clf_accuracy: 0.5395 - val_loss: 7.2026 - val_regr_loss: 1.1158 - val_clf_loss: 0.6961 - val_regr_mae: 0.6747 - val_clf_accuracy: 0.5347
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.2629 - regr_loss: 1.2061 - clf_loss: 0.7264 - regr_mae: 0.7383 - clf_accuracy: 0.5353
# Epoch 00007: val_loss improved from 7.20261 to 7.05648, saving model to models\conv1d_multivar\multitask\07.hdf5
# 32/32 [==============================] - 14s 427ms/step - loss: 7.2566 - regr_loss: 1.2020 - clf_loss: 0.7261 - regr_mae: 0.7373 - clf_accuracy: 0.5356 - val_loss: 7.0565 - val_regr_loss: 1.1003 - val_clf_loss: 0.6943 - val_regr_mae: 0.6710 - val_clf_accuracy: 0.5347
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.1718 - regr_loss: 1.2342 - clf_loss: 0.7372 - regr_mae: 0.7425 - clf_accuracy: 0.5010
# Epoch 00008: val_loss improved from 7.05648 to 6.93105, saving model to models\conv1d_multivar\multitask\08.hdf5
# 32/32 [==============================] - 13s 413ms/step - loss: 7.1835 - regr_loss: 1.2466 - clf_loss: 0.7387 - regr_mae: 0.7449 - clf_accuracy: 0.5010 - val_loss: 6.9310 - val_regr_loss: 1.1034 - val_clf_loss: 0.6962 - val_regr_mae: 0.6709 - val_clf_accuracy: 0.5296
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.0059 - regr_loss: 1.2119 - clf_loss: 0.7254 - regr_mae: 0.7295 - clf_accuracy: 0.5252
# Epoch 00009: val_loss improved from 6.93105 to 6.79755, saving model to models\conv1d_multivar\multitask\09.hdf5
# 32/32 [==============================] - 13s 420ms/step - loss: 6.9863 - regr_loss: 1.1959 - clf_loss: 0.7236 - regr_mae: 0.7289 - clf_accuracy: 0.5267 - val_loss: 6.7975 - val_regr_loss: 1.1031 - val_clf_loss: 0.6966 - val_regr_mae: 0.6695 - val_clf_accuracy: 0.5013
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.8413 - regr_loss: 1.1681 - clf_loss: 0.7071 - regr_mae: 0.7247 - clf_accuracy: 0.5403
# Epoch 00010: val_loss improved from 6.79755 to 6.72658, saving model to models\conv1d_multivar\multitask\10.hdf5
# 32/32 [==============================] - 14s 448ms/step - loss: 6.8325 - regr_loss: 1.1604 - clf_loss: 0.7071 - regr_mae: 0.7256 - clf_accuracy: 0.5366 - val_loss: 6.7266 - val_regr_loss: 1.0990 - val_clf_loss: 0.6978 - val_regr_mae: 0.6669 - val_clf_accuracy: 0.5064
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.7914 - regr_loss: 1.1737 - clf_loss: 0.7200 - regr_mae: 0.7122 - clf_accuracy: 0.5252
# Epoch 00011: val_loss improved from 6.72658 to 6.65631, saving model to models\conv1d_multivar\multitask\11.hdf5
# 32/32 [==============================] - 14s 429ms/step - loss: 6.7761 - regr_loss: 1.1608 - clf_loss: 0.7185 - regr_mae: 0.7125 - clf_accuracy: 0.5267 - val_loss: 6.6563 - val_regr_loss: 1.0976 - val_clf_loss: 0.6976 - val_regr_mae: 0.6662 - val_clf_accuracy: 0.5244
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.7379 - regr_loss: 1.1802 - clf_loss: 0.7285 - regr_mae: 0.7034 - clf_accuracy: 0.5212
# Epoch 00012: val_loss improved from 6.65631 to 6.59181, saving model to models\conv1d_multivar\multitask\12.hdf5
# 32/32 [==============================] - 14s 428ms/step - loss: 6.7248 - regr_loss: 1.1694 - clf_loss: 0.7273 - regr_mae: 0.7048 - clf_accuracy: 0.5227 - val_loss: 6.5918 - val_regr_loss: 1.1024 - val_clf_loss: 0.6968 - val_regr_mae: 0.6693 - val_clf_accuracy: 0.5296
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.5444 - regr_loss: 1.0817 - clf_loss: 0.7028 - regr_mae: 0.6800 - clf_accuracy: 0.5565
# Epoch 00013: val_loss improved from 6.59181 to 6.52475, saving model to models\conv1d_multivar\multitask\13.hdf5
# 32/32 [==============================] - 14s 439ms/step - loss: 6.5203 - regr_loss: 1.0614 - clf_loss: 0.6998 - regr_mae: 0.6776 - clf_accuracy: 0.5563 - val_loss: 6.5248 - val_regr_loss: 1.1044 - val_clf_loss: 0.6977 - val_regr_mae: 0.6715 - val_clf_accuracy: 0.4936
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.5356 - regr_loss: 1.1341 - clf_loss: 0.7121 - regr_mae: 0.6970 - clf_accuracy: 0.5484
# Epoch 00014: val_loss improved from 6.52475 to 6.45504, saving model to models\conv1d_multivar\multitask\14.hdf5
# 32/32 [==============================] - 13s 412ms/step - loss: 6.5193 - regr_loss: 1.1181 - clf_loss: 0.7128 - regr_mae: 0.6958 - clf_accuracy: 0.5474 - val_loss: 6.4550 - val_regr_loss: 1.1064 - val_clf_loss: 0.6966 - val_regr_mae: 0.6718 - val_clf_accuracy: 0.5116
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.4559 - regr_loss: 1.1177 - clf_loss: 0.7032 - regr_mae: 0.6973 - clf_accuracy: 0.5575
# Epoch 00015: val_loss improved from 6.45504 to 6.41979, saving model to models\conv1d_multivar\multitask\15.hdf5
# 32/32 [==============================] - 13s 420ms/step - loss: 6.4467 - regr_loss: 1.1097 - clf_loss: 0.7024 - regr_mae: 0.6986 - clf_accuracy: 0.5593 - val_loss: 6.4198 - val_regr_loss: 1.1076 - val_clf_loss: 0.6963 - val_regr_mae: 0.6723 - val_clf_accuracy: 0.5141
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.4149 - regr_loss: 1.1120 - clf_loss: 0.7042 - regr_mae: 0.6876 - clf_accuracy: 0.5534
# Epoch 00016: val_loss improved from 6.41979 to 6.38213, saving model to models\conv1d_multivar\multitask\16.hdf5
# 32/32 [==============================] - 14s 437ms/step - loss: 6.4083 - regr_loss: 1.1057 - clf_loss: 0.7044 - regr_mae: 0.6887 - clf_accuracy: 0.5534 - val_loss: 6.3821 - val_regr_loss: 1.1063 - val_clf_loss: 0.6966 - val_regr_mae: 0.6720 - val_clf_accuracy: 0.5167
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.4861 - regr_loss: 1.2053 - clf_loss: 0.7183 - regr_mae: 0.7182 - clf_accuracy: 0.5312
# Epoch 00017: val_loss improved from 6.38213 to 6.34243, saving model to models\conv1d_multivar\multitask\17.hdf5
# 32/32 [==============================] - 14s 434ms/step - loss: 6.4742 - regr_loss: 1.1925 - clf_loss: 0.7199 - regr_mae: 0.7173 - clf_accuracy: 0.5267 - val_loss: 6.3424 - val_regr_loss: 1.1032 - val_clf_loss: 0.6962 - val_regr_mae: 0.6705 - val_clf_accuracy: 0.5193
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.3852 - regr_loss: 1.1414 - clf_loss: 0.7178 - regr_mae: 0.7066 - clf_accuracy: 0.5474
# Epoch 00018: val_loss improved from 6.34243 to 6.30886, saving model to models\conv1d_multivar\multitask\18.hdf5
# 32/32 [==============================] - 14s 433ms/step - loss: 6.3849 - regr_loss: 1.1421 - clf_loss: 0.7175 - regr_mae: 0.7084 - clf_accuracy: 0.5474 - val_loss: 6.3089 - val_regr_loss: 1.1069 - val_clf_loss: 0.6955 - val_regr_mae: 0.6712 - val_clf_accuracy: 0.5321
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.2908 - regr_loss: 1.0852 - clf_loss: 0.7162 - regr_mae: 0.6891 - clf_accuracy: 0.5474
# Epoch 00019: val_loss improved from 6.30886 to 6.27154, saving model to models\conv1d_multivar\multitask\19.hdf5
# 32/32 [==============================] - 14s 430ms/step - loss: 6.2906 - regr_loss: 1.0876 - clf_loss: 0.7142 - regr_mae: 0.6905 - clf_accuracy: 0.5494 - val_loss: 6.2715 - val_regr_loss: 1.1061 - val_clf_loss: 0.6954 - val_regr_mae: 0.6703 - val_clf_accuracy: 0.5321
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.2458 - regr_loss: 1.0754 - clf_loss: 0.7092 - regr_mae: 0.6802 - clf_accuracy: 0.5454
# Epoch 00020: val_loss improved from 6.27154 to 6.25334, saving model to models\conv1d_multivar\multitask\20.hdf5
# 32/32 [==============================] - 14s 422ms/step - loss: 6.2348 - regr_loss: 1.0610 - clf_loss: 0.7128 - regr_mae: 0.6804 - clf_accuracy: 0.5425 - val_loss: 6.2533 - val_regr_loss: 1.1065 - val_clf_loss: 0.6957 - val_regr_mae: 0.6702 - val_clf_accuracy: 0.5270
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.2679 - regr_loss: 1.1078 - clf_loss: 0.7179 - regr_mae: 0.6959 - clf_accuracy: 0.5413
# Epoch 00021: val_loss improved from 6.25334 to 6.23675, saving model to models\conv1d_multivar\multitask\21.hdf5
# 32/32 [==============================] - 14s 427ms/step - loss: 6.2590 - regr_loss: 1.0911 - clf_loss: 0.7259 - regr_mae: 0.6939 - clf_accuracy: 0.5395 - val_loss: 6.2367 - val_regr_loss: 1.1082 - val_clf_loss: 0.6962 - val_regr_mae: 0.6709 - val_clf_accuracy: 0.5321
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.2338 - regr_loss: 1.1057 - clf_loss: 0.7046 - regr_mae: 0.6895 - clf_accuracy: 0.5504
# Epoch 00022: val_loss improved from 6.23675 to 6.21789, saving model to models\conv1d_multivar\multitask\22.hdf5
# 32/32 [==============================] - 14s 425ms/step - loss: 6.2274 - regr_loss: 1.1030 - clf_loss: 0.7012 - regr_mae: 0.6917 - clf_accuracy: 0.5534 - val_loss: 6.2179 - val_regr_loss: 1.1083 - val_clf_loss: 0.6963 - val_regr_mae: 0.6705 - val_clf_accuracy: 0.5270
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.1929 - regr_loss: 1.0779 - clf_loss: 0.7107 - regr_mae: 0.6891 - clf_accuracy: 0.5423
# Epoch 00023: val_loss improved from 6.21789 to 6.19872, saving model to models\conv1d_multivar\multitask\23.hdf5
# 32/32 [==============================] - 13s 418ms/step - loss: 6.1801 - regr_loss: 1.0680 - clf_loss: 0.7079 - regr_mae: 0.6902 - clf_accuracy: 0.5455 - val_loss: 6.1987 - val_regr_loss: 1.1081 - val_clf_loss: 0.6963 - val_regr_mae: 0.6704 - val_clf_accuracy: 0.5321
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.2058 - regr_loss: 1.1126 - clf_loss: 0.7079 - regr_mae: 0.6791 - clf_accuracy: 0.5534
# Epoch 00024: val_loss improved from 6.19872 to 6.17985, saving model to models\conv1d_multivar\multitask\24.hdf5
# 32/32 [==============================] - 13s 418ms/step - loss: 6.1828 - regr_loss: 1.0889 - clf_loss: 0.7086 - regr_mae: 0.6754 - clf_accuracy: 0.5534 - val_loss: 6.1799 - val_regr_loss: 1.1080 - val_clf_loss: 0.6966 - val_regr_mae: 0.6700 - val_clf_accuracy: 0.5296
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.1345 - regr_loss: 1.0543 - clf_loss: 0.7095 - regr_mae: 0.6693 - clf_accuracy: 0.5262
# Epoch 00025: val_loss improved from 6.17985 to 6.16832, saving model to models\conv1d_multivar\multitask\25.hdf5
# 32/32 [==============================] - 13s 422ms/step - loss: 6.1296 - regr_loss: 1.0449 - clf_loss: 0.7142 - regr_mae: 0.6701 - clf_accuracy: 0.5267 - val_loss: 6.1683 - val_regr_loss: 1.1065 - val_clf_loss: 0.6964 - val_regr_mae: 0.6690 - val_clf_accuracy: 0.5398
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.1618 - regr_loss: 1.0868 - clf_loss: 0.7142 - regr_mae: 0.6852 - clf_accuracy: 0.5514
# Epoch 00026: val_loss improved from 6.16832 to 6.15612, saving model to models\conv1d_multivar\multitask\26.hdf5
# 32/32 [==============================] - 14s 440ms/step - loss: 6.1451 - regr_loss: 1.0685 - clf_loss: 0.7157 - regr_mae: 0.6827 - clf_accuracy: 0.5504 - val_loss: 6.1561 - val_regr_loss: 1.1041 - val_clf_loss: 0.6964 - val_regr_mae: 0.6678 - val_clf_accuracy: 0.5424
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.1539 - regr_loss: 1.1229 - clf_loss: 0.6801 - regr_mae: 0.6916 - clf_accuracy: 0.5696
# Epoch 00027: val_loss improved from 6.15612 to 6.14470, saving model to models\conv1d_multivar\multitask\27.hdf5
# 32/32 [==============================] - 14s 422ms/step - loss: 6.1320 - regr_loss: 1.1026 - clf_loss: 0.6784 - regr_mae: 0.6885 - clf_accuracy: 0.5721 - val_loss: 6.1447 - val_regr_loss: 1.1029 - val_clf_loss: 0.6961 - val_regr_mae: 0.6672 - val_clf_accuracy: 0.5347
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.0769 - regr_loss: 1.0376 - clf_loss: 0.6983 - regr_mae: 0.6572 - clf_accuracy: 0.5675
# Epoch 00028: val_loss improved from 6.14470 to 6.13586, saving model to models\conv1d_multivar\multitask\28.hdf5
# 32/32 [==============================] - 13s 414ms/step - loss: 6.0682 - regr_loss: 1.0331 - clf_loss: 0.6942 - regr_mae: 0.6611 - clf_accuracy: 0.5702 - val_loss: 6.1359 - val_regr_loss: 1.1038 - val_clf_loss: 0.6962 - val_regr_mae: 0.6677 - val_clf_accuracy: 0.5501
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.1652 - regr_loss: 1.1404 - clf_loss: 0.6936 - regr_mae: 0.6919 - clf_accuracy: 0.5474
# Epoch 00029: val_loss improved from 6.13586 to 6.12688, saving model to models\conv1d_multivar\multitask\29.hdf5
# 32/32 [==============================] - 13s 416ms/step - loss: 6.1678 - regr_loss: 1.1417 - clf_loss: 0.6950 - regr_mae: 0.6939 - clf_accuracy: 0.5484 - val_loss: 6.1269 - val_regr_loss: 1.1047 - val_clf_loss: 0.6961 - val_regr_mae: 0.6681 - val_clf_accuracy: 0.5476
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.1011 - regr_loss: 1.0706 - clf_loss: 0.7067 - regr_mae: 0.6750 - clf_accuracy: 0.5736
# Epoch 00030: val_loss improved from 6.12688 to 6.12079, saving model to models\conv1d_multivar\multitask\30.hdf5
# 32/32 [==============================] - 14s 426ms/step - loss: 6.0905 - regr_loss: 1.0597 - clf_loss: 0.7070 - regr_mae: 0.6758 - clf_accuracy: 0.5751 - val_loss: 6.1208 - val_regr_loss: 1.1035 - val_clf_loss: 0.6962 - val_regr_mae: 0.6673 - val_clf_accuracy: 0.5450
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.1202 - regr_loss: 1.1089 - clf_loss: 0.6926 - regr_mae: 0.6871 - clf_accuracy: 0.5655
# Epoch 00031: val_loss improved from 6.12079 to 6.11561, saving model to models\conv1d_multivar\multitask\31.hdf5
# 32/32 [==============================] - 13s 417ms/step - loss: 6.0987 - regr_loss: 1.0910 - clf_loss: 0.6888 - regr_mae: 0.6855 - clf_accuracy: 0.5682 - val_loss: 6.1156 - val_regr_loss: 1.1033 - val_clf_loss: 0.6963 - val_regr_mae: 0.6668 - val_clf_accuracy: 0.5424
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.0886 - regr_loss: 1.0718 - clf_loss: 0.7031 - regr_mae: 0.6830 - clf_accuracy: 0.5343
# Epoch 00032: val_loss improved from 6.11561 to 6.11110, saving model to models\conv1d_multivar\multitask\32.hdf5
# 32/32 [==============================] - 13s 416ms/step - loss: 6.0796 - regr_loss: 1.0644 - clf_loss: 0.7015 - regr_mae: 0.6834 - clf_accuracy: 0.5336 - val_loss: 6.1111 - val_regr_loss: 1.1038 - val_clf_loss: 0.6963 - val_regr_mae: 0.6669 - val_clf_accuracy: 0.5424

# %%
def plot_multitask_history(hist):
    fig, ax = plt.subplots(2, 2, figsize=(16, 12))
    plotHelpers.plot_train_history(ax[0, 0], hist, 'Total loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[0, 1], hist, 'Accuracy', 'clf_accuracy', 'val_clf_accuracy')
    plotHelpers.plot_train_history(ax[1, 0], hist, 'MSE', 'regr_loss', 'val_regr_loss')
    plotHelpers.plot_train_history(ax[1, 1], hist, 'MAE', 'regr_mae', 'val_regr_mae')
    
plot_multitask_history(multitask_history);

# %% [markdown]
# ### Прогноз

# %%
# загружаем последнюю эпоху с минимальным лоссом
multivariate_multitask_conv1d.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret, pred_direction_proba = multivariate_multitask_conv1d.predict_generator(test_multi_gen, verbose=1)
# Out:
# 13/13 [==============================] - 1s 71ms/step

# %%
np.set_printoptions(precision=3, suppress=True)

np.column_stack([pred_log_ret, pred_direction_proba])[-10:]
# Out:
# array([[ 0.069,  0.468],
#        [-0.065,  0.477],
#        [-0.039,  0.475],
#        [-0.131,  0.466],
#        [-0.053,  0.52 ],
#        [-0.063,  0.539],
#        [ 0.091,  0.564],
#        [ 0.1  ,  0.557],
#        [ 0.074,  0.521],
#        [ 0.09 ,  0.509]], dtype=float32)

# %% [markdown]
# #### Прогноз задачи регрессии

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret, figsize=(16, 10),
                                  datetime_unit='m', xlabel='Time', plot_data_slice=slice(1, None))

# %% [markdown]
# #### Прогноз задачи классификации

# %%
true_direction = test_multi_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 0.47970012

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([203, 186], dtype=int64)),
#  (array([0, 1]), array([216, 173], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.59      0.57       203
#            1       0.52      0.48      0.50       186
#
#     accuracy                           0.54       389
#    macro avg       0.54      0.54      0.54       389
# weighted avg       0.54      0.54      0.54       389

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[120,  83],
#        [ 96,  90]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.556, 0.48 ],
#        [0.444, 0.52 ]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# # Выводы
#
# 1.  Модель с 1D свёртками обучается гораздо быстрее модели LSTM
# 2.  Задача классификации не решается удовлетворительно.

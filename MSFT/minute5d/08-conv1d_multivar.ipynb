# %% [markdown]
# <a href="https://colab.research.google.com/github/rklepov/hse-cs-ml-2018-2019-grad-work/blob/CVX-1yr/CVX/daily1y/08_conv1d_multivar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # *Многомерная модель на 1D свёрточных слоях*
#
# В качестве признаков используются цены, объём торгов и некоторое число индикаторов (всего 18 признаков)

# %%
import os
import glob
import datetime
import pickle

import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from pandas_datareader import data as pdr

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
import tensorflow as tf
# tf.test.is_gpu_available()
tf.__version__
# Out:
# '2.0.0'

# %%
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import (Input, Dense, Convolution1D, MaxPooling1D, Flatten,
                                     ReLU, LeakyReLU, Dropout, BatchNormalization)
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers import Nadam

# %%
from mdp import TimeSeries
from mdp import MarketData
from mdp import MovingWindowFeatures
from mdp import ClassificationGenerator, RegressionGenerator, MultitaskGenerator
from mdp import invert_log_ret

import mdp.utils as utils
import mdp.plotHelpers as plotHelpers

# %%
import importlib

import mdp

importlib.reload(mdp)
importlib.reload(mdp.datasetGenerator)
importlib.reload(mdp.marketData)
importlib.reload(mdp.movingWindowFeatures)
importlib.reload(mdp.timeSeries)
importlib.reload(mdp.plotHelpers)
importlib.reload(mdp.utils);

# %% [markdown]
# # *Параметры*

# %%
INSTRUMENT = 'MSFT' # Microsoft corp
START_FROM = np.datetime64('today') - 7
WINDOW_SIZE = 120
FORECAST_OFFSET=1
BATCH_SIZE = 32
FORCE_TRAIN = True

# %% [markdown]
# # *Исходные данные*
#
# Загрузка данных и вычисление индикаторов.

# %%
instr = MarketData.create_from_alphavantage_intraday(INSTRUMENT, start=START_FROM)

# %%
instr.feature_names
# Out:
# ['o',
#  'h',
#  'l',
#  'c',
#  'v',
#  'ema14',
#  'ema30',
#  'macd',
#  'macd_signal',
#  'rsi14',
#  'bband20_upper',
#  'bband20_middle',
#  'bband20_lower',
#  'willr14',
#  'stochk',
#  'stochd',
#  'adline',
#  'adosc']

# %% [markdown]
# Здесь не будем делить отдельно на тест и валидацию, поскольку данных у нас только 5 дней.

# %%
dates_unique = np.unique(instr.timestamps.astype('datetime64[D]'))

START_FROM = dates_unique[0]
VAL_TEST_SPLIT = dates_unique[-1]

START_FROM, VAL_TEST_SPLIT
# Out:
# (numpy.datetime64('2020-04-08'), numpy.datetime64('2020-04-14'))

# %% [markdown]
# ## Целевая переменная

# %% [markdown]
# Цена закрытия.

# %%
orig_target = instr.c

# %%
def plot_transformed_series(instrument, series, orig_display_name, transformed_display_name):
    plotHelpers.plot_transformed_timeseries(
        instrument.instrument,
        series,
        title_orig = orig_display_name,
        xlabel_orig = 'Date',
        ylabel_orig = orig_display_name,
        title_transformed = transformed_display_name,
        xlabel_transformed = 'Date',
        ylabel_transformed = transformed_display_name
    )

# %% [markdown]
# Переходим к логарифмической доходности.

# %%
transformed_target = instr.c.transform(transforms={'ratios' : {}, 'ln' : {}})

# %%
plotHelpers.plot_transformed_timeseries_unit(instr,
                                             transformed_target,
                                             'Price, USD', 'Log return',
                                             datetime_unit='m', rotation=45)

# %% [markdown]
# ## Трансформация признаков
#
# Приведение временных рядов к стационарности.

# %%
def make_feature_selector():
    price_transformer = lambda: {'ratios': {}, 'ln': {}}
    diff_transformer = lambda o: {'diffs': {'order': o}}
    identity_transformer = lambda: {}
    feature_transformations = {
        'o': price_transformer(),
        'h': price_transformer(),
        'l': price_transformer(),
        'c': price_transformer(),
        'v': diff_transformer(1),
        'ema14': diff_transformer(1),
        'ema30': diff_transformer(1),
        'macd': identity_transformer(),
        'macd_signal': identity_transformer(),
        'rsi14': identity_transformer(),
        'bband20_upper': diff_transformer(1),
        'bband20_middle': diff_transformer(1),
        'bband20_lower': diff_transformer(1),
        'willr14': identity_transformer(),
        'stochd': identity_transformer(),
        'stochk': identity_transformer(),
        'adline': diff_transformer(1),
        'adosc': identity_transformer()
    }
    return feature_transformations

# %%
instr_transformed = instr.select_transform(make_feature_selector())

# %%
transformed_target = instr_transformed.c

# %% [markdown]
# ## Обучающая, валидационная и тестовая выборки

# %%
instr_train, instr_test = instr_transformed.train_test_split(VAL_TEST_SPLIT, window_size=WINDOW_SIZE,
                                                             scaler=StandardScaler)
#                                                              scaler=MinMaxScaler,
#                                                              scaler_kwargs={'feature_range': (-1, 1)})

# instr_val, instr_test = instr_val_test.train_test_split(TEST_SPLIT, window_size=WINDOW_SIZE, scaler=None)

len(instr_train), len(instr_test)
# Out:
# (1134, 508)

# %% [markdown]
# Все отмасштабированные признаки на одном графике (для валидационного датасета):

# %%
plotHelpers.plot_all_features(instr_test)

# %% [markdown]
# ## Признаки - скользящие окна

# %%
train_mwf = MovingWindowFeatures.create(instr_train.c, [instr_train], instr_train.feature_names, window_size=WINDOW_SIZE)
# val_mwf = MovingWindowFeatures.create(instr_val.c, [instr_val], instr_val.feature_names, window_size=WINDOW_SIZE)
test_mwf = MovingWindowFeatures.create(instr_test.c, [instr_test], instr_test.feature_names, window_size=WINDOW_SIZE)

len(instr_train), len(train_mwf), train_mwf.features.shape
# Out:
# (1134, 1014, (1014, 120, 18))

# %% [markdown]
# Проверка, что скользящие окна соответствуют исходным данным.
#
# Возьмём произвольный признак и произвольное окно (строка #**41**). Проверим, что данные в точности совпадают:

# %%
def check_data(md, mwf, row):
    col = np.random.randint(len(mwf.feature_names))
    feature = mwf.feature_names[col]
    check = (getattr(md, feature).data[row:row + mwf.window_size] == mwf.features[row, :, col]).all()
    assert check
    return feature, check

check_data(instr_train, train_mwf, 41)
# Out:
# ('l', True)

# %% [markdown]
# # *Модели*

# %% [markdown]
# Модель с двумя 1D свёрточными слоями.

# %%
def build_conv1d_layers(input_shape, filters=(32, 16, 8), kernel_size=3, pool_size=2):
    # формат входа: наша матрица (окно; признак)
    inp = Input(input_shape, name='input')

    filter_blocks = np.array(filters)
    filter_blocks = np.lib.stride_tricks.as_strided(filter_blocks, 
                                                    (filter_blocks.shape[0] - 1, 2), 
                                                    2 * [filter_blocks.strides[0]])
    conv1d = inp
    # стекаем слои Conv1D: блоками Conv1D-Conv1D-MaxPool
    for filter_block in filter_blocks:
        for f in filter_block:
            conv1d = Convolution1D(filters=f,
                                   kernel_size=kernel_size,
                                   padding='same',
                                   bias_initializer='he_uniform',
                                   bias_regularizer=L1L2(0.01, 0.02),
                                   kernel_regularizer=L1L2(0.01, 0.02)
                                  )(conv1d)
            conv1d = BatchNormalization()(conv1d)
            conv1d = LeakyReLU()(conv1d)
            conv1d = Dropout(0.25)(conv1d)
        conv1d = MaxPooling1D(pool_size=pool_size)(conv1d)
    
    conv1d = Flatten()(conv1d)
    
    return inp, conv1d

# %% [markdown]
# #### Пути:

# %%
model_path_root = 'models'
model_type_name = 'conv1d_multivar'

def make_model_save_dir(path_root, type_name, class_name):
    save_dir = os.path.join(path_root, type_name, class_name)
    os.makedirs(save_dir, exist_ok=True)
    return save_dir

# %% [markdown]
# #### Общие коллбэки:

# %%
# уменьшение learning rate в случае, если loss не изменяется
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001, verbose=1)

# уменьшение learning rate в 2 раза каждую 5-ю эпоху
def lr_decay(e, lr):
    return lr * (1 - 0.5 * (0 == (e + 1) % 5))

lr_scheduler = LearningRateScheduler(schedule=lr_decay, verbose=1)

# %% [markdown]
# ## Задача регрессии
#
# Непосредственное прогнозирование цены следующего периода.

# %%
train_regr_gen = RegressionGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_regr_gen = RegressionGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_regr_gen = RegressionGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# Следующие числа соответствуют значению параметра `steps_per_epoch` метода [`fit_generator`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit_generator "tf.keras.layers.SimpleRNN &nbsp;|&nbsp; TensorFlow Core r2.0") - то есть это число батчей, которые генератор выдаст за одну эпоху обучения (если класс генератора поддерживает метод `len()`, то данный параметр можно не указывать).

# %%
len(train_regr_gen), (test_regr_gen)
# Out:
# (32, <mdp.datasetGenerator.RegressionGenerator at 0x2c8a1a2ea08>)

# %% [markdown]
# Один сэмпл данных представляет собой матрицу размером *(длина окна; число признаков)*

# %%
train_regr_gen.input_shape
# Out:
# (120, 18)

# %% [markdown]
# ### Модель для задачи регрессии

# %%
model_class_name = 'regression'

# %%
def build_regression_model(input_shape):
    inp, conv1d = build_conv1d_layers(input_shape, filters=(32, 16, 8))

    regr = Dense(64)(conv1d)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.25)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    return Model(inputs=[inp], outputs=[regr])

# %%
multivariate_regression_conv1d = build_regression_model(train_regr_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:
# [`Nadam`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Nadam) (*Adam with Nestrov momentum*).

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Функция потерь:
#
# В качестве функции потерь будем использовать [MSE](https://www.tensorflow.org/api_docs/python/tf/keras/losses/MSE) (чтобы штрафовать за большие отклонения). Xотя хорошая функция потерь в контексте темы данной задачи - это [вопрос сложный](https://github.com/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Chapter5_LossFunctions/Ch5_LossFunctions_PyMC3.ipynb). В частности, здесь нам, очевидно, помимо абсолютного значения отклонения также важен его знак.

# %%
multivariate_regression_conv1d.compile(optimizer=optimizer,
                                       loss={'regr': 'mse'},
                                       metrics={'regr': 'mae'})

multivariate_regression_conv1d.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 120, 18)]         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 120, 32)           1760
# _________________________________________________________________
# batch_normalization (BatchNo (None, 120, 32)           128
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 120, 32)           0
# _________________________________________________________________
# dropout (Dropout)            (None, 120, 32)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 120, 16)           1552
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 120, 16)           64
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 120, 16)           0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 120, 16)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 60, 16)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 60, 16)            784
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 60, 16)            64
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 60, 16)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 60, 16)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 60, 8)             392
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 60, 8)             32
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 60, 8)             0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 60, 8)             0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 30, 8)             0
# _________________________________________________________________
# flatten (Flatten)            (None, 240)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                15424
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# regr (Dense)                 (None, 1)                 65
# =================================================================
# Total params: 20,521
# Trainable params: 20,249
# Non-trainable params: 272
# _________________________________________________________________

# %% [markdown]
# #### Обучение:

# %%
regr_history = utils.train_model(multivariate_regression_conv1d,
                                 model_save_dir, train_regr_gen, test_regr_gen,
                                 callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                 force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.5050 - mae: 1.0881
# Epoch 00001: val_loss improved from inf to 7.95438, saving model to models\conv1d_multivar\regression\01.hdf5
# 32/32 [==============================] - 15s 480ms/step - loss: 8.4642 - mae: 1.0814 - val_loss: 7.9544 - val_mae: 0.7341
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.8851 - mae: 0.9746
# Epoch 00002: val_loss improved from 7.95438 to 7.63707, saving model to models\conv1d_multivar\regression\02.hdf5
# 32/32 [==============================] - 11s 343ms/step - loss: 7.8656 - mae: 0.9737 - val_loss: 7.6371 - val_mae: 0.7051
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.4713 - mae: 0.9210
# Epoch 00003: val_loss improved from 7.63707 to 7.35540, saving model to models\conv1d_multivar\regression\03.hdf5
# 32/32 [==============================] - 11s 345ms/step - loss: 7.4874 - mae: 0.9275 - val_loss: 7.3554 - val_mae: 0.6861
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.1065 - mae: 0.8660
# Epoch 00004: val_loss improved from 7.35540 to 7.28894, saving model to models\conv1d_multivar\regression\04.hdf5
# 32/32 [==============================] - 11s 355ms/step - loss: 7.0862 - mae: 0.8637 - val_loss: 7.2889 - val_mae: 0.7517
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.9003 - mae: 0.8813
# Epoch 00005: val_loss improved from 7.28894 to 7.05073, saving model to models\conv1d_multivar\regression\05.hdf5
# 32/32 [==============================] - 14s 436ms/step - loss: 6.8897 - mae: 0.8812 - val_loss: 7.0507 - val_mae: 0.7027
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.7918 - mae: 0.8756
# Epoch 00006: val_loss improved from 7.05073 to 6.99568, saving model to models\conv1d_multivar\regression\06.hdf5
# 32/32 [==============================] - 13s 402ms/step - loss: 6.8123 - mae: 0.8764 - val_loss: 6.9957 - val_mae: 0.7299
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.5461 - mae: 0.8330
# Epoch 00007: val_loss improved from 6.99568 to 6.76031, saving model to models\conv1d_multivar\regression\07.hdf5
# 32/32 [==============================] - 13s 404ms/step - loss: 6.5289 - mae: 0.8301 - val_loss: 6.7603 - val_mae: 0.6856
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.4201 - mae: 0.8342
# Epoch 00008: val_loss improved from 6.76031 to 6.69503, saving model to models\conv1d_multivar\regression\08.hdf5
# 32/32 [==============================] - 13s 401ms/step - loss: 6.4099 - mae: 0.8347 - val_loss: 6.6950 - val_mae: 0.7132
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.2223 - mae: 0.8126
# Epoch 00009: val_loss improved from 6.69503 to 6.56690, saving model to models\conv1d_multivar\regression\09.hdf5
# 32/32 [==============================] - 13s 400ms/step - loss: 6.2442 - mae: 0.8189 - val_loss: 6.5669 - val_mae: 0.7124
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.1694 - mae: 0.8338
# Epoch 00010: val_loss improved from 6.56690 to 6.53689, saving model to models\conv1d_multivar\regression\10.hdf5
# 32/32 [==============================] - 13s 418ms/step - loss: 6.2182 - mae: 0.8399 - val_loss: 6.5369 - val_mae: 0.7296
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.1341 - mae: 0.8289
# Epoch 00011: val_loss improved from 6.53689 to 6.46784, saving model to models\conv1d_multivar\regression\11.hdf5
# 32/32 [==============================] - 14s 429ms/step - loss: 6.1349 - mae: 0.8308 - val_loss: 6.4678 - val_mae: 0.7249
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.9796 - mae: 0.7908
# Epoch 00012: val_loss improved from 6.46784 to 6.41951, saving model to models\conv1d_multivar\regression\12.hdf5
# 32/32 [==============================] - 13s 412ms/step - loss: 5.9749 - mae: 0.7904 - val_loss: 6.4195 - val_mae: 0.7295
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.9685 - mae: 0.8058
# Epoch 00013: val_loss improved from 6.41951 to 6.38067, saving model to models\conv1d_multivar\regression\13.hdf5
# 32/32 [==============================] - 15s 475ms/step - loss: 5.9656 - mae: 0.8060 - val_loss: 6.3807 - val_mae: 0.7391
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.8237 - mae: 0.8059
# Epoch 00014: val_loss improved from 6.38067 to 6.29830, saving model to models\conv1d_multivar\regression\14.hdf5
# 32/32 [==============================] - 13s 391ms/step - loss: 5.8249 - mae: 0.8096 - val_loss: 6.2983 - val_mae: 0.7334
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.7655 - mae: 0.7871
# Epoch 00015: val_loss improved from 6.29830 to 6.21637, saving model to models\conv1d_multivar\regression\15.hdf5
# 32/32 [==============================] - 13s 393ms/step - loss: 5.7645 - mae: 0.7890 - val_loss: 6.2164 - val_mae: 0.7160
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.7874 - mae: 0.8012
# Epoch 00016: val_loss improved from 6.21637 to 6.18519, saving model to models\conv1d_multivar\regression\16.hdf5
# 32/32 [==============================] - 16s 515ms/step - loss: 5.7678 - mae: 0.7959 - val_loss: 6.1852 - val_mae: 0.7182
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.7463 - mae: 0.7928
# Epoch 00017: val_loss improved from 6.18519 to 6.16995, saving model to models\conv1d_multivar\regression\17.hdf5
# 32/32 [==============================] - 13s 415ms/step - loss: 5.7336 - mae: 0.7908 - val_loss: 6.1700 - val_mae: 0.7252
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.6637 - mae: 0.7862
# Epoch 00018: val_loss improved from 6.16995 to 6.14737, saving model to models\conv1d_multivar\regression\18.hdf5
# 32/32 [==============================] - 12s 390ms/step - loss: 5.6600 - mae: 0.7852 - val_loss: 6.1474 - val_mae: 0.7296
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.6572 - mae: 0.8001
# Epoch 00019: val_loss improved from 6.14737 to 6.11269, saving model to models\conv1d_multivar\regression\19.hdf5
# 32/32 [==============================] - 13s 415ms/step - loss: 5.6483 - mae: 0.7994 - val_loss: 6.1127 - val_mae: 0.7289
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.5683 - mae: 0.7754
# Epoch 00020: val_loss improved from 6.11269 to 6.09414, saving model to models\conv1d_multivar\regression\20.hdf5
# 32/32 [==============================] - 13s 409ms/step - loss: 5.5753 - mae: 0.7740 - val_loss: 6.0941 - val_mae: 0.7298
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.5540 - mae: 0.7879
# Epoch 00021: val_loss improved from 6.09414 to 6.04953, saving model to models\conv1d_multivar\regression\21.hdf5
# 32/32 [==============================] - 13s 403ms/step - loss: 5.5648 - mae: 0.7907 - val_loss: 6.0495 - val_mae: 0.7192
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.6231 - mae: 0.8054
# Epoch 00022: val_loss improved from 6.04953 to 6.03449, saving model to models\conv1d_multivar\regression\22.hdf5
# 32/32 [==============================] - 15s 476ms/step - loss: 5.6044 - mae: 0.8007 - val_loss: 6.0345 - val_mae: 0.7208
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.6410 - mae: 0.8188
# Epoch 00023: val_loss improved from 6.03449 to 6.01848, saving model to models\conv1d_multivar\regression\23.hdf5
# 32/32 [==============================] - 12s 382ms/step - loss: 5.6418 - mae: 0.8200 - val_loss: 6.0185 - val_mae: 0.7204
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.5540 - mae: 0.8001
# Epoch 00024: val_loss improved from 6.01848 to 6.00340, saving model to models\conv1d_multivar\regression\24.hdf5
# 32/32 [==============================] - 13s 395ms/step - loss: 5.5499 - mae: 0.7982 - val_loss: 6.0034 - val_mae: 0.7218
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.5156 - mae: 0.7969
# Epoch 00025: val_loss improved from 6.00340 to 5.99431, saving model to models\conv1d_multivar\regression\25.hdf5
# 32/32 [==============================] - 13s 394ms/step - loss: 5.5199 - mae: 0.7982 - val_loss: 5.9943 - val_mae: 0.7216
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.5023 - mae: 0.7905
# Epoch 00026: val_loss improved from 5.99431 to 5.98891, saving model to models\conv1d_multivar\regression\26.hdf5
# 32/32 [==============================] - 12s 381ms/step - loss: 5.5031 - mae: 0.7916 - val_loss: 5.9889 - val_mae: 0.7233
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.4941 - mae: 0.7795
# Epoch 00027: val_loss improved from 5.98891 to 5.97830, saving model to models\conv1d_multivar\regression\27.hdf5
# 32/32 [==============================] - 12s 363ms/step - loss: 5.4882 - mae: 0.7799 - val_loss: 5.9783 - val_mae: 0.7223
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.4801 - mae: 0.7978
# Epoch 00028: val_loss improved from 5.97830 to 5.97588, saving model to models\conv1d_multivar\regression\28.hdf5
# 32/32 [==============================] - 11s 355ms/step - loss: 5.4742 - mae: 0.7973 - val_loss: 5.9759 - val_mae: 0.7249
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.4742 - mae: 0.7901
# Epoch 00029: val_loss improved from 5.97588 to 5.95519, saving model to models\conv1d_multivar\regression\29.hdf5
# 32/32 [==============================] - 13s 413ms/step - loss: 5.4967 - mae: 0.7927 - val_loss: 5.9552 - val_mae: 0.7207
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.4276 - mae: 0.7702
# Epoch 00030: val_loss did not improve from 5.95519
# 32/32 [==============================] - 12s 385ms/step - loss: 5.4183 - mae: 0.7706 - val_loss: 5.9573 - val_mae: 0.7231
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.5227 - mae: 0.8090
# Epoch 00031: val_loss improved from 5.95519 to 5.94803, saving model to models\conv1d_multivar\regression\31.hdf5
# 32/32 [==============================] - 12s 378ms/step - loss: 5.5078 - mae: 0.8060 - val_loss: 5.9480 - val_mae: 0.7218
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.4647 - mae: 0.7926
# Epoch 00032: val_loss improved from 5.94803 to 5.93509, saving model to models\conv1d_multivar\regression\32.hdf5
# 32/32 [==============================] - 12s 376ms/step - loss: 5.4810 - mae: 0.7958 - val_loss: 5.9351 - val_mae: 0.7187

# %%
def plot_regr_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'MSE', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'MAE', 'mae', 'val_mae')
    
plot_regr_history(regr_history);

# %% [markdown]
# ### Прогноз задачи регрессии

# %%
# загружаем последнюю эпоху с минимальным лоссом
multivariate_regression_conv1d.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret_test = multivariate_regression_conv1d.predict_generator(test_regr_gen, verbose=1)
# Out:
# 13/13 [==============================] - 1s 53ms/step

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret_test, figsize=(16, 10),
                                  datetime_unit='m', xlabel='Time', plot_data_slice=slice(1, None))

# %% [markdown]
# ## Задача классификации
#
# Прогнозируем направление изменения цены по сравнению с предыдущим периодом (**0** - снижение, **1** - рост).

# %%
model_class_name = 'classification'

# %%
train_clf_gen = ClassificationGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_clf_gen = ClassificationGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_clf_gen = ClassificationGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_classification_model(input_shape):
    inp, conv1d = build_conv1d_layers(input_shape, filters=(32, 16, 8))

    clf = Dense(64)(conv1d)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.25)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)

    return Model(inputs=[inp], outputs=[clf])

# %%
multivariate_classification_conv1d = build_classification_model(test_clf_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
multivariate_classification_conv1d.compile(optimizer=optimizer,
                                           loss={'clf': 'binary_crossentropy'},
                                           metrics={'clf': 'accuracy'})

multivariate_classification_conv1d.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 120, 18)]         0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 120, 32)           1760
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 120, 32)           128
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 120, 32)           0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 120, 32)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 120, 16)           1552
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 120, 16)           64
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 120, 16)           0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 120, 16)           0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 60, 16)            0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 60, 16)            784
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 60, 16)            64
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 60, 16)            0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 60, 16)            0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 60, 8)             392
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 60, 8)             32
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 60, 8)             0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 60, 8)             0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 30, 8)             0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 240)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                15424
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 64)                0
# _________________________________________________________________
# clf (Dense)                  (None, 1)                 65
# =================================================================
# Total params: 20,521
# Trainable params: 20,249
# Non-trainable params: 272
# _________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
clf_history = utils.train_model(multivariate_classification_conv1d,
                                model_save_dir, train_clf_gen, test_clf_gen,
                                callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.0495 - accuracy: 0.4919
# Epoch 00001: val_loss improved from inf to 6.66417, saving model to models\conv1d_multivar\classification\01.hdf5
# 32/32 [==============================] - 12s 379ms/step - loss: 7.0400 - accuracy: 0.4901 - val_loss: 6.6642 - val_accuracy: 0.4330
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.2353 - accuracy: 0.5302
# Epoch 00002: val_loss improved from 6.66417 to 5.81976, saving model to models\conv1d_multivar\classification\02.hdf5
# 32/32 [==============================] - 12s 369ms/step - loss: 6.2223 - accuracy: 0.5306 - val_loss: 5.8198 - val_accuracy: 0.4510
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 5.4896 - accuracy: 0.5081
# Epoch 00003: val_loss improved from 5.81976 to 5.10996, saving model to models\conv1d_multivar\classification\03.hdf5
# 32/32 [==============================] - 11s 358ms/step - loss: 5.4771 - accuracy: 0.5079 - val_loss: 5.1100 - val_accuracy: 0.4510
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.7868 - accuracy: 0.5312
# Epoch 00004: val_loss improved from 5.10996 to 4.44453, saving model to models\conv1d_multivar\classification\04.hdf5
# 32/32 [==============================] - 12s 368ms/step - loss: 4.7760 - accuracy: 0.5306 - val_loss: 4.4445 - val_accuracy: 0.4588
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 4.2859 - accuracy: 0.5575
# Epoch 00005: val_loss improved from 4.44453 to 4.14276, saving model to models\conv1d_multivar\classification\05.hdf5
# 32/32 [==============================] - 14s 426ms/step - loss: 4.2855 - accuracy: 0.5533 - val_loss: 4.1428 - val_accuracy: 0.4536
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.9770 - accuracy: 0.5383
# Epoch 00006: val_loss improved from 4.14276 to 3.84308, saving model to models\conv1d_multivar\classification\06.hdf5
# 32/32 [==============================] - 14s 423ms/step - loss: 3.9729 - accuracy: 0.5365 - val_loss: 3.8431 - val_accuracy: 0.4485
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.6812 - accuracy: 0.5565
# Epoch 00007: val_loss improved from 3.84308 to 3.57098, saving model to models\conv1d_multivar\classification\07.hdf5
# 32/32 [==============================] - 14s 431ms/step - loss: 3.6772 - accuracy: 0.5582 - val_loss: 3.5710 - val_accuracy: 0.4485
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.4304 - accuracy: 0.5544
# Epoch 00008: val_loss improved from 3.57098 to 3.32355, saving model to models\conv1d_multivar\classification\08.hdf5
# 32/32 [==============================] - 13s 404ms/step - loss: 3.4273 - accuracy: 0.5523 - val_loss: 3.3236 - val_accuracy: 0.4459
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 3.1825 - accuracy: 0.5454
# Epoch 00009: val_loss improved from 3.32355 to 3.09097, saving model to models\conv1d_multivar\classification\09.hdf5
# 32/32 [==============================] - 13s 394ms/step - loss: 3.1821 - accuracy: 0.5424 - val_loss: 3.0910 - val_accuracy: 0.4536
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.9836 - accuracy: 0.5464
# Epoch 00010: val_loss improved from 3.09097 to 2.97022, saving model to models\conv1d_multivar\classification\10.hdf5
# 32/32 [==============================] - 14s 424ms/step - loss: 2.9836 - accuracy: 0.5464 - val_loss: 2.9702 - val_accuracy: 0.4536
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.8803 - accuracy: 0.5615
# Epoch 00011: val_loss improved from 2.97022 to 2.86669, saving model to models\conv1d_multivar\classification\11.hdf5
# 32/32 [==============================] - 13s 411ms/step - loss: 2.8790 - accuracy: 0.5592 - val_loss: 2.8667 - val_accuracy: 0.4485
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.7873 - accuracy: 0.5232
# Epoch 00012: val_loss improved from 2.86669 to 2.75820, saving model to models\conv1d_multivar\classification\12.hdf5
# 32/32 [==============================] - 14s 422ms/step - loss: 2.7843 - accuracy: 0.5247 - val_loss: 2.7582 - val_accuracy: 0.4510
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.6742 - accuracy: 0.5504
# Epoch 00013: val_loss improved from 2.75820 to 2.66502, saving model to models\conv1d_multivar\classification\13.hdf5
# 32/32 [==============================] - 13s 412ms/step - loss: 2.6743 - accuracy: 0.5493 - val_loss: 2.6650 - val_accuracy: 0.4459
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.5868 - accuracy: 0.5433
# Epoch 00014: val_loss improved from 2.66502 to 2.58370, saving model to models\conv1d_multivar\classification\14.hdf5
# 32/32 [==============================] - 14s 430ms/step - loss: 2.5835 - accuracy: 0.5473 - val_loss: 2.5837 - val_accuracy: 0.4407
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.4821 - accuracy: 0.5665
# Epoch 00015: val_loss improved from 2.58370 to 2.53934, saving model to models\conv1d_multivar\classification\15.hdf5
# 32/32 [==============================] - 14s 430ms/step - loss: 2.4782 - accuracy: 0.5700 - val_loss: 2.5393 - val_accuracy: 0.4433
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.4411 - accuracy: 0.5726
# Epoch 00016: val_loss improved from 2.53934 to 2.50441, saving model to models\conv1d_multivar\classification\16.hdf5
# 32/32 [==============================] - 13s 396ms/step - loss: 2.4407 - accuracy: 0.5740 - val_loss: 2.5044 - val_accuracy: 0.4433
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.4135 - accuracy: 0.5413
# Epoch 00017: val_loss improved from 2.50441 to 2.46681, saving model to models\conv1d_multivar\classification\17.hdf5
# 32/32 [==============================] - 14s 437ms/step - loss: 2.4151 - accuracy: 0.5394 - val_loss: 2.4668 - val_accuracy: 0.4485
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.3675 - accuracy: 0.5484
# Epoch 00018: val_loss improved from 2.46681 to 2.42066, saving model to models\conv1d_multivar\classification\18.hdf5
# 32/32 [==============================] - 12s 366ms/step - loss: 2.3656 - accuracy: 0.5503 - val_loss: 2.4207 - val_accuracy: 0.4459
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.3088 - accuracy: 0.5645
# Epoch 00019: val_loss improved from 2.42066 to 2.37438, saving model to models\conv1d_multivar\classification\19.hdf5
# 32/32 [==============================] - 12s 361ms/step - loss: 2.3040 - accuracy: 0.5680 - val_loss: 2.3744 - val_accuracy: 0.4407
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2777 - accuracy: 0.5706
# Epoch 00020: val_loss improved from 2.37438 to 2.35487, saving model to models\conv1d_multivar\classification\20.hdf5
# 32/32 [==============================] - 11s 351ms/step - loss: 2.2780 - accuracy: 0.5710 - val_loss: 2.3549 - val_accuracy: 0.4485
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2684 - accuracy: 0.5565
# Epoch 00021: val_loss improved from 2.35487 to 2.33982, saving model to models\conv1d_multivar\classification\21.hdf5
# 32/32 [==============================] - 11s 357ms/step - loss: 2.2693 - accuracy: 0.5572 - val_loss: 2.3398 - val_accuracy: 0.4433
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2267 - accuracy: 0.5585
# Epoch 00022: val_loss improved from 2.33982 to 2.31934, saving model to models\conv1d_multivar\classification\22.hdf5
# 32/32 [==============================] - 11s 352ms/step - loss: 2.2300 - accuracy: 0.5533 - val_loss: 2.3193 - val_accuracy: 0.4459
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.2149 - accuracy: 0.5706
# Epoch 00023: val_loss improved from 2.31934 to 2.30017, saving model to models\conv1d_multivar\classification\23.hdf5
# 32/32 [==============================] - 13s 410ms/step - loss: 2.2154 - accuracy: 0.5680 - val_loss: 2.3002 - val_accuracy: 0.4407
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1989 - accuracy: 0.5534
# Epoch 00024: val_loss improved from 2.30017 to 2.28091, saving model to models\conv1d_multivar\classification\24.hdf5
# 32/32 [==============================] - 11s 350ms/step - loss: 2.2004 - accuracy: 0.5503 - val_loss: 2.2809 - val_accuracy: 0.4485
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1751 - accuracy: 0.5675
# Epoch 00025: val_loss improved from 2.28091 to 2.27400, saving model to models\conv1d_multivar\classification\25.hdf5
# 32/32 [==============================] - 11s 334ms/step - loss: 2.1758 - accuracy: 0.5680 - val_loss: 2.2740 - val_accuracy: 0.4485
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1601 - accuracy: 0.5796
# Epoch 00026: val_loss improved from 2.27400 to 2.26699, saving model to models\conv1d_multivar\classification\26.hdf5
# 32/32 [==============================] - 11s 339ms/step - loss: 2.1617 - accuracy: 0.5769 - val_loss: 2.2670 - val_accuracy: 0.4485
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1565 - accuracy: 0.5806
# Epoch 00027: val_loss improved from 2.26699 to 2.26236, saving model to models\conv1d_multivar\classification\27.hdf5
# 32/32 [==============================] - 11s 345ms/step - loss: 2.1554 - accuracy: 0.5809 - val_loss: 2.2624 - val_accuracy: 0.4510
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1557 - accuracy: 0.5585
# Epoch 00028: val_loss improved from 2.26236 to 2.25542, saving model to models\conv1d_multivar\classification\28.hdf5
# 32/32 [==============================] - 11s 336ms/step - loss: 2.1522 - accuracy: 0.5611 - val_loss: 2.2554 - val_accuracy: 0.4536
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1415 - accuracy: 0.5706
# Epoch 00029: val_loss improved from 2.25542 to 2.24719, saving model to models\conv1d_multivar\classification\29.hdf5
# 32/32 [==============================] - 10s 318ms/step - loss: 2.1435 - accuracy: 0.5661 - val_loss: 2.2472 - val_accuracy: 0.4510
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1325 - accuracy: 0.5605
# Epoch 00030: val_loss improved from 2.24719 to 2.24483, saving model to models\conv1d_multivar\classification\30.hdf5
# 32/32 [==============================] - 10s 325ms/step - loss: 2.1323 - accuracy: 0.5621 - val_loss: 2.2448 - val_accuracy: 0.4536
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1266 - accuracy: 0.5605
# Epoch 00031: val_loss improved from 2.24483 to 2.23944, saving model to models\conv1d_multivar\classification\31.hdf5
# 32/32 [==============================] - 10s 324ms/step - loss: 2.1245 - accuracy: 0.5611 - val_loss: 2.2394 - val_accuracy: 0.4536
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 31/32 [============================>.] - ETA: 0s - loss: 2.1150 - accuracy: 0.5756
# Epoch 00032: val_loss improved from 2.23944 to 2.23731, saving model to models\conv1d_multivar\classification\32.hdf5
# 32/32 [==============================] - 12s 370ms/step - loss: 2.1158 - accuracy: 0.5759 - val_loss: 2.2373 - val_accuracy: 0.4536

# %%
def plot_clf_history(hist):
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    plotHelpers.plot_train_history(ax[0], hist, 'Loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[1], hist, 'Accuracy', 'accuracy', 'val_accuracy')
    
plot_clf_history(clf_history);

# %% [markdown]
# ### Прогноз задачи классификации

# %%
# загружаем последнюю эпоху с минимальным лоссом
multivariate_classification_conv1d.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %%
pred_direction_proba = multivariate_classification_conv1d.predict_generator(test_clf_gen, verbose=1)

true_direction = test_clf_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 13/13 [==============================] - 1s 64ms/step
# 0.38150606

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([166, 222], dtype=int64)),
#  (array([0, 1]), array([151, 237], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.44      0.40      0.42       166
#            1       0.58      0.62      0.60       222
#
#     accuracy                           0.52       388
#    macro avg       0.51      0.51      0.51       388
# weighted avg       0.52      0.52      0.52       388

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[ 66, 100],
#        [ 85, 137]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.43708609, 0.42194093],
#        [0.56291391, 0.57805907]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# ## Многозадачная модель: одновременно регрессия и классификация

# %%
model_class_name = 'multitask'

# %%
train_multi_gen = MultitaskGenerator.create(train_mwf, batch_size=BATCH_SIZE)
# val_multi_gen = MultitaskGenerator.create(val_mwf, batch_size=BATCH_SIZE, shuffle=False)
test_multi_gen = MultitaskGenerator.create(test_mwf, batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_multitask_model(input_shape):
    inp, conv1d = build_conv1d_layers(input_shape, filters=(32, 16, 8))

    # первый выход: задача регрссии
    regr = Dense(64)(conv1d)
    regr = BatchNormalization()(regr)
    regr = LeakyReLU()(regr)
    regr = Dropout(0.25)(regr)
    regr = Dense(1, activation='linear', name='regr')(regr)

    # второй выход: задача классификации
    clf = Dense(64)(conv1d)
    clf = BatchNormalization()(clf)
    clf = LeakyReLU()(clf)
    clf = Dropout(0.25)(clf)
    clf = Dense(1, activation='sigmoid', name='clf')(clf)
    
    return Model(inputs=[inp], outputs=[regr, clf])

# %%
multivariate_multitask_conv1d = build_multitask_model(train_multi_gen.input_shape)

model_save_dir = make_model_save_dir(model_path_root, model_type_name, model_class_name)

# %% [markdown]
# #### Оптимизатор:

# %%
optimizer = Nadam(lr=0.001, clipnorm=0.5)

# %% [markdown]
# #### Функция потерь:

# %%
multivariate_multitask_conv1d.compile(optimizer=optimizer,
                                      loss={'regr': 'mse', 'clf': 'binary_crossentropy'},
                                      loss_weights={'regr': 1., 'clf': 1.},
                                      metrics={'regr': 'mae', 'clf' : 'accuracy'})

multivariate_multitask_conv1d.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 120, 18)]    0
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 120, 32)      1760        input[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 120, 32)      128         conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 120, 32)      0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 120, 32)      0           leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 120, 16)      1552        dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 120, 16)      64          conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 120, 16)      0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 120, 16)      0           leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 60, 16)       0           dropout_11[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 60, 16)       784         max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 60, 16)       64          conv1d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 60, 16)       0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 60, 16)       0           leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 60, 8)        392         dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 60, 8)        32          conv1d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 60, 8)        0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 60, 8)        0           leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 30, 8)        0           dropout_13[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 240)          0           max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           15424       flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           15424       flatten_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64)           256         dense_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64)           256         dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 64)           0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 64)           0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 64)           0           leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 64)           0           leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# regr (Dense)                    (None, 1)            65          dropout_14[0][0]
# __________________________________________________________________________________________________
# clf (Dense)                     (None, 1)            65          dropout_15[0][0]
# ==================================================================================================
# Total params: 36,266
# Trainable params: 35,866
# Non-trainable params: 400
# __________________________________________________________________________________________________

# %% [markdown]
# #### Дополнительные коллбэки:

# %%
checkpointer = ModelCheckpoint(monitor='val_loss', verbose=1, save_best_only=True,
                               filepath=os.path.join(model_save_dir, '{epoch:02d}.hdf5'))

earlyStopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, verbose=1)

# %% [markdown]
# #### Обучение:

# %%
multitask_history = utils.train_model(multivariate_multitask_conv1d,
                                      model_save_dir, train_multi_gen, test_multi_gen,
                                      callbacks=[reduce_lr, lr_scheduler, checkpointer, earlyStopping],
                                      force_train=FORCE_TRAIN, verbose=1)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/32
# 31/32 [============================>.] - ETA: 0s - loss: 9.4716 - regr_loss: 2.1286 - clf_loss: 0.8277 - regr_mae: 1.0897 - clf_accuracy: 0.4657
# Epoch 00001: val_loss improved from inf to 8.67800, saving model to models\conv1d_multivar\multitask\01.hdf5
# 32/32 [==============================] - 15s 470ms/step - loss: 9.4594 - regr_loss: 2.1208 - clf_loss: 0.8261 - regr_mae: 1.0876 - clf_accuracy: 0.4675 - val_loss: 8.6780 - val_regr_loss: 1.5458 - val_clf_loss: 0.7157 - val_regr_mae: 0.6894 - val_clf_accuracy: 0.5129
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.6985 - regr_loss: 1.6188 - clf_loss: 0.7624 - regr_mae: 0.9575 - clf_accuracy: 0.5181
# Epoch 00002: val_loss improved from 8.67800 to 8.35955, saving model to models\conv1d_multivar\multitask\02.hdf5
# 32/32 [==============================] - 14s 426ms/step - loss: 8.6763 - regr_loss: 1.6006 - clf_loss: 0.7616 - regr_mae: 0.9542 - clf_accuracy: 0.5187 - val_loss: 8.3595 - val_regr_loss: 1.4475 - val_clf_loss: 0.7105 - val_regr_mae: 0.6400 - val_clf_accuracy: 0.4845
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/32
# 31/32 [============================>.] - ETA: 0s - loss: 8.3015 - regr_loss: 1.4443 - clf_loss: 0.7611 - regr_mae: 0.9126 - clf_accuracy: 0.5010
# Epoch 00003: val_loss improved from 8.35955 to 8.10151, saving model to models\conv1d_multivar\multitask\03.hdf5
# 32/32 [==============================] - 14s 433ms/step - loss: 8.2754 - regr_loss: 1.4232 - clf_loss: 0.7595 - regr_mae: 0.9080 - clf_accuracy: 0.5000 - val_loss: 8.1015 - val_regr_loss: 1.4221 - val_clf_loss: 0.7064 - val_regr_mae: 0.6343 - val_clf_accuracy: 0.4948
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.9412 - regr_loss: 1.3527 - clf_loss: 0.7287 - regr_mae: 0.8796 - clf_accuracy: 0.5333
# Epoch 00004: val_loss improved from 8.10151 to 7.88233, saving model to models\conv1d_multivar\multitask\04.hdf5
# 32/32 [==============================] - 14s 436ms/step - loss: 7.9252 - regr_loss: 1.3391 - clf_loss: 0.7300 - regr_mae: 0.8767 - clf_accuracy: 0.5316 - val_loss: 7.8823 - val_regr_loss: 1.4362 - val_clf_loss: 0.7154 - val_regr_mae: 0.6396 - val_clf_accuracy: 0.4974
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.6046 - regr_loss: 1.2216 - clf_loss: 0.7109 - regr_mae: 0.8328 - clf_accuracy: 0.5363
# Epoch 00005: val_loss improved from 7.88233 to 7.76704, saving model to models\conv1d_multivar\multitask\05.hdf5
# 32/32 [==============================] - 14s 427ms/step - loss: 7.6226 - regr_loss: 1.2403 - clf_loss: 0.7124 - regr_mae: 0.8337 - clf_accuracy: 0.5345 - val_loss: 7.7670 - val_regr_loss: 1.4452 - val_clf_loss: 0.7167 - val_regr_mae: 0.6398 - val_clf_accuracy: 0.5000
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.5417 - regr_loss: 1.2921 - clf_loss: 0.7052 - regr_mae: 0.8561 - clf_accuracy: 0.5635
# Epoch 00006: val_loss improved from 7.76704 to 7.63429, saving model to models\conv1d_multivar\multitask\06.hdf5
# 32/32 [==============================] - 14s 428ms/step - loss: 7.5374 - regr_loss: 1.2913 - clf_loss: 0.7037 - regr_mae: 0.8574 - clf_accuracy: 0.5651 - val_loss: 7.6343 - val_regr_loss: 1.4391 - val_clf_loss: 0.7201 - val_regr_mae: 0.6406 - val_clf_accuracy: 0.4871
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.3807 - regr_loss: 1.2724 - clf_loss: 0.6946 - regr_mae: 0.8455 - clf_accuracy: 0.5575
# Epoch 00007: val_loss improved from 7.63429 to 7.52042, saving model to models\conv1d_multivar\multitask\07.hdf5
# 32/32 [==============================] - 14s 423ms/step - loss: 7.3861 - regr_loss: 1.2802 - clf_loss: 0.6944 - regr_mae: 0.8486 - clf_accuracy: 0.5562 - val_loss: 7.5204 - val_regr_loss: 1.4455 - val_clf_loss: 0.7313 - val_regr_mae: 0.6518 - val_clf_accuracy: 0.4897
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.2779 - regr_loss: 1.2793 - clf_loss: 0.7178 - regr_mae: 0.8435 - clf_accuracy: 0.5554
# Epoch 00008: val_loss improved from 7.52042 to 7.40005, saving model to models\conv1d_multivar\multitask\08.hdf5
# 32/32 [==============================] - 14s 428ms/step - loss: 7.2623 - regr_loss: 1.2654 - clf_loss: 0.7180 - regr_mae: 0.8412 - clf_accuracy: 0.5552 - val_loss: 7.4001 - val_regr_loss: 1.4470 - val_clf_loss: 0.7432 - val_regr_mae: 0.6524 - val_clf_accuracy: 0.4613
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/32
# 31/32 [============================>.] - ETA: 0s - loss: 7.0950 - regr_loss: 1.2281 - clf_loss: 0.7206 - regr_mae: 0.8289 - clf_accuracy: 0.5302
# Epoch 00009: val_loss improved from 7.40005 to 7.25721, saving model to models\conv1d_multivar\multitask\09.hdf5
# 32/32 [==============================] - 14s 439ms/step - loss: 7.0655 - regr_loss: 1.2010 - clf_loss: 0.7201 - regr_mae: 0.8216 - clf_accuracy: 0.5286 - val_loss: 7.2572 - val_regr_loss: 1.4379 - val_clf_loss: 0.7449 - val_regr_mae: 0.6484 - val_clf_accuracy: 0.4613
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.9804 - regr_loss: 1.2466 - clf_loss: 0.6912 - regr_mae: 0.8281 - clf_accuracy: 0.5726
# Epoch 00010: val_loss improved from 7.25721 to 7.22172, saving model to models\conv1d_multivar\multitask\10.hdf5
# 32/32 [==============================] - 14s 442ms/step - loss: 6.9708 - regr_loss: 1.2427 - clf_loss: 0.6864 - regr_mae: 0.8273 - clf_accuracy: 0.5759 - val_loss: 7.2217 - val_regr_loss: 1.4674 - val_clf_loss: 0.7481 - val_regr_mae: 0.6627 - val_clf_accuracy: 0.4716
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.8550 - regr_loss: 1.1894 - clf_loss: 0.6920 - regr_mae: 0.8261 - clf_accuracy: 0.5817
# Epoch 00011: val_loss improved from 7.22172 to 7.12665, saving model to models\conv1d_multivar\multitask\11.hdf5
# 32/32 [==============================] - 14s 445ms/step - loss: 6.8581 - regr_loss: 1.1901 - clf_loss: 0.6955 - regr_mae: 0.8258 - clf_accuracy: 0.5819 - val_loss: 7.1266 - val_regr_loss: 1.4446 - val_clf_loss: 0.7455 - val_regr_mae: 0.6503 - val_clf_accuracy: 0.4613
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.8166 - regr_loss: 1.2032 - clf_loss: 0.7098 - regr_mae: 0.8130 - clf_accuracy: 0.5423
# Epoch 00012: val_loss improved from 7.12665 to 7.04519, saving model to models\conv1d_multivar\multitask\12.hdf5
# 32/32 [==============================] - 14s 422ms/step - loss: 6.8131 - regr_loss: 1.1990 - clf_loss: 0.7115 - regr_mae: 0.8132 - clf_accuracy: 0.5404 - val_loss: 7.0452 - val_regr_loss: 1.4349 - val_clf_loss: 0.7436 - val_regr_mae: 0.6444 - val_clf_accuracy: 0.4845
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 13/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.6922 - regr_loss: 1.1601 - clf_loss: 0.6984 - regr_mae: 0.8057 - clf_accuracy: 0.5544
# Epoch 00013: val_loss improved from 7.04519 to 6.96992, saving model to models\conv1d_multivar\multitask\13.hdf5
# 32/32 [==============================] - 14s 429ms/step - loss: 6.6832 - regr_loss: 1.1512 - clf_loss: 0.6992 - regr_mae: 0.8048 - clf_accuracy: 0.5503 - val_loss: 6.9699 - val_regr_loss: 1.4301 - val_clf_loss: 0.7433 - val_regr_mae: 0.6396 - val_clf_accuracy: 0.4897
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 14/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.6763 - regr_loss: 1.2041 - clf_loss: 0.7087 - regr_mae: 0.8190 - clf_accuracy: 0.5514
# Epoch 00014: val_loss improved from 6.96992 to 6.89363, saving model to models\conv1d_multivar\multitask\14.hdf5
# 32/32 [==============================] - 14s 424ms/step - loss: 6.6605 - regr_loss: 1.1907 - clf_loss: 0.7073 - regr_mae: 0.8166 - clf_accuracy: 0.5513 - val_loss: 6.8936 - val_regr_loss: 1.4255 - val_clf_loss: 0.7425 - val_regr_mae: 0.6363 - val_clf_accuracy: 0.5000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.5884 - regr_loss: 1.1710 - clf_loss: 0.7087 - regr_mae: 0.8113 - clf_accuracy: 0.5494
# Epoch 00015: val_loss improved from 6.89363 to 6.86736, saving model to models\conv1d_multivar\multitask\15.hdf5
# 32/32 [==============================] - 14s 422ms/step - loss: 6.5728 - regr_loss: 1.1578 - clf_loss: 0.7067 - regr_mae: 0.8079 - clf_accuracy: 0.5533 - val_loss: 6.8674 - val_regr_loss: 1.4320 - val_clf_loss: 0.7461 - val_regr_mae: 0.6390 - val_clf_accuracy: 0.4742
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 16/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.5027 - regr_loss: 1.1352 - clf_loss: 0.6952 - regr_mae: 0.7880 - clf_accuracy: 0.5524
# Epoch 00016: val_loss improved from 6.86736 to 6.83154, saving model to models\conv1d_multivar\multitask\16.hdf5
# 32/32 [==============================] - 14s 429ms/step - loss: 6.5012 - regr_loss: 1.1357 - clf_loss: 0.6937 - regr_mae: 0.7896 - clf_accuracy: 0.5523 - val_loss: 6.8315 - val_regr_loss: 1.4318 - val_clf_loss: 0.7466 - val_regr_mae: 0.6371 - val_clf_accuracy: 0.4871
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 17/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.5184 - regr_loss: 1.1610 - clf_loss: 0.7215 - regr_mae: 0.8034 - clf_accuracy: 0.5423
# Epoch 00017: val_loss improved from 6.83154 to 6.81866, saving model to models\conv1d_multivar\multitask\17.hdf5
# 32/32 [==============================] - 14s 445ms/step - loss: 6.5048 - regr_loss: 1.1485 - clf_loss: 0.7209 - regr_mae: 0.8008 - clf_accuracy: 0.5414 - val_loss: 6.8187 - val_regr_loss: 1.4539 - val_clf_loss: 0.7484 - val_regr_mae: 0.6467 - val_clf_accuracy: 0.4871
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 18/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.5151 - regr_loss: 1.2132 - clf_loss: 0.7029 - regr_mae: 0.8156 - clf_accuracy: 0.5464
# Epoch 00018: val_loss improved from 6.81866 to 6.76489, saving model to models\conv1d_multivar\multitask\18.hdf5
# 32/32 [==============================] - 13s 404ms/step - loss: 6.5116 - regr_loss: 1.2093 - clf_loss: 0.7038 - regr_mae: 0.8151 - clf_accuracy: 0.5444 - val_loss: 6.7649 - val_regr_loss: 1.4406 - val_clf_loss: 0.7449 - val_regr_mae: 0.6398 - val_clf_accuracy: 0.4923
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 19/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.3205 - regr_loss: 1.0755 - clf_loss: 0.6829 - regr_mae: 0.7654 - clf_accuracy: 0.5827
# Epoch 00019: val_loss improved from 6.76489 to 6.71168, saving model to models\conv1d_multivar\multitask\19.hdf5
# 32/32 [==============================] - 14s 438ms/step - loss: 6.3195 - regr_loss: 1.0730 - clf_loss: 0.6849 - regr_mae: 0.7648 - clf_accuracy: 0.5809 - val_loss: 6.7117 - val_regr_loss: 1.4287 - val_clf_loss: 0.7406 - val_regr_mae: 0.6333 - val_clf_accuracy: 0.4948
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 20/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.3861 - regr_loss: 1.1650 - clf_loss: 0.6875 - regr_mae: 0.8061 - clf_accuracy: 0.5786
# Epoch 00020: val_loss improved from 6.71168 to 6.69948, saving model to models\conv1d_multivar\multitask\20.hdf5
# 32/32 [==============================] - 17s 521ms/step - loss: 6.3930 - regr_loss: 1.1709 - clf_loss: 0.6890 - regr_mae: 0.8075 - clf_accuracy: 0.5730 - val_loss: 6.6995 - val_regr_loss: 1.4343 - val_clf_loss: 0.7416 - val_regr_mae: 0.6356 - val_clf_accuracy: 0.4923
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 21/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.3448 - regr_loss: 1.1431 - clf_loss: 0.6871 - regr_mae: 0.7954 - clf_accuracy: 0.5746
# Epoch 00021: val_loss improved from 6.69948 to 6.68411, saving model to models\conv1d_multivar\multitask\21.hdf5
# 32/32 [==============================] - 15s 464ms/step - loss: 6.3406 - regr_loss: 1.1380 - clf_loss: 0.6882 - regr_mae: 0.7953 - clf_accuracy: 0.5730 - val_loss: 6.6841 - val_regr_loss: 1.4365 - val_clf_loss: 0.7430 - val_regr_mae: 0.6354 - val_clf_accuracy: 0.4974
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 22/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.3475 - regr_loss: 1.1565 - clf_loss: 0.6952 - regr_mae: 0.8039 - clf_accuracy: 0.5827
# Epoch 00022: val_loss improved from 6.68411 to 6.67019, saving model to models\conv1d_multivar\multitask\22.hdf5
# 32/32 [==============================] - 14s 442ms/step - loss: 6.3391 - regr_loss: 1.1489 - clf_loss: 0.6945 - regr_mae: 0.8034 - clf_accuracy: 0.5838 - val_loss: 6.6702 - val_regr_loss: 1.4383 - val_clf_loss: 0.7461 - val_regr_mae: 0.6361 - val_clf_accuracy: 0.4948
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 23/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.2936 - regr_loss: 1.1247 - clf_loss: 0.6920 - regr_mae: 0.7875 - clf_accuracy: 0.5514
# Epoch 00023: val_loss improved from 6.67019 to 6.65029, saving model to models\conv1d_multivar\multitask\23.hdf5
# 32/32 [==============================] - 16s 490ms/step - loss: 6.2823 - regr_loss: 1.1128 - clf_loss: 0.6928 - regr_mae: 0.7854 - clf_accuracy: 0.5493 - val_loss: 6.6503 - val_regr_loss: 1.4391 - val_clf_loss: 0.7444 - val_regr_mae: 0.6363 - val_clf_accuracy: 0.4974
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 6.25000029685907e-05.
# Epoch 24/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.3726 - regr_loss: 1.2295 - clf_loss: 0.6852 - regr_mae: 0.8048 - clf_accuracy: 0.5625
# Epoch 00024: val_loss improved from 6.65029 to 6.63819, saving model to models\conv1d_multivar\multitask\24.hdf5
# 32/32 [==============================] - 16s 488ms/step - loss: 6.3604 - regr_loss: 1.2147 - clf_loss: 0.6880 - regr_mae: 0.8029 - clf_accuracy: 0.5582 - val_loss: 6.6382 - val_regr_loss: 1.4442 - val_clf_loss: 0.7462 - val_regr_mae: 0.6390 - val_clf_accuracy: 0.4974
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 25/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.2372 - regr_loss: 1.1210 - clf_loss: 0.6729 - regr_mae: 0.7868 - clf_accuracy: 0.5806
# Epoch 00025: val_loss improved from 6.63819 to 6.63116, saving model to models\conv1d_multivar\multitask\25.hdf5
# 32/32 [==============================] - 20s 617ms/step - loss: 6.2214 - regr_loss: 1.1059 - clf_loss: 0.6723 - regr_mae: 0.7844 - clf_accuracy: 0.5838 - val_loss: 6.6312 - val_regr_loss: 1.4455 - val_clf_loss: 0.7476 - val_regr_mae: 0.6396 - val_clf_accuracy: 0.4897
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 26/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.1944 - regr_loss: 1.0729 - clf_loss: 0.6879 - regr_mae: 0.7572 - clf_accuracy: 0.5887
# Epoch 00026: val_loss improved from 6.63116 to 6.62414, saving model to models\conv1d_multivar\multitask\26.hdf5
# 32/32 [==============================] - 19s 601ms/step - loss: 6.2004 - regr_loss: 1.0786 - clf_loss: 0.6884 - regr_mae: 0.7607 - clf_accuracy: 0.5878 - val_loss: 6.6241 - val_regr_loss: 1.4490 - val_clf_loss: 0.7469 - val_regr_mae: 0.6415 - val_clf_accuracy: 0.4948
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 27/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.2149 - regr_loss: 1.1055 - clf_loss: 0.6858 - regr_mae: 0.7859 - clf_accuracy: 0.5827
# Epoch 00027: val_loss improved from 6.62414 to 6.61743, saving model to models\conv1d_multivar\multitask\27.hdf5
# 32/32 [==============================] - 17s 543ms/step - loss: 6.2312 - regr_loss: 1.1213 - clf_loss: 0.6865 - regr_mae: 0.7889 - clf_accuracy: 0.5809 - val_loss: 6.6174 - val_regr_loss: 1.4517 - val_clf_loss: 0.7472 - val_regr_mae: 0.6429 - val_clf_accuracy: 0.4948
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 28/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.2546 - regr_loss: 1.1572 - clf_loss: 0.6835 - regr_mae: 0.7780 - clf_accuracy: 0.5665
# Epoch 00028: val_loss improved from 6.61743 to 6.60810, saving model to models\conv1d_multivar\multitask\28.hdf5
# 32/32 [==============================] - 16s 494ms/step - loss: 6.2471 - regr_loss: 1.1524 - clf_loss: 0.6809 - regr_mae: 0.7784 - clf_accuracy: 0.5680 - val_loss: 6.6081 - val_regr_loss: 1.4517 - val_clf_loss: 0.7477 - val_regr_mae: 0.6426 - val_clf_accuracy: 0.4897
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.125000148429535e-05.
# Epoch 29/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.2415 - regr_loss: 1.1286 - clf_loss: 0.7088 - regr_mae: 0.7973 - clf_accuracy: 0.5333
# Epoch 00029: val_loss improved from 6.60810 to 6.59630, saving model to models\conv1d_multivar\multitask\29.hdf5
# 32/32 [==============================] - 15s 472ms/step - loss: 6.2720 - regr_loss: 1.1623 - clf_loss: 0.7060 - regr_mae: 0.7998 - clf_accuracy: 0.5365 - val_loss: 6.5963 - val_regr_loss: 1.4493 - val_clf_loss: 0.7480 - val_regr_mae: 0.6407 - val_clf_accuracy: 0.4948
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 30/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.2027 - regr_loss: 1.1242 - clf_loss: 0.6820 - regr_mae: 0.7775 - clf_accuracy: 0.5615
# Epoch 00030: val_loss improved from 6.59630 to 6.59416, saving model to models\conv1d_multivar\multitask\30.hdf5
# 32/32 [==============================] - 14s 445ms/step - loss: 6.1924 - regr_loss: 1.1157 - clf_loss: 0.6801 - regr_mae: 0.7766 - clf_accuracy: 0.5621 - val_loss: 6.5942 - val_regr_loss: 1.4516 - val_clf_loss: 0.7487 - val_regr_mae: 0.6422 - val_clf_accuracy: 0.4897
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.2404 - regr_loss: 1.1533 - clf_loss: 0.6955 - regr_mae: 0.7946 - clf_accuracy: 0.5423
# Epoch 00031: val_loss improved from 6.59416 to 6.58808, saving model to models\conv1d_multivar\multitask\31.hdf5
# 32/32 [==============================] - 15s 475ms/step - loss: 6.2428 - regr_loss: 1.1566 - clf_loss: 0.6947 - regr_mae: 0.7958 - clf_accuracy: 0.5444 - val_loss: 6.5881 - val_regr_loss: 1.4502 - val_clf_loss: 0.7490 - val_regr_mae: 0.6417 - val_clf_accuracy: 0.4923
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/32
# 31/32 [============================>.] - ETA: 0s - loss: 6.2146 - regr_loss: 1.1367 - clf_loss: 0.6913 - regr_mae: 0.7907 - clf_accuracy: 0.5655
# Epoch 00032: val_loss improved from 6.58808 to 6.58230, saving model to models\conv1d_multivar\multitask\32.hdf5
# 32/32 [==============================] - 16s 499ms/step - loss: 6.2318 - regr_loss: 1.1536 - clf_loss: 0.6919 - regr_mae: 0.7905 - clf_accuracy: 0.5621 - val_loss: 6.5823 - val_regr_loss: 1.4503 - val_clf_loss: 0.7481 - val_regr_mae: 0.6417 - val_clf_accuracy: 0.5000

# %%
def plot_multitask_history(hist):
    fig, ax = plt.subplots(2, 2, figsize=(16, 12))
    plotHelpers.plot_train_history(ax[0, 0], hist, 'Total loss', 'loss', 'val_loss')
    plotHelpers.plot_train_history(ax[0, 1], hist, 'Accuracy', 'clf_accuracy', 'val_clf_accuracy')
    plotHelpers.plot_train_history(ax[1, 0], hist, 'MSE', 'regr_loss', 'val_regr_loss')
    plotHelpers.plot_train_history(ax[1, 1], hist, 'MAE', 'regr_mae', 'val_regr_mae')
    
plot_multitask_history(multitask_history);

# %% [markdown]
# ### Прогноз

# %%
# загружаем последнюю эпоху с минимальным лоссом
multivariate_multitask_conv1d.load_weights(sorted(glob.glob(os.path.join(model_save_dir,'*.hdf5')))[-1])

# %% [markdown]
# #### На тесте:

# %%
pred_log_ret, pred_direction_proba = multivariate_multitask_conv1d.predict_generator(test_multi_gen, verbose=1)
# Out:
# 13/13 [==============================] - 1s 68ms/step

# %%
np.set_printoptions(precision=3, suppress=True)

np.column_stack([pred_log_ret, pred_direction_proba])[-10:]
# Out:
# array([[-0.14 ,  0.527],
#        [ 0.02 ,  0.54 ],
#        [ 0.286,  0.646],
#        [ 0.067,  0.554],
#        [ 0.299,  0.614],
#        [ 0.127,  0.546],
#        [ 0.092,  0.547],
#        [ 0.146,  0.565],
#        [ 0.153,  0.517],
#        [-0.094,  0.422]], dtype=float32)

# %% [markdown]
# #### Прогноз задачи регрессии

# %%
plotHelpers.plot_regr_predictions(orig_target, instr_test, pred_log_ret, figsize=(16, 10),
                                  datetime_unit='m', xlabel='Time', plot_data_slice=slice(1, None))

# %% [markdown]
# #### Прогноз задачи классификации

# %%
true_direction = test_multi_gen.get_target_direction(test_mwf.target[-len(pred_direction_proba):])

predicted_direction = (np.mean(pred_direction_proba) < pred_direction_proba).astype(np.int)

np.mean(pred_direction_proba)
# Out:
# 0.43086165

# %%
np.unique(true_direction, return_counts=True), \
np.unique(predicted_direction, return_counts=True)
# Out:
# ((array([0, 1]), array([166, 222], dtype=int64)),
#  (array([0, 1]), array([167, 221], dtype=int64)))

# %%
plt.hist(pred_direction_proba, bins=20)
plt.axvline(np.mean(pred_direction_proba), c='r');

# %%
print(classification_report(true_direction, predicted_direction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.47      0.47      0.47       166
#            1       0.60      0.60      0.60       222
#
#     accuracy                           0.54       388
#    macro avg       0.53      0.53      0.53       388
# weighted avg       0.54      0.54      0.54       388

# %%
confusion_matrix(true_direction, predicted_direction)
# Out:
# array([[ 78,  88],
#        [ 89, 133]], dtype=int64)

# %%
plotHelpers.show_confusion_matrix(true_direction, predicted_direction, ['down', 'up'])
# Out:
# array([[0.467, 0.398],
#        [0.533, 0.602]])

# %%
plotHelpers.plot_roc_pr_curves(true_direction, pred_direction_proba)

# %% [markdown]
# # Выводы
#
# 1.  Модель с 1D свёртками обучается гораздо быстрее модели LSTM
# 2.  Задача классификации не решается удовлетворительно.
